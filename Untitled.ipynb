# %%
# %matplotlib inline

# %%
loans = [
    { "amount" : """0.4""" },
    { "amount" : """0.35""" },
    { "amount" : """0.6""" },
    { "amount" : """0.7""" },
    { "amount" : """2.5""" },
    { "amount" : """0.3""" },
    { "amount" : """5""" },
    { "amount" : """5""" },
    { "amount" : """10""" },
    { "amount" : """6""" },
    { "amount" : """0.25""" },
    { "amount" : """0.75""" },
    { "amount" : """7.5""" },
    { "amount" : """3""" },
    { "amount" : """4.75""" },
    { "amount" : """7""" },
    { "amount" : """1""" },
    { "amount" : """3""" },
    { "amount" : """1.25""" },
    { "amount" : """0.31""" },
    { "amount" : """0.06""" },
    { "amount" : """5""" },
    { "amount" : """2.1""" },
    { "amount" : """2.2""" },
    { "amount" : """5""" },
    { "amount" : """2""" },
    { "amount" : """3""" },
    { "amount" : """5""" },
    { "amount" : """0.4""" },
    { "amount" : """5""" },
    { "amount" : """5""" },
    { "amount" : """2""" },
    { "amount" : """0.3""" },
    { "amount" : """0.2345""" },
    { "amount" : """0.31""" },
    { "amount" : """2""" },
    { "amount" : """3""" },
    { "amount" : """5""" },
    { "amount" : """1.5""" },
    { "amount" : """1""" },
    { "amount" : """1""" },
    { "amount" : """5""" },
    { "amount" : """0.956""" },
    { "amount" : """0.5678""" },
    { "amount" : """5""" },
    { "amount" : """1""" },
    { "amount" : """0.5""" },
    { "amount" : """1""" },
    { "amount" : """0.0082""" },
    { "amount" : """4""" },
    { "amount" : """1""" },
    { "amount" : """2.5""" },
    { "amount" : """0.5""" },
    { "amount" : """2.5""" },
    { "amount" : """1.5""" },
    { "amount" : """1.5""" },
    { "amount" : """5""" },
    { "amount" : """0.06""" },
    { "amount" : """10""" },
    { "amount" : """1""" },
    { "amount" : """2.5""" },
    { "amount" : """0.3""" },
    { "amount" : """0.19""" },
    { "amount" : """5""" },
    { "amount" : """5""" },
    { "amount" : """0.5""" },
    { "amount" : """2""" },
    { "amount" : """7.5""" },
    { "amount" : """1""" },
    { "amount" : """0.5""" },
    { "amount" : """2.25""" },
    { "amount" : """1""" },
    { "amount" : """3.6""" },
    { "amount" : """1""" },
    { "amount" : """0.5""" },
    { "amount" : """0.25""" },
    { "amount" : """0.3""" },
    { "amount" : """1.1""" },
    { "amount" : """0.3""" },
    { "amount" : """11""" },
    { "amount" : """3""" },
    { "amount" : """1""" },
    { "amount" : """4""" },
    { "amount" : """1""" },
    { "amount" : """5""" },
    { "amount" : """0.0001""" },
    { "amount" : """0.3""" },
    { "amount" : """0.3""" },
    { "amount" : """2""" },
    { "amount" : """2.0005""" },
    { "amount" : """1""" },
    { "amount" : """2""" },
    { "amount" : """2""" },
    { "amount" : """0.0001""" },
    { "amount" : """1""" },
    { "amount" : """0.0001""" },
    { "amount" : """0.1""" },
    { "amount" : """1.5""" },
    { "amount" : """0.1""" },
    { "amount" : """3""" },
    { "amount" : """0.1""" },
    { "amount" : """0.1""" },
    { "amount" : """0.2""" },
    { "amount" : """0.5""" },
    { "amount" : """3""" },
    { "amount" : """0.5""" },
    { "amount" : """0.001""" },
    { "amount" : """0.001""" },
    { "amount" : """0.05""" },
    { "amount" : """0.5""" },
    { "amount" : """1.3""" },
    { "amount" : """2""" },
    { "amount" : """0.5""" },
    { "amount" : """0.1""" },
    { "amount" : """0.7""" },
    { "amount" : """2.5""" },
    { "amount" : """0.8""" },
    { "amount" : """0.6""" },
    { "amount" : """0.2""" },
    { "amount" : """2""" },
    { "amount" : """2""" },
    { "amount" : """2""" },
    { "amount" : """0.0024""" },
    { "amount" : """2.5""" },
    { "amount" : """0.6143""" },
    { "amount" : """0.7""" },
    { "amount" : """5""" },
    { "amount" : """2""" },
    { "amount" : """1.35""" },
    { "amount" : """2""" },
    { "amount" : """0.5""" },
    { "amount" : """7""" },
    { "amount" : """1.05""" },
    { "amount" : """2""" },
    { "amount" : """0.3""" },
    { "amount" : """1""" },
    { "amount" : """5""" },
    { "amount" : """3.5""" },
    { "amount" : """4.5""" },
    { "amount" : """0.4""" },
    { "amount" : """0.2""" },
    { "amount" : """0.2""" },
    { "amount" : """1.8""" },
    { "amount" : """0.2""" },
    { "amount" : """1.7""" },
    { "amount" : """1""" },
    { "amount" : """1""" },
    { "amount" : """1.5""" },
    { "amount" : """1.5""" },
    { "amount" : """2""" },
    { "amount" : """2""" },
    { "amount" : """0.1""" },
    { "amount" : """6""" },
    { "amount" : """7""" },
    { "amount" : """1.1""" },
    { "amount" : """0.2""" },
    { "amount" : """0.01""" },
    { "amount" : """2.5""" },
    { "amount" : """2.5""" },
    { "amount" : """0.2""" },
    { "amount" : """3""" },
    { "amount" : """3""" },
    { "amount" : """7""" },
    { "amount" : """5""" },
    { "amount" : """2""" },
    { "amount" : """0.75""" },
    { "amount" : """0.6""" },
    { "amount" : """0.5""" },
    { "amount" : """9""" },
    { "amount" : """0.05""" },
    { "amount" : """0.5""" },
    { "amount" : """2""" },
    { "amount" : """1.2""" },
    { "amount" : """3""" },
    { "amount" : """0.8""" },
    { "amount" : """2.25""" },
    { "amount" : """0.5""" },
    { "amount" : """3.86""" },
    { "amount" : """1.5""" },
    { "amount" : """1.0001""" },
    { "amount" : """0.1""" },
    { "amount" : """0.25""" },
    { "amount" : """0.65""" },
    { "amount" : """0.1""" },
    { "amount" : """10""" },
    { "amount" : """0.1""" },
    { "amount" : """1""" },
    { "amount" : """3""" },
    { "amount" : """14""" },
    { "amount" : """3""" },
    { "amount" : """6""" },
    { "amount" : """0.1""" },
    { "amount" : """0.05""" },
    { "amount" : """0.2""" },
    { "amount" : """0.05""" },
    { "amount" : """2.5""" },
    { "amount" : """0.5""" },
    { "amount" : """0.05""" },
    { "amount" : """0.5""" },
    { "amount" : """1.8""" },
    { "amount" : """0.09""" },
    { "amount" : """2.5""" },
    { "amount" : """0.05""" },
    { "amount" : """1""" },
    { "amount" : """0.5""" },
    { "amount" : """10""" },
    { "amount" : """0.5""" },
    { "amount" : """0.5""" },
    { "amount" : """0.06""" },
    { "amount" : """0.09""" },
    { "amount" : """2""" },
    { "amount" : """0.2""" },
    { "amount" : """0.03""" },
    { "amount" : """0.1""" },
    { "amount" : """0.1""" },
    { "amount" : """0.09""" },
    { "amount" : """0.5""" },
    { "amount" : """2""" },
    { "amount" : """3.25""" },
    { "amount" : """1.2""" },
    { "amount" : """0.7""" },
    { "amount" : """0.39""" },
    { "amount" : """0.273""" },
    { "amount" : """0.3""" },
    { "amount" : """7""" },
    { "amount" : """0.75""" },
    { "amount" : """7""" },
    { "amount" : """0.8""" },
    { "amount" : """6.5""" },
    { "amount" : """0.09""" },
    { "amount" : """0.5""" },
    { "amount" : """1""" },
    { "amount" : """10""" },
    { "amount" : """0.42""" },
    { "amount" : """2.5""" },
    { "amount" : """0.5""" },
    { "amount" : """0.3""" },
    { "amount" : """0.1""" },
    { "amount" : """0.85""" },
    { "amount" : """1.5""" },
    { "amount" : """15""" },
    { "amount" : """2""" },
    { "amount" : """5""" },
    { "amount" : """0.255""" },
    { "amount" : """0.6""" },
    { "amount" : """0.25""" },
    { "amount" : """0.86""" },
    { "amount" : """0.142""" },
    { "amount" : """0.07""" },
    { "amount" : """0.904""" },
    { "amount" : """0.7""" },
    { "amount" : """1""" },
    { "amount" : """2""" },
    { "amount" : """0.3""" },
    { "amount" : """0.47""" },
    { "amount" : """0.45""" },
    { "amount" : """1""" },
    { "amount" : """0.47""" },
    { "amount" : """0.205""" },
    { "amount" : """0.1""" },
    { "amount" : """0.65""" },
    { "amount" : """5""" },
    { "amount" : """1""" },
    { "amount" : """0.1""" },
    { "amount" : """0.03""" },
    { "amount" : """1""" },
    { "amount" : """0.32""" },
    { "amount" : """0.125""" },
    { "amount" : """8""" },
    { "amount" : """0.2""" },
    { "amount" : """0.3""" },
    { "amount" : """1.75""" },
    { "amount" : """0.47""" },
    { "amount" : """0.3""" },
    { "amount" : """2""" },
    { "amount" : """15""" },
    { "amount" : """1""" },
    { "amount" : """0.1""" },
    { "amount" : """5""" },
    { "amount" : """0.5""" },
    { "amount" : """3""" },
    { "amount" : """1""" },
    { "amount" : """1""" },
    { "amount" : """1.5""" },
    { "amount" : """0.3""" },
    { "amount" : """0.48""" },
    { "amount" : """1""" },
    { "amount" : """0.5""" },
    { "amount" : """0.25""" },
    { "amount" : """0.5""" },
    { "amount" : """3""" },
    { "amount" : """2.7""" },
    { "amount" : """0.5""" },
    { "amount" : """7""" },
    { "amount" : """2.75""" },
    { "amount" : """0.5""" },
    { "amount" : """3""" },
    { "amount" : """2.5826""" },
    { "amount" : """0.1""" },
    { "amount" : """1""" },
    { "amount" : """10""" },
    { "amount" : """0.25""" },
    { "amount" : """3""" },
    { "amount" : """0.5""" },
    { "amount" : """1.3""" },
    { "amount" : """1""" },
    { "amount" : """0.75""" },
    { "amount" : """1""" },
    { "amount" : """2.5""" },
    { "amount" : """0.55""" },
    { "amount" : """2""" },
    { "amount" : """10""" },
    { "amount" : """0.475""" },
    { "amount" : """0.48""" },
    { "amount" : """5""" },
    { "amount" : """0.05""" },
    { "amount" : """0.498""" },
    { "amount" : """0.973""" },
    { "amount" : """1""" },
    { "amount" : """0.76""" },
    { "amount" : """0.0001""" },
    { "amount" : """5.5""" },
    { "amount" : """0.5""" },
    { "amount" : """0.5""" },
    { "amount" : """1.5""" },
    { "amount" : """2""" },
    { "amount" : """0.0001""" },
    { "amount" : """1""" },
    { "amount" : """1""" },
    { "amount" : """0.08""" },
    { "amount" : """20""" },
    { "amount" : """1""" },
    { "amount" : """5.1""" },
    { "amount" : """1.5""" },
    { "amount" : """2""" },
    { "amount" : """0.16""" },
    { "amount" : """20""" },
    { "amount" : """3""" },
    { "amount" : """0.385""" },
    { "amount" : """2""" },
    { "amount" : """30""" },
    { "amount" : """0.06""" },
    { "amount" : """3.5""" },
    { "amount" : """1.26""" },
    { "amount" : """1.26""" },
    { "amount" : """1""" },
    { "amount" : """0.1611""" },
    { "amount" : """5""" },
    { "amount" : """2""" },
    { "amount" : """0.2""" },
    { "amount" : """3.92""" },
    { "amount" : """0.3""" },
    { "amount" : """3""" },
    { "amount" : """15""" },
    { "amount" : """0.5""" },
    { "amount" : """0.25""" },
    { "amount" : """7""" },
    { "amount" : """10""" },
    { "amount" : """2""" },
    { "amount" : """3""" },
    { "amount" : """2""" },
    { "amount" : """1""" },
    { "amount" : """15""" },
    { "amount" : """1.7""" },
    { "amount" : """0.5""" },
    { "amount" : """2.85""" },
    { "amount" : """2""" },
    { "amount" : """6""" },
    { "amount" : """2""" },
    { "amount" : """0.7""" },
    { "amount" : """0.85""" },
    { "amount" : """0.5""" },
    { "amount" : """0.0001""" },
    { "amount" : """0.05""" },
    { "amount" : """1""" },
    { "amount" : """0.12""" },
    { "amount" : """0.2945""" },
    { "amount" : """13""" },
    { "amount" : """15""" },
    { "amount" : """3""" },
    { "amount" : """30""" },
    { "amount" : """0.35""" },
    { "amount" : """1""" },
    { "amount" : """7""" },
    { "amount" : """3.5""" },
    { "amount" : """1.7""" },
    { "amount" : """0.005""" },
    { "amount" : """0.5""" },
    { "amount" : """4.12""" },
    { "amount" : """0.5""" },
    { "amount" : """7""" },
    { "amount" : """7.25""" },
    { "amount" : """0.5""" },
    { "amount" : """2.3""" },
    { "amount" : """2""" },
    { "amount" : """1""" },
    { "amount" : """0.5""" },
    { "amount" : """0.4""" },
    { "amount" : """0.09""" },
    { "amount" : """1.5""" },
    { "amount" : """1""" },
    { "amount" : """15""" },
    { "amount" : """2.55""" },
    { "amount" : """0.95""" },
    { "amount" : """0.032""" },
    { "amount" : """1.3""" },
    { "amount" : """1""" },
    { "amount" : """0.2""" },
    { "amount" : """0.5""" },
    { "amount" : """0.25""" },
    { "amount" : """15""" },
    { "amount" : """0.7""" },
    { "amount" : """1.2001""" },
    { "amount" : """1""" },
    { "amount" : """2""" },
    { "amount" : """0.25""" },
    { "amount" : """4""" },
    { "amount" : """0.2""" },
    { "amount" : """3""" },
    { "amount" : """0.03""" },
    { "amount" : """2""" },
    { "amount" : """1.5""" },
    { "amount" : """0.5""" },
    { "amount" : """0.7""" },
    { "amount" : """1.5""" },
    { "amount" : """10""" },
    { "amount" : """0.12""" },
    { "amount" : """4""" },
    { "amount" : """7""" },
    { "amount" : """1""" },
    { "amount" : """1.3""" },
    { "amount" : """2""" },
    { "amount" : """1.5""" },
    { "amount" : """0.0001""" },
    { "amount" : """1""" },
    { "amount" : """3""" },
    { "amount" : """8""" },
    { "amount" : """30""" },
    { "amount" : """2""" },
    { "amount" : """0.04""" },
    { "amount" : """0.0101""" },
    { "amount" : """0.028""" },
    { "amount" : """0.02""" },
    { "amount" : """2""" },
    { "amount" : """5""" },
    { "amount" : """15""" },
    { "amount" : """8""" },
    { "amount" : """0.015""" },
    { "amount" : """0.1""" },
    { "amount" : """8""" },
    { "amount" : """1.5""" },
    { "amount" : """1.5""" },
    { "amount" : """0.975""" },
    { "amount" : """0.5""" },
    { "amount" : """1.5""" },
    { "amount" : """1.5""" },
    { "amount" : """4""" },
    { "amount" : """1.7""" },
    { "amount" : """0.25""" },
    { "amount" : """3""" },
    { "amount" : """10""" },
    { "amount" : """0.4""" },
    { "amount" : """10""" },
    { "amount" : """21""" },
    { "amount" : """2.5""" },
    { "amount" : """0.4""" },
    { "amount" : """0.02""" },
    { "amount" : """0.2674""" },
    { "amount" : """0.15""" },
    { "amount" : """1""" },
    { "amount" : """0.523""" },
    { "amount" : """2""" },
    { "amount" : """14.5""" },
    { "amount" : """10""" },
    { "amount" : """2""" },
    { "amount" : """0.1""" },
    { "amount" : """0.0086""" },
    { "amount" : """3""" },
    { "amount" : """0.05""" },
    { "amount" : """0.76""" },
    { "amount" : """0.1""" },
    { "amount" : """0.5""" },
    { "amount" : """2.5""" },
    { "amount" : """1""" },
    { "amount" : """1.5""" },
    { "amount" : """1""" },
    { "amount" : """1.5""" },
    { "amount" : """1""" },
    { "amount" : """11""" },
    { "amount" : """0.1""" },
    { "amount" : """0.5""" },
    { "amount" : """12""" },
    { "amount" : """5""" },
    { "amount" : """0.5""" },
    { "amount" : """10""" },
    { "amount" : """1.5""" },
    { "amount" : """0.9""" },
    { "amount" : """0.9""" },
    { "amount" : """0.5""" },
    { "amount" : """2.5""" },
    { "amount" : """0.3""" },
    { "amount" : """3""" },
    { "amount" : """1.6""" },
    { "amount" : """0.05""" },
    { "amount" : """1""" },
    { "amount" : """16""" },
    { "amount" : """0.075""" },
    { "amount" : """0.4""" },
    { "amount" : """0.9""" },
    { "amount" : """0.5""" },
    { "amount" : """4""" },
    { "amount" : """15""" },
    { "amount" : """2.2""" },
    { "amount" : """20""" },
    { "amount" : """0.4""" },
    { "amount" : """1.5""" },
    { "amount" : """2.84""" },
    { "amount" : """1.3""" },
    { "amount" : """3.5""" },
    { "amount" : """0.4099""" },
    { "amount" : """10""" },
    { "amount" : """1.3""" },
    { "amount" : """12.5""" },
    { "amount" : """3""" },
    { "amount" : """2""" },
    { "amount" : """2.1""" },
    { "amount" : """1.48""" },
    { "amount" : """3.5""" },
    { "amount" : """1.25""" },
    { "amount" : """50""" },
    { "amount" : """0.5""" },
    { "amount" : """2""" },
    { "amount" : """0.4""" },
    { "amount" : """0.9""" },
    { "amount" : """19.5""" },
    { "amount" : """7""" },
    { "amount" : """0.5""" },
    { "amount" : """3""" },
    { "amount" : """2.1""" },
    { "amount" : """0.009""" },
    { "amount" : """0.009""" },
    { "amount" : """0.009""" },
    { "amount" : """0.1""" },
    { "amount" : """0.001""" },
    { "amount" : """1""" },
    { "amount" : """20""" },
    { "amount" : """20""" },
    { "amount" : """3""" },
    { "amount" : """5""" },
    { "amount" : """0.85""" },
    { "amount" : """1.5""" },
    { "amount" : """1.25""" },
    { "amount" : """0.4""" },
    { "amount" : """2""" },
    { "amount" : """0.0032""" },
    { "amount" : """0.4""" },
    { "amount" : """0.15""" },
    { "amount" : """1""" },
    { "amount" : """3.125""" },
    { "amount" : """10.1""" },
    { "amount" : """0.0473""" },
    { "amount" : """22""" },
    { "amount" : """5""" },
    { "amount" : """5""" },
    { "amount" : """1.5""" },
    { "amount" : """2.222""" },
    { "amount" : """1.4""" },
    { "amount" : """0.65""" },
    { "amount" : """0.8""" },
    { "amount" : """1.75""" },
    { "amount" : """4.06""" },
    { "amount" : """6.5167""" },
    { "amount" : """4""" },
    { "amount" : """2.15""" },
    { "amount" : """2""" },
    { "amount" : """0.5""" },
    { "amount" : """2""" },
    { "amount" : """0.454""" },
    { "amount" : """2.5""" },
    { "amount" : """1.5""" },
    { "amount" : """25""" },
    { "amount" : """1.6""" },
    { "amount" : """0.2673""" },
    { "amount" : """3""" },
    { "amount" : """1.2""" },
    { "amount" : """0.5""" },
    { "amount" : """24.5""" },
    { "amount" : """0.4""" },
    { "amount" : """1.85""" },
    { "amount" : """0.5""" },
    { "amount" : """0.11""" },
    { "amount" : """12""" },
    { "amount" : """3""" },
    { "amount" : """2""" },
    { "amount" : """15""" },
    { "amount" : """1.2""" },
    { "amount" : """1.5""" },
    { "amount" : """10""" },
    { "amount" : """5""" },
    { "amount" : """27""" },
    { "amount" : """2""" },
    { "amount" : """7""" },
    { "amount" : """1.6""" },
    { "amount" : """3.6""" },
    { "amount" : """5""" },
    { "amount" : """0.05""" },
    { "amount" : """0.2""" },
    { "amount" : """4""" },
    { "amount" : """1""" },
    { "amount" : """1.75""" },
    { "amount" : """1""" },
    { "amount" : """0.6""" },
    { "amount" : """0.2""" },
    { "amount" : """10""" },
    { "amount" : """1.5""" },
    { "amount" : """10""" },
    { "amount" : """10""" },
    { "amount" : """2.5""" },
    { "amount" : """20""" },
    { "amount" : """0.1""" },
    { "amount" : """2.5""" },
    { "amount" : """1""" },
    { "amount" : """0.75""" },
    { "amount" : """2""" },
    { "amount" : """0.5""" },
    { "amount" : """1""" },
    { "amount" : """2""" },
    { "amount" : """0.3""" },
    { "amount" : """2.5""" },
    { "amount" : """2.5""" },
    { "amount" : """2""" },
    { "amount" : """1""" },
    { "amount" : """0.5""" },
    { "amount" : """2.562""" },
    { "amount" : """0.5""" },
    { "amount" : """25""" },
    { "amount" : """7.67""" },
    { "amount" : """3.5""" },
    { "amount" : """4""" },
    { "amount" : """2.5""" },
    { "amount" : """3""" },
    { "amount" : """50""" },
    { "amount" : """1.5""" },
    { "amount" : """2.5""" },
    { "amount" : """2.5""" },
    { "amount" : """3""" },
    { "amount" : """7""" },
    { "amount" : """1""" },
    { "amount" : """1.5""" },
    { "amount" : """1""" },
    { "amount" : """0.2""" },
    { "amount" : """2""" },
    { "amount" : """0.5""" },
    { "amount" : """2.5""" },
    { "amount" : """2""" },
    { "amount" : """1.5""" },
    { "amount" : """0.3""" },
    { "amount" : """2""" },
    { "amount" : """0.1""" },
    { "amount" : """0.3""" },
    { "amount" : """0.4""" },
    { "amount" : """4""" },
    { "amount" : """0.5""" },
    { "amount" : """2""" },
    { "amount" : """0.47""" },
    { "amount" : """15""" },
    { "amount" : """1.7""" },
    { "amount" : """6""" },
    { "amount" : """15""" },
    { "amount" : """2.5""" },
    { "amount" : """1.5""" },
    { "amount" : """0.1""" },
    { "amount" : """1""" },
    { "amount" : """0.2""" },
    { "amount" : """1""" },
    { "amount" : """0.12""" },
    { "amount" : """0.7""" },
    { "amount" : """1.8""" },
    { "amount" : """12""" },
    { "amount" : """3""" },
    { "amount" : """8.1229""" },
    { "amount" : """3.7176""" },
    { "amount" : """0.05""" },
    { "amount" : """10""" },
    { "amount" : """7""" },
    { "amount" : """0.15""" },
    { "amount" : """0.2""" },
    { "amount" : """2.5""" },
    { "amount" : """26""" },
    { "amount" : """3""" },
    { "amount" : """0.5""" },
    { "amount" : """2""" },
    { "amount" : """4""" },
    { "amount" : """0.21""" },
    { "amount" : """8.9639""" },
    { "amount" : """0.4""" },
    { "amount" : """0.25""" },
    { "amount" : """2""" },
    { "amount" : """2""" },
    { "amount" : """0.5""" },
    { "amount" : """2""" },
    { "amount" : """2""" },
    { "amount" : """1""" },
    { "amount" : """12""" },
    { "amount" : """2""" },
    { "amount" : """3""" },
    { "amount" : """1.5""" },
    { "amount" : """2""" },
    { "amount" : """2""" },
    { "amount" : """10.01""" },
    { "amount" : """0.25""" },
    { "amount" : """1.7798""" },
    { "amount" : """12""" },
    { "amount" : """4""" },
    { "amount" : """2.6""" },
    { "amount" : """1""" },
    { "amount" : """0.8""" },
    { "amount" : """10""" },
    { "amount" : """8""" },
    { "amount" : """3""" },
    { "amount" : """0.5""" },
    { "amount" : """5""" },
    { "amount" : """1""" },
    { "amount" : """0.8""" },
    { "amount" : """2.5""" },
    { "amount" : """0.6""" },
    { "amount" : """22""" },
    { "amount" : """3""" },
    { "amount" : """1""" },
    { "amount" : """2""" },
    { "amount" : """2""" },
    { "amount" : """1""" },
    { "amount" : """5""" },
    { "amount" : """2""" },
    { "amount" : """0.5""" },
    { "amount" : """1""" },
    { "amount" : """2.5""" },
    { "amount" : """10""" },
    { "amount" : """3""" },
    { "amount" : """1.5""" },
    { "amount" : """1.2""" },
    { "amount" : """1""" },
    { "amount" : """6""" },
    { "amount" : """2""" },
    { "amount" : """0.2""" },
    { "amount" : """20""" },
    { "amount" : """1.5""" },
    { "amount" : """1.5""" },
    { "amount" : """3.4444""" },
    { "amount" : """1""" },
    { "amount" : """0.5""" },
    { "amount" : """15""" },
    { "amount" : """3""" },
    { "amount" : """15""" },
    { "amount" : """10""" },
    { "amount" : """0.4""" },
    { "amount" : """1.2""" },
    { "amount" : """8""" },
    { "amount" : """34""" },
    { "amount" : """0.4""" },
    { "amount" : """2.2""" },
    { "amount" : """1.8""" },
    { "amount" : """10""" },
    { "amount" : """1""" },
    { "amount" : """0.3""" },
    { "amount" : """1.218""" },
    { "amount" : """3.25""" },
    { "amount" : """0.5""" },
    { "amount" : """0.1""" },
    { "amount" : """8""" },
    { "amount" : """0.3""" },
    { "amount" : """0.88""" },
    { "amount" : """5.5""" },
    { "amount" : """0.1""" },
    { "amount" : """3""" },
    { "amount" : """0.5""" },
    { "amount" : """10""" },
    { "amount" : """5""" },
    { "amount" : """1""" },
    { "amount" : """7""" },
    { "amount" : """1""" },
    { "amount" : """4""" },
    { "amount" : """1""" },
    { "amount" : """10""" },
    { "amount" : """2""" },
    { "amount" : """10""" },
    { "amount" : """7""" },
    { "amount" : """2.2""" },
    { "amount" : """3""" },
    { "amount" : """0.0123""" },
    { "amount" : """33""" },
    { "amount" : """0.1""" },
    { "amount" : """1.05""" },
    { "amount" : """1.3""" },
    { "amount" : """2.2""" },
    { "amount" : """0.7""" },
    { "amount" : """8""" },
    { "amount" : """5""" },
    { "amount" : """2""" },
    { "amount" : """3""" },
    { "amount" : """2.5432""" },
    { "amount" : """1""" },
    { "amount" : """2""" },
    { "amount" : """1""" },
    { "amount" : """0.01""" },
    { "amount" : """0.35""" },
    { "amount" : """2.5""" },
    { "amount" : """0.012""" },
    { "amount" : """0.01""" },
    { "amount" : """0.25""" },
    { "amount" : """2""" },
    { "amount" : """1""" },
    { "amount" : """4""" },
    { "amount" : """4""" },
    { "amount" : """1""" },
    { "amount" : """1""" },
    { "amount" : """0.689""" },
    { "amount" : """0.14""" },
    { "amount" : """25""" },
    { "amount" : """50""" },
    { "amount" : """8""" },
    { "amount" : """2.5""" },
    { "amount" : """1""" },
    { "amount" : """0.9""" },
    { "amount" : """12""" },
    { "amount" : """3""" },
    { "amount" : """0.55""" },
    { "amount" : """0.5""" },
    { "amount" : """2""" },
    { "amount" : """2""" },
    { "amount" : """19""" },
    { "amount" : """3.2""" },
    { "amount" : """0.5""" },
    { "amount" : """34""" },
    { "amount" : """3""" },
    { "amount" : """0.09""" },
    { "amount" : """10""" },
    { "amount" : """2""" },
    { "amount" : """11.68""" },
    { "amount" : """0.5""" },
    { "amount" : """0.5""" },
    { "amount" : """2""" },
    { "amount" : """0.17""" },
    { "amount" : """0.05""" },
    { "amount" : """1.2737""" },
    { "amount" : """16""" },
    { "amount" : """1""" },
    { "amount" : """15""" },
    { "amount" : """0.18""" },
    { "amount" : """8""" },
    { "amount" : """0.5""" },
    { "amount" : """1.5""" },
    { "amount" : """15""" },
    { "amount" : """20""" },
    { "amount" : """7""" },
    { "amount" : """1.2""" },
    { "amount" : """0.5""" },
    { "amount" : """12""" },
    { "amount" : """0.5""" },
    { "amount" : """0.75""" },
    { "amount" : """10""" },
    { "amount" : """1""" },
    { "amount" : """0.2""" },
    { "amount" : """1.88""" },
    { "amount" : """0.4""" },
    { "amount" : """15""" },
    { "amount" : """0.0015""" },
    { "amount" : """3.5""" },
    { "amount" : """0.5""" },
    { "amount" : """0.09""" },
    { "amount" : """3.25""" },
    { "amount" : """1.2""" },
    { "amount" : """0.75""" },
    { "amount" : """0.37""" },
    { "amount" : """5.5""" },
    { "amount" : """2""" },
    { "amount" : """3""" },
    { "amount" : """2""" },
    { "amount" : """3.5""" },
    { "amount" : """6""" },
    { "amount" : """0.25""" },
    { "amount" : """1""" },
    { "amount" : """8""" },
    { "amount" : """0.4""" },
    { "amount" : """0.33""" },
    { "amount" : """33""" },
    { "amount" : """9""" },
    { "amount" : """1.5""" },
    { "amount" : """1""" },
    { "amount" : """0.5""" },
    { "amount" : """1""" },
    { "amount" : """0.0211""" },
    { "amount" : """22""" },
    { "amount" : """1""" },
    { "amount" : """7""" },
    { "amount" : """3""" },
    { "amount" : """2""" },
    { "amount" : """0.3""" },
    { "amount" : """0.005""" },
    { "amount" : """0.3""" },
    { "amount" : """1""" },
    { "amount" : """2.5""" },
    { "amount" : """1""" },
    { "amount" : """1.2""" },
    { "amount" : """3.4""" },
    { "amount" : """0.5""" },
    { "amount" : """10""" },
    { "amount" : """1""" },
    { "amount" : """1.2777""" },
    { "amount" : """6""" },
    { "amount" : """9""" },
    { "amount" : """0.05""" },
    { "amount" : """10""" },
    { "amount" : """3.35""" },
    { "amount" : """0.4""" },
    { "amount" : """38""" },
    { "amount" : """0.5""" },
    { "amount" : """0.2""" },
    { "amount" : """9.5""" },
    { "amount" : """0.3""" },
    { "amount" : """7""" },
    { "amount" : """6""" },
    { "amount" : """1.24""" },
    { "amount" : """2""" },
    { "amount" : """0.15""" },
    { "amount" : """0.8""" },
    { "amount" : """8""" },
    { "amount" : """3""" },
    { "amount" : """0.7""" },
    { "amount" : """13""" },
    { "amount" : """3""" },
    { "amount" : """1.3""" },
    { "amount" : """1.5""" },
    { "amount" : """3.5""" },
    { "amount" : """0.8436""" },
    { "amount" : """1""" },
    { "amount" : """34""" },
    { "amount" : """12""" },
    { "amount" : """10""" },
    { "amount" : """2""" },
    { "amount" : """2""" },
    { "amount" : """9.8""" },
    { "amount" : """1.2""" },
    { "amount" : """1""" },
    { "amount" : """0.03""" },
    { "amount" : """0.2""" },
    { "amount" : """0.45""" },
    { "amount" : """3.5""" },
    { "amount" : """1""" },
    { "amount" : """0.25""" },
    { "amount" : """1""" },
    { "amount" : """2""" },
    { "amount" : """1.26""" },
    { "amount" : """50""" },
    { "amount" : """22""" },
    { "amount" : """0.0012""" },
    { "amount" : """10""" },
    { "amount" : """0.1""" },
    { "amount" : """1.2675""" },
    { "amount" : """0.2""" },
    { "amount" : """10""" },
    { "amount" : """15""" },
    { "amount" : """1""" },
    { "amount" : """3""" },
    { "amount" : """1""" },
    { "amount" : """0.25""" },
    { "amount" : """0.6""" },
    { "amount" : """1.5""" },
    { "amount" : """10""" },
    { "amount" : """0.004""" },
    { "amount" : """0.2""" },
    { "amount" : """0.01""" },
    { "amount" : """0.36""" },
    { "amount" : """2.8""" },
    { "amount" : """1""" },
    { "amount" : """10""" },
    { "amount" : """7""" },
    { "amount" : """5""" },
    { "amount" : """0.1475""" },
    { "amount" : """1""" },
    { "amount" : """15""" },
    { "amount" : """20""" },
    { "amount" : """1.3""" },
    { "amount" : """0.01""" },
    { "amount" : """2.5""" },
    { "amount" : """0.41""" },
    { "amount" : """0.65""" },
    { "amount" : """12""" },
    { "amount" : """0.32""" },
    { "amount" : """15""" },
    { "amount" : """2""" },
    { "amount" : """24""" },
    { "amount" : """20""" },
    { "amount" : """0.443""" },
    { "amount" : """0.19""" },
    { "amount" : """3.45""" },
    { "amount" : """5""" },
    { "amount" : """4""" },
    { "amount" : """0.53""" },
    { "amount" : """1.5""" },
    { "amount" : """1.3""" },
    { "amount" : """2""" },
    { "amount" : """1""" },
    { "amount" : """3""" },
    { "amount" : """0.5""" },
    { "amount" : """0.19""" },
    { "amount" : """1""" },
    { "amount" : """1.0005""" },
    { "amount" : """1.2""" },
    { "amount" : """27.25""" },
    { "amount" : """1""" },
    { "amount" : """1""" },
    { "amount" : """27""" },
    { "amount" : """0.5""" },
    { "amount" : """10""" },
    { "amount" : """8.5""" },
    { "amount" : """18""" },
    { "amount" : """0.2""" },
    { "amount" : """0.5""" },
    { "amount" : """3.85""" },
    { "amount" : """4""" },
    { "amount" : """0.7""" },
    { "amount" : """3""" },
    { "amount" : """0.6""" },
    { "amount" : """1.3""" },
    { "amount" : """0.1""" },
    { "amount" : """5.5""" },
    { "amount" : """3.5""" },
    { "amount" : """15""" },
    { "amount" : """2.5""" },
    { "amount" : """20""" },
    { "amount" : """3""" },
    { "amount" : """15""" },
    { "amount" : """0.5""" },
    { "amount" : """1""" },
    { "amount" : """1""" },
    { "amount" : """0.11""" },
    { "amount" : """10""" },
    { "amount" : """2""" },
    { "amount" : """1.5""" },
    { "amount" : """1""" },
    { "amount" : """20""" },
    { "amount" : """1.2""" },
    { "amount" : """0.45""" },
    { "amount" : """0.3""" },
    { "amount" : """0.3""" },
    { "amount" : """0.7""" },
    { "amount" : """0.17""" },
    { "amount" : """0.25""" },
    { "amount" : """1.2353""" },
    { "amount" : """0.6""" },
    { "amount" : """0.42""" },
    { "amount" : """3""" },
    { "amount" : """0.5""" },
    { "amount" : """3.2071""" },
    { "amount" : """0.99""" },
    { "amount" : """0.5855""" },
    { "amount" : """0.05""" },
    { "amount" : """0.001""" },
    { "amount" : """0.27""" },
    { "amount" : """2""" },
    { "amount" : """2""" },
    { "amount" : """1.25""" },
    { "amount" : """1.1""" },
    { "amount" : """0.1227""" },
    { "amount" : """2""" },
    { "amount" : """0.5""" },
    { "amount" : """0.5""" },
    { "amount" : """3""" },
    { "amount" : """11.75""" },
    { "amount" : """3""" },
    { "amount" : """0.4""" },
    { "amount" : """2""" },
    { "amount" : """23.2""" },
    { "amount" : """0.3""" },
    { "amount" : """0.5""" },
    { "amount" : """3""" },
    { "amount" : """1""" },
    { "amount" : """0.5""" },
    { "amount" : """0.5""" },
    { "amount" : """2.3""" },
    { "amount" : """1""" },
    { "amount" : """0.15""" },
    { "amount" : """0.1""" },
    { "amount" : """19""" },
    { "amount" : """0.72""" },
    { "amount" : """4""" },
    { "amount" : """30""" },
    { "amount" : """1""" },
    { "amount" : """3.5""" },
    { "amount" : """75""" },
    { "amount" : """3.55""" },
    { "amount" : """0.25""" },
    { "amount" : """26""" },
    { "amount" : """7.5""" },
    { "amount" : """0.5""" },
    { "amount" : """24""" },
    { "amount" : """0.15""" },
    { "amount" : """0.17""" },
    { "amount" : """3.5""" },
    { "amount" : """0.15""" },
    { "amount" : """0.6""" },
    { "amount" : """0.13""" },
    { "amount" : """2""" },
    { "amount" : """1""" },
    { "amount" : """0.17""" },
    { "amount" : """4""" },
    { "amount" : """0.14""" },
    { "amount" : """1""" },
    { "amount" : """0.16""" },
    { "amount" : """0.65""" },
    { "amount" : """0.17""" },
    { "amount" : """1.0788""" },
    { "amount" : """0.18""" },
    { "amount" : """4.1""" },
    { "amount" : """15""" },
    { "amount" : """0.7""" },
    { "amount" : """5""" },
    { "amount" : """5""" },
    { "amount" : """25""" },
    { "amount" : """0.7""" },
    { "amount" : """15""" },
    { "amount" : """0.6""" },
    { "amount" : """4""" },
    { "amount" : """50""" },
    { "amount" : """0.18""" },
    { "amount" : """3.7""" },
    { "amount" : """1.5""" },
    { "amount" : """0.16""" },
    { "amount" : """0.5""" },
    { "amount" : """24""" },
    { "amount" : """2""" },
    { "amount" : """0.5""" },
    { "amount" : """0.45""" },
    { "amount" : """1""" },
    { "amount" : """0.3""" },
    { "amount" : """0.5""" },
    { "amount" : """0.4""" },
    { "amount" : """2""" },
    { "amount" : """0.6303""" },
    { "amount" : """0.42""" },
    { "amount" : """24""" },
    { "amount" : """0.18""" },
    { "amount" : """14""" },
    { "amount" : """3.2019""" },
    { "amount" : """15""" },
    { "amount" : """1.1""" },
    { "amount" : """0.5""" },
    { "amount" : """0.5""" },
    { "amount" : """10.5""" },
    { "amount" : """16.7""" },
    { "amount" : """1""" },
    { "amount" : """3""" },
    { "amount" : """1.471""" },
    { "amount" : """18""" },
    { "amount" : """25""" },
    { "amount" : """0.7""" },
    { "amount" : """0.55""" },
    { "amount" : """3.4""" },
    { "amount" : """11""" },
    { "amount" : """0.2""" },
    { "amount" : """3""" },
    { "amount" : """0.5""" },
    { "amount" : """1""" },
    { "amount" : """0.5""" },
    { "amount" : """0.5""" },
    { "amount" : """7.5""" },
    { "amount" : """0.4""" },
    { "amount" : """50""" },
    { "amount" : """1.29""" },
    { "amount" : """0.2""" },
    { "amount" : """1.3065""" },
    { "amount" : """2.5""" },
    { "amount" : """1.312""" },
    { "amount" : """9.3""" },
    { "amount" : """19""" },
    { "amount" : """3""" },
    { "amount" : """0.3""" },
    { "amount" : """72.5""" },
    { "amount" : """2""" },
    { "amount" : """0.7""" },
    { "amount" : """1.3""" },
    { "amount" : """0.3""" },
    { "amount" : """0.1""" },
    { "amount" : """0.3""" },
    { "amount" : """0.022""" },
    { "amount" : """1.5""" },
    { "amount" : """0.31""" },
    { "amount" : """15""" },
    { "amount" : """74.5""" },
    { "amount" : """0.1""" },
    { "amount" : """1""" },
    { "amount" : """1""" },
    { "amount" : """0.8""" },
    { "amount" : """0.2""" },
    { "amount" : """1.5""" },
    { "amount" : """0.1""" },
    { "amount" : """0.5""" },
    { "amount" : """3.5""" },
    { "amount" : """7""" },
    { "amount" : """0.17""" },
    { "amount" : """0.17""" },
    { "amount" : """12""" },
    { "amount" : """1.2""" },
    { "amount" : """0.26""" },
    { "amount" : """0.32""" },
    { "amount" : """0.2""" },
    { "amount" : """2""" },
    { "amount" : """5.5""" },
    { "amount" : """11""" },
    { "amount" : """1.33""" },
    { "amount" : """1.7""" },
    { "amount" : """20""" },
    { "amount" : """0.3""" },
    { "amount" : """0.05""" },
    { "amount" : """0.098""" },
    { "amount" : """6.25""" },
    { "amount" : """0.75""" },
    { "amount" : """6""" },
    { "amount" : """100""" },
    { "amount" : """30""" },
    { "amount" : """0.1""" },
    { "amount" : """1""" },
    { "amount" : """3""" },
    { "amount" : """1.2""" },
    { "amount" : """1.2""" },
    { "amount" : """24""" },
    { "amount" : """0.98""" },
    { "amount" : """0.86""" },
    { "amount" : """0.0216""" },
    { "amount" : """30""" },
    { "amount" : """1""" },
    { "amount" : """10""" },
    { "amount" : """1.5""" },
    { "amount" : """42.5""" },
    { "amount" : """9.5""" },
    { "amount" : """1.1""" },
    { "amount" : """35""" },
    { "amount" : """0.5""" },
    { "amount" : """1""" },
    { "amount" : """10""" },
    { "amount" : """0.85""" },
    { "amount" : """0.4""" },
    { "amount" : """4""" },
    { "amount" : """3.4""" },
    { "amount" : """3.75""" },
    { "amount" : """1.26""" },
    { "amount" : """0.32""" },
    { "amount" : """1""" },
    { "amount" : """1.2642""" },
    { "amount" : """1.5""" },
    { "amount" : """1""" },
    { "amount" : """0.2""" },
    { "amount" : """1""" },
    { "amount" : """0.5""" },
    { "amount" : """30""" },
    { "amount" : """12""" },
    { "amount" : """1.2585""" },
    { "amount" : """0.5""" },
    { "amount" : """0.02""" },
    { "amount" : """0.8""" },
    { "amount" : """0.3""" },
    { "amount" : """50""" },
    { "amount" : """0.0042""" },
    { "amount" : """5""" },
    { "amount" : """2.5""" },
    { "amount" : """7""" },
    { "amount" : """0.4""" },
    { "amount" : """8.5""" },
    { "amount" : """4.5""" },
    { "amount" : """0.9""" },
    { "amount" : """1""" },
    { "amount" : """0.86""" },
    { "amount" : """5""" },
    { "amount" : """10""" },
    { "amount" : """2.5""" },
    { "amount" : """35""" },
    { "amount" : """32.5""" },
    { "amount" : """1.2""" },
    { "amount" : """1.22""" },
    { "amount" : """1""" },
    { "amount" : """2""" },
    { "amount" : """1.2135""" },
    { "amount" : """5""" },
    { "amount" : """1.2""" },
    { "amount" : """4""" },
    { "amount" : """0.15""" },
    { "amount" : """0.2""" },
    { "amount" : """0.5""" },
    { "amount" : """1.5""" },
    { "amount" : """5""" },
    { "amount" : """0.3""" },
    { "amount" : """2""" },
    { "amount" : """10""" },
    { "amount" : """0.29""" },
    { "amount" : """1.18""" },
    { "amount" : """4.8""" },
    { "amount" : """35""" },
    { "amount" : """7.25""" },
    { "amount" : """5.5""" },
    { "amount" : """1.132""" },
    { "amount" : """11""" },
    { "amount" : """8""" },
    { "amount" : """3.5""" },
    { "amount" : """0.09""" },
    { "amount" : """2""" },
    { "amount" : """15""" },
    { "amount" : """0.72""" },
    { "amount" : """15""" },
    { "amount" : """0.5""" },
    { "amount" : """2""" },
    { "amount" : """100""" },
    { "amount" : """0.75""" },
    { "amount" : """1.22""" },
    { "amount" : """0.32""" },
    { "amount" : """4""" },
    { "amount" : """1.484""" },
    { "amount" : """0.9426""" },
    { "amount" : """6""" },
    { "amount" : """0.1""" },
    { "amount" : """1""" },
    { "amount" : """0.8""" },
    { "amount" : """0.8""" },
    { "amount" : """2""" },
    { "amount" : """0.1""" },
    { "amount" : """4.5""" },
    { "amount" : """2""" },
    { "amount" : """0.8013""" },
    { "amount" : """0.5""" },
    { "amount" : """1""" },
    { "amount" : """14.5""" },
    { "amount" : """0.056""" },
    { "amount" : """1""" },
    { "amount" : """0.85""" },
    { "amount" : """1""" },
    { "amount" : """1.7""" },
    { "amount" : """2""" },
]

# %%
loans
# Out:
# [{'amount': '0.4'},
#  {'amount': '0.35'},
#  {'amount': '0.6'},
#  {'amount': '0.7'},
#  {'amount': '2.5'},
#  {'amount': '0.3'},
#  {'amount': '5'},
#  {'amount': '5'},
#  {'amount': '10'},
#  {'amount': '6'},
#  {'amount': '0.25'},
#  {'amount': '0.75'},
#  {'amount': '7.5'},
#  {'amount': '3'},
#  {'amount': '4.75'},
#  {'amount': '7'},
#  {'amount': '1'},
#  {'amount': '3'},
#  {'amount': '1.25'},
#  {'amount': '0.31'},
#  {'amount': '0.06'},
#  {'amount': '5'},
#  {'amount': '2.1'},
#  {'amount': '2.2'},
#  {'amount': '5'},
#  {'amount': '2'},
#  {'amount': '3'},
#  {'amount': '5'},
#  {'amount': '0.4'},
#  {'amount': '5'},
#  {'amount': '5'},
#  {'amount': '2'},
#  {'amount': '0.3'},
#  {'amount': '0.2345'},
#  {'amount': '0.31'},
#  {'amount': '2'},
#  {'amount': '3'},
#  {'amount': '5'},
#  {'amount': '1.5'},
#  {'amount': '1'},
#  {'amount': '1'},
#  {'amount': '5'},
#  {'amount': '0.956'},
#  {'amount': '0.5678'},
#  {'amount': '5'},
#  {'amount': '1'},
# ...

# %%
from matplotlib import pyplot as plt

# %%
import pandas as pd

# %%
datacut = pd.Series([float(x['amount'])  for x in loans if float(x['amount'])<20 ])

# %%
data.hist(bins=25)

# %%
help(data.hist)
# Out:
# Help on method hist_series in module pandas.tools.plotting:
#
# hist_series(self, by=None, ax=None, grid=True, xlabelsize=None, xrot=None, ylabelsize=None, yrot=None, figsize=None, bins=10, **kwds) method of pandas.core.series.Series instance
#     Draw histogram of the input series using matplotlib
#
#     Parameters
#     ----------
#     by : object, optional
#         If passed, then used to form histograms for separate groups
#     ax : matplotlib axis object
#         If not passed, uses gca()
#     grid : boolean, default True
#         Whether to show axis grid lines
#     xlabelsize : int, default None
#         If specified changes the x-axis label size
#     xrot : float, default None
#         rotation of x axis labels
#     ylabelsize : int, default None
#         If specified changes the y-axis label size
#     yrot : float, default None
#         rotation of y axis labels
#     figsize : tuple, default None
#         figure size in inches by default
# ...

# %%
data4 = [
    { "borrower" : """2110""", "count" : """190""" },
    { "borrower" : """1012""", "count" : """143""" },
    { "borrower" : """1995""", "count" : """126""" },
    { "borrower" : """77""", "count" : """103""" },
    { "borrower" : """2312""", "count" : """95""" },
    { "borrower" : """991""", "count" : """92""" },
    { "borrower" : """4630""", "count" : """84""" },
    { "borrower" : """6670""", "count" : """83""" },
    { "borrower" : """3188""", "count" : """81""" },
    { "borrower" : """1008""", "count" : """80""" },
    { "borrower" : """8798""", "count" : """76""" },
    { "borrower" : """532""", "count" : """75""" },
    { "borrower" : """2857""", "count" : """74""" },
    { "borrower" : """707""", "count" : """73""" },
    { "borrower" : """4533""", "count" : """70""" },
    { "borrower" : """3340""", "count" : """66""" },
    { "borrower" : """1176""", "count" : """65""" },
    { "borrower" : """1183""", "count" : """65""" },
    { "borrower" : """4161""", "count" : """64""" },
    { "borrower" : """585""", "count" : """63""" },
    { "borrower" : """5333""", "count" : """63""" },
    { "borrower" : """8436""", "count" : """63""" },
    { "borrower" : """2507""", "count" : """60""" },
    { "borrower" : """1960""", "count" : """59""" },
    { "borrower" : """1002""", "count" : """58""" },
    { "borrower" : """2374""", "count" : """56""" },
    { "borrower" : """1818""", "count" : """53""" },
    { "borrower" : """2551""", "count" : """53""" },
    { "borrower" : """2324""", "count" : """51""" },
    { "borrower" : """4284""", "count" : """50""" },
    { "borrower" : """9321""", "count" : """49""" },
    { "borrower" : """3137""", "count" : """48""" },
    { "borrower" : """3612""", "count" : """48""" },
    { "borrower" : """990""", "count" : """47""" },
    { "borrower" : """2040""", "count" : """47""" },
    { "borrower" : """2423""", "count" : """46""" },
    { "borrower" : """2939""", "count" : """46""" },
    { "borrower" : """4244""", "count" : """46""" },
    { "borrower" : """5920""", "count" : """46""" },
    { "borrower" : """8532""", "count" : """46""" },
    { "borrower" : """3483""", "count" : """45""" },
    { "borrower" : """15231""", "count" : """45""" },
    { "borrower" : """608""", "count" : """44""" },
    { "borrower" : """5081""", "count" : """44""" },
    { "borrower" : """1310""", "count" : """43""" },
    { "borrower" : """12580""", "count" : """43""" },
    { "borrower" : """3323""", "count" : """42""" },
    { "borrower" : """4746""", "count" : """42""" },
    { "borrower" : """658""", "count" : """41""" },
    { "borrower" : """5588""", "count" : """41""" },
    { "borrower" : """5984""", "count" : """41""" },
    { "borrower" : """7771""", "count" : """41""" },
    { "borrower" : """1134""", "count" : """40""" },
    { "borrower" : """1559""", "count" : """40""" },
    { "borrower" : """3662""", "count" : """40""" },
    { "borrower" : """3808""", "count" : """40""" },
    { "borrower" : """4780""", "count" : """40""" },
    { "borrower" : """551""", "count" : """39""" },
    { "borrower" : """1588""", "count" : """39""" },
    { "borrower" : """2792""", "count" : """39""" },
    { "borrower" : """1113""", "count" : """38""" },
    { "borrower" : """1188""", "count" : """38""" },
    { "borrower" : """2746""", "count" : """38""" },
    { "borrower" : """4503""", "count" : """38""" },
    { "borrower" : """13383""", "count" : """38""" },
    { "borrower" : """9208""", "count" : """37""" },
    { "borrower" : """783""", "count" : """36""" },
    { "borrower" : """4814""", "count" : """36""" },
    { "borrower" : """5708""", "count" : """36""" },
    { "borrower" : """9512""", "count" : """36""" },
    { "borrower" : """1174""", "count" : """35""" },
    { "borrower" : """1707""", "count" : """35""" },
    { "borrower" : """4547""", "count" : """35""" },
    { "borrower" : """6205""", "count" : """35""" },
    { "borrower" : """8903""", "count" : """35""" },
    { "borrower" : """9919""", "count" : """35""" },
    { "borrower" : """11601""", "count" : """35""" },
    { "borrower" : """7992""", "count" : """34""" },
    { "borrower" : """721""", "count" : """33""" },
    { "borrower" : """7368""", "count" : """33""" },
    { "borrower" : """3585""", "count" : """32""" },
    { "borrower" : """9388""", "count" : """32""" },
    { "borrower" : """9572""", "count" : """32""" },
    { "borrower" : """10332""", "count" : """32""" },
    { "borrower" : """15580""", "count" : """32""" },
    { "borrower" : """1854""", "count" : """31""" },
    { "borrower" : """3043""", "count" : """31""" },
    { "borrower" : """3511""", "count" : """31""" },
    { "borrower" : """5471""", "count" : """31""" },
    { "borrower" : """7972""", "count" : """31""" },
    { "borrower" : """1087""", "count" : """30""" },
    { "borrower" : """1390""", "count" : """30""" },
    { "borrower" : """1518""", "count" : """30""" },
    { "borrower" : """1893""", "count" : """30""" },
    { "borrower" : """3598""", "count" : """30""" },
    { "borrower" : """3923""", "count" : """30""" },
    { "borrower" : """9604""", "count" : """30""" },
    { "borrower" : """19190""", "count" : """30""" },
    { "borrower" : """1067""", "count" : """29""" },
    { "borrower" : """2453""", "count" : """29""" },
    { "borrower" : """3223""", "count" : """29""" },
    { "borrower" : """3775""", "count" : """29""" },
    { "borrower" : """3827""", "count" : """29""" },
    { "borrower" : """6167""", "count" : """29""" },
    { "borrower" : """6467""", "count" : """29""" },
    { "borrower" : """6848""", "count" : """29""" },
    { "borrower" : """1924""", "count" : """28""" },
    { "borrower" : """7667""", "count" : """28""" },
    { "borrower" : """8720""", "count" : """28""" },
    { "borrower" : """1159""", "count" : """27""" },
    { "borrower" : """2136""", "count" : """27""" },
    { "borrower" : """3295""", "count" : """27""" },
    { "borrower" : """4341""", "count" : """27""" },
    { "borrower" : """5682""", "count" : """27""" },
    { "borrower" : """7272""", "count" : """27""" },
    { "borrower" : """10443""", "count" : """27""" },
    { "borrower" : """18931""", "count" : """27""" },
    { "borrower" : """286""", "count" : """26""" },
    { "borrower" : """1004""", "count" : """26""" },
    { "borrower" : """1043""", "count" : """26""" },
    { "borrower" : """2702""", "count" : """26""" },
    { "borrower" : """2711""", "count" : """26""" },
    { "borrower" : """2742""", "count" : """26""" },
    { "borrower" : """12384""", "count" : """26""" },
    { "borrower" : """479""", "count" : """25""" },
    { "borrower" : """728""", "count" : """25""" },
    { "borrower" : """1555""", "count" : """25""" },
    { "borrower" : """1710""", "count" : """25""" },
    { "borrower" : """2108""", "count" : """25""" },
    { "borrower" : """3144""", "count" : """25""" },
    { "borrower" : """4279""", "count" : """25""" },
    { "borrower" : """6552""", "count" : """25""" },
    { "borrower" : """12204""", "count" : """25""" },
    { "borrower" : """12581""", "count" : """25""" },
    { "borrower" : """18716""", "count" : """25""" },
    { "borrower" : """132""", "count" : """24""" },
    { "borrower" : """665""", "count" : """24""" },
    { "borrower" : """1868""", "count" : """24""" },
    { "borrower" : """3980""", "count" : """24""" },
    { "borrower" : """4807""", "count" : """24""" },
    { "borrower" : """7142""", "count" : """24""" },
    { "borrower" : """11096""", "count" : """24""" },
    { "borrower" : """11339""", "count" : """24""" },
    { "borrower" : """11921""", "count" : """24""" },
    { "borrower" : """13217""", "count" : """24""" },
    { "borrower" : """13888""", "count" : """24""" },
    { "borrower" : """16692""", "count" : """24""" },
    { "borrower" : """1053""", "count" : """23""" },
    { "borrower" : """2997""", "count" : """23""" },
    { "borrower" : """4987""", "count" : """23""" },
    { "borrower" : """8404""", "count" : """23""" },
    { "borrower" : """11021""", "count" : """23""" },
    { "borrower" : """12438""", "count" : """23""" },
    { "borrower" : """12569""", "count" : """23""" },
    { "borrower" : """3226""", "count" : """22""" },
    { "borrower" : """5406""", "count" : """22""" },
    { "borrower" : """7675""", "count" : """22""" },
    { "borrower" : """226""", "count" : """21""" },
    { "borrower" : """1083""", "count" : """21""" },
    { "borrower" : """5194""", "count" : """21""" },
    { "borrower" : """6932""", "count" : """21""" },
    { "borrower" : """7076""", "count" : """21""" },
    { "borrower" : """8692""", "count" : """21""" },
    { "borrower" : """10975""", "count" : """21""" },
    { "borrower" : """11213""", "count" : """21""" },
    { "borrower" : """14135""", "count" : """21""" },
    { "borrower" : """17766""", "count" : """21""" },
    { "borrower" : """17779""", "count" : """21""" },
    { "borrower" : """546""", "count" : """20""" },
    { "borrower" : """1222""", "count" : """20""" },
    { "borrower" : """1625""", "count" : """20""" },
    { "borrower" : """2184""", "count" : """20""" },
    { "borrower" : """3174""", "count" : """20""" },
    { "borrower" : """3852""", "count" : """20""" },
    { "borrower" : """5602""", "count" : """20""" },
    { "borrower" : """8768""", "count" : """20""" },
    { "borrower" : """10478""", "count" : """20""" },
    { "borrower" : """11376""", "count" : """20""" },
    { "borrower" : """11846""", "count" : """20""" },
    { "borrower" : """11946""", "count" : """20""" },
    { "borrower" : """4""", "count" : """19""" },
    { "borrower" : """1144""", "count" : """19""" },
    { "borrower" : """1602""", "count" : """19""" },
    { "borrower" : """2280""", "count" : """19""" },
    { "borrower" : """2631""", "count" : """19""" },
    { "borrower" : """2868""", "count" : """19""" },
    { "borrower" : """3824""", "count" : """19""" },
    { "borrower" : """4020""", "count" : """19""" },
    { "borrower" : """5034""", "count" : """19""" },
    { "borrower" : """5348""", "count" : """19""" },
    { "borrower" : """5455""", "count" : """19""" },
    { "borrower" : """9260""", "count" : """19""" },
    { "borrower" : """10083""", "count" : """19""" },
    { "borrower" : """12192""", "count" : """19""" },
    { "borrower" : """19181""", "count" : """19""" },
    { "borrower" : """1254""", "count" : """18""" },
    { "borrower" : """1913""", "count" : """18""" },
    { "borrower" : """1931""", "count" : """18""" },
    { "borrower" : """1967""", "count" : """18""" },
    { "borrower" : """1975""", "count" : """18""" },
    { "borrower" : """2150""", "count" : """18""" },
    { "borrower" : """2844""", "count" : """18""" },
    { "borrower" : """3443""", "count" : """18""" },
    { "borrower" : """3819""", "count" : """18""" },
    { "borrower" : """5584""", "count" : """18""" },
    { "borrower" : """6891""", "count" : """18""" },
    { "borrower" : """8834""", "count" : """18""" },
    { "borrower" : """10405""", "count" : """18""" },
    { "borrower" : """10934""", "count" : """18""" },
    { "borrower" : """11640""", "count" : """18""" },
    { "borrower" : """13041""", "count" : """18""" },
    { "borrower" : """20741""", "count" : """18""" },
    { "borrower" : """260""", "count" : """17""" },
    { "borrower" : """720""", "count" : """17""" },
    { "borrower" : """967""", "count" : """17""" },
    { "borrower" : """1018""", "count" : """17""" },
    { "borrower" : """1926""", "count" : """17""" },
    { "borrower" : """2593""", "count" : """17""" },
    { "borrower" : """2734""", "count" : """17""" },
    { "borrower" : """3278""", "count" : """17""" },
    { "borrower" : """3726""", "count" : """17""" },
    { "borrower" : """5574""", "count" : """17""" },
    { "borrower" : """5778""", "count" : """17""" },
    { "borrower" : """8263""", "count" : """17""" },
    { "borrower" : """8323""", "count" : """17""" },
    { "borrower" : """9432""", "count" : """17""" },
    { "borrower" : """10334""", "count" : """17""" },
    { "borrower" : """10765""", "count" : """17""" },
    { "borrower" : """12133""", "count" : """17""" },
    { "borrower" : """13239""", "count" : """17""" },
    { "borrower" : """14806""", "count" : """17""" },
    { "borrower" : """407""", "count" : """16""" },
    { "borrower" : """1150""", "count" : """16""" },
    { "borrower" : """1374""", "count" : """16""" },
    { "borrower" : """2143""", "count" : """16""" },
    { "borrower" : """2465""", "count" : """16""" },
    { "borrower" : """2566""", "count" : """16""" },
    { "borrower" : """4410""", "count" : """16""" },
    { "borrower" : """5058""", "count" : """16""" },
    { "borrower" : """5219""", "count" : """16""" },
    { "borrower" : """7141""", "count" : """16""" },
    { "borrower" : """7167""", "count" : """16""" },
    { "borrower" : """9169""", "count" : """16""" },
    { "borrower" : """9225""", "count" : """16""" },
    { "borrower" : """10073""", "count" : """16""" },
    { "borrower" : """11022""", "count" : """16""" },
    { "borrower" : """12124""", "count" : """16""" },
    { "borrower" : """12355""", "count" : """16""" },
    { "borrower" : """12965""", "count" : """16""" },
    { "borrower" : """13769""", "count" : """16""" },
    { "borrower" : """17441""", "count" : """16""" },
    { "borrower" : """2603""", "count" : """15""" },
    { "borrower" : """2816""", "count" : """15""" },
    { "borrower" : """2817""", "count" : """15""" },
    { "borrower" : """3098""", "count" : """15""" },
    { "borrower" : """3773""", "count" : """15""" },
    { "borrower" : """3842""", "count" : """15""" },
    { "borrower" : """4628""", "count" : """15""" },
    { "borrower" : """4959""", "count" : """15""" },
    { "borrower" : """5304""", "count" : """15""" },
    { "borrower" : """6226""", "count" : """15""" },
    { "borrower" : """7145""", "count" : """15""" },
    { "borrower" : """9425""", "count" : """15""" },
    { "borrower" : """10152""", "count" : """15""" },
    { "borrower" : """10364""", "count" : """15""" },
    { "borrower" : """11590""", "count" : """15""" },
    { "borrower" : """12324""", "count" : """15""" },
    { "borrower" : """12962""", "count" : """15""" },
    { "borrower" : """13763""", "count" : """15""" },
    { "borrower" : """14083""", "count" : """15""" },
    { "borrower" : """14540""", "count" : """15""" },
    { "borrower" : """14995""", "count" : """15""" },
    { "borrower" : """15695""", "count" : """15""" },
    { "borrower" : """17040""", "count" : """15""" },
    { "borrower" : """19484""", "count" : """15""" },
    { "borrower" : """20817""", "count" : """15""" },
    { "borrower" : """21895""", "count" : """15""" },
    { "borrower" : """147""", "count" : """14""" },
    { "borrower" : """677""", "count" : """14""" },
    { "borrower" : """1085""", "count" : """14""" },
    { "borrower" : """1179""", "count" : """14""" },
    { "borrower" : """1571""", "count" : """14""" },
    { "borrower" : """1580""", "count" : """14""" },
    { "borrower" : """1689""", "count" : """14""" },
    { "borrower" : """1862""", "count" : """14""" },
    { "borrower" : """3016""", "count" : """14""" },
    { "borrower" : """3095""", "count" : """14""" },
    { "borrower" : """3305""", "count" : """14""" },
    { "borrower" : """3486""", "count" : """14""" },
    { "borrower" : """4906""", "count" : """14""" },
    { "borrower" : """4970""", "count" : """14""" },
    { "borrower" : """4991""", "count" : """14""" },
    { "borrower" : """4996""", "count" : """14""" },
    { "borrower" : """5687""", "count" : """14""" },
    { "borrower" : """6790""", "count" : """14""" },
    { "borrower" : """6862""", "count" : """14""" },
    { "borrower" : """7963""", "count" : """14""" },
    { "borrower" : """8311""", "count" : """14""" },
    { "borrower" : """9735""", "count" : """14""" },
    { "borrower" : """11074""", "count" : """14""" },
    { "borrower" : """12009""", "count" : """14""" },
    { "borrower" : """12406""", "count" : """14""" },
    { "borrower" : """13121""", "count" : """14""" },
    { "borrower" : """14113""", "count" : """14""" },
    { "borrower" : """17955""", "count" : """14""" },
    { "borrower" : """23036""", "count" : """14""" },
    { "borrower" : """23202""", "count" : """14""" },
    { "borrower" : """24483""", "count" : """14""" },
    { "borrower" : """438""", "count" : """13""" },
    { "borrower" : """1064""", "count" : """13""" },
    { "borrower" : """1080""", "count" : """13""" },
    { "borrower" : """1852""", "count" : """13""" },
    { "borrower" : """1936""", "count" : """13""" },
    { "borrower" : """2360""", "count" : """13""" },
    { "borrower" : """2768""", "count" : """13""" },
    { "borrower" : """3379""", "count" : """13""" },
    { "borrower" : """3398""", "count" : """13""" },
    { "borrower" : """4164""", "count" : """13""" },
    { "borrower" : """4843""", "count" : """13""" },
    { "borrower" : """4846""", "count" : """13""" },
    { "borrower" : """4941""", "count" : """13""" },
    { "borrower" : """5107""", "count" : """13""" },
    { "borrower" : """6694""", "count" : """13""" },
    { "borrower" : """6912""", "count" : """13""" },
    { "borrower" : """7848""", "count" : """13""" },
    { "borrower" : """8000""", "count" : """13""" },
    { "borrower" : """8175""", "count" : """13""" },
    { "borrower" : """8207""", "count" : """13""" },
    { "borrower" : """8228""", "count" : """13""" },
    { "borrower" : """8302""", "count" : """13""" },
    { "borrower" : """8407""", "count" : """13""" },
    { "borrower" : """8597""", "count" : """13""" },
    { "borrower" : """8663""", "count" : """13""" },
    { "borrower" : """8821""", "count" : """13""" },
    { "borrower" : """9341""", "count" : """13""" },
    { "borrower" : """10620""", "count" : """13""" },
    { "borrower" : """11383""", "count" : """13""" },
    { "borrower" : """11416""", "count" : """13""" },
    { "borrower" : """11783""", "count" : """13""" },
    { "borrower" : """11855""", "count" : """13""" },
    { "borrower" : """13223""", "count" : """13""" },
    { "borrower" : """13937""", "count" : """13""" },
    { "borrower" : """14307""", "count" : """13""" },
    { "borrower" : """14334""", "count" : """13""" },
    { "borrower" : """15133""", "count" : """13""" },
    { "borrower" : """15737""", "count" : """13""" },
    { "borrower" : """17242""", "count" : """13""" },
    { "borrower" : """20895""", "count" : """13""" },
    { "borrower" : """21068""", "count" : """13""" },
    { "borrower" : """21548""", "count" : """13""" },
    { "borrower" : """23213""", "count" : """13""" },
    { "borrower" : """437""", "count" : """12""" },
    { "borrower" : """654""", "count" : """12""" },
    { "borrower" : """1340""", "count" : """12""" },
    { "borrower" : """1537""", "count" : """12""" },
    { "borrower" : """1614""", "count" : """12""" },
    { "borrower" : """1656""", "count" : """12""" },
    { "borrower" : """2151""", "count" : """12""" },
    { "borrower" : """2361""", "count" : """12""" },
    { "borrower" : """2765""", "count" : """12""" },
    { "borrower" : """2835""", "count" : """12""" },
    { "borrower" : """3233""", "count" : """12""" },
    { "borrower" : """3249""", "count" : """12""" },
    { "borrower" : """4197""", "count" : """12""" },
    { "borrower" : """4369""", "count" : """12""" },
    { "borrower" : """5394""", "count" : """12""" },
    { "borrower" : """6091""", "count" : """12""" },
    { "borrower" : """6189""", "count" : """12""" },
    { "borrower" : """6238""", "count" : """12""" },
    { "borrower" : """6782""", "count" : """12""" },
    { "borrower" : """6830""", "count" : """12""" },
    { "borrower" : """7116""", "count" : """12""" },
    { "borrower" : """7542""", "count" : """12""" },
    { "borrower" : """8147""", "count" : """12""" },
    { "borrower" : """9393""", "count" : """12""" },
    { "borrower" : """9673""", "count" : """12""" },
    { "borrower" : """9674""", "count" : """12""" },
    { "borrower" : """10072""", "count" : """12""" },
    { "borrower" : """10365""", "count" : """12""" },
    { "borrower" : """10953""", "count" : """12""" },
    { "borrower" : """10966""", "count" : """12""" },
    { "borrower" : """11394""", "count" : """12""" },
    { "borrower" : """14214""", "count" : """12""" },
    { "borrower" : """18080""", "count" : """12""" },
    { "borrower" : """18370""", "count" : """12""" },
    { "borrower" : """160""", "count" : """11""" },
    { "borrower" : """1045""", "count" : """11""" },
    { "borrower" : """1078""", "count" : """11""" },
    { "borrower" : """1185""", "count" : """11""" },
    { "borrower" : """1554""", "count" : """11""" },
    { "borrower" : """1557""", "count" : """11""" },
    { "borrower" : """1916""", "count" : """11""" },
    { "borrower" : """2168""", "count" : """11""" },
    { "borrower" : """2213""", "count" : """11""" },
    { "borrower" : """2373""", "count" : """11""" },
    { "borrower" : """2412""", "count" : """11""" },
    { "borrower" : """3821""", "count" : """11""" },
    { "borrower" : """4142""", "count" : """11""" },
    { "borrower" : """4301""", "count" : """11""" },
    { "borrower" : """4342""", "count" : """11""" },
    { "borrower" : """5090""", "count" : """11""" },
    { "borrower" : """5099""", "count" : """11""" },
    { "borrower" : """5327""", "count" : """11""" },
    { "borrower" : """5470""", "count" : """11""" },
    { "borrower" : """6089""", "count" : """11""" },
    { "borrower" : """6123""", "count" : """11""" },
    { "borrower" : """6206""", "count" : """11""" },
    { "borrower" : """6393""", "count" : """11""" },
    { "borrower" : """6499""", "count" : """11""" },
    { "borrower" : """6730""", "count" : """11""" },
    { "borrower" : """7638""", "count" : """11""" },
    { "borrower" : """7797""", "count" : """11""" },
    { "borrower" : """7801""", "count" : """11""" },
    { "borrower" : """7983""", "count" : """11""" },
    { "borrower" : """8329""", "count" : """11""" },
    { "borrower" : """8779""", "count" : """11""" },
    { "borrower" : """8852""", "count" : """11""" },
    { "borrower" : """8934""", "count" : """11""" },
    { "borrower" : """8958""", "count" : """11""" },
    { "borrower" : """9409""", "count" : """11""" },
    { "borrower" : """10131""", "count" : """11""" },
    { "borrower" : """10282""", "count" : """11""" },
    { "borrower" : """12174""", "count" : """11""" },
    { "borrower" : """12759""", "count" : """11""" },
    { "borrower" : """12785""", "count" : """11""" },
    { "borrower" : """12970""", "count" : """11""" },
    { "borrower" : """13461""", "count" : """11""" },
    { "borrower" : """13989""", "count" : """11""" },
    { "borrower" : """14140""", "count" : """11""" },
    { "borrower" : """14238""", "count" : """11""" },
    { "borrower" : """14713""", "count" : """11""" },
    { "borrower" : """17188""", "count" : """11""" },
    { "borrower" : """17813""", "count" : """11""" },
    { "borrower" : """19961""", "count" : """11""" },
    { "borrower" : """220""", "count" : """10""" },
    { "borrower" : """243""", "count" : """10""" },
    { "borrower" : """1037""", "count" : """10""" },
    { "borrower" : """1162""", "count" : """10""" },
    { "borrower" : """1261""", "count" : """10""" },
    { "borrower" : """1462""", "count" : """10""" },
    { "borrower" : """1508""", "count" : """10""" },
    { "borrower" : """1764""", "count" : """10""" },
    { "borrower" : """1797""", "count" : """10""" },
    { "borrower" : """1867""", "count" : """10""" },
    { "borrower" : """1882""", "count" : """10""" },
    { "borrower" : """3064""", "count" : """10""" },
    { "borrower" : """3124""", "count" : """10""" },
    { "borrower" : """3931""", "count" : """10""" },
    { "borrower" : """4382""", "count" : """10""" },
    { "borrower" : """4844""", "count" : """10""" },
    { "borrower" : """5128""", "count" : """10""" },
    { "borrower" : """5365""", "count" : """10""" },
    { "borrower" : """6100""", "count" : """10""" },
    { "borrower" : """6584""", "count" : """10""" },
    { "borrower" : """7401""", "count" : """10""" },
    { "borrower" : """7610""", "count" : """10""" },
    { "borrower" : """7651""", "count" : """10""" },
    { "borrower" : """8233""", "count" : """10""" },
    { "borrower" : """8418""", "count" : """10""" },
    { "borrower" : """8931""", "count" : """10""" },
    { "borrower" : """9155""", "count" : """10""" },
    { "borrower" : """10231""", "count" : """10""" },
    { "borrower" : """10878""", "count" : """10""" },
    { "borrower" : """10948""", "count" : """10""" },
    { "borrower" : """11323""", "count" : """10""" },
    { "borrower" : """11468""", "count" : """10""" },
    { "borrower" : """12049""", "count" : """10""" },
    { "borrower" : """12208""", "count" : """10""" },
    { "borrower" : """13281""", "count" : """10""" },
    { "borrower" : """13880""", "count" : """10""" },
    { "borrower" : """13974""", "count" : """10""" },
    { "borrower" : """14048""", "count" : """10""" },
    { "borrower" : """14062""", "count" : """10""" },
    { "borrower" : """15668""", "count" : """10""" },
    { "borrower" : """15822""", "count" : """10""" },
    { "borrower" : """16386""", "count" : """10""" },
    { "borrower" : """17322""", "count" : """10""" },
    { "borrower" : """17535""", "count" : """10""" },
    { "borrower" : """18596""", "count" : """10""" },
    { "borrower" : """18676""", "count" : """10""" },
    { "borrower" : """19263""", "count" : """10""" },
    { "borrower" : """19563""", "count" : """10""" },
    { "borrower" : """20358""", "count" : """10""" },
    { "borrower" : """21381""", "count" : """10""" },
    { "borrower" : """23604""", "count" : """10""" },
    { "borrower" : """2""", "count" : """9""" },
    { "borrower" : """82""", "count" : """9""" },
    { "borrower" : """91""", "count" : """9""" },
    { "borrower" : """97""", "count" : """9""" },
    { "borrower" : """117""", "count" : """9""" },
    { "borrower" : """515""", "count" : """9""" },
    { "borrower" : """540""", "count" : """9""" },
    { "borrower" : """610""", "count" : """9""" },
    { "borrower" : """809""", "count" : """9""" },
    { "borrower" : """843""", "count" : """9""" },
    { "borrower" : """1001""", "count" : """9""" },
    { "borrower" : """1206""", "count" : """9""" },
    { "borrower" : """1412""", "count" : """9""" },
    { "borrower" : """1788""", "count" : """9""" },
    { "borrower" : """1911""", "count" : """9""" },
    { "borrower" : """1928""", "count" : """9""" },
    { "borrower" : """1999""", "count" : """9""" },
    { "borrower" : """2030""", "count" : """9""" },
    { "borrower" : """2643""", "count" : """9""" },
    { "borrower" : """3242""", "count" : """9""" },
    { "borrower" : """3481""", "count" : """9""" },
    { "borrower" : """3875""", "count" : """9""" },
    { "borrower" : """3988""", "count" : """9""" },
    { "borrower" : """4013""", "count" : """9""" },
    { "borrower" : """4246""", "count" : """9""" },
    { "borrower" : """4455""", "count" : """9""" },
    { "borrower" : """4636""", "count" : """9""" },
    { "borrower" : """4646""", "count" : """9""" },
    { "borrower" : """4772""", "count" : """9""" },
    { "borrower" : """5051""", "count" : """9""" },
    { "borrower" : """5225""", "count" : """9""" },
    { "borrower" : """5797""", "count" : """9""" },
    { "borrower" : """5820""", "count" : """9""" },
    { "borrower" : """5859""", "count" : """9""" },
    { "borrower" : """6424""", "count" : """9""" },
    { "borrower" : """6619""", "count" : """9""" },
    { "borrower" : """6672""", "count" : """9""" },
    { "borrower" : """6791""", "count" : """9""" },
    { "borrower" : """7042""", "count" : """9""" },
    { "borrower" : """8349""", "count" : """9""" },
    { "borrower" : """8568""", "count" : """9""" },
    { "borrower" : """8606""", "count" : """9""" },
    { "borrower" : """9566""", "count" : """9""" },
    { "borrower" : """9598""", "count" : """9""" },
    { "borrower" : """10339""", "count" : """9""" },
    { "borrower" : """10703""", "count" : """9""" },
    { "borrower" : """10705""", "count" : """9""" },
    { "borrower" : """10920""", "count" : """9""" },
    { "borrower" : """11505""", "count" : """9""" },
    { "borrower" : """11525""", "count" : """9""" },
    { "borrower" : """11922""", "count" : """9""" },
    { "borrower" : """12356""", "count" : """9""" },
    { "borrower" : """12423""", "count" : """9""" },
    { "borrower" : """12671""", "count" : """9""" },
    { "borrower" : """13027""", "count" : """9""" },
    { "borrower" : """13065""", "count" : """9""" },
    { "borrower" : """13113""", "count" : """9""" },
    { "borrower" : """13911""", "count" : """9""" },
    { "borrower" : """13977""", "count" : """9""" },
    { "borrower" : """14103""", "count" : """9""" },
    { "borrower" : """14634""", "count" : """9""" },
    { "borrower" : """15977""", "count" : """9""" },
    { "borrower" : """16427""", "count" : """9""" },
    { "borrower" : """16884""", "count" : """9""" },
    { "borrower" : """18616""", "count" : """9""" },
    { "borrower" : """18857""", "count" : """9""" },
    { "borrower" : """19037""", "count" : """9""" },
    { "borrower" : """19170""", "count" : """9""" },
    { "borrower" : """19226""", "count" : """9""" },
    { "borrower" : """20249""", "count" : """9""" },
    { "borrower" : """20814""", "count" : """9""" },
    { "borrower" : """21167""", "count" : """9""" },
    { "borrower" : """21436""", "count" : """9""" },
    { "borrower" : """51""", "count" : """8""" },
    { "borrower" : """217""", "count" : """8""" },
    { "borrower" : """224""", "count" : """8""" },
    { "borrower" : """1068""", "count" : """8""" },
    { "borrower" : """1627""", "count" : """8""" },
    { "borrower" : """1726""", "count" : """8""" },
    { "borrower" : """2033""", "count" : """8""" },
    { "borrower" : """2181""", "count" : """8""" },
    { "borrower" : """2481""", "count" : """8""" },
    { "borrower" : """2518""", "count" : """8""" },
    { "borrower" : """2558""", "count" : """8""" },
    { "borrower" : """2628""", "count" : """8""" },
    { "borrower" : """3070""", "count" : """8""" },
    { "borrower" : """3203""", "count" : """8""" },
    { "borrower" : """3465""", "count" : """8""" },
    { "borrower" : """3614""", "count" : """8""" },
    { "borrower" : """4178""", "count" : """8""" },
    { "borrower" : """4346""", "count" : """8""" },
    { "borrower" : """4347""", "count" : """8""" },
    { "borrower" : """4476""", "count" : """8""" },
    { "borrower" : """4578""", "count" : """8""" },
    { "borrower" : """5357""", "count" : """8""" },
    { "borrower" : """5462""", "count" : """8""" },
    { "borrower" : """5480""", "count" : """8""" },
    { "borrower" : """5684""", "count" : """8""" },
    { "borrower" : """5711""", "count" : """8""" },
    { "borrower" : """6177""", "count" : """8""" },
    { "borrower" : """6282""", "count" : """8""" },
    { "borrower" : """6555""", "count" : """8""" },
    { "borrower" : """6580""", "count" : """8""" },
    { "borrower" : """6643""", "count" : """8""" },
    { "borrower" : """6693""", "count" : """8""" },
    { "borrower" : """6735""", "count" : """8""" },
    { "borrower" : """7206""", "count" : """8""" },
    { "borrower" : """7406""", "count" : """8""" },
    { "borrower" : """7501""", "count" : """8""" },
    { "borrower" : """7510""", "count" : """8""" },
    { "borrower" : """7897""", "count" : """8""" },
    { "borrower" : """8611""", "count" : """8""" },
    { "borrower" : """9160""", "count" : """8""" },
    { "borrower" : """9161""", "count" : """8""" },
    { "borrower" : """9540""", "count" : """8""" },
    { "borrower" : """9610""", "count" : """8""" },
    { "borrower" : """9858""", "count" : """8""" },
    { "borrower" : """9912""", "count" : """8""" },
    { "borrower" : """10088""", "count" : """8""" },
    { "borrower" : """10419""", "count" : """8""" },
    { "borrower" : """10612""", "count" : """8""" },
    { "borrower" : """10646""", "count" : """8""" },
    { "borrower" : """10682""", "count" : """8""" },
    { "borrower" : """10728""", "count" : """8""" },
    { "borrower" : """10868""", "count" : """8""" },
    { "borrower" : """10875""", "count" : """8""" },
    { "borrower" : """11515""", "count" : """8""" },
    { "borrower" : """11559""", "count" : """8""" },
    { "borrower" : """11638""", "count" : """8""" },
    { "borrower" : """11707""", "count" : """8""" },
    { "borrower" : """11786""", "count" : """8""" },
    { "borrower" : """12142""", "count" : """8""" },
    { "borrower" : """12255""", "count" : """8""" },
    { "borrower" : """12514""", "count" : """8""" },
    { "borrower" : """12627""", "count" : """8""" },
    { "borrower" : """12762""", "count" : """8""" },
    { "borrower" : """12939""", "count" : """8""" },
    { "borrower" : """12961""", "count" : """8""" },
    { "borrower" : """13211""", "count" : """8""" },
    { "borrower" : """13451""", "count" : """8""" },
    { "borrower" : """13487""", "count" : """8""" },
    { "borrower" : """13558""", "count" : """8""" },
    { "borrower" : """13833""", "count" : """8""" },
    { "borrower" : """14025""", "count" : """8""" },
    { "borrower" : """14335""", "count" : """8""" },
    { "borrower" : """15163""", "count" : """8""" },
    { "borrower" : """15285""", "count" : """8""" },
    { "borrower" : """15366""", "count" : """8""" },
    { "borrower" : """15388""", "count" : """8""" },
    { "borrower" : """15968""", "count" : """8""" },
    { "borrower" : """17551""", "count" : """8""" },
    { "borrower" : """17893""", "count" : """8""" },
    { "borrower" : """18088""", "count" : """8""" },
    { "borrower" : """18094""", "count" : """8""" },
    { "borrower" : """19993""", "count" : """8""" },
    { "borrower" : """20109""", "count" : """8""" },
    { "borrower" : """20694""", "count" : """8""" },
    { "borrower" : """22580""", "count" : """8""" },
    { "borrower" : """22911""", "count" : """8""" },
    { "borrower" : """23271""", "count" : """8""" },
    { "borrower" : """23575""", "count" : """8""" },
    { "borrower" : """23730""", "count" : """8""" },
    { "borrower" : """24197""", "count" : """8""" },
    { "borrower" : """71""", "count" : """7""" },
    { "borrower" : """101""", "count" : """7""" },
    { "borrower" : """212""", "count" : """7""" },
    { "borrower" : """222""", "count" : """7""" },
    { "borrower" : """264""", "count" : """7""" },
    { "borrower" : """295""", "count" : """7""" },
    { "borrower" : """352""", "count" : """7""" },
    { "borrower" : """417""", "count" : """7""" },
    { "borrower" : """770""", "count" : """7""" },
    { "borrower" : """942""", "count" : """7""" },
    { "borrower" : """1213""", "count" : """7""" },
    { "borrower" : """1215""", "count" : """7""" },
    { "borrower" : """1218""", "count" : """7""" },
    { "borrower" : """1303""", "count" : """7""" },
    { "borrower" : """1371""", "count" : """7""" },
    { "borrower" : """1479""", "count" : """7""" },
    { "borrower" : """1647""", "count" : """7""" },
    { "borrower" : """1925""", "count" : """7""" },
    { "borrower" : """2346""", "count" : """7""" },
    { "borrower" : """2393""", "count" : """7""" },
    { "borrower" : """2459""", "count" : """7""" },
    { "borrower" : """2501""", "count" : """7""" },
    { "borrower" : """2829""", "count" : """7""" },
    { "borrower" : """2873""", "count" : """7""" },
    { "borrower" : """3322""", "count" : """7""" },
    { "borrower" : """3415""", "count" : """7""" },
    { "borrower" : """3488""", "count" : """7""" },
    { "borrower" : """3507""", "count" : """7""" },
    { "borrower" : """3617""", "count" : """7""" },
    { "borrower" : """3797""", "count" : """7""" },
    { "borrower" : """3952""", "count" : """7""" },
    { "borrower" : """3975""", "count" : """7""" },
    { "borrower" : """4038""", "count" : """7""" },
    { "borrower" : """4326""", "count" : """7""" },
    { "borrower" : """4639""", "count" : """7""" },
    { "borrower" : """4706""", "count" : """7""" },
    { "borrower" : """5054""", "count" : """7""" },
    { "borrower" : """5248""", "count" : """7""" },
    { "borrower" : """5450""", "count" : """7""" },
    { "borrower" : """5496""", "count" : """7""" },
    { "borrower" : """5850""", "count" : """7""" },
    { "borrower" : """5866""", "count" : """7""" },
    { "borrower" : """5895""", "count" : """7""" },
    { "borrower" : """6535""", "count" : """7""" },
    { "borrower" : """6608""", "count" : """7""" },
    { "borrower" : """6669""", "count" : """7""" },
    { "borrower" : """6873""", "count" : """7""" },
    { "borrower" : """6892""", "count" : """7""" },
    { "borrower" : """6989""", "count" : """7""" },
    { "borrower" : """7489""", "count" : """7""" },
    { "borrower" : """8285""", "count" : """7""" },
    { "borrower" : """8422""", "count" : """7""" },
    { "borrower" : """8845""", "count" : """7""" },
    { "borrower" : """8985""", "count" : """7""" },
    { "borrower" : """9106""", "count" : """7""" },
    { "borrower" : """9130""", "count" : """7""" },
    { "borrower" : """9145""", "count" : """7""" },
    { "borrower" : """9243""", "count" : """7""" },
    { "borrower" : """9401""", "count" : """7""" },
    { "borrower" : """9764""", "count" : """7""" },
    { "borrower" : """9891""", "count" : """7""" },
    { "borrower" : """10043""", "count" : """7""" },
    { "borrower" : """10304""", "count" : """7""" },
    { "borrower" : """10502""", "count" : """7""" },
    { "borrower" : """10777""", "count" : """7""" },
    { "borrower" : """10986""", "count" : """7""" },
    { "borrower" : """11210""", "count" : """7""" },
    { "borrower" : """11237""", "count" : """7""" },
    { "borrower" : """11398""", "count" : """7""" },
    { "borrower" : """11413""", "count" : """7""" },
    { "borrower" : """11456""", "count" : """7""" },
    { "borrower" : """11596""", "count" : """7""" },
    { "borrower" : """11711""", "count" : """7""" },
    { "borrower" : """12069""", "count" : """7""" },
    { "borrower" : """12317""", "count" : """7""" },
    { "borrower" : """12427""", "count" : """7""" },
    { "borrower" : """12490""", "count" : """7""" },
    { "borrower" : """12499""", "count" : """7""" },
    { "borrower" : """12948""", "count" : """7""" },
    { "borrower" : """13091""", "count" : """7""" },
    { "borrower" : """13434""", "count" : """7""" },
    { "borrower" : """13468""", "count" : """7""" },
    { "borrower" : """13960""", "count" : """7""" },
    { "borrower" : """14036""", "count" : """7""" },
    { "borrower" : """14127""", "count" : """7""" },
    { "borrower" : """14345""", "count" : """7""" },
    { "borrower" : """14386""", "count" : """7""" },
    { "borrower" : """14439""", "count" : """7""" },
    { "borrower" : """15480""", "count" : """7""" },
    { "borrower" : """15607""", "count" : """7""" },
    { "borrower" : """15638""", "count" : """7""" },
    { "borrower" : """15874""", "count" : """7""" },
    { "borrower" : """16363""", "count" : """7""" },
    { "borrower" : """17229""", "count" : """7""" },
    { "borrower" : """17311""", "count" : """7""" },
    { "borrower" : """17565""", "count" : """7""" },
    { "borrower" : """17570""", "count" : """7""" },
    { "borrower" : """17689""", "count" : """7""" },
    { "borrower" : """17708""", "count" : """7""" },
    { "borrower" : """17901""", "count" : """7""" },
    { "borrower" : """17909""", "count" : """7""" },
    { "borrower" : """17939""", "count" : """7""" },
    { "borrower" : """18125""", "count" : """7""" },
    { "borrower" : """18481""", "count" : """7""" },
    { "borrower" : """18950""", "count" : """7""" },
    { "borrower" : """19066""", "count" : """7""" },
    { "borrower" : """19391""", "count" : """7""" },
    { "borrower" : """19783""", "count" : """7""" },
    { "borrower" : """20375""", "count" : """7""" },
    { "borrower" : """20559""", "count" : """7""" },
    { "borrower" : """21706""", "count" : """7""" },
    { "borrower" : """22069""", "count" : """7""" },
    { "borrower" : """22481""", "count" : """7""" },
    { "borrower" : """22922""", "count" : """7""" },
    { "borrower" : """22971""", "count" : """7""" },
    { "borrower" : """24066""", "count" : """7""" },
    { "borrower" : """112""", "count" : """6""" },
    { "borrower" : """239""", "count" : """6""" },
    { "borrower" : """377""", "count" : """6""" },
    { "borrower" : """538""", "count" : """6""" },
    { "borrower" : """565""", "count" : """6""" },
    { "borrower" : """638""", "count" : """6""" },
    { "borrower" : """842""", "count" : """6""" },
    { "borrower" : """1052""", "count" : """6""" },
    { "borrower" : """1109""", "count" : """6""" },
    { "borrower" : """1202""", "count" : """6""" },
    { "borrower" : """1270""", "count" : """6""" },
    { "borrower" : """1307""", "count" : """6""" },
    { "borrower" : """1367""", "count" : """6""" },
    { "borrower" : """1385""", "count" : """6""" },
    { "borrower" : """1413""", "count" : """6""" },
    { "borrower" : """1499""", "count" : """6""" },
    { "borrower" : """1530""", "count" : """6""" },
    { "borrower" : """1599""", "count" : """6""" },
    { "borrower" : """1823""", "count" : """6""" },
    { "borrower" : """1884""", "count" : """6""" },
    { "borrower" : """2179""", "count" : """6""" },
    { "borrower" : """2207""", "count" : """6""" },
    { "borrower" : """2345""", "count" : """6""" },
    { "borrower" : """2639""", "count" : """6""" },
    { "borrower" : """2747""", "count" : """6""" },
    { "borrower" : """2772""", "count" : """6""" },
    { "borrower" : """2823""", "count" : """6""" },
    { "borrower" : """2872""", "count" : """6""" },
    { "borrower" : """2963""", "count" : """6""" },
    { "borrower" : """2969""", "count" : """6""" },
    { "borrower" : """3059""", "count" : """6""" },
    { "borrower" : """3222""", "count" : """6""" },
    { "borrower" : """3247""", "count" : """6""" },
    { "borrower" : """3250""", "count" : """6""" },
    { "borrower" : """3336""", "count" : """6""" },
    { "borrower" : """4150""", "count" : """6""" },
    { "borrower" : """4664""", "count" : """6""" },
    { "borrower" : """4835""", "count" : """6""" },
    { "borrower" : """5105""", "count" : """6""" },
    { "borrower" : """5144""", "count" : """6""" },
    { "borrower" : """5260""", "count" : """6""" },
    { "borrower" : """5557""", "count" : """6""" },
    { "borrower" : """5830""", "count" : """6""" },
    { "borrower" : """6152""", "count" : """6""" },
    { "borrower" : """6160""", "count" : """6""" },
    { "borrower" : """6404""", "count" : """6""" },
    { "borrower" : """6546""", "count" : """6""" },
    { "borrower" : """6559""", "count" : """6""" },
    { "borrower" : """6704""", "count" : """6""" },
    { "borrower" : """6793""", "count" : """6""" },
    { "borrower" : """7082""", "count" : """6""" },
    { "borrower" : """7223""", "count" : """6""" },
    { "borrower" : """7380""", "count" : """6""" },
    { "borrower" : """7861""", "count" : """6""" },
    { "borrower" : """7946""", "count" : """6""" },
    { "borrower" : """8115""", "count" : """6""" },
    { "borrower" : """8145""", "count" : """6""" },
    { "borrower" : """8712""", "count" : """6""" },
    { "borrower" : """9287""", "count" : """6""" },
    { "borrower" : """9427""", "count" : """6""" },
    { "borrower" : """9637""", "count" : """6""" },
    { "borrower" : """9763""", "count" : """6""" },
    { "borrower" : """9872""", "count" : """6""" },
    { "borrower" : """9896""", "count" : """6""" },
    { "borrower" : """10318""", "count" : """6""" },
    { "borrower" : """10414""", "count" : """6""" },
    { "borrower" : """10738""", "count" : """6""" },
    { "borrower" : """10941""", "count" : """6""" },
    { "borrower" : """11434""", "count" : """6""" },
    { "borrower" : """11508""", "count" : """6""" },
    { "borrower" : """12301""", "count" : """6""" },
    { "borrower" : """12385""", "count" : """6""" },
    { "borrower" : """12567""", "count" : """6""" },
    { "borrower" : """12587""", "count" : """6""" },
    { "borrower" : """12696""", "count" : """6""" },
    { "borrower" : """12716""", "count" : """6""" },
    { "borrower" : """12746""", "count" : """6""" },
    { "borrower" : """12821""", "count" : """6""" },
    { "borrower" : """13001""", "count" : """6""" },
    { "borrower" : """13235""", "count" : """6""" },
    { "borrower" : """13324""", "count" : """6""" },
    { "borrower" : """13396""", "count" : """6""" },
    { "borrower" : """13427""", "count" : """6""" },
    { "borrower" : """13462""", "count" : """6""" },
    { "borrower" : """13692""", "count" : """6""" },
    { "borrower" : """13947""", "count" : """6""" },
    { "borrower" : """14473""", "count" : """6""" },
    { "borrower" : """14691""", "count" : """6""" },
    { "borrower" : """14729""", "count" : """6""" },
    { "borrower" : """14736""", "count" : """6""" },
    { "borrower" : """14749""", "count" : """6""" },
    { "borrower" : """15548""", "count" : """6""" },
    { "borrower" : """15624""", "count" : """6""" },
    { "borrower" : """16035""", "count" : """6""" },
    { "borrower" : """16050""", "count" : """6""" },
    { "borrower" : """16392""", "count" : """6""" },
    { "borrower" : """16493""", "count" : """6""" },
    { "borrower" : """16826""", "count" : """6""" },
    { "borrower" : """17629""", "count" : """6""" },
    { "borrower" : """17700""", "count" : """6""" },
    { "borrower" : """17777""", "count" : """6""" },
    { "borrower" : """17944""", "count" : """6""" },
    { "borrower" : """18159""", "count" : """6""" },
    { "borrower" : """18185""", "count" : """6""" },
    { "borrower" : """18223""", "count" : """6""" },
    { "borrower" : """18427""", "count" : """6""" },
    { "borrower" : """18685""", "count" : """6""" },
    { "borrower" : """18766""", "count" : """6""" },
    { "borrower" : """19019""", "count" : """6""" },
    { "borrower" : """19331""", "count" : """6""" },
    { "borrower" : """19539""", "count" : """6""" },
    { "borrower" : """19726""", "count" : """6""" },
    { "borrower" : """19758""", "count" : """6""" },
    { "borrower" : """20066""", "count" : """6""" },
    { "borrower" : """20264""", "count" : """6""" },
    { "borrower" : """20318""", "count" : """6""" },
    { "borrower" : """20645""", "count" : """6""" },
    { "borrower" : """20725""", "count" : """6""" },
    { "borrower" : """21546""", "count" : """6""" },
    { "borrower" : """21629""", "count" : """6""" },
    { "borrower" : """21818""", "count" : """6""" },
    { "borrower" : """22832""", "count" : """6""" },
    { "borrower" : """24186""", "count" : """6""" },
    { "borrower" : """25150""", "count" : """6""" },
    { "borrower" : """41""", "count" : """5""" },
    { "borrower" : """205""", "count" : """5""" },
    { "borrower" : """288""", "count" : """5""" },
    { "borrower" : """300""", "count" : """5""" },
    { "borrower" : """439""", "count" : """5""" },
    { "borrower" : """483""", "count" : """5""" },
    { "borrower" : """523""", "count" : """5""" },
    { "borrower" : """552""", "count" : """5""" },
    { "borrower" : """574""", "count" : """5""" },
    { "borrower" : """800""", "count" : """5""" },
    { "borrower" : """845""", "count" : """5""" },
    { "borrower" : """892""", "count" : """5""" },
    { "borrower" : """906""", "count" : """5""" },
    { "borrower" : """951""", "count" : """5""" },
    { "borrower" : """982""", "count" : """5""" },
    { "borrower" : """1165""", "count" : """5""" },
    { "borrower" : """1250""", "count" : """5""" },
    { "borrower" : """1319""", "count" : """5""" },
    { "borrower" : """1411""", "count" : """5""" },
    { "borrower" : """1416""", "count" : """5""" },
    { "borrower" : """1417""", "count" : """5""" },
    { "borrower" : """1541""", "count" : """5""" },
    { "borrower" : """1549""", "count" : """5""" },
    { "borrower" : """1598""", "count" : """5""" },
    { "borrower" : """1618""", "count" : """5""" },
    { "borrower" : """1702""", "count" : """5""" },
    { "borrower" : """1749""", "count" : """5""" },
    { "borrower" : """1845""", "count" : """5""" },
    { "borrower" : """2114""", "count" : """5""" },
    { "borrower" : """2120""", "count" : """5""" },
    { "borrower" : """2470""", "count" : """5""" },
    { "borrower" : """2491""", "count" : """5""" },
    { "borrower" : """2836""", "count" : """5""" },
    { "borrower" : """2851""", "count" : """5""" },
    { "borrower" : """2992""", "count" : """5""" },
    { "borrower" : """3073""", "count" : """5""" },
    { "borrower" : """3103""", "count" : """5""" },
    { "borrower" : """3270""", "count" : """5""" },
    { "borrower" : """3304""", "count" : """5""" },
    { "borrower" : """3537""", "count" : """5""" },
    { "borrower" : """3602""", "count" : """5""" },
    { "borrower" : """3778""", "count" : """5""" },
    { "borrower" : """3795""", "count" : """5""" },
    { "borrower" : """3813""", "count" : """5""" },
    { "borrower" : """3906""", "count" : """5""" },
    { "borrower" : """3924""", "count" : """5""" },
    { "borrower" : """4095""", "count" : """5""" },
    { "borrower" : """4474""", "count" : """5""" },
    { "borrower" : """4495""", "count" : """5""" },
    { "borrower" : """4500""", "count" : """5""" },
    { "borrower" : """4592""", "count" : """5""" },
    { "borrower" : """4752""", "count" : """5""" },
    { "borrower" : """5062""", "count" : """5""" },
    { "borrower" : """5115""", "count" : """5""" },
    { "borrower" : """5142""", "count" : """5""" },
    { "borrower" : """5180""", "count" : """5""" },
    { "borrower" : """5261""", "count" : """5""" },
    { "borrower" : """5579""", "count" : """5""" },
    { "borrower" : """5673""", "count" : """5""" },
    { "borrower" : """5692""", "count" : """5""" },
    { "borrower" : """6064""", "count" : """5""" },
    { "borrower" : """6198""", "count" : """5""" },
    { "borrower" : """6328""", "count" : """5""" },
    { "borrower" : """6349""", "count" : """5""" },
    { "borrower" : """6378""", "count" : """5""" },
    { "borrower" : """6761""", "count" : """5""" },
    { "borrower" : """7506""", "count" : """5""" },
    { "borrower" : """8064""", "count" : """5""" },
    { "borrower" : """8148""", "count" : """5""" },
    { "borrower" : """8152""", "count" : """5""" },
    { "borrower" : """8248""", "count" : """5""" },
    { "borrower" : """8490""", "count" : """5""" },
    { "borrower" : """8673""", "count" : """5""" },
    { "borrower" : """8824""", "count" : """5""" },
    { "borrower" : """9159""", "count" : """5""" },
    { "borrower" : """9589""", "count" : """5""" },
    { "borrower" : """9728""", "count" : """5""" },
    { "borrower" : """10184""", "count" : """5""" },
    { "borrower" : """10385""", "count" : """5""" },
    { "borrower" : """10415""", "count" : """5""" },
    { "borrower" : """10619""", "count" : """5""" },
    { "borrower" : """10676""", "count" : """5""" },
    { "borrower" : """10721""", "count" : """5""" },
    { "borrower" : """10908""", "count" : """5""" },
    { "borrower" : """10962""", "count" : """5""" },
    { "borrower" : """11165""", "count" : """5""" },
    { "borrower" : """11285""", "count" : """5""" },
    { "borrower" : """11356""", "count" : """5""" },
    { "borrower" : """11551""", "count" : """5""" },
    { "borrower" : """11657""", "count" : """5""" },
    { "borrower" : """11864""", "count" : """5""" },
    { "borrower" : """11867""", "count" : """5""" },
    { "borrower" : """12148""", "count" : """5""" },
    { "borrower" : """12244""", "count" : """5""" },
    { "borrower" : """12443""", "count" : """5""" },
    { "borrower" : """12482""", "count" : """5""" },
    { "borrower" : """12677""", "count" : """5""" },
    { "borrower" : """12683""", "count" : """5""" },
    { "borrower" : """12713""", "count" : """5""" },
    { "borrower" : """12842""", "count" : """5""" },
    { "borrower" : """12909""", "count" : """5""" },
    { "borrower" : """12934""", "count" : """5""" },
    { "borrower" : """13067""", "count" : """5""" },
    { "borrower" : """13079""", "count" : """5""" },
    { "borrower" : """13082""", "count" : """5""" },
    { "borrower" : """13105""", "count" : """5""" },
    { "borrower" : """13128""", "count" : """5""" },
    { "borrower" : """13196""", "count" : """5""" },
    { "borrower" : """13258""", "count" : """5""" },
    { "borrower" : """13323""", "count" : """5""" },
    { "borrower" : """13386""", "count" : """5""" },
    { "borrower" : """13552""", "count" : """5""" },
    { "borrower" : """13770""", "count" : """5""" },
    { "borrower" : """13808""", "count" : """5""" },
    { "borrower" : """14111""", "count" : """5""" },
    { "borrower" : """14193""", "count" : """5""" },
    { "borrower" : """14346""", "count" : """5""" },
    { "borrower" : """14583""", "count" : """5""" },
    { "borrower" : """14590""", "count" : """5""" },
    { "borrower" : """14628""", "count" : """5""" },
    { "borrower" : """14636""", "count" : """5""" },
    { "borrower" : """14788""", "count" : """5""" },
    { "borrower" : """14947""", "count" : """5""" },
    { "borrower" : """14971""", "count" : """5""" },
    { "borrower" : """15128""", "count" : """5""" },
    { "borrower" : """15257""", "count" : """5""" },
    { "borrower" : """15462""", "count" : """5""" },
    { "borrower" : """15561""", "count" : """5""" },
    { "borrower" : """15847""", "count" : """5""" },
    { "borrower" : """15855""", "count" : """5""" },
    { "borrower" : """16491""", "count" : """5""" },
    { "borrower" : """17319""", "count" : """5""" },
    { "borrower" : """17744""", "count" : """5""" },
    { "borrower" : """17758""", "count" : """5""" },
    { "borrower" : """17876""", "count" : """5""" },
    { "borrower" : """18144""", "count" : """5""" },
    { "borrower" : """18336""", "count" : """5""" },
    { "borrower" : """18530""", "count" : """5""" },
    { "borrower" : """18913""", "count" : """5""" },
    { "borrower" : """19068""", "count" : """5""" },
    { "borrower" : """20074""", "count" : """5""" },
    { "borrower" : """20374""", "count" : """5""" },
    { "borrower" : """20869""", "count" : """5""" },
    { "borrower" : """21376""", "count" : """5""" },
    { "borrower" : """21441""", "count" : """5""" },
    { "borrower" : """21497""", "count" : """5""" },
    { "borrower" : """21788""", "count" : """5""" },
    { "borrower" : """22737""", "count" : """5""" },
    { "borrower" : """23088""", "count" : """5""" },
    { "borrower" : """24326""", "count" : """5""" },
    { "borrower" : """24341""", "count" : """5""" },
    { "borrower" : """24807""", "count" : """5""" },
    { "borrower" : """35""", "count" : """4""" },
    { "borrower" : """79""", "count" : """4""" },
    { "borrower" : """88""", "count" : """4""" },
    { "borrower" : """96""", "count" : """4""" },
    { "borrower" : """115""", "count" : """4""" },
    { "borrower" : """143""", "count" : """4""" },
    { "borrower" : """169""", "count" : """4""" },
    { "borrower" : """189""", "count" : """4""" },
    { "borrower" : """238""", "count" : """4""" },
    { "borrower" : """330""", "count" : """4""" },
    { "borrower" : """341""", "count" : """4""" },
    { "borrower" : """442""", "count" : """4""" },
    { "borrower" : """502""", "count" : """4""" },
    { "borrower" : """528""", "count" : """4""" },
    { "borrower" : """592""", "count" : """4""" },
    { "borrower" : """919""", "count" : """4""" },
    { "borrower" : """1095""", "count" : """4""" },
    { "borrower" : """1133""", "count" : """4""" },
    { "borrower" : """1259""", "count" : """4""" },
    { "borrower" : """1281""", "count" : """4""" },
    { "borrower" : """1335""", "count" : """4""" },
    { "borrower" : """1366""", "count" : """4""" },
    { "borrower" : """1617""", "count" : """4""" },
    { "borrower" : """1957""", "count" : """4""" },
    { "borrower" : """1968""", "count" : """4""" },
    { "borrower" : """2139""", "count" : """4""" },
    { "borrower" : """2155""", "count" : """4""" },
    { "borrower" : """2349""", "count" : """4""" },
    { "borrower" : """2355""", "count" : """4""" },
    { "borrower" : """2392""", "count" : """4""" },
    { "borrower" : """2443""", "count" : """4""" },
    { "borrower" : """2474""", "count" : """4""" },
    { "borrower" : """2502""", "count" : """4""" },
    { "borrower" : """2534""", "count" : """4""" },
    { "borrower" : """2841""", "count" : """4""" },
    { "borrower" : """2858""", "count" : """4""" },
    { "borrower" : """2883""", "count" : """4""" },
    { "borrower" : """3065""", "count" : """4""" },
    { "borrower" : """3179""", "count" : """4""" },
    { "borrower" : """3294""", "count" : """4""" },
    { "borrower" : """3372""", "count" : """4""" },
    { "borrower" : """3373""", "count" : """4""" },
    { "borrower" : """3394""", "count" : """4""" },
    { "borrower" : """3516""", "count" : """4""" },
    { "borrower" : """3633""", "count" : """4""" },
    { "borrower" : """3752""", "count" : """4""" },
    { "borrower" : """3815""", "count" : """4""" },
    { "borrower" : """3895""", "count" : """4""" },
    { "borrower" : """4184""", "count" : """4""" },
    { "borrower" : """4198""", "count" : """4""" },
    { "borrower" : """4306""", "count" : """4""" },
    { "borrower" : """4397""", "count" : """4""" },
    { "borrower" : """4434""", "count" : """4""" },
    { "borrower" : """4509""", "count" : """4""" },
    { "borrower" : """4552""", "count" : """4""" },
    { "borrower" : """4583""", "count" : """4""" },
    { "borrower" : """4696""", "count" : """4""" },
    { "borrower" : """4714""", "count" : """4""" },
    { "borrower" : """4776""", "count" : """4""" },
    { "borrower" : """5038""", "count" : """4""" },
    { "borrower" : """5345""", "count" : """4""" },
    { "borrower" : """5369""", "count" : """4""" },
    { "borrower" : """5457""", "count" : """4""" },
    { "borrower" : """5567""", "count" : """4""" },
    { "borrower" : """5772""", "count" : """4""" },
    { "borrower" : """5776""", "count" : """4""" },
    { "borrower" : """5780""", "count" : """4""" },
    { "borrower" : """5796""", "count" : """4""" },
    { "borrower" : """5962""", "count" : """4""" },
    { "borrower" : """6015""", "count" : """4""" },
    { "borrower" : """6061""", "count" : """4""" },
    { "borrower" : """6232""", "count" : """4""" },
    { "borrower" : """6236""", "count" : """4""" },
    { "borrower" : """6302""", "count" : """4""" },
    { "borrower" : """6304""", "count" : """4""" },
    { "borrower" : """6373""", "count" : """4""" },
    { "borrower" : """6377""", "count" : """4""" },
    { "borrower" : """6667""", "count" : """4""" },
    { "borrower" : """6845""", "count" : """4""" },
    { "borrower" : """7039""", "count" : """4""" },
    { "borrower" : """7113""", "count" : """4""" },
    { "borrower" : """7228""", "count" : """4""" },
    { "borrower" : """7233""", "count" : """4""" },
    { "borrower" : """7400""", "count" : """4""" },
    { "borrower" : """7516""", "count" : """4""" },
    { "borrower" : """7580""", "count" : """4""" },
    { "borrower" : """8108""", "count" : """4""" },
    { "borrower" : """8273""", "count" : """4""" },
    { "borrower" : """8274""", "count" : """4""" },
    { "borrower" : """8314""", "count" : """4""" },
    { "borrower" : """8379""", "count" : """4""" },
    { "borrower" : """8502""", "count" : """4""" },
    { "borrower" : """8504""", "count" : """4""" },
    { "borrower" : """8843""", "count" : """4""" },
    { "borrower" : """8939""", "count" : """4""" },
    { "borrower" : """9200""", "count" : """4""" },
    { "borrower" : """9351""", "count" : """4""" },
    { "borrower" : """9379""", "count" : """4""" },
    { "borrower" : """9526""", "count" : """4""" },
    { "borrower" : """9661""", "count" : """4""" },
    { "borrower" : """9725""", "count" : """4""" },
    { "borrower" : """9960""", "count" : """4""" },
    { "borrower" : """10063""", "count" : """4""" },
    { "borrower" : """10265""", "count" : """4""" },
    { "borrower" : """10601""", "count" : """4""" },
    { "borrower" : """10890""", "count" : """4""" },
    { "borrower" : """11041""", "count" : """4""" },
    { "borrower" : """11145""", "count" : """4""" },
    { "borrower" : """11361""", "count" : """4""" },
    { "borrower" : """11517""", "count" : """4""" },
    { "borrower" : """11547""", "count" : """4""" },
    { "borrower" : """11581""", "count" : """4""" },
    { "borrower" : """11593""", "count" : """4""" },
    { "borrower" : """11739""", "count" : """4""" },
    { "borrower" : """11934""", "count" : """4""" },
    { "borrower" : """12024""", "count" : """4""" },
    { "borrower" : """12027""", "count" : """4""" },
    { "borrower" : """12225""", "count" : """4""" },
    { "borrower" : """12446""", "count" : """4""" },
    { "borrower" : """12480""", "count" : """4""" },
    { "borrower" : """12870""", "count" : """4""" },
    { "borrower" : """12940""", "count" : """4""" },
    { "borrower" : """12950""", "count" : """4""" },
    { "borrower" : """12968""", "count" : """4""" },
    { "borrower" : """13013""", "count" : """4""" },
    { "borrower" : """13229""", "count" : """4""" },
    { "borrower" : """13246""", "count" : """4""" },
    { "borrower" : """13327""", "count" : """4""" },
    { "borrower" : """13516""", "count" : """4""" },
    { "borrower" : """13642""", "count" : """4""" },
    { "borrower" : """13693""", "count" : """4""" },
    { "borrower" : """13729""", "count" : """4""" },
    { "borrower" : """13946""", "count" : """4""" },
    { "borrower" : """14160""", "count" : """4""" },
    { "borrower" : """14229""", "count" : """4""" },
    { "borrower" : """14262""", "count" : """4""" },
    { "borrower" : """14278""", "count" : """4""" },
    { "borrower" : """14292""", "count" : """4""" },
    { "borrower" : """14309""", "count" : """4""" },
    { "borrower" : """14323""", "count" : """4""" },
    { "borrower" : """14376""", "count" : """4""" },
    { "borrower" : """14424""", "count" : """4""" },
    { "borrower" : """14476""", "count" : """4""" },
    { "borrower" : """14533""", "count" : """4""" },
    { "borrower" : """14645""", "count" : """4""" },
    { "borrower" : """14708""", "count" : """4""" },
    { "borrower" : """14738""", "count" : """4""" },
    { "borrower" : """14812""", "count" : """4""" },
    { "borrower" : """14888""", "count" : """4""" },
    { "borrower" : """15017""", "count" : """4""" },
    { "borrower" : """15255""", "count" : """4""" },
    { "borrower" : """15792""", "count" : """4""" },
    { "borrower" : """15843""", "count" : """4""" },
    { "borrower" : """16005""", "count" : """4""" },
    { "borrower" : """16010""", "count" : """4""" },
    { "borrower" : """16049""", "count" : """4""" },
    { "borrower" : """16121""", "count" : """4""" },
    { "borrower" : """16389""", "count" : """4""" },
    { "borrower" : """17066""", "count" : """4""" },
    { "borrower" : """17076""", "count" : """4""" },
    { "borrower" : """17079""", "count" : """4""" },
    { "borrower" : """17421""", "count" : """4""" },
    { "borrower" : """17491""", "count" : """4""" },
    { "borrower" : """17691""", "count" : """4""" },
    { "borrower" : """17897""", "count" : """4""" },
    { "borrower" : """17971""", "count" : """4""" },
    { "borrower" : """17977""", "count" : """4""" },
    { "borrower" : """17987""", "count" : """4""" },
    { "borrower" : """18078""", "count" : """4""" },
    { "borrower" : """18108""", "count" : """4""" },
    { "borrower" : """18167""", "count" : """4""" },
    { "borrower" : """18220""", "count" : """4""" },
    { "borrower" : """18233""", "count" : """4""" },
    { "borrower" : """18234""", "count" : """4""" },
    { "borrower" : """18345""", "count" : """4""" },
    { "borrower" : """18379""", "count" : """4""" },
    { "borrower" : """18495""", "count" : """4""" },
    { "borrower" : """18572""", "count" : """4""" },
    { "borrower" : """18590""", "count" : """4""" },
    { "borrower" : """18639""", "count" : """4""" },
    { "borrower" : """18695""", "count" : """4""" },
    { "borrower" : """18772""", "count" : """4""" },
    { "borrower" : """18801""", "count" : """4""" },
    { "borrower" : """18835""", "count" : """4""" },
    { "borrower" : """18929""", "count" : """4""" },
    { "borrower" : """19015""", "count" : """4""" },
    { "borrower" : """19041""", "count" : """4""" },
    { "borrower" : """19067""", "count" : """4""" },
    { "borrower" : """19179""", "count" : """4""" },
    { "borrower" : """19255""", "count" : """4""" },
    { "borrower" : """19297""", "count" : """4""" },
    { "borrower" : """19430""", "count" : """4""" },
    { "borrower" : """19670""", "count" : """4""" },
    { "borrower" : """20006""", "count" : """4""" },
    { "borrower" : """20008""", "count" : """4""" },
    { "borrower" : """20119""", "count" : """4""" },
    { "borrower" : """20173""", "count" : """4""" },
    { "borrower" : """20182""", "count" : """4""" },
    { "borrower" : """20228""", "count" : """4""" },
    { "borrower" : """20238""", "count" : """4""" },
    { "borrower" : """20253""", "count" : """4""" },
    { "borrower" : """20347""", "count" : """4""" },
    { "borrower" : """20967""", "count" : """4""" },
    { "borrower" : """20983""", "count" : """4""" },
    { "borrower" : """21045""", "count" : """4""" },
    { "borrower" : """21123""", "count" : """4""" },
    { "borrower" : """21273""", "count" : """4""" },
    { "borrower" : """21455""", "count" : """4""" },
    { "borrower" : """21535""", "count" : """4""" },
    { "borrower" : """21831""", "count" : """4""" },
    { "borrower" : """21881""", "count" : """4""" },
    { "borrower" : """22061""", "count" : """4""" },
    { "borrower" : """22143""", "count" : """4""" },
    { "borrower" : """22474""", "count" : """4""" },
    { "borrower" : """22487""", "count" : """4""" },
    { "borrower" : """22621""", "count" : """4""" },
    { "borrower" : """22700""", "count" : """4""" },
    { "borrower" : """22956""", "count" : """4""" },
    { "borrower" : """23431""", "count" : """4""" },
    { "borrower" : """24777""", "count" : """4""" },
    { "borrower" : """25144""", "count" : """4""" },
    { "borrower" : """25400""", "count" : """4""" },
    { "borrower" : """25720""", "count" : """4""" },
    { "borrower" : """26052""", "count" : """4""" },
    { "borrower" : """134""", "count" : """3""" },
    { "borrower" : """156""", "count" : """3""" },
    { "borrower" : """198""", "count" : """3""" },
    { "borrower" : """208""", "count" : """3""" },
    { "borrower" : """232""", "count" : """3""" },
    { "borrower" : """233""", "count" : """3""" },
    { "borrower" : """235""", "count" : """3""" },
    { "borrower" : """247""", "count" : """3""" },
    { "borrower" : """253""", "count" : """3""" },
    { "borrower" : """258""", "count" : """3""" },
    { "borrower" : """262""", "count" : """3""" },
    { "borrower" : """274""", "count" : """3""" },
    { "borrower" : """307""", "count" : """3""" },
    { "borrower" : """310""", "count" : """3""" },
    { "borrower" : """359""", "count" : """3""" },
    { "borrower" : """372""", "count" : """3""" },
    { "borrower" : """387""", "count" : """3""" },
    { "borrower" : """487""", "count" : """3""" },
    { "borrower" : """503""", "count" : """3""" },
    { "borrower" : """512""", "count" : """3""" },
    { "borrower" : """522""", "count" : """3""" },
    { "borrower" : """660""", "count" : """3""" },
    { "borrower" : """841""", "count" : """3""" },
    { "borrower" : """860""", "count" : """3""" },
    { "borrower" : """905""", "count" : """3""" },
    { "borrower" : """1016""", "count" : """3""" },
    { "borrower" : """1154""", "count" : """3""" },
    { "borrower" : """1260""", "count" : """3""" },
    { "borrower" : """1302""", "count" : """3""" },
    { "borrower" : """1486""", "count" : """3""" },
    { "borrower" : """1546""", "count" : """3""" },
    { "borrower" : """1673""", "count" : """3""" },
    { "borrower" : """1690""", "count" : """3""" },
    { "borrower" : """1706""", "count" : """3""" },
    { "borrower" : """1898""", "count" : """3""" },
    { "borrower" : """1914""", "count" : """3""" },
    { "borrower" : """1934""", "count" : """3""" },
    { "borrower" : """2068""", "count" : """3""" },
    { "borrower" : """2147""", "count" : """3""" },
    { "borrower" : """2307""", "count" : """3""" },
    { "borrower" : """2363""", "count" : """3""" },
    { "borrower" : """2377""", "count" : """3""" },
    { "borrower" : """2584""", "count" : """3""" },
    { "borrower" : """2673""", "count" : """3""" },
    { "borrower" : """2723""", "count" : """3""" },
    { "borrower" : """2896""", "count" : """3""" },
    { "borrower" : """2903""", "count" : """3""" },
    { "borrower" : """2926""", "count" : """3""" },
    { "borrower" : """2984""", "count" : """3""" },
    { "borrower" : """2996""", "count" : """3""" },
    { "borrower" : """3023""", "count" : """3""" },
    { "borrower" : """3056""", "count" : """3""" },
    { "borrower" : """3348""", "count" : """3""" },
    { "borrower" : """3494""", "count" : """3""" },
    { "borrower" : """3673""", "count" : """3""" },
    { "borrower" : """3782""", "count" : """3""" },
    { "borrower" : """3946""", "count" : """3""" },
    { "borrower" : """4106""", "count" : """3""" },
    { "borrower" : """4120""", "count" : """3""" },
    { "borrower" : """4141""", "count" : """3""" },
    { "borrower" : """4234""", "count" : """3""" },
    { "borrower" : """4272""", "count" : """3""" },
    { "borrower" : """4287""", "count" : """3""" },
    { "borrower" : """4418""", "count" : """3""" },
    { "borrower" : """4454""", "count" : """3""" },
    { "borrower" : """4693""", "count" : """3""" },
    { "borrower" : """4701""", "count" : """3""" },
    { "borrower" : """4737""", "count" : """3""" },
    { "borrower" : """4867""", "count" : """3""" },
    { "borrower" : """5351""", "count" : """3""" },
    { "borrower" : """5405""", "count" : """3""" },
    { "borrower" : """5415""", "count" : """3""" },
    { "borrower" : """5431""", "count" : """3""" },
    { "borrower" : """5435""", "count" : """3""" },
    { "borrower" : """5485""", "count" : """3""" },
    { "borrower" : """5582""", "count" : """3""" },
    { "borrower" : """5618""", "count" : """3""" },
    { "borrower" : """5662""", "count" : """3""" },
    { "borrower" : """5718""", "count" : """3""" },
    { "borrower" : """5938""", "count" : """3""" },
    { "borrower" : """6085""", "count" : """3""" },
    { "borrower" : """6201""", "count" : """3""" },
    { "borrower" : """6261""", "count" : """3""" },
    { "borrower" : """6593""", "count" : """3""" },
    { "borrower" : """6909""", "count" : """3""" },
    { "borrower" : """7090""", "count" : """3""" },
    { "borrower" : """7092""", "count" : """3""" },
    { "borrower" : """7257""", "count" : """3""" },
    { "borrower" : """7505""", "count" : """3""" },
    { "borrower" : """7514""", "count" : """3""" },
    { "borrower" : """7530""", "count" : """3""" },
    { "borrower" : """7874""", "count" : """3""" },
    { "borrower" : """8081""", "count" : """3""" },
    { "borrower" : """8272""", "count" : """3""" },
    { "borrower" : """8288""", "count" : """3""" },
    { "borrower" : """8366""", "count" : """3""" },
    { "borrower" : """8569""", "count" : """3""" },
    { "borrower" : """8759""", "count" : """3""" },
    { "borrower" : """8764""", "count" : """3""" },
    { "borrower" : """8943""", "count" : """3""" },
    { "borrower" : """9074""", "count" : """3""" },
    { "borrower" : """9084""", "count" : """3""" },
    { "borrower" : """9121""", "count" : """3""" },
    { "borrower" : """9404""", "count" : """3""" },
    { "borrower" : """9479""", "count" : """3""" },
    { "borrower" : """9483""", "count" : """3""" },
    { "borrower" : """9648""", "count" : """3""" },
    { "borrower" : """9921""", "count" : """3""" },
    { "borrower" : """10248""", "count" : """3""" },
    { "borrower" : """10249""", "count" : """3""" },
    { "borrower" : """10276""", "count" : """3""" },
    { "borrower" : """10596""", "count" : """3""" },
    { "borrower" : """10710""", "count" : """3""" },
    { "borrower" : """10711""", "count" : """3""" },
    { "borrower" : """10734""", "count" : """3""" },
    { "borrower" : """10775""", "count" : """3""" },
    { "borrower" : """10958""", "count" : """3""" },
    { "borrower" : """11006""", "count" : """3""" },
    { "borrower" : """11107""", "count" : """3""" },
    { "borrower" : """11157""", "count" : """3""" },
    { "borrower" : """11246""", "count" : """3""" },
    { "borrower" : """11569""", "count" : """3""" },
    { "borrower" : """11591""", "count" : """3""" },
    { "borrower" : """11642""", "count" : """3""" },
    { "borrower" : """11725""", "count" : """3""" },
    { "borrower" : """11834""", "count" : """3""" },
    { "borrower" : """12025""", "count" : """3""" },
    { "borrower" : """12159""", "count" : """3""" },
    { "borrower" : """12165""", "count" : """3""" },
    { "borrower" : """12209""", "count" : """3""" },
    { "borrower" : """12243""", "count" : """3""" },
    { "borrower" : """12290""", "count" : """3""" },
    { "borrower" : """12292""", "count" : """3""" },
    { "borrower" : """12545""", "count" : """3""" },
    { "borrower" : """12707""", "count" : """3""" },
    { "borrower" : """12790""", "count" : """3""" },
    { "borrower" : """12869""", "count" : """3""" },
    { "borrower" : """12903""", "count" : """3""" },
    { "borrower" : """13055""", "count" : """3""" },
    { "borrower" : """13129""", "count" : """3""" },
    { "borrower" : """13178""", "count" : """3""" },
    { "borrower" : """13201""", "count" : """3""" },
    { "borrower" : """13238""", "count" : """3""" },
    { "borrower" : """13282""", "count" : """3""" },
    { "borrower" : """13304""", "count" : """3""" },
    { "borrower" : """13349""", "count" : """3""" },
    { "borrower" : """13491""", "count" : """3""" },
    { "borrower" : """13502""", "count" : """3""" },
    { "borrower" : """13624""", "count" : """3""" },
    { "borrower" : """13737""", "count" : """3""" },
    { "borrower" : """14003""", "count" : """3""" },
    { "borrower" : """14023""", "count" : """3""" },
    { "borrower" : """14181""", "count" : """3""" },
    { "borrower" : """14302""", "count" : """3""" },
    { "borrower" : """14478""", "count" : """3""" },
    { "borrower" : """14505""", "count" : """3""" },
    { "borrower" : """14627""", "count" : """3""" },
    { "borrower" : """14796""", "count" : """3""" },
    { "borrower" : """14843""", "count" : """3""" },
    { "borrower" : """14863""", "count" : """3""" },
    { "borrower" : """14877""", "count" : """3""" },
    { "borrower" : """14920""", "count" : """3""" },
    { "borrower" : """14972""", "count" : """3""" },
    { "borrower" : """14985""", "count" : """3""" },
    { "borrower" : """14996""", "count" : """3""" },
    { "borrower" : """15007""", "count" : """3""" },
    { "borrower" : """15064""", "count" : """3""" },
    { "borrower" : """15065""", "count" : """3""" },
    { "borrower" : """15184""", "count" : """3""" },
    { "borrower" : """15258""", "count" : """3""" },
    { "borrower" : """15296""", "count" : """3""" },
    { "borrower" : """15308""", "count" : """3""" },
    { "borrower" : """15312""", "count" : """3""" },
    { "borrower" : """15353""", "count" : """3""" },
    { "borrower" : """15554""", "count" : """3""" },
    { "borrower" : """15570""", "count" : """3""" },
    { "borrower" : """15635""", "count" : """3""" },
    { "borrower" : """15673""", "count" : """3""" },
    { "borrower" : """15680""", "count" : """3""" },
    { "borrower" : """15742""", "count" : """3""" },
    { "borrower" : """15769""", "count" : """3""" },
    { "borrower" : """15856""", "count" : """3""" },
    { "borrower" : """15973""", "count" : """3""" },
    { "borrower" : """15995""", "count" : """3""" },
    { "borrower" : """16142""", "count" : """3""" },
    { "borrower" : """16385""", "count" : """3""" },
    { "borrower" : """16518""", "count" : """3""" },
    { "borrower" : """16896""", "count" : """3""" },
    { "borrower" : """16973""", "count" : """3""" },
    { "borrower" : """17115""", "count" : """3""" },
    { "borrower" : """17450""", "count" : """3""" },
    { "borrower" : """17483""", "count" : """3""" },
    { "borrower" : """17773""", "count" : """3""" },
    { "borrower" : """17816""", "count" : """3""" },
    { "borrower" : """17852""", "count" : """3""" },
    { "borrower" : """17942""", "count" : """3""" },
    { "borrower" : """17946""", "count" : """3""" },
    { "borrower" : """17985""", "count" : """3""" },
    { "borrower" : """17994""", "count" : """3""" },
    { "borrower" : """18041""", "count" : """3""" },
    { "borrower" : """18046""", "count" : """3""" },
    { "borrower" : """18090""", "count" : """3""" },
    { "borrower" : """18153""", "count" : """3""" },
    { "borrower" : """18166""", "count" : """3""" },
    { "borrower" : """18169""", "count" : """3""" },
    { "borrower" : """18177""", "count" : """3""" },
    { "borrower" : """18200""", "count" : """3""" },
    { "borrower" : """18230""", "count" : """3""" },
    { "borrower" : """18262""", "count" : """3""" },
    { "borrower" : """18298""", "count" : """3""" },
    { "borrower" : """18306""", "count" : """3""" },
    { "borrower" : """18310""", "count" : """3""" },
    { "borrower" : """18339""", "count" : """3""" },
    { "borrower" : """18348""", "count" : """3""" },
    { "borrower" : """18371""", "count" : """3""" },
    { "borrower" : """18388""", "count" : """3""" },
    { "borrower" : """18410""", "count" : """3""" },
    { "borrower" : """18458""", "count" : """3""" },
    { "borrower" : """18462""", "count" : """3""" },
    { "borrower" : """18486""", "count" : """3""" },
    { "borrower" : """18526""", "count" : """3""" },
    { "borrower" : """18557""", "count" : """3""" },
    { "borrower" : """18558""", "count" : """3""" },
    { "borrower" : """18559""", "count" : """3""" },
    { "borrower" : """18561""", "count" : """3""" },
    { "borrower" : """18564""", "count" : """3""" },
    { "borrower" : """18623""", "count" : """3""" },
    { "borrower" : """18642""", "count" : """3""" },
    { "borrower" : """18740""", "count" : """3""" },
    { "borrower" : """18787""", "count" : """3""" },
    { "borrower" : """18894""", "count" : """3""" },
    { "borrower" : """18900""", "count" : """3""" },
    { "borrower" : """18915""", "count" : """3""" },
    { "borrower" : """18936""", "count" : """3""" },
    { "borrower" : """18944""", "count" : """3""" },
    { "borrower" : """19016""", "count" : """3""" },
    { "borrower" : """19054""", "count" : """3""" },
    { "borrower" : """19123""", "count" : """3""" },
    { "borrower" : """19174""", "count" : """3""" },
    { "borrower" : """19196""", "count" : """3""" },
    { "borrower" : """19247""", "count" : """3""" },
    { "borrower" : """19269""", "count" : """3""" },
    { "borrower" : """19634""", "count" : """3""" },
    { "borrower" : """19650""", "count" : """3""" },
    { "borrower" : """19741""", "count" : """3""" },
    { "borrower" : """19940""", "count" : """3""" },
    { "borrower" : """20042""", "count" : """3""" },
    { "borrower" : """20214""", "count" : """3""" },
    { "borrower" : """20260""", "count" : """3""" },
    { "borrower" : """20487""", "count" : """3""" },
    { "borrower" : """20539""", "count" : """3""" },
    { "borrower" : """20544""", "count" : """3""" },
    { "borrower" : """20751""", "count" : """3""" },
    { "borrower" : """20911""", "count" : """3""" },
    { "borrower" : """20930""", "count" : """3""" },
    { "borrower" : """20968""", "count" : """3""" },
    { "borrower" : """20996""", "count" : """3""" },
    { "borrower" : """21136""", "count" : """3""" },
    { "borrower" : """21614""", "count" : """3""" },
    { "borrower" : """21662""", "count" : """3""" },
    { "borrower" : """21876""", "count" : """3""" },
    { "borrower" : """21969""", "count" : """3""" },
    { "borrower" : """22004""", "count" : """3""" },
    { "borrower" : """22068""", "count" : """3""" },
    { "borrower" : """22362""", "count" : """3""" },
    { "borrower" : """22598""", "count" : """3""" },
    { "borrower" : """22678""", "count" : """3""" },
    { "borrower" : """22739""", "count" : """3""" },
    { "borrower" : """22814""", "count" : """3""" },
    { "borrower" : """22938""", "count" : """3""" },
    { "borrower" : """22974""", "count" : """3""" },
    { "borrower" : """23207""", "count" : """3""" },
    { "borrower" : """23285""", "count" : """3""" },
    { "borrower" : """23400""", "count" : """3""" },
    { "borrower" : """23722""", "count" : """3""" },
    { "borrower" : """23762""", "count" : """3""" },
    { "borrower" : """23778""", "count" : """3""" },
    { "borrower" : """23829""", "count" : """3""" },
    { "borrower" : """23901""", "count" : """3""" },
    { "borrower" : """24002""", "count" : """3""" },
    { "borrower" : """24185""", "count" : """3""" },
    { "borrower" : """24642""", "count" : """3""" },
    { "borrower" : """24997""", "count" : """3""" },
    { "borrower" : """28""", "count" : """2""" },
    { "borrower" : """29""", "count" : """2""" },
    { "borrower" : """30""", "count" : """2""" },
    { "borrower" : """39""", "count" : """2""" },
    { "borrower" : """74""", "count" : """2""" },
    { "borrower" : """78""", "count" : """2""" },
    { "borrower" : """89""", "count" : """2""" },
    { "borrower" : """92""", "count" : """2""" },
    { "borrower" : """106""", "count" : """2""" },
    { "borrower" : """127""", "count" : """2""" },
    { "borrower" : """135""", "count" : """2""" },
    { "borrower" : """138""", "count" : """2""" },
    { "borrower" : """166""", "count" : """2""" },
    { "borrower" : """176""", "count" : """2""" },
    { "borrower" : """178""", "count" : """2""" },
    { "borrower" : """183""", "count" : """2""" },
    { "borrower" : """209""", "count" : """2""" },
    { "borrower" : """218""", "count" : """2""" },
    { "borrower" : """229""", "count" : """2""" },
    { "borrower" : """234""", "count" : """2""" },
    { "borrower" : """236""", "count" : """2""" },
    { "borrower" : """244""", "count" : """2""" },
    { "borrower" : """263""", "count" : """2""" },
    { "borrower" : """284""", "count" : """2""" },
    { "borrower" : """294""", "count" : """2""" },
    { "borrower" : """296""", "count" : """2""" },
    { "borrower" : """306""", "count" : """2""" },
    { "borrower" : """308""", "count" : """2""" },
    { "borrower" : """321""", "count" : """2""" },
    { "borrower" : """322""", "count" : """2""" },
    { "borrower" : """331""", "count" : """2""" },
    { "borrower" : """335""", "count" : """2""" },
    { "borrower" : """336""", "count" : """2""" },
    { "borrower" : """369""", "count" : """2""" },
    { "borrower" : """371""", "count" : """2""" },
    { "borrower" : """392""", "count" : """2""" },
    { "borrower" : """400""", "count" : """2""" },
    { "borrower" : """412""", "count" : """2""" },
    { "borrower" : """428""", "count" : """2""" },
    { "borrower" : """432""", "count" : """2""" },
    { "borrower" : """450""", "count" : """2""" },
    { "borrower" : """452""", "count" : """2""" },
    { "borrower" : """455""", "count" : """2""" },
    { "borrower" : """498""", "count" : """2""" },
    { "borrower" : """514""", "count" : """2""" },
    { "borrower" : """525""", "count" : """2""" },
    { "borrower" : """554""", "count" : """2""" },
    { "borrower" : """558""", "count" : """2""" },
    { "borrower" : """560""", "count" : """2""" },
    { "borrower" : """567""", "count" : """2""" },
    { "borrower" : """812""", "count" : """2""" },
    { "borrower" : """828""", "count" : """2""" },
    { "borrower" : """952""", "count" : """2""" },
    { "borrower" : """965""", "count" : """2""" },
    { "borrower" : """998""", "count" : """2""" },
    { "borrower" : """1039""", "count" : """2""" },
    { "borrower" : """1060""", "count" : """2""" },
    { "borrower" : """1099""", "count" : """2""" },
    { "borrower" : """1122""", "count" : """2""" },
    { "borrower" : """1145""", "count" : """2""" },
    { "borrower" : """1203""", "count" : """2""" },
    { "borrower" : """1242""", "count" : """2""" },
    { "borrower" : """1317""", "count" : """2""" },
    { "borrower" : """1344""", "count" : """2""" },
    { "borrower" : """1348""", "count" : """2""" },
    { "borrower" : """1433""", "count" : """2""" },
    { "borrower" : """1452""", "count" : """2""" },
    { "borrower" : """1503""", "count" : """2""" },
    { "borrower" : """1573""", "count" : """2""" },
    { "borrower" : """1651""", "count" : """2""" },
    { "borrower" : """1664""", "count" : """2""" },
    { "borrower" : """1675""", "count" : """2""" },
    { "borrower" : """1737""", "count" : """2""" },
    { "borrower" : """1779""", "count" : """2""" },
    { "borrower" : """1816""", "count" : """2""" },
    { "borrower" : """1941""", "count" : """2""" },
    { "borrower" : """1958""", "count" : """2""" },
    { "borrower" : """2037""", "count" : """2""" },
    { "borrower" : """2043""", "count" : """2""" },
    { "borrower" : """2057""", "count" : """2""" },
    { "borrower" : """2070""", "count" : """2""" },
    { "borrower" : """2234""", "count" : """2""" },
    { "borrower" : """2244""", "count" : """2""" },
    { "borrower" : """2288""", "count" : """2""" },
    { "borrower" : """2313""", "count" : """2""" },
    { "borrower" : """2385""", "count" : """2""" },
    { "borrower" : """2445""", "count" : """2""" },
    { "borrower" : """2457""", "count" : """2""" },
    { "borrower" : """2476""", "count" : """2""" },
    { "borrower" : """2549""", "count" : """2""" },
    { "borrower" : """2562""", "count" : """2""" },
    { "borrower" : """2615""", "count" : """2""" },
    { "borrower" : """2704""", "count" : """2""" },
    { "borrower" : """2860""", "count" : """2""" },
    { "borrower" : """2961""", "count" : """2""" },
    { "borrower" : """2999""", "count" : """2""" },
    { "borrower" : """3007""", "count" : """2""" },
    { "borrower" : """3082""", "count" : """2""" },
    { "borrower" : """3109""", "count" : """2""" },
    { "borrower" : """3352""", "count" : """2""" },
    { "borrower" : """3413""", "count" : """2""" },
    { "borrower" : """3541""", "count" : """2""" },
    { "borrower" : """3560""", "count" : """2""" },
    { "borrower" : """3657""", "count" : """2""" },
    { "borrower" : """3825""", "count" : """2""" },
    { "borrower" : """3834""", "count" : """2""" },
    { "borrower" : """3873""", "count" : """2""" },
    { "borrower" : """3910""", "count" : """2""" },
    { "borrower" : """4016""", "count" : """2""" },
    { "borrower" : """4125""", "count" : """2""" },
    { "borrower" : """4292""", "count" : """2""" },
    { "borrower" : """4394""", "count" : """2""" },
    { "borrower" : """4419""", "count" : """2""" },
    { "borrower" : """4546""", "count" : """2""" },
    { "borrower" : """4627""", "count" : """2""" },
    { "borrower" : """4656""", "count" : """2""" },
    { "borrower" : """4692""", "count" : """2""" },
    { "borrower" : """4700""", "count" : """2""" },
    { "borrower" : """4720""", "count" : """2""" },
    { "borrower" : """4760""", "count" : """2""" },
    { "borrower" : """4818""", "count" : """2""" },
    { "borrower" : """4819""", "count" : """2""" },
    { "borrower" : """4833""", "count" : """2""" },
    { "borrower" : """4961""", "count" : """2""" },
    { "borrower" : """5046""", "count" : """2""" },
    { "borrower" : """5065""", "count" : """2""" },
    { "borrower" : """5076""", "count" : """2""" },
    { "borrower" : """5114""", "count" : """2""" },
    { "borrower" : """5178""", "count" : """2""" },
    { "borrower" : """5204""", "count" : """2""" },
    { "borrower" : """5511""", "count" : """2""" },
    { "borrower" : """5537""", "count" : """2""" },
    { "borrower" : """5631""", "count" : """2""" },
    { "borrower" : """5680""", "count" : """2""" },
    { "borrower" : """5688""", "count" : """2""" },
    { "borrower" : """5726""", "count" : """2""" },
    { "borrower" : """5803""", "count" : """2""" },
    { "borrower" : """5819""", "count" : """2""" },
    { "borrower" : """5839""", "count" : """2""" },
    { "borrower" : """5852""", "count" : """2""" },
    { "borrower" : """5868""", "count" : """2""" },
    { "borrower" : """5878""", "count" : """2""" },
    { "borrower" : """5943""", "count" : """2""" },
    { "borrower" : """5994""", "count" : """2""" },
    { "borrower" : """5995""", "count" : """2""" },
    { "borrower" : """6161""", "count" : """2""" },
    { "borrower" : """6174""", "count" : """2""" },
    { "borrower" : """6204""", "count" : """2""" },
    { "borrower" : """6266""", "count" : """2""" },
    { "borrower" : """6269""", "count" : """2""" },
    { "borrower" : """6286""", "count" : """2""" },
    { "borrower" : """6306""", "count" : """2""" },
    { "borrower" : """6358""", "count" : """2""" },
    { "borrower" : """6438""", "count" : """2""" },
    { "borrower" : """6446""", "count" : """2""" },
    { "borrower" : """6482""", "count" : """2""" },
    { "borrower" : """6556""", "count" : """2""" },
    { "borrower" : """6744""", "count" : """2""" },
    { "borrower" : """6855""", "count" : """2""" },
    { "borrower" : """6901""", "count" : """2""" },
    { "borrower" : """6954""", "count" : """2""" },
    { "borrower" : """6987""", "count" : """2""" },
    { "borrower" : """7147""", "count" : """2""" },
    { "borrower" : """7199""", "count" : """2""" },
    { "borrower" : """7253""", "count" : """2""" },
    { "borrower" : """7417""", "count" : """2""" },
    { "borrower" : """7424""", "count" : """2""" },
    { "borrower" : """7478""", "count" : """2""" },
    { "borrower" : """7545""", "count" : """2""" },
    { "borrower" : """7739""", "count" : """2""" },
    { "borrower" : """7843""", "count" : """2""" },
    { "borrower" : """7957""", "count" : """2""" },
    { "borrower" : """8036""", "count" : """2""" },
    { "borrower" : """8086""", "count" : """2""" },
    { "borrower" : """8160""", "count" : """2""" },
    { "borrower" : """8227""", "count" : """2""" },
    { "borrower" : """8232""", "count" : """2""" },
    { "borrower" : """8384""", "count" : """2""" },
    { "borrower" : """8523""", "count" : """2""" },
    { "borrower" : """8541""", "count" : """2""" },
    { "borrower" : """8557""", "count" : """2""" },
    { "borrower" : """8577""", "count" : """2""" },
    { "borrower" : """8581""", "count" : """2""" },
    { "borrower" : """8583""", "count" : """2""" },
    { "borrower" : """8591""", "count" : """2""" },
    { "borrower" : """8643""", "count" : """2""" },
    { "borrower" : """8723""", "count" : """2""" },
    { "borrower" : """8826""", "count" : """2""" },
    { "borrower" : """8837""", "count" : """2""" },
    { "borrower" : """9088""", "count" : """2""" },
    { "borrower" : """9120""", "count" : """2""" },
    { "borrower" : """9228""", "count" : """2""" },
    { "borrower" : """9240""", "count" : """2""" },
    { "borrower" : """9534""", "count" : """2""" },
    { "borrower" : """9619""", "count" : """2""" },
    { "borrower" : """9671""", "count" : """2""" },
    { "borrower" : """9870""", "count" : """2""" },
    { "borrower" : """9950""", "count" : """2""" },
    { "borrower" : """10064""", "count" : """2""" },
    { "borrower" : """10106""", "count" : """2""" },
    { "borrower" : """10215""", "count" : """2""" },
    { "borrower" : """10300""", "count" : """2""" },
    { "borrower" : """10400""", "count" : """2""" },
    { "borrower" : """10508""", "count" : """2""" },
    { "borrower" : """10519""", "count" : """2""" },
    { "borrower" : """10548""", "count" : """2""" },
    { "borrower" : """10695""", "count" : """2""" },
    { "borrower" : """10826""", "count" : """2""" },
    { "borrower" : """10847""", "count" : """2""" },
    { "borrower" : """10849""", "count" : """2""" },
    { "borrower" : """10921""", "count" : """2""" },
    { "borrower" : """10999""", "count" : """2""" },
    { "borrower" : """11003""", "count" : """2""" },
    { "borrower" : """11033""", "count" : """2""" },
    { "borrower" : """11078""", "count" : """2""" },
    { "borrower" : """11094""", "count" : """2""" },
    { "borrower" : """11102""", "count" : """2""" },
    { "borrower" : """11286""", "count" : """2""" },
    { "borrower" : """11516""", "count" : """2""" },
    { "borrower" : """11557""", "count" : """2""" },
    { "borrower" : """11572""", "count" : """2""" },
    { "borrower" : """11583""", "count" : """2""" },
    { "borrower" : """11625""", "count" : """2""" },
    { "borrower" : """11723""", "count" : """2""" },
    { "borrower" : """11748""", "count" : """2""" },
    { "borrower" : """11968""", "count" : """2""" },
    { "borrower" : """12011""", "count" : """2""" },
    { "borrower" : """12055""", "count" : """2""" },
    { "borrower" : """12056""", "count" : """2""" },
    { "borrower" : """12092""", "count" : """2""" },
    { "borrower" : """12169""", "count" : """2""" },
    { "borrower" : """12245""", "count" : """2""" },
    { "borrower" : """12327""", "count" : """2""" },
    { "borrower" : """12465""", "count" : """2""" },
    { "borrower" : """12471""", "count" : """2""" },
    { "borrower" : """12528""", "count" : """2""" },
    { "borrower" : """12694""", "count" : """2""" },
    { "borrower" : """12786""", "count" : """2""" },
    { "borrower" : """12861""", "count" : """2""" },
    { "borrower" : """12862""", "count" : """2""" },
    { "borrower" : """12911""", "count" : """2""" },
    { "borrower" : """12992""", "count" : """2""" },
    { "borrower" : """13220""", "count" : """2""" },
    { "borrower" : """13227""", "count" : """2""" },
    { "borrower" : """13286""", "count" : """2""" },
    { "borrower" : """13373""", "count" : """2""" },
    { "borrower" : """13415""", "count" : """2""" },
    { "borrower" : """13426""", "count" : """2""" },
    { "borrower" : """13442""", "count" : """2""" },
    { "borrower" : """13472""", "count" : """2""" },
    { "borrower" : """13553""", "count" : """2""" },
    { "borrower" : """13556""", "count" : """2""" },
    { "borrower" : """13648""", "count" : """2""" },
    { "borrower" : """13652""", "count" : """2""" },
    { "borrower" : """13698""", "count" : """2""" },
    { "borrower" : """13708""", "count" : """2""" },
    { "borrower" : """13866""", "count" : """2""" },
    { "borrower" : """13875""", "count" : """2""" },
    { "borrower" : """13916""", "count" : """2""" },
    { "borrower" : """14031""", "count" : """2""" },
    { "borrower" : """14072""", "count" : """2""" },
    { "borrower" : """14087""", "count" : """2""" },
    { "borrower" : """14094""", "count" : """2""" },
    { "borrower" : """14211""", "count" : """2""" },
    { "borrower" : """14215""", "count" : """2""" },
    { "borrower" : """14249""", "count" : """2""" },
    { "borrower" : """14288""", "count" : """2""" },
    { "borrower" : """14349""", "count" : """2""" },
    { "borrower" : """14463""", "count" : """2""" },
    { "borrower" : """14471""", "count" : """2""" },
    { "borrower" : """14568""", "count" : """2""" },
    { "borrower" : """14605""", "count" : """2""" },
    { "borrower" : """14652""", "count" : """2""" },
    { "borrower" : """14671""", "count" : """2""" },
    { "borrower" : """14705""", "count" : """2""" },
    { "borrower" : """14813""", "count" : """2""" },
    { "borrower" : """14820""", "count" : """2""" },
    { "borrower" : """14878""", "count" : """2""" },
    { "borrower" : """14919""", "count" : """2""" },
    { "borrower" : """14949""", "count" : """2""" },
    { "borrower" : """15003""", "count" : """2""" },
    { "borrower" : """15034""", "count" : """2""" },
    { "borrower" : """15036""", "count" : """2""" },
    { "borrower" : """15055""", "count" : """2""" },
    { "borrower" : """15079""", "count" : """2""" },
    { "borrower" : """15086""", "count" : """2""" },
    { "borrower" : """15122""", "count" : """2""" },
    { "borrower" : """15228""", "count" : """2""" },
    { "borrower" : """15230""", "count" : """2""" },
    { "borrower" : """15320""", "count" : """2""" },
    { "borrower" : """15343""", "count" : """2""" },
    { "borrower" : """15387""", "count" : """2""" },
    { "borrower" : """15583""", "count" : """2""" },
    { "borrower" : """15814""", "count" : """2""" },
    { "borrower" : """15953""", "count" : """2""" },
    { "borrower" : """16001""", "count" : """2""" },
    { "borrower" : """16184""", "count" : """2""" },
    { "borrower" : """16238""", "count" : """2""" },
    { "borrower" : """16257""", "count" : """2""" },
    { "borrower" : """16331""", "count" : """2""" },
    { "borrower" : """16382""", "count" : """2""" },
    { "borrower" : """16457""", "count" : """2""" },
    { "borrower" : """16720""", "count" : """2""" },
    { "borrower" : """16729""", "count" : """2""" },
    { "borrower" : """16747""", "count" : """2""" },
    { "borrower" : """16975""", "count" : """2""" },
    { "borrower" : """17191""", "count" : """2""" },
    { "borrower" : """17271""", "count" : """2""" },
    { "borrower" : """17282""", "count" : """2""" },
    { "borrower" : """17348""", "count" : """2""" },
    { "borrower" : """17415""", "count" : """2""" },
    { "borrower" : """17427""", "count" : """2""" },
    { "borrower" : """17453""", "count" : """2""" },
    { "borrower" : """17474""", "count" : """2""" },
    { "borrower" : """17484""", "count" : """2""" },
    { "borrower" : """17567""", "count" : """2""" },
    { "borrower" : """17735""", "count" : """2""" },
    { "borrower" : """17745""", "count" : """2""" },
    { "borrower" : """17769""", "count" : """2""" },
    { "borrower" : """17775""", "count" : """2""" },
    { "borrower" : """17781""", "count" : """2""" },
    { "borrower" : """17882""", "count" : """2""" },
    { "borrower" : """17902""", "count" : """2""" },
    { "borrower" : """17913""", "count" : """2""" },
    { "borrower" : """17926""", "count" : """2""" },
    { "borrower" : """17956""", "count" : """2""" },
    { "borrower" : """17968""", "count" : """2""" },
    { "borrower" : """18028""", "count" : """2""" },
    { "borrower" : """18117""", "count" : """2""" },
    { "borrower" : """18188""", "count" : """2""" },
    { "borrower" : """18189""", "count" : """2""" },
    { "borrower" : """18191""", "count" : """2""" },
    { "borrower" : """18277""", "count" : """2""" },
    { "borrower" : """18278""", "count" : """2""" },
    { "borrower" : """18304""", "count" : """2""" },
    { "borrower" : """18308""", "count" : """2""" },
    { "borrower" : """18309""", "count" : """2""" },
    { "borrower" : """18326""", "count" : """2""" },
    { "borrower" : """18327""", "count" : """2""" },
    { "borrower" : """18342""", "count" : """2""" },
    { "borrower" : """18349""", "count" : """2""" },
    { "borrower" : """18357""", "count" : """2""" },
    { "borrower" : """18380""", "count" : """2""" },
    { "borrower" : """18387""", "count" : """2""" },
    { "borrower" : """18390""", "count" : """2""" },
    { "borrower" : """18393""", "count" : """2""" },
    { "borrower" : """18467""", "count" : """2""" },
    { "borrower" : """18471""", "count" : """2""" },
    { "borrower" : """18472""", "count" : """2""" },
    { "borrower" : """18475""", "count" : """2""" },
    { "borrower" : """18490""", "count" : """2""" },
    { "borrower" : """18516""", "count" : """2""" },
    { "borrower" : """18535""", "count" : """2""" },
    { "borrower" : """18549""", "count" : """2""" },
    { "borrower" : """18606""", "count" : """2""" },
    { "borrower" : """18622""", "count" : """2""" },
    { "borrower" : """18625""", "count" : """2""" },
    { "borrower" : """18628""", "count" : """2""" },
    { "borrower" : """18643""", "count" : """2""" },
    { "borrower" : """18656""", "count" : """2""" },
    { "borrower" : """18670""", "count" : """2""" },
    { "borrower" : """18673""", "count" : """2""" },
    { "borrower" : """18704""", "count" : """2""" },
    { "borrower" : """18705""", "count" : """2""" },
    { "borrower" : """18757""", "count" : """2""" },
    { "borrower" : """18758""", "count" : """2""" },
    { "borrower" : """18773""", "count" : """2""" },
    { "borrower" : """18792""", "count" : """2""" },
    { "borrower" : """18830""", "count" : """2""" },
    { "borrower" : """18836""", "count" : """2""" },
    { "borrower" : """18842""", "count" : """2""" },
    { "borrower" : """18854""", "count" : """2""" },
    { "borrower" : """18861""", "count" : """2""" },
    { "borrower" : """18883""", "count" : """2""" },
    { "borrower" : """18908""", "count" : """2""" },
    { "borrower" : """18909""", "count" : """2""" },
    { "borrower" : """18945""", "count" : """2""" },
    { "borrower" : """18965""", "count" : """2""" },
    { "borrower" : """19009""", "count" : """2""" },
    { "borrower" : """19011""", "count" : """2""" },
    { "borrower" : """19030""", "count" : """2""" },
    { "borrower" : """19044""", "count" : """2""" },
    { "borrower" : """19047""", "count" : """2""" },
    { "borrower" : """19060""", "count" : """2""" },
    { "borrower" : """19094""", "count" : """2""" },
    { "borrower" : """19101""", "count" : """2""" },
    { "borrower" : """19125""", "count" : """2""" },
    { "borrower" : """19126""", "count" : """2""" },
    { "borrower" : """19138""", "count" : """2""" },
    { "borrower" : """19139""", "count" : """2""" },
    { "borrower" : """19142""", "count" : """2""" },
    { "borrower" : """19167""", "count" : """2""" },
    { "borrower" : """19197""", "count" : """2""" },
    { "borrower" : """19210""", "count" : """2""" },
    { "borrower" : """19213""", "count" : """2""" },
    { "borrower" : """19227""", "count" : """2""" },
    { "borrower" : """19231""", "count" : """2""" },
    { "borrower" : """19260""", "count" : """2""" },
    { "borrower" : """19314""", "count" : """2""" },
    { "borrower" : """19320""", "count" : """2""" },
    { "borrower" : """19323""", "count" : """2""" },
    { "borrower" : """19325""", "count" : """2""" },
    { "borrower" : """19346""", "count" : """2""" },
    { "borrower" : """19353""", "count" : """2""" },
    { "borrower" : """19356""", "count" : """2""" },
    { "borrower" : """19429""", "count" : """2""" },
    { "borrower" : """19432""", "count" : """2""" },
    { "borrower" : """19434""", "count" : """2""" },
    { "borrower" : """19446""", "count" : """2""" },
    { "borrower" : """19447""", "count" : """2""" },
    { "borrower" : """19470""", "count" : """2""" },
    { "borrower" : """19513""", "count" : """2""" },
    { "borrower" : """19514""", "count" : """2""" },
    { "borrower" : """19545""", "count" : """2""" },
    { "borrower" : """19547""", "count" : """2""" },
    { "borrower" : """19554""", "count" : """2""" },
    { "borrower" : """19609""", "count" : """2""" },
    { "borrower" : """19612""", "count" : """2""" },
    { "borrower" : """19695""", "count" : """2""" },
    { "borrower" : """19708""", "count" : """2""" },
    { "borrower" : """19721""", "count" : """2""" },
    { "borrower" : """19722""", "count" : """2""" },
    { "borrower" : """19742""", "count" : """2""" },
    { "borrower" : """19763""", "count" : """2""" },
    { "borrower" : """19781""", "count" : """2""" },
    { "borrower" : """19873""", "count" : """2""" },
    { "borrower" : """19944""", "count" : """2""" },
    { "borrower" : """19952""", "count" : """2""" },
    { "borrower" : """19973""", "count" : """2""" },
    { "borrower" : """20025""", "count" : """2""" },
    { "borrower" : """20044""", "count" : """2""" },
    { "borrower" : """20046""", "count" : """2""" },
    { "borrower" : """20047""", "count" : """2""" },
    { "borrower" : """20068""", "count" : """2""" },
    { "borrower" : """20101""", "count" : """2""" },
    { "borrower" : """20105""", "count" : """2""" },
    { "borrower" : """20132""", "count" : """2""" },
    { "borrower" : """20167""", "count" : """2""" },
    { "borrower" : """20227""", "count" : """2""" },
    { "borrower" : """20231""", "count" : """2""" },
    { "borrower" : """20261""", "count" : """2""" },
    { "borrower" : """20267""", "count" : """2""" },
    { "borrower" : """20300""", "count" : """2""" },
    { "borrower" : """20335""", "count" : """2""" },
    { "borrower" : """20401""", "count" : """2""" },
    { "borrower" : """20459""", "count" : """2""" },
    { "borrower" : """20556""", "count" : """2""" },
    { "borrower" : """20563""", "count" : """2""" },
    { "borrower" : """20636""", "count" : """2""" },
    { "borrower" : """20718""", "count" : """2""" },
    { "borrower" : """20729""", "count" : """2""" },
    { "borrower" : """20832""", "count" : """2""" },
    { "borrower" : """20839""", "count" : """2""" },
    { "borrower" : """20892""", "count" : """2""" },
    { "borrower" : """20959""", "count" : """2""" },
    { "borrower" : """21127""", "count" : """2""" },
    { "borrower" : """21132""", "count" : """2""" },
    { "borrower" : """21309""", "count" : """2""" },
    { "borrower" : """21377""", "count" : """2""" },
    { "borrower" : """21407""", "count" : """2""" },
    { "borrower" : """21421""", "count" : """2""" },
    { "borrower" : """21499""", "count" : """2""" },
    { "borrower" : """21563""", "count" : """2""" },
    { "borrower" : """21569""", "count" : """2""" },
    { "borrower" : """21659""", "count" : """2""" },
    { "borrower" : """21725""", "count" : """2""" },
    { "borrower" : """21743""", "count" : """2""" },
    { "borrower" : """21785""", "count" : """2""" },
    { "borrower" : """21922""", "count" : """2""" },
    { "borrower" : """21999""", "count" : """2""" },
    { "borrower" : """22210""", "count" : """2""" },
    { "borrower" : """22257""", "count" : """2""" },
    { "borrower" : """22295""", "count" : """2""" },
    { "borrower" : """22462""", "count" : """2""" },
    { "borrower" : """22496""", "count" : """2""" },
    { "borrower" : """22529""", "count" : """2""" },
    { "borrower" : """22548""", "count" : """2""" },
    { "borrower" : """22623""", "count" : """2""" },
    { "borrower" : """22801""", "count" : """2""" },
    { "borrower" : """22816""", "count" : """2""" },
    { "borrower" : """22853""", "count" : """2""" },
    { "borrower" : """23124""", "count" : """2""" },
    { "borrower" : """23151""", "count" : """2""" },
    { "borrower" : """23254""", "count" : """2""" },
    { "borrower" : """23274""", "count" : """2""" },
    { "borrower" : """23349""", "count" : """2""" },
    { "borrower" : """23372""", "count" : """2""" },
    { "borrower" : """23394""", "count" : """2""" },
    { "borrower" : """23522""", "count" : """2""" },
    { "borrower" : """23564""", "count" : """2""" },
    { "borrower" : """23566""", "count" : """2""" },
    { "borrower" : """23589""", "count" : """2""" },
    { "borrower" : """23728""", "count" : """2""" },
    { "borrower" : """23729""", "count" : """2""" },
    { "borrower" : """23768""", "count" : """2""" },
    { "borrower" : """23918""", "count" : """2""" },
    { "borrower" : """23929""", "count" : """2""" },
    { "borrower" : """24080""", "count" : """2""" },
    { "borrower" : """24115""", "count" : """2""" },
    { "borrower" : """24134""", "count" : """2""" },
    { "borrower" : """24156""", "count" : """2""" },
    { "borrower" : """24265""", "count" : """2""" },
    { "borrower" : """24519""", "count" : """2""" },
    { "borrower" : """24561""", "count" : """2""" },
    { "borrower" : """24954""", "count" : """2""" },
    { "borrower" : """25091""", "count" : """2""" },
    { "borrower" : """25098""", "count" : """2""" },
    { "borrower" : """25398""", "count" : """2""" },
    { "borrower" : """25736""", "count" : """2""" },
    { "borrower" : """8""", "count" : """1""" },
    { "borrower" : """10""", "count" : """1""" },
    { "borrower" : """12""", "count" : """1""" },
    { "borrower" : """16""", "count" : """1""" },
    { "borrower" : """27""", "count" : """1""" },
    { "borrower" : """31""", "count" : """1""" },
    { "borrower" : """32""", "count" : """1""" },
    { "borrower" : """42""", "count" : """1""" },
    { "borrower" : """44""", "count" : """1""" },
    { "borrower" : """46""", "count" : """1""" },
    { "borrower" : """52""", "count" : """1""" },
    { "borrower" : """54""", "count" : """1""" },
    { "borrower" : """57""", "count" : """1""" },
    { "borrower" : """58""", "count" : """1""" },
    { "borrower" : """60""", "count" : """1""" },
    { "borrower" : """61""", "count" : """1""" },
    { "borrower" : """66""", "count" : """1""" },
    { "borrower" : """81""", "count" : """1""" },
    { "borrower" : """87""", "count" : """1""" },
    { "borrower" : """102""", "count" : """1""" },
    { "borrower" : """104""", "count" : """1""" },
    { "borrower" : """107""", "count" : """1""" },
    { "borrower" : """110""", "count" : """1""" },
    { "borrower" : """111""", "count" : """1""" },
    { "borrower" : """121""", "count" : """1""" },
    { "borrower" : """124""", "count" : """1""" },
    { "borrower" : """129""", "count" : """1""" },
    { "borrower" : """136""", "count" : """1""" },
    { "borrower" : """137""", "count" : """1""" },
    { "borrower" : """141""", "count" : """1""" },
    { "borrower" : """144""", "count" : """1""" },
    { "borrower" : """159""", "count" : """1""" },
    { "borrower" : """165""", "count" : """1""" },
    { "borrower" : """170""", "count" : """1""" },
    { "borrower" : """171""", "count" : """1""" },
    { "borrower" : """177""", "count" : """1""" },
    { "borrower" : """181""", "count" : """1""" },
    { "borrower" : """185""", "count" : """1""" },
    { "borrower" : """187""", "count" : """1""" },
    { "borrower" : """190""", "count" : """1""" },
    { "borrower" : """192""", "count" : """1""" },
    { "borrower" : """194""", "count" : """1""" },
    { "borrower" : """197""", "count" : """1""" },
    { "borrower" : """200""", "count" : """1""" },
    { "borrower" : """201""", "count" : """1""" },
    { "borrower" : """207""", "count" : """1""" },
    { "borrower" : """221""", "count" : """1""" },
    { "borrower" : """237""", "count" : """1""" },
    { "borrower" : """241""", "count" : """1""" },
    { "borrower" : """246""", "count" : """1""" },
    { "borrower" : """249""", "count" : """1""" },
    { "borrower" : """250""", "count" : """1""" },
    { "borrower" : """257""", "count" : """1""" },
    { "borrower" : """267""", "count" : """1""" },
    { "borrower" : """268""", "count" : """1""" },
    { "borrower" : """273""", "count" : """1""" },
    { "borrower" : """276""", "count" : """1""" },
    { "borrower" : """277""", "count" : """1""" },
    { "borrower" : """278""", "count" : """1""" },
    { "borrower" : """279""", "count" : """1""" },
    { "borrower" : """281""", "count" : """1""" },
    { "borrower" : """283""", "count" : """1""" },
    { "borrower" : """289""", "count" : """1""" },
    { "borrower" : """291""", "count" : """1""" },
    { "borrower" : """299""", "count" : """1""" },
    { "borrower" : """312""", "count" : """1""" },
    { "borrower" : """315""", "count" : """1""" },
    { "borrower" : """317""", "count" : """1""" },
    { "borrower" : """318""", "count" : """1""" },
    { "borrower" : """320""", "count" : """1""" },
    { "borrower" : """326""", "count" : """1""" },
    { "borrower" : """333""", "count" : """1""" },
    { "borrower" : """334""", "count" : """1""" },
    { "borrower" : """338""", "count" : """1""" },
    { "borrower" : """340""", "count" : """1""" },
    { "borrower" : """351""", "count" : """1""" },
    { "borrower" : """354""", "count" : """1""" },
    { "borrower" : """358""", "count" : """1""" },
    { "borrower" : """360""", "count" : """1""" },
    { "borrower" : """362""", "count" : """1""" },
    { "borrower" : """365""", "count" : """1""" },
    { "borrower" : """367""", "count" : """1""" },
    { "borrower" : """375""", "count" : """1""" },
    { "borrower" : """380""", "count" : """1""" },
    { "borrower" : """386""", "count" : """1""" },
    { "borrower" : """388""", "count" : """1""" },
    { "borrower" : """391""", "count" : """1""" },
    { "borrower" : """413""", "count" : """1""" },
    { "borrower" : """415""", "count" : """1""" },
    { "borrower" : """418""", "count" : """1""" },
    { "borrower" : """420""", "count" : """1""" },
    { "borrower" : """426""", "count" : """1""" },
    { "borrower" : """429""", "count" : """1""" },
    { "borrower" : """431""", "count" : """1""" },
    { "borrower" : """435""", "count" : """1""" },
    { "borrower" : """440""", "count" : """1""" },
    { "borrower" : """441""", "count" : """1""" },
    { "borrower" : """446""", "count" : """1""" },
    { "borrower" : """449""", "count" : """1""" },
    { "borrower" : """451""", "count" : """1""" },
    { "borrower" : """460""", "count" : """1""" },
    { "borrower" : """466""", "count" : """1""" },
    { "borrower" : """470""", "count" : """1""" },
    { "borrower" : """475""", "count" : """1""" },
    { "borrower" : """480""", "count" : """1""" },
    { "borrower" : """481""", "count" : """1""" },
    { "borrower" : """485""", "count" : """1""" },
    { "borrower" : """488""", "count" : """1""" },
    { "borrower" : """492""", "count" : """1""" },
    { "borrower" : """493""", "count" : """1""" },
    { "borrower" : """509""", "count" : """1""" },
    { "borrower" : """516""", "count" : """1""" },
    { "borrower" : """517""", "count" : """1""" },
    { "borrower" : """518""", "count" : """1""" },
    { "borrower" : """520""", "count" : """1""" },
    { "borrower" : """527""", "count" : """1""" },
    { "borrower" : """531""", "count" : """1""" },
    { "borrower" : """534""", "count" : """1""" },
    { "borrower" : """537""", "count" : """1""" },
    { "borrower" : """541""", "count" : """1""" },
    { "borrower" : """543""", "count" : """1""" },
    { "borrower" : """548""", "count" : """1""" },
    { "borrower" : """550""", "count" : """1""" },
    { "borrower" : """556""", "count" : """1""" },
    { "borrower" : """561""", "count" : """1""" },
    { "borrower" : """568""", "count" : """1""" },
    { "borrower" : """569""", "count" : """1""" },
    { "borrower" : """572""", "count" : """1""" },
    { "borrower" : """573""", "count" : """1""" },
    { "borrower" : """685""", "count" : """1""" },
    { "borrower" : """696""", "count" : """1""" },
    { "borrower" : """715""", "count" : """1""" },
    { "borrower" : """760""", "count" : """1""" },
    { "borrower" : """786""", "count" : """1""" },
    { "borrower" : """802""", "count" : """1""" },
    { "borrower" : """811""", "count" : """1""" },
    { "borrower" : """865""", "count" : """1""" },
    { "borrower" : """950""", "count" : """1""" },
    { "borrower" : """1054""", "count" : """1""" },
    { "borrower" : """1055""", "count" : """1""" },
    { "borrower" : """1057""", "count" : """1""" },
    { "borrower" : """1100""", "count" : """1""" },
    { "borrower" : """1173""", "count" : """1""" },
    { "borrower" : """1187""", "count" : """1""" },
    { "borrower" : """1190""", "count" : """1""" },
    { "borrower" : """1208""", "count" : """1""" },
    { "borrower" : """1233""", "count" : """1""" },
    { "borrower" : """1326""", "count" : """1""" },
    { "borrower" : """1349""", "count" : """1""" },
    { "borrower" : """1368""", "count" : """1""" },
    { "borrower" : """1386""", "count" : """1""" },
    { "borrower" : """1432""", "count" : """1""" },
    { "borrower" : """1460""", "count" : """1""" },
    { "borrower" : """1510""", "count" : """1""" },
    { "borrower" : """1511""", "count" : """1""" },
    { "borrower" : """1539""", "count" : """1""" },
    { "borrower" : """1563""", "count" : """1""" },
    { "borrower" : """1619""", "count" : """1""" },
    { "borrower" : """1678""", "count" : """1""" },
    { "borrower" : """1793""", "count" : """1""" },
    { "borrower" : """1794""", "count" : """1""" },
    { "borrower" : """1894""", "count" : """1""" },
    { "borrower" : """1919""", "count" : """1""" },
    { "borrower" : """1927""", "count" : """1""" },
    { "borrower" : """1938""", "count" : """1""" },
    { "borrower" : """1945""", "count" : """1""" },
    { "borrower" : """1969""", "count" : """1""" },
    { "borrower" : """1991""", "count" : """1""" },
    { "borrower" : """2014""", "count" : """1""" },
    { "borrower" : """2041""", "count" : """1""" },
    { "borrower" : """2137""", "count" : """1""" },
    { "borrower" : """2178""", "count" : """1""" },
    { "borrower" : """2197""", "count" : """1""" },
    { "borrower" : """2268""", "count" : """1""" },
    { "borrower" : """2276""", "count" : """1""" },
    { "borrower" : """2402""", "count" : """1""" },
    { "borrower" : """2415""", "count" : """1""" },
    { "borrower" : """2492""", "count" : """1""" },
    { "borrower" : """2658""", "count" : """1""" },
    { "borrower" : """2688""", "count" : """1""" },
    { "borrower" : """2796""", "count" : """1""" },
    { "borrower" : """2849""", "count" : """1""" },
    { "borrower" : """2943""", "count" : """1""" },
    { "borrower" : """2965""", "count" : """1""" },
    { "borrower" : """2986""", "count" : """1""" },
    { "borrower" : """3004""", "count" : """1""" },
    { "borrower" : """3022""", "count" : """1""" },
    { "borrower" : """3049""", "count" : """1""" },
    { "borrower" : """3143""", "count" : """1""" },
    { "borrower" : """3153""", "count" : """1""" },
    { "borrower" : """3335""", "count" : """1""" },
    { "borrower" : """3339""", "count" : """1""" },
    { "borrower" : """3462""", "count" : """1""" },
    { "borrower" : """3552""", "count" : """1""" },
    { "borrower" : """3556""", "count" : """1""" },
    { "borrower" : """3690""", "count" : """1""" },
    { "borrower" : """3948""", "count" : """1""" },
    { "borrower" : """3991""", "count" : """1""" },
    { "borrower" : """4033""", "count" : """1""" },
    { "borrower" : """4046""", "count" : """1""" },
    { "borrower" : """4066""", "count" : """1""" },
    { "borrower" : """4092""", "count" : """1""" },
    { "borrower" : """4425""", "count" : """1""" },
    { "borrower" : """4440""", "count" : """1""" },
    { "borrower" : """4496""", "count" : """1""" },
    { "borrower" : """4631""", "count" : """1""" },
    { "borrower" : """4681""", "count" : """1""" },
    { "borrower" : """4727""", "count" : """1""" },
    { "borrower" : """4732""", "count" : """1""" },
    { "borrower" : """4783""", "count" : """1""" },
    { "borrower" : """4916""", "count" : """1""" },
    { "borrower" : """5013""", "count" : """1""" },
    { "borrower" : """5073""", "count" : """1""" },
    { "borrower" : """5075""", "count" : """1""" },
    { "borrower" : """5138""", "count" : """1""" },
    { "borrower" : """5233""", "count" : """1""" },
    { "borrower" : """5269""", "count" : """1""" },
    { "borrower" : """5285""", "count" : """1""" },
    { "borrower" : """5293""", "count" : """1""" },
    { "borrower" : """5294""", "count" : """1""" },
    { "borrower" : """5323""", "count" : """1""" },
    { "borrower" : """5464""", "count" : """1""" },
    { "borrower" : """5478""", "count" : """1""" },
    { "borrower" : """5519""", "count" : """1""" },
    { "borrower" : """5534""", "count" : """1""" },
    { "borrower" : """5689""", "count" : """1""" },
    { "borrower" : """5701""", "count" : """1""" },
    { "borrower" : """5812""", "count" : """1""" },
    { "borrower" : """5858""", "count" : """1""" },
    { "borrower" : """5904""", "count" : """1""" },
    { "borrower" : """6024""", "count" : """1""" },
    { "borrower" : """6027""", "count" : """1""" },
    { "borrower" : """6050""", "count" : """1""" },
    { "borrower" : """6179""", "count" : """1""" },
    { "borrower" : """6259""", "count" : """1""" },
    { "borrower" : """6265""", "count" : """1""" },
    { "borrower" : """6342""", "count" : """1""" },
    { "borrower" : """6343""", "count" : """1""" },
    { "borrower" : """6451""", "count" : """1""" },
    { "borrower" : """6506""", "count" : """1""" },
    { "borrower" : """6528""", "count" : """1""" },
    { "borrower" : """6590""", "count" : """1""" },
    { "borrower" : """6655""", "count" : """1""" },
    { "borrower" : """6676""", "count" : """1""" },
    { "borrower" : """6765""", "count" : """1""" },
    { "borrower" : """6804""", "count" : """1""" },
    { "borrower" : """6820""", "count" : """1""" },
    { "borrower" : """6834""", "count" : """1""" },
    { "borrower" : """7068""", "count" : """1""" },
    { "borrower" : """7124""", "count" : """1""" },
    { "borrower" : """7277""", "count" : """1""" },
    { "borrower" : """7307""", "count" : """1""" },
    { "borrower" : """7480""", "count" : """1""" },
    { "borrower" : """7668""", "count" : """1""" },
    { "borrower" : """7829""", "count" : """1""" },
    { "borrower" : """7908""", "count" : """1""" },
    { "borrower" : """7921""", "count" : """1""" },
    { "borrower" : """8084""", "count" : """1""" },
    { "borrower" : """8229""", "count" : """1""" },
    { "borrower" : """8250""", "count" : """1""" },
    { "borrower" : """8279""", "count" : """1""" },
    { "borrower" : """8445""", "count" : """1""" },
    { "borrower" : """8487""", "count" : """1""" },
    { "borrower" : """8610""", "count" : """1""" },
    { "borrower" : """8681""", "count" : """1""" },
    { "borrower" : """8707""", "count" : """1""" },
    { "borrower" : """8796""", "count" : """1""" },
    { "borrower" : """8820""", "count" : """1""" },
    { "borrower" : """8854""", "count" : """1""" },
    { "borrower" : """9017""", "count" : """1""" },
    { "borrower" : """9018""", "count" : """1""" },
    { "borrower" : """9193""", "count" : """1""" },
    { "borrower" : """9398""", "count" : """1""" },
    { "borrower" : """9437""", "count" : """1""" },
    { "borrower" : """9454""", "count" : """1""" },
    { "borrower" : """9614""", "count" : """1""" },
    { "borrower" : """9647""", "count" : """1""" },
    { "borrower" : """9873""", "count" : """1""" },
    { "borrower" : """9961""", "count" : """1""" },
    { "borrower" : """9979""", "count" : """1""" },
    { "borrower" : """10346""", "count" : """1""" },
    { "borrower" : """10361""", "count" : """1""" },
    { "borrower" : """10375""", "count" : """1""" },
    { "borrower" : """10439""", "count" : """1""" },
    { "borrower" : """10479""", "count" : """1""" },
    { "borrower" : """10516""", "count" : """1""" },
    { "borrower" : """10561""", "count" : """1""" },
    { "borrower" : """10689""", "count" : """1""" },
    { "borrower" : """10781""", "count" : """1""" },
    { "borrower" : """10914""", "count" : """1""" },
    { "borrower" : """10969""", "count" : """1""" },
    { "borrower" : """10977""", "count" : """1""" },
    { "borrower" : """11132""", "count" : """1""" },
    { "borrower" : """11139""", "count" : """1""" },
    { "borrower" : """11362""", "count" : """1""" },
    { "borrower" : """11414""", "count" : """1""" },
    { "borrower" : """11437""", "count" : """1""" },
    { "borrower" : """11533""", "count" : """1""" },
    { "borrower" : """11535""", "count" : """1""" },
    { "borrower" : """11537""", "count" : """1""" },
    { "borrower" : """11571""", "count" : """1""" },
    { "borrower" : """11618""", "count" : """1""" },
    { "borrower" : """11624""", "count" : """1""" },
    { "borrower" : """11637""", "count" : """1""" },
    { "borrower" : """11671""", "count" : """1""" },
    { "borrower" : """11747""", "count" : """1""" },
    { "borrower" : """11788""", "count" : """1""" },
    { "borrower" : """11831""", "count" : """1""" },
    { "borrower" : """11866""", "count" : """1""" },
    { "borrower" : """11903""", "count" : """1""" },
    { "borrower" : """11973""", "count" : """1""" },
    { "borrower" : """11986""", "count" : """1""" },
    { "borrower" : """12003""", "count" : """1""" },
    { "borrower" : """12081""", "count" : """1""" },
    { "borrower" : """12114""", "count" : """1""" },
    { "borrower" : """12120""", "count" : """1""" },
    { "borrower" : """12200""", "count" : """1""" },
    { "borrower" : """12251""", "count" : """1""" },
    { "borrower" : """12266""", "count" : """1""" },
    { "borrower" : """12276""", "count" : """1""" },
    { "borrower" : """12315""", "count" : """1""" },
    { "borrower" : """12326""", "count" : """1""" },
    { "borrower" : """12396""", "count" : """1""" },
    { "borrower" : """12404""", "count" : """1""" },
    { "borrower" : """12574""", "count" : """1""" },
    { "borrower" : """12617""", "count" : """1""" },
    { "borrower" : """12726""", "count" : """1""" },
    { "borrower" : """12781""", "count" : """1""" },
    { "borrower" : """12850""", "count" : """1""" },
    { "borrower" : """12866""", "count" : """1""" },
    { "borrower" : """13071""", "count" : """1""" },
    { "borrower" : """13072""", "count" : """1""" },
    { "borrower" : """13075""", "count" : """1""" },
    { "borrower" : """13112""", "count" : """1""" },
    { "borrower" : """13123""", "count" : """1""" },
    { "borrower" : """13136""", "count" : """1""" },
    { "borrower" : """13150""", "count" : """1""" },
    { "borrower" : """13242""", "count" : """1""" },
    { "borrower" : """13284""", "count" : """1""" },
    { "borrower" : """13317""", "count" : """1""" },
    { "borrower" : """13340""", "count" : """1""" },
    { "borrower" : """13384""", "count" : """1""" },
    { "borrower" : """13406""", "count" : """1""" },
    { "borrower" : """13440""", "count" : """1""" },
    { "borrower" : """13486""", "count" : """1""" },
    { "borrower" : """13525""", "count" : """1""" },
    { "borrower" : """13559""", "count" : """1""" },
    { "borrower" : """13570""", "count" : """1""" },
    { "borrower" : """13611""", "count" : """1""" },
    { "borrower" : """13612""", "count" : """1""" },
    { "borrower" : """13711""", "count" : """1""" },
    { "borrower" : """13724""", "count" : """1""" },
    { "borrower" : """13727""", "count" : """1""" },
    { "borrower" : """13741""", "count" : """1""" },
    { "borrower" : """13748""", "count" : """1""" },
    { "borrower" : """13794""", "count" : """1""" },
    { "borrower" : """13887""", "count" : """1""" },
    { "borrower" : """13926""", "count" : """1""" },
    { "borrower" : """14045""", "count" : """1""" },
    { "borrower" : """14108""", "count" : """1""" },
    { "borrower" : """14173""", "count" : """1""" },
    { "borrower" : """14179""", "count" : """1""" },
    { "borrower" : """14189""", "count" : """1""" },
    { "borrower" : """14205""", "count" : """1""" },
    { "borrower" : """14218""", "count" : """1""" },
    { "borrower" : """14225""", "count" : """1""" },
    { "borrower" : """14324""", "count" : """1""" },
    { "borrower" : """14389""", "count" : """1""" },
    { "borrower" : """14395""", "count" : """1""" },
    { "borrower" : """14430""", "count" : """1""" },
    { "borrower" : """14448""", "count" : """1""" },
    { "borrower" : """14449""", "count" : """1""" },
    { "borrower" : """14477""", "count" : """1""" },
    { "borrower" : """14493""", "count" : """1""" },
    { "borrower" : """14494""", "count" : """1""" },
    { "borrower" : """14513""", "count" : """1""" },
    { "borrower" : """14516""", "count" : """1""" },
    { "borrower" : """14520""", "count" : """1""" },
    { "borrower" : """14536""", "count" : """1""" },
    { "borrower" : """14554""", "count" : """1""" },
    { "borrower" : """14571""", "count" : """1""" },
    { "borrower" : """14679""", "count" : """1""" },
    { "borrower" : """14697""", "count" : """1""" },
    { "borrower" : """14772""", "count" : """1""" },
    { "borrower" : """14804""", "count" : """1""" },
    { "borrower" : """14909""", "count" : """1""" },
    { "borrower" : """14914""", "count" : """1""" },
    { "borrower" : """14946""", "count" : """1""" },
    { "borrower" : """15033""", "count" : """1""" },
    { "borrower" : """15118""", "count" : """1""" },
    { "borrower" : """15156""", "count" : """1""" },
    { "borrower" : """15238""", "count" : """1""" },
    { "borrower" : """15340""", "count" : """1""" },
    { "borrower" : """15360""", "count" : """1""" },
    { "borrower" : """15381""", "count" : """1""" },
    { "borrower" : """15530""", "count" : """1""" },
    { "borrower" : """15556""", "count" : """1""" },
    { "borrower" : """15614""", "count" : """1""" },
    { "borrower" : """15652""", "count" : """1""" },
    { "borrower" : """15730""", "count" : """1""" },
    { "borrower" : """15736""", "count" : """1""" },
    { "borrower" : """15783""", "count" : """1""" },
    { "borrower" : """15805""", "count" : """1""" },
    { "borrower" : """15845""", "count" : """1""" },
    { "borrower" : """15954""", "count" : """1""" },
    { "borrower" : """16020""", "count" : """1""" },
    { "borrower" : """16043""", "count" : """1""" },
    { "borrower" : """16114""", "count" : """1""" },
    { "borrower" : """16135""", "count" : """1""" },
    { "borrower" : """16180""", "count" : """1""" },
    { "borrower" : """16194""", "count" : """1""" },
    { "borrower" : """16505""", "count" : """1""" },
    { "borrower" : """16510""", "count" : """1""" },
    { "borrower" : """16539""", "count" : """1""" },
    { "borrower" : """16555""", "count" : """1""" },
    { "borrower" : """16597""", "count" : """1""" },
    { "borrower" : """16661""", "count" : """1""" },
    { "borrower" : """16704""", "count" : """1""" },
    { "borrower" : """16740""", "count" : """1""" },
    { "borrower" : """16787""", "count" : """1""" },
    { "borrower" : """16807""", "count" : """1""" },
    { "borrower" : """16898""", "count" : """1""" },
    { "borrower" : """17075""", "count" : """1""" },
    { "borrower" : """17105""", "count" : """1""" },
    { "borrower" : """17208""", "count" : """1""" },
    { "borrower" : """17211""", "count" : """1""" },
    { "borrower" : """17234""", "count" : """1""" },
    { "borrower" : """17303""", "count" : """1""" },
    { "borrower" : """17351""", "count" : """1""" },
    { "borrower" : """17455""", "count" : """1""" },
    { "borrower" : """17510""", "count" : """1""" },
    { "borrower" : """17516""", "count" : """1""" },
    { "borrower" : """17680""", "count" : """1""" },
    { "borrower" : """17793""", "count" : """1""" },
    { "borrower" : """17841""", "count" : """1""" },
    { "borrower" : """17922""", "count" : """1""" },
    { "borrower" : """18003""", "count" : """1""" },
    { "borrower" : """18029""", "count" : """1""" },
    { "borrower" : """18111""", "count" : """1""" },
    { "borrower" : """18119""", "count" : """1""" },
    { "borrower" : """18155""", "count" : """1""" },
    { "borrower" : """18173""", "count" : """1""" },
    { "borrower" : """18221""", "count" : """1""" },
    { "borrower" : """18276""", "count" : """1""" },
    { "borrower" : """18322""", "count" : """1""" },
    { "borrower" : """18335""", "count" : """1""" },
    { "borrower" : """18352""", "count" : """1""" },
    { "borrower" : """18374""", "count" : """1""" },
    { "borrower" : """18377""", "count" : """1""" },
    { "borrower" : """18464""", "count" : """1""" },
    { "borrower" : """18534""", "count" : """1""" },
    { "borrower" : """18570""", "count" : """1""" },
    { "borrower" : """18612""", "count" : """1""" },
    { "borrower" : """18688""", "count" : """1""" },
    { "borrower" : """18779""", "count" : """1""" },
    { "borrower" : """18847""", "count" : """1""" },
    { "borrower" : """18897""", "count" : """1""" },
    { "borrower" : """18952""", "count" : """1""" },
    { "borrower" : """19000""", "count" : """1""" },
    { "borrower" : """19073""", "count" : """1""" },
    { "borrower" : """19103""", "count" : """1""" },
    { "borrower" : """19147""", "count" : """1""" },
    { "borrower" : """19171""", "count" : """1""" },
    { "borrower" : """19187""", "count" : """1""" },
    { "borrower" : """19221""", "count" : """1""" },
    { "borrower" : """19228""", "count" : """1""" },
    { "borrower" : """19235""", "count" : """1""" },
    { "borrower" : """19270""", "count" : """1""" },
    { "borrower" : """19281""", "count" : """1""" },
    { "borrower" : """19296""", "count" : """1""" },
    { "borrower" : """19354""", "count" : """1""" },
    { "borrower" : """19380""", "count" : """1""" },
    { "borrower" : """19401""", "count" : """1""" },
    { "borrower" : """19415""", "count" : """1""" },
    { "borrower" : """19520""", "count" : """1""" },
    { "borrower" : """19571""", "count" : """1""" },
    { "borrower" : """19655""", "count" : """1""" },
    { "borrower" : """19676""", "count" : """1""" },
    { "borrower" : """19692""", "count" : """1""" },
    { "borrower" : """19804""", "count" : """1""" },
    { "borrower" : """19839""", "count" : """1""" },
    { "borrower" : """19857""", "count" : """1""" },
    { "borrower" : """19863""", "count" : """1""" },
    { "borrower" : """19888""", "count" : """1""" },
    { "borrower" : """19908""", "count" : """1""" },
    { "borrower" : """19920""", "count" : """1""" },
    { "borrower" : """20052""", "count" : """1""" },
    { "borrower" : """20135""", "count" : """1""" },
    { "borrower" : """20156""", "count" : """1""" },
    { "borrower" : """20216""", "count" : """1""" },
    { "borrower" : """20297""", "count" : """1""" },
    { "borrower" : """20299""", "count" : """1""" },
    { "borrower" : """20301""", "count" : """1""" },
    { "borrower" : """20324""", "count" : """1""" },
    { "borrower" : """20328""", "count" : """1""" },
    { "borrower" : """20396""", "count" : """1""" },
    { "borrower" : """20409""", "count" : """1""" },
    { "borrower" : """20513""", "count" : """1""" },
    { "borrower" : """20518""", "count" : """1""" },
    { "borrower" : """20522""", "count" : """1""" },
    { "borrower" : """20527""", "count" : """1""" },
    { "borrower" : """20546""", "count" : """1""" },
    { "borrower" : """20551""", "count" : """1""" },
    { "borrower" : """20598""", "count" : """1""" },
    { "borrower" : """20632""", "count" : """1""" },
    { "borrower" : """20865""", "count" : """1""" },
    { "borrower" : """20972""", "count" : """1""" },
    { "borrower" : """21005""", "count" : """1""" },
    { "borrower" : """21030""", "count" : """1""" },
    { "borrower" : """21034""", "count" : """1""" },
    { "borrower" : """21044""", "count" : """1""" },
    { "borrower" : """21065""", "count" : """1""" },
    { "borrower" : """21115""", "count" : """1""" },
    { "borrower" : """21184""", "count" : """1""" },
    { "borrower" : """21235""", "count" : """1""" },
    { "borrower" : """21249""", "count" : """1""" },
    { "borrower" : """21263""", "count" : """1""" },
    { "borrower" : """21314""", "count" : """1""" },
    { "borrower" : """21363""", "count" : """1""" },
    { "borrower" : """21379""", "count" : """1""" },
    { "borrower" : """21405""", "count" : """1""" },
    { "borrower" : """21406""", "count" : """1""" },
    { "borrower" : """21444""", "count" : """1""" },
    { "borrower" : """21512""", "count" : """1""" },
    { "borrower" : """21584""", "count" : """1""" },
    { "borrower" : """21592""", "count" : """1""" },
    { "borrower" : """21660""", "count" : """1""" },
    { "borrower" : """21701""", "count" : """1""" },
    { "borrower" : """21717""", "count" : """1""" },
    { "borrower" : """21733""", "count" : """1""" },
    { "borrower" : """21806""", "count" : """1""" },
    { "borrower" : """21848""", "count" : """1""" },
    { "borrower" : """21936""", "count" : """1""" },
    { "borrower" : """21952""", "count" : """1""" },
    { "borrower" : """22088""", "count" : """1""" },
    { "borrower" : """22181""", "count" : """1""" },
    { "borrower" : """22280""", "count" : """1""" },
    { "borrower" : """22297""", "count" : """1""" },
    { "borrower" : """22417""", "count" : """1""" },
    { "borrower" : """22423""", "count" : """1""" },
    { "borrower" : """22429""", "count" : """1""" },
    { "borrower" : """22544""", "count" : """1""" },
    { "borrower" : """22674""", "count" : """1""" },
    { "borrower" : """22724""", "count" : """1""" },
    { "borrower" : """22761""", "count" : """1""" },
    { "borrower" : """22775""", "count" : """1""" },
    { "borrower" : """22859""", "count" : """1""" },
    { "borrower" : """22996""", "count" : """1""" },
    { "borrower" : """22999""", "count" : """1""" },
    { "borrower" : """23008""", "count" : """1""" },
    { "borrower" : """23061""", "count" : """1""" },
    { "borrower" : """23149""", "count" : """1""" },
    { "borrower" : """23175""", "count" : """1""" },
    { "borrower" : """23176""", "count" : """1""" },
    { "borrower" : """23180""", "count" : """1""" },
    { "borrower" : """23287""", "count" : """1""" },
    { "borrower" : """23336""", "count" : """1""" },
    { "borrower" : """23402""", "count" : """1""" },
    { "borrower" : """23444""", "count" : """1""" },
    { "borrower" : """23462""", "count" : """1""" },
    { "borrower" : """23481""", "count" : """1""" },
    { "borrower" : """23504""", "count" : """1""" },
    { "borrower" : """23654""", "count" : """1""" },
    { "borrower" : """23731""", "count" : """1""" },
    { "borrower" : """23739""", "count" : """1""" },
    { "borrower" : """23741""", "count" : """1""" },
    { "borrower" : """23822""", "count" : """1""" },
    { "borrower" : """23888""", "count" : """1""" },
    { "borrower" : """23912""", "count" : """1""" },
    { "borrower" : """24032""", "count" : """1""" },
    { "borrower" : """24074""", "count" : """1""" },
    { "borrower" : """24111""", "count" : """1""" },
    { "borrower" : """24139""", "count" : """1""" },
    { "borrower" : """24246""", "count" : """1""" },
    { "borrower" : """24464""", "count" : """1""" },
    { "borrower" : """24495""", "count" : """1""" },
    { "borrower" : """24895""", "count" : """1""" },
    { "borrower" : """24949""", "count" : """1""" },
    { "borrower" : """24955""", "count" : """1""" },
    { "borrower" : """25045""", "count" : """1""" },
    { "borrower" : """25047""", "count" : """1""" },
    { "borrower" : """25066""", "count" : """1""" },
    { "borrower" : """25081""", "count" : """1""" },
    { "borrower" : """25103""", "count" : """1""" },
    { "borrower" : """25329""", "count" : """1""" },
    { "borrower" : """25377""", "count" : """1""" },
    { "borrower" : """25545""", "count" : """1""" },
    { "borrower" : """25558""", "count" : """1""" },
    { "borrower" : """25570""", "count" : """1""" },
    { "borrower" : """25572""", "count" : """1""" },
    { "borrower" : """25587""", "count" : """1""" },
    { "borrower" : """25696""", "count" : """1""" },
    { "borrower" : """25802""", "count" : """1""" },
    { "borrower" : """25973""", "count" : """1""" },
]

# %%
data5= [
    { "rate" : """25""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """30""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """100""" },
    { "rate" : """5""" },
    { "rate" : """0""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """1e-05""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """1e-05""" },
    { "rate" : """1e-05""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """100""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """14""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """11""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """11""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """11""" },
    { "rate" : """7""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """7""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """14""" },
    { "rate" : """14""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """21""" },
    { "rate" : """5""" },
    { "rate" : """21""" },
    { "rate" : """7""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """21""" },
    { "rate" : """21""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """21""" },
    { "rate" : """21""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """21""" },
    { "rate" : """21""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """21""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """20""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """21""" },
    { "rate" : """11""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """21""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """11""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """21""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """17""" },
    { "rate" : """21""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """14""" },
    { "rate" : """18""" },
    { "rate" : """21""" },
    { "rate" : """15""" },
    { "rate" : """17""" },
    { "rate" : """18""" },
    { "rate" : """18""" },
    { "rate" : """17""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """20""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """21""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """6""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """21""" },
    { "rate" : """19""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """18""" },
    { "rate" : """21""" },
    { "rate" : """20""" },
    { "rate" : """21""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """1""" },
    { "rate" : """20""" },
    { "rate" : """11""" },
    { "rate" : """20""" },
    { "rate" : """11""" },
    { "rate" : """11""" },
    { "rate" : """19""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """11""" },
    { "rate" : """11""" },
    { "rate" : """20""" },
    { "rate" : """21""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """21""" },
    { "rate" : """21""" },
    { "rate" : """21""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """19""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """21""" },
    { "rate" : """10""" },
    { "rate" : """21""" },
    { "rate" : """21""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """21""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """12""" },
    { "rate" : """11""" },
    { "rate" : """2""" },
    { "rate" : """21""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """21""" },
    { "rate" : """21""" },
    { "rate" : """18""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """17""" },
    { "rate" : """10""" },
    { "rate" : """21""" },
    { "rate" : """22""" },
    { "rate" : """22""" },
    { "rate" : """100""" },
    { "rate" : """100""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """28""" },
    { "rate" : """11""" },
    { "rate" : """28""" },
    { "rate" : """18""" },
    { "rate" : """18""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """25""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """21""" },
    { "rate" : """10""" },
    { "rate" : """28""" },
    { "rate" : """21""" },
    { "rate" : """12""" },
    { "rate" : """28""" },
    { "rate" : """4""" },
    { "rate" : """24""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """28""" },
    { "rate" : """20""" },
    { "rate" : """28""" },
    { "rate" : """21""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """21""" },
    { "rate" : """10""" },
    { "rate" : """25""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """26""" },
    { "rate" : """28""" },
    { "rate" : """28""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """28""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """21""" },
    { "rate" : """15""" },
    { "rate" : """28""" },
    { "rate" : """28""" },
    { "rate" : """21""" },
    { "rate" : """11""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """28""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """27""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """30""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """21""" },
    { "rate" : """14""" },
    { "rate" : """14""" },
    { "rate" : """2""" },
    { "rate" : """21""" },
    { "rate" : """18""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """20""" },
    { "rate" : """1""" },
    { "rate" : """21""" },
    { "rate" : """22""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """21""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """21""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """21""" },
    { "rate" : """21""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """21""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """21""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """21""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """18""" },
    { "rate" : """18""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """24""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """18""" },
    { "rate" : """18""" },
    { "rate" : """18""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """18""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """18""" },
    { "rate" : """18""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """18""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """18""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """18""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """18""" },
    { "rate" : """6""" },
    { "rate" : """18""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """18""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """18""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """30""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """18""" },
    { "rate" : """30""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """30""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """18""" },
    { "rate" : """18""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """30""" },
    { "rate" : """6""" },
    { "rate" : """21""" },
    { "rate" : """5""" },
    { "rate" : """30""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """100""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """11""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """1000""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """18""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """18""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """19""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """30""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """25""" },
    { "rate" : """30""" },
    { "rate" : """5""" },
    { "rate" : """19""" },
    { "rate" : """11""" },
    { "rate" : """7.9""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """19""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """30""" },
    { "rate" : """11""" },
    { "rate" : """15""" },
    { "rate" : """18""" },
    { "rate" : """35""" },
    { "rate" : """15""" },
    { "rate" : """25""" },
    { "rate" : """19""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """12.5""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """25""" },
    { "rate" : """20""" },
    { "rate" : """11""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """8.7""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """8.999""" },
    { "rate" : """30""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """0.9""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """8.995""" },
    { "rate" : """8.99999""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """8.9999""" },
    { "rate" : """9""" },
    { "rate" : """8.9999""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """30""" },
    { "rate" : """23""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """10.5""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """11""" },
    { "rate" : """8""" },
    { "rate" : """8.25""" },
    { "rate" : """9""" },
    { "rate" : """7.5""" },
    { "rate" : """2.5""" },
    { "rate" : """8.24999""" },
    { "rate" : """8.5""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """4.99999""" },
    { "rate" : """8.24998""" },
    { "rate" : """1""" },
    { "rate" : """2.99""" },
    { "rate" : """8.25""" },
    { "rate" : """8.75""" },
    { "rate" : """15""" },
    { "rate" : """4.9""" },
    { "rate" : """14""" },
    { "rate" : """4.9999""" },
    { "rate" : """1.5""" },
    { "rate" : """2.6""" },
    { "rate" : """1.99""" },
    { "rate" : """1""" },
    { "rate" : """30""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """2.48""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """2.5""" },
    { "rate" : """8.75""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """2""" },
    { "rate" : """100""" },
    { "rate" : """2""" },
    { "rate" : """95""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """12.5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """0.001""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """11.49999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """11.5""" },
    { "rate" : """8.99""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """6.25""" },
    { "rate" : """6.24987""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """8.75""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """100""" },
    { "rate" : """1.99""" },
    { "rate" : """9""" },
    { "rate" : """100""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """25""" },
    { "rate" : """1.95""" },
    { "rate" : """28""" },
    { "rate" : """35""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """8.99999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """12.5""" },
    { "rate" : """12.5""" },
    { "rate" : """2.9""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """11.5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """0.0001""" },
    { "rate" : """3""" },
    { "rate" : """0.0001""" },
    { "rate" : """1.06546234""" },
    { "rate" : """3""" },
    { "rate" : """0.0001""" },
    { "rate" : """2.9""" },
    { "rate" : """1.06546234""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """1.06546234""" },
    { "rate" : """13""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.06546234""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """11.99999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """1.06546234""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.06546234""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """14""" },
    { "rate" : """0.0001""" },
    { "rate" : """2""" },
    { "rate" : """0.0001""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """0.0001""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.0001""" },
    { "rate" : """0.0001""" },
    { "rate" : """0.0001""" },
    { "rate" : """0.0001""" },
    { "rate" : """0.0001""" },
    { "rate" : """1.06546234""" },
    { "rate" : """1.06546""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """14.99997""" },
    { "rate" : """15""" },
    { "rate" : """14.999999""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """0""" },
    { "rate" : """14.99999""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """0""" },
    { "rate" : """15""" },
    { "rate" : """0""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """14.9""" },
    { "rate" : """12""" },
    { "rate" : """0""" },
    { "rate" : """2.5""" },
    { "rate" : """2""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """2""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """2.4""" },
    { "rate" : """2.5""" },
    { "rate" : """1""" },
    { "rate" : """0""" },
    { "rate" : """0""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """1.4""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """2.49""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """0.01""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """0.96""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """0.96""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """20""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """20""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """11""" },
    { "rate" : """20""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """15.8""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """8.9""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99722""" },
    { "rate" : """14""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """14""" },
    { "rate" : """0.02778""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """8.99""" },
    { "rate" : """30""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """1.5""" },
    { "rate" : """11""" },
    { "rate" : """20""" },
    { "rate" : """9""" },
    { "rate" : """13""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """12.5""" },
    { "rate" : """25""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """9.16667""" },
    { "rate" : """22""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """19.99999""" },
    { "rate" : """10""" },
    { "rate" : """16""" },
    { "rate" : """25""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """8""" },
    { "rate" : """9.99""" },
    { "rate" : """9.98""" },
    { "rate" : """5.49""" },
    { "rate" : """9.97""" },
    { "rate" : """4""" },
    { "rate" : """4.49""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """4.145""" },
    { "rate" : """11""" },
    { "rate" : """4.14499""" },
    { "rate" : """10""" },
    { "rate" : """4.15""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """3.9999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """0.75""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """21""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """14.99999""" },
    { "rate" : """0.99988""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """0.99989""" },
    { "rate" : """5.49999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """19""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """3.11111""" },
    { "rate" : """20""" },
    { "rate" : """5.5""" },
    { "rate" : """5""" },
    { "rate" : """5.99999""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """9.1""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """102000""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """1.99""" },
    { "rate" : """6""" },
    { "rate" : """11.5""" },
    { "rate" : """11""" },
    { "rate" : """21""" },
    { "rate" : """21""" },
    { "rate" : """21""" },
    { "rate" : """21""" },
    { "rate" : """21""" },
    { "rate" : """21""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """21""" },
    { "rate" : """5""" },
    { "rate" : """17""" },
    { "rate" : """21""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """21""" },
    { "rate" : """21""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """2.9""" },
    { "rate" : """3""" },
    { "rate" : """2.8""" },
    { "rate" : """2.99999""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.8""" },
    { "rate" : """2.98999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """2.8""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """12""" },
    { "rate" : """2.79""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """2.9""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """2.94""" },
    { "rate" : """2.94999""" },
    { "rate" : """2.9""" },
    { "rate" : """2.98999""" },
    { "rate" : """20""" },
    { "rate" : """2""" },
    { "rate" : """2.9""" },
    { "rate" : """3""" },
    { "rate" : """2.88""" },
    { "rate" : """2.8""" },
    { "rate" : """2.8""" },
    { "rate" : """10""" },
    { "rate" : """16""" },
    { "rate" : """1""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """1.5""" },
    { "rate" : """2""" },
    { "rate" : """1.9""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """1.75""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.9999""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """4.99999""" },
    { "rate" : """6""" },
    { "rate" : """4.5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3.98999""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """386835""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """2.98""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.8""" },
    { "rate" : """2.5""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7.7""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7.9""" },
    { "rate" : """7.9""" },
    { "rate" : """2.49""" },
    { "rate" : """2.85""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """10.7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """2.99""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3.2""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """12""" },
    { "rate" : """30""" },
    { "rate" : """30""" },
    { "rate" : """30""" },
    { "rate" : """27.5""" },
    { "rate" : """10""" },
    { "rate" : """25""" },
    { "rate" : """18""" },
    { "rate" : """3.9""" },
    { "rate" : """30""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """30""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """30""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """30""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """30""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """17""" },
    { "rate" : """11""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4.8""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """18""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """14""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """24""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """24""" },
    { "rate" : """24""" },
    { "rate" : """12""" },
    { "rate" : """3""" },
    { "rate" : """2.94999""" },
    { "rate" : """3.49""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """19""" },
    { "rate" : """19""" },
    { "rate" : """19""" },
    { "rate" : """19""" },
    { "rate" : """5""" },
    { "rate" : """4.98""" },
    { "rate" : """5.79""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """2""" },
    { "rate" : """4.2""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """1e-05""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1e-05""" },
    { "rate" : """3""" },
    { "rate" : """1e-05""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """1e-05""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """2.5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1.89999""" },
    { "rate" : """1.9""" },
    { "rate" : """0""" },
    { "rate" : """0""" },
    { "rate" : """5""" },
    { "rate" : """0""" },
    { "rate" : """5""" },
    { "rate" : """0""" },
    { "rate" : """0""" },
    { "rate" : """0""" },
    { "rate" : """5""" },
    { "rate" : """0""" },
    { "rate" : """3.75""" },
    { "rate" : """5""" },
    { "rate" : """0""" },
    { "rate" : """3.5""" },
    { "rate" : """0""" },
    { "rate" : """4""" },
    { "rate" : """0""" },
    { "rate" : """0""" },
    { "rate" : """5""" },
    { "rate" : """4.8""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """0""" },
    { "rate" : """20""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """4""" },
    { "rate" : """0""" },
    { "rate" : """17.5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """3.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """0""" },
    { "rate" : """0""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """0""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """0""" },
    { "rate" : """0""" },
    { "rate" : """0""" },
    { "rate" : """0""" },
    { "rate" : """0""" },
    { "rate" : """15""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.4""" },
    { "rate" : """1.5""" },
    { "rate" : """1""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.4""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.48999""" },
    { "rate" : """1.5""" },
    { "rate" : """0.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.49999""" },
    { "rate" : """1.5""" },
    { "rate" : """1.25""" },
    { "rate" : """1.5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """20""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2.9""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2.25""" },
    { "rate" : """2.75""" },
    { "rate" : """20""" },
    { "rate" : """2.99999""" },
    { "rate" : """2.95""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """3.5""" },
    { "rate" : """6""" },
    { "rate" : """8.5""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5.99999""" },
    { "rate" : """5.99999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """20""" },
    { "rate" : """0.4""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.499""" },
    { "rate" : """5""" },
    { "rate" : """0.35""" },
    { "rate" : """0.348""" },
    { "rate" : """0.348""" },
    { "rate" : """0.349""" },
    { "rate" : """6""" },
    { "rate" : """0.1""" },
    { "rate" : """0.1""" },
    { "rate" : """0.1""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99995""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """0.1""" },
    { "rate" : """0.1""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """0.1""" },
    { "rate" : """0.1""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """0.1""" },
    { "rate" : """0.1""" },
    { "rate" : """0.1""" },
    { "rate" : """0.099""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """3.49""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """7.875""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """0.00278""" },
    { "rate" : """6.5""" },
    { "rate" : """0.00028""" },
    { "rate" : """3e-05""" },
    { "rate" : """7""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """1.7""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """7.99999""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """11""" },
    { "rate" : """7.99998""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """2.59999""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """0.198""" },
    { "rate" : """2.99""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """14""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.99""" },
    { "rate" : """1""" },
    { "rate" : """13""" },
    { "rate" : """0.1""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """9.5""" },
    { "rate" : """100""" },
    { "rate" : """7""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """3.25""" },
    { "rate" : """3.3""" },
    { "rate" : """3.25""" },
    { "rate" : """3.25""" },
    { "rate" : """5.9""" },
    { "rate" : """8""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """11""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """8""" },
    { "rate" : """3.5""" },
    { "rate" : """7.99999""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """35""" },
    { "rate" : """7.75""" },
    { "rate" : """9""" },
    { "rate" : """6.99999""" },
    { "rate" : """3.5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """3.49""" },
    { "rate" : """7.98""" },
    { "rate" : """7""" },
    { "rate" : """7.99""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """9""" },
    { "rate" : """7.5""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """19""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """7.99999""" },
    { "rate" : """3.5""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """0.96""" },
    { "rate" : """3.5""" },
    { "rate" : """6.5""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """3.5""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """0.01386""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """2.35""" },
    { "rate" : """0.01389""" },
    { "rate" : """7""" },
    { "rate" : """20""" },
    { "rate" : """7""" },
    { "rate" : """0.05""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """3.49""" },
    { "rate" : """7""" },
    { "rate" : """3.49999""" },
    { "rate" : """0.05""" },
    { "rate" : """0.05""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """0.01389""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """0.05""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """7.499""" },
    { "rate" : """7.49999""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6.5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7.48""" },
    { "rate" : """6.999""" },
    { "rate" : """3""" },
    { "rate" : """2.498""" },
    { "rate" : """2""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """0.5""" },
    { "rate" : """0.379""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """1e-05""" },
    { "rate" : """50""" },
    { "rate" : """1e-05""" },
    { "rate" : """1e-05""" },
    { "rate" : """20.49999""" },
    { "rate" : """1e-05""" },
    { "rate" : """20""" },
    { "rate" : """1e-05""" },
    { "rate" : """20""" },
    { "rate" : """0.04167""" },
    { "rate" : """20.5""" },
    { "rate" : """0.06""" },
    { "rate" : """3.9""" },
    { "rate" : """40""" },
    { "rate" : """10""" },
    { "rate" : """21""" },
    { "rate" : """20""" },
    { "rate" : """4""" },
    { "rate" : """20""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """24""" },
    { "rate" : """15""" },
    { "rate" : """19.5""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """100""" },
    { "rate" : """19""" },
    { "rate" : """20""" },
    { "rate" : """20.5""" },
    { "rate" : """99.999999""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """100""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """50""" },
    { "rate" : """15""" },
    { "rate" : """18""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """19.9""" },
    { "rate" : """0.01""" },
    { "rate" : """15""" },
    { "rate" : """3.9""" },
    { "rate" : """15""" },
    { "rate" : """18""" },
    { "rate" : """15""" },
    { "rate" : """24""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """14.5""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """0.05""" },
    { "rate" : """15""" },
    { "rate" : """14.5""" },
    { "rate" : """14""" },
    { "rate" : """14.9999""" },
    { "rate" : """3.9999999""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """50""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """99.99999""" },
    { "rate" : """19.89999""" },
    { "rate" : """19.9""" },
    { "rate" : """99.99999""" },
    { "rate" : """100""" },
    { "rate" : """100""" },
    { "rate" : """97""" },
    { "rate" : """15""" },
    { "rate" : """14.99999""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """14.9""" },
    { "rate" : """8.99""" },
    { "rate" : """8.99999""" },
    { "rate" : """100""" },
    { "rate" : """1000""" },
    { "rate" : """1000""" },
    { "rate" : """5""" },
    { "rate" : """997""" },
    { "rate" : """0.24999""" },
    { "rate" : """0.24999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """24""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """0.01""" },
    { "rate" : """25""" },
    { "rate" : """12.5""" },
    { "rate" : """14.98765""" },
    { "rate" : """0.01385""" },
    { "rate" : """5.89""" },
    { "rate" : """15""" },
    { "rate" : """0""" },
    { "rate" : """15""" },
    { "rate" : """5.99999""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """0.01""" },
    { "rate" : """5.8999999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """14.9""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """0.04""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """45""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """0.05556""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """0.01""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """35""" },
    { "rate" : """9.65""" },
    { "rate" : """9.99""" },
    { "rate" : """9.5""" },
    { "rate" : """15""" },
    { "rate" : """14.7""" },
    { "rate" : """20.8""" },
    { "rate" : """35""" },
    { "rate" : """0.05555""" },
    { "rate" : """36""" },
    { "rate" : """9.95""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """36""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """35""" },
    { "rate" : """33.5""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """7.9""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """0.05""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """36""" },
    { "rate" : """9.5""" },
    { "rate" : """14""" },
    { "rate" : """14.9""" },
    { "rate" : """5""" },
    { "rate" : """36""" },
    { "rate" : """5""" },
    { "rate" : """36""" },
    { "rate" : """36""" },
    { "rate" : """10""" },
    { "rate" : """36""" },
    { "rate" : """10""" },
    { "rate" : """36""" },
    { "rate" : """20""" },
    { "rate" : """36""" },
    { "rate" : """100""" },
    { "rate" : """5""" },
    { "rate" : """36""" },
    { "rate" : """0.00278""" },
    { "rate" : """0.00278""" },
    { "rate" : """35""" },
    { "rate" : """3.7""" },
    { "rate" : """15""" },
    { "rate" : """36""" },
    { "rate" : """4""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.9""" },
    { "rate" : """36""" },
    { "rate" : """36""" },
    { "rate" : """36""" },
    { "rate" : """21""" },
    { "rate" : """4""" },
    { "rate" : """21""" },
    { "rate" : """21""" },
    { "rate" : """36""" },
    { "rate" : """21""" },
    { "rate" : """4""" },
    { "rate" : """21""" },
    { "rate" : """1""" },
    { "rate" : """36""" },
    { "rate" : """7""" },
    { "rate" : """12.5""" },
    { "rate" : """18""" },
    { "rate" : """3.58""" },
    { "rate" : """13""" },
    { "rate" : """21""" },
    { "rate" : """21""" },
    { "rate" : """21""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """36""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """100""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """21""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """21""" },
    { "rate" : """5""" },
    { "rate" : """22""" },
    { "rate" : """34""" },
    { "rate" : """15""" },
    { "rate" : """21""" },
    { "rate" : """18""" },
    { "rate" : """21""" },
    { "rate" : """3.5""" },
    { "rate" : """4""" },
    { "rate" : """0.2779""" },
    { "rate" : """8.3334""" },
    { "rate" : """8.3334""" },
    { "rate" : """8.3334""" },
    { "rate" : """21""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """20.75""" },
    { "rate" : """3.65""" },
    { "rate" : """21""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """4.15""" },
    { "rate" : """3.99999""" },
    { "rate" : """2.98999""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """5.5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3.95""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """7.2""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """1e-06""" },
    { "rate" : """1e-06""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """4.9""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """40""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """8.5""" },
    { "rate" : """9.5""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """8.99""" },
    { "rate" : """8.99""" },
    { "rate" : """8""" },
    { "rate" : """8.99""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3.9999""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """8.99""" },
    { "rate" : """25.5""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """42""" },
    { "rate" : """42""" },
    { "rate" : """7""" },
    { "rate" : """4.996""" },
    { "rate" : """4.996""" },
    { "rate" : """9""" },
    { "rate" : """42""" },
    { "rate" : """10""" },
    { "rate" : """42""" },
    { "rate" : """42""" },
    { "rate" : """42""" },
    { "rate" : """42""" },
    { "rate" : """10""" },
    { "rate" : """41.9""" },
    { "rate" : """100""" },
    { "rate" : """42""" },
    { "rate" : """7""" },
    { "rate" : """42""" },
    { "rate" : """4.5""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """99.9""" },
    { "rate" : """5""" },
    { "rate" : """8.9""" },
    { "rate" : """4.9""" },
    { "rate" : """7""" },
    { "rate" : """1.7""" },
    { "rate" : """1.89999""" },
    { "rate" : """1.8""" },
    { "rate" : """20""" },
    { "rate" : """1.8""" },
    { "rate" : """1.8""" },
    { "rate" : """1.5""" },
    { "rate" : """1.89998""" },
    { "rate" : """1.69""" },
    { "rate" : """1.5""" },
    { "rate" : """1.9""" },
    { "rate" : """1.9""" },
    { "rate" : """1.89998""" },
    { "rate" : """1.89""" },
    { "rate" : """1.7""" },
    { "rate" : """8""" },
    { "rate" : """5.5""" },
    { "rate" : """4""" },
    { "rate" : """1.75""" },
    { "rate" : """1.8""" },
    { "rate" : """7""" },
    { "rate" : """3.9""" },
    { "rate" : """8""" },
    { "rate" : """1.5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7.999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2.489""" },
    { "rate" : """1""" },
    { "rate" : """2.4""" },
    { "rate" : """2.48""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2.4""" },
    { "rate" : """2.49""" },
    { "rate" : """1""" },
    { "rate" : """2.25""" },
    { "rate" : """1""" },
    { "rate" : """2.24999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.9999999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.975""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """6.9""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8.5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """8.7""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """6.99999""" },
    { "rate" : """10""" },
    { "rate" : """39.9""" },
    { "rate" : """39.99999""" },
    { "rate" : """39.9""" },
    { "rate" : """39.89999""" },
    { "rate" : """0.979""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9""" },
    { "rate" : """40""" },
    { "rate" : """39.9""" },
    { "rate" : """0.98""" },
    { "rate" : """8""" },
    { "rate" : """0.979""" },
    { "rate" : """0.9""" },
    { "rate" : """0.89999""" },
    { "rate" : """40""" },
    { "rate" : """0.5""" },
    { "rate" : """40""" },
    { "rate" : """40""" },
    { "rate" : """0.9""" },
    { "rate" : """0.97899""" },
    { "rate" : """10""" },
    { "rate" : """39""" },
    { "rate" : """10""" },
    { "rate" : """35""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """1.9""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.9999""" },
    { "rate" : """2""" },
    { "rate" : """1.8""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.9""" },
    { "rate" : """1.98999""" },
    { "rate" : """1.9""" },
    { "rate" : """40""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.89""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.889""" },
    { "rate" : """2""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """1.9""" },
    { "rate" : """1.98""" },
    { "rate" : """1.9""" },
    { "rate" : """1.75""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.03""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """0.9""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.98999""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.9999""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """0.99""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """3""" },
    { "rate" : """0.1""" },
    { "rate" : """2.4""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """0.98""" },
    { "rate" : """2.6""" },
    { "rate" : """0.8""" },
    { "rate" : """10""" },
    { "rate" : """0.98""" },
    { "rate" : """0.00972""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """0.01""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """3e-05""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """9""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """9.99""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """8.999999""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """2.1""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.9""" },
    { "rate" : """1.98""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.9""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """0.48999""" },
    { "rate" : """0.5""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """1.9""" },
    { "rate" : """2""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """7.99999""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """0.5""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """1.9""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """6""" },
    { "rate" : """0.4""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """0.4""" },
    { "rate" : """0.25""" },
    { "rate" : """1""" },
    { "rate" : """0.999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1.99999""" },
    { "rate" : """0.9999""" },
    { "rate" : """1""" },
    { "rate" : """20""" },
    { "rate" : """0.1""" },
    { "rate" : """0.5""" },
    { "rate" : """0.95""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """0.5""" },
    { "rate" : """0.98765""" },
    { "rate" : """25""" },
    { "rate" : """0.99""" },
    { "rate" : """8""" },
    { "rate" : """14.5""" },
    { "rate" : """5.999""" },
    { "rate" : """25""" },
    { "rate" : """3""" },
    { "rate" : """0.5""" },
    { "rate" : """1""" },
    { "rate" : """25""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """0.99989""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """7.9999""" },
    { "rate" : """2.5""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """23.9""" },
    { "rate" : """1""" },
    { "rate" : """0.5""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """0.5""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.9999""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """0.5""" },
    { "rate" : """20""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """0.5""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """25""" },
    { "rate" : """0.0499""" },
    { "rate" : """0.5""" },
    { "rate" : """0.99999""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """0.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """25""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """0.9999""" },
    { "rate" : """3""" },
    { "rate" : """0.9999""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """0.499""" },
    { "rate" : """10""" },
    { "rate" : """2.99999""" },
    { "rate" : """7.75""" },
    { "rate" : """0.5""" },
    { "rate" : """0.99999""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """7.99999""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """0.999""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """1.999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """24.9""" },
    { "rate" : """25""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """2.95""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """4.99999""" },
    { "rate" : """1.98""" },
    { "rate" : """5""" },
    { "rate" : """23.9""" },
    { "rate" : """1.98""" },
    { "rate" : """0.49""" },
    { "rate" : """2.7""" },
    { "rate" : """5.5""" },
    { "rate" : """3""" },
    { "rate" : """7.5""" },
    { "rate" : """1.95""" },
    { "rate" : """14.5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """21.8""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """0.5""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """0.5""" },
    { "rate" : """14.99895""" },
    { "rate" : """4""" },
    { "rate" : """4.99895""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """18""" },
    { "rate" : """1.99""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """0.5""" },
    { "rate" : """1.9""" },
    { "rate" : """14.98""" },
    { "rate" : """2.2222""" },
    { "rate" : """1.995""" },
    { "rate" : """0.5""" },
    { "rate" : """18""" },
    { "rate" : """4.6969""" },
    { "rate" : """1""" },
    { "rate" : """0.5""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """0.49999""" },
    { "rate" : """2""" },
    { "rate" : """6.45""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.49999""" },
    { "rate" : """4""" },
    { "rate" : """6.5""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """0.499""" },
    { "rate" : """5.99999""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """6.5""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """24""" },
    { "rate" : """0.5""" },
    { "rate" : """6""" },
    { "rate" : """6.5""" },
    { "rate" : """6.5""" },
    { "rate" : """6.1""" },
    { "rate" : """0.255""" },
    { "rate" : """3.99""" },
    { "rate" : """1.97""" },
    { "rate" : """6.4""" },
    { "rate" : """6.45""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6.5""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """0.49999""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """7.99999""" },
    { "rate" : """6.49999""" },
    { "rate" : """7.9998""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.97""" },
    { "rate" : """3""" },
    { "rate" : """2.99999""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """18""" },
    { "rate" : """3""" },
    { "rate" : """1.75""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """14.5""" },
    { "rate" : """3.99""" },
    { "rate" : """4.99""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2.99997""" },
    { "rate" : """2""" },
    { "rate" : """16""" },
    { "rate" : """0.97""" },
    { "rate" : """1""" },
    { "rate" : """4.8""" },
    { "rate" : """2.99997""" },
    { "rate" : """8.9""" },
    { "rate" : """2.9""" },
    { "rate" : """5""" },
    { "rate" : """0.95""" },
    { "rate" : """19.99999""" },
    { "rate" : """2.79998""" },
    { "rate" : """3""" },
    { "rate" : """17""" },
    { "rate" : """2""" },
    { "rate" : """0.96999""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """19.9""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """4.99999""" },
    { "rate" : """1.98""" },
    { "rate" : """15""" },
    { "rate" : """18""" },
    { "rate" : """1""" },
    { "rate" : """15.99""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """18""" },
    { "rate" : """4.99999""" },
    { "rate" : """14.99999""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.99998""" },
    { "rate" : """4.9""" },
    { "rate" : """14""" },
    { "rate" : """1.89998""" },
    { "rate" : """24""" },
    { "rate" : """0.6""" },
    { "rate" : """0.6""" },
    { "rate" : """25""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """2.5""" },
    { "rate" : """0.6""" },
    { "rate" : """0.8""" },
    { "rate" : """14""" },
    { "rate" : """0.6""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """2.99997""" },
    { "rate" : """0.59999""" },
    { "rate" : """15""" },
    { "rate" : """0.6""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """2.99999""" },
    { "rate" : """25""" },
    { "rate" : """0.5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """0.6""" },
    { "rate" : """0.6""" },
    { "rate" : """0.6""" },
    { "rate" : """10""" },
    { "rate" : """2.99999""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """2.99""" },
    { "rate" : """14.99999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.999""" },
    { "rate" : """14""" },
    { "rate" : """22""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """0.65""" },
    { "rate" : """0.6""" },
    { "rate" : """0.9""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """0.6""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """7.49999""" },
    { "rate" : """0.59999""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """1.99998""" },
    { "rate" : """1.99998""" },
    { "rate" : """1.99999""" },
    { "rate" : """9.8""" },
    { "rate" : """7.9""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2.99996""" },
    { "rate" : """0.97""" },
    { "rate" : """0.8""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """0.6""" },
    { "rate" : """1.95""" },
    { "rate" : """0.6""" },
    { "rate" : """0.9""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """0.96895""" },
    { "rate" : """3.9""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """0.9999""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """3.99999""" },
    { "rate" : """2.99""" },
    { "rate" : """5""" },
    { "rate" : """0.969""" },
    { "rate" : """14.8""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """0.25""" },
    { "rate" : """5""" },
    { "rate" : """3.98""" },
    { "rate" : """20""" },
    { "rate" : """3.99999""" },
    { "rate" : """10""" },
    { "rate" : """0.96999""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """0.9""" },
    { "rate" : """20""" },
    { "rate" : """4""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.9999""" },
    { "rate" : """4.5""" },
    { "rate" : """0.8""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """19""" },
    { "rate" : """19.99999""" },
    { "rate" : """0.99""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """0.25""" },
    { "rate" : """3.98""" },
    { "rate" : """17""" },
    { "rate" : """15""" },
    { "rate" : """3.79""" },
    { "rate" : """14""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """19.99999""" },
    { "rate" : """8""" },
    { "rate" : """25""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.999""" },
    { "rate" : """12""" },
    { "rate" : """3.99999""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """19.9""" },
    { "rate" : """0.95""" },
    { "rate" : """4""" },
    { "rate" : """3.888""" },
    { "rate" : """2.5""" },
    { "rate" : """15.5""" },
    { "rate" : """0.89""" },
    { "rate" : """3.8""" },
    { "rate" : """13""" },
    { "rate" : """9.7""" },
    { "rate" : """0.9""" },
    { "rate" : """4""" },
    { "rate" : """6.99""" },
    { "rate" : """3.749""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """0.98""" },
    { "rate" : """15""" },
    { "rate" : """3.49""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """3.99""" },
    { "rate" : """4.99""" },
    { "rate" : """4.9898""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """3.99998""" },
    { "rate" : """4""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """0.9""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """0.99""" },
    { "rate" : """4.99""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4.9999""" },
    { "rate" : """3.99""" },
    { "rate" : """14""" },
    { "rate" : """3.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """0.99998""" },
    { "rate" : """12""" },
    { "rate" : """3.97""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """3.99999""" },
    { "rate" : """4""" },
    { "rate" : """11""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """8.5""" },
    { "rate" : """4""" },
    { "rate" : """3.9""" },
    { "rate" : """0.85""" },
    { "rate" : """4""" },
    { "rate" : """1.06""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """3.99999""" },
    { "rate" : """12.9""" },
    { "rate" : """9.9""" },
    { "rate" : """7.7""" },
    { "rate" : """14.99999""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """3.99""" },
    { "rate" : """4""" },
    { "rate" : """3.49""" },
    { "rate" : """3.9""" },
    { "rate" : """3.99999""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4.6""" },
    { "rate" : """4.99""" },
    { "rate" : """3.99999""" },
    { "rate" : """5""" },
    { "rate" : """3.9999""" },
    { "rate" : """3.49999""" },
    { "rate" : """5.8""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """4.9""" },
    { "rate" : """14""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """14.99999""" },
    { "rate" : """8.99989""" },
    { "rate" : """14.9""" },
    { "rate" : """18""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """19.89""" },
    { "rate" : """3""" },
    { "rate" : """2.99""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """10.99895""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """3.49985""" },
    { "rate" : """3.5""" },
    { "rate" : """3.498""" },
    { "rate" : """2.999""" },
    { "rate" : """4.99895""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """3.49999""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """11""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """9.9""" },
    { "rate" : """12""" },
    { "rate" : """3.9""" },
    { "rate" : """10""" },
    { "rate" : """3.8""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """1.5""" },
    { "rate" : """9.5""" },
    { "rate" : """3.9""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """5.9""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5.89999""" },
    { "rate" : """5.9""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """9.9999""" },
    { "rate" : """3""" },
    { "rate" : """5.99999""" },
    { "rate" : """5.99999""" },
    { "rate" : """6""" },
    { "rate" : """5.9999""" },
    { "rate" : """9.5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5.88""" },
    { "rate" : """9.99""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """5.99""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5.9""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4.4""" },
    { "rate" : """5.5""" },
    { "rate" : """7""" },
    { "rate" : """5.99998""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2.99999""" },
    { "rate" : """7""" },
    { "rate" : """4.4""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """11""" },
    { "rate" : """5.9""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """2.9""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """5.88""" },
    { "rate" : """9.5""" },
    { "rate" : """8""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.9999""" },
    { "rate" : """1.5""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """2.5""" },
    { "rate" : """5.99999""" },
    { "rate" : """9.9""" },
    { "rate" : """2.49999""" },
    { "rate" : """2.49999""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """2.5""" },
    { "rate" : """2.9""" },
    { "rate" : """5""" },
    { "rate" : """9.99895""" },
    { "rate" : """2.99999""" },
    { "rate" : """2.5""" },
    { "rate" : """5.99999""" },
    { "rate" : """2.5""" },
    { "rate" : """5.99998""" },
    { "rate" : """2.499""" },
    { "rate" : """5""" },
    { "rate" : """2.99999""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """5.99""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """2.4999""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5.7""" },
    { "rate" : """3""" },
    { "rate" : """2.5""" },
    { "rate" : """6""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """8.9""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """2.499""" },
    { "rate" : """9.99""" },
    { "rate" : """3.7""" },
    { "rate" : """2.999""" },
    { "rate" : """3""" },
    { "rate" : """6.7""" },
    { "rate" : """2.49989""" },
    { "rate" : """2.4""" },
    { "rate" : """5.5""" },
    { "rate" : """2.5""" },
    { "rate" : """2.9999""" },
    { "rate" : """0.7""" },
    { "rate" : """5.5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """9.9999""" },
    { "rate" : """10""" },
    { "rate" : """5.9""" },
    { "rate" : """2.4999""" },
    { "rate" : """2.37""" },
    { "rate" : """2""" },
    { "rate" : """2.489""" },
    { "rate" : """8.98""" },
    { "rate" : """2.989""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6.99999""" },
    { "rate" : """6""" },
    { "rate" : """2.5""" },
    { "rate" : """2.49""" },
    { "rate" : """2.49985""" },
    { "rate" : """3""" },
    { "rate" : """4.95""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """1.5""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """3.5""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """2.5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """2.49999""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """8.9999""" },
    { "rate" : """6""" },
    { "rate" : """7.9999""" },
    { "rate" : """1.75""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """9.99999""" },
    { "rate" : """5.99999""" },
    { "rate" : """4""" },
    { "rate" : """6.9999""" },
    { "rate" : """7""" },
    { "rate" : """7.9999""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """9.93""" },
    { "rate" : """7""" },
    { "rate" : """1.74""" },
    { "rate" : """5.98""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """2.99""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """4.875""" },
    { "rate" : """2.5""" },
    { "rate" : """2.99999""" },
    { "rate" : """3.5""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """2.999""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """5.5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2.999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2.99999""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """2.999""" },
    { "rate" : """2.99999""" },
    { "rate" : """2.99999""" },
    { "rate" : """6""" },
    { "rate" : """1.999""" },
    { "rate" : """4.25""" },
    { "rate" : """5""" },
    { "rate" : """1.98""" },
    { "rate" : """0.25""" },
    { "rate" : """3.4""" },
    { "rate" : """9.9999""" },
    { "rate" : """4.97""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """14.99""" },
    { "rate" : """5""" },
    { "rate" : """8.99""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """7.7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5.99999""" },
    { "rate" : """3.5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """2.99""" },
    { "rate" : """7""" },
    { "rate" : """6.99""" },
    { "rate" : """7.99""" },
    { "rate" : """2""" },
    { "rate" : """4.8""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """7.66667""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """6.99999""" },
    { "rate" : """2.75""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """6.9""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """18.5""" },
    { "rate" : """20""" },
    { "rate" : """3.5""" },
    { "rate" : """2.4""" },
    { "rate" : """7.9999""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """2""" },
    { "rate" : """4.3""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """5.9""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.93939""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """0.8""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9.8""" },
    { "rate" : """4.99989""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """2.99999""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """5.5""" },
    { "rate" : """7""" },
    { "rate" : """2.93""" },
    { "rate" : """5.95""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """3.12""" },
    { "rate" : """3.99999""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3.995""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """3.6""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """7.99999""" },
    { "rate" : """19.9999""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """5.9""" },
    { "rate" : """1.9""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """5.89""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1.75""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """4.99""" },
    { "rate" : """4.99""" },
    { "rate" : """0.999""" },
    { "rate" : """4.998""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """6.7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1.2""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.7""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """1.99999""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """1.99999""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5.6""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """9.875""" },
    { "rate" : """1.5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """1.8""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """8.99895""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """4.985""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """4.99""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """2""" },
    { "rate" : """0.99""" },
    { "rate" : """7""" },
    { "rate" : """5.99999""" },
    { "rate" : """2""" },
    { "rate" : """5.99999""" },
    { "rate" : """1.75""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """5.5""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.9999""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """9.75""" },
    { "rate" : """1.8""" },
    { "rate" : """10""" },
    { "rate" : """1.8""" },
    { "rate" : """7.9""" },
    { "rate" : """5""" },
    { "rate" : """7.999""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """1.6""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1.75""" },
    { "rate" : """1.99999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """9.9999""" },
    { "rate" : """2""" },
    { "rate" : """9.9999""" },
    { "rate" : """1.95""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.99999""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """1.999""" },
    { "rate" : """9.99999""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """2""" },
    { "rate" : """3.5""" },
    { "rate" : """9.5""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """1.9""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """1.99""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5.9""" },
    { "rate" : """2""" },
    { "rate" : """4.9999""" },
    { "rate" : """10""" },
    { "rate" : """1.75""" },
    { "rate" : """3.5""" },
    { "rate" : """9.99""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """3.5""" },
    { "rate" : """1""" },
    { "rate" : """1.99""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6.85""" },
    { "rate" : """6.75""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """0.999""" },
    { "rate" : """1.7""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """5.98""" },
    { "rate" : """10""" },
    { "rate" : """4.98""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.9999""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """1.9999""" },
    { "rate" : """6.9999""" },
    { "rate" : """6""" },
    { "rate" : """1.9""" },
    { "rate" : """5.99999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """5.85""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """14.9999""" },
    { "rate" : """4.985""" },
    { "rate" : """11""" },
    { "rate" : """5.99999""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7.7""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.89999""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """1.7""" },
    { "rate" : """5""" },
    { "rate" : """5.4""" },
    { "rate" : """1.5""" },
    { "rate" : """5.25""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """6.9""" },
    { "rate" : """5.99999""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """6.99999""" },
    { "rate" : """7.3""" },
    { "rate" : """6.99995""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """1.99999""" },
    { "rate" : """14.99999""" },
    { "rate" : """1.95""" },
    { "rate" : """3.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """4.97""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6.25""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """1.99""" },
    { "rate" : """5.5""" },
    { "rate" : """2""" },
    { "rate" : """4.9393""" },
    { "rate" : """1.9393""" },
    { "rate" : """5.5""" },
    { "rate" : """6""" },
    { "rate" : """4.99999""" },
    { "rate" : """1.71""" },
    { "rate" : """7""" },
    { "rate" : """5.5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """7""" },
    { "rate" : """4.99999""" },
    { "rate" : """5.5""" },
    { "rate" : """2""" },
    { "rate" : """1.999""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """7.5""" },
    { "rate" : """2""" },
    { "rate" : """4.9""" },
    { "rate" : """2""" },
    { "rate" : """4.9""" },
    { "rate" : """6""" },
    { "rate" : """5.4""" },
    { "rate" : """1.99998""" },
    { "rate" : """6.99998""" },
    { "rate" : """1.99""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """1.4""" },
    { "rate" : """4.99999""" },
    { "rate" : """2""" },
    { "rate" : """0.25""" },
    { "rate" : """1.99999""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """6.5""" },
    { "rate" : """2""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """6.999""" },
    { "rate" : """1.999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """7.5""" },
    { "rate" : """5""" },
    { "rate" : """1.99998""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """6.99999""" },
    { "rate" : """2""" },
    { "rate" : """4.93939""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """6.995""" },
    { "rate" : """0.5""" },
    { "rate" : """3.5""" },
    { "rate" : """0.49999""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """7.4""" },
    { "rate" : """4.8""" },
    { "rate" : """6.5""" },
    { "rate" : """6.99999""" },
    { "rate" : """0.49999""" },
    { "rate" : """1.99999""" },
    { "rate" : """5""" },
    { "rate" : """0.49989""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """1.99""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.98499""" },
    { "rate" : """9.99999""" },
    { "rate" : """1.99""" },
    { "rate" : """5.99""" },
    { "rate" : """1.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """6.9""" },
    { "rate" : """1.999""" },
    { "rate" : """5""" },
    { "rate" : """1.75""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """1.999""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7.99999""" },
    { "rate" : """8""" },
    { "rate" : """4.99989""" },
    { "rate" : """4.9999""" },
    { "rate" : """6.49998""" },
    { "rate" : """4.99895""" },
    { "rate" : """5.49995""" },
    { "rate" : """1.98""" },
    { "rate" : """9.9""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """6.9999""" },
    { "rate" : """7""" },
    { "rate" : """3.99998""" },
    { "rate" : """3.99997""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """3.9999""" },
    { "rate" : """1.99""" },
    { "rate" : """5""" },
    { "rate" : """3.9999""" },
    { "rate" : """3.9""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """6""" },
    { "rate" : """5.8""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5.5""" },
    { "rate" : """6""" },
    { "rate" : """5.99998""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5.99998""" },
    { "rate" : """5.99999""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """3.93939""" },
    { "rate" : """5""" },
    { "rate" : """7.5""" },
    { "rate" : """2.99""" },
    { "rate" : """5.99""" },
    { "rate" : """9.89998""" },
    { "rate" : """0.9999""" },
    { "rate" : """5.5""" },
    { "rate" : """5""" },
    { "rate" : """7.99""" },
    { "rate" : """5.5""" },
    { "rate" : """6""" },
    { "rate" : """5.5""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """6.5""" },
    { "rate" : """5.4899""" },
    { "rate" : """5""" },
    { "rate" : """5.5""" },
    { "rate" : """0.9998""" },
    { "rate" : """5.999""" },
    { "rate" : """5.5""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """1.999""" },
    { "rate" : """11.88888""" },
    { "rate" : """3.5""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """7.93939""" },
    { "rate" : """5.5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3.5""" },
    { "rate" : """1""" },
    { "rate" : """7.5""" },
    { "rate" : """13""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """2.99999""" },
    { "rate" : """12""" },
    { "rate" : """5.5""" },
    { "rate" : """11""" },
    { "rate" : """2""" },
    { "rate" : """4.5""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """14""" },
    { "rate" : """11""" },
    { "rate" : """8""" },
    { "rate" : """0.19444""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """3.99""" },
    { "rate" : """4.5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """14.999""" },
    { "rate" : """2""" },
    { "rate" : """4.9525""" },
    { "rate" : """6""" },
    { "rate" : """5.5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """8.999""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """5.49999""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """1.99999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """5.5""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5.5""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """8.9""" },
    { "rate" : """4""" },
    { "rate" : """1.9999""" },
    { "rate" : """3""" },
    { "rate" : """3.99999""" },
    { "rate" : """7""" },
    { "rate" : """3.4""" },
    { "rate" : """13.9""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """9.9999""" },
    { "rate" : """2""" },
    { "rate" : """0.1""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """0.1989""" },
    { "rate" : """2.99999""" },
    { "rate" : """5.5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """5.5""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """1.2""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """5.5""" },
    { "rate" : """2""" },
    { "rate" : """3.5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """1.75""" },
    { "rate" : """9.75""" },
    { "rate" : """9""" },
    { "rate" : """7.9""" },
    { "rate" : """5.9595""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """5""" },
    { "rate" : """9.99""" },
    { "rate" : """0.19""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """8.99""" },
    { "rate" : """8.96""" },
    { "rate" : """8.99999""" },
    { "rate" : """9""" },
    { "rate" : """8.99999""" },
    { "rate" : """1.75""" },
    { "rate" : """10""" },
    { "rate" : """9.98""" },
    { "rate" : """15""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """4.99999""" },
    { "rate" : """9.723""" },
    { "rate" : """0.25""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """3.12""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """3.5""" },
    { "rate" : """2""" },
    { "rate" : """6.25""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9.875""" },
    { "rate" : """5.5""" },
    { "rate" : """2.93939""" },
    { "rate" : """5.8""" },
    { "rate" : """5""" },
    { "rate" : """7.8""" },
    { "rate" : """17""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """0.14""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """14.99999""" },
    { "rate" : """34""" },
    { "rate" : """33.99999""" },
    { "rate" : """14.99999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5.5""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """13.67""" },
    { "rate" : """1.99999""" },
    { "rate" : """6""" },
    { "rate" : """4.9""" },
    { "rate" : """11""" },
    { "rate" : """11""" },
    { "rate" : """14.9999""" },
    { "rate" : """2""" },
    { "rate" : """6.9""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """5.9""" },
    { "rate" : """5""" },
    { "rate" : """1.999""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """4.5""" },
    { "rate" : """3.95""" },
    { "rate" : """4""" },
    { "rate" : """11""" },
    { "rate" : """19""" },
    { "rate" : """15""" },
    { "rate" : """3.99999""" },
    { "rate" : """5.25""" },
    { "rate" : """17.5""" },
    { "rate" : """13.8""" },
    { "rate" : """3.5""" },
    { "rate" : """12.9999""" },
    { "rate" : """2.99999""" },
    { "rate" : """14.9""" },
    { "rate" : """3.99999""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """14.99999""" },
    { "rate" : """7""" },
    { "rate" : """7.5""" },
    { "rate" : """9.8""" },
    { "rate" : """3.9999""" },
    { "rate" : """9.9999""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """3.99999""" },
    { "rate" : """14""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """14""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """9.5""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """14.99""" },
    { "rate" : """12.99985""" },
    { "rate" : """13""" },
    { "rate" : """7.7""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """3.99999""" },
    { "rate" : """5.75""" },
    { "rate" : """3.5""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """12.9""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """14.95""" },
    { "rate" : """4""" },
    { "rate" : """2.93939""" },
    { "rate" : """14""" },
    { "rate" : """12.5""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """3.5""" },
    { "rate" : """14.99""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """15.99999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7.9""" },
    { "rate" : """9.5""" },
    { "rate" : """3.5""" },
    { "rate" : """15.88888""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """13""" },
    { "rate" : """4""" },
    { "rate" : """3.49999""" },
    { "rate" : """13""" },
    { "rate" : """15""" },
    { "rate" : """13""" },
    { "rate" : """9.89999""" },
    { "rate" : """10""" },
    { "rate" : """2.99""" },
    { "rate" : """10""" },
    { "rate" : """2.99999""" },
    { "rate" : """9""" },
    { "rate" : """9.999""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """7.5""" },
    { "rate" : """9.9999""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """4.5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """3.9""" },
    { "rate" : """14.99""" },
    { "rate" : """0.19444""" },
    { "rate" : """13""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """9.9""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5.99""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """1.5""" },
    { "rate" : """7.5""" },
    { "rate" : """9.5""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """17""" },
    { "rate" : """0.199""" },
    { "rate" : """10""" },
    { "rate" : """14.85""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """0.99999""" },
    { "rate" : """3""" },
    { "rate" : """1.98""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """18""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """3.95""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """8.33333""" },
    { "rate" : """12.95""" },
    { "rate" : """9.99985""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """12.5""" },
    { "rate" : """7.9999""" },
    { "rate" : """4.99999""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """13""" },
    { "rate" : """9.99""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """7.99999""" },
    { "rate" : """12""" },
    { "rate" : """3""" },
    { "rate" : """11""" },
    { "rate" : """7""" },
    { "rate" : """8.5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """4.6""" },
    { "rate" : """13""" },
    { "rate" : """13.9""" },
    { "rate" : """3.499""" },
    { "rate" : """3.33""" },
    { "rate" : """9""" },
    { "rate" : """7.5""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """5.99""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """5.93939""" },
    { "rate" : """3.8888""" },
    { "rate" : """7.5""" },
    { "rate" : """7.8888""" },
    { "rate" : """5.8888""" },
    { "rate" : """3.49999""" },
    { "rate" : """3.5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """7.5""" },
    { "rate" : """9""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """14.99""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """9.5""" },
    { "rate" : """9.7547""" },
    { "rate" : """15""" },
    { "rate" : """9.9""" },
    { "rate" : """4.75""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.15""" },
    { "rate" : """10""" },
    { "rate" : """14.8""" },
    { "rate" : """8""" },
    { "rate" : """0.17""" },
    { "rate" : """8""" },
    { "rate" : """8.5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """3.49""" },
    { "rate" : """9""" },
    { "rate" : """3.49999""" },
    { "rate" : """9.999""" },
    { "rate" : """3.5""" },
    { "rate" : """8""" },
    { "rate" : """7.99""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """12.5""" },
    { "rate" : """10""" },
    { "rate" : """9.5""" },
    { "rate" : """8.41667""" },
    { "rate" : """14.9999""" },
    { "rate" : """9.9""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """7.7""" },
    { "rate" : """10""" },
    { "rate" : """4.6""" },
    { "rate" : """13.99999""" },
    { "rate" : """19.44444""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """11.66667""" },
    { "rate" : """4.5""" },
    { "rate" : """7""" },
    { "rate" : """4.6""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.19444""" },
    { "rate" : """7.99999""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """11""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """4.999""" },
    { "rate" : """14""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """5.899""" },
    { "rate" : """7.49""" },
    { "rate" : """6""" },
    { "rate" : """9.88""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """7.5""" },
    { "rate" : """9.79""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """9.75""" },
    { "rate" : """6.9""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """4.5""" },
    { "rate" : """20""" },
    { "rate" : """5.998""" },
    { "rate" : """5.99895""" },
    { "rate" : """6.99""" },
    { "rate" : """10""" },
    { "rate" : """5.99999""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """16""" },
    { "rate" : """6""" },
    { "rate" : """5.75""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """9.5""" },
    { "rate" : """5.99""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """5.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """7""" },
    { "rate" : """6.9""" },
    { "rate" : """5.99999""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """6""" },
    { "rate" : """5.75""" },
    { "rate" : """6.95""" },
    { "rate" : """6""" },
    { "rate" : """5.96""" },
    { "rate" : """7""" },
    { "rate" : """6.96""" },
    { "rate" : """6.99999""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5.9""" },
    { "rate" : """7""" },
    { "rate" : """5.99999""" },
    { "rate" : """6""" },
    { "rate" : """6.99999""" },
    { "rate" : """5.49""" },
    { "rate" : """4.5""" },
    { "rate" : """6""" },
    { "rate" : """5.9""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """4.8""" },
    { "rate" : """3""" },
    { "rate" : """6.98""" },
    { "rate" : """5.99999""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """5.999""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """9.999""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5.95""" },
    { "rate" : """9""" },
    { "rate" : """5.95""" },
    { "rate" : """6.95""" },
    { "rate" : """12""" },
    { "rate" : """5.9""" },
    { "rate" : """12""" },
    { "rate" : """3""" },
    { "rate" : """19""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """6.99999""" },
    { "rate" : """8.33333""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9.9999""" },
    { "rate" : """4.5""" },
    { "rate" : """5.75""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5.8""" },
    { "rate" : """10""" },
    { "rate" : """1.999""" },
    { "rate" : """1.99999""" },
    { "rate" : """4""" },
    { "rate" : """5.99""" },
    { "rate" : """5.99""" },
    { "rate" : """5.9""" },
    { "rate" : """9.9""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """11""" },
    { "rate" : """2""" },
    { "rate" : """7.77778""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """17.9""" },
    { "rate" : """19.95""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """1.99999""" },
    { "rate" : """5""" },
    { "rate" : """5.54321""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """5.99""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """5.75""" },
    { "rate" : """5.2""" },
    { "rate" : """10""" },
    { "rate" : """6.8""" },
    { "rate" : """5.9""" },
    { "rate" : """4.7""" },
    { "rate" : """11""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """6.99""" },
    { "rate" : """12""" },
    { "rate" : """13""" },
    { "rate" : """6""" },
    { "rate" : """4.9""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5.95""" },
    { "rate" : """4.5""" },
    { "rate" : """6""" },
    { "rate" : """4.5""" },
    { "rate" : """5.99""" },
    { "rate" : """7""" },
    { "rate" : """2.99999""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """1.5""" },
    { "rate" : """6""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """4.8""" },
    { "rate" : """8""" },
    { "rate" : """5.99999""" },
    { "rate" : """7""" },
    { "rate" : """4.99895""" },
    { "rate" : """5.49985""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5.9""" },
    { "rate" : """5.9""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """13.99""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """8.5""" },
    { "rate" : """5.9""" },
    { "rate" : """9.5""" },
    { "rate" : """5.9""" },
    { "rate" : """6""" },
    { "rate" : """5.99999""" },
    { "rate" : """6""" },
    { "rate" : """5.9999""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """12.75""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """8.69999""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """2.99""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """1.97""" },
    { "rate" : """1.94444""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """7""" },
    { "rate" : """1.975""" },
    { "rate" : """0.18999""" },
    { "rate" : """1.99""" },
    { "rate" : """6""" },
    { "rate" : """1.99999""" },
    { "rate" : """1""" },
    { "rate" : """7.98""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """9.99999""" },
    { "rate" : """6.89999""" },
    { "rate" : """14""" },
    { "rate" : """9.88888""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """0.194""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5.96""" },
    { "rate" : """4.75""" },
    { "rate" : """7.45""" },
    { "rate" : """5""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """9.4""" },
    { "rate" : """9.7""" },
    { "rate" : """0.95""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4.75""" },
    { "rate" : """0.97""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """7.98""" },
    { "rate" : """11.998""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8.5""" },
    { "rate" : """0.99""" },
    { "rate" : """6""" },
    { "rate" : """0.6969""" },
    { "rate" : """0.88""" },
    { "rate" : """0.9999""" },
    { "rate" : """6""" },
    { "rate" : """2.99""" },
    { "rate" : """3""" },
    { "rate" : """5.2""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """6.99""" },
    { "rate" : """5.77""" },
    { "rate" : """4.9""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """7.98""" },
    { "rate" : """4.5""" },
    { "rate" : """4.9""" },
    { "rate" : """9.75""" },
    { "rate" : """10""" },
    { "rate" : """5.625""" },
    { "rate" : """13.8999""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """9.9""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """4.999""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """5.875""" },
    { "rate" : """6""" },
    { "rate" : """9.99999""" },
    { "rate" : """7.9""" },
    { "rate" : """10""" },
    { "rate" : """6.5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """8.5""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3.99999""" },
    { "rate" : """4""" },
    { "rate" : """3.99999""" },
    { "rate" : """3.99999""" },
    { "rate" : """9.9""" },
    { "rate" : """9""" },
    { "rate" : """13.99999""" },
    { "rate" : """8.5""" },
    { "rate" : """14""" },
    { "rate" : """7.77777""" },
    { "rate" : """12.99999""" },
    { "rate" : """6.9999""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """4.75""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """9.9""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """2.9""" },
    { "rate" : """4.99999""" },
    { "rate" : """7.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """6""" },
    { "rate" : """2.99999""" },
    { "rate" : """5""" },
    { "rate" : """2.9""" },
    { "rate" : """2.998""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """5.9999""" },
    { "rate" : """2.5""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """4.2""" },
    { "rate" : """4.6""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """3.99""" },
    { "rate" : """3.99999""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """7.999""" },
    { "rate" : """9.99999""" },
    { "rate" : """10.999""" },
    { "rate" : """5.999""" },
    { "rate" : """4.7""" },
    { "rate" : """3.999""" },
    { "rate" : """4.5""" },
    { "rate" : """6""" },
    { "rate" : """14""" },
    { "rate" : """6""" },
    { "rate" : """7.97""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """7.99999""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """7.99999""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """5.99999""" },
    { "rate" : """5.89""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6.99999""" },
    { "rate" : """5""" },
    { "rate" : """5.99""" },
    { "rate" : """5.99999""" },
    { "rate" : """6.66""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """11.998""" },
    { "rate" : """5.99989""" },
    { "rate" : """3.75""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """2.72222""" },
    { "rate" : """11.88888""" },
    { "rate" : """8.5""" },
    { "rate" : """5.83333""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.88888""" },
    { "rate" : """5.95""" },
    { "rate" : """13.5""" },
    { "rate" : """11.5""" },
    { "rate" : """4.9""" },
    { "rate" : """1""" },
    { "rate" : """9.9""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """1.5""" },
    { "rate" : """0.99""" },
    { "rate" : """0.888""" },
    { "rate" : """6.88""" },
    { "rate" : """17""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """6.99999""" },
    { "rate" : """1""" },
    { "rate" : """4.99""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """1.75""" },
    { "rate" : """1""" },
    { "rate" : """10.5""" },
    { "rate" : """0.99""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.99999""" },
    { "rate" : """9.998""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """0.88""" },
    { "rate" : """0.88895""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """2.99999""" },
    { "rate" : """7""" },
    { "rate" : """19.95""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """10""" },
    { "rate" : """9.98""" },
    { "rate" : """20""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """9.5""" },
    { "rate" : """6.5""" },
    { "rate" : """2.99999""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """2.99998""" },
    { "rate" : """2.6""" },
    { "rate" : """6""" },
    { "rate" : """9.99""" },
    { "rate" : """2.75""" },
    { "rate" : """11.99999""" },
    { "rate" : """9.5""" },
    { "rate" : """10.5""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """9.4""" },
    { "rate" : """8.5""" },
    { "rate" : """2.65""" },
    { "rate" : """8""" },
    { "rate" : """3.975""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """10.25""" },
    { "rate" : """7.5""" },
    { "rate" : """2.94""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """22""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """10.99999""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """8.36844""" },
    { "rate" : """14""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """5.57024""" },
    { "rate" : """11""" },
    { "rate" : """12.80348""" },
    { "rate" : """10""" },
    { "rate" : """5.41891""" },
    { "rate" : """11""" },
    { "rate" : """10.73991""" },
    { "rate" : """7.5""" },
    { "rate" : """10""" },
    { "rate" : """4.05384""" },
    { "rate" : """11""" },
    { "rate" : """5.51642""" },
    { "rate" : """7""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """5.5""" },
    { "rate" : """6.889""" },
    { "rate" : """14""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """1.5""" },
    { "rate" : """1""" },
    { "rate" : """14""" },
    { "rate" : """7""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """1.5""" },
    { "rate" : """11""" },
    { "rate" : """1.5""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """5.99999""" },
    { "rate" : """10""" },
    { "rate" : """1.5""" },
    { "rate" : """10""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """1.5""" },
    { "rate" : """5""" },
    { "rate" : """1.399""" },
    { "rate" : """1.4""" },
    { "rate" : """11.5""" },
    { "rate" : """4""" },
    { "rate" : """7.987""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """3.99""" },
    { "rate" : """3.88""" },
    { "rate" : """4""" },
    { "rate" : """10.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """9.9""" },
    { "rate" : """4.999""" },
    { "rate" : """7.99999""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5.95""" },
    { "rate" : """9.95""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """5.30833""" },
    { "rate" : """6.88""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """4.99""" },
    { "rate" : """9.9""" },
    { "rate" : """4.7""" },
    { "rate" : """4.5""" },
    { "rate" : """2""" },
    { "rate" : """3.98""" },
    { "rate" : """2.5""" },
    { "rate" : """12""" },
    { "rate" : """17""" },
    { "rate" : """3.9""" },
    { "rate" : """17.99999""" },
    { "rate" : """4""" },
    { "rate" : """13""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """13.99""" },
    { "rate" : """13.9""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """5.99999""" },
    { "rate" : """11""" },
    { "rate" : """4.95""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """5.78""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """3.99999""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.96354""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """4""" },
    { "rate" : """13""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3.9""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """14""" },
    { "rate" : """9.99999""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """17""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4.4""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """14""" },
    { "rate" : """3.8""" },
    { "rate" : """4""" },
    { "rate" : """3.99999""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """6.9999""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """14""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """3.75""" },
    { "rate" : """6.95""" },
    { "rate" : """14.75""" },
    { "rate" : """14""" },
    { "rate" : """6""" },
    { "rate" : """9.9""" },
    { "rate" : """13.99999""" },
    { "rate" : """3.99""" },
    { "rate" : """4""" },
    { "rate" : """4.999""" },
    { "rate" : """3.99""" },
    { "rate" : """5.5""" },
    { "rate" : """2.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.45648""" },
    { "rate" : """9.45""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """14""" },
    { "rate" : """6""" },
    { "rate" : """11""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """4.99895""" },
    { "rate" : """4.99895""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8.88888""" },
    { "rate" : """6""" },
    { "rate" : """9.9""" },
    { "rate" : """6""" },
    { "rate" : """6.8""" },
    { "rate" : """10.9""" },
    { "rate" : """10.9""" },
    { "rate" : """13.49""" },
    { "rate" : """5.99999""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """3.5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """3.8""" },
    { "rate" : """4.9999""" },
    { "rate" : """11.375""" },
    { "rate" : """12.25""" },
    { "rate" : """5""" },
    { "rate" : """11.99999""" },
    { "rate" : """14""" },
    { "rate" : """4""" },
    { "rate" : """11.55""" },
    { "rate" : """5.899""" },
    { "rate" : """6.99999""" },
    { "rate" : """13.99999""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """5.9""" },
    { "rate" : """10.99999""" },
    { "rate" : """7.599""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """6.99""" },
    { "rate" : """10.88888""" },
    { "rate" : """6""" },
    { "rate" : """8.33333""" },
    { "rate" : """3.5""" },
    { "rate" : """13.999""" },
    { "rate" : """11""" },
    { "rate" : """7.7""" },
    { "rate" : """10""" },
    { "rate" : """19""" },
    { "rate" : """8.75""" },
    { "rate" : """19""" },
    { "rate" : """5""" },
    { "rate" : """5.5""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """14""" },
    { "rate" : """12""" },
    { "rate" : """6.99""" },
    { "rate" : """14""" },
    { "rate" : """4""" },
    { "rate" : """19.8""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """5.88""" },
    { "rate" : """6""" },
    { "rate" : """9.5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5.5""" },
    { "rate" : """6""" },
    { "rate" : """2.99895""" },
    { "rate" : """10""" },
    { "rate" : """5.99999""" },
    { "rate" : """6.06666""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6.5""" },
    { "rate" : """5.99895""" },
    { "rate" : """10""" },
    { "rate" : """4.9999""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """6.9999""" },
    { "rate" : """14""" },
    { "rate" : """4""" },
    { "rate" : """5.9""" },
    { "rate" : """10.5""" },
    { "rate" : """4""" },
    { "rate" : """6.9""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """1.3552""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """5.5""" },
    { "rate" : """4""" },
    { "rate" : """12.75""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """11.99999""" },
    { "rate" : """6.99""" },
    { "rate" : """1.5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5.9999""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """11""" },
    { "rate" : """5.9""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """6.5""" },
    { "rate" : """5.5555""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """3.99999""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """6.01""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """4.5""" },
    { "rate" : """4.5""" },
    { "rate" : """4.899""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6.999""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """6.8888""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """5.1""" },
    { "rate" : """6""" },
    { "rate" : """2.99""" },
    { "rate" : """13.99999""" },
    { "rate" : """18.9""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """2.8""" },
    { "rate" : """11.2896""" },
    { "rate" : """3""" },
    { "rate" : """4.5""" },
    { "rate" : """7.7""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """8.33333""" },
    { "rate" : """7.25826""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """2.99999""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """2.999""" },
    { "rate" : """11""" },
    { "rate" : """6.8""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """5.9""" },
    { "rate" : """7""" },
    { "rate" : """4.9""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """1.98""" },
    { "rate" : """3""" },
    { "rate" : """10.99""" },
    { "rate" : """1.99999""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """7.7""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """5.2""" },
    { "rate" : """2.9""" },
    { "rate" : """9.8""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """11""" },
    { "rate" : """12.5""" },
    { "rate" : """12.5""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """1.999""" },
    { "rate" : """1.98""" },
    { "rate" : """2.999""" },
    { "rate" : """4.999""" },
    { "rate" : """1.99999""" },
    { "rate" : """15""" },
    { "rate" : """1.999""" },
    { "rate" : """9.999""" },
    { "rate" : """7.5""" },
    { "rate" : """4.9999""" },
    { "rate" : """6.999""" },
    { "rate" : """5.9999""" },
    { "rate" : """4.999""" },
    { "rate" : """9.9999""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """11""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """6.125""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """4.988""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """11""" },
    { "rate" : """2.99999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.97""" },
    { "rate" : """11.98889""" },
    { "rate" : """4.99999""" },
    { "rate" : """2.99999""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """2.9""" },
    { "rate" : """1.99""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """4.5""" },
    { "rate" : """4.99895""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """2.99999""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6.98""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """4.9777""" },
    { "rate" : """5""" },
    { "rate" : """5.06643""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """4.99999""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5.99""" },
    { "rate" : """15""" },
    { "rate" : """5.99999""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """4.99""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.999""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """5.9""" },
    { "rate" : """4.9""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """14.99""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """4.5""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """5.9""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """14.98889""" },
    { "rate" : """14.9753""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """9.5""" },
    { "rate" : """4.8""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """5.9""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5.99999""" },
    { "rate" : """5.99895""" },
    { "rate" : """4.99999""" },
    { "rate" : """15""" },
    { "rate" : """3.998""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """4.9""" },
    { "rate" : """14.8""" },
    { "rate" : """4.5""" },
    { "rate" : """14.8""" },
    { "rate" : """14.99999""" },
    { "rate" : """6""" },
    { "rate" : """4.99999""" },
    { "rate" : """3.5""" },
    { "rate" : """5.99999""" },
    { "rate" : """4.85""" },
    { "rate" : """8""" },
    { "rate" : """6.99999""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """4.999""" },
    { "rate" : """4.999""" },
    { "rate" : """8.99999""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """6.99999""" },
    { "rate" : """2.99999""" },
    { "rate" : """6.999""" },
    { "rate" : """6.8888""" },
    { "rate" : """5""" },
    { "rate" : """1.5""" },
    { "rate" : """6.66667""" },
    { "rate" : """6""" },
    { "rate" : """4.5""" },
    { "rate" : """6""" },
    { "rate" : """4.2""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """9""" },
    { "rate" : """6.599""" },
    { "rate" : """8""" },
    { "rate" : """7.999""" },
    { "rate" : """7.99999""" },
    { "rate" : """7.99895""" },
    { "rate" : """6""" },
    { "rate" : """7.99998""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """4.7""" },
    { "rate" : """5.75""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """4.99""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """4.9""" },
    { "rate" : """4.9""" },
    { "rate" : """4.5""" },
    { "rate" : """6.89""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """4.9""" },
    { "rate" : """11.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.95""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9.99""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5.99""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """6.9""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """4.9999""" },
    { "rate" : """5.999""" },
    { "rate" : """5""" },
    { "rate" : """11.5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5.9""" },
    { "rate" : """6.86""" },
    { "rate" : """6.9""" },
    { "rate" : """5.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """6.49999""" },
    { "rate" : """6.99999""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """4.6""" },
    { "rate" : """5.95""" },
    { "rate" : """6.999""" },
    { "rate" : """4.9""" },
    { "rate" : """4.998""" },
    { "rate" : """4.9999""" },
    { "rate" : """5""" },
    { "rate" : """11.5""" },
    { "rate" : """5""" },
    { "rate" : """6.8""" },
    { "rate" : """5""" },
    { "rate" : """9.9""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """4.9999""" },
    { "rate" : """5.98888""" },
    { "rate" : """4.95""" },
    { "rate" : """1.9999""" },
    { "rate" : """5""" },
    { "rate" : """2.9999""" },
    { "rate" : """9.999""" },
    { "rate" : """1.9999""" },
    { "rate" : """1.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """9.98""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5.99""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """9""" },
    { "rate" : """3.5""" },
    { "rate" : """5.99999""" },
    { "rate" : """5""" },
    { "rate" : """7.69""" },
    { "rate" : """14.99""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """6.97""" },
    { "rate" : """10.99""" },
    { "rate" : """8.9""" },
    { "rate" : """14""" },
    { "rate" : """5.999""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5.99998""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """5.999""" },
    { "rate" : """5.99998""" },
    { "rate" : """5.99""" },
    { "rate" : """10""" },
    { "rate" : """5.5""" },
    { "rate" : """8.888""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """11.99""" },
    { "rate" : """11""" },
    { "rate" : """3""" },
    { "rate" : """4.9999""" },
    { "rate" : """4.9999""" },
    { "rate" : """14""" },
    { "rate" : """5.99999""" },
    { "rate" : """5.99999""" },
    { "rate" : """6""" },
    { "rate" : """4.99999""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """9.99999""" },
    { "rate" : """4.16667""" },
    { "rate" : """7.6""" },
    { "rate" : """10""" },
    { "rate" : """12.5""" },
    { "rate" : """9.999""" },
    { "rate" : """13.9999""" },
    { "rate" : """29""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """13.99895""" },
    { "rate" : """9.99895""" },
    { "rate" : """5.99895""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """6.9""" },
    { "rate" : """5""" },
    { "rate" : """9.99""" },
    { "rate" : """5.9""" },
    { "rate" : """12""" },
    { "rate" : """11""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """11.99""" },
    { "rate" : """12.9""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """7.99999""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """9.5""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """11""" },
    { "rate" : """11""" },
    { "rate" : """7.8""" },
    { "rate" : """7""" },
    { "rate" : """12.9""" },
    { "rate" : """7.68""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """6.9999""" },
    { "rate" : """7.99""" },
    { "rate" : """2.9999""" },
    { "rate" : """4.99999""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6.8""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """14""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """9.99999""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """11.85""" },
    { "rate" : """4.9""" },
    { "rate" : """10.99""" },
    { "rate" : """13.9""" },
    { "rate" : """11.9999""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """11.98889""" },
    { "rate" : """5.5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """5.5""" },
    { "rate" : """30""" },
    { "rate" : """5""" },
    { "rate" : """5.5""" },
    { "rate" : """5""" },
    { "rate" : """9.9""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """5.3""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """9.99""" },
    { "rate" : """4.99""" },
    { "rate" : """5.49""" },
    { "rate" : """5""" },
    { "rate" : """9.99""" },
    { "rate" : """9.998""" },
    { "rate" : """13.89""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4.99988""" },
    { "rate" : """9.98""" },
    { "rate" : """5""" },
    { "rate" : """5.97""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """6.999""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """4.5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """5.4""" },
    { "rate" : """9.9999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """14.95""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """14.9999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """14.999""" },
    { "rate" : """2.8""" },
    { "rate" : """1.5""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """11.9""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """0.55""" },
    { "rate" : """0.75""" },
    { "rate" : """14.8""" },
    { "rate" : """15""" },
    { "rate" : """4.5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """14.99895""" },
    { "rate" : """2""" },
    { "rate" : """0.78""" },
    { "rate" : """1.999""" },
    { "rate" : """1.95""" },
    { "rate" : """0.49""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """9.99999""" },
    { "rate" : """2""" },
    { "rate" : """9.99895""" },
    { "rate" : """11""" },
    { "rate" : """13.8""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """0.5""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6.5""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """1.99999""" },
    { "rate" : """9.99""" },
    { "rate" : """7.99""" },
    { "rate" : """14.99999""" },
    { "rate" : """1.95""" },
    { "rate" : """15""" },
    { "rate" : """8.5""" },
    { "rate" : """9.99""" },
    { "rate" : """14.95""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """1.999""" },
    { "rate" : """14.999""" },
    { "rate" : """6""" },
    { "rate" : """14.998""" },
    { "rate" : """15""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """6.98""" },
    { "rate" : """8.98889""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """0.75""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """5.5""" },
    { "rate" : """13.83333""" },
    { "rate" : """11.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """14.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.73""" },
    { "rate" : """15""" },
    { "rate" : """0.4""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """2.5""" },
    { "rate" : """4.5""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """0.3""" },
    { "rate" : """6""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """0.3""" },
    { "rate" : """11.9""" },
    { "rate" : """14.5""" },
    { "rate" : """6.5""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """9.75""" },
    { "rate" : """9""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """5.99""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """1.5""" },
    { "rate" : """9.5""" },
    { "rate" : """9.99999""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """14.5""" },
    { "rate" : """6.399""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """14.9""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """9.9999""" },
    { "rate" : """0.3""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """0.3""" },
    { "rate" : """9""" },
    { "rate" : """9.98889""" },
    { "rate" : """0.29""" },
    { "rate" : """4.99999""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """9.85""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """13.75""" },
    { "rate" : """0.3""" },
    { "rate" : """14.99999""" },
    { "rate" : """4""" },
    { "rate" : """0.29985""" },
    { "rate" : """9.99999""" },
    { "rate" : """8""" },
    { "rate" : """7.99""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """14.79""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """30""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """11.9999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """9.35714""" },
    { "rate" : """11""" },
    { "rate" : """0.25""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """14.9""" },
    { "rate" : """6""" },
    { "rate" : """9.5""" },
    { "rate" : """14.98""" },
    { "rate" : """6.75""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """7.99""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """9.5""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """17""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """5.5""" },
    { "rate" : """12""" },
    { "rate" : """0.29999""" },
    { "rate" : """5.9""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """2.4""" },
    { "rate" : """0.75""" },
    { "rate" : """19""" },
    { "rate" : """14""" },
    { "rate" : """2.9""" },
    { "rate" : """4.5""" },
    { "rate" : """9.9""" },
    { "rate" : """6.125""" },
    { "rate" : """4.875""" },
    { "rate" : """5""" },
    { "rate" : """0.998""" },
    { "rate" : """0.279""" },
    { "rate" : """5""" },
    { "rate" : """30""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """13""" },
    { "rate" : """4.9""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """13""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """0.3""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """0.975""" },
    { "rate" : """5.5""" },
    { "rate" : """1""" },
    { "rate" : """6.999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """0.99999""" },
    { "rate" : """6""" },
    { "rate" : """16""" },
    { "rate" : """13.95""" },
    { "rate" : """15""" },
    { "rate" : """0.3""" },
    { "rate" : """0.98999""" },
    { "rate" : """0.9975""" },
    { "rate" : """5.8""" },
    { "rate" : """5.999""" },
    { "rate" : """0.3""" },
    { "rate" : """5.99895""" },
    { "rate" : """5.8""" },
    { "rate" : """17.50505""" },
    { "rate" : """20""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """5.9""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """5.9""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """0.7""" },
    { "rate" : """5.9""" },
    { "rate" : """10""" },
    { "rate" : """9.85""" },
    { "rate" : """14.9""" },
    { "rate" : """16""" },
    { "rate" : """15""" },
    { "rate" : """0.999""" },
    { "rate" : """15""" },
    { "rate" : """5.98""" },
    { "rate" : """14.76""" },
    { "rate" : """6""" },
    { "rate" : """5.9999""" },
    { "rate" : """6""" },
    { "rate" : """14.99999""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """18""" },
    { "rate" : """0.28""" },
    { "rate" : """14""" },
    { "rate" : """5.99999""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """0.89""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5.998""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """11""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """14.9999""" },
    { "rate" : """5.83333""" },
    { "rate" : """6.66""" },
    { "rate" : """10""" },
    { "rate" : """5.97""" },
    { "rate" : """5.9999""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """4.99999""" },
    { "rate" : """5.99989""" },
    { "rate" : """5.9""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5.99""" },
    { "rate" : """0.98""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """0.98""" },
    { "rate" : """5.7""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """5.9""" },
    { "rate" : """5.5""" },
    { "rate" : """9.89""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """14.99995""" },
    { "rate" : """19.5""" },
    { "rate" : """14.99999""" },
    { "rate" : """15""" },
    { "rate" : """4.5""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """0.3""" },
    { "rate" : """20""" },
    { "rate" : """5.9""" },
    { "rate" : """9.98""" },
    { "rate" : """5.89""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """0.3""" },
    { "rate" : """18""" },
    { "rate" : """15""" },
    { "rate" : """5.75""" },
    { "rate" : """4.625""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """4.7""" },
    { "rate" : """7.99999""" },
    { "rate" : """5.89999""" },
    { "rate" : """5""" },
    { "rate" : """5.9""" },
    { "rate" : """14.998""" },
    { "rate" : """7.99999""" },
    { "rate" : """17.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """5.99999""" },
    { "rate" : """5.9""" },
    { "rate" : """5.85""" },
    { "rate" : """6.9""" },
    { "rate" : """13""" },
    { "rate" : """5.99999""" },
    { "rate" : """0.3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3.9""" },
    { "rate" : """1.5""" },
    { "rate" : """1.77""" },
    { "rate" : """1.83""" },
    { "rate" : """15""" },
    { "rate" : """5.98889""" },
    { "rate" : """5.98889""" },
    { "rate" : """1.6""" },
    { "rate" : """5.99999""" },
    { "rate" : """6.4""" },
    { "rate" : """5""" },
    { "rate" : """7.9""" },
    { "rate" : """20""" },
    { "rate" : """5.9999""" },
    { "rate" : """3.33""" },
    { "rate" : """15""" },
    { "rate" : """5.99""" },
    { "rate" : """5.8""" },
    { "rate" : """5""" },
    { "rate" : """5.99""" },
    { "rate" : """0.23""" },
    { "rate" : """7.99999""" },
    { "rate" : """5.99999""" },
    { "rate" : """14.99999""" },
    { "rate" : """0.3""" },
    { "rate" : """8""" },
    { "rate" : """7.9""" },
    { "rate" : """14.9""" },
    { "rate" : """9.99""" },
    { "rate" : """4.95""" },
    { "rate" : """5.9995""" },
    { "rate" : """16.42""" },
    { "rate" : """8""" },
    { "rate" : """13.89""" },
    { "rate" : """8""" },
    { "rate" : """6.66""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """6.75""" },
    { "rate" : """10""" },
    { "rate" : """5.9""" },
    { "rate" : """7.99999""" },
    { "rate" : """7.999""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """13.99995""" },
    { "rate" : """0.49999""" },
    { "rate" : """7.998""" },
    { "rate" : """8.8""" },
    { "rate" : """7.8""" },
    { "rate" : """20""" },
    { "rate" : """7.99995""" },
    { "rate" : """0.69444""" },
    { "rate" : """0.49999""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """0.3""" },
    { "rate" : """4""" },
    { "rate" : """0.5915""" },
    { "rate" : """4""" },
    { "rate" : """9.999""" },
    { "rate" : """4""" },
    { "rate" : """0.5""" },
    { "rate" : """12""" },
    { "rate" : """20""" },
    { "rate" : """4""" },
    { "rate" : """3.99""" },
    { "rate" : """4.86111""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """12.5""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """12.5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """12.49999""" },
    { "rate" : """12.5""" },
    { "rate" : """7""" },
    { "rate" : """12.5""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """12.4""" },
    { "rate" : """6.666""" },
    { "rate" : """11.999""" },
    { "rate" : """7.99895""" },
    { "rate" : """9.98""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """3""" },
    { "rate" : """6.99""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """9.99""" },
    { "rate" : """5.8""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """7.69999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """17""" },
    { "rate" : """2.99""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """12.38""" },
    { "rate" : """3""" },
    { "rate" : """4.99""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """7.9""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """0.99999""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """2.98888""" },
    { "rate" : """7""" },
    { "rate" : """7.98889""" },
    { "rate" : """2.9""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """5.9""" },
    { "rate" : """7.9998""" },
    { "rate" : """7.8""" },
    { "rate" : """12""" },
    { "rate" : """8.95""" },
    { "rate" : """12.25""" },
    { "rate" : """18""" },
    { "rate" : """8""" },
    { "rate" : """7.5""" },
    { "rate" : """7.5""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """7.999""" },
    { "rate" : """8""" },
    { "rate" : """11.75""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """0.3""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """0.3""" },
    { "rate" : """16""" },
    { "rate" : """3.5""" },
    { "rate" : """8""" },
    { "rate" : """2.99998""" },
    { "rate" : """3.4""" },
    { "rate" : """10""" },
    { "rate" : """19.99999""" },
    { "rate" : """3""" },
    { "rate" : """34""" },
    { "rate" : """2""" },
    { "rate" : """11.9""" },
    { "rate" : """6""" },
    { "rate" : """2.5""" },
    { "rate" : """2""" },
    { "rate" : """5.99""" },
    { "rate" : """2.99""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """2.98""" },
    { "rate" : """7.9999""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """3.33""" },
    { "rate" : """0.98""" },
    { "rate" : """2.99999""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """9.5""" },
    { "rate" : """3.49""" },
    { "rate" : """0.3""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """7.5""" },
    { "rate" : """5""" },
    { "rate" : """2.99""" },
    { "rate" : """7.5""" },
    { "rate" : """9.95""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """3.74984""" },
    { "rate" : """3.5""" },
    { "rate" : """4.5""" },
    { "rate" : """0.75""" },
    { "rate" : """3.4999""" },
    { "rate" : """20""" },
    { "rate" : """19.99999""" },
    { "rate" : """19""" },
    { "rate" : """7.45""" },
    { "rate" : """15""" },
    { "rate" : """0.3""" },
    { "rate" : """18.99999""" },
    { "rate" : """19.99999""" },
    { "rate" : """7.7""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """19.9999""" },
    { "rate" : """1""" },
    { "rate" : """9.99999""" },
    { "rate" : """4.9""" },
    { "rate" : """0.299""" },
    { "rate" : """6""" },
    { "rate" : """0.97""" },
    { "rate" : """0.95""" },
    { "rate" : """11""" },
    { "rate" : """1""" },
    { "rate" : """14.5""" },
    { "rate" : """12""" },
    { "rate" : """12.45""" },
    { "rate" : """14.9999""" },
    { "rate" : """8""" },
    { "rate" : """9.99999""" },
    { "rate" : """15""" },
    { "rate" : """0.97989""" },
    { "rate" : """0.3""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """4.5""" },
    { "rate" : """4""" },
    { "rate" : """5.5""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """5.99999""" },
    { "rate" : """14.9999""" },
    { "rate" : """8""" },
    { "rate" : """5.9""" },
    { "rate" : """4.5""" },
    { "rate" : """0.9""" },
    { "rate" : """6""" },
    { "rate" : """0.29998""" },
    { "rate" : """5.99998""" },
    { "rate" : """15""" },
    { "rate" : """14.99""" },
    { "rate" : """4.5""" },
    { "rate" : """5.99""" },
    { "rate" : """0.5""" },
    { "rate" : """4.5""" },
    { "rate" : """7""" },
    { "rate" : """0.75""" },
    { "rate" : """4.4998""" },
    { "rate" : """4.5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """0.9""" },
    { "rate" : """12.4""" },
    { "rate" : """15""" },
    { "rate" : """0.2""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """14""" },
    { "rate" : """2.8""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """7""" },
    { "rate" : """0.5""" },
    { "rate" : """8.5""" },
    { "rate" : """3.99""" },
    { "rate" : """12.49999""" },
    { "rate" : """12""" },
    { "rate" : """0.85""" },
    { "rate" : """0.8""" },
    { "rate" : """0.3""" },
    { "rate" : """3""" },
    { "rate" : """14.9999""" },
    { "rate" : """3.99999""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """3.9""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """4.5""" },
    { "rate" : """11""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """1.75""" },
    { "rate" : """11.4999""" },
    { "rate" : """1.5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """2.85""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """3.99""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """11.98889""" },
    { "rate" : """0.9""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """20""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """0.9""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """7.999""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """3.88889""" },
    { "rate" : """4.5""" },
    { "rate" : """12.4999""" },
    { "rate" : """3.9""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """15.56345""" },
    { "rate" : """9.96219""" },
    { "rate" : """8""" },
    { "rate" : """3.9""" },
    { "rate" : """4.9""" },
    { "rate" : """14""" },
    { "rate" : """4""" },
    { "rate" : """8.9""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """11""" },
    { "rate" : """3.9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7.9""" },
    { "rate" : """7.99989""" },
    { "rate" : """3.91999""" },
    { "rate" : """7.9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """9.99889""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """9.99999""" },
    { "rate" : """4""" },
    { "rate" : """9.999""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """7.85""" },
    { "rate" : """9.88""" },
    { "rate" : """6""" },
    { "rate" : """4.5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """9.5""" },
    { "rate" : """5.5""" },
    { "rate" : """1.4""" },
    { "rate" : """9.9""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """8.33333""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """9.7""" },
    { "rate" : """10""" },
    { "rate" : """0.05556""" },
    { "rate" : """4.5""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """0.41667""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """3.9""" },
    { "rate" : """8""" },
    { "rate" : """0.48608""" },
    { "rate" : """3""" },
    { "rate" : """9.5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """25""" },
    { "rate" : """10.5""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """3.7505""" },
    { "rate" : """2""" },
    { "rate" : """4.49985""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.9999""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.98888""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """4.5""" },
    { "rate" : """1.75""" },
    { "rate" : """4""" },
    { "rate" : """1.99506""" },
    { "rate" : """25""" },
    { "rate" : """8.33333""" },
    { "rate" : """8.33333""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """4.5""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """1.75""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """3.99""" },
    { "rate" : """8""" },
    { "rate" : """2.999""" },
    { "rate" : """2.999""" },
    { "rate" : """4.5""" },
    { "rate" : """2.9""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """3.9""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """2.5""" },
    { "rate" : """3.99999""" },
    { "rate" : """1""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """1""" },
    { "rate" : """2.9""" },
    { "rate" : """10""" },
    { "rate" : """1.5""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """0.33333""" },
    { "rate" : """2.999""" },
    { "rate" : """2.49999""" },
    { "rate" : """2.49999""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """1.5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """0.6969""" },
    { "rate" : """1""" },
    { "rate" : """0.9999""" },
    { "rate" : """4.5""" },
    { "rate" : """9.88888""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """4.99""" },
    { "rate" : """9.5""" },
    { "rate" : """9.9""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """0.5""" },
    { "rate" : """7""" },
    { "rate" : """6.5""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """9.9999""" },
    { "rate" : """4""" },
    { "rate" : """6.82""" },
    { "rate" : """1""" },
    { "rate" : """4.5""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """3.9""" },
    { "rate" : """6.9""" },
    { "rate" : """8""" },
    { "rate" : """9.999""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """6.99999""" },
    { "rate" : """4""" },
    { "rate" : """0.5""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """0.5""" },
    { "rate" : """7""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """0.85""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """4.49999""" },
    { "rate" : """4.4999""" },
    { "rate" : """2.89999""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """2.37901""" },
    { "rate" : """0.5""" },
    { "rate" : """3.9999""" },
    { "rate" : """3.99""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """9.9""" },
    { "rate" : """7""" },
    { "rate" : """3.9""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """0.5""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """9.4""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """3.9""" },
    { "rate" : """7""" },
    { "rate" : """6.999""" },
    { "rate" : """7.5""" },
    { "rate" : """11""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """7.5""" },
    { "rate" : """7.9""" },
    { "rate" : """6.899""" },
    { "rate" : """3.99""" },
    { "rate" : """9.6""" },
    { "rate" : """4.9""" },
    { "rate" : """6.99999""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """3.9""" },
    { "rate" : """1.95""" },
    { "rate" : """0.49""" },
    { "rate" : """3.5""" },
    { "rate" : """7.5""" },
    { "rate" : """10""" },
    { "rate" : """1.94444""" },
    { "rate" : """7.5""" },
    { "rate" : """1.945""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """9.8""" },
    { "rate" : """4""" },
    { "rate" : """2.5""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """0.49""" },
    { "rate" : """7.01""" },
    { "rate" : """1""" },
    { "rate" : """3.998""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """20""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """3.5""" },
    { "rate" : """3""" },
    { "rate" : """2.9""" },
    { "rate" : """10""" },
    { "rate" : """7.9""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """0.5""" },
    { "rate" : """3.99998""" },
    { "rate" : """10""" },
    { "rate" : """3.3""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """8.59""" },
    { "rate" : """8.5""" },
    { "rate" : """9.7""" },
    { "rate" : """2.49""" },
    { "rate" : """4.89""" },
    { "rate" : """13.9""" },
    { "rate" : """4""" },
    { "rate" : """8.75""" },
    { "rate" : """4.9""" },
    { "rate" : """3.8""" },
    { "rate" : """6.75""" },
    { "rate" : """9""" },
    { "rate" : """0.4999""" },
    { "rate" : """4.959""" },
    { "rate" : """6.69""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """3.9999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """6.99999""" },
    { "rate" : """4""" },
    { "rate" : """3.25""" },
    { "rate" : """9""" },
    { "rate" : """1.25""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7.5""" },
    { "rate" : """2.9""" },
    { "rate" : """3.9999""" },
    { "rate" : """6.99989""" },
    { "rate" : """10""" },
    { "rate" : """2.2""" },
    { "rate" : """3.99""" },
    { "rate" : """3.99""" },
    { "rate" : """6.38""" },
    { "rate" : """1""" },
    { "rate" : """3.9999""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """6.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """1""" },
    { "rate" : """5.99""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """0.99""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """0.5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """3.9""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """3.33""" },
    { "rate" : """6.25""" },
    { "rate" : """5""" },
    { "rate" : """3.999""" },
    { "rate" : """1""" },
    { "rate" : """0.99""" },
    { "rate" : """1""" },
    { "rate" : """3.76""" },
    { "rate" : """4.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.95""" },
    { "rate" : """9""" },
    { "rate" : """1.95""" },
    { "rate" : """0.9""" },
    { "rate" : """1""" },
    { "rate" : """0.8""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """0.99""" },
    { "rate" : """10""" },
    { "rate" : """0.99985""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """0.99989""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """5.9""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """3.89999""" },
    { "rate" : """1""" },
    { "rate" : """1.25""" },
    { "rate" : """0.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """0.98""" },
    { "rate" : """8.2""" },
    { "rate" : """4.25""" },
    { "rate" : """0.75""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """1.25""" },
    { "rate" : """2.99999""" },
    { "rate" : """8.99999""" },
    { "rate" : """4""" },
    { "rate" : """2.49""" },
    { "rate" : """0.5""" },
    { "rate" : """0.99999""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2.5""" },
    { "rate" : """1.2""" },
    { "rate" : """1""" },
    { "rate" : """9.5""" },
    { "rate" : """4""" },
    { "rate" : """2.5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2.5""" },
    { "rate" : """0.9""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """2.4""" },
    { "rate" : """2.48""" },
    { "rate" : """2.47989""" },
    { "rate" : """2.499""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2.49""" },
    { "rate" : """2.49""" },
    { "rate" : """3.01""" },
    { "rate" : """5""" },
    { "rate" : """2.49999""" },
    { "rate" : """6.9999""" },
    { "rate" : """2.4""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """3.5""" },
    { "rate" : """2.49999""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """19.99889""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """3.9""" },
    { "rate" : """1""" },
    { "rate" : """20""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """3.999""" },
    { "rate" : """3.9""" },
    { "rate" : """2.2""" },
    { "rate" : """10.75""" },
    { "rate" : """6.9""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """2.5""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """3.75""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """9.86""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """5.43""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """2.39""" },
    { "rate" : """3.5""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """6.99999""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """3.99""" },
    { "rate" : """2.2222""" },
    { "rate" : """5.5555""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """3.89""" },
    { "rate" : """3.99999""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """6.98""" },
    { "rate" : """4""" },
    { "rate" : """4.2""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """5.44942""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """4.86""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """19""" },
    { "rate" : """5""" },
    { "rate" : """4.49999""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """6.25""" },
    { "rate" : """3.99""" },
    { "rate" : """7""" },
    { "rate" : """2.99""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """2.98""" },
    { "rate" : """4.85""" },
    { "rate" : """6.97""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """9.97""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4.4""" },
    { "rate" : """5.99999""" },
    { "rate" : """3""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """29.98""" },
    { "rate" : """9.96""" },
    { "rate" : """6""" },
    { "rate" : """4.99""" },
    { "rate" : """3.99""" },
    { "rate" : """4.975""" },
    { "rate" : """6""" },
    { "rate" : """4.5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """4.61""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """5.7""" },
    { "rate" : """6""" },
    { "rate" : """14.97""" },
    { "rate" : """4.4""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """9.989""" },
    { "rate" : """4.899""" },
    { "rate" : """5.98""" },
    { "rate" : """9.97""" },
    { "rate" : """9.9899""" },
    { "rate" : """5.98""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """9.98""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """25""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """5.9999""" },
    { "rate" : """5.9999""" },
    { "rate" : """5.999""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """1.9999""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """4.5""" },
    { "rate" : """6""" },
    { "rate" : """9.9""" },
    { "rate" : """4.9999""" },
    { "rate" : """5.99999""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """4.99999""" },
    { "rate" : """1.6""" },
    { "rate" : """5.899""" },
    { "rate" : """1.99998""" },
    { "rate" : """1.4999""" },
    { "rate" : """3.9998""" },
    { "rate" : """4.95""" },
    { "rate" : """3.9""" },
    { "rate" : """1.98""" },
    { "rate" : """4""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.5""" },
    { "rate" : """2.5""" },
    { "rate" : """4""" },
    { "rate" : """5.98""" },
    { "rate" : """15""" },
    { "rate" : """4.9""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """1.5""" },
    { "rate" : """2""" },
    { "rate" : """0.69444""" },
    { "rate" : """0.999""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """0.97""" },
    { "rate" : """0.5""" },
    { "rate" : """2""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """5.9""" },
    { "rate" : """4.99""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """3.99999""" },
    { "rate" : """6.9999""" },
    { "rate" : """1.9""" },
    { "rate" : """4""" },
    { "rate" : """1.9999""" },
    { "rate" : """6.998""" },
    { "rate" : """2.99""" },
    { "rate" : """3""" },
    { "rate" : """1.99""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """6.99999""" },
    { "rate" : """3.98""" },
    { "rate" : """6.75""" },
    { "rate" : """5.99""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """5.9""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """4.9999""" },
    { "rate" : """6""" },
    { "rate" : """6.99""" },
    { "rate" : """7""" },
    { "rate" : """3.999""" },
    { "rate" : """1.999""" },
    { "rate" : """8""" },
    { "rate" : """1.99""" },
    { "rate" : """5""" },
    { "rate" : """1.9""" },
    { "rate" : """4.95""" },
    { "rate" : """5.5""" },
    { "rate" : """3.95""" },
    { "rate" : """6.8""" },
    { "rate" : """7""" },
    { "rate" : """3.8""" },
    { "rate" : """1.99""" },
    { "rate" : """1""" },
    { "rate" : """6.99999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3.9999""" },
    { "rate" : """1""" },
    { "rate" : """0.35""" },
    { "rate" : """0.35""" },
    { "rate" : """0.35""" },
    { "rate" : """0.35""" },
    { "rate" : """0.35""" },
    { "rate" : """0.35""" },
    { "rate" : """4.8""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """0.35""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """5.9""" },
    { "rate" : """4.5""" },
    { "rate" : """4""" },
    { "rate" : """6.9""" },
    { "rate" : """6""" },
    { "rate" : """0.35""" },
    { "rate" : """9.99999""" },
    { "rate" : """5.9""" },
    { "rate" : """6.9""" },
    { "rate" : """4.5""" },
    { "rate" : """0.35""" },
    { "rate" : """2.99999""" },
    { "rate" : """6""" },
    { "rate" : """9.99999""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """3.99999""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """2.5""" },
    { "rate" : """6.98""" },
    { "rate" : """0.35""" },
    { "rate" : """3""" },
    { "rate" : """6.99""" },
    { "rate" : """5.9""" },
    { "rate" : """4.5""" },
    { "rate" : """4.99""" },
    { "rate" : """5.99""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """2.5""" },
    { "rate" : """4.5""" },
    { "rate" : """3.95""" },
    { "rate" : """2.95""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.9999""" },
    { "rate" : """0.35""" },
    { "rate" : """2.5""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """2.48899""" },
    { "rate" : """2.5""" },
    { "rate" : """4.5""" },
    { "rate" : """2.99999""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """0.3""" },
    { "rate" : """3""" },
    { "rate" : """2.98""" },
    { "rate" : """8.7""" },
    { "rate" : """2.99999""" },
    { "rate" : """5.998""" },
    { "rate" : """4.2""" },
    { "rate" : """3.3""" },
    { "rate" : """8.7""" },
    { "rate" : """5.2""" },
    { "rate" : """5.9""" },
    { "rate" : """3.99""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """9.999""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """9.999""" },
    { "rate" : """5.9999""" },
    { "rate" : """4.9999""" },
    { "rate" : """3.999""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """5.9""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5.99999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """0.34989""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5.83333""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """8.9999""" },
    { "rate" : """3""" },
    { "rate" : """9.8888""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """5.99889""" },
    { "rate" : """5.99""" },
    { "rate" : """4.99899""" },
    { "rate" : """9.99899""" },
    { "rate" : """8.7""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """4.86111""" },
    { "rate" : """9""" },
    { "rate" : """3.5""" },
    { "rate" : """9.5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """8.7""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """2.9999""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """9.99""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """3.8""" },
    { "rate" : """2.7""" },
    { "rate" : """3.5""" },
    { "rate" : """2""" },
    { "rate" : """3.3""" },
    { "rate" : """4.2""" },
    { "rate" : """5.91""" },
    { "rate" : """5.83""" },
    { "rate" : """14.5""" },
    { "rate" : """14.9999""" },
    { "rate" : """13.9999""" },
    { "rate" : """8.7""" },
    { "rate" : """10""" },
    { "rate" : """5.9998""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """14.8""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """9.99""" },
    { "rate" : """3.5""" },
    { "rate" : """9.99999""" },
    { "rate" : """2.5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """8.5""" },
    { "rate" : """6.95""" },
    { "rate" : """2.95""" },
    { "rate" : """4.5""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """2.99""" },
    { "rate" : """8.69""" },
    { "rate" : """29.99""" },
    { "rate" : """6.99""" },
    { "rate" : """7.99""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """2.5""" },
    { "rate" : """8.69""" },
    { "rate" : """3""" },
    { "rate" : """3.4""" },
    { "rate" : """2.99""" },
    { "rate" : """9.99""" },
    { "rate" : """2.5""" },
    { "rate" : """2.9""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """14.99""" },
    { "rate" : """8.6999""" },
    { "rate" : """10""" },
    { "rate" : """4.49""" },
    { "rate" : """3.99""" },
    { "rate" : """1.49""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """3.5""" },
    { "rate" : """2.4999""" },
    { "rate" : """9.95219""" },
    { "rate" : """5""" },
    { "rate" : """3.4999""" },
    { "rate" : """10""" },
    { "rate" : """3.999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """3.5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """7""" },
    { "rate" : """2.99""" },
    { "rate" : """7""" },
    { "rate" : """19""" },
    { "rate" : """19""" },
    { "rate" : """6.9""" },
    { "rate" : """6.99""" },
    { "rate" : """4""" },
    { "rate" : """2.99999""" },
    { "rate" : """3.488""" },
    { "rate" : """6.9""" },
    { "rate" : """7""" },
    { "rate" : """4.999""" },
    { "rate" : """2.75""" },
    { "rate" : """10""" },
    { "rate" : """4.99999""" },
    { "rate" : """2.98999""" },
    { "rate" : """6.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """12.75""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.5""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """4.876""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """4.47""" },
    { "rate" : """3.4""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """1.49""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.89999""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """1.5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """14.5""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """1.5""" },
    { "rate" : """3.5""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """4.44444""" },
    { "rate" : """4.99999""" },
    { "rate" : """3.7""" },
    { "rate" : """3.88889""" },
    { "rate" : """4.89899""" },
    { "rate" : """12.5""" },
    { "rate" : """1.94444""" },
    { "rate" : """14""" },
    { "rate" : """9.9""" },
    { "rate" : """13""" },
    { "rate" : """4.8""" },
    { "rate" : """13.8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.95""" },
    { "rate" : """3.5""" },
    { "rate" : """4.9""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.9""" },
    { "rate" : """4.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.98""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.99""" },
    { "rate" : """4.99""" },
    { "rate" : """4.9""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """1.95""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.988""" },
    { "rate" : """3.3""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.86111""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """4.59""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2.9393""" },
    { "rate" : """1.95""" },
    { "rate" : """1.9393""" },
    { "rate" : """2""" },
    { "rate" : """4.98""" },
    { "rate" : """2""" },
    { "rate" : """4.95""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """1.49999""" },
    { "rate" : """4.9""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """1.9599""" },
    { "rate" : """4""" },
    { "rate" : """1.9""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """24""" },
    { "rate" : """10""" },
    { "rate" : """4.99999""" },
    { "rate" : """9.99""" },
    { "rate" : """1.99""" },
    { "rate" : """30""" },
    { "rate" : """4.5""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """4.99989""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """1.999""" },
    { "rate" : """8.99999""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """3.5""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """3.33333""" },
    { "rate" : """6.95""" },
    { "rate" : """6""" },
    { "rate" : """3.38""" },
    { "rate" : """6.56""" },
    { "rate" : """9.48""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """3.5""" },
    { "rate" : """6.9999""" },
    { "rate" : """14.5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """6.9""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """1.989""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """1.9""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """3.5""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """1.99999""" },
    { "rate" : """5.99999""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """9.25""" },
    { "rate" : """15""" },
    { "rate" : """8.9""" },
    { "rate" : """7.16536""" },
    { "rate" : """1.9""" },
    { "rate" : """5.8""" },
    { "rate" : """8""" },
    { "rate" : """1.99""" },
    { "rate" : """1.98998""" },
    { "rate" : """9.99""" },
    { "rate" : """6""" },
    { "rate" : """1.89""" },
    { "rate" : """6""" },
    { "rate" : """5.98""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """1.98999""" },
    { "rate" : """6""" },
    { "rate" : """5.95""" },
    { "rate" : """1.975""" },
    { "rate" : """3.475""" },
    { "rate" : """9.975""" },
    { "rate" : """9.975""" },
    { "rate" : """3.975""" },
    { "rate" : """14.95""" },
    { "rate" : """9.5""" },
    { "rate" : """3.5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """1.99""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8.99""" },
    { "rate" : """4.99""" },
    { "rate" : """3.5""" },
    { "rate" : """14.9""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5.999""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """3.25""" },
    { "rate" : """5""" },
    { "rate" : """3.8""" },
    { "rate" : """12""" },
    { "rate" : """4.3""" },
    { "rate" : """2.7""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1.99""" },
    { "rate" : """13""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """1.95""" },
    { "rate" : """2.5""" },
    { "rate" : """5.9""" },
    { "rate" : """4.99999""" },
    { "rate" : """3.2""" },
    { "rate" : """5.78""" },
    { "rate" : """3.9""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """3.5""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.86""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """1.92""" },
    { "rate" : """2.87""" },
    { "rate" : """4.99""" },
    { "rate" : """1.99998""" },
    { "rate" : """3.33333""" },
    { "rate" : """1.88888""" },
    { "rate" : """6.66666""" },
    { "rate" : """14""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """2.5""" },
    { "rate" : """5.95""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """14.879""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """1.99""" },
    { "rate" : """3.45""" },
    { "rate" : """14.99""" },
    { "rate" : """6""" },
    { "rate" : """5.9""" },
    { "rate" : """2.5""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """2.5875""" },
    { "rate" : """2.868""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """9.5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """14.9""" },
    { "rate" : """4.999""" },
    { "rate" : """14.999""" },
    { "rate" : """13""" },
    { "rate" : """11""" },
    { "rate" : """5.44444""" },
    { "rate" : """4.99""" },
    { "rate" : """15""" },
    { "rate" : """13.99""" },
    { "rate" : """8.99988""" },
    { "rate" : """6""" },
    { "rate" : """3.4995""" },
    { "rate" : """2.8""" },
    { "rate" : """10""" },
    { "rate" : """4.9995""" },
    { "rate" : """9.9995""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """12.99999""" },
    { "rate" : """4.9999""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """3.88889""" },
    { "rate" : """6.1""" },
    { "rate" : """7""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """2.49""" },
    { "rate" : """2.858""" },
    { "rate" : """3.321""" },
    { "rate" : """8""" },
    { "rate" : """8.5""" },
    { "rate" : """14.99""" },
    { "rate" : """9.24""" },
    { "rate" : """7.5""" },
    { "rate" : """10""" },
    { "rate" : """4.99999""" },
    { "rate" : """3.5""" },
    { "rate" : """1.5""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """6.5""" },
    { "rate" : """4.99""" },
    { "rate" : """6""" },
    { "rate" : """5.9""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """3.52""" },
    { "rate" : """3.5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """14""" },
    { "rate" : """4.998""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5.9999""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5.98""" },
    { "rate" : """5""" },
    { "rate" : """2.98""" },
    { "rate" : """2.5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """5.99998""" },
    { "rate" : """3.49""" },
    { "rate" : """6.9""" },
    { "rate" : """6.9""" },
    { "rate" : """6""" },
    { "rate" : """1.5""" },
    { "rate" : """2.79""" },
    { "rate" : """10""" },
    { "rate" : """5.99899""" },
    { "rate" : """5""" },
    { "rate" : """0.05556""" },
    { "rate" : """5""" },
    { "rate" : """7.9999""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """0.05556""" },
    { "rate" : """2.49""" },
    { "rate" : """8""" },
    { "rate" : """0.05561""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49999""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """0.05555""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """0.45""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """15""" },
    { "rate" : """0.49999""" },
    { "rate" : """4.8""" },
    { "rate" : """2.75""" },
    { "rate" : """7.5""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """4.99""" },
    { "rate" : """0.05555""" },
    { "rate" : """11""" },
    { "rate" : """0.05556""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """1.5""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """6.99""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2.75""" },
    { "rate" : """2.49""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.05556""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """0.05""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """1.88888""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """4.9""" },
    { "rate" : """6.66666""" },
    { "rate" : """3.33333""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """1.2""" },
    { "rate" : """2.5""" },
    { "rate" : """1.5""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """3.1""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2.8""" },
    { "rate" : """4.996""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """3.11111""" },
    { "rate" : """7.9""" },
    { "rate" : """4.998""" },
    { "rate" : """3.5""" },
    { "rate" : """20""" },
    { "rate" : """9.4""" },
    { "rate" : """0.05556""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.9""" },
    { "rate" : """3.1""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4.99999""" },
    { "rate" : """15""" },
    { "rate" : """0.0555""" },
    { "rate" : """19.99""" },
    { "rate" : """11""" },
    { "rate" : """4.85""" },
    { "rate" : """5""" },
    { "rate" : """4.9999""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """4.98""" },
    { "rate" : """19.989""" },
    { "rate" : """4.9995""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.1""" },
    { "rate" : """5""" },
    { "rate" : """3.10683""" },
    { "rate" : """3""" },
    { "rate" : """0.05269""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """4.999""" },
    { "rate" : """4.9""" },
    { "rate" : """4.99""" },
    { "rate" : """1.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """2.99999""" },
    { "rate" : """6""" },
    { "rate" : """7.95""" },
    { "rate" : """15""" },
    { "rate" : """14.99""" },
    { "rate" : """14.99999""" },
    { "rate" : """20""" },
    { "rate" : """0.04561""" },
    { "rate" : """0.055""" },
    { "rate" : """3""" },
    { "rate" : """0.054""" },
    { "rate" : """0.05467""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """6.96111""" },
    { "rate" : """6""" },
    { "rate" : """14.99""" },
    { "rate" : """7""" },
    { "rate" : """14.5""" },
    { "rate" : """20""" },
    { "rate" : """3.5""" },
    { "rate" : """3""" },
    { "rate" : """2.45""" },
    { "rate" : """15""" },
    { "rate" : """20""" },
    { "rate" : """13.8""" },
    { "rate" : """14""" },
    { "rate" : """2.48999""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """6.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """14.95""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """14.9999""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """7.99999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """9.998""" },
    { "rate" : """19.5""" },
    { "rate" : """9.9999""" },
    { "rate" : """4.9999""" },
    { "rate" : """7.95""" },
    { "rate" : """20""" },
    { "rate" : """7.95""" },
    { "rate" : """9.9999""" },
    { "rate" : """4.9999""" },
    { "rate" : """9.6""" },
    { "rate" : """3.26667""" },
    { "rate" : """19.9""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """7.99""" },
    { "rate" : """6.99""" },
    { "rate" : """6.99""" },
    { "rate" : """9.999""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """7.8""" },
    { "rate" : """8""" },
    { "rate" : """7.99""" },
    { "rate" : """4.99""" },
    { "rate" : """7""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4.99999""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """7.9""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """9.999""" },
    { "rate" : """9.5""" },
    { "rate" : """9.99""" },
    { "rate" : """9.5""" },
    { "rate" : """7""" },
    { "rate" : """9.5""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """1.5""" },
    { "rate" : """4.99""" },
    { "rate" : """2.99999""" },
    { "rate" : """2.5""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """4.5""" },
    { "rate" : """7.9""" },
    { "rate" : """7.9""" },
    { "rate" : """9.8""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """7.25""" },
    { "rate" : """0.25""" },
    { "rate" : """13.99""" },
    { "rate" : """10""" },
    { "rate" : """6.66666""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """5.4""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """11.98989""" },
    { "rate" : """7.99889""" },
    { "rate" : """2.91667""" },
    { "rate" : """7.99""" },
    { "rate" : """10.566""" },
    { "rate" : """9.5""" },
    { "rate" : """8""" },
    { "rate" : """1.5""" },
    { "rate" : """5""" },
    { "rate" : """12.6""" },
    { "rate" : """5""" },
    { "rate" : """4.8""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """11.5""" },
    { "rate" : """4.99""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """11""" },
    { "rate" : """6""" },
    { "rate" : """4.9""" },
    { "rate" : """7.9""" },
    { "rate" : """12""" },
    { "rate" : """2.91666""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """2.91""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """11.99""" },
    { "rate" : """8.99""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """1.65278""" },
    { "rate" : """1.75""" },
    { "rate" : """3.3""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """14.99999""" },
    { "rate" : """5""" },
    { "rate" : """10.5""" },
    { "rate" : """9.989""" },
    { "rate" : """4.99""" },
    { "rate" : """3.9""" },
    { "rate" : """12""" },
    { "rate" : """8.5""" },
    { "rate" : """5""" },
    { "rate" : """3.2""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """0.375""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """3.11111""" },
    { "rate" : """11""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """4.99998""" },
    { "rate" : """8.34""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """14.9""" },
    { "rate" : """6""" },
    { "rate" : """4.95""" },
    { "rate" : """3""" },
    { "rate" : """0.01""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """14.9999""" },
    { "rate" : """11.9999""" },
    { "rate" : """8""" },
    { "rate" : """13""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5.99999""" },
    { "rate" : """4.5""" },
    { "rate" : """11.9""" },
    { "rate" : """10""" },
    { "rate" : """13.5""" },
    { "rate" : """3.33333""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """9.6""" },
    { "rate" : """9.9""" },
    { "rate" : """4.9""" },
    { "rate" : """12.99""" },
    { "rate" : """14.9999""" },
    { "rate" : """12.999""" },
    { "rate" : """14.4""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """4.99""" },
    { "rate" : """12""" },
    { "rate" : """3.25""" },
    { "rate" : """4""" },
    { "rate" : """4.9""" },
    { "rate" : """7.5""" },
    { "rate" : """14.9""" },
    { "rate" : """12.9""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """4.95""" },
    { "rate" : """4.9999""" },
    { "rate" : """1""" },
    { "rate" : """2.9""" },
    { "rate" : """4.99989""" },
    { "rate" : """2.9""" },
    { "rate" : """1""" },
    { "rate" : """9.5999""" },
    { "rate" : """10""" },
    { "rate" : """2.9""" },
    { "rate" : """5""" },
    { "rate" : """5.1""" },
    { "rate" : """0.9999""" },
    { "rate" : """3""" },
    { "rate" : """1.49""" },
    { "rate" : """6.9""" },
    { "rate" : """5""" },
    { "rate" : """12.5""" },
    { "rate" : """12""" },
    { "rate" : """2.9""" },
    { "rate" : """4.9""" },
    { "rate" : """5.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """7.5""" },
    { "rate" : """5""" },
    { "rate" : """7.5""" },
    { "rate" : """3""" },
    { "rate" : """2.9""" },
    { "rate" : """5""" },
    { "rate" : """1.5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.99""" },
    { "rate" : """4.99999""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """14.9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """20""" },
    { "rate" : """4.99999""" },
    { "rate" : """6""" },
    { "rate" : """1.9888""" },
    { "rate" : """2.90666""" },
    { "rate" : """4.99""" },
    { "rate" : """3.07218""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """1.988""" },
    { "rate" : """5""" },
    { "rate" : """3.11111""" },
    { "rate" : """1.925""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """3.11111""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9.5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """12.5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """1.999""" },
    { "rate" : """4.5""" },
    { "rate" : """8""" },
    { "rate" : """1.5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """3.11111""" },
    { "rate" : """11""" },
    { "rate" : """13.99999""" },
    { "rate" : """1.99999""" },
    { "rate" : """2.91666""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6.5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """9.9999""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """6.9""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """1.9999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """1.99""" },
    { "rate" : """12""" },
    { "rate" : """2.9""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """9.98899""" },
    { "rate" : """1.98799""" },
    { "rate" : """12.5""" },
    { "rate" : """6.25""" },
    { "rate" : """4.98999""" },
    { "rate" : """1.5""" },
    { "rate" : """11""" },
    { "rate" : """4.999""" },
    { "rate" : """4""" },
    { "rate" : """9.9""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """1.99""" },
    { "rate" : """12""" },
    { "rate" : """0.9""" },
    { "rate" : """9.8""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """9.9999""" },
    { "rate" : """1""" },
    { "rate" : """1.5""" },
    { "rate" : """4.7""" },
    { "rate" : """8""" },
    { "rate" : """9.9""" },
    { "rate" : """3.11111""" },
    { "rate" : """4.9""" },
    { "rate" : """1.95""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """7.99""" },
    { "rate" : """2.91666""" },
    { "rate" : """1.999""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """6.5""" },
    { "rate" : """2.9""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """13.5""" },
    { "rate" : """9""" },
    { "rate" : """1.99""" },
    { "rate" : """2""" },
    { "rate" : """4.86""" },
    { "rate" : """3.05""" },
    { "rate" : """10""" },
    { "rate" : """4.98""" },
    { "rate" : """4.8888""" },
    { "rate" : """10""" },
    { "rate" : """14.5""" },
    { "rate" : """5""" },
    { "rate" : """9.99""" },
    { "rate" : """7.99999""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """11""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """7.999""" },
    { "rate" : """4.8""" },
    { "rate" : """4.999""" },
    { "rate" : """6""" },
    { "rate" : """4.1""" },
    { "rate" : """11.5""" },
    { "rate" : """12""" },
    { "rate" : """6.4""" },
    { "rate" : """9.9""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """19.99999""" },
    { "rate" : """1.5""" },
    { "rate" : """11.99""" },
    { "rate" : """7""" },
    { "rate" : """3.1111""" },
    { "rate" : """4.99""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """14.99""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """4.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1""" },
    { "rate" : """4.9""" },
    { "rate" : """11""" },
    { "rate" : """14.9""" },
    { "rate" : """2""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """5""" },
    { "rate" : """4.95""" },
    { "rate" : """4""" },
    { "rate" : """1.45""" },
    { "rate" : """8.5""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """4.35""" },
    { "rate" : """1.5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """1.5""" },
    { "rate" : """1.493""" },
    { "rate" : """10""" },
    { "rate" : """1.5""" },
    { "rate" : """5""" },
    { "rate" : """1.5""" },
    { "rate" : """10""" },
    { "rate" : """1.49""" },
    { "rate" : """7.9""" },
    { "rate" : """10""" },
    { "rate" : """7.8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """8""" },
    { "rate" : """1.49999""" },
    { "rate" : """4.2""" },
    { "rate" : """1.4999""" },
    { "rate" : """8""" },
    { "rate" : """10.99899""" },
    { "rate" : """3.6""" },
    { "rate" : """7""" },
    { "rate" : """1.5""" },
    { "rate" : """13.3""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """1.2345""" },
    { "rate" : """1.49999""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """14""" },
    { "rate" : """7.8""" },
    { "rate" : """10.5""" },
    { "rate" : """4.94""" },
    { "rate" : """10""" },
    { "rate" : """9.9999""" },
    { "rate" : """7""" },
    { "rate" : """6.5""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """4.9""" },
    { "rate" : """10.98899""" },
    { "rate" : """0.99""" },
    { "rate" : """4.99""" },
    { "rate" : """1.5""" },
    { "rate" : """5""" },
    { "rate" : """7.8""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """9.9""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """7.5""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """2.33333""" },
    { "rate" : """4.95""" },
    { "rate" : """3.75""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """13.9""" },
    { "rate" : """8.9""" },
    { "rate" : """8""" },
    { "rate" : """4.8611""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4.9""" },
    { "rate" : """4.99999""" },
    { "rate" : """14.99999""" },
    { "rate" : """1""" },
    { "rate" : """4.5""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """0.9999""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """9.99""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """0.9""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """0.98""" },
    { "rate" : """0.9""" },
    { "rate" : """1.4""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """3.3""" },
    { "rate" : """11""" },
    { "rate" : """4.9""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """5""" },
    { "rate" : """3.3""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """6.6""" },
    { "rate" : """0.6969""" },
    { "rate" : """4.2""" },
    { "rate" : """5""" },
    { "rate" : """0.9999""" },
    { "rate" : """9.9""" },
    { "rate" : """15""" },
    { "rate" : """7.9998""" },
    { "rate" : """0.997""" },
    { "rate" : """5""" },
    { "rate" : """9.9998""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3.999""" },
    { "rate" : """1""" },
    { "rate" : """17.5""" },
    { "rate" : """1""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """3.11111""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """19.9""" },
    { "rate" : """5""" },
    { "rate" : """14.2""" },
    { "rate" : """18.88""" },
    { "rate" : """8.4""" },
    { "rate" : """19.99999""" },
    { "rate" : """10""" },
    { "rate" : """3.999""" },
    { "rate" : """5""" },
    { "rate" : """8.9""" },
    { "rate" : """0.5""" },
    { "rate" : """0.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """18.49999""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """0.2""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.29999""" },
    { "rate" : """10""" },
    { "rate" : """4.9999""" },
    { "rate" : """5""" },
    { "rate" : """13.9""" },
    { "rate" : """14""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.85""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """3.9""" },
    { "rate" : """0.95""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """14""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.99999""" },
    { "rate" : """5.2148""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """0.23456""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """17.379""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """0.95""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """9.5""" },
    { "rate" : """9.9""" },
    { "rate" : """3.1""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """0.99999""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """14""" },
    { "rate" : """14.99""" },
    { "rate" : """10""" },
    { "rate" : """9.8""" },
    { "rate" : """14.8""" },
    { "rate" : """0.99985""" },
    { "rate" : """19.48""" },
    { "rate" : """0.999""" },
    { "rate" : """4.8""" },
    { "rate" : """8.4""" },
    { "rate" : """4""" },
    { "rate" : """0.99999""" },
    { "rate" : """9.8""" },
    { "rate" : """8""" },
    { "rate" : """1.5""" },
    { "rate" : """8""" },
    { "rate" : """3.2""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """9.9""" },
    { "rate" : """0.99""" },
    { "rate" : """19.5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """19.99999""" },
    { "rate" : """8.5""" },
    { "rate" : """11.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """6.5""" },
    { "rate" : """7.9""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """14.99899""" },
    { "rate" : """14.94""" },
    { "rate" : """15""" },
    { "rate" : """0.99989""" },
    { "rate" : """0.5""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """20""" },
    { "rate" : """7.99999""" },
    { "rate" : """7""" },
    { "rate" : """7.99999""" },
    { "rate" : """19""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """19""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """8.5""" },
    { "rate" : """15""" },
    { "rate" : """0.99999""" },
    { "rate" : """10""" },
    { "rate" : """14.99""" },
    { "rate" : """20""" },
    { "rate" : """19.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """14.9999""" },
    { "rate" : """8""" },
    { "rate" : """0.99999""" },
    { "rate" : """14""" },
    { "rate" : """7.999""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """1.5""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """0.9999""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """19.98""" },
    { "rate" : """0.99999""" },
    { "rate" : """19.9""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9.8""" },
    { "rate" : """5""" },
    { "rate" : """19.99999""" },
    { "rate" : """14.9""" },
    { "rate" : """14""" },
    { "rate" : """7.5""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """7.5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """0.2""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """5.5""" },
    { "rate" : """7""" },
    { "rate" : """13.99""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """17""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """13""" },
    { "rate" : """0.55555""" },
    { "rate" : """9.5""" },
    { "rate" : """0.19999""" },
    { "rate" : """0.98""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """18""" },
    { "rate" : """0.8""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4.9999""" },
    { "rate" : """1""" },
    { "rate" : """9.99999""" },
    { "rate" : """14.9""" },
    { "rate" : """0.99999""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """8.4""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """0.9""" },
    { "rate" : """7.99""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5.95""" },
    { "rate" : """0.999""" },
    { "rate" : """12""" },
    { "rate" : """0.99""" },
    { "rate" : """7.5""" },
    { "rate" : """7.55""" },
    { "rate" : """0.9""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """5.5""" },
    { "rate" : """0.9999""" },
    { "rate" : """7.9""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """14""" },
    { "rate" : """2.9""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """2.99999""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.3""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """14.99""" },
    { "rate" : """8""" },
    { "rate" : """13""" },
    { "rate" : """2.8""" },
    { "rate" : """16""" },
    { "rate" : """20""" },
    { "rate" : """1""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """0.9999""" },
    { "rate" : """2.99""" },
    { "rate" : """15""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """11""" },
    { "rate" : """0.5""" },
    { "rate" : """0.99999""" },
    { "rate" : """20""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """20""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """4.99998""" },
    { "rate" : """8.9999""" },
    { "rate" : """6.999""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """2.999""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """7.99999""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """7.9""" },
    { "rate" : """8""" },
    { "rate" : """9.98""" },
    { "rate" : """7.9""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """9.9999""" },
    { "rate" : """9.999""" },
    { "rate" : """1.5""" },
    { "rate" : """0.005""" },
    { "rate" : """3""" },
    { "rate" : """1.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.2""" },
    { "rate" : """20""" },
    { "rate" : """3.4""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """20""" },
    { "rate" : """9.99""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.95""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """20""" },
    { "rate" : """0.99""" },
    { "rate" : """20.2""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """0.75""" },
    { "rate" : """3.11""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """4.9""" },
    { "rate" : """20""" },
    { "rate" : """6.9""" },
    { "rate" : """0.99989""" },
    { "rate" : """0.999""" },
    { "rate" : """20""" },
    { "rate" : """3""" },
    { "rate" : """20""" },
    { "rate" : """2.9984""" },
    { "rate" : """17""" },
    { "rate" : """7.9""" },
    { "rate" : """7.999""" },
    { "rate" : """2.75""" },
    { "rate" : """3.1""" },
    { "rate" : """19.8999""" },
    { "rate" : """2.91667""" },
    { "rate" : """5""" },
    { "rate" : """19.9""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """2.9""" },
    { "rate" : """4.95""" },
    { "rate" : """0.98999""" },
    { "rate" : """6.49999""" },
    { "rate" : """7""" },
    { "rate" : """20""" },
    { "rate" : """18.5""" },
    { "rate" : """4.5""" },
    { "rate" : """3.1""" },
    { "rate" : """1""" },
    { "rate" : """6.49999""" },
    { "rate" : """0.99999""" },
    { "rate" : """18""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """20""" },
    { "rate" : """0.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2.99""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """2.99""" },
    { "rate" : """0.8""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """0.9989""" },
    { "rate" : """0.9898""" },
    { "rate" : """0.75""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """2.99999""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """2.98999""" },
    { "rate" : """3""" },
    { "rate" : """7.5""" },
    { "rate" : """3.1""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """2.99""" },
    { "rate" : """9.99""" },
    { "rate" : """0.99989""" },
    { "rate" : """1""" },
    { "rate" : """0.29""" },
    { "rate" : """0.98""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.9999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.8""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """20""" },
    { "rate" : """1""" },
    { "rate" : """19.99999""" },
    { "rate" : """3.1""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """0.99999""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """18""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """0.7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.9""" },
    { "rate" : """4""" },
    { "rate" : """2.9""" },
    { "rate" : """12""" },
    { "rate" : """20""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """2.998""" },
    { "rate" : """2.9999""" },
    { "rate" : """1""" },
    { "rate" : """18""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """0.75""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.2""" },
    { "rate" : """4.99""" },
    { "rate" : """9.99""" },
    { "rate" : """20""" },
    { "rate" : """1""" },
    { "rate" : """0.299""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """2.4""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """3.2""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2.9999""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.99999""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """4.999""" },
    { "rate" : """20""" },
    { "rate" : """1""" },
    { "rate" : """0.29999""" },
    { "rate" : """1""" },
    { "rate" : """9.99999""" },
    { "rate" : """4.9""" },
    { "rate" : """3""" },
    { "rate" : """20""" },
    { "rate" : """4.5""" },
    { "rate" : """1""" },
    { "rate" : """5.75""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """1""" },
    { "rate" : """20""" },
    { "rate" : """3""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """11.9""" },
    { "rate" : """1""" },
    { "rate" : """17""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """0.998""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """20""" },
    { "rate" : """6.99""" },
    { "rate" : """7.9""" },
    { "rate" : """7""" },
    { "rate" : """3.1""" },
    { "rate" : """7.25""" },
    { "rate" : """3""" },
    { "rate" : """3.11112""" },
    { "rate" : """3.9""" },
    { "rate" : """6.9""" },
    { "rate" : """12""" },
    { "rate" : """0.99999""" },
    { "rate" : """19.999""" },
    { "rate" : """3""" },
    { "rate" : """1.3""" },
    { "rate" : """0.99""" },
    { "rate" : """1""" },
    { "rate" : """1.45""" },
    { "rate" : """1""" },
    { "rate" : """11""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1.19999""" },
    { "rate" : """1.2""" },
    { "rate" : """11.9999""" },
    { "rate" : """0.9""" },
    { "rate" : """7.99999""" },
    { "rate" : """1""" },
    { "rate" : """19.999""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """0.95""" },
    { "rate" : """11.9""" },
    { "rate" : """4.99998""" },
    { "rate" : """1""" },
    { "rate" : """1.1""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.2999""" },
    { "rate" : """19""" },
    { "rate" : """2.91667""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.98""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """1.44""" },
    { "rate" : """15""" },
    { "rate" : """4.599""" },
    { "rate" : """14.99999""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """14.95""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.8""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """14.9""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """14.95""" },
    { "rate" : """3""" },
    { "rate" : """4.5""" },
    { "rate" : """0.99999""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """2.99999""" },
    { "rate" : """19""" },
    { "rate" : """0.91234""" },
    { "rate" : """14.8""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """2.99445""" },
    { "rate" : """0.83333""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """19.99999""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """1.15""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """14""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """19.9""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.9""" },
    { "rate" : """4""" },
    { "rate" : """19""" },
    { "rate" : """1.2""" },
    { "rate" : """0.79""" },
    { "rate" : """0.5""" },
    { "rate" : """0.99999""" },
    { "rate" : """14.5""" },
    { "rate" : """0.75""" },
    { "rate" : """11""" },
    { "rate" : """0.8""" },
    { "rate" : """0.979""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.8999""" },
    { "rate" : """0.9999""" },
    { "rate" : """4.67""" },
    { "rate" : """20""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """0.9988""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """20""" },
    { "rate" : """14""" },
    { "rate" : """13""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """18""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """16""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """24""" },
    { "rate" : """0.9""" },
    { "rate" : """0.75""" },
    { "rate" : """2.5""" },
    { "rate" : """3.99999""" },
    { "rate" : """3.95""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """19.99998""" },
    { "rate" : """2.999""" },
    { "rate" : """7.999""" },
    { "rate" : """6.999""" },
    { "rate" : """10""" },
    { "rate" : """6.99998""" },
    { "rate" : """4""" },
    { "rate" : """0.1""" },
    { "rate" : """3.5""" },
    { "rate" : """20""" },
    { "rate" : """2.5""" },
    { "rate" : """4""" },
    { "rate" : """20""" },
    { "rate" : """6""" },
    { "rate" : """19.99""" },
    { "rate" : """12""" },
    { "rate" : """19.99""" },
    { "rate" : """9.8""" },
    { "rate" : """20""" },
    { "rate" : """7""" },
    { "rate" : """17.5""" },
    { "rate" : """4.7""" },
    { "rate" : """1.25""" },
    { "rate" : """1.4999""" },
    { "rate" : """6.99981""" },
    { "rate" : """19.999""" },
    { "rate" : """4""" },
    { "rate" : """7.99999""" },
    { "rate" : """3.99999""" },
    { "rate" : """14.99999""" },
    { "rate" : """5""" },
    { "rate" : """19.999""" },
    { "rate" : """1.49""" },
    { "rate" : """11.99""" },
    { "rate" : """3.99""" },
    { "rate" : """6.9999""" },
    { "rate" : """11.99998""" },
    { "rate" : """1""" },
    { "rate" : """6.99999""" },
    { "rate" : """1""" },
    { "rate" : """3.8""" },
    { "rate" : """5""" },
    { "rate" : """6.99998""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """40""" },
    { "rate" : """3.5""" },
    { "rate" : """12""" },
    { "rate" : """11.999""" },
    { "rate" : """12""" },
    { "rate" : """11.99999""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """1.498""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """11.99""" },
    { "rate" : """11.99989""" },
    { "rate" : """11""" },
    { "rate" : """6""" },
    { "rate" : """11.99""" },
    { "rate" : """11.9""" },
    { "rate" : """1.45""" },
    { "rate" : """7""" },
    { "rate" : """6.95""" },
    { "rate" : """11.9""" },
    { "rate" : """11.9""" },
    { "rate" : """11.99999""" },
    { "rate" : """6.5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """14.998""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.95""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """8.9999""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """6.9999""" },
    { "rate" : """1.39998""" },
    { "rate" : """11.9""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """14.9""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """11.99998""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """3.75""" },
    { "rate" : """14.89""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.8""" },
    { "rate" : """12""" },
    { "rate" : """3.5""" },
    { "rate" : """3.8""" },
    { "rate" : """14.9""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """0.99989""" },
    { "rate" : """4.25""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """14.999""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """0.9""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """3.8""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """6.99999""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """7.9999""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """7.5""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """7.67246""" },
    { "rate" : """7""" },
    { "rate" : """11.43019""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """3.9""" },
    { "rate" : """3.9""" },
    { "rate" : """7.5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """0.99999""" },
    { "rate" : """3.9""" },
    { "rate" : """7.5""" },
    { "rate" : """5.68""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """4.8""" },
    { "rate" : """12""" },
    { "rate" : """9.9""" },
    { "rate" : """9.9""" },
    { "rate" : """17""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """6.9999""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """7.85""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """6.99""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """3.78384""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6.9999""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """3.5""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """9.9999""" },
    { "rate" : """3""" },
    { "rate" : """1.998""" },
    { "rate" : """7""" },
    { "rate" : """3.5""" },
    { "rate" : """6.998""" },
    { "rate" : """2""" },
    { "rate" : """9.93135""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """4.8""" },
    { "rate" : """2.99""" },
    { "rate" : """9.38577""" },
    { "rate" : """7.998""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """2.99""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """7.9""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """2.5""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """1.99""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6.75""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2.99895""" },
    { "rate" : """2""" },
    { "rate" : """6.75""" },
    { "rate" : """9.95""" },
    { "rate" : """1.99952""" },
    { "rate" : """4.9995""" },
    { "rate" : """19.78""" },
    { "rate" : """3.99""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """14""" },
    { "rate" : """7.49999""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """9.999""" },
    { "rate" : """8.5""" },
    { "rate" : """7""" },
    { "rate" : """6.99999""" },
    { "rate" : """2""" },
    { "rate" : """6.997""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """4.99999""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.99""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """5.7""" },
    { "rate" : """3.5""" },
    { "rate" : """6.99999""" },
    { "rate" : """4.5""" },
    { "rate" : """9""" },
    { "rate" : """8.99999""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """14.95""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """2.99""" },
    { "rate" : """6.9""" },
    { "rate" : """7""" },
    { "rate" : """4.9""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """9.99999""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """9.999""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4.9999""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.99""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """6.93""" },
    { "rate" : """3""" },
    { "rate" : """6.99""" },
    { "rate" : """4""" },
    { "rate" : """14""" },
    { "rate" : """5.8""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """13""" },
    { "rate" : """1""" },
    { "rate" : """14""" },
    { "rate" : """3.8""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """13""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """4.99""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """3.3""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """4.99""" },
    { "rate" : """7""" },
    { "rate" : """2.99""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3.5""" },
    { "rate" : """3""" },
    { "rate" : """11""" },
    { "rate" : """3""" },
    { "rate" : """6.9""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """14.99998""" },
    { "rate" : """7""" },
    { "rate" : """4.9999""" },
    { "rate" : """5.5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.99999""" },
    { "rate" : """12""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """13""" },
    { "rate" : """3.8""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.5""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """4.99""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """3.5""" },
    { "rate" : """2.99999""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """6.9""" },
    { "rate" : """5""" },
    { "rate" : """1.9""" },
    { "rate" : """2.9""" },
    { "rate" : """8.9""" },
    { "rate" : """3""" },
    { "rate" : """2.5""" },
    { "rate" : """1.8""" },
    { "rate" : """5""" },
    { "rate" : """1.99998""" },
    { "rate" : """2.5""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """6.99998""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """3.6""" },
    { "rate" : """7.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """3.99999""" },
    { "rate" : """2""" },
    { "rate" : """5.99999""" },
    { "rate" : """0.33333""" },
    { "rate" : """13.25""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """2.99""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """14""" },
    { "rate" : """3.99""" },
    { "rate" : """2.4""" },
    { "rate" : """0.1""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """1.5""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """0.1""" },
    { "rate" : """0.2""" },
    { "rate" : """12""" },
    { "rate" : """0.5""" },
    { "rate" : """6.25""" },
    { "rate" : """18""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.96429""" },
    { "rate" : """2.9998""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """4.81702""" },
    { "rate" : """6.95134""" },
    { "rate" : """1""" },
    { "rate" : """3.95""" },
    { "rate" : """3""" },
    { "rate" : """5.99998""" },
    { "rate" : """7""" },
    { "rate" : """19""" },
    { "rate" : """6.99998""" },
    { "rate" : """5""" },
    { "rate" : """5.5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """6.9""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """6.55""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """1.99998""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """7.5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """4.9999""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """3.98""" },
    { "rate" : """4.39998""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """7.8""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """3.2""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """7.20942""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7.9""" },
    { "rate" : """4.99998""" },
    { "rate" : """9""" },
    { "rate" : """4.9999""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """14""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """7.9""" },
    { "rate" : """7""" },
    { "rate" : """9.99999""" },
    { "rate" : """7""" },
    { "rate" : """1.999""" },
    { "rate" : """6.9""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """1.9999""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """1.9""" },
    { "rate" : """7""" },
    { "rate" : """7.1""" },
    { "rate" : """2""" },
    { "rate" : """6.75""" },
    { "rate" : """19.9999""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """8.9""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """7.5""" },
    { "rate" : """15""" },
    { "rate" : """6.9999""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """6.9""" },
    { "rate" : """6""" },
    { "rate" : """6.99""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5.9""" },
    { "rate" : """3""" },
    { "rate" : """6.55""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """7.99999""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """5.9""" },
    { "rate" : """8.5""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5.9""" },
    { "rate" : """6.99""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """6.5""" },
    { "rate" : """8.99999""" },
    { "rate" : """4.9""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """6.99""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """4.7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """5.99999""" },
    { "rate" : """7""" },
    { "rate" : """5.5""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """5.4""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6.5""" },
    { "rate" : """7""" },
    { "rate" : """8.75""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """4.9999""" },
    { "rate" : """5.1""" },
    { "rate" : """5.9""" },
    { "rate" : """8.75""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """18""" },
    { "rate" : """14.99999""" },
    { "rate" : """7""" },
    { "rate" : """4.89999""" },
    { "rate" : """7""" },
    { "rate" : """23""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """6.9""" },
    { "rate" : """5""" },
    { "rate" : """13.9""" },
    { "rate" : """6.9999""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """6.99999""" },
    { "rate" : """8.25""" },
    { "rate" : """15""" },
    { "rate" : """6.99999""" },
    { "rate" : """8""" },
    { "rate" : """5.99999""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """8""" },
    { "rate" : """1.5""" },
    { "rate" : """8""" },
    { "rate" : """6.99""" },
    { "rate" : """4.35""" },
    { "rate" : """8.9""" },
    { "rate" : """8""" },
    { "rate" : """7.47326""" },
    { "rate" : """4.9999""" },
    { "rate" : """7.9999""" },
    { "rate" : """8""" },
    { "rate" : """7.999""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4.98""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """4.876""" },
    { "rate" : """7.8""" },
    { "rate" : """9.9""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """9.9""" },
    { "rate" : """9.999""" },
    { "rate" : """7.99998""" },
    { "rate" : """4.99998""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """4.99739""" },
    { "rate" : """10""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.9999""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.9999""" },
    { "rate" : """9.9999""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """9.99998""" },
    { "rate" : """4""" },
    { "rate" : """6.9""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """11.99999""" },
    { "rate" : """9""" },
    { "rate" : """9.99999""" },
    { "rate" : """3""" },
    { "rate" : """3.5""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """13""" },
    { "rate" : """14""" },
    { "rate" : """2""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """7.99""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.9999""" },
    { "rate" : """2""" },
    { "rate" : """4.5""" },
    { "rate" : """9.5""" },
    { "rate" : """7.99999""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """14.5""" },
    { "rate" : """10""" },
    { "rate" : """9.995""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """9.99999""" },
    { "rate" : """8""" },
    { "rate" : """6.99""" },
    { "rate" : """9.9""" },
    { "rate" : """8.5""" },
    { "rate" : """1.9988""" },
    { "rate" : """1.8""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.9""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """3.11111""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """6.9999""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """3.11107""" },
    { "rate" : """3.99999""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """1.95""" },
    { "rate" : """3.95""" },
    { "rate" : """9.5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """10.5""" },
    { "rate" : """1.95""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """1.995""" },
    { "rate" : """4.9""" },
    { "rate" : """1.997""" },
    { "rate" : """4""" },
    { "rate" : """1.99""" },
    { "rate" : """10""" },
    { "rate" : """1.8""" },
    { "rate" : """3""" },
    { "rate" : """1.99""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """1.94444""" },
    { "rate" : """1.99""" },
    { "rate" : """15""" },
    { "rate" : """3.11111""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """6.99""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """3.11111""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """3.00974""" },
    { "rate" : """11.5""" },
    { "rate" : """1.9""" },
    { "rate" : """3.11""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """1.95""" },
    { "rate" : """4.9""" },
    { "rate" : """2.8""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """3.1119""" },
    { "rate" : """5""" },
    { "rate" : """2.8""" },
    { "rate" : """3.8""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """2.8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """3.98""" },
    { "rate" : """2.8""" },
    { "rate" : """8""" },
    { "rate" : """9.5""" },
    { "rate" : """3.11111""" },
    { "rate" : """8""" },
    { "rate" : """3.9""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """1.99""" },
    { "rate" : """8.99999""" },
    { "rate" : """2.8""" },
    { "rate" : """2.5""" },
    { "rate" : """10""" },
    { "rate" : """1.5""" },
    { "rate" : """1.9""" },
    { "rate" : """1.94444""" },
    { "rate" : """5""" },
    { "rate" : """6.95""" },
    { "rate" : """3.11111""" },
    { "rate" : """15""" },
    { "rate" : """1.9999""" },
    { "rate" : """4.99999""" },
    { "rate" : """2.8""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """2.8""" },
    { "rate" : """10""" },
    { "rate" : """3.11112""" },
    { "rate" : """1.99999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """1.9999""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """1.99999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.9999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6.99999""" },
    { "rate" : """3.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """11""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9.5""" },
    { "rate" : """1.96827""" },
    { "rate" : """9.89""" },
    { "rate" : """3.97967""" },
    { "rate" : """6""" },
    { "rate" : """4.9""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3.55""" },
    { "rate" : """2.9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """1.999""" },
    { "rate" : """14""" },
    { "rate" : """2.9""" },
    { "rate" : """2.8""" },
    { "rate" : """5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.9""" },
    { "rate" : """6.66667""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """8.75""" },
    { "rate" : """1.999""" },
    { "rate" : """7""" },
    { "rate" : """9.99998""" },
    { "rate" : """3.11111""" },
    { "rate" : """1.999""" },
    { "rate" : """5""" },
    { "rate" : """3.12999""" },
    { "rate" : """1.99999""" },
    { "rate" : """5""" },
    { "rate" : """9.999""" },
    { "rate" : """1.98862""" },
    { "rate" : """10""" },
    { "rate" : """1.9""" },
    { "rate" : """9.98""" },
    { "rate" : """9.985""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """8.75""" },
    { "rate" : """5.7""" },
    { "rate" : """4.4""" },
    { "rate" : """6""" },
    { "rate" : """9.9""" },
    { "rate" : """6""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """1.5""" },
    { "rate" : """17""" },
    { "rate" : """5""" },
    { "rate" : """1.999""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """18""" },
    { "rate" : """0.75""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3.11111""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """0.74999""" },
    { "rate" : """0.75""" },
    { "rate" : """2.99999""" },
    { "rate" : """6.9975""" },
    { "rate" : """7""" },
    { "rate" : """4.75""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """6.98""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """1.9""" },
    { "rate" : """15""" },
    { "rate" : """14.9""" },
    { "rate" : """8""" },
    { "rate" : """9.8""" },
    { "rate" : """3""" },
    { "rate" : """1.8""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """0.75""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """9.9""" },
    { "rate" : """11.9""" },
    { "rate" : """4""" },
    { "rate" : """3.11111""" },
    { "rate" : """19""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9.79""" },
    { "rate" : """18""" },
    { "rate" : """4.9999""" },
    { "rate" : """2.49999""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """2.9999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5.99999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.89""" },
    { "rate" : """5""" },
    { "rate" : """4.96""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6.95""" },
    { "rate" : """20""" },
    { "rate" : """7""" },
    { "rate" : """20""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """7.5""" },
    { "rate" : """4.66667""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """3.11111""" },
    { "rate" : """8.1""" },
    { "rate" : """0.75""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """2.49999""" },
    { "rate" : """4.5""" },
    { "rate" : """4.999""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """0.7499""" },
    { "rate" : """3""" },
    { "rate" : """5.9999""" },
    { "rate" : """3.99999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """2.5""" },
    { "rate" : """10""" },
    { "rate" : """5.005""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """9.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """5.5""" },
    { "rate" : """11.99""" },
    { "rate" : """9.99""" },
    { "rate" : """34.98999""" },
    { "rate" : """9.99""" },
    { "rate" : """4.9""" },
    { "rate" : """4.97""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """2.5""" },
    { "rate" : """4.9""" },
    { "rate" : """6.9""" },
    { "rate" : """6.97""" },
    { "rate" : """10""" },
    { "rate" : """9.5""" },
    { "rate" : """14""" },
    { "rate" : """5.83333""" },
    { "rate" : """2.5""" },
    { "rate" : """4.9999""" },
    { "rate" : """7.2""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """6.99""" },
    { "rate" : """2.5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """9.4""" },
    { "rate" : """10""" },
    { "rate" : """2.3""" },
    { "rate" : """4""" },
    { "rate" : """6.5""" },
    { "rate" : """2.5""" },
    { "rate" : """3.11""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """4.99999""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """2.9""" },
    { "rate" : """10""" },
    { "rate" : """4.9995""" },
    { "rate" : """3""" },
    { "rate" : """2.45""" },
    { "rate" : """4.98999""" },
    { "rate" : """0.75""" },
    { "rate" : """2.449""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """2.499""" },
    { "rate" : """6.99999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """2.66667""" },
    { "rate" : """3.33333""" },
    { "rate" : """3""" },
    { "rate" : """3.33333""" },
    { "rate" : """3.33333""" },
    { "rate" : """3.33332""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """3.333""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """2.9995""" },
    { "rate" : """6.5""" },
    { "rate" : """14""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """2.9""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """8.41""" },
    { "rate" : """3.05""" },
    { "rate" : """3""" },
    { "rate" : """3.3333""" },
    { "rate" : """6.9999""" },
    { "rate" : """7.999""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """3.3333""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """3.3""" },
    { "rate" : """7""" },
    { "rate" : """4.89""" },
    { "rate" : """3.3""" },
    { "rate" : """5""" },
    { "rate" : """3.33""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """14.9997""" },
    { "rate" : """4.965""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3.3""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """9.5""" },
    { "rate" : """8.5""" },
    { "rate" : """6.5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """34.99999""" },
    { "rate" : """35""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7.6""" },
    { "rate" : """0.01""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """8.499""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """0.1""" },
    { "rate" : """6.99998""" },
    { "rate" : """0.74""" },
    { "rate" : """4""" },
    { "rate" : """3.6""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3.3""" },
    { "rate" : """3.99998""" },
    { "rate" : """9.99998""" },
    { "rate" : """9.99998""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """3.99999""" },
    { "rate" : """10""" },
    { "rate" : """3.33""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """6.5""" },
    { "rate" : """4.9""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """3.1""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """4.2""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """3.99""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """9.99998""" },
    { "rate" : """3.9""" },
    { "rate" : """3.12""" },
    { "rate" : """3.3""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """2.9""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """3.111""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """6.99""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """6.99""" },
    { "rate" : """3.33332""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """9.9""" },
    { "rate" : """3.33332""" },
    { "rate" : """9.99999""" },
    { "rate" : """4""" },
    { "rate" : """3.99999""" },
    { "rate" : """4""" },
    { "rate" : """2.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """2.99999""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """0.75""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """6.66""" },
    { "rate" : """3.99999""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """0.75""" },
    { "rate" : """6.9999""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """6.99999""" },
    { "rate" : """5""" },
    { "rate" : """7.5""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """9.9""" },
    { "rate" : """6.95""" },
    { "rate" : """4""" },
    { "rate" : """3.95""" },
    { "rate" : """3.99999""" },
    { "rate" : """4.95""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """3.3""" },
    { "rate" : """3.95""" },
    { "rate" : """5.99998""" },
    { "rate" : """9.99888""" },
    { "rate" : """9.998""" },
    { "rate" : """3.99998""" },
    { "rate" : """3.88889""" },
    { "rate" : """9.99998""" },
    { "rate" : """4""" },
    { "rate" : """3.3""" },
    { "rate" : """6""" },
    { "rate" : """3.98""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """3.99999""" },
    { "rate" : """6""" },
    { "rate" : """8.99""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """7.8""" },
    { "rate" : """4""" },
    { "rate" : """8.33333""" },
    { "rate" : """10""" },
    { "rate" : """6.99""" },
    { "rate" : """3.9999""" },
    { "rate" : """9.9999""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """9.99""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """9.9975""" },
    { "rate" : """14.8""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """4.5""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """3.33""" },
    { "rate" : """8.49""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9.5""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """3.99""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """2.5""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """3.33167""" },
    { "rate" : """4""" },
    { "rate" : """9.99999""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """5.99998""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """3.99999""" },
    { "rate" : """4.5""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """3.25""" },
    { "rate" : """3.333""" },
    { "rate" : """2.5""" },
    { "rate" : """9.987""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """4.95""" },
    { "rate" : """3.3""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5.9""" },
    { "rate" : """9.99""" },
    { "rate" : """6.99""" },
    { "rate" : """10""" },
    { "rate" : """17.99999""" },
    { "rate" : """17.99999""" },
    { "rate" : """16""" },
    { "rate" : """15.999""" },
    { "rate" : """18""" },
    { "rate" : """7""" },
    { "rate" : """4.375""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """17.99999""" },
    { "rate" : """3.32899""" },
    { "rate" : """18""" },
    { "rate" : """6""" },
    { "rate" : """9.99""" },
    { "rate" : """20""" },
    { "rate" : """9.5""" },
    { "rate" : """16""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """7""" },
    { "rate" : """3.33""" },
    { "rate" : """10""" },
    { "rate" : """6.99""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """17.99999""" },
    { "rate" : """3.3""" },
    { "rate" : """17.99""" },
    { "rate" : """3.3""" },
    { "rate" : """10""" },
    { "rate" : """4.44444""" },
    { "rate" : """9.5""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """3.33""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """3.11""" },
    { "rate" : """5""" },
    { "rate" : """9.999""" },
    { "rate" : """17.99999""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """2.98""" },
    { "rate" : """7""" },
    { "rate" : """3.29167""" },
    { "rate" : """2.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """2.99998""" },
    { "rate" : """8""" },
    { "rate" : """17.99999""" },
    { "rate" : """2.99998""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9.5""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """9.5""" },
    { "rate" : """3.5""" },
    { "rate" : """17""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """9.97""" },
    { "rate" : """9.99""" },
    { "rate" : """5.95""" },
    { "rate" : """17.95""" },
    { "rate" : """3.32""" },
    { "rate" : """16.99895""" },
    { "rate" : """4.5""" },
    { "rate" : """6.99895""" },
    { "rate" : """7""" },
    { "rate" : """2.99""" },
    { "rate" : """4.75""" },
    { "rate" : """17""" },
    { "rate" : """2.98""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """2.5""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """2.91667""" },
    { "rate" : """9.9""" },
    { "rate" : """17.25""" },
    { "rate" : """9.99999""" },
    { "rate" : """5.5""" },
    { "rate" : """6.5""" },
    { "rate" : """3""" },
    { "rate" : """9.49""" },
    { "rate" : """7.5""" },
    { "rate" : """8""" },
    { "rate" : """7.1""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """3.3""" },
    { "rate" : """8.9""" },
    { "rate" : """7.99999""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """4.9""" },
    { "rate" : """8.9""" },
    { "rate" : """2.99""" },
    { "rate" : """7""" },
    { "rate" : """7.5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """14.6""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """2.99555""" },
    { "rate" : """7""" },
    { "rate" : """17.5""" },
    { "rate" : """7.99999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """0.75""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """17.999""" },
    { "rate" : """8.89""" },
    { "rate" : """2.89""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """7.5""" },
    { "rate" : """9.49""" },
    { "rate" : """3.5""" },
    { "rate" : """14.58333""" },
    { "rate" : """9.5""" },
    { "rate" : """4.66667""" },
    { "rate" : """3.5""" },
    { "rate" : """9.8""" },
    { "rate" : """7.99""" },
    { "rate" : """15""" },
    { "rate" : """9.99998""" },
    { "rate" : """4.99998""" },
    { "rate" : """7.99999""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """2.99999""" },
    { "rate" : """7.98""" },
    { "rate" : """3""" },
    { "rate" : """16.99998""" },
    { "rate" : """2.9""" },
    { "rate" : """4.9""" },
    { "rate" : """17.99999""" },
    { "rate" : """7""" },
    { "rate" : """6.89""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """6.99""" },
    { "rate" : """9.488""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """9.9999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """3.4999""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7.99""" },
    { "rate" : """9.99999""" },
    { "rate" : """7.5""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """9.99957""" },
    { "rate" : """7.99999""" },
    { "rate" : """9.98""" },
    { "rate" : """7.5""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """2.9""" },
    { "rate" : """9.8""" },
    { "rate" : """7.5""" },
    { "rate" : """9.99998""" },
    { "rate" : """9.999""" },
    { "rate" : """6.99998""" },
    { "rate" : """4""" },
    { "rate" : """9.99998""" },
    { "rate" : """8""" },
    { "rate" : """9.99998""" },
    { "rate" : """10""" },
    { "rate" : """3.99999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """3.89""" },
    { "rate" : """4.99""" },
    { "rate" : """9.999""" },
    { "rate" : """8.99""" },
    { "rate" : """4.5""" },
    { "rate" : """3""" },
    { "rate" : """2.5""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4.5""" },
    { "rate" : """7.99999""" },
    { "rate" : """4.99""" },
    { "rate" : """3.99999""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """3.99""" },
    { "rate" : """9.9""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """4.5""" },
    { "rate" : """7.25""" },
    { "rate" : """9.75""" },
    { "rate" : """3.5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """3.4""" },
    { "rate" : """7.89""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """3""" },
    { "rate" : """4.99""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """3.5""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """3.99999""" },
    { "rate" : """2.99999""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """7.5""" },
    { "rate" : """14.98999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """9.89""" },
    { "rate" : """1""" },
    { "rate" : """4.5""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """21.52""" },
    { "rate" : """0.75""" },
    { "rate" : """3.5""" },
    { "rate" : """1.5""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """4.5""" },
    { "rate" : """8.5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """3.9999""" },
    { "rate" : """3.85""" },
    { "rate" : """6.9""" },
    { "rate" : """14.9999""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """8""" },
    { "rate" : """1.5""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """1.45""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """12.5""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """3.86""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """0.001""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """14.999""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """3.4879""" },
    { "rate" : """8.31""" },
    { "rate" : """3.97""" },
    { "rate" : """4.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """3.3""" },
    { "rate" : """3.5""" },
    { "rate" : """7.5""" },
    { "rate" : """3""" },
    { "rate" : """3.5""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """3.49999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7.9""" },
    { "rate" : """10""" },
    { "rate" : """6.5""" },
    { "rate" : """14.99999""" },
    { "rate" : """9.99""" },
    { "rate" : """7.5""" },
    { "rate" : """7.99999""" },
    { "rate" : """3.2""" },
    { "rate" : """6""" },
    { "rate" : """3.499""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """1.5""" },
    { "rate" : """6.87055""" },
    { "rate" : """5""" },
    { "rate" : """3.43643""" },
    { "rate" : """5""" },
    { "rate" : """4.2""" },
    { "rate" : """4""" },
    { "rate" : """7.66082""" },
    { "rate" : """3""" },
    { "rate" : """4.97303""" },
    { "rate" : """2.99998""" },
    { "rate" : """9.67108""" },
    { "rate" : """3.98569""" },
    { "rate" : """6""" },
    { "rate" : """3.5""" },
    { "rate" : """3.00665""" },
    { "rate" : """3.49999""" },
    { "rate" : """4.44657""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """6.5""" },
    { "rate" : """6.995""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """7.5""" },
    { "rate" : """9""" },
    { "rate" : """3.5""" },
    { "rate" : """4.9""" },
    { "rate" : """4.89""" },
    { "rate" : """4.89""" },
    { "rate" : """8""" },
    { "rate" : """8.993""" },
    { "rate" : """8.998""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """8.99999""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """8""" },
    { "rate" : """7.99""" },
    { "rate" : """4.999""" },
    { "rate" : """9.5""" },
    { "rate" : """3""" },
    { "rate" : """0.99""" },
    { "rate" : """11.999""" },
    { "rate" : """4.876""" },
    { "rate" : """4.98""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3.9""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """4.99""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """7.98""" },
    { "rate" : """3""" },
    { "rate" : """2.9999""" },
    { "rate" : """6.999""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """2.999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3.11111""" },
    { "rate" : """10.76862""" },
    { "rate" : """5""" },
    { "rate" : """9.58805""" },
    { "rate" : """6""" },
    { "rate" : """7.98""" },
    { "rate" : """2.9999""" },
    { "rate" : """3""" },
    { "rate" : """14.998""" },
    { "rate" : """9.999""" },
    { "rate" : """6.999""" },
    { "rate" : """3.4""" },
    { "rate" : """3.49999""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """8.49999""" },
    { "rate" : """3""" },
    { "rate" : """6.999""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """8""" },
    { "rate" : """4.99999""" },
    { "rate" : """3.5""" },
    { "rate" : """3""" },
    { "rate" : """9.75""" },
    { "rate" : """2.99999""" },
    { "rate" : """3""" },
    { "rate" : """3.5""" },
    { "rate" : """3.4999""" },
    { "rate" : """3""" },
    { "rate" : """3.11111""" },
    { "rate" : """3""" },
    { "rate" : """9.999""" },
    { "rate" : """6.99999""" },
    { "rate" : """3""" },
    { "rate" : """9.999""" },
    { "rate" : """5""" },
    { "rate" : """4.998""" },
    { "rate" : """3.5""" },
    { "rate" : """6.99""" },
    { "rate" : """3.85""" },
    { "rate" : """6.99639""" },
    { "rate" : """9""" },
    { "rate" : """6.99895""" },
    { "rate" : """14""" },
    { "rate" : """6""" },
    { "rate" : """3.11111""" },
    { "rate" : """3.5""" },
    { "rate" : """2.999""" },
    { "rate" : """6.9""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """3.49""" },
    { "rate" : """4.9""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """9.9""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """3.4""" },
    { "rate" : """6.9""" },
    { "rate" : """2.95""" },
    { "rate" : """8.999""" },
    { "rate" : """3.2""" },
    { "rate" : """10""" },
    { "rate" : """3.4999""" },
    { "rate" : """2.99998""" },
    { "rate" : """6.999""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """18.77""" },
    { "rate" : """14.39286""" },
    { "rate" : """6.89999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6.999""" },
    { "rate" : """13""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """6.9999""" },
    { "rate" : """6.99999""" },
    { "rate" : """0.99989""" },
    { "rate" : """1""" },
    { "rate" : """0.9""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """3.5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """7.99999""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """3.0144""" },
    { "rate" : """1.5""" },
    { "rate" : """8""" },
    { "rate" : """8.89""" },
    { "rate" : """2""" },
    { "rate" : """1.749""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """7.99998""" },
    { "rate" : """5""" },
    { "rate" : """4.74604""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """7.99""" },
    { "rate" : """2.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """15""" },
    { "rate" : """9.30506""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """0.9997""" },
    { "rate" : """5""" },
    { "rate" : """0.999""" },
    { "rate" : """9.89""" },
    { "rate" : """10""" },
    { "rate" : """6.9""" },
    { "rate" : """6.999""" },
    { "rate" : """0.9999""" },
    { "rate" : """4.99895""" },
    { "rate" : """0.8999""" },
    { "rate" : """14.99998""" },
    { "rate" : """10""" },
    { "rate" : """4.99998""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9.999""" },
    { "rate" : """6.9""" },
    { "rate" : """8.5""" },
    { "rate" : """6.85""" },
    { "rate" : """0.99999""" },
    { "rate" : """7.95""" },
    { "rate" : """10""" },
    { "rate" : """4.85999""" },
    { "rate" : """6.9""" },
    { "rate" : """7.5""" },
    { "rate" : """4.86111""" },
    { "rate" : """5""" },
    { "rate" : """4.8""" },
    { "rate" : """4.7""" },
    { "rate" : """10""" },
    { "rate" : """3.49998""" },
    { "rate" : """9.99998""" },
    { "rate" : """14.87""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """6.4""" },
    { "rate" : """9.98""" },
    { "rate" : """2.89""" },
    { "rate" : """6.87""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """6.5""" },
    { "rate" : """0.9989""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """2.998""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """6.8""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4.999""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """2.9""" },
    { "rate" : """6.9""" },
    { "rate" : """3.45""" },
    { "rate" : """4.95""" },
    { "rate" : """9.5""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """0.1""" },
    { "rate" : """10""" },
    { "rate" : """3.111""" },
    { "rate" : """4.99999""" },
    { "rate" : """2.999""" },
    { "rate" : """7.99998""" },
    { "rate" : """3.5""" },
    { "rate" : """9.9""" },
    { "rate" : """4.87""" },
    { "rate" : """10""" },
    { "rate" : """6.9""" },
    { "rate" : """13""" },
    { "rate" : """6.99998""" },
    { "rate" : """6.85""" },
    { "rate" : """5""" },
    { "rate" : """0.66666""" },
    { "rate" : """5""" },
    { "rate" : """6.99""" },
    { "rate" : """9.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.99""" },
    { "rate" : """2.99998""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """2.91667""" },
    { "rate" : """0.99999""" },
    { "rate" : """8""" },
    { "rate" : """6.85""" },
    { "rate" : """3.5""" },
    { "rate" : """6.99999""" },
    { "rate" : """3.2""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """3.99999""" },
    { "rate" : """6.99899""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """1.99999""" },
    { "rate" : """12""" },
    { "rate" : """7.999""" },
    { "rate" : """7.99998""" },
    { "rate" : """9.998""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """6.8""" },
    { "rate" : """8""" },
    { "rate" : """3.5""" },
    { "rate" : """8.75""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """0.58333""" },
    { "rate" : """5""" },
    { "rate" : """1.999""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """2.98999""" },
    { "rate" : """0.98999""" },
    { "rate" : """9.5""" },
    { "rate" : """3.49""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """9""" },
    { "rate" : """3.4""" },
    { "rate" : """1""" },
    { "rate" : """4.99""" },
    { "rate" : """1""" },
    { "rate" : """4.99""" },
    { "rate" : """2.9""" },
    { "rate" : """4.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """0.99998""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """4.5""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """4.99""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.4""" },
    { "rate" : """1""" },
    { "rate" : """1.99999""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """8.99998""" },
    { "rate" : """2.69999""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """9.49999""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """4.87""" },
    { "rate" : """6""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.99999""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """0.92""" },
    { "rate" : """1""" },
    { "rate" : """8.4""" },
    { "rate" : """6.99999""" },
    { "rate" : """5""" },
    { "rate" : """9.99998""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """0.8""" },
    { "rate" : """4""" },
    { "rate" : """0.999""" },
    { "rate" : """3.1""" },
    { "rate" : """5""" },
    { "rate" : """4.27778""" },
    { "rate" : """3.49987""" },
    { "rate" : """4.99998""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.99989""" },
    { "rate" : """7.75""" },
    { "rate" : """4.99999""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7.9999""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """3.11112""" },
    { "rate" : """2""" },
    { "rate" : """3.11111""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.99""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """4.9""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.99""" },
    { "rate" : """7""" },
    { "rate" : """4.99999""" },
    { "rate" : """9.95""" },
    { "rate" : """4.999""" },
    { "rate" : """1.999""" },
    { "rate" : """3""" },
    { "rate" : """9.97""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """14.998""" },
    { "rate" : """17.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """1""" },
    { "rate" : """9.1""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """4.8""" },
    { "rate" : """4.16667""" },
    { "rate" : """17.8""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """4.5""" },
    { "rate" : """9.5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """0.9""" },
    { "rate" : """9.9""" },
    { "rate" : """8.9""" },
    { "rate" : """8.9""" },
    { "rate" : """9.999""" },
    { "rate" : """18""" },
    { "rate" : """0.99999""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """9.999""" },
    { "rate" : """9.99998""" },
    { "rate" : """4.999""" },
    { "rate" : """9.9""" },
    { "rate" : """0.9""" },
    { "rate" : """14.9393""" },
    { "rate" : """0.98""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """2.9999""" },
    { "rate" : """3""" },
    { "rate" : """4.98""" },
    { "rate" : """8.5""" },
    { "rate" : """9.99998""" },
    { "rate" : """10""" },
    { "rate" : """17.5""" },
    { "rate" : """9.99999""" },
    { "rate" : """1.99998""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9.7079""" },
    { "rate" : """18""" },
    { "rate" : """4.97874""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.75""" },
    { "rate" : """2.999""" },
    { "rate" : """4.9999""" },
    { "rate" : """2.35983""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """4.99988""" },
    { "rate" : """7""" },
    { "rate" : """9.89""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """4.99999""" },
    { "rate" : """9.97699""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """4.7""" },
    { "rate" : """9.99998""" },
    { "rate" : """3.03282""" },
    { "rate" : """1.99""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """14.9""" },
    { "rate" : """10""" },
    { "rate" : """4.95""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4.99999""" },
    { "rate" : """10""" },
    { "rate" : """2.9999""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """4.99999""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """2.6""" },
    { "rate" : """4.99999""" },
    { "rate" : """9.9""" },
    { "rate" : """2.99999""" },
    { "rate" : """9""" },
    { "rate" : """4.99998""" },
    { "rate" : """9.98999""" },
    { "rate" : """17.99999""" },
    { "rate" : """7""" },
    { "rate" : """18""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """4.95""" },
    { "rate" : """15""" },
    { "rate" : """9.98""" },
    { "rate" : """4.99999""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """9.8""" },
    { "rate" : """18.52""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """9.9""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """3.11111""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """4.98""" },
    { "rate" : """2.99""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """9.99""" },
    { "rate" : """9.99""" },
    { "rate" : """14""" },
    { "rate" : """6.293""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """15""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.1""" },
    { "rate" : """9.99999""" },
    { "rate" : """4.99989""" },
    { "rate" : """9.9998""" },
    { "rate" : """5""" },
    { "rate" : """13.5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """3.1""" },
    { "rate" : """11""" },
    { "rate" : """3.99999""" },
    { "rate" : """17.99""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """1.9999""" },
    { "rate" : """9.98""" },
    { "rate" : """2.94""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """9.99999""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """19""" },
    { "rate" : """3""" },
    { "rate" : """4.999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """3.11341""" },
    { "rate" : """9.99""" },
    { "rate" : """5""" },
    { "rate" : """0.74""" },
    { "rate" : """14.99998""" },
    { "rate" : """10""" },
    { "rate" : """1.99998""" },
    { "rate" : """16""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """9.99998""" },
    { "rate" : """9""" },
    { "rate" : """4.9""" },
    { "rate" : """1.9""" },
    { "rate" : """4.98""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """17.5""" },
    { "rate" : """0.74""" },
    { "rate" : """9.9""" },
    { "rate" : """9.99998""" },
    { "rate" : """2.5""" },
    { "rate" : """1.55""" },
    { "rate" : """4.5""" },
    { "rate" : """8""" },
    { "rate" : """14.99998""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """2.99998""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """9.99998""" },
    { "rate" : """1""" },
    { "rate" : """18""" },
    { "rate" : """9.66""" },
    { "rate" : """0.86""" },
    { "rate" : """4.9""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """4.9""" },
    { "rate" : """3.1""" },
    { "rate" : """9.5""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """4.375""" },
    { "rate" : """12.5""" },
    { "rate" : """5""" },
    { "rate" : """9.87""" },
    { "rate" : """9.97""" },
    { "rate" : """4.99998""" },
    { "rate" : """9.97""" },
    { "rate" : """9.99998""" },
    { "rate" : """9.5""" },
    { "rate" : """3.99998""" },
    { "rate" : """3""" },
    { "rate" : """9.99998""" },
    { "rate" : """4.5""" },
    { "rate" : """4""" },
    { "rate" : """4.75""" },
    { "rate" : """4.55467""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """2.99""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """4.4""" },
    { "rate" : """4.4999""" },
    { "rate" : """20""" },
    { "rate" : """3.1""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """9.99""" },
    { "rate" : """12""" },
    { "rate" : """9""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.99""" },
    { "rate" : """2.99999""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """18""" },
    { "rate" : """4.8""" },
    { "rate" : """9.8""" },
    { "rate" : """5""" },
    { "rate" : """4.39""" },
    { "rate" : """3.10112""" },
    { "rate" : """9.99998""" },
    { "rate" : """19.9899""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5.9999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """3.2""" },
    { "rate" : """2.33333""" },
    { "rate" : """2.99999""" },
    { "rate" : """2.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9.9999""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """2.25""" },
    { "rate" : """2.9999""" },
    { "rate" : """4.99999""" },
    { "rate" : """15""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """4.66666""" },
    { "rate" : """10""" },
    { "rate" : """3.89""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """10.7""" },
    { "rate" : """15""" },
    { "rate" : """1.55556""" },
    { "rate" : """2.5""" },
    { "rate" : """4.95""" },
    { "rate" : """4.98""" },
    { "rate" : """9.5""" },
    { "rate" : """2.98""" },
    { "rate" : """8""" },
    { "rate" : """2.33333""" },
    { "rate" : """5.83333""" },
    { "rate" : """11""" },
    { "rate" : """11""" },
    { "rate" : """12.5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """8.5""" },
    { "rate" : """19.99999""" },
    { "rate" : """9.99""" },
    { "rate" : """8.5""" },
    { "rate" : """5""" },
    { "rate" : """1.559""" },
    { "rate" : """4.97378""" },
    { "rate" : """9.99999""" },
    { "rate" : """2.5""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """9.9999""" },
    { "rate" : """4""" },
    { "rate" : """4.5""" },
    { "rate" : """1""" },
    { "rate" : """14""" },
    { "rate" : """2.5""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """4.98""" },
    { "rate" : """4.999""" },
    { "rate" : """9.999""" },
    { "rate" : """5""" },
    { "rate" : """9.5""" },
    { "rate" : """9.99""" },
    { "rate" : """4.99998""" },
    { "rate" : """10.699""" },
    { "rate" : """6""" },
    { "rate" : """3.33333""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """4.9""" },
    { "rate" : """13.99""" },
    { "rate" : """9.5""" },
    { "rate" : """9.5""" },
    { "rate" : """8.33333""" },
    { "rate" : """6""" },
    { "rate" : """2.4""" },
    { "rate" : """10""" },
    { "rate" : """9.3""" },
    { "rate" : """4""" },
    { "rate" : """9.3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """17.5""" },
    { "rate" : """8.45569""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """2.99997""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """10""" },
    { "rate" : """2.99895""" },
    { "rate" : """2.3317""" },
    { "rate" : """7.77778""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """11.66667""" },
    { "rate" : """12.89531""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """3.49""" },
    { "rate" : """5""" },
    { "rate" : """3.9""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """2.5""" },
    { "rate" : """18""" },
    { "rate" : """12.85""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """60""" },
    { "rate" : """2.92""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """2.2""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """14.2""" },
    { "rate" : """15.04""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.99""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """20""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """1""" },
    { "rate" : """4.93889""" },
    { "rate" : """9.83""" },
    { "rate" : """9.99999""" },
    { "rate" : """1""" },
    { "rate" : """4.97""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """9.99""" },
    { "rate" : """1""" },
    { "rate" : """8.9998""" },
    { "rate" : """10""" },
    { "rate" : """8.9""" },
    { "rate" : """9""" },
    { "rate" : """8.89""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """8.9""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """0.99999""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """0.9999""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """2.33333""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.97222""" },
    { "rate" : """5""" },
    { "rate" : """0.9999""" },
    { "rate" : """14""" },
    { "rate" : """4.97778""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8.1""" },
    { "rate" : """1""" },
    { "rate" : """9.75""" },
    { "rate" : """1""" },
    { "rate" : """8.1""" },
    { "rate" : """8""" },
    { "rate" : """7.2""" },
    { "rate" : """14""" },
    { "rate" : """4.999""" },
    { "rate" : """4.998""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """4.9998""" },
    { "rate" : """3.33333""" },
    { "rate" : """8.08333""" },
    { "rate" : """4.998""" },
    { "rate" : """4.9993""" },
    { "rate" : """8.9998""" },
    { "rate" : """8""" },
    { "rate" : """4.998""" },
    { "rate" : """4.998""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """14.998""" },
    { "rate" : """9.998""" },
    { "rate" : """9.998""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """4.998""" },
    { "rate" : """5.998""" },
    { "rate" : """12""" },
    { "rate" : """8.998""" },
    { "rate" : """1""" },
    { "rate" : """2.1998""" },
    { "rate" : """1""" },
    { "rate" : """119""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """3.998""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """17.9""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """8.1""" },
    { "rate" : """4.75""" },
    { "rate" : """3.3""" },
    { "rate" : """4.99998""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """4.75""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """14""" },
    { "rate" : """20""" },
    { "rate" : """3.4998""" },
    { "rate" : """6.9999""" },
    { "rate" : """6.998""" },
    { "rate" : """1""" },
    { "rate" : """4.99999""" },
    { "rate" : """8.09998""" },
    { "rate" : """3.3998""" },
    { "rate" : """9.9""" },
    { "rate" : """4.9""" },
    { "rate" : """4.99999""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """9.9999""" },
    { "rate" : """10""" },
    { "rate" : """17.8""" },
    { "rate" : """0.999""" },
    { "rate" : """19.9999""" },
    { "rate" : """18""" },
    { "rate" : """18.77""" },
    { "rate" : """1""" },
    { "rate" : """3.9998""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """8.1""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """3.48""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """7.62079""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """60""" },
    { "rate" : """20""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """20""" },
    { "rate" : """4.599""" },
    { "rate" : """3""" },
    { "rate" : """16""" },
    { "rate" : """20""" },
    { "rate" : """3""" },
    { "rate" : """7.9""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """17""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """7.5""" },
    { "rate" : """5.83333""" },
    { "rate" : """1""" },
    { "rate" : """17""" },
    { "rate" : """7""" },
    { "rate" : """5.99999""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """0.99995""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """14.9""" },
    { "rate" : """7.5""" },
    { "rate" : """8.05""" },
    { "rate" : """7.2""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """0.99998""" },
    { "rate" : """7.5""" },
    { "rate" : """6.99999""" },
    { "rate" : """18.52""" },
    { "rate" : """3.33""" },
    { "rate" : """0.9899""" },
    { "rate" : """9.99999""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """5.998""" },
    { "rate" : """7""" },
    { "rate" : """6.02434""" },
    { "rate" : """5.85""" },
    { "rate" : """9.99999""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """0.98""" },
    { "rate" : """9.9""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """10""" },
    { "rate" : """7.99""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """60""" },
    { "rate" : """30""" },
    { "rate" : """2.3""" },
    { "rate" : """6.99998""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """6.99""" },
    { "rate" : """7""" },
    { "rate" : """4.29722""" },
    { "rate" : """5.99""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5.8""" },
    { "rate" : """5""" },
    { "rate" : """15.9999""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """9.99999""" },
    { "rate" : """8.71111""" },
    { "rate" : """4.99999""" },
    { "rate" : """3""" },
    { "rate" : """9.73""" },
    { "rate" : """14.75""" },
    { "rate" : """8.25""" },
    { "rate" : """5""" },
    { "rate" : """8.75""" },
    { "rate" : """9.7223""" },
    { "rate" : """4""" },
    { "rate" : """20""" },
    { "rate" : """9.9""" },
    { "rate" : """6""" },
    { "rate" : """6.9""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9.5""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """9.99998""" },
    { "rate" : """6.99985""" },
    { "rate" : """6.99""" },
    { "rate" : """5.9""" },
    { "rate" : """9.5""" },
    { "rate" : """6.7""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """60""" },
    { "rate" : """7""" },
    { "rate" : """6.5""" },
    { "rate" : """3.11112""" },
    { "rate" : """5.5""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """5.999""" },
    { "rate" : """6.999""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """4.998""" },
    { "rate" : """11.998""" },
    { "rate" : """4.998""" },
    { "rate" : """14.998""" },
    { "rate" : """14.998""" },
    { "rate" : """3.33333""" },
    { "rate" : """4.4""" },
    { "rate" : """9""" },
    { "rate" : """2.6""" },
    { "rate" : """15""" },
    { "rate" : """20""" },
    { "rate" : """3.5""" },
    { "rate" : """7""" },
    { "rate" : """4.9899""" },
    { "rate" : """4.5""" },
    { "rate" : """6.9989""" },
    { "rate" : """2.9989""" },
    { "rate" : """6.9989""" },
    { "rate" : """8""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """18""" },
    { "rate" : """4.9""" },
    { "rate" : """25""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """1.5""" },
    { "rate" : """14.5""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """1.998""" },
    { "rate" : """2""" },
    { "rate" : """9.75""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99989""" },
    { "rate" : """1.999""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """3.25""" },
    { "rate" : """9.5""" },
    { "rate" : """6.9""" },
    { "rate" : """3.35""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """7.25""" },
    { "rate" : """3""" },
    { "rate" : """3.49""" },
    { "rate" : """9.959""" },
    { "rate" : """6.69""" },
    { "rate" : """4.99""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """1.99998""" },
    { "rate" : """6.99999""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """6.89""" },
    { "rate" : """1.99999""" },
    { "rate" : """6.9999""" },
    { "rate" : """7.99999""" },
    { "rate" : """14.99999""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """6.5""" },
    { "rate" : """9.997""" },
    { "rate" : """7.92""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """2.33333""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """9.969""" },
    { "rate" : """3.3""" },
    { "rate" : """1.9""" },
    { "rate" : """4.998""" },
    { "rate" : """11""" },
    { "rate" : """6.8""" },
    { "rate" : """6.7""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """9""" },
    { "rate" : """11""" },
    { "rate" : """9.99998""" },
    { "rate" : """11.99998""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """9.9997""" },
    { "rate" : """6.99999""" },
    { "rate" : """2.99999""" },
    { "rate" : """1.99999""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """15""" },
    { "rate" : """2.35599""" },
    { "rate" : """7""" },
    { "rate" : """9.72222""" },
    { "rate" : """1.999""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """2.93""" },
    { "rate" : """5""" },
    { "rate" : """3.34""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """11.5""" },
    { "rate" : """10""" },
    { "rate" : """4.42828""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """4.875""" },
    { "rate" : """9.99997""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5.99998""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """8.85""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """4.87""" },
    { "rate" : """2""" },
    { "rate" : """4.92097""" },
    { "rate" : """6""" },
    { "rate" : """5.9998""" },
    { "rate" : """5.8""" },
    { "rate" : """1.9998""" },
    { "rate" : """4.9998""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """11.97""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """19""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """9.96699""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """1.65""" },
    { "rate" : """14.9""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """14.899""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """5""" },
    { "rate" : """1.975""" },
    { "rate" : """4.5""" },
    { "rate" : """4.5""" },
    { "rate" : """1.997""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """2.3""" },
    { "rate" : """4.99""" },
    { "rate" : """9.99""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """2.3""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3.499""" },
    { "rate" : """5""" },
    { "rate" : """12.7""" },
    { "rate" : """2.4""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """19.5""" },
    { "rate" : """4.99998""" },
    { "rate" : """17.49999""" },
    { "rate" : """15""" },
    { "rate" : """1.98999""" },
    { "rate" : """4.5""" },
    { "rate" : """7.9""" },
    { "rate" : """6""" },
    { "rate" : """7.8""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """118.99""" },
    { "rate" : """14.99""" },
    { "rate" : """6.99""" },
    { "rate" : """2.3""" },
    { "rate" : """2.2""" },
    { "rate" : """2""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """18.9""" },
    { "rate" : """4.9""" },
    { "rate" : """3.75""" },
    { "rate" : """6.8""" },
    { "rate" : """15""" },
    { "rate" : """7.998""" },
    { "rate" : """7.5""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """7.8508""" },
    { "rate" : """3.5""" },
    { "rate" : """4""" },
    { "rate" : """14""" },
    { "rate" : """6.99999""" },
    { "rate" : """10.998""" },
    { "rate" : """10""" },
    { "rate" : """10.99999""" },
    { "rate" : """15""" },
    { "rate" : """4.998""" },
    { "rate" : """2""" },
    { "rate" : """7.89""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """1.95""" },
    { "rate" : """12""" },
    { "rate" : """10.55""" },
    { "rate" : """10.89""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """4.9""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """10.9""" },
    { "rate" : """17""" },
    { "rate" : """4.99999""" },
    { "rate" : """9.99""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.94444""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """1.99998""" },
    { "rate" : """4.5""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """10.77402""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """2""" },
    { "rate" : """4.5""" },
    { "rate" : """4.94""" },
    { "rate" : """1.899""" },
    { "rate" : """7""" },
    { "rate" : """3.98""" },
    { "rate" : """13.98""" },
    { "rate" : """9.75""" },
    { "rate" : """2""" },
    { "rate" : """17.4""" },
    { "rate" : """6""" },
    { "rate" : """4.89""" },
    { "rate" : """11.95""" },
    { "rate" : """9.98""" },
    { "rate" : """0.74""" },
    { "rate" : """10.88""" },
    { "rate" : """4.5""" },
    { "rate" : """4.43""" },
    { "rate" : """5.94""" },
    { "rate" : """14.98""" },
    { "rate" : """1.99999""" },
    { "rate" : """5.99""" },
    { "rate" : """9.55""" },
    { "rate" : """1.95""" },
    { "rate" : """6.99""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """13""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """18""" },
    { "rate" : """10""" },
    { "rate" : """4.8""" },
    { "rate" : """14""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7.998""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """17.9""" },
    { "rate" : """4.9899""" },
    { "rate" : """13.9999""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """8.9""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """12.99999""" },
    { "rate" : """5.5""" },
    { "rate" : """6.5""" },
    { "rate" : """18""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """9.99""" },
    { "rate" : """4.25""" },
    { "rate" : """6""" },
    { "rate" : """10.83333""" },
    { "rate" : """11.25""" },
    { "rate" : """18""" },
    { "rate" : """4.86111""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """3.5""" },
    { "rate" : """7.99999""" },
    { "rate" : """11.99999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """11.66667""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """6.5""" },
    { "rate" : """4.9""" },
    { "rate" : """13.5""" },
    { "rate" : """11.998""" },
    { "rate" : """14""" },
    { "rate" : """18""" },
    { "rate" : """14""" },
    { "rate" : """8.9""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """4.9""" },
    { "rate" : """6""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """5.99999""" },
    { "rate" : """5""" },
    { "rate" : """11.95""" },
    { "rate" : """3.5""" },
    { "rate" : """5.9""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """5.85""" },
    { "rate" : """12""" },
    { "rate" : """4.99""" },
    { "rate" : """5.99""" },
    { "rate" : """6.99""" },
    { "rate" : """4""" },
    { "rate" : """2.33333""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """11.5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """11.999""" },
    { "rate" : """18.998""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """4.9""" },
    { "rate" : """3""" },
    { "rate" : """4.9""" },
    { "rate" : """1.5""" },
    { "rate" : """8""" },
    { "rate" : """6.9999""" },
    { "rate" : """4.9999""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """1.4998""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """1.5""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """11""" },
    { "rate" : """4.5""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """2.33333""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """17.77""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """3.99""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """11.99998""" },
    { "rate" : """15""" },
    { "rate" : """1.5""" },
    { "rate" : """8.99""" },
    { "rate" : """1.1""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """11.98""" },
    { "rate" : """14.9""" },
    { "rate" : """12""" },
    { "rate" : """9""" },
    { "rate" : """2.33333""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """11.9""" },
    { "rate" : """10""" },
    { "rate" : """2.25""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """1.99998""" },
    { "rate" : """11.9""" },
    { "rate" : """11.85""" },
    { "rate" : """1.5""" },
    { "rate" : """1.9""" },
    { "rate" : """2""" },
    { "rate" : """1.49999""" },
    { "rate" : """1.99999""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """1.95""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """17.8""" },
    { "rate" : """7.5""" },
    { "rate" : """8""" },
    { "rate" : """1.998""" },
    { "rate" : """15""" },
    { "rate" : """3.49998""" },
    { "rate" : """14.998""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """1.5""" },
    { "rate" : """18""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """1.5""" },
    { "rate" : """11""" },
    { "rate" : """1.5""" },
    { "rate" : """7.5""" },
    { "rate" : """14.5""" },
    { "rate" : """12""" },
    { "rate" : """13.5""" },
    { "rate" : """8.9998""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """9.99""" },
    { "rate" : """8""" },
    { "rate" : """1.5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """3.49998""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """9.95""" },
    { "rate" : """1.4997""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """4.2""" },
    { "rate" : """0.7""" },
    { "rate" : """4.95""" },
    { "rate" : """3""" },
    { "rate" : """1.45""" },
    { "rate" : """12.86""" },
    { "rate" : """0.7""" },
    { "rate" : """3.5""" },
    { "rate" : """3.49""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """4.5""" },
    { "rate" : """1.45""" },
    { "rate" : """1""" },
    { "rate" : """4.2""" },
    { "rate" : """8.25""" },
    { "rate" : """4.97778""" },
    { "rate" : """18""" },
    { "rate" : """9""" },
    { "rate" : """14""" },
    { "rate" : """14.8""" },
    { "rate" : """10""" },
    { "rate" : """7.8""" },
    { "rate" : """3.45""" },
    { "rate" : """4""" },
    { "rate" : """3.49999""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """14.99999""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """3.8""" },
    { "rate" : """1.499""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """6.5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """23""" },
    { "rate" : """9.2""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9.44335""" },
    { "rate" : """3.25""" },
    { "rate" : """9.5""" },
    { "rate" : """1.48""" },
    { "rate" : """19.93""" },
    { "rate" : """9.999""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """9.44""" },
    { "rate" : """1.498""" },
    { "rate" : """7.99999""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """1.449""" },
    { "rate" : """3.9""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """15""" },
    { "rate" : """20""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7.5""" },
    { "rate" : """1""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """1.4""" },
    { "rate" : """8.998""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """19.9""" },
    { "rate" : """15""" },
    { "rate" : """1.48""" },
    { "rate" : """15""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """6.4""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """0.7""" },
    { "rate" : """8""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """9.666""" },
    { "rate" : """15""" },
    { "rate" : """4.9""" },
    { "rate" : """15""" },
    { "rate" : """3.9""" },
    { "rate" : """9.59""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """14""" },
    { "rate" : """4""" },
    { "rate" : """18""" },
    { "rate" : """9.9999""" },
    { "rate" : """10""" },
    { "rate" : """4.59999""" },
    { "rate" : """4""" },
    { "rate" : """58""" },
    { "rate" : """14""" },
    { "rate" : """7""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.75""" },
    { "rate" : """9.999""" },
    { "rate" : """0.75""" },
    { "rate" : """0.75""" },
    { "rate" : """9.5""" },
    { "rate" : """9.75""" },
    { "rate" : """0.73611""" },
    { "rate" : """1.5""" },
    { "rate" : """4.5""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """9.98""" },
    { "rate" : """3.48998""" },
    { "rate" : """17.99""" },
    { "rate" : """20""" },
    { "rate" : """9""" },
    { "rate" : """4.99""" },
    { "rate" : """2.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """9.99""" },
    { "rate" : """9.9""" },
    { "rate" : """9.99""" },
    { "rate" : """3.99""" },
    { "rate" : """9.99""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99""" },
    { "rate" : """7.99""" },
    { "rate" : """18""" },
    { "rate" : """5""" },
    { "rate" : """17.5""" },
    { "rate" : """9.99""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """9.87""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """9.9""" },
    { "rate" : """4.5""" },
    { "rate" : """8.12""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """9.9998""" },
    { "rate" : """9.9""" },
    { "rate" : """4.499""" },
    { "rate" : """9.99""" },
    { "rate" : """7.99""" },
    { "rate" : """9.99""" },
    { "rate" : """2.99""" },
    { "rate" : """9.998""" },
    { "rate" : """7.49999""" },
    { "rate" : """14""" },
    { "rate" : """7.5""" },
    { "rate" : """9.5""" },
    { "rate" : """7.48""" },
    { "rate" : """4""" },
    { "rate" : """7.5""" },
    { "rate" : """12.99999""" },
    { "rate" : """7""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.69""" },
    { "rate" : """9.99999""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """8.75""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5.7""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """13""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """5.998""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """13.99999""" },
    { "rate" : """15""" },
    { "rate" : """9.99""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """40""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """3.8""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """9.75""" },
    { "rate" : """7""" },
    { "rate" : """13.5""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """14.8""" },
    { "rate" : """7.5""" },
    { "rate" : """10""" },
    { "rate" : """3.49998""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """14.99""" },
    { "rate" : """18""" },
    { "rate" : """15""" },
    { "rate" : """3.48998""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """19""" },
    { "rate" : """17.9""" },
    { "rate" : """5""" },
    { "rate" : """8.75""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """14""" },
    { "rate" : """14.99999""" },
    { "rate" : """2""" },
    { "rate" : """16""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """2.95""" },
    { "rate" : """4""" },
    { "rate" : """3.998""" },
    { "rate" : """1.99999""" },
    { "rate" : """0.75""" },
    { "rate" : """10""" },
    { "rate" : """1.9444""" },
    { "rate" : """9""" },
    { "rate" : """8.01963""" },
    { "rate" : """14.9""" },
    { "rate" : """12.75""" },
    { "rate" : """3.88""" },
    { "rate" : """4.5""" },
    { "rate" : """4.99""" },
    { "rate" : """4.75""" },
    { "rate" : """0.75""" },
    { "rate" : """2.45""" },
    { "rate" : """2.4999""" },
    { "rate" : """18""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """19.5""" },
    { "rate" : """5""" },
    { "rate" : """9.999""" },
    { "rate" : """2.3""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.999""" },
    { "rate" : """2.5""" },
    { "rate" : """10""" },
    { "rate" : """5.99999""" },
    { "rate" : """2.5""" },
    { "rate" : """4.5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """3.99985""" },
    { "rate" : """18""" },
    { "rate" : """6.25""" },
    { "rate" : """1.8""" },
    { "rate" : """2.42""" },
    { "rate" : """1""" },
    { "rate" : """3.2""" },
    { "rate" : """10""" },
    { "rate" : """2.49""" },
    { "rate" : """18""" },
    { "rate" : """9.98""" },
    { "rate" : """9.98""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """3.11111""" },
    { "rate" : """5.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2.49999""" },
    { "rate" : """4.99999""" },
    { "rate" : """17.25""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.99998""" },
    { "rate" : """5""" },
    { "rate" : """19.4""" },
    { "rate" : """2""" },
    { "rate" : """3.49998""" },
    { "rate" : """7""" },
    { "rate" : """4.98""" },
    { "rate" : """1.5""" },
    { "rate" : """9.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5.99999""" },
    { "rate" : """9.5""" },
    { "rate" : """1.5""" },
    { "rate" : """3.1999""" },
    { "rate" : """5.998""" },
    { "rate" : """1""" },
    { "rate" : """3.99""" },
    { "rate" : """1.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1.5""" },
    { "rate" : """2""" },
    { "rate" : """16""" },
    { "rate" : """0.3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """4.99999""" },
    { "rate" : """1.5""" },
    { "rate" : """3""" },
    { "rate" : """4.99""" },
    { "rate" : """5.988""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """4.99""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """6.97""" },
    { "rate" : """3.5""" },
    { "rate" : """4.95""" },
    { "rate" : """7.2""" },
    { "rate" : """2.99998""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """18""" },
    { "rate" : """10""" },
    { "rate" : """3.9989""" },
    { "rate" : """4""" },
    { "rate" : """4.99998""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """19.49999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """4.88""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """14.2""" },
    { "rate" : """4.9""" },
    { "rate" : """4.32""" },
    { "rate" : """4.5""" },
    { "rate" : """4.9999""" },
    { "rate" : """2.98""" },
    { "rate" : """4.99999""" },
    { "rate" : """8.5""" },
    { "rate" : """8.47""" },
    { "rate" : """4""" },
    { "rate" : """8.6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.8444""" },
    { "rate" : """7.5""" },
    { "rate" : """4.44444""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """2.44444""" },
    { "rate" : """0.84435""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """4.44444""" },
    { "rate" : """3""" },
    { "rate" : """0.6""" },
    { "rate" : """5""" },
    { "rate" : """0.6""" },
    { "rate" : """0.6""" },
    { "rate" : """0.6""" },
    { "rate" : """0.6""" },
    { "rate" : """0.6""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """0.89999""" },
    { "rate" : """3""" },
    { "rate" : """0.6""" },
    { "rate" : """3.9""" },
    { "rate" : """3""" },
    { "rate" : """4.97""" },
    { "rate" : """0.4444""" },
    { "rate" : """0.6""" },
    { "rate" : """5""" },
    { "rate" : """2.84444""" },
    { "rate" : """0.6""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """3.99""" },
    { "rate" : """4.86111""" },
    { "rate" : """0.59""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """0.59989""" },
    { "rate" : """4.99999""" },
    { "rate" : """18""" },
    { "rate" : """0.39999""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """2.99""" },
    { "rate" : """3""" },
    { "rate" : """26.79""" },
    { "rate" : """19.48999""" },
    { "rate" : """4.9""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """5.9""" },
    { "rate" : """1.98998""" },
    { "rate" : """1.99999""" },
    { "rate" : """2.99999""" },
    { "rate" : """4.99998""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """1.98999""" },
    { "rate" : """1.99""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """14.9""" },
    { "rate" : """17.99998""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """9.95""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """4.85""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """14.9""" },
    { "rate" : """5""" },
    { "rate" : """18""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """13.33""" },
    { "rate" : """10""" },
    { "rate" : """1.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3.99908""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.9""" },
    { "rate" : """4.99999""" },
    { "rate" : """14.9""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2.95""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.98""" },
    { "rate" : """5""" },
    { "rate" : """2.83889""" },
    { "rate" : """1.99998""" },
    { "rate" : """18""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """4.95""" },
    { "rate" : """4.91""" },
    { "rate" : """9.9998""" },
    { "rate" : """4.9998""" },
    { "rate" : """1.99722""" },
    { "rate" : """1.999""" },
    { "rate" : """1.9999""" },
    { "rate" : """14.5""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """1.99999""" },
    { "rate" : """12""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """17.99""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """3.99""" },
    { "rate" : """5""" },
    { "rate" : """3.98""" },
    { "rate" : """8.93""" },
    { "rate" : """13""" },
    { "rate" : """14""" },
    { "rate" : """4.979""" },
    { "rate" : """14.93""" },
    { "rate" : """4""" },
    { "rate" : """18""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """4.9""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """4.9989""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """14.99999""" },
    { "rate" : """1""" },
    { "rate" : """13""" },
    { "rate" : """4""" },
    { "rate" : """14.99""" },
    { "rate" : """14.44""" },
    { "rate" : """14.5""" },
    { "rate" : """0.19""" },
    { "rate" : """0.75""" },
    { "rate" : """1""" },
    { "rate" : """14""" },
    { "rate" : """14.49999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """6.75""" },
    { "rate" : """0.1""" },
    { "rate" : """0.1""" },
    { "rate" : """1.10101""" },
    { "rate" : """7""" },
    { "rate" : """11""" },
    { "rate" : """15""" },
    { "rate" : """0.75""" },
    { "rate" : """20""" },
    { "rate" : """14""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """3.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """0.72""" },
    { "rate" : """4.2""" },
    { "rate" : """3.9""" },
    { "rate" : """0.9""" },
    { "rate" : """3.999""" },
    { "rate" : """8.05""" },
    { "rate" : """3""" },
    { "rate" : """4.9999""" },
    { "rate" : """4.999""" },
    { "rate" : """4.99999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """8.9""" },
    { "rate" : """3""" },
    { "rate" : """0.998""" },
    { "rate" : """0.00834""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """4.9""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """4.49998""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """4.49""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1.98""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """5.98998""" },
    { "rate" : """14.99""" },
    { "rate" : """8.99""" },
    { "rate" : """15.99""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """4.99999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """4""" },
    { "rate" : """4.74""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """14.99999""" },
    { "rate" : """4.5""" },
    { "rate" : """8""" },
    { "rate" : """9.99999""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """6""" },
    { "rate" : """4.9998""" },
    { "rate" : """10""" },
    { "rate" : """1.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """4.5""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """9.99981""" },
    { "rate" : """4.25""" },
    { "rate" : """9.78""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """7.8""" },
    { "rate" : """5.25""" },
    { "rate" : """15""" },
    { "rate" : """2.94""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """2.95""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """4.98989""" },
    { "rate" : """4.89""" },
    { "rate" : """4""" },
    { "rate" : """1.4""" },
    { "rate" : """4.99998""" },
    { "rate" : """7.9""" },
    { "rate" : """7.89""" },
    { "rate" : """7.79""" },
    { "rate" : """10""" },
    { "rate" : """7.89999""" },
    { "rate" : """7.8""" },
    { "rate" : """1.94""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7.9""" },
    { "rate" : """8""" },
    { "rate" : """1.9""" },
    { "rate" : """5""" },
    { "rate" : """1.88888""" },
    { "rate" : """4""" },
    { "rate" : """7.99999""" },
    { "rate" : """9.999""" },
    { "rate" : """4.9""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """6.66666""" },
    { "rate" : """7.999""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """7.8""" },
    { "rate" : """4.5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """5.99989""" },
    { "rate" : """16""" },
    { "rate" : """18""" },
    { "rate" : """7.99999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """7.99""" },
    { "rate" : """12""" },
    { "rate" : """5.99998""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """0.9999""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """0.97999""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """0.9997""" },
    { "rate" : """15.01""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.96""" },
    { "rate" : """4.97""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """4.989""" },
    { "rate" : """0.9""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """0.99""" },
    { "rate" : """15""" },
    { "rate" : """1.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1.5""" },
    { "rate" : """4.99997""" },
    { "rate" : """5""" },
    { "rate" : """14.9""" },
    { "rate" : """10""" },
    { "rate" : """1.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.91667""" },
    { "rate" : """0.75""" },
    { "rate" : """2.9393""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """11.99999""" },
    { "rate" : """12""" },
    { "rate" : """11.5999""" },
    { "rate" : """0.99""" },
    { "rate" : """4.5""" },
    { "rate" : """2.5""" },
    { "rate" : """5.01667""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.9999""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """9.9""" },
    { "rate" : """5""" },
    { "rate" : """9.979""" },
    { "rate" : """9.9""" },
    { "rate" : """8""" },
    { "rate" : """9.9""" },
    { "rate" : """4.5""" },
    { "rate" : """1.9""" },
    { "rate" : """4.9""" },
    { "rate" : """4.97""" },
    { "rate" : """15""" },
    { "rate" : """4.95""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """0.75""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """4.99""" },
    { "rate" : """0.75""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """4.9998""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4.98""" },
    { "rate" : """1.5""" },
    { "rate" : """14.95""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """0.75""" },
    { "rate" : """9""" },
    { "rate" : """4.99""" },
    { "rate" : """18.1""" },
    { "rate" : """5""" },
    { "rate" : """13.9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """8.5""" },
    { "rate" : """8.99999""" },
    { "rate" : """11.99999""" },
    { "rate" : """7""" },
    { "rate" : """4.9999""" },
    { "rate" : """3.9""" },
    { "rate" : """0.74999""" },
    { "rate" : """0.725""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.48999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """4.3""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """1.5""" },
    { "rate" : """0.75""" },
    { "rate" : """5""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.75""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.4998""" },
    { "rate" : """0.5""" },
    { "rate" : """18""" },
    { "rate" : """4.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49""" },
    { "rate" : """4.5""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """0.7493""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49722""" },
    { "rate" : """18""" },
    { "rate" : """3.88889""" },
    { "rate" : """4""" },
    { "rate" : """4.4""" },
    { "rate" : """0.49999""" },
    { "rate" : """4.5""" },
    { "rate" : """0.498""" },
    { "rate" : """8""" },
    { "rate" : """0.4996""" },
    { "rate" : """6.9799""" },
    { "rate" : """0.49""" },
    { "rate" : """3.99""" },
    { "rate" : """4""" },
    { "rate" : """0.49989""" },
    { "rate" : """0.49""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """9.73""" },
    { "rate" : """8""" },
    { "rate" : """8.98""" },
    { "rate" : """2.5""" },
    { "rate" : """9.4999""" },
    { "rate" : """0.49999""" },
    { "rate" : """9.5""" },
    { "rate" : """3.98""" },
    { "rate" : """3.7""" },
    { "rate" : """0.489""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """0.75""" },
    { "rate" : """4.5""" },
    { "rate" : """2""" },
    { "rate" : """0.49999""" },
    { "rate" : """3.99999""" },
    { "rate" : """0.49""" },
    { "rate" : """8.4""" },
    { "rate" : """9.98999""" },
    { "rate" : """0.475""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.45""" },
    { "rate" : """3.9999""" },
    { "rate" : """0.49999""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.69999""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.4598""" },
    { "rate" : """9.99998""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4.58333""" },
    { "rate" : """9.9876""" },
    { "rate" : """6.9899""" },
    { "rate" : """4""" },
    { "rate" : """4.5""" },
    { "rate" : """8""" },
    { "rate" : """2.4899""" },
    { "rate" : """0.48999""" },
    { "rate" : """8""" },
    { "rate" : """0.445""" },
    { "rate" : """4.5""" },
    { "rate" : """5.9""" },
    { "rate" : """2.25""" },
    { "rate" : """0.49""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """0.66""" },
    { "rate" : """2.5""" },
    { "rate" : """18""" },
    { "rate" : """2.49998""" },
    { "rate" : """18""" },
    { "rate" : """2.48999""" },
    { "rate" : """1.5""" },
    { "rate" : """2.5""" },
    { "rate" : """6""" },
    { "rate" : """2.5""" },
    { "rate" : """4""" },
    { "rate" : """0.75""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """4""" },
    { "rate" : """2.5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """3.98""" },
    { "rate" : """1.5""" },
    { "rate" : """4.9999""" },
    { "rate" : """2.488""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """4.99""" },
    { "rate" : """4.9999""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.9999""" },
    { "rate" : """4.99999""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """29""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """0.9998""" },
    { "rate" : """5""" },
    { "rate" : """0.75""" },
    { "rate" : """4.5""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """2.5""" },
    { "rate" : """4.99""" },
    { "rate" : """0.75""" },
    { "rate" : """0.74""" },
    { "rate" : """1.5""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """30""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """0.9997""" },
    { "rate" : """2.5""" },
    { "rate" : """4.99998""" },
    { "rate" : """0.99979""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """0.73999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """3.99""" },
    { "rate" : """4.98""" },
    { "rate" : """2.49""" },
    { "rate" : """0.99""" },
    { "rate" : """2.5""" },
    { "rate" : """18""" },
    { "rate" : """4.6""" },
    { "rate" : """4""" },
    { "rate" : """6.8999""" },
    { "rate" : """0.9989""" },
    { "rate" : """11""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """0.99""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """0.99998""" },
    { "rate" : """0.98""" },
    { "rate" : """1""" },
    { "rate" : """3.5""" },
    { "rate" : """0.99722""" },
    { "rate" : """18""" },
    { "rate" : """1.5""" },
    { "rate" : """2.5""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """11.99999""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """2.9999""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99""" },
    { "rate" : """0.7""" },
    { "rate" : """0.98999""" },
    { "rate" : """5""" },
    { "rate" : """0.9999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2.49""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """3.99999""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """18""" },
    { "rate" : """9""" },
    { "rate" : """17.99999""" },
    { "rate" : """29""" },
    { "rate" : """1.4""" },
    { "rate" : """11.5""" },
    { "rate" : """2.99999""" },
    { "rate" : """0.66""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """11""" },
    { "rate" : """2.5""" },
    { "rate" : """4.8""" },
    { "rate" : """1""" },
    { "rate" : """4.5""" },
    { "rate" : """2.95""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """17""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """9.9""" },
    { "rate" : """11.99998""" },
    { "rate" : """10""" },
    { "rate" : """4.99998""" },
    { "rate" : """11.98""" },
    { "rate" : """11.5""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """11.9799""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """2.98""" },
    { "rate" : """3.5""" },
    { "rate" : """3""" },
    { "rate" : """2.5""" },
    { "rate" : """4.5""" },
    { "rate" : """3""" },
    { "rate" : """3.9799""" },
    { "rate" : """11""" },
    { "rate" : """4.7""" },
    { "rate" : """9.479""" },
    { "rate" : """3.99998""" },
    { "rate" : """2.45""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """3.99999""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """3.9999""" },
    { "rate" : """1""" },
    { "rate" : """9.8""" },
    { "rate" : """1.5""" },
    { "rate" : """9.99""" },
    { "rate" : """9.5""" },
    { "rate" : """10.76""" },
    { "rate" : """4.5""" },
    { "rate" : """0.75""" },
    { "rate" : """2.42""" },
    { "rate" : """4.5""" },
    { "rate" : """8.5""" },
    { "rate" : """7.9999""" },
    { "rate" : """14""" },
    { "rate" : """3.9""" },
    { "rate" : """2.4""" },
    { "rate" : """18""" },
    { "rate" : """4.5""" },
    { "rate" : """4.95""" },
    { "rate" : """17.99999""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """2.4""" },
    { "rate" : """2.5""" },
    { "rate" : """4.99""" },
    { "rate" : """10""" },
    { "rate" : """1.4""" },
    { "rate" : """9.91667""" },
    { "rate" : """0.75""" },
    { "rate" : """16""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """2.5""" },
    { "rate" : """4.5""" },
    { "rate" : """9""" },
    { "rate" : """9.49999""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """0.973""" },
    { "rate" : """9.6""" },
    { "rate" : """3.99""" },
    { "rate" : """4.3""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1.5""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.9979""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """7.99""" },
    { "rate" : """4.99""" },
    { "rate" : """16""" },
    { "rate" : """1.5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """20""" },
    { "rate" : """11""" },
    { "rate" : """18""" },
    { "rate" : """2.5""" },
    { "rate" : """5.5""" },
    { "rate" : """3.9""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """18""" },
    { "rate" : """3.30556""" },
    { "rate" : """3.99998""" },
    { "rate" : """0.75""" },
    { "rate" : """2.5""" },
    { "rate" : """3.5""" },
    { "rate" : """12.5""" },
    { "rate" : """10""" },
    { "rate" : """0.0001""" },
    { "rate" : """4""" },
    { "rate" : """14.99998""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """18""" },
    { "rate" : """18""" },
    { "rate" : """9.9799""" },
    { "rate" : """1.4979""" },
    { "rate" : """10""" },
    { "rate" : """9.5""" },
    { "rate" : """10""" },
    { "rate" : """4.69999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """19.99999""" },
    { "rate" : """3.5""" },
    { "rate" : """1.5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """7.5""" },
    { "rate" : """10""" },
    { "rate" : """7.9""" },
    { "rate" : """0.75""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """1.5""" },
    { "rate" : """10""" },
    { "rate" : """1.489""" },
    { "rate" : """9.8999""" },
    { "rate" : """16.99999""" },
    { "rate" : """4.98911""" },
    { "rate" : """3.99""" },
    { "rate" : """9.99""" },
    { "rate" : """9""" },
    { "rate" : """9.99999""" },
    { "rate" : """8.5""" },
    { "rate" : """1""" },
    { "rate" : """24.9""" },
    { "rate" : """1""" },
    { "rate" : """0.95""" },
    { "rate" : """6.9""" },
    { "rate" : """1""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """0.8""" },
    { "rate" : """1""" },
    { "rate" : """0.9988""" },
    { "rate" : """1""" },
    { "rate" : """0.9""" },
    { "rate" : """12""" },
    { "rate" : """1.5""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.88887""" },
    { "rate" : """9.7""" },
    { "rate" : """2.5""" },
    { "rate" : """0.9997""" },
    { "rate" : """4.9""" },
    { "rate" : """2.5""" },
    { "rate" : """0.98""" },
    { "rate" : """0.9999""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """0.8""" },
    { "rate" : """0.97""" },
    { "rate" : """1.5""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.7""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """3.8""" },
    { "rate" : """3""" },
    { "rate" : """0.99969""" },
    { "rate" : """10""" },
    { "rate" : """0.98""" },
    { "rate" : """0.9""" },
    { "rate" : """0.85""" },
    { "rate" : """0.95""" },
    { "rate" : """0.6""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """7.77778""" },
    { "rate" : """2.99999""" },
    { "rate" : """0.2""" },
    { "rate" : """2.99995""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """3.2""" },
    { "rate" : """12""" },
    { "rate" : """0.95""" },
    { "rate" : """5""" },
    { "rate" : """0.88888""" },
    { "rate" : """15""" },
    { "rate" : """0.89799""" },
    { "rate" : """1.5""" },
    { "rate" : """0.9999""" },
    { "rate" : """18""" },
    { "rate" : """1.5""" },
    { "rate" : """2.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.99""" },
    { "rate" : """9""" },
    { "rate" : """9.25""" },
    { "rate" : """5.99""" },
    { "rate" : """18""" },
    { "rate" : """9.99""" },
    { "rate" : """14""" },
    { "rate" : """20""" },
    { "rate" : """11""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """8.99998""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """0.3""" },
    { "rate" : """0.95""" },
    { "rate" : """2""" },
    { "rate" : """8.98333""" },
    { "rate" : """0.79999""" },
    { "rate" : """0.99722""" },
    { "rate" : """1""" },
    { "rate" : """18""" },
    { "rate" : """1""" },
    { "rate" : """0.3""" },
    { "rate" : """11""" },
    { "rate" : """6.99""" },
    { "rate" : """0.59999""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """0.8""" },
    { "rate" : """11""" },
    { "rate" : """7""" },
    { "rate" : """7.9""" },
    { "rate" : """4""" },
    { "rate" : """9.25""" },
    { "rate" : """7.9799""" },
    { "rate" : """3.925""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """3.9""" },
    { "rate" : """4.5""" },
    { "rate" : """19.964""" },
    { "rate" : """8.99999""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """0.74999""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """7.978""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """7.89999""" },
    { "rate" : """7.89999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """7.5""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """0.75""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """0.75""" },
    { "rate" : """2.917""" },
    { "rate" : """7.99999""" },
    { "rate" : """7""" },
    { "rate" : """13.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """13.99999""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """17.22""" },
    { "rate" : """16.5""" },
    { "rate" : """7.8""" },
    { "rate" : """4""" },
    { "rate" : """1.4999""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """6.4""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """14""" },
    { "rate" : """6.5""" },
    { "rate" : """13.998""" },
    { "rate" : """9.99""" },
    { "rate" : """13.95""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """14""" },
    { "rate" : """6""" },
    { "rate" : """13.99998""" },
    { "rate" : """1.95""" },
    { "rate" : """6.4999""" },
    { "rate" : """2.5""" },
    { "rate" : """7""" },
    { "rate" : """9.99998""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """9.99998""" },
    { "rate" : """1.5""" },
    { "rate" : """8.99999""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """18""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """3.2""" },
    { "rate" : """8""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """4.9""" },
    { "rate" : """7.99998""" },
    { "rate" : """10""" },
    { "rate" : """9.25""" },
    { "rate" : """9.99998""" },
    { "rate" : """15""" },
    { "rate" : """1.75""" },
    { "rate" : """8.25""" },
    { "rate" : """6""" },
    { "rate" : """9.9""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """17.99""" },
    { "rate" : """9.99""" },
    { "rate" : """13.99""" },
    { "rate" : """9.99""" },
    { "rate" : """9.99""" },
    { "rate" : """2.99""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3.99999""" },
    { "rate" : """1.75""" },
    { "rate" : """2.3""" },
    { "rate" : """2.98""" },
    { "rate" : """3.99999""" },
    { "rate" : """7.5""" },
    { "rate" : """3.98""" },
    { "rate" : """7.99998""" },
    { "rate" : """1.5""" },
    { "rate" : """14""" },
    { "rate" : """9""" },
    { "rate" : """18""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8.5""" },
    { "rate" : """4""" },
    { "rate" : """18""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """2.9998""" },
    { "rate" : """29""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """9.9998""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """4.499""" },
    { "rate" : """2""" },
    { "rate" : """4.75""" },
    { "rate" : """4.4""" },
    { "rate" : """9.998""" },
    { "rate" : """4.75999""" },
    { "rate" : """4.4799""" },
    { "rate" : """0.75""" },
    { "rate" : """14.9""" },
    { "rate" : """8.7999""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """3.95""" },
    { "rate" : """7.6999""" },
    { "rate" : """7.8""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """7.9998""" },
    { "rate" : """8""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """28""" },
    { "rate" : """9.98""" },
    { "rate" : """0.745""" },
    { "rate" : """5""" },
    { "rate" : """17.85""" },
    { "rate" : """15""" },
    { "rate" : """2.29999""" },
    { "rate" : """9.99999""" },
    { "rate" : """2.5""" },
    { "rate" : """7.99""" },
    { "rate" : """7""" },
    { "rate" : """1.45""" },
    { "rate" : """7.95""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """14.5""" },
    { "rate" : """4.9""" },
    { "rate" : """18""" },
    { "rate" : """8""" },
    { "rate" : """9.98""" },
    { "rate" : """2""" },
    { "rate" : """13""" },
    { "rate" : """6.5""" },
    { "rate" : """11""" },
    { "rate" : """11""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """6.99""" },
    { "rate" : """11""" },
    { "rate" : """2.5""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """30""" },
    { "rate" : """9.5""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """30""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """4.9""" },
    { "rate" : """6.9""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """3.5""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """1.99999""" },
    { "rate" : """8""" },
    { "rate" : """0.5""" },
    { "rate" : """9.89""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """9.99""" },
    { "rate" : """7.9699""" },
    { "rate" : """4.99""" },
    { "rate" : """7""" },
    { "rate" : """14""" },
    { "rate" : """7""" },
    { "rate" : """9.78999""" },
    { "rate" : """0.1""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """7.9799""" },
    { "rate" : """0.5""" },
    { "rate" : """0.75""" },
    { "rate" : """4.2""" },
    { "rate" : """9.8""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """9.299""" },
    { "rate" : """9.5""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """7.98999""" },
    { "rate" : """10""" },
    { "rate" : """9.3""" },
    { "rate" : """4.16667""" },
    { "rate" : """4.8""" },
    { "rate" : """2.99""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """9.4""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """9.96999""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """1.8""" },
    { "rate" : """14.95""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """8.33333""" },
    { "rate" : """8""" },
    { "rate" : """9.9""" },
    { "rate" : """4.3""" },
    { "rate" : """2.49""" },
    { "rate" : """20.83333""" },
    { "rate" : """28.5""" },
    { "rate" : """14.98""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7.9999""" },
    { "rate" : """14.9""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """9.99999""" },
    { "rate" : """1.9999""" },
    { "rate" : """15""" },
    { "rate" : """14""" },
    { "rate" : """7.99999""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """2.3""" },
    { "rate" : """9""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """17.5""" },
    { "rate" : """14.99895""" },
    { "rate" : """2.5""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """4.5""" },
    { "rate" : """2.5""" },
    { "rate" : """14""" },
    { "rate" : """11""" },
    { "rate" : """4.3""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """4.3""" },
    { "rate" : """9.9999""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """9.45""" },
    { "rate" : """4.9999""" },
    { "rate" : """15""" },
    { "rate" : """12.5""" },
    { "rate" : """18""" },
    { "rate" : """13.99""" },
    { "rate" : """15""" },
    { "rate" : """9.5""" },
    { "rate" : """20""" },
    { "rate" : """11""" },
    { "rate" : """2.49999""" },
    { "rate" : """13.9""" },
    { "rate" : """2.5""" },
    { "rate" : """9""" },
    { "rate" : """7.98""" },
    { "rate" : """2.9""" },
    { "rate" : """2.49""" },
    { "rate" : """4.3""" },
    { "rate" : """20""" },
    { "rate" : """1.9988""" },
    { "rate" : """5""" },
    { "rate" : """7.95""" },
    { "rate" : """2.99999""" },
    { "rate" : """9.5""" },
    { "rate" : """8""" },
    { "rate" : """9.9""" },
    { "rate" : """2.49999""" },
    { "rate" : """2""" },
    { "rate" : """19.9""" },
    { "rate" : """14.99""" },
    { "rate" : """14.3""" },
    { "rate" : """15""" },
    { "rate" : """6.7""" },
    { "rate" : """1.9""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """9.9""" },
    { "rate" : """8.5""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """1.799""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """2.99999""" },
    { "rate" : """5""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.99""" },
    { "rate" : """3""" },
    { "rate" : """1.998""" },
    { "rate" : """9.98765""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """2.5""" },
    { "rate" : """14.75""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9.72222""" },
    { "rate" : """2.2""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """4.6""" },
    { "rate" : """2.72222""" },
    { "rate" : """7.99999""" },
    { "rate" : """14""" },
    { "rate" : """7.5""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """4.99""" },
    { "rate" : """2.36""" },
    { "rate" : """9.9899""" },
    { "rate" : """4.98999""" },
    { "rate" : """29.99""" },
    { "rate" : """19.99""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """4.66667""" },
    { "rate" : """4.9""" },
    { "rate" : """4.987""" },
    { "rate" : """4.99""" },
    { "rate" : """9.999""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """18""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """7.99""" },
    { "rate" : """7.999""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """9.98""" },
    { "rate" : """3""" },
    { "rate" : """7.9""" },
    { "rate" : """4.9""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """20""" },
    { "rate" : """2.37""" },
    { "rate" : """3.99""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """19""" },
    { "rate" : """2.5""" },
    { "rate" : """7.9""" },
    { "rate" : """9.99999""" },
    { "rate" : """28.75""" },
    { "rate" : """8""" },
    { "rate" : """7.5""" },
    { "rate" : """8""" },
    { "rate" : """6.99999""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """18""" },
    { "rate" : """5""" },
    { "rate" : """9.9998""" },
    { "rate" : """25""" },
    { "rate" : """27""" },
    { "rate" : """7.98""" },
    { "rate" : """28.9""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.99""" },
    { "rate" : """9.9""" },
    { "rate" : """1.995""" },
    { "rate" : """1.9499""" },
    { "rate" : """28.99""" },
    { "rate" : """1.99""" },
    { "rate" : """1.9""" },
    { "rate" : """12""" },
    { "rate" : """5.8""" },
    { "rate" : """17""" },
    { "rate" : """9.9""" },
    { "rate" : """1.95""" },
    { "rate" : """14.99999""" },
    { "rate" : """1.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """4.99""" },
    { "rate" : """9.9799""" },
    { "rate" : """29""" },
    { "rate" : """1.89""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """9.72222""" },
    { "rate" : """1.9""" },
    { "rate" : """1.95""" },
    { "rate" : """8""" },
    { "rate" : """7.5""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """0.1""" },
    { "rate" : """1.75""" },
    { "rate" : """19.99999""" },
    { "rate" : """1.9""" },
    { "rate" : """8""" },
    { "rate" : """1.9467""" },
    { "rate" : """9.9""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """1.8""" },
    { "rate" : """1.2""" },
    { "rate" : """6""" },
    { "rate" : """12.5""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """1.9""" },
    { "rate" : """1.99""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.98999""" },
    { "rate" : """0.9999""" },
    { "rate" : """1.99999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """14.9999""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """0.9999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """28.5""" },
    { "rate" : """0.9999""" },
    { "rate" : """7.98999""" },
    { "rate" : """5""" },
    { "rate" : """0.98""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """0.9""" },
    { "rate" : """0.99999""" },
    { "rate" : """4""" },
    { "rate" : """9.10972""" },
    { "rate" : """11.5""" },
    { "rate" : """0.9""" },
    { "rate" : """6.99""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """0.99997""" },
    { "rate" : """0.99998""" },
    { "rate" : """15""" },
    { "rate" : """6.99999""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """0.89999""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7.998""" },
    { "rate" : """29""" },
    { "rate" : """25""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """25""" },
    { "rate" : """29""" },
    { "rate" : """0.99895""" },
    { "rate" : """6.99895""" },
    { "rate" : """2.99895""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """20""" },
    { "rate" : """28""" },
    { "rate" : """0.5""" },
    { "rate" : """1.99""" },
    { "rate" : """13""" },
    { "rate" : """15""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.999""" },
    { "rate" : """14.9999""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """3""" },
    { "rate" : """2.999""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """0.8""" },
    { "rate" : """25""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """0.9999""" },
    { "rate" : """2.5""" },
    { "rate" : """29""" },
    { "rate" : """2.975""" },
    { "rate" : """2.9""" },
    { "rate" : """3.3333""" },
    { "rate" : """14.99999""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """2.9""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """0.81""" },
    { "rate" : """0.9998""" },
    { "rate" : """15""" },
    { "rate" : """0.89""" },
    { "rate" : """14.99999""" },
    { "rate" : """0.99""" },
    { "rate" : """5""" },
    { "rate" : """18""" },
    { "rate" : """13""" },
    { "rate" : """0.8""" },
    { "rate" : """27""" },
    { "rate" : """17""" },
    { "rate" : """14.99""" },
    { "rate" : """25""" },
    { "rate" : """8""" },
    { "rate" : """18""" },
    { "rate" : """14.25""" },
    { "rate" : """8""" },
    { "rate" : """3.99""" },
    { "rate" : """6""" },
    { "rate" : """6.99""" },
    { "rate" : """19.99""" },
    { "rate" : """6.99998""" },
    { "rate" : """14.99""" },
    { "rate" : """7.99999""" },
    { "rate" : """19.8""" },
    { "rate" : """6.99999""" },
    { "rate" : """7""" },
    { "rate" : """9.99998""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """4.3""" },
    { "rate" : """4.3""" },
    { "rate" : """5.3""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """18""" },
    { "rate" : """15.5""" },
    { "rate" : """4.99998""" },
    { "rate" : """1.99998""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """4.99998""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """19""" },
    { "rate" : """3.9""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """20""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """2.899""" },
    { "rate" : """2.9""" },
    { "rate" : """14.5""" },
    { "rate" : """8""" },
    { "rate" : """5.5""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """18""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """2.9999""" },
    { "rate" : """3""" },
    { "rate" : """2.8999""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """2.95""" },
    { "rate" : """4""" },
    { "rate" : """2.92""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """14.99""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """17.98""" },
    { "rate" : """19""" },
    { "rate" : """14.95""" },
    { "rate" : """14.9""" },
    { "rate" : """2""" },
    { "rate" : """2.5""" },
    { "rate" : """4""" },
    { "rate" : """9.99998""" },
    { "rate" : """3.99998""" },
    { "rate" : """8""" },
    { "rate" : """2.08333""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """1.5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """9.99998""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """3.9""" },
    { "rate" : """7.8""" },
    { "rate" : """2""" },
    { "rate" : """20""" },
    { "rate" : """1.5""" },
    { "rate" : """3.9999""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """1.98998""" },
    { "rate" : """3.99998""" },
    { "rate" : """1.999""" },
    { "rate" : """1.95""" },
    { "rate" : """9.25""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """6.99999""" },
    { "rate" : """17.5""" },
    { "rate" : """6.97999""" },
    { "rate" : """3""" },
    { "rate" : """20""" },
    { "rate" : """4.99""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """8.99999""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """7.98""" },
    { "rate" : """9.5""" },
    { "rate" : """8.87""" },
    { "rate" : """7""" },
    { "rate" : """18""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """1.99998""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """9.9799""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """6""" },
    { "rate" : """1.99998""" },
    { "rate" : """0.99""" },
    { "rate" : """1.95""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """20""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """6.99998""" },
    { "rate" : """17.75""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """1.9""" },
    { "rate" : """0.98""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """6.5""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """19.87""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """0.99""" },
    { "rate" : """6.6""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """18""" },
    { "rate" : """2""" },
    { "rate" : """7.999""" },
    { "rate" : """6.99999""" },
    { "rate" : """0.9997""" },
    { "rate" : """0.9""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """0.99998""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """9.9799""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """6.89""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """9.999""" },
    { "rate" : """25""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """6.99""" },
    { "rate" : """8""" },
    { "rate" : """9.99999""" },
    { "rate" : """4""" },
    { "rate" : """19.89999""" },
    { "rate" : """3.9""" },
    { "rate" : """0.1""" },
    { "rate" : """9.5""" },
    { "rate" : """6.9799""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """2.75""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8.9""" },
    { "rate" : """15""" },
    { "rate" : """2.72""" },
    { "rate" : """9.99998""" },
    { "rate" : """9""" },
    { "rate" : """9.9998""" },
    { "rate" : """9""" },
    { "rate" : """6.999""" },
    { "rate" : """7.9""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """6.49999""" },
    { "rate" : """6.99999""" },
    { "rate" : """7.89""" },
    { "rate" : """20""" },
    { "rate" : """2.5""" },
    { "rate" : """15""" },
    { "rate" : """2.33333""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """3.9""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """2.72222""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3.999""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """2.72""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """6.5""" },
    { "rate" : """3.9""" },
    { "rate" : """1.5""" },
    { "rate" : """3.95""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3.75""" },
    { "rate" : """18""" },
    { "rate" : """0.00039""" },
    { "rate" : """2""" },
    { "rate" : """2.71999""" },
    { "rate" : """4""" },
    { "rate" : """14.99999""" },
    { "rate" : """3.99895""" },
    { "rate" : """6.99895""" },
    { "rate" : """6.99895""" },
    { "rate" : """4""" },
    { "rate" : """3.9""" },
    { "rate" : """4""" },
    { "rate" : """14""" },
    { "rate" : """13.99999""" },
    { "rate" : """3.99999""" },
    { "rate" : """5""" },
    { "rate" : """3.9799""" },
    { "rate" : """7""" },
    { "rate" : """3.9""" },
    { "rate" : """1.5""" },
    { "rate" : """3.9""" },
    { "rate" : """3.99""" },
    { "rate" : """3.998""" },
    { "rate" : """8""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """4.99999""" },
    { "rate" : """18""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7.99998""" },
    { "rate" : """1.99998""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """3.8""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """13""" },
    { "rate" : """2""" },
    { "rate" : """1.75""" },
    { "rate" : """6""" },
    { "rate" : """1.5""" },
    { "rate" : """13.99999""" },
    { "rate" : """18""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """4.9998""" },
    { "rate" : """13.99998""" },
    { "rate" : """2.99998""" },
    { "rate" : """4.8""" },
    { "rate" : """2.5""" },
    { "rate" : """4.999""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """4.99998""" },
    { "rate" : """13.49""" },
    { "rate" : """11""" },
    { "rate" : """14.999""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """1.99""" },
    { "rate" : """3.98""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """14.9999""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """2.99999""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """4.5""" },
    { "rate" : """14.48""" },
    { "rate" : """15.55556""" },
    { "rate" : """5""" },
    { "rate" : """6.97""" },
    { "rate" : """6.99998""" },
    { "rate" : """15""" },
    { "rate" : """6.98""" },
    { "rate" : """2.99""" },
    { "rate" : """14.99""" },
    { "rate" : """13.99""" },
    { "rate" : """4.99""" },
    { "rate" : """14""" },
    { "rate" : """4.99998""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """12.5""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """1.98999""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """6.99""" },
    { "rate" : """6.9899""" },
    { "rate" : """14""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """2""" },
    { "rate" : """4.16667""" },
    { "rate" : """3.4""" },
    { "rate" : """25""" },
    { "rate" : """2.5""" },
    { "rate" : """8""" },
    { "rate" : """1.9""" },
    { "rate" : """7.9998""" },
    { "rate" : """18""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """30""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """6.65""" },
    { "rate" : """2.72222""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """13""" },
    { "rate" : """4.98""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """0.99979""" },
    { "rate" : """1""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.98""" },
    { "rate" : """0.99""" },
    { "rate" : """0.98""" },
    { "rate" : """18""" },
    { "rate" : """0.988""" },
    { "rate" : """0.99""" },
    { "rate" : """0.9999""" },
    { "rate" : """10""" },
    { "rate" : """0.99999""" },
    { "rate" : """8""" },
    { "rate" : """0.97""" },
    { "rate" : """0.99""" },
    { "rate" : """4""" },
    { "rate" : """6.9""" },
    { "rate" : """0.98999""" },
    { "rate" : """9.99""" },
    { "rate" : """0.9999""" },
    { "rate" : """20""" },
    { "rate" : """0.94999""" },
    { "rate" : """4""" },
    { "rate" : """0.9""" },
    { "rate" : """3.5""" },
    { "rate" : """18""" },
    { "rate" : """0.99999""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """0.9""" },
    { "rate" : """8""" },
    { "rate" : """3.5""" },
    { "rate" : """3.49""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """0.9""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """13""" },
    { "rate" : """2""" },
    { "rate" : """16""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """4.2""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3.99""" },
    { "rate" : """2""" },
    { "rate" : """3.7""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """2.473""" },
    { "rate" : """2.38""" },
    { "rate" : """2.475""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """18""" },
    { "rate" : """12.9999""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """12.9""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """18""" },
    { "rate" : """2.8""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """10.99""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """11""" },
    { "rate" : """25""" },
    { "rate" : """2.99999""" },
    { "rate" : """4.6""" },
    { "rate" : """3.7""" },
    { "rate" : """8""" },
    { "rate" : """11""" },
    { "rate" : """3""" },
    { "rate" : """11""" },
    { "rate" : """6.899""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """9.99998""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """12""" },
    { "rate" : """10.97999""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """9.99999""" },
    { "rate" : """2.53""" },
    { "rate" : """10""" },
    { "rate" : """1.9""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """24.99""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """14.9""" },
    { "rate" : """20""" },
    { "rate" : """25""" },
    { "rate" : """11""" },
    { "rate" : """8""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """13.9999""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """20""" },
    { "rate" : """18""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """19""" },
    { "rate" : """12""" },
    { "rate" : """4.99999""" },
    { "rate" : """12""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.99997""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """7.5""" },
    { "rate" : """10""" },
    { "rate" : """3.7""" },
    { "rate" : """3.49999""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """14""" },
    { "rate" : """4.9""" },
    { "rate" : """4""" },
    { "rate" : """7.99999""" },
    { "rate" : """10.99""" },
    { "rate" : """4.8""" },
    { "rate" : """4.5""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """16.16""" },
    { "rate" : """11.9999""" },
    { "rate" : """8""" },
    { "rate" : """13.5""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """11.99999""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """4.999""" },
    { "rate" : """13.99999""" },
    { "rate" : """9.99997""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """2.95""" },
    { "rate" : """8""" },
    { "rate" : """18""" },
    { "rate" : """10""" },
    { "rate" : """2.99""" },
    { "rate" : """13""" },
    { "rate" : """17.99988""" },
    { "rate" : """3""" },
    { "rate" : """24""" },
    { "rate" : """1""" },
    { "rate" : """10.0001""" },
    { "rate" : """10""" },
    { "rate" : """7.99""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """2.99999""" },
    { "rate" : """17""" },
    { "rate" : """3.7""" },
    { "rate" : """10.5""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """2.9988""" },
    { "rate" : """2.95""" },
    { "rate" : """14""" },
    { "rate" : """14.85""" },
    { "rate" : """24.8""" },
    { "rate" : """15""" },
    { "rate" : """1.5""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.979""" },
    { "rate" : """9.9999""" },
    { "rate" : """8""" },
    { "rate" : """3.99999""" },
    { "rate" : """4""" },
    { "rate" : """9.9998""" },
    { "rate" : """9.76""" },
    { "rate" : """9.9998""" },
    { "rate" : """14""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """3.99""" },
    { "rate" : """7.9999""" },
    { "rate" : """7.99999""" },
    { "rate" : """5""" },
    { "rate" : """2.99""" },
    { "rate" : """3""" },
    { "rate" : """7.99999""" },
    { "rate" : """7.99""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """13.99""" },
    { "rate" : """10""" },
    { "rate" : """0.33333""" },
    { "rate" : """7""" },
    { "rate" : """24""" },
    { "rate" : """3.99""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """14""" },
    { "rate" : """4.8799""" },
    { "rate" : """2.99""" },
    { "rate" : """18""" },
    { "rate" : """4.889""" },
    { "rate" : """17""" },
    { "rate" : """17""" },
    { "rate" : """3""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """1.8""" },
    { "rate" : """4.7""" },
    { "rate" : """4.99""" },
    { "rate" : """7.99""" },
    { "rate" : """13.99""" },
    { "rate" : """14""" },
    { "rate" : """13""" },
    { "rate" : """17""" },
    { "rate" : """3""" },
    { "rate" : """18""" },
    { "rate" : """16""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """2.9""" },
    { "rate" : """3.99""" },
    { "rate" : """4.9""" },
    { "rate" : """3""" },
    { "rate" : """14""" },
    { "rate" : """17""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """14""" },
    { "rate" : """3""" },
    { "rate" : """0.1""" },
    { "rate" : """13""" },
    { "rate" : """20""" },
    { "rate" : """4.99999""" },
    { "rate" : """14""" },
    { "rate" : """2.99999""" },
    { "rate" : """16.99999""" },
    { "rate" : """13""" },
    { "rate" : """0.5""" },
    { "rate" : """0.55""" },
    { "rate" : """0.9""" },
    { "rate" : """3.99999""" },
    { "rate" : """13.9999""" },
    { "rate" : """20""" },
    { "rate" : """4.998""" },
    { "rate" : """3""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.5""" },
    { "rate" : """7.99999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """0.97999""" },
    { "rate" : """20""" },
    { "rate" : """13.8""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """13""" },
    { "rate" : """2.99""" },
    { "rate" : """4""" },
    { "rate" : """4.8""" },
    { "rate" : """17""" },
    { "rate" : """4""" },
    { "rate" : """25""" },
    { "rate" : """8""" },
    { "rate" : """1.8""" },
    { "rate" : """5""" },
    { "rate" : """1.3""" },
    { "rate" : """8""" },
    { "rate" : """1.9""" },
    { "rate" : """1.8999""" },
    { "rate" : """18""" },
    { "rate" : """1.99""" },
    { "rate" : """1.95""" },
    { "rate" : """7""" },
    { "rate" : """1.94""" },
    { "rate" : """9""" },
    { "rate" : """1.89999""" },
    { "rate" : """8.99999""" },
    { "rate" : """9""" },
    { "rate" : """4.16667""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6.25""" },
    { "rate" : """14.9799""" },
    { "rate" : """2.5""" },
    { "rate" : """19.99""" },
    { "rate" : """3""" },
    { "rate" : """2.999""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """2.999""" },
    { "rate" : """14.99""" },
    { "rate" : """4.99999""" },
    { "rate" : """1.5""" },
    { "rate" : """3""" },
    { "rate" : """1.49999""" },
    { "rate" : """1.25""" },
    { "rate" : """0.7""" },
    { "rate" : """6.66667""" },
    { "rate" : """4.99""" },
    { "rate" : """9""" },
    { "rate" : """14.96""" },
    { "rate" : """8.99999""" },
    { "rate" : """1.5""" },
    { "rate" : """13.99""" },
    { "rate" : """5""" },
    { "rate" : """17.9899""" },
    { "rate" : """3""" },
    { "rate" : """5.6""" },
    { "rate" : """8""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """3.12""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """1.5""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """8.9999""" },
    { "rate" : """2.9899""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """2.99998""" },
    { "rate" : """8.99998""" },
    { "rate" : """1.5""" },
    { "rate" : """1.4""" },
    { "rate" : """8.55556""" },
    { "rate" : """8.9799""" },
    { "rate" : """9""" },
    { "rate" : """4.8899""" },
    { "rate" : """1.5""" },
    { "rate" : """1.4998""" },
    { "rate" : """8.5""" },
    { "rate" : """7.99""" },
    { "rate" : """4.5""" },
    { "rate" : """8.99999""" },
    { "rate" : """14""" },
    { "rate" : """14""" },
    { "rate" : """8.99988""" },
    { "rate" : """15""" },
    { "rate" : """1.36111""" },
    { "rate" : """8.99999""" },
    { "rate" : """18""" },
    { "rate" : """24.9""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.998""" },
    { "rate" : """2""" },
    { "rate" : """1.5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """18""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """19.99895""" },
    { "rate" : """16.99895""" },
    { "rate" : """1.9""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.4""" },
    { "rate" : """1.98""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """1.49999""" },
    { "rate" : """17.99999""" },
    { "rate" : """8.9998""" },
    { "rate" : """8""" },
    { "rate" : """7.9""" },
    { "rate" : """9""" },
    { "rate" : """1.25""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2.9""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """1.99999""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """1.98""" },
    { "rate" : """1.98""" },
    { "rate" : """1.9""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """2.98""" },
    { "rate" : """0.33167""" },
    { "rate" : """1.5""" },
    { "rate" : """2""" },
    { "rate" : """8.99999""" },
    { "rate" : """11.99""" },
    { "rate" : """1.99999""" },
    { "rate" : """20""" },
    { "rate" : """1.49999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.5""" },
    { "rate" : """1.99989""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """18""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """1.49988""" },
    { "rate" : """20""" },
    { "rate" : """1.49888""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """1.99999""" },
    { "rate" : """8.9""" },
    { "rate" : """2""" },
    { "rate" : """20""" },
    { "rate" : """9""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.9999""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """4.87""" },
    { "rate" : """9""" },
    { "rate" : """7.1""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """1.979""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.5""" },
    { "rate" : """1.98""" },
    { "rate" : """13.99999""" },
    { "rate" : """7.999""" },
    { "rate" : """12""" },
    { "rate" : """11""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1.249""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """2.91667""" },
    { "rate" : """7""" },
    { "rate" : """14""" },
    { "rate" : """8.99""" },
    { "rate" : """14""" },
    { "rate" : """1.5""" },
    { "rate" : """7.5""" },
    { "rate" : """7.99""" },
    { "rate" : """3.99999""" },
    { "rate" : """7.9799""" },
    { "rate" : """3.99999""" },
    { "rate" : """3.8""" },
    { "rate" : """5""" },
    { "rate" : """24.75""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """7.99998""" },
    { "rate" : """9""" },
    { "rate" : """14""" },
    { "rate" : """4""" },
    { "rate" : """12.5""" },
    { "rate" : """1.49722""" },
    { "rate" : """14""" },
    { "rate" : """7.99997""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """7.9799""" },
    { "rate" : """8""" },
    { "rate" : """18""" },
    { "rate" : """3.75""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """3.5""" },
    { "rate" : """8.9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """14""" },
    { "rate" : """4.98999""" },
    { "rate" : """8.98999""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """11""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """7.99999""" },
    { "rate" : """18""" },
    { "rate" : """13""" },
    { "rate" : """7.95""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """6.99""" },
    { "rate" : """7""" },
    { "rate" : """13.9799""" },
    { "rate" : """3.7""" },
    { "rate" : """1.5""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """9.99998""" },
    { "rate" : """3""" },
    { "rate" : """1.99999""" },
    { "rate" : """17.9""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """4.15999""" },
    { "rate" : """18""" },
    { "rate" : """7""" },
    { "rate" : """1.9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """1.89999""" },
    { "rate" : """6.5""" },
    { "rate" : """1.8""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """8.99895""" },
    { "rate" : """4""" },
    { "rate" : """19.99999""" },
    { "rate" : """7""" },
    { "rate" : """3.99998""" },
    { "rate" : """5""" },
    { "rate" : """6.99999""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """14""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """13.25""" },
    { "rate" : """17""" },
    { "rate" : """6.8""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """13.5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """17""" },
    { "rate" : """8""" },
    { "rate" : """7.9""" },
    { "rate" : """9""" },
    { "rate" : """24.5""" },
    { "rate" : """8""" },
    { "rate" : """14""" },
    { "rate" : """9.5""" },
    { "rate" : """12""" },
    { "rate" : """18.5""" },
    { "rate" : """8""" },
    { "rate" : """13.99""" },
    { "rate" : """11.17""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """9.9799""" },
    { "rate" : """14""" },
    { "rate" : """9.99999""" },
    { "rate" : """6.9999""" },
    { "rate" : """3""" },
    { "rate" : """8.9""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """8.99998""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """7.95""" },
    { "rate" : """3""" },
    { "rate" : """18""" },
    { "rate" : """14""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """2.99999""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """18""" },
    { "rate" : """10""" },
    { "rate" : """2.72222""" },
    { "rate" : """6.42""" },
    { "rate" : """4.99""" },
    { "rate" : """14.9699""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """18""" },
    { "rate" : """2.99999""" },
    { "rate" : """7""" },
    { "rate" : """8.99""" },
    { "rate" : """3""" },
    { "rate" : """8.5""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """2.9999""" },
    { "rate" : """11""" },
    { "rate" : """6.9998""" },
    { "rate" : """4.998""" },
    { "rate" : """24.85""" },
    { "rate" : """5""" },
    { "rate" : """2.98""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """17""" },
    { "rate" : """18""" },
    { "rate" : """7.998""" },
    { "rate" : """9.99999""" },
    { "rate" : """8""" },
    { "rate" : """2.5""" },
    { "rate" : """18""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """9.99998""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """18""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """19.99""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """4.999""" },
    { "rate" : """10""" },
    { "rate" : """4.9799""" },
    { "rate" : """17""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """6.999""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """16""" },
    { "rate" : """8""" },
    { "rate" : """6.9""" },
    { "rate" : """8""" },
    { "rate" : """18""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """4.75""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.9799""" },
    { "rate" : """17""" },
    { "rate" : """4.99999""" },
    { "rate" : """13.99998""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """9.9""" },
    { "rate" : """4.9""" },
    { "rate" : """2.95""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """2.49999""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """2.5""" },
    { "rate" : """9.99""" },
    { "rate" : """12.99999""" },
    { "rate" : """2.7399""" },
    { "rate" : """2.4""" },
    { "rate" : """9.9""" },
    { "rate" : """4.8""" },
    { "rate" : """2.5""" },
    { "rate" : """9""" },
    { "rate" : """9.9799""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """2.4""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """13""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """11.99999""" },
    { "rate" : """8.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.9""" },
    { "rate" : """2.5""" },
    { "rate" : """13""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """2.5""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """2.94999""" },
    { "rate" : """11.99999""" },
    { "rate" : """13""" },
    { "rate" : """17""" },
    { "rate" : """11.9998""" },
    { "rate" : """12""" },
    { "rate" : """13""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """11.25""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """18""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """4.89999""" },
    { "rate" : """15""" },
    { "rate" : """13.79""" },
    { "rate" : """8.9799""" },
    { "rate" : """17.75""" },
    { "rate" : """13""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """11.99998""" },
    { "rate" : """12.99999""" },
    { "rate" : """14""" },
    { "rate" : """6.98""" },
    { "rate" : """18""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """1.33333""" },
    { "rate" : """6.99""" },
    { "rate" : """17.99""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """14""" },
    { "rate" : """30""" },
    { "rate" : """12""" },
    { "rate" : """26.8""" },
    { "rate" : """4.8""" },
    { "rate" : """6.9""" },
    { "rate" : """7""" },
    { "rate" : """14""" },
    { "rate" : """13.979""" },
    { "rate" : """6.99999""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """4.899""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """9.79""" },
    { "rate" : """6.89""" },
    { "rate" : """14.999""" },
    { "rate" : """11.99998""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """18""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """7""" },
    { "rate" : """17.89""" },
    { "rate" : """10""" },
    { "rate" : """14.9""" },
    { "rate" : """8.75""" },
    { "rate" : """4.66667""" },
    { "rate" : """1.98""" },
    { "rate" : """12""" },
    { "rate" : """17.05""" },
    { "rate" : """13.9""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """5.81""" },
    { "rate" : """4.5""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """19.99999""" },
    { "rate" : """7""" },
    { "rate" : """11.99999""" },
    { "rate" : """7""" },
    { "rate" : """20""" },
    { "rate" : """9""" },
    { "rate" : """7.7""" },
    { "rate" : """17""" },
    { "rate" : """20""" },
    { "rate" : """11""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """17""" },
    { "rate" : """10""" },
    { "rate" : """5.99999""" },
    { "rate" : """4""" },
    { "rate" : """4.9""" },
    { "rate" : """4.899""" },
    { "rate" : """4""" },
    { "rate" : """4.89999""" },
    { "rate" : """20""" },
    { "rate" : """4""" },
    { "rate" : """3.99""" },
    { "rate" : """18""" },
    { "rate" : """15""" },
    { "rate" : """11.9""" },
    { "rate" : """17""" },
    { "rate" : """7.91667""" },
    { "rate" : """14.99999""" },
    { "rate" : """19.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """11.99999""" },
    { "rate" : """4.79999""" },
    { "rate" : """6.99998""" },
    { "rate" : """14""" },
    { "rate" : """13""" },
    { "rate" : """9.9979""" },
    { "rate" : """20""" },
    { "rate" : """6.87""" },
    { "rate" : """13.88""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """6.99""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.99""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """17""" },
    { "rate" : """14.9""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """14.999""" },
    { "rate" : """3""" },
    { "rate" : """13""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """2.8""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """0.99899""" },
    { "rate" : """1""" },
    { "rate" : """0.97222""" },
    { "rate" : """9.72222""" },
    { "rate" : """2.91667""" },
    { "rate" : """6.9""" },
    { "rate" : """7.9""" },
    { "rate" : """7.9""" },
    { "rate" : """3""" },
    { "rate" : """14""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.99979""" },
    { "rate" : """7.89999""" },
    { "rate" : """16.99998""" },
    { "rate" : """0.97""" },
    { "rate" : """6""" },
    { "rate" : """7.99998""" },
    { "rate" : """10""" },
    { "rate" : """5.22""" },
    { "rate" : """2""" },
    { "rate" : """9.99998""" },
    { "rate" : """0.98""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """16.99""" },
    { "rate" : """0.99""" },
    { "rate" : """7.9""" },
    { "rate" : """1""" },
    { "rate" : """14.99""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """6.87""" },
    { "rate" : """6.87""" },
    { "rate" : """11""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """6.8699""" },
    { "rate" : """14""" },
    { "rate" : """1""" },
    { "rate" : """6.9""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2.75""" },
    { "rate" : """7.99999""" },
    { "rate" : """14""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2.25""" },
    { "rate" : """0.98999""" },
    { "rate" : """1""" },
    { "rate" : """7.99998""" },
    { "rate" : """7""" },
    { "rate" : """19.99998""" },
    { "rate" : """1""" },
    { "rate" : """14.9""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2.75""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """7.95""" },
    { "rate" : """2.75""" },
    { "rate" : """15""" },
    { "rate" : """13""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2.75""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """14.9999""" },
    { "rate" : """19.999""" },
    { "rate" : """7.999""" },
    { "rate" : """14""" },
    { "rate" : """13""" },
    { "rate" : """1""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """2.75""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """14""" },
    { "rate" : """14""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """13""" },
    { "rate" : """20""" },
    { "rate" : """0.99""" },
    { "rate" : """0.9999""" },
    { "rate" : """13.75""" },
    { "rate" : """1""" },
    { "rate" : """7.95""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """7.999""" },
    { "rate" : """9""" },
    { "rate" : """2.75""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """7.9998""" },
    { "rate" : """7.9998""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """0.99998""" },
    { "rate" : """18""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """5.99998""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """14""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """1""" },
    { "rate" : """0.99""" },
    { "rate" : """2""" },
    { "rate" : """13""" },
    { "rate" : """8.33333""" },
    { "rate" : """7""" },
    { "rate" : """20""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """7""" },
    { "rate" : """13""" },
    { "rate" : """13.99998""" },
    { "rate" : """0.99998""" },
    { "rate" : """12""" },
    { "rate" : """18""" },
    { "rate" : """8""" },
    { "rate" : """7.99899""" },
    { "rate" : """16""" },
    { "rate" : """4.5""" },
    { "rate" : """19""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """16.5""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """3.5""" },
    { "rate" : """4.75""" },
    { "rate" : """14""" },
    { "rate" : """16""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """6""" },
    { "rate" : """17""" },
    { "rate" : """13.99999""" },
    { "rate" : """14.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """18""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """14""" },
    { "rate" : """14.8999""" },
    { "rate" : """0.9""" },
    { "rate" : """12.75""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.9999""" },
    { "rate" : """5""" },
    { "rate" : """18""" },
    { "rate" : """18""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """3.49999""" },
    { "rate" : """3.5""" },
    { "rate" : """13""" },
    { "rate" : """3.49999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """12.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """4.89999""" },
    { "rate" : """3.5""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """4.99998""" },
    { "rate" : """2""" },
    { "rate" : """7.9""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """4.8""" },
    { "rate" : """13""" },
    { "rate" : """4.9979""" },
    { "rate" : """7""" },
    { "rate" : """13""" },
    { "rate" : """4.8""" },
    { "rate" : """4""" },
    { "rate" : """4.9979""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.99995""" },
    { "rate" : """7.95""" },
    { "rate" : """17.5""" },
    { "rate" : """4.5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """12""" },
    { "rate" : """0.99998""" },
    { "rate" : """0.99""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99998""" },
    { "rate" : """5""" },
    { "rate" : """0.99""" },
    { "rate" : """10""" },
    { "rate" : """4.99999""" },
    { "rate" : """15""" },
    { "rate" : """3.5""" },
    { "rate" : """0.99989""" },
    { "rate" : """15""" },
    { "rate" : """3.5""" },
    { "rate" : """2""" },
    { "rate" : """18""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """3.5""" },
    { "rate" : """9.98""" },
    { "rate" : """9.98""" },
    { "rate" : """0.99999""" },
    { "rate" : """4.9999""" },
    { "rate" : """13""" },
    { "rate" : """9""" },
    { "rate" : """4.99998""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """0.999""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """9.8978""" },
    { "rate" : """1""" },
    { "rate" : """0.95""" },
    { "rate" : """0.999""" },
    { "rate" : """1""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """3.49""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99979""" },
    { "rate" : """1""" },
    { "rate" : """0.99979""" },
    { "rate" : """0.99989""" },
    { "rate" : """0.99989""" },
    { "rate" : """7""" },
    { "rate" : """9.99998""" },
    { "rate" : """9.8973""" },
    { "rate" : """18""" },
    { "rate" : """7.5""" },
    { "rate" : """7.9""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """9.998""" },
    { "rate" : """9.999""" },
    { "rate" : """3.49""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """19.9""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """7.9""" },
    { "rate" : """7.998""" },
    { "rate" : """9.99""" },
    { "rate" : """8.5""" },
    { "rate" : """8""" },
    { "rate" : """9.9""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7.99999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """8.99999""" },
    { "rate" : """15""" },
    { "rate" : """17""" },
    { "rate" : """17.99999""" },
    { "rate" : """1""" },
    { "rate" : """18""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """9.8""" },
    { "rate" : """9.97""" },
    { "rate" : """15""" },
    { "rate" : """1.9""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """4.876""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """7.9999""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """7.9""" },
    { "rate" : """3.5""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """4.9""" },
    { "rate" : """18""" },
    { "rate" : """18""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """0.99998""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """18""" },
    { "rate" : """7""" },
    { "rate" : """4.9998""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """18""" },
    { "rate" : """3.5""" },
    { "rate" : """20""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """90""" },
    { "rate" : """1""" },
    { "rate" : """3.5""" },
    { "rate" : """30""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.5""" },
    { "rate" : """7""" },
    { "rate" : """25""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """12.73""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """0.9""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """6.5""" },
    { "rate" : """9""" },
    { "rate" : """7.9799""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """7.9""" },
    { "rate" : """1""" },
    { "rate" : """14.99999""" },
    { "rate" : """8.99999""" },
    { "rate" : """1""" },
    { "rate" : """12.99998""" },
    { "rate" : """3.5""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """4.9""" },
    { "rate" : """20""" },
    { "rate" : """13""" },
    { "rate" : """9""" },
    { "rate" : """8.99999""" },
    { "rate" : """1.995""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """4.5""" },
    { "rate" : """1.999""" },
    { "rate" : """1.95""" },
    { "rate" : """1.9753""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """1.99999""" },
    { "rate" : """3.49998""" },
    { "rate" : """7.99998""" },
    { "rate" : """3.5""" },
    { "rate" : """1.999""" },
    { "rate" : """1.5""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """9.1""" },
    { "rate" : """5""" },
    { "rate" : """4.6""" },
    { "rate" : """3.499""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """0.99""" },
    { "rate" : """0.85""" },
    { "rate" : """9""" },
    { "rate" : """12.5""" },
    { "rate" : """3.49999""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """25""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """14.9""" },
    { "rate" : """9""" },
    { "rate" : """0.99999""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """24.99999""" },
    { "rate" : """17.9""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.98""" },
    { "rate" : """2""" },
    { "rate" : """3.49""" },
    { "rate" : """2""" },
    { "rate" : """8.99""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """18""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """4.5""" },
    { "rate" : """8.99""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """17""" },
    { "rate" : """9""" },
    { "rate" : """1.5""" },
    { "rate" : """1.9979""" },
    { "rate" : """2""" },
    { "rate" : """3.5""" },
    { "rate" : """1.9998""" },
    { "rate" : """2.88888""" },
    { "rate" : """10""" },
    { "rate" : """1.9999""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """7.9999""" },
    { "rate" : """3.5""" },
    { "rate" : """7""" },
    { "rate" : """1.9998""" },
    { "rate" : """1.9998""" },
    { "rate" : """3.5""" },
    { "rate" : """2""" },
    { "rate" : """3.5""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """3.5""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """12.99998""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """18""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """2.8""" },
    { "rate" : """3.2""" },
    { "rate" : """3""" },
    { "rate" : """2.99999""" },
    { "rate" : """15""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """2.5""" },
    { "rate" : """10""" },
    { "rate" : """8.99999""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """0.95""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """0.99""" },
    { "rate" : """9.5""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """4.5""" },
    { "rate" : """6.25""" },
    { "rate" : """10""" },
    { "rate" : """3.49999""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """6""" },
    { "rate" : """9.99998""" },
    { "rate" : """3""" },
    { "rate" : """2.99895""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """14""" },
    { "rate" : """3.4999""" },
    { "rate" : """2.99999""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """5.99999""" },
    { "rate" : """0.1""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """25""" },
    { "rate" : """10""" },
    { "rate" : """6.99999""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """5.99999""" },
    { "rate" : """5.9""" },
    { "rate" : """2.9""" },
    { "rate" : """13""" },
    { "rate" : """9.99999""" },
    { "rate" : """4.9""" },
    { "rate" : """7""" },
    { "rate" : """3.5""" },
    { "rate" : """4.9979""" },
    { "rate" : """6""" },
    { "rate" : """1.8""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """7.8""" },
    { "rate" : """10""" },
    { "rate" : """3.49999""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """7""" },
    { "rate" : """1.9979""" },
    { "rate" : """1.99999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1.94""" },
    { "rate" : """1.75""" },
    { "rate" : """1.75""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """4.9""" },
    { "rate" : """4""" },
    { "rate" : """1.9999""" },
    { "rate" : """6""" },
    { "rate" : """6.5999""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """1.5""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """1.9999""" },
    { "rate" : """1.9999""" },
    { "rate" : """6.89""" },
    { "rate" : """9.89""" },
    { "rate" : """6.89""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """1.95""" },
    { "rate" : """1.99""" },
    { "rate" : """1.99""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """1.99999""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """4.9999""" },
    { "rate" : """4.9""" },
    { "rate" : """4.58333""" },
    { "rate" : """9.5""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """4.5""" },
    { "rate" : """7""" },
    { "rate" : """3.5""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """7.8""" },
    { "rate" : """6.9393""" },
    { "rate" : """4""" },
    { "rate" : """4.999""" },
    { "rate" : """5""" },
    { "rate" : """3.2""" },
    { "rate" : """3.1""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """1.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """14.16667""" },
    { "rate" : """6""" },
    { "rate" : """4.8""" },
    { "rate" : """10""" },
    { "rate" : """4.95""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """9.99999""" },
    { "rate" : """4.99997""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """7""" },
    { "rate" : """10.99999""" },
    { "rate" : """1.4999""" },
    { "rate" : """7""" },
    { "rate" : """1.6""" },
    { "rate" : """1""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """1.49999""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """1.4""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """10.99998""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """4.999""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9""" },
    { "rate" : """7.97""" },
    { "rate" : """10.99994""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """1.49999""" },
    { "rate" : """0.999""" },
    { "rate" : """5""" },
    { "rate" : """1.498""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10.9979""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """3.25""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """6.99998""" },
    { "rate" : """3.45""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """7""" },
    { "rate" : """6.99999""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """3.49999""" },
    { "rate" : """3.45""" },
    { "rate" : """3.5""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.99998""" },
    { "rate" : """12.5""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """4.5""" },
    { "rate" : """4.9""" },
    { "rate" : """3.49998""" },
    { "rate" : """3.4""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """6.99998""" },
    { "rate" : """3.49985""" },
    { "rate" : """3.30556""" },
    { "rate" : """4.5""" },
    { "rate" : """4.8""" },
    { "rate" : """5.99999""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """9.99""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """3.5""" },
    { "rate" : """1""" },
    { "rate" : """0.6""" },
    { "rate" : """0.495""" },
    { "rate" : """0.5""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """3.1""" },
    { "rate" : """6.5""" },
    { "rate" : """4.94""" },
    { "rate" : """3.4""" },
    { "rate" : """6.9999""" },
    { "rate" : """4.8""" },
    { "rate" : """2.91667""" },
    { "rate" : """5.9""" },
    { "rate" : """3.49""" },
    { "rate" : """6.4444""" },
    { "rate" : """4.999""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7.5""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """4.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """3.88889""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """5.9799""" },
    { "rate" : """9.99998""" },
    { "rate" : """4.99998""" },
    { "rate" : """10""" },
    { "rate" : """7.5""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5.5""" },
    { "rate" : """3.25""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """2.9""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """2.9""" },
    { "rate" : """6.99""" },
    { "rate" : """10""" },
    { "rate" : """2.99999""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """7.77778""" },
    { "rate" : """4""" },
    { "rate" : """2.9""" },
    { "rate" : """8""" },
    { "rate" : """4.8""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """4.99999""" },
    { "rate" : """10""" },
    { "rate" : """0.98""" },
    { "rate" : """6.99""" },
    { "rate" : """0.82099""" },
    { "rate" : """4.99""" },
    { "rate" : """2.99""" },
    { "rate" : """6.99""" },
    { "rate" : """7.76778""" },
    { "rate" : """2.99997""" },
    { "rate" : """12""" },
    { "rate" : """0.9""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """0.798""" },
    { "rate" : """7.99999""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """0.91989""" },
    { "rate" : """9.99""" },
    { "rate" : """4""" },
    { "rate" : """3.99999""" },
    { "rate" : """4.1""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """3.99999""" },
    { "rate" : """4.099""" },
    { "rate" : """4.5""" },
    { "rate" : """3""" },
    { "rate" : """3.74999""" },
    { "rate" : """4.8""" },
    { "rate" : """3.9""" },
    { "rate" : """4.1""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """4.1""" },
    { "rate" : """4.1""" },
    { "rate" : """3""" },
    { "rate" : """3.999""" },
    { "rate" : """5""" },
    { "rate" : """4.099""" },
    { "rate" : """6.49979""" },
    { "rate" : """7""" },
    { "rate" : """7.99999""" },
    { "rate" : """6.5""" },
    { "rate" : """4.099""" },
    { "rate" : """5""" },
    { "rate" : """4.09999""" },
    { "rate" : """4.1""" },
    { "rate" : """4.8""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4.79""" },
    { "rate" : """4.1""" },
    { "rate" : """4""" },
    { "rate" : """10.99999""" },
    { "rate" : """11""" },
    { "rate" : """3""" },
    { "rate" : """4.8""" },
    { "rate" : """4.9""" },
    { "rate" : """10.83333""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """8.99999""" },
    { "rate" : """4.9999""" },
    { "rate" : """12.5""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """4.99""" },
    { "rate" : """2.98""" },
    { "rate" : """4.9""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """4.87""" },
    { "rate" : """3""" },
    { "rate" : """9.9""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """7.8""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """6.8""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """2.99999""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """11""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """0.1""" },
    { "rate" : """8.3""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """10.75""" },
    { "rate" : """8""" },
    { "rate" : """8.75""" },
    { "rate" : """6.99""" },
    { "rate" : """7""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """11.75""" },
    { "rate" : """2.99998""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """3.5""" },
    { "rate" : """4.49999""" },
    { "rate" : """3.5""" },
    { "rate" : """3.49999""" },
    { "rate" : """10""" },
    { "rate" : """3.3""" },
    { "rate" : """7""" },
    { "rate" : """2.9""" },
    { "rate" : """2.99999""" },
    { "rate" : """3.49999""" },
    { "rate" : """10.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """6""" },
    { "rate" : """11.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """9.9""" },
    { "rate" : """3.49999""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """1.9""" },
    { "rate" : """11""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """2.9999""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """3.75""" },
    { "rate" : """11""" },
    { "rate" : """29.98999""" },
    { "rate" : """3.49""" },
    { "rate" : """12.48999""" },
    { "rate" : """10.99""" },
    { "rate" : """2.99""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.6""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """10.987""" },
    { "rate" : """6""" },
    { "rate" : """8.99""" },
    { "rate" : """4.99""" },
    { "rate" : """9.99""" },
    { "rate" : """2.73""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """2.95""" },
    { "rate" : """2.9998""" },
    { "rate" : """6""" },
    { "rate" : """5.3""" },
    { "rate" : """4""" },
    { "rate" : """7.5""" },
    { "rate" : """10""" },
    { "rate" : """3.8""" },
    { "rate" : """9.89""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """11""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """9.5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """9.9""" },
    { "rate" : """2.99""" },
    { "rate" : """9.5""" },
    { "rate" : """0.99998""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """11""" },
    { "rate" : """7""" },
    { "rate" : """11""" },
    { "rate" : """11""" },
    { "rate" : """15""" },
    { "rate" : """5.75""" },
    { "rate" : """7.29""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """10.99895""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """7.25""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """8.25""" },
    { "rate" : """5""" },
    { "rate" : """1.99999""" },
    { "rate" : """5.75""" },
    { "rate" : """7""" },
    { "rate" : """4.99999""" },
    { "rate" : """1""" },
    { "rate" : """5.5""" },
    { "rate" : """4.47222""" },
    { "rate" : """10.5""" },
    { "rate" : """7""" },
    { "rate" : """9.99""" },
    { "rate" : """4.5""" },
    { "rate" : """1""" },
    { "rate" : """11""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """19""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """7.988""" },
    { "rate" : """10""" },
    { "rate" : """0.99999""" },
    { "rate" : """4.9999""" },
    { "rate" : """10.99999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """6.4""" },
    { "rate" : """6.65999""" },
    { "rate" : """6.6""" },
    { "rate" : """6""" },
    { "rate" : """6.39999""" },
    { "rate" : """4.5""" },
    { "rate" : """6.65""" },
    { "rate" : """6.5""" },
    { "rate" : """6.666""" },
    { "rate" : """6.6666""" },
    { "rate" : """6.31999""" },
    { "rate" : """6.66""" },
    { "rate" : """6.66""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1.5""" },
    { "rate" : """11""" },
    { "rate" : """11""" },
    { "rate" : """15""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """4.5""" },
    { "rate" : """6.6""" },
    { "rate" : """5""" },
    { "rate" : """7.29""" },
    { "rate" : """1.9""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4.9999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """2.975""" },
    { "rate" : """9.5""" },
    { "rate" : """13.25""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """11""" },
    { "rate" : """4.33333""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """11.975""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """4.5""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """11.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """14.99""" },
    { "rate" : """4.98999""" },
    { "rate" : """9.89""" },
    { "rate" : """4.99""" },
    { "rate" : """1.49""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """4.4""" },
    { "rate" : """7.7""" },
    { "rate" : """9.9""" },
    { "rate" : """1.1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """11""" },
    { "rate" : """9.995""" },
    { "rate" : """0.01""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """7.32333""" },
    { "rate" : """9.89""" },
    { "rate" : """5.99""" },
    { "rate" : """9.9""" },
    { "rate" : """9.83979""" },
    { "rate" : """9.9998""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.87""" },
    { "rate" : """9.99999""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """9.8""" },
    { "rate" : """9.99""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """11""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """0.99998""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """3.9393""" },
    { "rate" : """8.99""" },
    { "rate" : """3""" },
    { "rate" : """9.99999""" },
    { "rate" : """5.5""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """10.89""" },
    { "rate" : """11.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """4.89""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10.99998""" },
    { "rate" : """1""" },
    { "rate" : """7.99998""" },
    { "rate" : """7.28999""" },
    { "rate" : """1.5""" },
    { "rate" : """5""" },
    { "rate" : """4.8""" },
    { "rate" : """10.55""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """4.8""" },
    { "rate" : """9""" },
    { "rate" : """4.89""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """9.9""" },
    { "rate" : """6.5""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """3.9393""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """1.5""" },
    { "rate" : """11""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """14""" },
    { "rate" : """9.9""" },
    { "rate" : """5.49""" },
    { "rate" : """9.9899""" },
    { "rate" : """9.99999""" },
    { "rate" : """4.99""" },
    { "rate" : """4.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """8.99999""" },
    { "rate" : """4.9""" },
    { "rate" : """0.99999""" },
    { "rate" : """9.99""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """10.99""" },
    { "rate" : """12""" },
    { "rate" : """4.99""" },
    { "rate" : """1.9""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """9""" },
    { "rate" : """4.9""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """11""" },
    { "rate" : """8.99999""" },
    { "rate" : """8.999""" },
    { "rate" : """5.99""" },
    { "rate" : """0.99""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """4.89999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """3.3333""" },
    { "rate" : """4.9""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """1.99995""" },
    { "rate" : """10.5""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """20""" },
    { "rate" : """7.29""" },
    { "rate" : """15""" },
    { "rate" : """11.5""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """12.5""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """9.9999""" },
    { "rate" : """10""" },
    { "rate" : """6.5""" },
    { "rate" : """9.9999""" },
    { "rate" : """11""" },
    { "rate" : """20""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """15.2""" },
    { "rate" : """19.95""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """15""" },
    { "rate" : """3.99""" },
    { "rate" : """4.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """8.7""" },
    { "rate" : """4.2""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """0.49999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """8.99999""" },
    { "rate" : """13.13""" },
    { "rate" : """15""" },
    { "rate" : """24""" },
    { "rate" : """0.5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.99999""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """1.5""" },
    { "rate" : """8.9999""" },
    { "rate" : """7""" },
    { "rate" : """2.8""" },
    { "rate" : """8""" },
    { "rate" : """8.99998""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """8.9999""" },
    { "rate" : """4.9998""" },
    { "rate" : """5""" },
    { "rate" : """8.9""" },
    { "rate" : """4.9999""" },
    { "rate" : """29.988""" },
    { "rate" : """6.9393""" },
    { "rate" : """11""" },
    { "rate" : """8.9""" },
    { "rate" : """5.5""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """7.25""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.9999""" },
    { "rate" : """7""" },
    { "rate" : """19.9111""" },
    { "rate" : """9""" },
    { "rate" : """6.9999""" },
    { "rate" : """14""" },
    { "rate" : """22""" },
    { "rate" : """7""" },
    { "rate" : """7.25""" },
    { "rate" : """19""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """14.5""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """24.99""" },
    { "rate" : """9.99""" },
    { "rate" : """25""" },
    { "rate" : """8.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """7""" },
    { "rate" : """1.92""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """4.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """7""" },
    { "rate" : """4.99""" },
    { "rate" : """0.98999""" },
    { "rate" : """8.99""" },
    { "rate" : """8.95""" },
    { "rate" : """8.94""" },
    { "rate" : """1.95""" },
    { "rate" : """3.25""" },
    { "rate" : """7""" },
    { "rate" : """8.9""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """2.25""" },
    { "rate" : """5""" },
    { "rate" : """1.99999""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """12.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.9998""" },
    { "rate" : """2""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """1.99895""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """16""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """1.99999""" },
    { "rate" : """10""" },
    { "rate" : """1.99998""" },
    { "rate" : """1""" },
    { "rate" : """0.9999""" },
    { "rate" : """6.99999""" },
    { "rate" : """1.11111""" },
    { "rate" : """15""" },
    { "rate" : """0.98""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """8.99999""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """6.3""" },
    { "rate" : """4""" },
    { "rate" : """8.99999""" },
    { "rate" : """0.75""" },
    { "rate" : """5.99999""" },
    { "rate" : """5.999""" },
    { "rate" : """4.49999""" },
    { "rate" : """6""" },
    { "rate" : """0.5""" },
    { "rate" : """5.5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """0.45""" },
    { "rate" : """4.5""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """4.8""" },
    { "rate" : """23.75""" },
    { "rate" : """4.4""" },
    { "rate" : """7.99841""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """8.9""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """9.998""" },
    { "rate" : """3.5""" },
    { "rate" : """0.9998""" },
    { "rate" : """0.5""" },
    { "rate" : """5.99999""" },
    { "rate" : """2""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """4.5""" },
    { "rate" : """8.79""" },
    { "rate" : """2""" },
    { "rate" : """4.89""" },
    { "rate" : """4.89""" },
    { "rate" : """7.5""" },
    { "rate" : """5""" },
    { "rate" : """4.9989""" },
    { "rate" : """4.99999""" },
    { "rate" : """0.89999""" },
    { "rate" : """1.99999""" },
    { "rate" : """11.9989""" },
    { "rate" : """14.99999""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5.5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """1.66667""" },
    { "rate" : """5.5""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """8.8999""" },
    { "rate" : """8.99""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """7.9""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """4.99895""" },
    { "rate" : """9""" },
    { "rate" : """11.7""" },
    { "rate" : """7.9""" },
    { "rate" : """4.5""" },
    { "rate" : """18.5""" },
    { "rate" : """5.5""" },
    { "rate" : """9.9""" },
    { "rate" : """14.89""" },
    { "rate" : """7.29""" },
    { "rate" : """5""" },
    { "rate" : """5.5""" },
    { "rate" : """6.6""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """5.83334""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """7.5""" },
    { "rate" : """7""" },
    { "rate" : """8.9""" },
    { "rate" : """6""" },
    { "rate" : """5.49""" },
    { "rate" : """5""" },
    { "rate" : """5.9""" },
    { "rate" : """9""" },
    { "rate" : """14""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """20""" },
    { "rate" : """5.999""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5.85""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """1.99""" },
    { "rate" : """10.7""" },
    { "rate" : """4""" },
    { "rate" : """8.75""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """12.5""" },
    { "rate" : """5.41667""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """9.9""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """8.99999""" },
    { "rate" : """1.95""" },
    { "rate" : """6.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """8.99""" },
    { "rate" : """5""" },
    { "rate" : """7.9999""" },
    { "rate" : """15""" },
    { "rate" : """8.9""" },
    { "rate" : """14""" },
    { "rate" : """7.5""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """6.5""" },
    { "rate" : """14.99999""" },
    { "rate" : """10""" },
    { "rate" : """5.99999""" },
    { "rate" : """7""" },
    { "rate" : """8.88888""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6.49""" },
    { "rate" : """8.9""" },
    { "rate" : """6""" },
    { "rate" : """8.8""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """5.99""" },
    { "rate" : """7""" },
    { "rate" : """8.9799""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """14.99""" },
    { "rate" : """7.69""" },
    { "rate" : """9.99""" },
    { "rate" : """7.5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5.99999""" },
    { "rate" : """25""" },
    { "rate" : """6.99998""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """8""" },
    { "rate" : """14.99999""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """12.49999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1.7""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """11.9""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9.99998""" },
    { "rate" : """7""" },
    { "rate" : """1.4989""" },
    { "rate" : """5""" },
    { "rate" : """9.99""" },
    { "rate" : """14.99999""" },
    { "rate" : """7""" },
    { "rate" : """13.8""" },
    { "rate" : """5.989""" },
    { "rate" : """15""" },
    { "rate" : """2.5""" },
    { "rate" : """7.7""" },
    { "rate" : """2.5""" },
    { "rate" : """10""" },
    { "rate" : """1.67222""" },
    { "rate" : """2.5""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """11""" },
    { "rate" : """2.5""" },
    { "rate" : """5.45""" },
    { "rate" : """2.5""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """2.5""" },
    { "rate" : """2.49""" },
    { "rate" : """2.49""" },
    { "rate" : """6.9""" },
    { "rate" : """2.2""" },
    { "rate" : """0.9""" },
    { "rate" : """10""" },
    { "rate" : """0.99999""" },
    { "rate" : """5.8""" },
    { "rate" : """10""" },
    { "rate" : """2.4999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """14.8999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5.99""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """25""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """7.29""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """14.99998""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5.99999""" },
    { "rate" : """9.99998""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """8.17""" },
    { "rate" : """14""" },
    { "rate" : """5.99999""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5.5""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """9.89""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """5.98899""" },
    { "rate" : """4.99999""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """9.5""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """13.9""" },
    { "rate" : """7.9393""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """14.99999""" },
    { "rate" : """5.5""" },
    { "rate" : """9.49999""" },
    { "rate" : """7.29""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9.9""" },
    { "rate" : """5""" },
    { "rate" : """7.2""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """20""" },
    { "rate" : """5.8""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """9.2""" },
    { "rate" : """6.99998""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """1.65""" },
    { "rate" : """12.25""" },
    { "rate" : """9.2""" },
    { "rate" : """15""" },
    { "rate" : """5.99799""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """8.99895""" },
    { "rate" : """4.99895""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """19.9999""" },
    { "rate" : """9.9""" },
    { "rate" : """14.14""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """9.19999""" },
    { "rate" : """14.99999""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.98""" },
    { "rate" : """3""" },
    { "rate" : """2.9""" },
    { "rate" : """5.5""" },
    { "rate" : """1.7""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9.5""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """0.01""" },
    { "rate" : """15""" },
    { "rate" : """20""" },
    { "rate" : """14.7""" },
    { "rate" : """9.5""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.7""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """13""" },
    { "rate" : """2""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """14.9""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """2""" },
    { "rate" : """1.9999""" },
    { "rate" : """1.9999""" },
    { "rate" : """9.99999""" },
    { "rate" : """2""" },
    { "rate" : """11.99999""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """0.9""" },
    { "rate" : """1.7""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """1.99939""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """14.5""" },
    { "rate" : """1.9989""" },
    { "rate" : """5""" },
    { "rate" : """1.9""" },
    { "rate" : """9.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.99999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """4.95""" },
    { "rate" : """9.99""" },
    { "rate" : """1.9""" },
    { "rate" : """1.9989""" },
    { "rate" : """15""" },
    { "rate" : """1.6999""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """14""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1.69""" },
    { "rate" : """9.49""" },
    { "rate" : """4""" },
    { "rate" : """9.99""" },
    { "rate" : """14.99""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9.9""" },
    { "rate" : """5.5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """1.99""" },
    { "rate" : """1.998""" },
    { "rate" : """10""" },
    { "rate" : """0.99999""" },
    { "rate" : """2.99999""" },
    { "rate" : """11.99998""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """6.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """1""" },
    { "rate" : """10.99999""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """9.999""" },
    { "rate" : """14.999""" },
    { "rate" : """1.8956""" },
    { "rate" : """4.98999""" },
    { "rate" : """1.99999""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """9.99998""" },
    { "rate" : """1.699""" },
    { "rate" : """5.9999""" },
    { "rate" : """20""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """11.99999""" },
    { "rate" : """9.999""" },
    { "rate" : """14.99""" },
    { "rate" : """1""" },
    { "rate" : """9.99""" },
    { "rate" : """25""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """1.7""" },
    { "rate" : """29.99999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """4.99998""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """1.65278""" },
    { "rate" : """14.99""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.9999""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """2.45""" },
    { "rate" : """2""" },
    { "rate" : """4.99999""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.9999""" },
    { "rate" : """0.9999""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """1.99""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """0.9899""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """4.9999""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """6.99939""" },
    { "rate" : """14.9999""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1.9999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.95""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """4.9393""" },
    { "rate" : """0.99999""" },
    { "rate" : """2.9393""" },
    { "rate" : """5.99999""" },
    { "rate" : """0.98""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """7.29""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """11.5""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """4.999""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """9.99999""" },
    { "rate" : """35""" },
    { "rate" : """5""" },
    { "rate" : """1.99999""" },
    { "rate" : """15""" },
    { "rate" : """14.89""" },
    { "rate" : """4.8""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """0.9999""" },
    { "rate" : """5.89""" },
    { "rate" : """15""" },
    { "rate" : """1.8""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """1.9""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """3""" },
    { "rate" : """0.99999""" },
    { "rate" : """5""" },
    { "rate" : """7.77778""" },
    { "rate" : """4.66667""" },
    { "rate" : """0.97222""" },
    { "rate" : """2.91667""" },
    { "rate" : """8""" },
    { "rate" : """13""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """0.5""" },
    { "rate" : """3""" },
    { "rate" : """14.99999""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """1.1""" },
    { "rate" : """6.6""" },
    { "rate" : """22.5""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """1.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """5.99999""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """0.9""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """9.9""" },
    { "rate" : """3""" },
    { "rate" : """2.999""" },
    { "rate" : """5.9""" },
    { "rate" : """11""" },
    { "rate" : """11""" },
    { "rate" : """4.9999""" },
    { "rate" : """18""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """4.4""" },
    { "rate" : """12""" },
    { "rate" : """0.99""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """4.9995""" },
    { "rate" : """3.75""" },
    { "rate" : """2""" },
    { "rate" : """2.45""" },
    { "rate" : """4.7""" },
    { "rate" : """2""" },
    { "rate" : """0.99""" },
    { "rate" : """5""" },
    { "rate" : """0.98888""" },
    { "rate" : """2.9""" },
    { "rate" : """4""" },
    { "rate" : """1.99""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """1.9""" },
    { "rate" : """4.99999""" },
    { "rate" : """14""" },
    { "rate" : """1.99""" },
    { "rate" : """3.5""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """14.9""" },
    { "rate" : """1.75""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """0.9999""" },
    { "rate" : """5""" },
    { "rate" : """14.9""" },
    { "rate" : """5""" },
    { "rate" : """5.99""" },
    { "rate" : """15""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """3.49999""" },
    { "rate" : """4.998""" },
    { "rate" : """11.999""" },
    { "rate" : """9.85""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """6.987""" },
    { "rate" : """5""" },
    { "rate" : """0.89999""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """3.3""" },
    { "rate" : """5""" },
    { "rate" : """2.44999""" },
    { "rate" : """0.9999""" },
    { "rate" : """2.44999""" },
    { "rate" : """3.4""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """6.85""" },
    { "rate" : """8.9""" },
    { "rate" : """7""" },
    { "rate" : """14.9""" },
    { "rate" : """0.95""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """4.99""" },
    { "rate" : """3.5""" },
    { "rate" : """2.3""" },
    { "rate" : """5""" },
    { "rate" : """1.999""" },
    { "rate" : """2.9""" },
    { "rate" : """4.4""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5.9393""" },
    { "rate" : """4.9393""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """4.8""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1.5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """2.13889""" },
    { "rate" : """2.91667""" },
    { "rate" : """3""" },
    { "rate" : """7.25""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """1""" },
    { "rate" : """4.99999""" },
    { "rate" : """1""" },
    { "rate" : """7.2""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """6.99999""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """3.26666""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """0.99997""" },
    { "rate" : """12""" },
    { "rate" : """23""" },
    { "rate" : """2.95""" },
    { "rate" : """15""" },
    { "rate" : """9.5""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """8""" },
    { "rate" : """5.5""" },
    { "rate" : """6.99999""" },
    { "rate" : """7""" },
    { "rate" : """6.6""" },
    { "rate" : """9.9""" },
    { "rate" : """6.8999""" },
    { "rate" : """1""" },
    { "rate" : """0.1""" },
    { "rate" : """0.999""" },
    { "rate" : """0.89""" },
    { "rate" : """0.98""" },
    { "rate" : """0.9""" },
    { "rate" : """7.2""" },
    { "rate" : """1""" },
    { "rate" : """5.5""" },
    { "rate" : """1""" },
    { "rate" : """4.65""" },
    { "rate" : """10""" },
    { "rate" : """0.80777""" },
    { "rate" : """7.28""" },
    { "rate" : """10""" },
    { "rate" : """10.99999""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """1.49""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1.487""" },
    { "rate" : """4.4""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """0.999""" },
    { "rate" : """4""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.9999""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """1.47799""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1.4""" },
    { "rate" : """1.477""" },
    { "rate" : """0.01""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """1.39999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """10""" },
    { "rate" : """0.99979""" },
    { "rate" : """14""" },
    { "rate" : """9.9393""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """5.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """11""" },
    { "rate" : """1""" },
    { "rate" : """0.99""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """4.4""" },
    { "rate" : """8""" },
    { "rate" : """10.99""" },
    { "rate" : """10.889""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.5""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """5.85""" },
    { "rate" : """16""" },
    { "rate" : """4.99999""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """5.5""" },
    { "rate" : """0.5""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """5.99""" },
    { "rate" : """14.99""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """0.5""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """7""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """0.5""" },
    { "rate" : """9""" },
    { "rate" : """4.97""" },
    { "rate" : """15""" },
    { "rate" : """14.9""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """0.5""" },
    { "rate" : """6.29""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """2.5""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """5.5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """0.49999""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """6.9393""" },
    { "rate" : """0.5""" },
    { "rate" : """7""" },
    { "rate" : """0.99998""" },
    { "rate" : """1""" },
    { "rate" : """2.99998""" },
    { "rate" : """0.5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """11.5""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """14.9998""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """13""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """0.9998""" },
    { "rate" : """0.49999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """0.48""" },
    { "rate" : """9.99999""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """19""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5.99999""" },
    { "rate" : """1""" },
    { "rate" : """5.83""" },
    { "rate" : """9.8""" },
    { "rate" : """4.5""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9.9""" },
    { "rate" : """6.6""" },
    { "rate" : """7.7""" },
    { "rate" : """0.55""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """14.14""" },
    { "rate" : """0.5""" },
    { "rate" : """2.2""" },
    { "rate" : """6.6""" },
    { "rate" : """4.4""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """0.5""" },
    { "rate" : """3.26667""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """7.5""" },
    { "rate" : """5.99999""" },
    { "rate" : """15""" },
    { "rate" : """6.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """9.99""" },
    { "rate" : """0.5""" },
    { "rate" : """3""" },
    { "rate" : """6.6""" },
    { "rate" : """0.97222""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """2.9""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """0.45""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """0.99""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """19""" },
    { "rate" : """12""" },
    { "rate" : """4.99""" },
    { "rate" : """2.99""" },
    { "rate" : """0.5""" },
    { "rate" : """3.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9""" },
    { "rate" : """14.9999""" },
    { "rate" : """6.98""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99939""" },
    { "rate" : """14.99999""" },
    { "rate" : """10""" },
    { "rate" : """1.99998""" },
    { "rate" : """10""" },
    { "rate" : """0.9999""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """3.99999""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """20""" },
    { "rate" : """0.9999""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """0.5""" },
    { "rate" : """5.9""" },
    { "rate" : """7""" },
    { "rate" : """4.9""" },
    { "rate" : """12""" },
    { "rate" : """6.999""" },
    { "rate" : """1.94""" },
    { "rate" : """5.3""" },
    { "rate" : """1.9393""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """4.88888""" },
    { "rate" : """5.9999""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """6.5""" },
    { "rate" : """5.99999""" },
    { "rate" : """0.49999""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.9998""" },
    { "rate" : """5""" },
    { "rate" : """0.98""" },
    { "rate" : """1.75""" },
    { "rate" : """2""" },
    { "rate" : """5.5""" },
    { "rate" : """0.89""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """1.95""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """4.5""" },
    { "rate" : """6""" },
    { "rate" : """4.9""" },
    { "rate" : """3""" },
    { "rate" : """2.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """6.5""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """17.5""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """6.5""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4.9999""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """4.99999""" },
    { "rate" : """6.61111""" },
    { "rate" : """9.99998""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """0.49""" },
    { "rate" : """0.49""" },
    { "rate" : """1.9989""" },
    { "rate" : """0.5""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """4.9393""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """6.9""" },
    { "rate" : """7""" },
    { "rate" : """2.3""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """6.99998""" },
    { "rate" : """6.9998""" },
    { "rate" : """1.99998""" },
    { "rate" : """12""" },
    { "rate" : """6.81""" },
    { "rate" : """7""" },
    { "rate" : """0.5""" },
    { "rate" : """6.9""" },
    { "rate" : """1.98""" },
    { "rate" : """1.99""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """3.26667""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """4.5""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """11""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """8.99""" },
    { "rate" : """8""" },
    { "rate" : """9.3""" },
    { "rate" : """0.5""" },
    { "rate" : """3.75""" },
    { "rate" : """0.8""" },
    { "rate" : """5""" },
    { "rate" : """6.87999""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """6.99999""" },
    { "rate" : """17""" },
    { "rate" : """0.5""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """1.945""" },
    { "rate" : """5.5""" },
    { "rate" : """9.5""" },
    { "rate" : """4.4""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """2.2""" },
    { "rate" : """14.9""" },
    { "rate" : """0.99""" },
    { "rate" : """1.9999""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """7.5""" },
    { "rate" : """6.9""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """0.99""" },
    { "rate" : """4""" },
    { "rate" : """7.5""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """0.5""" },
    { "rate" : """1""" },
    { "rate" : """12.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """12.5""" },
    { "rate" : """11.95""" },
    { "rate" : """11.43848""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """1.0101""" },
    { "rate" : """5.76""" },
    { "rate" : """4""" },
    { "rate" : """14""" },
    { "rate" : """4.9""" },
    { "rate" : """14""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """11.99999""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """1.9999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """7""" },
    { "rate" : """13.99999""" },
    { "rate" : """11.99999""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """11.99999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.4998""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """0.99993""" },
    { "rate" : """0.98""" },
    { "rate" : """1.94444""" },
    { "rate" : """11.99939""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """20""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.4""" },
    { "rate" : """0.9999""" },
    { "rate" : """1.99""" },
    { "rate" : """9.99399""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.49999""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """4.5""" },
    { "rate" : """4.49999""" },
    { "rate" : """4.5""" },
    { "rate" : """3.99999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """0.5""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """0.9809""" },
    { "rate" : """6.9""" },
    { "rate" : """1""" },
    { "rate" : """13.5""" },
    { "rate" : """13.99999""" },
    { "rate" : """4.75""" },
    { "rate" : """4.8699""" },
    { "rate" : """1""" },
    { "rate" : """13""" },
    { "rate" : """6.59""" },
    { "rate" : """1.99""" },
    { "rate" : """13.7999""" },
    { "rate" : """4.499""" },
    { "rate" : """2.99999""" },
    { "rate" : """1.88""" },
    { "rate" : """4.99""" },
    { "rate" : """0.99""" },
    { "rate" : """4.5""" },
    { "rate" : """14.99""" },
    { "rate" : """14.99""" },
    { "rate" : """12""" },
    { "rate" : """0.99999""" },
    { "rate" : """13""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """2""" },
    { "rate" : """17""" },
    { "rate" : """13.99998""" },
    { "rate" : """19.99""" },
    { "rate" : """6.99""" },
    { "rate" : """6.999""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """4""" },
    { "rate" : """0.99""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """14.2""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """7.4998""" },
    { "rate" : """20""" },
    { "rate" : """7.5""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """6.8899""" },
    { "rate" : """6.99999""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """7.9393""" },
    { "rate" : """8.99999""" },
    { "rate" : """14.998""" },
    { "rate" : """5.9""" },
    { "rate" : """5.89999""" },
    { "rate" : """5.798""" },
    { "rate" : """5.5""" },
    { "rate" : """5""" },
    { "rate" : """5.79999""" },
    { "rate" : """5.8""" },
    { "rate" : """14""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """30""" },
    { "rate" : """12""" },
    { "rate" : """5.89""" },
    { "rate" : """0.9998""" },
    { "rate" : """2""" },
    { "rate" : """5.8""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """7.4999""" },
    { "rate" : """14.99""" },
    { "rate" : """14.99999""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5.5""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """7.99""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """2.99""" },
    { "rate" : """1.99""" },
    { "rate" : """19.99""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """13.99""" },
    { "rate" : """0.5""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49999""" },
    { "rate" : """5.5""" },
    { "rate" : """7""" },
    { "rate" : """7.98""" },
    { "rate" : """12""" },
    { "rate" : """9.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """11""" },
    { "rate" : """7.5""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """7.49939""" },
    { "rate" : """0.49""" },
    { "rate" : """4.4""" },
    { "rate" : """17.9""" },
    { "rate" : """3.8""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """0.5""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """7.88""" },
    { "rate" : """4.99""" },
    { "rate" : """14.99""" },
    { "rate" : """5""" },
    { "rate" : """6.99""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """3.99999""" },
    { "rate" : """12""" },
    { "rate" : """6.9""" },
    { "rate" : """18""" },
    { "rate" : """7""" },
    { "rate" : """4.5""" },
    { "rate" : """2.9999""" },
    { "rate" : """3.5""" },
    { "rate" : """4""" },
    { "rate" : """3.3""" },
    { "rate" : """0.45""" },
    { "rate" : """3.8""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """12.5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """3.5""" },
    { "rate" : """0.41""" },
    { "rate" : """3.9""" },
    { "rate" : """0.4""" },
    { "rate" : """12""" },
    { "rate" : """6.5""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """7.5""" },
    { "rate" : """3.99""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """18""" },
    { "rate" : """4""" },
    { "rate" : """0.4999""" },
    { "rate" : """4""" },
    { "rate" : """4.99""" },
    { "rate" : """3.25""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """3.5""" },
    { "rate" : """18.34""" },
    { "rate" : """3.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.7""" },
    { "rate" : """6.99999""" },
    { "rate" : """11""" },
    { "rate" : """4.7""" },
    { "rate" : """5""" },
    { "rate" : """0.29999""" },
    { "rate" : """4""" },
    { "rate" : """6.9""" },
    { "rate" : """6.99999""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """6.5""" },
    { "rate" : """4.5""" },
    { "rate" : """20""" },
    { "rate" : """6""" },
    { "rate" : """20""" },
    { "rate" : """18""" },
    { "rate" : """20""" },
    { "rate" : """7""" },
    { "rate" : """4.5""" },
    { "rate" : """6""" },
    { "rate" : """20""" },
    { "rate" : """0.4""" },
    { "rate" : """6.99998""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """19.71""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """3.9978""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """4.5""" },
    { "rate" : """7""" },
    { "rate" : """3.9""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """3.99""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """6.9""" },
    { "rate" : """7""" },
    { "rate" : """9.9393""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """0.45""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """11.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """4.66667""" },
    { "rate" : """4.66667""" },
    { "rate" : """7.77778""" },
    { "rate" : """19""" },
    { "rate" : """15""" },
    { "rate" : """3.98""" },
    { "rate" : """9.82""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """16""" },
    { "rate" : """8.5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """8.99999""" },
    { "rate" : """6.9""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """8.99999""" },
    { "rate" : """6.5""" },
    { "rate" : """3.9""" },
    { "rate" : """6.99""" },
    { "rate" : """7.9""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """16""" },
    { "rate" : """9.38""" },
    { "rate" : """10""" },
    { "rate" : """8.899""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """6.98""" },
    { "rate" : """8.88""" },
    { "rate" : """9.99""" },
    { "rate" : """1.5""" },
    { "rate" : """4.94""" },
    { "rate" : """3""" },
    { "rate" : """9.49""" },
    { "rate" : """5""" },
    { "rate" : """1.5""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """8.5""" },
    { "rate" : """1.5""" },
    { "rate" : """8.89""" },
    { "rate" : """8.99""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """0.49998""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """4.9999""" },
    { "rate" : """4""" },
    { "rate" : """0.49999""" },
    { "rate" : """1.7""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """3.5""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """7.95""" },
    { "rate" : """7.969""" },
    { "rate" : """7.4""" },
    { "rate" : """7.5""" },
    { "rate" : """7.3""" },
    { "rate" : """7.49""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """1.71""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """6.987""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """8.8829""" },
    { "rate" : """8.99999""" },
    { "rate" : """9.85""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """8.89""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """7.5""" },
    { "rate" : """0.46""" },
    { "rate" : """8.99321""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """8.33333""" },
    { "rate" : """10""" },
    { "rate" : """1.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """3.5""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """7.77778""" },
    { "rate" : """16.66667""" },
    { "rate" : """0.499""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """16""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7.89""" },
    { "rate" : """0.4999""" },
    { "rate" : """9.98""" },
    { "rate" : """8""" },
    { "rate" : """9.89""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """4.99999""" },
    { "rate" : """6""" },
    { "rate" : """6.48""" },
    { "rate" : """5""" },
    { "rate" : """5.9""" },
    { "rate" : """2.9""" },
    { "rate" : """8.9""" },
    { "rate" : """8""" },
    { "rate" : """19.77""" },
    { "rate" : """5.5555""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """8.99777""" },
    { "rate" : """4""" },
    { "rate" : """1.7799""" },
    { "rate" : """9.99""" },
    { "rate" : """3.25""" },
    { "rate" : """7.88""" },
    { "rate" : """19.99""" },
    { "rate" : """8.99""" },
    { "rate" : """4""" },
    { "rate" : """18""" },
    { "rate" : """7.5""" },
    { "rate" : """4.5""" },
    { "rate" : """4.95""" },
    { "rate" : """18""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """0.99""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """0.49""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """4.9999""" },
    { "rate" : """8.5""" },
    { "rate" : """8.888""" },
    { "rate" : """0.99999""" },
    { "rate" : """14.9999""" },
    { "rate" : """19.99333""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """0.99""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """4.9999""" },
    { "rate" : """4.4""" },
    { "rate" : """4.95""" },
    { "rate" : """4.99722""" },
    { "rate" : """5""" },
    { "rate" : """0.999""" },
    { "rate" : """9""" },
    { "rate" : """8.5""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """8.9""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """4.5""" },
    { "rate" : """6""" },
    { "rate" : """0.5""" },
    { "rate" : """19""" },
    { "rate" : """4.89939""" },
    { "rate" : """1""" },
    { "rate" : """8.97939""" },
    { "rate" : """8.98""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """0.49""" },
    { "rate" : """4.99999""" },
    { "rate" : """1""" },
    { "rate" : """8.5""" },
    { "rate" : """8.99""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """8.9999""" },
    { "rate" : """4.8""" },
    { "rate" : """6.9989""" },
    { "rate" : """8.9999""" },
    { "rate" : """4.95""" },
    { "rate" : """1""" },
    { "rate" : """4.16667""" },
    { "rate" : """3.9989""" },
    { "rate" : """15""" },
    { "rate" : """0.97222""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """0.99999""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """4.9998""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """0.5""" },
    { "rate" : """5.9393""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """7.9""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """17.25""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """13""" },
    { "rate" : """1.49999""" },
    { "rate" : """4.8""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """7.8""" },
    { "rate" : """17.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """9.67""" },
    { "rate" : """15""" },
    { "rate" : """4.979""" },
    { "rate" : """6""" },
    { "rate" : """9.8""" },
    { "rate" : """4.88""" },
    { "rate" : """1.98""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """4.8""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5.55""" },
    { "rate" : """1""" },
    { "rate" : """1.58""" },
    { "rate" : """1.88""" },
    { "rate" : """1.77989""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """6.9""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """0.999""" },
    { "rate" : """0.99999""" },
    { "rate" : """4.9""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.9""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """6.99""" },
    { "rate" : """9.99""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.987""" },
    { "rate" : """5""" },
    { "rate" : """1.9999""" },
    { "rate" : """2.91667""" },
    { "rate" : """4.9999""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """4.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.5""" },
    { "rate" : """19.99999""" },
    { "rate" : """9.75""" },
    { "rate" : """6""" },
    { "rate" : """1.75""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """19""" },
    { "rate" : """4.75""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2.916""" },
    { "rate" : """7""" },
    { "rate" : """20""" },
    { "rate" : """13""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """0.99998""" },
    { "rate" : """19.9999""" },
    { "rate" : """0.9999""" },
    { "rate" : """6.99999""" },
    { "rate" : """4.4""" },
    { "rate" : """5""" },
    { "rate" : """0.75""" },
    { "rate" : """4.1""" },
    { "rate" : """14""" },
    { "rate" : """20""" },
    { "rate" : """6.05""" },
    { "rate" : """20""" },
    { "rate" : """3""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """7.8""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """4.8""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """2.5""" },
    { "rate" : """19.99999""" },
    { "rate" : """10""" },
    { "rate" : """6.99999""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2.95""" },
    { "rate" : """20""" },
    { "rate" : """2.7899""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """0.09722""" },
    { "rate" : """8""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2.92""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """19""" },
    { "rate" : """2.89""" },
    { "rate" : """5""" },
    { "rate" : """11.99999""" },
    { "rate" : """18""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """13""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """4.4""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """4.8""" },
    { "rate" : """7.7""" },
    { "rate" : """5""" },
    { "rate" : """4.7""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """11.6999""" },
    { "rate" : """12""" },
    { "rate" : """11.7""" },
    { "rate" : """12.89""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """4.99""" },
    { "rate" : """12.9""" },
    { "rate" : """5.5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """2.91667""" },
    { "rate" : """2.9998""" },
    { "rate" : """4.98""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """0.89""" },
    { "rate" : """6""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """2.7""" },
    { "rate" : """3.5""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """9.99777""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.9975""" },
    { "rate" : """9""" },
    { "rate" : """5.2""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """9.1""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """4.4""" },
    { "rate" : """0.99999""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """12.99999""" },
    { "rate" : """19.99""" },
    { "rate" : """4.99""" },
    { "rate" : """2.78""" },
    { "rate" : """6.94""" },
    { "rate" : """4.99""" },
    { "rate" : """14.99""" },
    { "rate" : """4.99""" },
    { "rate" : """9.99""" },
    { "rate" : """4.99""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """0.99""" },
    { "rate" : """0.99""" },
    { "rate" : """6.95""" },
    { "rate" : """19.9999""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """0.99939""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5.99999""" },
    { "rate" : """9""" },
    { "rate" : """0.999""" },
    { "rate" : """0.9999""" },
    { "rate" : """3.5""" },
    { "rate" : """2.5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.5""" },
    { "rate" : """1""" },
    { "rate" : """9.5""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """0.4""" },
    { "rate" : """18.5""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """2.5""" },
    { "rate" : """6""" },
    { "rate" : """5.9999""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """4.9999""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """4.8999""" },
    { "rate" : """0.7""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.9999""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """25""" },
    { "rate" : """5.5""" },
    { "rate" : """20""" },
    { "rate" : """4.987""" },
    { "rate" : """19.99""" },
    { "rate" : """10""" },
    { "rate" : """9.869""" },
    { "rate" : """6""" },
    { "rate" : """20""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """4.99599""" },
    { "rate" : """6""" },
    { "rate" : """22""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5.8999""" },
    { "rate" : """7""" },
    { "rate" : """4.99998""" },
    { "rate" : """2.5""" },
    { "rate" : """4.99""" },
    { "rate" : """45""" },
    { "rate" : """3.25""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """6""" },
    { "rate" : """13""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """3.5""" },
    { "rate" : """20""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """4.99999""" },
    { "rate" : """3.49999""" },
    { "rate" : """5.9""" },
    { "rate" : """10""" },
    { "rate" : """12.94""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """12.5""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """4""" },
    { "rate" : """20""" },
    { "rate" : """2.69939""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """25""" },
    { "rate" : """24""" },
    { "rate" : """3.5""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """1.48""" },
    { "rate" : """7""" },
    { "rate" : """6.9""" },
    { "rate" : """24.99999""" },
    { "rate" : """8.88""" },
    { "rate" : """7""" },
    { "rate" : """12.9""" },
    { "rate" : """24.99""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """6.8""" },
    { "rate" : """6""" },
    { "rate" : """20""" },
    { "rate" : """11.9999""" },
    { "rate" : """24.98999""" },
    { "rate" : """4.9999""" },
    { "rate" : """3.49985""" },
    { "rate" : """3.49999""" },
    { "rate" : """1""" },
    { "rate" : """6.89999""" },
    { "rate" : """3""" },
    { "rate" : """2.4""" },
    { "rate" : """6.99999""" },
    { "rate" : """2""" },
    { "rate" : """1.9""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """9.5""" },
    { "rate" : """4.9""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """3.9""" },
    { "rate" : """4.99""" },
    { "rate" : """3.89""" },
    { "rate" : """3""" },
    { "rate" : """12.3""" },
    { "rate" : """2.99999""" },
    { "rate" : """10""" },
    { "rate" : """24.95""" },
    { "rate" : """3.5""" },
    { "rate" : """9""" },
    { "rate" : """19.75""" },
    { "rate" : """12.95""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """14""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """3.5""" },
    { "rate" : """9.99""" },
    { "rate" : """7.995""" },
    { "rate" : """7.9999""" },
    { "rate" : """12.49""" },
    { "rate" : """5.99""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """2.77999""" },
    { "rate" : """9.99998""" },
    { "rate" : """12""" },
    { "rate" : """4.99""" },
    { "rate" : """20""" },
    { "rate" : """1.47999""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """2.77""" },
    { "rate" : """8""" },
    { "rate" : """3.5""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """7.77""" },
    { "rate" : """13""" },
    { "rate" : """13""" },
    { "rate" : """18""" },
    { "rate" : """15""" },
    { "rate" : """9.5""" },
    { "rate" : """11.5""" },
    { "rate" : """14.4""" },
    { "rate" : """12""" },
    { "rate" : """11.99""" },
    { "rate" : """13""" },
    { "rate" : """17""" },
    { "rate" : """10""" },
    { "rate" : """4.89""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """3.68""" },
    { "rate" : """0.97989""" },
    { "rate" : """5.77""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4.9998""" },
    { "rate" : """4.7999""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """4.9999""" },
    { "rate" : """0.98499""" },
    { "rate" : """12.99998""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7.8999""" },
    { "rate" : """8""" },
    { "rate" : """9.999""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """7.9""" },
    { "rate" : """8""" },
    { "rate" : """7.7""" },
    { "rate" : """7.6""" },
    { "rate" : """9.9""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """12.998""" },
    { "rate" : """7.99998""" },
    { "rate" : """9""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.99939""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """13""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """0.97""" },
    { "rate" : """1.47939""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """0.01944""" },
    { "rate" : """12""" },
    { "rate" : """4.9""" },
    { "rate" : """7.99999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """1.49""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """21.9""" },
    { "rate" : """4.95""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """4.99999""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """4.9999""" },
    { "rate" : """22""" },
    { "rate" : """22""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """4.8""" },
    { "rate" : """11.99999""" },
    { "rate" : """8""" },
    { "rate" : """4.99999""" },
    { "rate" : """19.99998""" },
    { "rate" : """19""" },
    { "rate" : """20""" },
    { "rate" : """7.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """13""" },
    { "rate" : """20.89""" },
    { "rate" : """15""" },
    { "rate" : """19""" },
    { "rate" : """6""" },
    { "rate" : """19.99999""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """4.99999""" },
    { "rate" : """4""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.9""" },
    { "rate" : """6""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """5.98""" },
    { "rate" : """21""" },
    { "rate" : """3""" },
    { "rate" : """14""" },
    { "rate" : """12.4""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5.5""" },
    { "rate" : """6""" },
    { "rate" : """22""" },
    { "rate" : """9.99999""" },
    { "rate" : """7.8""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """22""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """19.5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4.95""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """19.99998""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """9.99""" },
    { "rate" : """15""" },
    { "rate" : """4.99939""" },
    { "rate" : """5""" },
    { "rate" : """18""" },
    { "rate" : """18""" },
    { "rate" : """9.8""" },
    { "rate" : """21.99999""" },
    { "rate" : """3.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.8""" },
    { "rate" : """5""" },
    { "rate" : """21.49999""" },
    { "rate" : """20""" },
    { "rate" : """4.99999""" },
    { "rate" : """15""" },
    { "rate" : """9.99999""" },
    { "rate" : """14.99999""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """4.95""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4.99999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """22""" },
    { "rate" : """4.999""" },
    { "rate" : """9.88""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """5.999""" },
    { "rate" : """4.9""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """22""" },
    { "rate" : """12.7999""" },
    { "rate" : """4.9899""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12.99999""" },
    { "rate" : """14""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """4.75""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """12""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """12.9""" },
    { "rate" : """9""" },
    { "rate" : """4.99999""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """19.99799""" },
    { "rate" : """9.99997""" },
    { "rate" : """4.89""" },
    { "rate" : """5""" },
    { "rate" : """19.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """3.5""" },
    { "rate" : """13.33""" },
    { "rate" : """19.99999""" },
    { "rate" : """10""" },
    { "rate" : """4.998""" },
    { "rate" : """4.97""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """4.82""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """4.95""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """19.19""" },
    { "rate" : """3.2""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """19.9""" },
    { "rate" : """4.9""" },
    { "rate" : """12.5""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """12""" },
    { "rate" : """12.99999""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """4.9""" },
    { "rate" : """14.9""" },
    { "rate" : """5.9999""" },
    { "rate" : """19.4999""" },
    { "rate" : """4.89895""" },
    { "rate" : """5""" },
    { "rate" : """7.49999""" },
    { "rate" : """19.8999""" },
    { "rate" : """9.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """13""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """0.3575""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.99""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """12.999""" },
    { "rate" : """1""" },
    { "rate" : """12.95""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """3.2""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """0.9999""" },
    { "rate" : """9.69""" },
    { "rate" : """3.45""" },
    { "rate" : """3.5""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.75""" },
    { "rate" : """9.99979""" },
    { "rate" : """0.99979""" },
    { "rate" : """13""" },
    { "rate" : """0.99978""" },
    { "rate" : """0.9999""" },
    { "rate" : """18""" },
    { "rate" : """3.493""" },
    { "rate" : """3.49999""" },
    { "rate" : """3.5""" },
    { "rate" : """0.99999""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """13""" },
    { "rate" : """0.99979""" },
    { "rate" : """9""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """6""" },
    { "rate" : """3.49999""" },
    { "rate" : """4.998""" },
    { "rate" : """3.45""" },
    { "rate" : """21.9""" },
    { "rate" : """7""" },
    { "rate" : """4.99979""" },
    { "rate" : """5""" },
    { "rate" : """7.4""" },
    { "rate" : """3""" },
    { "rate" : """13""" },
    { "rate" : """9.99998""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """4.75""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """9.8""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """12.5""" },
    { "rate" : """3""" },
    { "rate" : """0.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99979""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """3.48""" },
    { "rate" : """4""" },
    { "rate" : """7.48999""" },
    { "rate" : """1""" },
    { "rate" : """3.44999""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """3.5""" },
    { "rate" : """12""" },
    { "rate" : """6.99999""" },
    { "rate" : """18""" },
    { "rate" : """3.4999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """3.46111""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """11.55""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """9.81""" },
    { "rate" : """4.999""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.9988""" },
    { "rate" : """14.99""" },
    { "rate" : """10""" },
    { "rate" : """21.99""" },
    { "rate" : """10""" },
    { "rate" : """4.99999""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """5.5""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """4.99""" },
    { "rate" : """3.49""" },
    { "rate" : """9.99""" },
    { "rate" : """5.99""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """0.97""" },
    { "rate" : """5""" },
    { "rate" : """4.8""" },
    { "rate" : """12""" },
    { "rate" : """3.5""" },
    { "rate" : """0.66""" },
    { "rate" : """1""" },
    { "rate" : """0.7""" },
    { "rate" : """0.7""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """0.65""" },
    { "rate" : """20""" },
    { "rate" : """8.5""" },
    { "rate" : """1""" },
    { "rate" : """2.49999""" },
    { "rate" : """12""" },
    { "rate" : """2.5""" },
    { "rate" : """3.45""" },
    { "rate" : """2.3""" },
    { "rate" : """1.99999""" },
    { "rate" : """2.2""" },
    { "rate" : """9.9""" },
    { "rate" : """14.9999""" },
    { "rate" : """21.99999""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """1.9999""" },
    { "rate" : """2""" },
    { "rate" : """9.9""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """1.987""" },
    { "rate" : """2""" },
    { "rate" : """3.45""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """1.99979""" },
    { "rate" : """1.9999""" },
    { "rate" : """1.89""" },
    { "rate" : """1.99989""" },
    { "rate" : """3.49""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.99""" },
    { "rate" : """1.99""" },
    { "rate" : """2.9""" },
    { "rate" : """1.985""" },
    { "rate" : """1.65""" },
    { "rate" : """0.99""" },
    { "rate" : """3.45""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """0.99""" },
    { "rate" : """5.9""" },
    { "rate" : """5.55""" },
    { "rate" : """3.3""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10.5""" },
    { "rate" : """18""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """5.5""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """3.45""" },
    { "rate" : """1.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """1.999""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """1.99999""" },
    { "rate" : """14.99""" },
    { "rate" : """14.98""" },
    { "rate" : """4.95""" },
    { "rate" : """21.5""" },
    { "rate" : """9.98999""" },
    { "rate" : """4.82""" },
    { "rate" : """4.99999""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """0.9975""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """4.9899""" },
    { "rate" : """5.4998""" },
    { "rate" : """0.999""" },
    { "rate" : """0.99997""" },
    { "rate" : """0.999""" },
    { "rate" : """17.99""" },
    { "rate" : """14.98999""" },
    { "rate" : """3.499""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """1""" },
    { "rate" : """2.493""" },
    { "rate" : """2""" },
    { "rate" : """4.5""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """3.4""" },
    { "rate" : """1.95""" },
    { "rate" : """19.99""" },
    { "rate" : """0.99""" },
    { "rate" : """3.45""" },
    { "rate" : """2.99999""" },
    { "rate" : """1.5""" },
    { "rate" : """4.8""" },
    { "rate" : """7.9""" },
    { "rate" : """11.98333""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """3.4""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """0.98""" },
    { "rate" : """2""" },
    { "rate" : """1.986""" },
    { "rate" : """1""" },
    { "rate" : """3.4888""" },
    { "rate" : """1.7""" },
    { "rate" : """4.99999""" },
    { "rate" : """2""" },
    { "rate" : """5.999""" },
    { "rate" : """2""" },
    { "rate" : """4.999""" },
    { "rate" : """16.99999""" },
    { "rate" : """6""" },
    { "rate" : """18""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """3.45""" },
    { "rate" : """4.98""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """0.99""" },
    { "rate" : """14.99999""" },
    { "rate" : """11""" },
    { "rate" : """14.14""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2.91667""" },
    { "rate" : """3.4499""" },
    { "rate" : """4.999""" },
    { "rate" : """18.99""" },
    { "rate" : """1.4""" },
    { "rate" : """0.9979""" },
    { "rate" : """3.30556""" },
    { "rate" : """0.9999""" },
    { "rate" : """1.9999""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """0.3""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """14.99999""" },
    { "rate" : """3.9999""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """1.9999""" },
    { "rate" : """1""" },
    { "rate" : """0.99""" },
    { "rate" : """4.4""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """15""" },
    { "rate" : """4.4""" },
    { "rate" : """22""" },
    { "rate" : """0.98""" },
    { "rate" : """1.99""" },
    { "rate" : """1.9999""" },
    { "rate" : """3.9""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """13.5""" },
    { "rate" : """16""" },
    { "rate" : """4.9999""" },
    { "rate" : """4""" },
    { "rate" : """1.9999""" },
    { "rate" : """5""" },
    { "rate" : """0.97989""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """5.99""" },
    { "rate" : """4.5""" },
    { "rate" : """3.49999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3.3""" },
    { "rate" : """1.6""" },
    { "rate" : """18""" },
    { "rate" : """1.99999""" },
    { "rate" : """7.8""" },
    { "rate" : """1.99999""" },
    { "rate" : """4.979""" },
    { "rate" : """14.9999""" },
    { "rate" : """5""" },
    { "rate" : """1.6""" },
    { "rate" : """0.98999""" },
    { "rate" : """13""" },
    { "rate" : """11.5""" },
    { "rate" : """13""" },
    { "rate" : """3.5""" },
    { "rate" : """3.4""" },
    { "rate" : """14.9""" },
    { "rate" : """7.5""" },
    { "rate" : """0.987""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """0.95""" },
    { "rate" : """0.99999""" },
    { "rate" : """22""" },
    { "rate" : """12.98999""" },
    { "rate" : """0.99999""" },
    { "rate" : """12""" },
    { "rate" : """1.94999""" },
    { "rate" : """0.94""" },
    { "rate" : """1.9""" },
    { "rate" : """15""" },
    { "rate" : """0.98699""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """22""" },
    { "rate" : """7.49""" },
    { "rate" : """11""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """7.5""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """1.97""" },
    { "rate" : """17.9""" },
    { "rate" : """14.8""" },
    { "rate" : """15""" },
    { "rate" : """11.5""" },
    { "rate" : """14""" },
    { "rate" : """22""" },
    { "rate" : """11.9""" },
    { "rate" : """11.79979""" },
    { "rate" : """3""" },
    { "rate" : """14.99999""" },
    { "rate" : """13.99999""" },
    { "rate" : """7""" },
    { "rate" : """2.99""" },
    { "rate" : """5""" },
    { "rate" : """4.8""" },
    { "rate" : """14""" },
    { "rate" : """9.8""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """1.85""" },
    { "rate" : """7.75""" },
    { "rate" : """14.9998""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """1.5""" },
    { "rate" : """14.99999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """11.99999""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.99987""" },
    { "rate" : """14.14""" },
    { "rate" : """17.17""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """12.49979""" },
    { "rate" : """18""" },
    { "rate" : """13""" },
    { "rate" : """11""" },
    { "rate" : """15""" },
    { "rate" : """18""" },
    { "rate" : """18""" },
    { "rate" : """22""" },
    { "rate" : """14.5""" },
    { "rate" : """11.86699""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """14""" },
    { "rate" : """14""" },
    { "rate" : """9.8""" },
    { "rate" : """4.5""" },
    { "rate" : """4.75""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """4.5""" },
    { "rate" : """19.99998""" },
    { "rate" : """18""" },
    { "rate" : """4""" },
    { "rate" : """4.99999""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """14.99999""" },
    { "rate" : """5""" },
    { "rate" : """6.66667""" },
    { "rate" : """3.9988""" },
    { "rate" : """6.66667""" },
    { "rate" : """4.99""" },
    { "rate" : """4.99""" },
    { "rate" : """3.33333""" },
    { "rate" : """8.99""" },
    { "rate" : """3.33333""" },
    { "rate" : """19.98998""" },
    { "rate" : """13.99""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """20""" },
    { "rate" : """3.99999""" },
    { "rate" : """4.5""" },
    { "rate" : """12""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """22""" },
    { "rate" : """11""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """11.99979""" },
    { "rate" : """9""" },
    { "rate" : """13.99979""" },
    { "rate" : """3""" },
    { "rate" : """14.99999""" },
    { "rate" : """5""" },
    { "rate" : """2.95""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """14.99""" },
    { "rate" : """9.99999""" },
    { "rate" : """2.5""" },
    { "rate" : """12.5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """4.75""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """22""" },
    { "rate" : """5""" },
    { "rate" : """3.89999""" },
    { "rate" : """10""" },
    { "rate" : """3.8""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """6.25""" },
    { "rate" : """8.5""" },
    { "rate" : """3.9""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """3.9""" },
    { "rate" : """4.99999""" },
    { "rate" : """3.89998""" },
    { "rate" : """4.99998""" },
    { "rate" : """2.5""" },
    { "rate" : """2""" },
    { "rate" : """14""" },
    { "rate" : """4.4""" },
    { "rate" : """4.5""" },
    { "rate" : """4.99998""" },
    { "rate" : """4""" },
    { "rate" : """18""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """3.9""" },
    { "rate" : """18""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """2.49999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """5.99999""" },
    { "rate" : """6""" },
    { "rate" : """9.9""" },
    { "rate" : """5.998""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5.95""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """9.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """2.9""" },
    { "rate" : """5""" },
    { "rate" : """4.89""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """18""" },
    { "rate" : """4.98""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """18""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """3.9""" },
    { "rate" : """10""" },
    { "rate" : """0.05""" },
    { "rate" : """15""" },
    { "rate" : """4.9999""" },
    { "rate" : """5""" },
    { "rate" : """3.9""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """22""" },
    { "rate" : """6""" },
    { "rate" : """7.99""" },
    { "rate" : """22""" },
    { "rate" : """5""" },
    { "rate" : """9.99957""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """6.999""" },
    { "rate" : """4.99""" },
    { "rate" : """9""" },
    { "rate" : """9.889""" },
    { "rate" : """4.89""" },
    { "rate" : """4""" },
    { "rate" : """22""" },
    { "rate" : """3.89""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4.88""" },
    { "rate" : """9.9""" },
    { "rate" : """7.5""" },
    { "rate" : """9.99958""" },
    { "rate" : """3""" },
    { "rate" : """6.9""" },
    { "rate" : """4.989""" },
    { "rate" : """8.999""" },
    { "rate" : """8.74912""" },
    { "rate" : """18""" },
    { "rate" : """8""" },
    { "rate" : """8.75""" },
    { "rate" : """22""" },
    { "rate" : """16.99""" },
    { "rate" : """3.9""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """7.99""" },
    { "rate" : """7""" },
    { "rate" : """4.6""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """21.98765""" },
    { "rate" : """5.9""" },
    { "rate" : """7""" },
    { "rate" : """8.73999""" },
    { "rate" : """8""" },
    { "rate" : """8.97""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """18""" },
    { "rate" : """4.5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """18""" },
    { "rate" : """5.25""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """20""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3.9""" },
    { "rate" : """6""" },
    { "rate" : """5.49985""" },
    { "rate" : """22""" },
    { "rate" : """3.5""" },
    { "rate" : """3.85""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4.9""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """9.9""" },
    { "rate" : """18""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """15.5""" },
    { "rate" : """3.9""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """7.5""" },
    { "rate" : """5""" },
    { "rate" : """2.49""" },
    { "rate" : """2.5""" },
    { "rate" : """8""" },
    { "rate" : """3.99""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """8.9""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """2.49""" },
    { "rate" : """5.99999""" },
    { "rate" : """9.85833""" },
    { "rate" : """2.5""" },
    { "rate" : """3.9""" },
    { "rate" : """10""" },
    { "rate" : """2.5""" },
    { "rate" : """9.99""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.99999""" },
    { "rate" : """13.99979""" },
    { "rate" : """3.875""" },
    { "rate" : """5.99979""" },
    { "rate" : """3.99999""" },
    { "rate" : """6""" },
    { "rate" : """4.98""" },
    { "rate" : """3.99""" },
    { "rate" : """5""" },
    { "rate" : """2.99999""" },
    { "rate" : """4.9""" },
    { "rate" : """9.8""" },
    { "rate" : """4.8""" },
    { "rate" : """3.8""" },
    { "rate" : """3.999""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """3.9999""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """9.9""" },
    { "rate" : """2.99""" },
    { "rate" : """4.99""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """22""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """18""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """3.9""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """4.99999""" },
    { "rate" : """21.99""" },
    { "rate" : """22""" },
    { "rate" : """4.9""" },
    { "rate" : """22""" },
    { "rate" : """4.5""" },
    { "rate" : """9.59999""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """4.9""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """14""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """4.99""" },
    { "rate" : """8""" },
    { "rate" : """2.99999""" },
    { "rate" : """10""" },
    { "rate" : """22""" },
    { "rate" : """5""" },
    { "rate" : """22""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """18""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """3.89995""" },
    { "rate" : """4.25""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """12.5""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """5.98889""" },
    { "rate" : """3.9""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """4.98""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.999""" },
    { "rate" : """4.99""" },
    { "rate" : """2.99""" },
    { "rate" : """3.99""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """3.9""" },
    { "rate" : """1.95""" },
    { "rate" : """1.97""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """9.5""" },
    { "rate" : """22""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """5.9""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """14""" },
    { "rate" : """2.4""" },
    { "rate" : """22""" },
    { "rate" : """18""" },
    { "rate" : """7""" },
    { "rate" : """0.99""" },
    { "rate" : """17.99999""" },
    { "rate" : """0.99""" },
    { "rate" : """1.9""" },
    { "rate" : """2.75""" },
    { "rate" : """22""" },
    { "rate" : """1""" },
    { "rate" : """1.98999""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """1.94444""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """9""" },
    { "rate" : """17.5""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """4.82""" },
    { "rate" : """2.39""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """9.899""" },
    { "rate" : """1.999""" },
    { "rate" : """3.89""" },
    { "rate" : """1.99979""" },
    { "rate" : """4.9""" },
    { "rate" : """1""" },
    { "rate" : """5.5""" },
    { "rate" : """1.9""" },
    { "rate" : """1.95""" },
    { "rate" : """5""" },
    { "rate" : """18""" },
    { "rate" : """1.9753""" },
    { "rate" : """10""" },
    { "rate" : """5.99""" },
    { "rate" : """5""" },
    { "rate" : """1.945""" },
    { "rate" : """2.7""" },
    { "rate" : """2.8""" },
    { "rate" : """5""" },
    { "rate" : """5.99""" },
    { "rate" : """4.99""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """1.99""" },
    { "rate" : """3""" },
    { "rate" : """1.95""" },
    { "rate" : """1.9""" },
    { "rate" : """6.04""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """9.9956""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """0.99999""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """9.9""" },
    { "rate" : """4.98""" },
    { "rate" : """22""" },
    { "rate" : """22""" },
    { "rate" : """2""" },
    { "rate" : """7.99999""" },
    { "rate" : """1""" },
    { "rate" : """4.2""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """1.94""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """2.99999""" },
    { "rate" : """2.99""" },
    { "rate" : """2.79""" },
    { "rate" : """11.99""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """1.98""" },
    { "rate" : """9.25""" },
    { "rate" : """9.99979""" },
    { "rate" : """9.99979""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.9998""" },
    { "rate" : """9.9393""" },
    { "rate" : """10""" },
    { "rate" : """4.99999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """9.97999""" },
    { "rate" : """9.99999""" },
    { "rate" : """9""" },
    { "rate" : """9.9999""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """3.51""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """22""" },
    { "rate" : """7.46""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """1.95""" },
    { "rate" : """18""" },
    { "rate" : """4.5""" },
    { "rate" : """8""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """14.5""" },
    { "rate" : """0.71999""" },
    { "rate" : """19""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """0.71998""" },
    { "rate" : """3.9""" },
    { "rate" : """1""" },
    { "rate" : """9.79978""" },
    { "rate" : """20""" },
    { "rate" : """4""" },
    { "rate" : """0.70998""" },
    { "rate" : """12""" },
    { "rate" : """3.5""" },
    { "rate" : """9.95""" },
    { "rate" : """9.5""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9.999""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """7.14""" },
    { "rate" : """3""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """6.5""" },
    { "rate" : """8.5""" },
    { "rate" : """5""" },
    { "rate" : """0.7""" },
    { "rate" : """7.5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """0.69""" },
    { "rate" : """0.7""" },
    { "rate" : """9.5""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """7.6""" },
    { "rate" : """9.99""" },
    { "rate" : """3.5""" },
    { "rate" : """9""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """9.5""" },
    { "rate" : """10""" },
    { "rate" : """4.8""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """7.5""" },
    { "rate" : """4.1""" },
    { "rate" : """18""" },
    { "rate" : """5""" },
    { "rate" : """8.5""" },
    { "rate" : """1""" },
    { "rate" : """1.99""" },
    { "rate" : """21""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """22""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """3.9""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """3.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """3.899""" },
    { "rate" : """1.99999""" },
    { "rate" : """9.5""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """18""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3.75""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """9.5""" },
    { "rate" : """2.99999""" },
    { "rate" : """4.9""" },
    { "rate" : """22""" },
    { "rate" : """17.5""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """1.85""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """2.99999""" },
    { "rate" : """5""" },
    { "rate" : """22""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """19.9""" },
    { "rate" : """9.9""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """21.99999""" },
    { "rate" : """4.89999""" },
    { "rate" : """21.95""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """7.5""" },
    { "rate" : """20""" },
    { "rate" : """4""" },
    { "rate" : """20""" },
    { "rate" : """9""" },
    { "rate" : """9.5""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """4.9""" },
    { "rate" : """15""" },
    { "rate" : """3.241""" },
    { "rate" : """9.1""" },
    { "rate" : """6.813""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """4.98""" },
    { "rate" : """3""" },
    { "rate" : """7.2""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """8.99999""" },
    { "rate" : """2.98999""" },
    { "rate" : """21.99""" },
    { "rate" : """7.3""" },
    { "rate" : """9""" },
    { "rate" : """3.95""" },
    { "rate" : """7.77""" },
    { "rate" : """15""" },
    { "rate" : """4.12345""" },
    { "rate" : """8""" },
    { "rate" : """19.99""" },
    { "rate" : """7.99""" },
    { "rate" : """3.9899""" },
    { "rate" : """9.99""" },
    { "rate" : """7.8""" },
    { "rate" : """7.4""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """3""" },
    { "rate" : """3.4""" },
    { "rate" : """3""" },
    { "rate" : """3.4999""" },
    { "rate" : """8.5""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """9.99979""" },
    { "rate" : """2.99""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """2.99""" },
    { "rate" : """2.89""" },
    { "rate" : """2.89""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """4.99""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """2""" },
    { "rate" : """7.44""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """18""" },
    { "rate" : """8.99998""" },
    { "rate" : """9.99999""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """0.99""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """17""" },
    { "rate" : """1""" },
    { "rate" : """8.9999""" },
    { "rate" : """18""" },
    { "rate" : """8.05""" },
    { "rate" : """18.99999""" },
    { "rate" : """19""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """14""" },
    { "rate" : """4.5""" },
    { "rate" : """15""" },
    { "rate" : """14.999""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """9.5""" },
    { "rate" : """9.9""" },
    { "rate" : """4""" },
    { "rate" : """19.99999""" },
    { "rate" : """20""" },
    { "rate" : """1""" },
    { "rate" : """6.25""" },
    { "rate" : """10""" },
    { "rate" : """7.7""" },
    { "rate" : """3.5""" },
    { "rate" : """9""" },
    { "rate" : """0.01""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """2.99""" },
    { "rate" : """4.99""" },
    { "rate" : """12""" },
    { "rate" : """2.9""" },
    { "rate" : """0.7""" },
    { "rate" : """3""" },
    { "rate" : """0.5""" },
    { "rate" : """0.6""" },
    { "rate" : """9.95""" },
    { "rate" : """9""" },
    { "rate" : """9.99999""" },
    { "rate" : """9""" },
    { "rate" : """0.79""" },
    { "rate" : """9""" },
    { "rate" : """14.99999""" },
    { "rate" : """3.9""" },
    { "rate" : """10""" },
    { "rate" : """0.99979""" },
    { "rate" : """0.9999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """9.88""" },
    { "rate" : """4.83""" },
    { "rate" : """0.99""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.99998""" },
    { "rate" : """9.99999""" },
    { "rate" : """14.5""" },
    { "rate" : """0.9975""" },
    { "rate" : """3.89999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """4.98999""" },
    { "rate" : """3.99""" },
    { "rate" : """7.45""" },
    { "rate" : """3.74""" },
    { "rate" : """0.99""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """0.98""" },
    { "rate" : """4.9""" },
    { "rate" : """1""" },
    { "rate" : """1.5""" },
    { "rate" : """7.5""" },
    { "rate" : """4""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1""" },
    { "rate" : """9.99""" },
    { "rate" : """3.9999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """4.5""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1.49999""" },
    { "rate" : """0.9999""" },
    { "rate" : """4.99999""" },
    { "rate" : """1""" },
    { "rate" : """0.96""" },
    { "rate" : """0.999""" },
    { "rate" : """4""" },
    { "rate" : """9.9999""" },
    { "rate" : """0.979""" },
    { "rate" : """1""" },
    { "rate" : """4.99999""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """2.2""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """5.99""" },
    { "rate" : """5""" },
    { "rate" : """9.83333""" },
    { "rate" : """9.9""" },
    { "rate" : """5""" },
    { "rate" : """3.88889""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """9.5""" },
    { "rate" : """11""" },
    { "rate" : """13""" },
    { "rate" : """9.99""" },
    { "rate" : """3.979""" },
    { "rate" : """4.09""" },
    { "rate" : """10""" },
    { "rate" : """2.99""" },
    { "rate" : """9.98""" },
    { "rate" : """10.34""" },
    { "rate" : """4""" },
    { "rate" : """2.978""" },
    { "rate" : """0.9999""" },
    { "rate" : """4.99999""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """0.99""" },
    { "rate" : """0.36964""" },
    { "rate" : """1""" },
    { "rate" : """1.58333""" },
    { "rate" : """6""" },
    { "rate" : """1.16667""" },
    { "rate" : """0.99979""" },
    { "rate" : """1.25""" },
    { "rate" : """10""" },
    { "rate" : """0.83333""" },
    { "rate" : """4.99979""" },
    { "rate" : """3""" },
    { "rate" : """3.978""" },
    { "rate" : """14""" },
    { "rate" : """0.38889""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """0.05833""" },
    { "rate" : """0.99999""" },
    { "rate" : """5""" },
    { "rate" : """3.9""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """14.88""" },
    { "rate" : """0.96""" },
    { "rate" : """0.999""" },
    { "rate" : """7.3333""" },
    { "rate" : """2.977""" },
    { "rate" : """6.99""" },
    { "rate" : """3.399""" },
    { "rate" : """1.23333""" },
    { "rate" : """2""" },
    { "rate" : """0.3""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99998""" },
    { "rate" : """14.99999""" },
    { "rate" : """1""" },
    { "rate" : """1.9357""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """2.89""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """14.9998""" },
    { "rate" : """0.98""" },
    { "rate" : """2.9""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """1.95""" },
    { "rate" : """1.94""" },
    { "rate" : """17""" },
    { "rate" : """4.8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.97989""" },
    { "rate" : """15""" },
    { "rate" : """2.5""" },
    { "rate" : """2.99""" },
    { "rate" : """3""" },
    { "rate" : """1.979""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """1.95""" },
    { "rate" : """1.99997""" },
    { "rate" : """7""" },
    { "rate" : """3.5""" },
    { "rate" : """3""" },
    { "rate" : """1.94444""" },
    { "rate" : """8.33333""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """1.98""" },
    { "rate" : """10""" },
    { "rate" : """9.999""" },
    { "rate" : """5""" },
    { "rate" : """6.99999""" },
    { "rate" : """3""" },
    { "rate" : """6.9""" },
    { "rate" : """3""" },
    { "rate" : """14""" },
    { "rate" : """2.95""" },
    { "rate" : """3""" },
    { "rate" : """4.75""" },
    { "rate" : """2.79""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """2.88""" },
    { "rate" : """3""" },
    { "rate" : """1.99895""" },
    { "rate" : """9""" },
    { "rate" : """1.94""" },
    { "rate" : """5""" },
    { "rate" : """1.99997""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """1""" },
    { "rate" : """1.97899""" },
    { "rate" : """2.78999""" },
    { "rate" : """1.976""" },
    { "rate" : """19.99""" },
    { "rate" : """1.98997""" },
    { "rate" : """4.99""" },
    { "rate" : """14.99""" },
    { "rate" : """4""" },
    { "rate" : """12.69""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """9.999""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """0.9879""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """19""" },
    { "rate" : """3.9""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """3.999""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.9999""" },
    { "rate" : """9""" },
    { "rate" : """9.98""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7.7""" },
    { "rate" : """9.99979""" },
    { "rate" : """6.969""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.9998""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.9""" },
    { "rate" : """7""" },
    { "rate" : """9.999""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """1.45""" },
    { "rate" : """7""" },
    { "rate" : """2.9999""" },
    { "rate" : """10""" },
    { "rate" : """6.99999""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.99998""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """14.5""" },
    { "rate" : """9.99""" },
    { "rate" : """0.9""" },
    { "rate" : """4""" },
    { "rate" : """0.999""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """2.9""" },
    { "rate" : """9.99""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """6.9""" },
    { "rate" : """4.5""" },
    { "rate" : """14""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """3.5""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """1.5""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """7""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4.94999""" },
    { "rate" : """10""" },
    { "rate" : """6.99""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3.978""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """4.99999""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """4.5""" },
    { "rate" : """15""" },
    { "rate" : """12.68""" },
    { "rate" : """9.989""" },
    { "rate" : """0.99""" },
    { "rate" : """3.99""" },
    { "rate" : """2.99""" },
    { "rate" : """14.99""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """4.96""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """4.9393""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """4.94979""" },
    { "rate" : """14.99""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """4.89""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """6.99""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4.89""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.5""" },
    { "rate" : """3.75""" },
    { "rate" : """3.89989""" },
    { "rate" : """9.9899""" },
    { "rate" : """0.99899""" },
    { "rate" : """14.98999""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4.95""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """3.9""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """10""" },
    { "rate" : """0.00972""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """15.99999""" },
    { "rate" : """7""" },
    { "rate" : """5.83333""" },
    { "rate" : """3""" },
    { "rate" : """8.99999""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """3.74""" },
    { "rate" : """9.5""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """8.99999""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.97""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4.18""" },
    { "rate" : """15""" },
    { "rate" : """2.9""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """8.75""" },
    { "rate" : """9""" },
    { "rate" : """9.89999""" },
    { "rate" : """13""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """3.5""" },
    { "rate" : """4""" },
    { "rate" : """4.499""" },
    { "rate" : """5""" },
    { "rate" : """3.9""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """3.9""" },
    { "rate" : """10""" },
    { "rate" : """9.7""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.02""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """3.9""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """9.5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """4.89""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """4.99""" },
    { "rate" : """7""" },
    { "rate" : """6.965""" },
    { "rate" : """10""" },
    { "rate" : """2.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """2.9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """3.95""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """2.86""" },
    { "rate" : """9.8""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """4.78999""" },
    { "rate" : """4.75""" },
    { "rate" : """4""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.97999""" },
    { "rate" : """4.88999""" },
    { "rate" : """3""" },
    { "rate" : """4.98""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """14.99""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """14.99999""" },
    { "rate" : """8""" },
    { "rate" : """14.9999""" },
    { "rate" : """4.99""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """7.99999""" },
    { "rate" : """9.998""" },
    { "rate" : """4.999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4.85""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """9.98""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4.9989""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7.9""" },
    { "rate" : """2.5""" },
    { "rate" : """6.8""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """2.22222""" },
    { "rate" : """9.96""" },
    { "rate" : """9.999""" },
    { "rate" : """2.76""" },
    { "rate" : """3.7""" },
    { "rate" : """4.98999""" },
    { "rate" : """4.99""" },
    { "rate" : """6.99""" },
    { "rate" : """2.99""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """2.5""" },
    { "rate" : """3""" },
    { "rate" : """5.98999""" },
    { "rate" : """3.9""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.99998""" },
    { "rate" : """6""" },
    { "rate" : """3.9""" },
    { "rate" : """2""" },
    { "rate" : """9.9""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """2.99""" },
    { "rate" : """9.98999""" },
    { "rate" : """9.99998""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """9.99""" },
    { "rate" : """4.95""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """3.9""" },
    { "rate" : """10""" },
    { "rate" : """12.437""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """7.96""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """9.9999""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """9.9""" },
    { "rate" : """3""" },
    { "rate" : """2.9""" },
    { "rate" : """3""" },
    { "rate" : """2.95""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """9.9998""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """3.998""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """4.7""" },
    { "rate" : """3.9""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """4.975""" },
    { "rate" : """9.826""" },
    { "rate" : """4""" },
    { "rate" : """3.64""" },
    { "rate" : """2.9999""" },
    { "rate" : """2.9""" },
    { "rate" : """7.77778""" },
    { "rate" : """2.9""" },
    { "rate" : """4.999""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """2.99999""" },
    { "rate" : """2.9""" },
    { "rate" : """8""" },
    { "rate" : """2.9999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """2.98""" },
    { "rate" : """10""" },
    { "rate" : """9.8543""" },
    { "rate" : """10""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """9.9""" },
    { "rate" : """2""" },
    { "rate" : """2.99""" },
    { "rate" : """9.99999""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """3.9""" },
    { "rate" : """7""" },
    { "rate" : """9.72222""" },
    { "rate" : """7.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """2.5""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """7.4999""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """7.4888""" },
    { "rate" : """3""" },
    { "rate" : """4.9989""" },
    { "rate" : """7.999""" },
    { "rate" : """7.5""" },
    { "rate" : """2""" },
    { "rate" : """10.895""" },
    { "rate" : """7""" },
    { "rate" : """3.46979""" },
    { "rate" : """11.998""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """9.8765""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """9.5""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """9.5""" },
    { "rate" : """7.8""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """9.5""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """4.8""" },
    { "rate" : """3""" },
    { "rate" : """5.5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15.3""" },
    { "rate" : """15.1""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """7.5""" },
    { "rate" : """9""" },
    { "rate" : """3.8""" },
    { "rate" : """6.8""" },
    { "rate" : """9.9""" },
    { "rate" : """7.5""" },
    { "rate" : """7.5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7.5""" },
    { "rate" : """7.463""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """3.9""" },
    { "rate" : """4""" },
    { "rate" : """3.9""" },
    { "rate" : """8.89999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3.9""" },
    { "rate" : """5.99999""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """8.99999""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """9.6""" },
    { "rate" : """7.6""" },
    { "rate" : """9.4""" },
    { "rate" : """7.3""" },
    { "rate" : """4""" },
    { "rate" : """5.99""" },
    { "rate" : """4.88999""" },
    { "rate" : """7""" },
    { "rate" : """9.02""" },
    { "rate" : """4.897""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """4.75""" },
    { "rate" : """3""" },
    { "rate" : """9.75""" },
    { "rate" : """5""" },
    { "rate" : """4.8999""" },
    { "rate" : """10""" },
    { "rate" : """4.8898""" },
    { "rate" : """9.999""" },
    { "rate" : """5""" },
    { "rate" : """9.9999""" },
    { "rate" : """3.8999""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """7.5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5.5""" },
    { "rate" : """3""" },
    { "rate" : """2.9""" },
    { "rate" : """15""" },
    { "rate" : """7.5""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """9.9999""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """4.1""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """7.5""" },
    { "rate" : """8""" },
    { "rate" : """9.99999""" },
    { "rate" : """3""" },
    { "rate" : """7.4989""" },
    { "rate" : """3.9""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """9.9989""" },
    { "rate" : """5.224""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """10.5""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """7.45""" },
    { "rate" : """9.763""" },
    { "rate" : """5""" },
    { "rate" : """7.4989""" },
    { "rate" : """4""" },
    { "rate" : """9.9989""" },
    { "rate" : """4.99""" },
    { "rate" : """9""" },
    { "rate" : """6.989""" },
    { "rate" : """10""" },
    { "rate" : """7.99999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """9.9988""" },
    { "rate" : """4""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7.5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """5""" },
    { "rate" : """3.9""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """7.5""" },
    { "rate" : """7.5""" },
    { "rate" : """7.5""" },
    { "rate" : """9""" },
    { "rate" : """10.9""" },
    { "rate" : """8""" },
    { "rate" : """7.77""" },
    { "rate" : """11.49""" },
    { "rate" : """9.99""" },
    { "rate" : """9.99""" },
    { "rate" : """9.88""" },
    { "rate" : """19.99""" },
    { "rate" : """4.99""" },
    { "rate" : """9.99""" },
    { "rate" : """9.99""" },
    { "rate" : """7.49""" },
    { "rate" : """4""" },
    { "rate" : """11""" },
    { "rate" : """9.99""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """3.75""" },
    { "rate" : """4""" },
    { "rate" : """3.98""" },
    { "rate" : """5""" },
    { "rate" : """3.999""" },
    { "rate" : """3""" },
    { "rate" : """7.5""" },
    { "rate" : """9.5""" },
    { "rate" : """3.98""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """9.5""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """3.3""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """11""" },
    { "rate" : """3.99999""" },
    { "rate" : """9.9""" },
    { "rate" : """9.9""" },
    { "rate" : """8.9""" },
    { "rate" : """7.9999""" },
    { "rate" : """5""" },
    { "rate" : """9.9""" },
    { "rate" : """3.8""" },
    { "rate" : """3.99999""" },
    { "rate" : """3.97""" },
    { "rate" : """3.9""" },
    { "rate" : """10.32""" },
    { "rate" : """10.89""" },
    { "rate" : """2.5""" },
    { "rate" : """7.49""" },
    { "rate" : """2.49999""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """3.9""" },
    { "rate" : """3.9""" },
    { "rate" : """7""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """4""" },
    { "rate" : """9.7""" },
    { "rate" : """9.99979""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """11""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """9.89""" },
    { "rate" : """9.7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5.99999""" },
    { "rate" : """5.9""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """7.25""" },
    { "rate" : """6""" },
    { "rate" : """3.9999""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """7.5""" },
    { "rate" : """0.1""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """3.5""" },
    { "rate" : """6""" },
    { "rate" : """9.99799""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """14""" },
    { "rate" : """13.16""" },
    { "rate" : """9.55""" },
    { "rate" : """10.894""" },
    { "rate" : """4.99""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """0.1""" },
    { "rate" : """11""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """3.95""" },
    { "rate" : """4.95""" },
    { "rate" : """8""" },
    { "rate" : """3.99""" },
    { "rate" : """4.95""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3.5""" },
    { "rate" : """9.9""" },
    { "rate" : """11.99999""" },
    { "rate" : """2.5""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7.5""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """3.5""" },
    { "rate" : """7.5""" },
    { "rate" : """6""" },
    { "rate" : """3.9998""" },
    { "rate" : """4.9998""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """3.88""" },
    { "rate" : """7""" },
    { "rate" : """4.95""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """7.49""" },
    { "rate" : """6""" },
    { "rate" : """3.9""" },
    { "rate" : """7.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """7""" },
    { "rate" : """3.99""" },
    { "rate" : """6.99""" },
    { "rate" : """3""" },
    { "rate" : """11""" },
    { "rate" : """8""" },
    { "rate" : """0.53""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """9.99999""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """4.75""" },
    { "rate" : """4.99""" },
    { "rate" : """0.54""" },
    { "rate" : """3.99""" },
    { "rate" : """9.99""" },
    { "rate" : """7.55""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """7.99999""" },
    { "rate" : """44.625""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """3.9998""" },
    { "rate" : """3""" },
    { "rate" : """7.999""" },
    { "rate" : """6.99""" },
    { "rate" : """7.98""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """12.5""" },
    { "rate" : """6""" },
    { "rate" : """7.4""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """1.5""" },
    { "rate" : """10""" },
    { "rate" : """2.99""" },
    { "rate" : """2.985""" },
    { "rate" : """3.99999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4.8""" },
    { "rate" : """5.7""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """4.98999""" },
    { "rate" : """5.49999""" },
    { "rate" : """7""" },
    { "rate" : """7.99999""" },
    { "rate" : """5.99""" },
    { "rate" : """5.9""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """5.99999""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """7.99999""" },
    { "rate" : """5.99999""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """6.96""" },
    { "rate" : """7.5""" },
    { "rate" : """7.5""" },
    { "rate" : """7.5""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """5.99""" },
    { "rate" : """5.89999""" },
    { "rate" : """13.99999""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """7.5""" },
    { "rate" : """3.97""" },
    { "rate" : """7.49999""" },
    { "rate" : """7.29""" },
    { "rate" : """10""" },
    { "rate" : """12.5""" },
    { "rate" : """10.5""" },
    { "rate" : """5.99999""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """7.47""" },
    { "rate" : """3.91""" },
    { "rate" : """7.2345""" },
    { "rate" : """11""" },
    { "rate" : """5.99""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """7.5""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """6""" },
    { "rate" : """4.5""" },
    { "rate" : """11""" },
    { "rate" : """7.49""" },
    { "rate" : """9.9""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """5.75""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """12.5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5.8""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5.5""" },
    { "rate" : """2.5""" },
    { "rate" : """5.99999""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """11.12""" },
    { "rate" : """8""" },
    { "rate" : """8.35""" },
    { "rate" : """7""" },
    { "rate" : """5.94""" },
    { "rate" : """5""" },
    { "rate" : """2.9""" },
    { "rate" : """14.99999""" },
    { "rate" : """8""" },
    { "rate" : """8.905""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """7.99999""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """7.9998""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """5.8989""" },
    { "rate" : """12.9989""" },
    { "rate" : """7.9998""" },
    { "rate" : """6.75""" },
    { "rate" : """7.77""" },
    { "rate" : """5""" },
    { "rate" : """5.9""" },
    { "rate" : """7.9""" },
    { "rate" : """6.99999""" },
    { "rate" : """5.9889""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """7.9""" },
    { "rate" : """5""" },
    { "rate" : """1.94444""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """7.9988""" },
    { "rate" : """9.99""" },
    { "rate" : """7.99""" },
    { "rate" : """5.99998""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """5.99""" },
    { "rate" : """6.99999""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """5.97999""" },
    { "rate" : """7.5""" },
    { "rate" : """4.26""" },
    { "rate" : """4.2""" },
    { "rate" : """6""" },
    { "rate" : """9.8""" },
    { "rate" : """9.895""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """7.9""" },
    { "rate" : """5.5""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """3.95""" },
    { "rate" : """9.5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """10.85""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6.95""" },
    { "rate" : """10""" },
    { "rate" : """7.96""" },
    { "rate" : """9.95""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """9.9""" },
    { "rate" : """5.473""" },
    { "rate" : """8""" },
    { "rate" : """2.8""" },
    { "rate" : """10""" },
    { "rate" : """5.98985""" },
    { "rate" : """10""" },
    { "rate" : """2.8""" },
    { "rate" : """2.79""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """2.8""" },
    { "rate" : """6""" },
    { "rate" : """9.99999""" },
    { "rate" : """4.5""" },
    { "rate" : """2.45""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """1.9""" },
    { "rate" : """3.5""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """2.75""" },
    { "rate" : """2.8""" },
    { "rate" : """4.5""" },
    { "rate" : """4.482""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """2.99""" },
    { "rate" : """7.9""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """2.95""" },
    { "rate" : """7.998""" },
    { "rate" : """7.6""" },
    { "rate" : """7.5""" },
    { "rate" : """3.7""" },
    { "rate" : """3""" },
    { "rate" : """2.79999""" },
    { "rate" : """5.99999""" },
    { "rate" : """3""" },
    { "rate" : """4.09""" },
    { "rate" : """2.81""" },
    { "rate" : """2.75""" },
    { "rate" : """2.885""" },
    { "rate" : """8""" },
    { "rate" : """9.89""" },
    { "rate" : """2.985""" },
    { "rate" : """3.5""" },
    { "rate" : """8""" },
    { "rate" : """9.99999""" },
    { "rate" : """8.75""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """7.463""" },
    { "rate" : """7.99""" },
    { "rate" : """6""" },
    { "rate" : """5.99999""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """5.99979""" },
    { "rate" : """2.99979""" },
    { "rate" : """2.8""" },
    { "rate" : """0.52999""" },
    { "rate" : """9.91""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """7.959""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """4.7""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """7.77778""" },
    { "rate" : """3.88889""" },
    { "rate" : """4.5""" },
    { "rate" : """3""" },
    { "rate" : """3.9""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """1.43""" },
    { "rate" : """4.9999""" },
    { "rate" : """0.99979""" },
    { "rate" : """0.99999""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """5.98""" },
    { "rate" : """5""" },
    { "rate" : """0.99""" },
    { "rate" : """4.45""" },
    { "rate" : """3.9989""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """6.98""" },
    { "rate" : """30""" },
    { "rate" : """9.99""" },
    { "rate" : """0.99999""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """12.999""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """0.55""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """0.8""" },
    { "rate" : """1.8""" },
    { "rate" : """6""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """0.99""" },
    { "rate" : """0.999""" },
    { "rate" : """11""" },
    { "rate" : """2.95999""" },
    { "rate" : """8.5""" },
    { "rate" : """15""" },
    { "rate" : """5.95""" },
    { "rate" : """14.9""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """12.5""" },
    { "rate" : """3.99999""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """9.99999""" },
    { "rate" : """9""" },
    { "rate" : """13.9999""" },
    { "rate" : """9.9""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """3""" },
    { "rate" : """14.16""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """13""" },
    { "rate" : """13""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """5.99""" },
    { "rate" : """11""" },
    { "rate" : """7.49979""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """9.9""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """7.84""" },
    { "rate" : """5.98999""" },
    { "rate" : """5.99""" },
    { "rate" : """10.99""" },
    { "rate" : """7.5""" },
    { "rate" : """11.9""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """14.99""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """2.5""" },
    { "rate" : """8.978""" },
    { "rate" : """8""" },
    { "rate" : """4.99""" },
    { "rate" : """11.5""" },
    { "rate" : """11""" },
    { "rate" : """7""" },
    { "rate" : """11.99989""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """2.9999""" },
    { "rate" : """9""" },
    { "rate" : """11""" },
    { "rate" : """3""" },
    { "rate" : """3.99""" },
    { "rate" : """7""" },
    { "rate" : """6.5""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """7.88""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """7.05""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """7.85""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """17""" },
    { "rate" : """9.25""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """9.99999""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """8.25""" },
    { "rate" : """6""" },
    { "rate" : """5.9""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """8.5""" },
    { "rate" : """12""" },
    { "rate" : """7.5""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8.99""" },
    { "rate" : """8.9988""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """5.99""" },
    { "rate" : """0.74917""" },
    { "rate" : """5.998""" },
    { "rate" : """9.998""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """0.54167""" },
    { "rate" : """7""" },
    { "rate" : """0.51""" },
    { "rate" : """6.99895""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """3.9989""" },
    { "rate" : """11""" },
    { "rate" : """6.99""" },
    { "rate" : """4.25""" },
    { "rate" : """8""" },
    { "rate" : """8.2""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """8.25""" },
    { "rate" : """5""" },
    { "rate" : """3.33""" },
    { "rate" : """3.99999""" },
    { "rate" : """9""" },
    { "rate" : """3.88889""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7.8""" },
    { "rate" : """7.5""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """4.99999""" },
    { "rate" : """13.98""" },
    { "rate" : """7""" },
    { "rate" : """9.5""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """4.9999""" },
    { "rate" : """4.95""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """5.55""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """6.99999""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """8.99999""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """8.99999""" },
    { "rate" : """9.999""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """6.99979""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """9.99979""" },
    { "rate" : """9""" },
    { "rate" : """9.99979""" },
    { "rate" : """7""" },
    { "rate" : """8.25""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """3.99999""" },
    { "rate" : """3.5""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """6.99999""" },
    { "rate" : """7""" },
    { "rate" : """9.9""" },
    { "rate" : """3.9""" },
    { "rate" : """9""" },
    { "rate" : """11""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """9.9898""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """3""" },
    { "rate" : """2.999""" },
    { "rate" : """7""" },
    { "rate" : """9.99""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """9.95""" },
    { "rate" : """16""" },
    { "rate" : """19.99""" },
    { "rate" : """6.9""" },
    { "rate" : """5.5""" },
    { "rate" : """12.5""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """10.90777""" },
    { "rate" : """12""" },
    { "rate" : """8.33333""" },
    { "rate" : """17.22""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """9.98""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """9.9999""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """2.9""" },
    { "rate" : """7""" },
    { "rate" : """8.2""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """7.75""" },
    { "rate" : """9.9""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """5.49999""" },
    { "rate" : """6.5""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """6.9""" },
    { "rate" : """9""" },
    { "rate" : """2.99167""" },
    { "rate" : """9""" },
    { "rate" : """4.99""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """2.94""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """14""" },
    { "rate" : """14""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.99""" },
    { "rate" : """11""" },
    { "rate" : """9.8""" },
    { "rate" : """2.4""" },
    { "rate" : """17.5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """10.9""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """14""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """4.88""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """14""" },
    { "rate" : """8.999""" },
    { "rate" : """13.89""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """14.99""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """8.99""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9.989""" },
    { "rate" : """7.55""" },
    { "rate" : """11.99""" },
    { "rate" : """14.9""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """4.99979""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """10.99999""" },
    { "rate" : """5.98""" },
    { "rate" : """9.95""" },
    { "rate" : """5""" },
    { "rate" : """11.99""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2.8""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """10.98""" },
    { "rate" : """5.9""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """7.99999""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """4.99999""" },
    { "rate" : """8""" },
    { "rate" : """7.9999""" },
    { "rate" : """7.99999""" },
    { "rate" : """5.99999""" },
    { "rate" : """3""" },
    { "rate" : """14""" },
    { "rate" : """9.998""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """9.8""" },
    { "rate" : """2.99999""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """0.1""" },
    { "rate" : """9.99999""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """5.9998""" },
    { "rate" : """7.989""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """6.5""" },
    { "rate" : """2""" },
    { "rate" : """4.9""" },
    { "rate" : """4.86111""" },
    { "rate" : """9.9""" },
    { "rate" : """16.66667""" },
    { "rate" : """3.88889""" },
    { "rate" : """1.94444""" },
    { "rate" : """1.89999""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """7.89999""" },
    { "rate" : """9.89999""" },
    { "rate" : """3.98""" },
    { "rate" : """4""" },
    { "rate" : """19.99999""" },
    { "rate" : """10""" },
    { "rate" : """14.9999""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """1.999""" },
    { "rate" : """3.9""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """8.9""" },
    { "rate" : """10""" },
    { "rate" : """1.99999""" },
    { "rate" : """7.599""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """1.9""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """18""" },
    { "rate" : """6""" },
    { "rate" : """0.748""" },
    { "rate" : """4.9""" },
    { "rate" : """4.8""" },
    { "rate" : """8""" },
    { "rate" : """3.9""" },
    { "rate" : """1""" },
    { "rate" : """1.97999""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """2.33333""" },
    { "rate" : """3""" },
    { "rate" : """1.9998""" },
    { "rate" : """1.99979""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """1.98""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """2.9""" },
    { "rate" : """1.97979""" },
    { "rate" : """2.99""" },
    { "rate" : """2.99""" },
    { "rate" : """3""" },
    { "rate" : """1.98""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """9.72222""" },
    { "rate" : """2.99444""" },
    { "rate" : """7.97222""" },
    { "rate" : """1.8""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """2.98999""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.99""" },
    { "rate" : """2.99444""" },
    { "rate" : """20""" },
    { "rate" : """1.9""" },
    { "rate" : """1.9""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """1.99999""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """1.75""" },
    { "rate" : """15""" },
    { "rate" : """14.89""" },
    { "rate" : """1.95""" },
    { "rate" : """3""" },
    { "rate" : """2.99""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """20""" },
    { "rate" : """3""" },
    { "rate" : """1.94999""" },
    { "rate" : """14.99999""" },
    { "rate" : """7.89""" },
    { "rate" : """14""" },
    { "rate" : """6""" },
    { "rate" : """5.99999""" },
    { "rate" : """6""" },
    { "rate" : """2.99""" },
    { "rate" : """6""" },
    { "rate" : """5.99979""" },
    { "rate" : """14.5""" },
    { "rate" : """15""" },
    { "rate" : """4.98""" },
    { "rate" : """14""" },
    { "rate" : """12.9999""" },
    { "rate" : """1.98""" },
    { "rate" : """1.95""" },
    { "rate" : """3""" },
    { "rate" : """2.9999""" },
    { "rate" : """5""" },
    { "rate" : """2.99""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """1.979""" },
    { "rate" : """5.99999""" },
    { "rate" : """5""" },
    { "rate" : """8.5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5.99998""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """1.98""" },
    { "rate" : """8""" },
    { "rate" : """1.99988""" },
    { "rate" : """19.44444""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """8.5""" },
    { "rate" : """3""" },
    { "rate" : """1.95""" },
    { "rate" : """9.998""" },
    { "rate" : """5""" },
    { "rate" : """14.99""" },
    { "rate" : """5.5""" },
    { "rate" : """1.975""" },
    { "rate" : """6""" },
    { "rate" : """14""" },
    { "rate" : """14.99999""" },
    { "rate" : """14.99""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """35.77""" },
    { "rate" : """6""" },
    { "rate" : """1.99999""" },
    { "rate" : """5.99""" },
    { "rate" : """13""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """9.99""" },
    { "rate" : """12.5""" },
    { "rate" : """7""" },
    { "rate" : """7.5""" },
    { "rate" : """6""" },
    { "rate" : """1.99""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """1.99999""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5.99999""" },
    { "rate" : """5.99""" },
    { "rate" : """14""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """5.95""" },
    { "rate" : """1.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.94""" },
    { "rate" : """5.9""" },
    { "rate" : """1.93""" },
    { "rate" : """15""" },
    { "rate" : """4.95""" },
    { "rate" : """5.99""" },
    { "rate" : """19.5""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """5.978""" },
    { "rate" : """7.9999""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """5.9""" },
    { "rate" : """9.99999""" },
    { "rate" : """2""" },
    { "rate" : """5.99979""" },
    { "rate" : """9.8""" },
    { "rate" : """8""" },
    { "rate" : """4.95""" },
    { "rate" : """1.92""" },
    { "rate" : """14.5""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.88""" },
    { "rate" : """5.98""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6.9""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """2""" },
    { "rate" : """1.99995""" },
    { "rate" : """6""" },
    { "rate" : """5.5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """1.95""" },
    { "rate" : """9""" },
    { "rate" : """7.5""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """11""" },
    { "rate" : """25""" },
    { "rate" : """12""" },
    { "rate" : """9.5""" },
    { "rate" : """7.5""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """7.5""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """1.9""" },
    { "rate" : """7.5""" },
    { "rate" : """19.05""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """1.8""" },
    { "rate" : """14""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """19.98889""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """3.5""" },
    { "rate" : """4.777""" },
    { "rate" : """8.33333""" },
    { "rate" : """9""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """7.49999""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """2.99""" },
    { "rate" : """6""" },
    { "rate" : """9.95""" },
    { "rate" : """7""" },
    { "rate" : """5.99999""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """4.8""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """5.99899""" },
    { "rate" : """13.99999""" },
    { "rate" : """6.9""" },
    { "rate" : """7.5""" },
    { "rate" : """19""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """9.2""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """1.99999""" },
    { "rate" : """6""" },
    { "rate" : """5.99""" },
    { "rate" : """20""" },
    { "rate" : """8.33333""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """5.99999""" },
    { "rate" : """4.7""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """14.99998""" },
    { "rate" : """5.9""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """5.9""" },
    { "rate" : """7.95""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """4.7""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """2.899""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """14.99""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """14.5""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """7.68""" },
    { "rate" : """15""" },
    { "rate" : """5.96""" },
    { "rate" : """5.99""" },
    { "rate" : """14""" },
    { "rate" : """1.95""" },
    { "rate" : """4.95""" },
    { "rate" : """6""" },
    { "rate" : """7.5""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """7.99""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """7.9""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """6.6""" },
    { "rate" : """5""" },
    { "rate" : """4.75""" },
    { "rate" : """5""" },
    { "rate" : """5.99999""" },
    { "rate" : """6.87""" },
    { "rate" : """7.35""" },
    { "rate" : """4.9""" },
    { "rate" : """1.4""" },
    { "rate" : """1.9""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """7.99999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5.985""" },
    { "rate" : """7.8""" },
    { "rate" : """5.9""" },
    { "rate" : """5.9""" },
    { "rate" : """5.91""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """19""" },
    { "rate" : """7.99998""" },
    { "rate" : """5.99""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """4.5""" },
    { "rate" : """2""" },
    { "rate" : """2.99999""" },
    { "rate" : """14.99""" },
    { "rate" : """5""" },
    { "rate" : """7.96""" },
    { "rate" : """1.99""" },
    { "rate" : """5.97""" },
    { "rate" : """7.463""" },
    { "rate" : """5.97""" },
    { "rate" : """14.925""" },
    { "rate" : """6.716""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """18""" },
    { "rate" : """7.99""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """5.99999""" },
    { "rate" : """5""" },
    { "rate" : """5.89999""" },
    { "rate" : """7.99999""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """9.9899""" },
    { "rate" : """17.5""" },
    { "rate" : """1.999""" },
    { "rate" : """7.96""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """7.96""" },
    { "rate" : """7""" },
    { "rate" : """7.214""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """5.99998""" },
    { "rate" : """8""" },
    { "rate" : """6.99""" },
    { "rate" : """5.99""" },
    { "rate" : """17.4""" },
    { "rate" : """7.99""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5.9998""" },
    { "rate" : """15""" },
    { "rate" : """1.97""" },
    { "rate" : """1.95""" },
    { "rate" : """11.99""" },
    { "rate" : """999""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """5.999""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """1.99""" },
    { "rate" : """5""" },
    { "rate" : """7.9""" },
    { "rate" : """4.5""" },
    { "rate" : """9.99""" },
    { "rate" : """1.99""" },
    { "rate" : """2.99""" },
    { "rate" : """7.99""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """7.8""" },
    { "rate" : """2""" },
    { "rate" : """12.99""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """8.5""" },
    { "rate" : """1.98""" },
    { "rate" : """7.99999""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """11.75""" },
    { "rate" : """10""" },
    { "rate" : """17.4""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5.9""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """19.19""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """4.99999""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """9.99""" },
    { "rate" : """6""" },
    { "rate" : """5.9""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """7.899""" },
    { "rate" : """9.99999""" },
    { "rate" : """8""" },
    { "rate" : """2.95""" },
    { "rate" : """7.99""" },
    { "rate" : """1.99889""" },
    { "rate" : """1.95""" },
    { "rate" : """8.4""" },
    { "rate" : """5.5""" },
    { "rate" : """8.3334""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """13""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """20""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """2.99999""" },
    { "rate" : """2.99""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """2.985""" },
    { "rate" : """9.99""" },
    { "rate" : """2.99999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """7.99999""" },
    { "rate" : """6""" },
    { "rate" : """9.99999""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """13.99999""" },
    { "rate" : """2""" },
    { "rate" : """17""" },
    { "rate" : """9.99""" },
    { "rate" : """24""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """5.9999""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """7.9999""" },
    { "rate" : """1.99""" },
    { "rate" : """2""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """9.2""" },
    { "rate" : """8""" },
    { "rate" : """14""" },
    { "rate" : """2""" },
    { "rate" : """4.975""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """2.985""" },
    { "rate" : """13.9542""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """14""" },
    { "rate" : """5.5""" },
    { "rate" : """1.9999""" },
    { "rate" : """13""" },
    { "rate" : """14""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """4.8""" },
    { "rate" : """3""" },
    { "rate" : """4.975""" },
    { "rate" : """5""" },
    { "rate" : """8.5""" },
    { "rate" : """7.75""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """14""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """0.00039""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """7.9999""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """9.999""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """11""" },
    { "rate" : """8""" },
    { "rate" : """7.9999""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """6.5""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """14""" },
    { "rate" : """9.9999""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """5.9998""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """9.9988""" },
    { "rate" : """2.9998""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """9.79""" },
    { "rate" : """4.9""" },
    { "rate" : """2""" },
    { "rate" : """14""" },
    { "rate" : """2.9""" },
    { "rate" : """2.89""" },
    { "rate" : """7.999""" },
    { "rate" : """9.62""" },
    { "rate" : """10""" },
    { "rate" : """14.95""" },
    { "rate" : """6""" },
    { "rate" : """4.95""" },
    { "rate" : """2.99""" },
    { "rate" : """6.5""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """13.5""" },
    { "rate" : """3""" },
    { "rate" : """7.8""" },
    { "rate" : """14.99999""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """13.5""" },
    { "rate" : """4.99""" },
    { "rate" : """1.9975""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """1.9""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """9.9""" },
    { "rate" : """7.89999""" },
    { "rate" : """7.5""" },
    { "rate" : """3""" },
    { "rate" : """2.9999""" },
    { "rate" : """7""" },
    { "rate" : """7.99""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """4.98""" },
    { "rate" : """11.9""" },
    { "rate" : """13.99""" },
    { "rate" : """3.25""" },
    { "rate" : """7.5""" },
    { "rate" : """1.9""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """1.94444""" },
    { "rate" : """3.4""" },
    { "rate" : """3.5""" },
    { "rate" : """9.92""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """1.5""" },
    { "rate" : """1.9""" },
    { "rate" : """3.49999""" },
    { "rate" : """29.99999""" },
    { "rate" : """3.5""" },
    { "rate" : """4.9""" },
    { "rate" : """13.9""" },
    { "rate" : """3.5""" },
    { "rate" : """1.99""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.989""" },
    { "rate" : """8""" },
    { "rate" : """3.30556""" },
    { "rate" : """17.99999""" },
    { "rate" : """14""" },
    { "rate" : """3.39""" },
    { "rate" : """3.49999""" },
    { "rate" : """1.94444""" },
    { "rate" : """1.94444""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """18""" },
    { "rate" : """7.9995""" },
    { "rate" : """15""" },
    { "rate" : """3.5""" },
    { "rate" : """18""" },
    { "rate" : """18""" },
    { "rate" : """1.9""" },
    { "rate" : """1.5""" },
    { "rate" : """17.999""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """6.25""" },
    { "rate" : """3""" },
    { "rate" : """3.5""" },
    { "rate" : """9.9999""" },
    { "rate" : """15""" },
    { "rate" : """17.9""" },
    { "rate" : """18""" },
    { "rate" : """6.5""" },
    { "rate" : """9.999""" },
    { "rate" : """3""" },
    { "rate" : """18""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """2.99998""" },
    { "rate" : """3.5""" },
    { "rate" : """4.95""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """4.9""" },
    { "rate" : """18""" },
    { "rate" : """17.99999""" },
    { "rate" : """14""" },
    { "rate" : """17.9""" },
    { "rate" : """4.5""" },
    { "rate" : """18""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """17.91""" },
    { "rate" : """3.49""" },
    { "rate" : """4.99999""" },
    { "rate" : """18""" },
    { "rate" : """9""" },
    { "rate" : """18""" },
    { "rate" : """18""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """13.89""" },
    { "rate" : """3""" },
    { "rate" : """4.9999""" },
    { "rate" : """14""" },
    { "rate" : """14""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """4.49""" },
    { "rate" : """3.49999""" },
    { "rate" : """29.99998""" },
    { "rate" : """2.99998""" },
    { "rate" : """10""" },
    { "rate" : """9.99998""" },
    { "rate" : """17.99999""" },
    { "rate" : """18""" },
    { "rate" : """3""" },
    { "rate" : """5.5""" },
    { "rate" : """15""" },
    { "rate" : """18""" },
    { "rate" : """18""" },
    { "rate" : """18""" },
    { "rate" : """4.99999""" },
    { "rate" : """2.99999""" },
    { "rate" : """4.89""" },
    { "rate" : """3.5""" },
    { "rate" : """2.989""" },
    { "rate" : """2.99""" },
    { "rate" : """3.3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """8.95""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """17""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """2.99""" },
    { "rate" : """0.15""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """17""" },
    { "rate" : """0.15""" },
    { "rate" : """2.999""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """17.99999""" },
    { "rate" : """3.25""" },
    { "rate" : """0.15""" },
    { "rate" : """0.15""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """2.9""" },
    { "rate" : """14""" },
    { "rate" : """18""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """7.99998""" },
    { "rate" : """14""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """0.15""" },
    { "rate" : """3.4999""" },
    { "rate" : """10""" },
    { "rate" : """9.95""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.999""" },
    { "rate" : """0.14979""" },
    { "rate" : """0.15""" },
    { "rate" : """0.15""" },
    { "rate" : """15""" },
    { "rate" : """2.9975""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """0.15""" },
    { "rate" : """5""" },
    { "rate" : """0.15""" },
    { "rate" : """3""" },
    { "rate" : """0.15""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """9.99""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """2.985""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """0.15""" },
    { "rate" : """2.99""" },
    { "rate" : """9""" },
    { "rate" : """2.99999""" },
    { "rate" : """14""" },
    { "rate" : """0.15""" },
    { "rate" : """2""" },
    { "rate" : """14.99""" },
    { "rate" : """9.48999""" },
    { "rate" : """8.5""" },
    { "rate" : """6""" },
    { "rate" : """0.15""" },
    { "rate" : """2.99998""" },
    { "rate" : """10""" },
    { "rate" : """0.15""" },
    { "rate" : """5""" },
    { "rate" : """9.99998""" },
    { "rate" : """0.149""" },
    { "rate" : """3""" },
    { "rate" : """14""" },
    { "rate" : """3.5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """0.15""" },
    { "rate" : """0.14989""" },
    { "rate" : """4.8""" },
    { "rate" : """9.95""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """14.98999""" },
    { "rate" : """6.5""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """9.9999""" },
    { "rate" : """3""" },
    { "rate" : """14""" },
    { "rate" : """13.999""" },
    { "rate" : """3.49""" },
    { "rate" : """1.94444""" },
    { "rate" : """18""" },
    { "rate" : """10""" },
    { "rate" : """6.49""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """3.9""" },
    { "rate" : """4""" },
    { "rate" : """6.99""" },
    { "rate" : """7""" },
    { "rate" : """13.9""" },
    { "rate" : """9.9""" },
    { "rate" : """9.9""" },
    { "rate" : """6.99999""" },
    { "rate" : """6.91""" },
    { "rate" : """9.99""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """6.75""" },
    { "rate" : """30""" },
    { "rate" : """0.149""" },
    { "rate" : """14""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """29""" },
    { "rate" : """14.5""" },
    { "rate" : """1""" },
    { "rate" : """6.3""" },
    { "rate" : """13""" },
    { "rate" : """11""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """0.145""" },
    { "rate" : """6.99979""" },
    { "rate" : """10""" },
    { "rate" : """0.149""" },
    { "rate" : """2.99""" },
    { "rate" : """0.13611""" },
    { "rate" : """12""" },
    { "rate" : """3""" },
    { "rate" : """8.33333""" },
    { "rate" : """0.14999""" },
    { "rate" : """6.89""" },
    { "rate" : """9.99""" },
    { "rate" : """8""" },
    { "rate" : """30""" },
    { "rate" : """15""" },
    { "rate" : """17""" },
    { "rate" : """5""" },
    { "rate" : """6.8""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """6.8""" },
    { "rate" : """10""" },
    { "rate" : """6.99999""" },
    { "rate" : """3.2999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2.98""" },
    { "rate" : """6.99999""" },
    { "rate" : """9.95""" },
    { "rate" : """5.9""" },
    { "rate" : """7""" },
    { "rate" : """2.79999""" },
    { "rate" : """10""" },
    { "rate" : """2.8""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """3.49""" },
    { "rate" : """10""" },
    { "rate" : """8.5""" },
    { "rate" : """6.9""" },
    { "rate" : """0.145""" },
    { "rate" : """10""" },
    { "rate" : """2.79999""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """6.99""" },
    { "rate" : """9.99899""" },
    { "rate" : """0.14999""" },
    { "rate" : """2.5""" },
    { "rate" : """2.99999""" },
    { "rate" : """3.5""" },
    { "rate" : """2.7""" },
    { "rate" : """4""" },
    { "rate" : """14.98""" },
    { "rate" : """29.959""" },
    { "rate" : """0.15""" },
    { "rate" : """15""" },
    { "rate" : """14.9""" },
    { "rate" : """14.99""" },
    { "rate" : """4.5""" },
    { "rate" : """2.8""" },
    { "rate" : """0.11111""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """0.13""" },
    { "rate" : """0.15""" },
    { "rate" : """2.8""" },
    { "rate" : """2.786""" },
    { "rate" : """2.7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """2.9""" },
    { "rate" : """4.99999""" },
    { "rate" : """9""" },
    { "rate" : """14""" },
    { "rate" : """28""" },
    { "rate" : """6""" },
    { "rate" : """0.15""" },
    { "rate" : """2.99""" },
    { "rate" : """3.89999""" },
    { "rate" : """2.79""" },
    { "rate" : """18""" },
    { "rate" : """6""" },
    { "rate" : """3.5""" },
    { "rate" : """9""" },
    { "rate" : """0.15""" },
    { "rate" : """5.85""" },
    { "rate" : """0.99999""" },
    { "rate" : """9.99""" },
    { "rate" : """9.99""" },
    { "rate" : """6.99""" },
    { "rate" : """11.99""" },
    { "rate" : """4.99""" },
    { "rate" : """9.98999""" },
    { "rate" : """0.15""" },
    { "rate" : """19.99""" },
    { "rate" : """6.95""" },
    { "rate" : """9.99""" },
    { "rate" : """3.49998""" },
    { "rate" : """9.998""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """7.89""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """4.975""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """9.9""" },
    { "rate" : """8""" },
    { "rate" : """13.9999""" },
    { "rate" : """3.4999""" },
    { "rate" : """8.5""" },
    { "rate" : """17.5""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """14.99""" },
    { "rate" : """15""" },
    { "rate" : """28""" },
    { "rate" : """18""" },
    { "rate" : """2.8""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """9""" },
    { "rate" : """9.98999""" },
    { "rate" : """9.98999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """4.48""" },
    { "rate" : """3.4""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """1""" },
    { "rate" : """14.89999""" },
    { "rate" : """3.5""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """4.5""" },
    { "rate" : """14.9""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.99""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """0.999""" },
    { "rate" : """9""" },
    { "rate" : """0.9888""" },
    { "rate" : """15""" },
    { "rate" : """0.98""" },
    { "rate" : """9""" },
    { "rate" : """0.998""" },
    { "rate" : """10""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.95""" },
    { "rate" : """4""" },
    { "rate" : """0.97""" },
    { "rate" : """5""" },
    { "rate" : """0.95""" },
    { "rate" : """28""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """14.999""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """3.5""" },
    { "rate" : """3.49""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """7.988""" },
    { "rate" : """0.99""" },
    { "rate" : """2.79998""" },
    { "rate" : """15""" },
    { "rate" : """14.99999""" },
    { "rate" : """0.99979""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.97222""" },
    { "rate" : """0.99999""" },
    { "rate" : """9""" },
    { "rate" : """11""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.95""" },
    { "rate" : """4.935""" },
    { "rate" : """8.68955""" },
    { "rate" : """4.9""" },
    { "rate" : """9""" },
    { "rate" : """8.99999""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """7.88""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """8.9999""" },
    { "rate" : """9.999""" },
    { "rate" : """8.875""" },
    { "rate" : """3.5""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """2.8""" },
    { "rate" : """10""" },
    { "rate" : """9.67""" },
    { "rate" : """9.899""" },
    { "rate" : """9""" },
    { "rate" : """13.5""" },
    { "rate" : """8.99999""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """11.99""" },
    { "rate" : """0.83333""" },
    { "rate" : """0.83333""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """6.9999""" },
    { "rate" : """14""" },
    { "rate" : """8.9""" },
    { "rate" : """12""" },
    { "rate" : """28""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """11.9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """2.8""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """14.99""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """30""" },
    { "rate" : """10""" },
    { "rate" : """13.9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """20""" },
    { "rate" : """8.9""" },
    { "rate" : """8.99999""" },
    { "rate" : """1.9975""" },
    { "rate" : """9""" },
    { "rate" : """29.99999""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """9""" },
    { "rate" : """30""" },
    { "rate" : """9""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """7.89""" },
    { "rate" : """7""" },
    { "rate" : """4.9999""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """5.9999""" },
    { "rate" : """18""" },
    { "rate" : """2.5""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """2.99999""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """8.999""" },
    { "rate" : """5.99999""" },
    { "rate" : """9.99""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """2.8""" },
    { "rate" : """7.9""" },
    { "rate" : """3.5""" },
    { "rate" : """2.99""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """7.99""" },
    { "rate" : """8.5""" },
    { "rate" : """13.8""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """5.75""" },
    { "rate" : """8.5""" },
    { "rate" : """10""" },
    { "rate" : """4.8""" },
    { "rate" : """9.5""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.8""" },
    { "rate" : """14""" },
    { "rate" : """3""" },
    { "rate" : """2.99444""" },
    { "rate" : """2.8""" },
    { "rate" : """2.85""" },
    { "rate" : """4.95""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.79""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """4.5""" },
    { "rate" : """20""" },
    { "rate" : """3""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """2.8""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """19.9""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """2.99""" },
    { "rate" : """7.99""" },
    { "rate" : """2.99""" },
    { "rate" : """9.9""" },
    { "rate" : """2.8""" },
    { "rate" : """7.99999""" },
    { "rate" : """1""" },
    { "rate" : """9.99998""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """7.99""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """4.99""" },
    { "rate" : """2.98999""" },
    { "rate" : """3.5""" },
    { "rate" : """4.99""" },
    { "rate" : """2""" },
    { "rate" : """3.5""" },
    { "rate" : """4""" },
    { "rate" : """3.49999""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """2""" },
    { "rate" : """17.99895""" },
    { "rate" : """2.9999""" },
    { "rate" : """1.99""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """4.5""" },
    { "rate" : """2.98995""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2.99999""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """3""" },
    { "rate" : """7.999""" },
    { "rate" : """3.49""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """3.49988""" },
    { "rate" : """2""" },
    { "rate" : """3.85""" },
    { "rate" : """9""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """3.30556""" },
    { "rate" : """3.49""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """2.7""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """2.98""" },
    { "rate" : """3.5""" },
    { "rate" : """3.4""" },
    { "rate" : """3.5""" },
    { "rate" : """4.94999""" },
    { "rate" : """4.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """4.99""" },
    { "rate" : """4.89611""" },
    { "rate" : """3.42""" },
    { "rate" : """10""" },
    { "rate" : """3.49""" },
    { "rate" : """3.475""" },
    { "rate" : """3.2""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """3.5""" },
    { "rate" : """3""" },
    { "rate" : """2.8""" },
    { "rate" : """12""" },
    { "rate" : """4.9""" },
    { "rate" : """9""" },
    { "rate" : """18""" },
    { "rate" : """4.5""" },
    { "rate" : """3.5""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """4.98""" },
    { "rate" : """4.9998""" },
    { "rate" : """4.98""" },
    { "rate" : """4.9888""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9.1""" },
    { "rate" : """9.99998""" },
    { "rate" : """4.99""" },
    { "rate" : """4.99""" },
    { "rate" : """9.99""" },
    { "rate" : """6.99""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """3.49999""" },
    { "rate" : """10""" },
    { "rate" : """3.2""" },
    { "rate" : """7.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.98""" },
    { "rate" : """2.9""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """4.9999""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9.98""" },
    { "rate" : """4.98""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """9.75""" },
    { "rate" : """4""" },
    { "rate" : """9.99998""" },
    { "rate" : """3.49999""" },
    { "rate" : """3.5""" },
    { "rate" : """2.5""" },
    { "rate" : """3.2""" },
    { "rate" : """9""" },
    { "rate" : """4.99999""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """3.49""" },
    { "rate" : """2.8""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """9.84""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """3.48""" },
    { "rate" : """12""" },
    { "rate" : """3.49""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """3.9""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """3.5""" },
    { "rate" : """6""" },
    { "rate" : """2.52778""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """1.94444""" },
    { "rate" : """9.99""" },
    { "rate" : """5""" },
    { "rate" : """2.8""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5.99""" },
    { "rate" : """10""" },
    { "rate" : """5.99979""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """12.49""" },
    { "rate" : """3.4""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """2.99""" },
    { "rate" : """9.99999""" },
    { "rate" : """4.999""" },
    { "rate" : """9.9""" },
    { "rate" : """9.99999""" },
    { "rate" : """6""" },
    { "rate" : """22""" },
    { "rate" : """6""" },
    { "rate" : """8.5""" },
    { "rate" : """22""" },
    { "rate" : """12.49999""" },
    { "rate" : """16.98765""" },
    { "rate" : """5""" },
    { "rate" : """5.5""" },
    { "rate" : """4.86111""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """2.79""" },
    { "rate" : """3.49""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """12.5""" },
    { "rate" : """2.8""" },
    { "rate" : """5""" },
    { "rate" : """22""" },
    { "rate" : """5""" },
    { "rate" : """2.68333""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.5""" },
    { "rate" : """10""" },
    { "rate" : """5.9""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """2.5""" },
    { "rate" : """5.9999""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """12.5""" },
    { "rate" : """4""" },
    { "rate" : """5.5""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """20""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """14""" },
    { "rate" : """6.49""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """3.48""" },
    { "rate" : """8""" },
    { "rate" : """3.49""" },
    { "rate" : """2.59""" },
    { "rate" : """11.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.9988""" },
    { "rate" : """15""" },
    { "rate" : """5.5""" },
    { "rate" : """17.5""" },
    { "rate" : """4""" },
    { "rate" : """18""" },
    { "rate" : """5.5""" },
    { "rate" : """21.99""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """4.98""" },
    { "rate" : """3""" },
    { "rate" : """0.99998""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """3.4""" },
    { "rate" : """3.45""" },
    { "rate" : """5""" },
    { "rate" : """3.49999""" },
    { "rate" : """6.9""" },
    { "rate" : """5""" },
    { "rate" : """3.49995""" },
    { "rate" : """21.999""" },
    { "rate" : """2""" },
    { "rate" : """19.99""" },
    { "rate" : """2.8""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """11.5""" },
    { "rate" : """5.49999""" },
    { "rate" : """6.9""" },
    { "rate" : """6""" },
    { "rate" : """6.9999""" },
    { "rate" : """5""" },
    { "rate" : """21.9999""" },
    { "rate" : """3.495""" },
    { "rate" : """4.9""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """13""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """1.97""" },
    { "rate" : """1.96""" },
    { "rate" : """1.85""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """14""" },
    { "rate" : """6.95""" },
    { "rate" : """2.5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1.84999""" },
    { "rate" : """11.999""" },
    { "rate" : """6.999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """12.5""" },
    { "rate" : """21""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """5.49""" },
    { "rate" : """21.99""" },
    { "rate" : """1.8""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """4.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """1.99999""" },
    { "rate" : """21.99999""" },
    { "rate" : """4.5""" },
    { "rate" : """4.8""" },
    { "rate" : """10""" },
    { "rate" : """2.8""" },
    { "rate" : """4""" },
    { "rate" : """14""" },
    { "rate" : """3""" },
    { "rate" : """1.99999""" },
    { "rate" : """2.8""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """1.99999""" },
    { "rate" : """2.8""" },
    { "rate" : """2.8""" },
    { "rate" : """3.88888""" },
    { "rate" : """1.9""" },
    { "rate" : """21.99999""" },
    { "rate" : """3""" },
    { "rate" : """11.98""" },
    { "rate" : """2""" },
    { "rate" : """20""" },
    { "rate" : """14""" },
    { "rate" : """3.99""" },
    { "rate" : """1.99""" },
    { "rate" : """11""" },
    { "rate" : """3""" },
    { "rate" : """6.5""" },
    { "rate" : """2.75""" },
    { "rate" : """11.9""" },
    { "rate" : """1.99979""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """11.5""" },
    { "rate" : """9.5""" },
    { "rate" : """3.95""" },
    { "rate" : """2""" },
    { "rate" : """2.8""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """6.99""" },
    { "rate" : """5.49""" },
    { "rate" : """11.99""" },
    { "rate" : """1.99""" },
    { "rate" : """9.99""" },
    { "rate" : """3.99""" },
    { "rate" : """11.9999""" },
    { "rate" : """4.9999""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """21.99999""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """4.99999""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """20""" },
    { "rate" : """9.99""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """3.99""" },
    { "rate" : """3""" },
    { "rate" : """6.99""" },
    { "rate" : """21.99""" },
    { "rate" : """6""" },
    { "rate" : """9.99""" },
    { "rate" : """3.99""" },
    { "rate" : """6""" },
    { "rate" : """20""" },
    { "rate" : """21.99""" },
    { "rate" : """21.99""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """3.99""" },
    { "rate" : """11.9""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.5""" },
    { "rate" : """9.9""" },
    { "rate" : """6.5""" },
    { "rate" : """21.5""" },
    { "rate" : """17.5""" },
    { "rate" : """9.9""" },
    { "rate" : """3.5""" },
    { "rate" : """14""" },
    { "rate" : """12""" },
    { "rate" : """21""" },
    { "rate" : """18""" },
    { "rate" : """8""" },
    { "rate" : """7.999""" },
    { "rate" : """20""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """7.81""" },
    { "rate" : """3.9""" },
    { "rate" : """20""" },
    { "rate" : """21.9899""" },
    { "rate" : """7""" },
    { "rate" : """9.99999""" },
    { "rate" : """6.99""" },
    { "rate" : """3.999""" },
    { "rate" : """9""" },
    { "rate" : """7.999""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """9.985""" },
    { "rate" : """13.99""" },
    { "rate" : """9""" },
    { "rate" : """3.88""" },
    { "rate" : """7.8""" },
    { "rate" : """6.89""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """9.99""" },
    { "rate" : """9.97999""" },
    { "rate" : """9.91999""" },
    { "rate" : """10""" },
    { "rate" : """21.999""" },
    { "rate" : """9.99""" },
    { "rate" : """7""" },
    { "rate" : """3.9""" },
    { "rate" : """9.5""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """3.5""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """3.9""" },
    { "rate" : """8.68""" },
    { "rate" : """17""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """20""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """9.5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """5.5""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """9.9999""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6.9""" },
    { "rate" : """3.88889""" },
    { "rate" : """14.99""" },
    { "rate" : """6.9999""" },
    { "rate" : """3.589""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6.99""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """3.9""" },
    { "rate" : """6""" },
    { "rate" : """6.93""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """6.9""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """3.99""" },
    { "rate" : """15""" },
    { "rate" : """3.83""" },
    { "rate" : """4""" },
    { "rate" : """7.55""" },
    { "rate" : """12""" },
    { "rate" : """2.9""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """0.33056""" },
    { "rate" : """0.33056""" },
    { "rate" : """0.34""" },
    { "rate" : """3.999""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """3.99""" },
    { "rate" : """14.8""" },
    { "rate" : """15""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """0.32999""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """3.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """14.99999""" },
    { "rate" : """3.9998""" },
    { "rate" : """3.75""" },
    { "rate" : """3.9""" },
    { "rate" : """14.99999""" },
    { "rate" : """3.99999""" },
    { "rate" : """2.99999""" },
    { "rate" : """3.98""" },
    { "rate" : """0.035""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """3.999""" },
    { "rate" : """8.69979""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """9.999""" },
    { "rate" : """9.34""" },
    { "rate" : """0.3399""" },
    { "rate" : """6.99""" },
    { "rate" : """0.3499""" },
    { "rate" : """9""" },
    { "rate" : """0.34028""" },
    { "rate" : """3""" },
    { "rate" : """0.34999""" },
    { "rate" : """14.99999""" },
    { "rate" : """14.99999""" },
    { "rate" : """0.88""" },
    { "rate" : """0.876""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """0.349""" },
    { "rate" : """3""" },
    { "rate" : """13.5""" },
    { "rate" : """12""" },
    { "rate" : """0.33""" },
    { "rate" : """0.84999""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """0.91989""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5.99999""" },
    { "rate" : """0.93""" },
    { "rate" : """6.99""" },
    { "rate" : """0.34""" },
    { "rate" : """0.33""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """14""" },
    { "rate" : """6""" },
    { "rate" : """0.94599""" },
    { "rate" : """0.89999""" },
    { "rate" : """12""" },
    { "rate" : """8.5""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """8.4999""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """0.9444""" },
    { "rate" : """6""" },
    { "rate" : """0.75""" },
    { "rate" : """8.5""" },
    { "rate" : """9.1""" },
    { "rate" : """8.49999""" },
    { "rate" : """8""" },
    { "rate" : """2.99""" },
    { "rate" : """8.49999""" },
    { "rate" : """8.49999""" },
    { "rate" : """15""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """0.8""" },
    { "rate" : """9.9999""" },
    { "rate" : """8.5""" },
    { "rate" : """8.4""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """8.495""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """8.49""" },
    { "rate" : """12""" },
    { "rate" : """3""" },
    { "rate" : """8.49722""" },
    { "rate" : """8.5""" },
    { "rate" : """18""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """8.5""" },
    { "rate" : """8.4998""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """0.3489""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """2.99999""" },
    { "rate" : """10""" },
    { "rate" : """7.85""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """2.98""" },
    { "rate" : """2.99""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """3""" },
    { "rate" : """2.9""" },
    { "rate" : """2.9999""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """2.5""" },
    { "rate" : """7""" },
    { "rate" : """0.89999""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """2.49999""" },
    { "rate" : """7.49999""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """13.98""" },
    { "rate" : """14.99""" },
    { "rate" : """9""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """0.9""" },
    { "rate" : """2.9""" },
    { "rate" : """0.96979""" },
    { "rate" : """4""" },
    { "rate" : """2.975""" },
    { "rate" : """9""" },
    { "rate" : """19.99""" },
    { "rate" : """13""" },
    { "rate" : """8.9""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """2.99""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """20""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """2.5""" },
    { "rate" : """14.5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """5.9999""" },
    { "rate" : """13""" },
    { "rate" : """4.5""" },
    { "rate" : """4.5""" },
    { "rate" : """4.49999""" },
    { "rate" : """4.5""" },
    { "rate" : """6""" },
    { "rate" : """4.4""" },
    { "rate" : """4.5""" },
    { "rate" : """4""" },
    { "rate" : """8.5""" },
    { "rate" : """2.99""" },
    { "rate" : """7""" },
    { "rate" : """4.5""" },
    { "rate" : """6""" },
    { "rate" : """4.5""" },
    { "rate" : """4.23""" },
    { "rate" : """8.5""" },
    { "rate" : """4.85""" },
    { "rate" : """17""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """6.5""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """14.999""" },
    { "rate" : """4.49999""" },
    { "rate" : """4.9999""" },
    { "rate" : """7""" },
    { "rate" : """4.5""" },
    { "rate" : """15""" },
    { "rate" : """4.5""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """2.98""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """18""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """7.75""" },
    { "rate" : """4.72""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """4.5""" },
    { "rate" : """2""" },
    { "rate" : """4.5""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """4.5""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """0.9""" },
    { "rate" : """7""" },
    { "rate" : """6.9""" },
    { "rate" : """3""" },
    { "rate" : """7.75""" },
    { "rate" : """0.5""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """5.9""" },
    { "rate" : """11.99777""" },
    { "rate" : """4""" },
    { "rate" : """4.99999""" },
    { "rate" : """19.2""" },
    { "rate" : """4.5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """6.99999""" },
    { "rate" : """4.5""" },
    { "rate" : """2""" },
    { "rate" : """4.49""" },
    { "rate" : """4.5""" },
    { "rate" : """14.98999""" },
    { "rate" : """2.98999""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """2.44""" },
    { "rate" : """2""" },
    { "rate" : """2.9""" },
    { "rate" : """4.5""" },
    { "rate" : """2.5""" },
    { "rate" : """0.58333""" },
    { "rate" : """4""" },
    { "rate" : """0.85""" },
    { "rate" : """4.5""" },
    { "rate" : """14.99""" },
    { "rate" : """2""" },
    { "rate" : """2.95""" },
    { "rate" : """2""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99998""" },
    { "rate" : """4.5""" },
    { "rate" : """4.49""" },
    { "rate" : """9.98""" },
    { "rate" : """9.89999""" },
    { "rate" : """2.999""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """4.5""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """2.89999""" },
    { "rate" : """5""" },
    { "rate" : """2.91667""" },
    { "rate" : """9""" },
    { "rate" : """1.75""" },
    { "rate" : """10""" },
    { "rate" : """2.9""" },
    { "rate" : """15""" },
    { "rate" : """9.999""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """9.9995""" },
    { "rate" : """4.5""" },
    { "rate" : """9.5""" },
    { "rate" : """1.79""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """1.5""" },
    { "rate" : """2.9""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """9.9""" },
    { "rate" : """3""" },
    { "rate" : """2.5""" },
    { "rate" : """9.99926""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """9.99979""" },
    { "rate" : """9""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2.99999""" },
    { "rate" : """3.5""" },
    { "rate" : """2.89""" },
    { "rate" : """3.55""" },
    { "rate" : """10""" },
    { "rate" : """8.9999""" },
    { "rate" : """3""" },
    { "rate" : """5.99999""" },
    { "rate" : """4.5""" },
    { "rate" : """9.99999""" },
    { "rate" : """11.9999""" },
    { "rate" : """3.5""" },
    { "rate" : """3""" },
    { "rate" : """18""" },
    { "rate" : """2.99999""" },
    { "rate" : """6""" },
    { "rate" : """2.99""" },
    { "rate" : """3""" },
    { "rate" : """0.01167""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """0.075""" },
    { "rate" : """0.6""" },
    { "rate" : """5.99999""" },
    { "rate" : """4.5""" },
    { "rate" : """3.31""" },
    { "rate" : """15""" },
    { "rate" : """4.49999""" },
    { "rate" : """1.74999""" },
    { "rate" : """3.3""" },
    { "rate" : """1.7555""" },
    { "rate" : """19.9995""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """3.88799""" },
    { "rate" : """14.98""" },
    { "rate" : """2""" },
    { "rate" : """1.975""" },
    { "rate" : """1.95""" },
    { "rate" : """4.5""" },
    { "rate" : """9.99999""" },
    { "rate" : """1.94444""" },
    { "rate" : """4.5""" },
    { "rate" : """18""" },
    { "rate" : """5""" },
    { "rate" : """1.98333""" },
    { "rate" : """15""" },
    { "rate" : """3.88889""" },
    { "rate" : """1.9""" },
    { "rate" : """4.49""" },
    { "rate" : """1.98""" },
    { "rate" : """3""" },
    { "rate" : """1.99""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """2.99999""" },
    { "rate" : """7.75""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """7.74978""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """4.8""" },
    { "rate" : """14.9""" },
    { "rate" : """2.95""" },
    { "rate" : """17.5""" },
    { "rate" : """9.99""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """17.99""" },
    { "rate" : """1.99""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """2.99""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """15""" },
    { "rate" : """14.5""" },
    { "rate" : """6""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """4.49985""" },
    { "rate" : """4.1""" },
    { "rate" : """4.5""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5.1""" },
    { "rate" : """9.99999""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """4.5""" },
    { "rate" : """6""" },
    { "rate" : """14.99""" },
    { "rate" : """8""" },
    { "rate" : """14.99999""" },
    { "rate" : """2.49""" },
    { "rate" : """9.99""" },
    { "rate" : """2.49""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """5.99999""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """14.95""" },
    { "rate" : """14.99999""" },
    { "rate" : """9""" },
    { "rate" : """4.5""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """14.9899""" },
    { "rate" : """6""" },
    { "rate" : """2.99""" },
    { "rate" : """6""" },
    { "rate" : """18""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """3.999""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """3.9""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """7.99""" },
    { "rate" : """4.5""" },
    { "rate" : """14.99""" },
    { "rate" : """1.99""" },
    { "rate" : """4.5""" },
    { "rate" : """9.99""" },
    { "rate" : """17.99""" },
    { "rate" : """2.1""" },
    { "rate" : """10""" },
    { "rate" : """4.99999""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """14.98""" },
    { "rate" : """1.6""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """2.9""" },
    { "rate" : """4""" },
    { "rate" : """4.5""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """7.75""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """4.69384""" },
    { "rate" : """1""" },
    { "rate" : """9.99""" },
    { "rate" : """3.99777""" },
    { "rate" : """14.97999""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """3.998""" },
    { "rate" : """4.5""" },
    { "rate" : """9.98""" },
    { "rate" : """4.49""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """4.99998""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """8.9998""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7.75""" },
    { "rate" : """11.99""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """13""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """8.99999""" },
    { "rate" : """14.99998""" },
    { "rate" : """12""" },
    { "rate" : """8.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """8""" },
    { "rate" : """9.97999""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """8.99999""" },
    { "rate" : """1.9799""" },
    { "rate" : """12""" },
    { "rate" : """2.44""" },
    { "rate" : """4.5""" },
    { "rate" : """11""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8.88888""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """1.99""" },
    { "rate" : """9""" },
    { "rate" : """7.89""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """11.8""" },
    { "rate" : """9.5""" },
    { "rate" : """2.42999""" },
    { "rate" : """17""" },
    { "rate" : """5.9""" },
    { "rate" : """7.5""" },
    { "rate" : """3""" },
    { "rate" : """8.5""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """8.9999""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """17""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """1.9""" },
    { "rate" : """7.75""" },
    { "rate" : """4""" },
    { "rate" : """2.5""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """14""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """13.99999""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """8.9999""" },
    { "rate" : """4.5""" },
    { "rate" : """12""" },
    { "rate" : """3""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.5""" },
    { "rate" : """3""" },
    { "rate" : """4.495""" },
    { "rate" : """4""" },
    { "rate" : """5.95""" },
    { "rate" : """4""" },
    { "rate" : """8.9""" },
    { "rate" : """9""" },
    { "rate" : """2.95""" },
    { "rate" : """4.5""" },
    { "rate" : """12""" },
    { "rate" : """8.88""" },
    { "rate" : """8""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """2.45""" },
    { "rate" : """1.9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """1.98989""" },
    { "rate" : """13.33333""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """8.99999""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """2.99999""" },
    { "rate" : """9.5""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """7.75""" },
    { "rate" : """10""" },
    { "rate" : """1.89999""" },
    { "rate" : """1.88888""" },
    { "rate" : """8""" },
    { "rate" : """1.99""" },
    { "rate" : """5.79999""" },
    { "rate" : """2.8""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """9.5""" },
    { "rate" : """1.95""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.9""" },
    { "rate" : """1.97999""" },
    { "rate" : """1.94999""" },
    { "rate" : """8.5""" },
    { "rate" : """1.94995""" },
    { "rate" : """5""" },
    { "rate" : """8.99999""" },
    { "rate" : """12.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """3""" },
    { "rate" : """9.59""" },
    { "rate" : """4""" },
    { "rate" : """1.9""" },
    { "rate" : """3""" },
    { "rate" : """7.99999""" },
    { "rate" : """4.49999""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """5.5""" },
    { "rate" : """14.99999""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """3.99999""" },
    { "rate" : """3.3""" },
    { "rate" : """2.99999""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """24""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """2.99999""" },
    { "rate" : """7.5""" },
    { "rate" : """5.5""" },
    { "rate" : """3.5""" },
    { "rate" : """2.25""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """4.999""" },
    { "rate" : """2.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """2""" },
    { "rate" : """14.99999""" },
    { "rate" : """10""" },
    { "rate" : """4.9995""" },
    { "rate" : """4.99999""" },
    { "rate" : """9.99998""" },
    { "rate" : """4.5""" },
    { "rate" : """9.8""" },
    { "rate" : """9.8""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """9.8""" },
    { "rate" : """9.8""" },
    { "rate" : """1""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """9.79999""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """2.43""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """14.9999""" },
    { "rate" : """20""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """9.99998""" },
    { "rate" : """6.85""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """4.5""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """18""" },
    { "rate" : """2""" },
    { "rate" : """3.5""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """4.5""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """11.9""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """30""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """2.99""" },
    { "rate" : """8.9""" },
    { "rate" : """10""" },
    { "rate" : """0.99167""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """9.89""" },
    { "rate" : """14.95""" },
    { "rate" : """0.99999""" },
    { "rate" : """8.89""" },
    { "rate" : """1""" },
    { "rate" : """2.5""" },
    { "rate" : """0.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """14.99999""" },
    { "rate" : """1""" },
    { "rate" : """9.89""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """14.9999""" },
    { "rate" : """9""" },
    { "rate" : """3.33""" },
    { "rate" : """3.49999""" },
    { "rate" : """9.9999""" },
    { "rate" : """14.95""" },
    { "rate" : """0.99""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """7.99998""" },
    { "rate" : """4.5""" },
    { "rate" : """15""" },
    { "rate" : """0.99""" },
    { "rate" : """4.5""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """0.99998""" },
    { "rate" : """10.99""" },
    { "rate" : """15""" },
    { "rate" : """0.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """8.99998""" },
    { "rate" : """0.99""" },
    { "rate" : """2.99""" },
    { "rate" : """9.9""" },
    { "rate" : """3""" },
    { "rate" : """4.5""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """1.98333""" },
    { "rate" : """4.5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """1.8""" },
    { "rate" : """9""" },
    { "rate" : """3.30556""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """4.5""" },
    { "rate" : """2.5""" },
    { "rate" : """7""" },
    { "rate" : """4.5""" },
    { "rate" : """34.99999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """0.9""" },
    { "rate" : """8.5""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """14""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """0.99999""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """11""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """14.9888""" },
    { "rate" : """3.2""" },
    { "rate" : """14.49""" },
    { "rate" : """3""" },
    { "rate" : """14.9""" },
    { "rate" : """10.53""" },
    { "rate" : """8.98""" },
    { "rate" : """8""" },
    { "rate" : """8.99""" },
    { "rate" : """1.98299""" },
    { "rate" : """8""" },
    { "rate" : """9.99999""" },
    { "rate" : """5.9""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """14.99""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """5.9""" },
    { "rate" : """11.9""" },
    { "rate" : """14.9""" },
    { "rate" : """4.999""" },
    { "rate" : """9""" },
    { "rate" : """8.16667""" },
    { "rate" : """1.99998""" },
    { "rate" : """7.99998""" },
    { "rate" : """2""" },
    { "rate" : """9.99998""" },
    { "rate" : """1.98""" },
    { "rate" : """0.9""" },
    { "rate" : """7.99999""" },
    { "rate" : """8""" },
    { "rate" : """7.99""" },
    { "rate" : """6.99998""" },
    { "rate" : """10""" },
    { "rate" : """35""" },
    { "rate" : """9.9""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """8.5""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """25""" },
    { "rate" : """12""" },
    { "rate" : """5.5""" },
    { "rate" : """9""" },
    { "rate" : """9.9999""" },
    { "rate" : """1.94444""" },
    { "rate" : """18""" },
    { "rate" : """10.95""" },
    { "rate" : """3""" },
    { "rate" : """25.5""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """18""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """0.899""" },
    { "rate" : """17.99999""" },
    { "rate" : """0.89""" },
    { "rate" : """0.78999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """8.5""" },
    { "rate" : """34.9""" },
    { "rate" : """7""" },
    { "rate" : """0.80833""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """2.66667""" },
    { "rate" : """1""" },
    { "rate" : """17.5""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """8.888""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """13""" },
    { "rate" : """5.88""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """9.999""" },
    { "rate" : """3""" },
    { "rate" : """11""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """5.5""" },
    { "rate" : """2.95""" },
    { "rate" : """2.5""" },
    { "rate" : """3""" },
    { "rate" : """2.99999""" },
    { "rate" : """9.98""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """2.95""" },
    { "rate" : """35""" },
    { "rate" : """4.8""" },
    { "rate" : """5""" },
    { "rate" : """4.75""" },
    { "rate" : """0.86""" },
    { "rate" : """0.87""" },
    { "rate" : """17.9""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """3.2""" },
    { "rate" : """10""" },
    { "rate" : """13.68""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """2.9""" },
    { "rate" : """12""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """2.995""" },
    { "rate" : """2.9999""" },
    { "rate" : """5.98999""" },
    { "rate" : """5.9999""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """7.93""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """18""" },
    { "rate" : """12""" },
    { "rate" : """11.5""" },
    { "rate" : """10""" },
    { "rate" : """9.97999""" },
    { "rate" : """7""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.8""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """9.98""" },
    { "rate" : """5""" },
    { "rate" : """8.5""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """11.99999""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """30""" },
    { "rate" : """9.999""" },
    { "rate" : """9.999""" },
    { "rate" : """9.5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """9.5""" },
    { "rate" : """3""" },
    { "rate" : """7.99""" },
    { "rate" : """11.99""" },
    { "rate" : """44.99""" },
    { "rate" : """9.9895""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """11.99""" },
    { "rate" : """9.97899""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """17""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """13.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7.98""" },
    { "rate" : """4.9998""" },
    { "rate" : """11.5""" },
    { "rate" : """9.8""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """11.999""" },
    { "rate" : """8.46""" },
    { "rate" : """7.8""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """5.9""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """11.9""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """17""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """9.5""" },
    { "rate" : """11.5""" },
    { "rate" : """3""" },
    { "rate" : """14""" },
    { "rate" : """12.5""" },
    { "rate" : """9""" },
    { "rate" : """12.5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """32""" },
    { "rate" : """9.95""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """11.9999""" },
    { "rate" : """8.99""" },
    { "rate" : """9.99""" },
    { "rate" : """14.99""" },
    { "rate" : """8""" },
    { "rate" : """11""" },
    { "rate" : """7.5""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """9.99999""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """6.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.5""" },
    { "rate" : """4.5""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """7.5""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """2.9""" },
    { "rate" : """9""" },
    { "rate" : """9.5""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """14""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """11.99999""" },
    { "rate" : """40""" },
    { "rate" : """7""" },
    { "rate" : """18""" },
    { "rate" : """30""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """14""" },
    { "rate" : """14.9""" },
    { "rate" : """7.5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """8.1""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """6.99""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """0.9999""" },
    { "rate" : """2.99999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """9.65""" },
    { "rate" : """4.5""" },
    { "rate" : """6.89""" },
    { "rate" : """4""" },
    { "rate" : """2.98""" },
    { "rate" : """5""" },
    { "rate" : """4.99979""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """4.5""" },
    { "rate" : """4.5""" },
    { "rate" : """4.95""" },
    { "rate" : """5.95""" },
    { "rate" : """11.95""" },
    { "rate" : """4.5""" },
    { "rate" : """4.8""" },
    { "rate" : """4.95""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """4.99""" },
    { "rate" : """1""" },
    { "rate" : """2.8""" },
    { "rate" : """4.9998""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """8.5""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """2.5""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7.98""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """18""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.999""" },
    { "rate" : """5.7""" },
    { "rate" : """9.999""" },
    { "rate" : """4.5""" },
    { "rate" : """4.9""" },
    { "rate" : """5.4""" },
    { "rate" : """3""" },
    { "rate" : """4.9""" },
    { "rate" : """18""" },
    { "rate" : """5.79""" },
    { "rate" : """5.54""" },
    { "rate" : """9.99999""" },
    { "rate" : """8.99999""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """5.24""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """5.74""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """5.7""" },
    { "rate" : """18""" },
    { "rate" : """5.5""" },
    { "rate" : """5.5""" },
    { "rate" : """5.74931""" },
    { "rate" : """5.7""" },
    { "rate" : """5""" },
    { "rate" : """5.5""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """5.749""" },
    { "rate" : """5.74167""" },
    { "rate" : """5.5""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5.7""" },
    { "rate" : """5.5""" },
    { "rate" : """4.89""" },
    { "rate" : """5.78""" },
    { "rate" : """24.99""" },
    { "rate" : """5.7""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5.7""" },
    { "rate" : """5.77""" },
    { "rate" : """7""" },
    { "rate" : """9.5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5.5""" },
    { "rate" : """7.89""" },
    { "rate" : """11.5""" },
    { "rate" : """8""" },
    { "rate" : """35""" },
    { "rate" : """3""" },
    { "rate" : """4.5""" },
    { "rate" : """9""" },
    { "rate" : """2.25""" },
    { "rate" : """15""" },
    { "rate" : """5.789""" },
    { "rate" : """4.5""" },
    { "rate" : """9.999""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """9.9899""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """18.99999""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """11.9899""" },
    { "rate" : """5.55555""" },
    { "rate" : """14.9899""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """5.7""" },
    { "rate" : """9.9995""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """9.5""" },
    { "rate" : """8""" },
    { "rate" : """14.99999""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """14.99""" },
    { "rate" : """14.89""" },
    { "rate" : """20""" },
    { "rate" : """1""" },
    { "rate" : """17.5""" },
    { "rate" : """18""" },
    { "rate" : """20""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """0.99979""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """18""" },
    { "rate" : """15""" },
    { "rate" : """2.5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """14.99999""" },
    { "rate" : """14.99999""" },
    { "rate" : """18""" },
    { "rate" : """19""" },
    { "rate" : """14""" },
    { "rate" : """7.99999""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """8.95""" },
    { "rate" : """8.5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """14""" },
    { "rate" : """9.95""" },
    { "rate" : """0.9975""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """2.5""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """0.99""" },
    { "rate" : """9.99""" },
    { "rate" : """19.99""" },
    { "rate" : """5.49""" },
    { "rate" : """6.99""" },
    { "rate" : """7.89""" },
    { "rate" : """0.95""" },
    { "rate" : """25""" },
    { "rate" : """6.6""" },
    { "rate" : """25""" },
    { "rate" : """24.99999""" },
    { "rate" : """5.5""" },
    { "rate" : """24.998""" },
    { "rate" : """25""" },
    { "rate" : """24.998""" },
    { "rate" : """4.5""" },
    { "rate" : """3.33333""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """12.5""" },
    { "rate" : """24.99999""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """5.75""" },
    { "rate" : """24.99""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """17""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """25""" },
    { "rate" : """2.5""" },
    { "rate" : """15""" },
    { "rate" : """2.3""" },
    { "rate" : """12""" },
    { "rate" : """4.5""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """2.49999""" },
    { "rate" : """14.9""" },
    { "rate" : """2.49999""" },
    { "rate" : """2.49999""" },
    { "rate" : """1.45""" },
    { "rate" : """9.99999""" },
    { "rate" : """17""" },
    { "rate" : """2.4998""" },
    { "rate" : """24.9""" },
    { "rate" : """4.4999""" },
    { "rate" : """7.5""" },
    { "rate" : """2.5""" },
    { "rate" : """2.49""" },
    { "rate" : """7""" },
    { "rate" : """9.899""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """20""" },
    { "rate" : """25""" },
    { "rate" : """5.25""" },
    { "rate" : """2.5""" },
    { "rate" : """2.49998""" },
    { "rate" : """9.999""" },
    { "rate" : """4.5""" },
    { "rate" : """4.49""" },
    { "rate" : """24.99""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """4.48""" },
    { "rate" : """10""" },
    { "rate" : """2.5""" },
    { "rate" : """19.99""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """4.5""" },
    { "rate" : """4.5""" },
    { "rate" : """2.49""" },
    { "rate" : """4.49979""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """2.49""" },
    { "rate" : """2.5""" },
    { "rate" : """25""" },
    { "rate" : """6""" },
    { "rate" : """6.99999""" },
    { "rate" : """11.4""" },
    { "rate" : """5.7""" },
    { "rate" : """2.5""" },
    { "rate" : """5.5""" },
    { "rate" : """9.9""" },
    { "rate" : """2.5""" },
    { "rate" : """15""" },
    { "rate" : """1.5""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """2.5""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """2.5""" },
    { "rate" : """24""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """14.9""" },
    { "rate" : """2.5""" },
    { "rate" : """7""" },
    { "rate" : """2.5""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """2.5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """6.99999""" },
    { "rate" : """24""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """6.9998""" },
    { "rate" : """24""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """5.5""" },
    { "rate" : """24""" },
    { "rate" : """2.48""" },
    { "rate" : """16""" },
    { "rate" : """18""" },
    { "rate" : """2.5""" },
    { "rate" : """7""" },
    { "rate" : """16""" },
    { "rate" : """15.83""" },
    { "rate" : """2.5""" },
    { "rate" : """5.7""" },
    { "rate" : """5.89""" },
    { "rate" : """15.5""" },
    { "rate" : """5.88""" },
    { "rate" : """4""" },
    { "rate" : """9.8""" },
    { "rate" : """15.99999""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """6.5""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """24""" },
    { "rate" : """3.5""" },
    { "rate" : """3.99999""" },
    { "rate" : """3""" },
    { "rate" : """3.99""" },
    { "rate" : """20""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """24""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """15.8""" },
    { "rate" : """15.9743""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """11.7""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """2.9""" },
    { "rate" : """2.5""" },
    { "rate" : """11.9999""" },
    { "rate" : """3""" },
    { "rate" : """2.99""" },
    { "rate" : """20""" },
    { "rate" : """15.99999""" },
    { "rate" : """20""" },
    { "rate" : """2.99""" },
    { "rate" : """24.99""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """2.99""" },
    { "rate" : """24.999""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """5.9999""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """2.8""" },
    { "rate" : """3.99""" },
    { "rate" : """10""" },
    { "rate" : """17""" },
    { "rate" : """24.99999""" },
    { "rate" : """5""" },
    { "rate" : """18""" },
    { "rate" : """12""" },
    { "rate" : """5.5""" },
    { "rate" : """25""" },
    { "rate" : """15.99""" },
    { "rate" : """11.98""" },
    { "rate" : """12""" },
    { "rate" : """22""" },
    { "rate" : """24.99""" },
    { "rate" : """11.99""" },
    { "rate" : """18""" },
    { "rate" : """15.99""" },
    { "rate" : """24.99979""" },
    { "rate" : """24.99998""" },
    { "rate" : """25""" },
    { "rate" : """5.8""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """7.99999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """24.99999""" },
    { "rate" : """24.99975""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """6""" },
    { "rate" : """5.95""" },
    { "rate" : """3""" },
    { "rate" : """24.95""" },
    { "rate" : """2.5""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """24""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """3.9""" },
    { "rate" : """24.5""" },
    { "rate" : """7.49""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """2.88""" },
    { "rate" : """2.1""" },
    { "rate" : """6""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """19.88999""" },
    { "rate" : """2.87""" },
    { "rate" : """15.99""" },
    { "rate" : """4.99""" },
    { "rate" : """2.98""" },
    { "rate" : """19.99""" },
    { "rate" : """9.99""" },
    { "rate" : """5""" },
    { "rate" : """8.99""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """6.99999""" },
    { "rate" : """5""" },
    { "rate" : """2.87999""" },
    { "rate" : """2.5""" },
    { "rate" : """7.5""" },
    { "rate" : """7""" },
    { "rate" : """2.94444""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """2.89""" },
    { "rate" : """7.5""" },
    { "rate" : """7.37""" },
    { "rate" : """7""" },
    { "rate" : """2.8""" },
    { "rate" : """2""" },
    { "rate" : """3.99""" },
    { "rate" : """11.9""" },
    { "rate" : """2.49989""" },
    { "rate" : """2.87""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """7.49999""" },
    { "rate" : """9""" },
    { "rate" : """11""" },
    { "rate" : """4""" },
    { "rate" : """2.8""" },
    { "rate" : """15""" },
    { "rate" : """14.5""" },
    { "rate" : """16.89""" },
    { "rate" : """6.99999""" },
    { "rate" : """3.9""" },
    { "rate" : """7.5""" },
    { "rate" : """7.5""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """2.5""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """2.5""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """14.9899""" },
    { "rate" : """6.99999""" },
    { "rate" : """6.5""" },
    { "rate" : """6""" },
    { "rate" : """2.5""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """2.5""" },
    { "rate" : """3.75""" },
    { "rate" : """7.5""" },
    { "rate" : """7.5""" },
    { "rate" : """4""" },
    { "rate" : """2.4975""" },
    { "rate" : """1""" },
    { "rate" : """24""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """0.98""" },
    { "rate" : """2.5""" },
    { "rate" : """1""" },
    { "rate" : """2.49""" },
    { "rate" : """1""" },
    { "rate" : """0.99""" },
    { "rate" : """1""" },
    { "rate" : """3.5""" },
    { "rate" : """2.49999""" },
    { "rate" : """2.5""" },
    { "rate" : """7.95""" },
    { "rate" : """14.5""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """6.5""" },
    { "rate" : """3.89""" },
    { "rate" : """1""" },
    { "rate" : """7.5""" },
    { "rate" : """1""" },
    { "rate" : """7.9""" },
    { "rate" : """3.5""" },
    { "rate" : """7.99""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """2.5""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2.9""" },
    { "rate" : """0.9999""" },
    { "rate" : """2.975""" },
    { "rate" : """7.91""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """2.99999""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """0.99999""" },
    { "rate" : """8""" },
    { "rate" : """2.9""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """2.99999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2.92""" },
    { "rate" : """14.99""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """24.9""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """0.99""" },
    { "rate" : """2.89""" },
    { "rate" : """0.99""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """7.74""" },
    { "rate" : """1""" },
    { "rate" : """2.5""" },
    { "rate" : """11.99999""" },
    { "rate" : """24""" },
    { "rate" : """19.9""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """14.9999""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """18""" },
    { "rate" : """4""" },
    { "rate" : """2.2""" },
    { "rate" : """2.3""" },
    { "rate" : """9""" },
    { "rate" : """6.5""" },
    { "rate" : """7.5""" },
    { "rate" : """5""" },
    { "rate" : """8.5""" },
    { "rate" : """1.5""" },
    { "rate" : """2.48""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """4.5""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """4.5""" },
    { "rate" : """2.5""" },
    { "rate" : """7.48""" },
    { "rate" : """1""" },
    { "rate" : """7.99""" },
    { "rate" : """1""" },
    { "rate" : """7.5""" },
    { "rate" : """15""" },
    { "rate" : """2.49999""" },
    { "rate" : """6""" },
    { "rate" : """23.9999""" },
    { "rate" : """8.9999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """3.58333""" },
    { "rate" : """4""" },
    { "rate" : """2.8""" },
    { "rate" : """7.5""" },
    { "rate" : """6""" },
    { "rate" : """2.08333""" },
    { "rate" : """2.5""" },
    { "rate" : """1""" },
    { "rate" : """4.16667""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """2.49""" },
    { "rate" : """2.5""" },
    { "rate" : """7.5""" },
    { "rate" : """7.5""" },
    { "rate" : """9""" },
    { "rate" : """0.99979""" },
    { "rate" : """2.5""" },
    { "rate" : """1.999""" },
    { "rate" : """0.98""" },
    { "rate" : """0.99999""" },
    { "rate" : """2.5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """11.999""" },
    { "rate" : """15""" },
    { "rate" : """6.66667""" },
    { "rate" : """0.99999""" },
    { "rate" : """4.5""" },
    { "rate" : """8""" },
    { "rate" : """9.8799""" },
    { "rate" : """24""" },
    { "rate" : """3.99999""" },
    { "rate" : """13""" },
    { "rate" : """6.59""" },
    { "rate" : """2.5""" },
    { "rate" : """5.99999""" },
    { "rate" : """19.95""" },
    { "rate" : """24.989""" },
    { "rate" : """18""" },
    { "rate" : """7.45""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """24""" },
    { "rate" : """5.65""" },
    { "rate" : """7.5""" },
    { "rate" : """0.99999""" },
    { "rate" : """2.89""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.9999""" },
    { "rate" : """6.9""" },
    { "rate" : """0.49""" },
    { "rate" : """0.99999""" },
    { "rate" : """2.499""" },
    { "rate" : """0.98""" },
    { "rate" : """0.499""" },
    { "rate" : """7.48""" },
    { "rate" : """22.25""" },
    { "rate" : """1""" },
    { "rate" : """3.75""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """5.9""" },
    { "rate" : """5.9""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """2.5""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """23.98""" },
    { "rate" : """0.99999""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """7.5""" },
    { "rate" : """0.99999""" },
    { "rate" : """8.5""" },
    { "rate" : """7.5""" },
    { "rate" : """5.99""" },
    { "rate" : """5.99""" },
    { "rate" : """0.9""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """0.97999""" },
    { "rate" : """7.5""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """2.4""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """1.8""" },
    { "rate" : """7.49""" },
    { "rate" : """2.49""" },
    { "rate" : """11.5""" },
    { "rate" : """2""" },
    { "rate" : """7.5""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """4.49""" },
    { "rate" : """7.45""" },
    { "rate" : """2.49""" },
    { "rate" : """6.9""" },
    { "rate" : """2.49999""" },
    { "rate" : """24.99999""" },
    { "rate" : """24.99999""" },
    { "rate" : """2.5""" },
    { "rate" : """2.99999""" },
    { "rate" : """2""" },
    { "rate" : """1.97""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """2.79999""" },
    { "rate" : """7.74979""" },
    { "rate" : """1.97""" },
    { "rate" : """1.98""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """2.79999""" },
    { "rate" : """2.79999""" },
    { "rate" : """2""" },
    { "rate" : """1.95""" },
    { "rate" : """3.5""" },
    { "rate" : """4.25""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """17.48""" },
    { "rate" : """2.25""" },
    { "rate" : """4.5""" },
    { "rate" : """7.73""" },
    { "rate" : """3.98""" },
    { "rate" : """0.99""" },
    { "rate" : """2.49""" },
    { "rate" : """1""" },
    { "rate" : """9.99""" },
    { "rate" : """18.99""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """1.9998""" },
    { "rate" : """1.99""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """2.8""" },
    { "rate" : """2.5""" },
    { "rate" : """3.9""" },
    { "rate" : """4.5""" },
    { "rate" : """2""" },
    { "rate" : """5.5""" },
    { "rate" : """1.9""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.9""" },
    { "rate" : """2.3""" },
    { "rate" : """1""" },
    { "rate" : """23.58""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """5.5""" },
    { "rate" : """2.8""" },
    { "rate" : """1""" },
    { "rate" : """1.99""" },
    { "rate" : """9""" },
    { "rate" : """5.5""" },
    { "rate" : """5""" },
    { "rate" : """22""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """1.99999""" },
    { "rate" : """2.99999""" },
    { "rate" : """7.19""" },
    { "rate" : """2""" },
    { "rate" : """20""" },
    { "rate" : """2.5""" },
    { "rate" : """2.8""" },
    { "rate" : """1.9""" },
    { "rate" : """15""" },
    { "rate" : """2.8""" },
    { "rate" : """1.95""" },
    { "rate" : """24""" },
    { "rate" : """2.99""" },
    { "rate" : """2.5""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """2.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """4.49""" },
    { "rate" : """2.5""" },
    { "rate" : """3.9999""" },
    { "rate" : """9.9393""" },
    { "rate" : """20""" },
    { "rate" : """2.5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9.5""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """1.9""" },
    { "rate" : """9.9""" },
    { "rate" : """4.99999""" },
    { "rate" : """2""" },
    { "rate" : """6.59""" },
    { "rate" : """6""" },
    { "rate" : """11""" },
    { "rate" : """9.99""" },
    { "rate" : """2.9999""" },
    { "rate" : """0.9999""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """1.5""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """9.99""" },
    { "rate" : """2.5""" },
    { "rate" : """17.48""" },
    { "rate" : """1.8""" },
    { "rate" : """2.95""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """6.59""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2.5""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """9.98""" },
    { "rate" : """2.5""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6.59""" },
    { "rate" : """9.8""" },
    { "rate" : """3""" },
    { "rate" : """2.8""" },
    { "rate" : """10""" },
    { "rate" : """6.58333""" },
    { "rate" : """4""" },
    { "rate" : """1.99979""" },
    { "rate" : """4.9""" },
    { "rate" : """1.95""" },
    { "rate" : """2.95""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """3.9""" },
    { "rate" : """11""" },
    { "rate" : """3.95""" },
    { "rate" : """4.2""" },
    { "rate" : """5.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5.5""" },
    { "rate" : """1""" },
    { "rate" : """3.7""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2.9""" },
    { "rate" : """4.5""" },
    { "rate" : """2.98""" },
    { "rate" : """5""" },
    { "rate" : """13.9""" },
    { "rate" : """9.979""" },
    { "rate" : """3""" },
    { "rate" : """4.99998""" },
    { "rate" : """9""" },
    { "rate" : """2.985""" },
    { "rate" : """1.99""" },
    { "rate" : """4.97""" },
    { "rate" : """9.945""" },
    { "rate" : """13.432""" },
    { "rate" : """1.99""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.999""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1.9989""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """1.99""" },
    { "rate" : """19.94""" },
    { "rate" : """2.99""" },
    { "rate" : """4.99""" },
    { "rate" : """3""" },
    { "rate" : """1.99999""" },
    { "rate" : """18""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """19""" },
    { "rate" : """5.25""" },
    { "rate" : """10""" },
    { "rate" : """1.99""" },
    { "rate" : """1.99""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """2.999""" },
    { "rate" : """2.49""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """2.49""" },
    { "rate" : """2.49""" },
    { "rate" : """1.97""" },
    { "rate" : """1.97""" },
    { "rate" : """7.9""" },
    { "rate" : """8.8""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """17""" },
    { "rate" : """6""" },
    { "rate" : """11""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """5.99999""" },
    { "rate" : """1.9""" },
    { "rate" : """6""" },
    { "rate" : """8.99777""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """8.99999""" },
    { "rate" : """15""" },
    { "rate" : """5.9999""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6.66417""" },
    { "rate" : """17""" },
    { "rate" : """7.9""" },
    { "rate" : """6""" },
    { "rate" : """2.5""" },
    { "rate" : """4.5""" },
    { "rate" : """1.8""" },
    { "rate" : """6""" },
    { "rate" : """8.8""" },
    { "rate" : """6""" },
    { "rate" : """1.0101""" },
    { "rate" : """7.99""" },
    { "rate" : """1.2""" },
    { "rate" : """2""" },
    { "rate" : """2.5""" },
    { "rate" : """1.8""" },
    { "rate" : """6""" },
    { "rate" : """1.8""" },
    { "rate" : """18""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """2.5""" },
    { "rate" : """0.9998""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2.48""" },
    { "rate" : """3""" },
    { "rate" : """2.8""" },
    { "rate" : """2""" },
    { "rate" : """2.5""" },
    { "rate" : """3""" },
    { "rate" : """2.8""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """2.8""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """3.999""" },
    { "rate" : """1""" },
    { "rate" : """3.5""" },
    { "rate" : """12""" },
    { "rate" : """3""" },
    { "rate" : """0.9""" },
    { "rate" : """4.8""" },
    { "rate" : """3.7""" },
    { "rate" : """11.99""" },
    { "rate" : """1.2""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """0.9""" },
    { "rate" : """2.4""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """3.6""" },
    { "rate" : """0.99""" },
    { "rate" : """0.99999""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2.49999""" },
    { "rate" : """2.5""" },
    { "rate" : """2.8""" },
    { "rate" : """6.99999""" },
    { "rate" : """3.95""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """2.4""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """0.99""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """4.5""" },
    { "rate" : """2.75""" },
    { "rate" : """5""" },
    { "rate" : """2.99""" },
    { "rate" : """5.99""" },
    { "rate" : """2""" },
    { "rate" : """6.6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """2.49999""" },
    { "rate" : """11.5""" },
    { "rate" : """2.8""" },
    { "rate" : """7.5""" },
    { "rate" : """2.7""" },
    { "rate" : """2.99""" },
    { "rate" : """20""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """11.99""" },
    { "rate" : """17.98""" },
    { "rate" : """1.89999""" },
    { "rate" : """3.99""" },
    { "rate" : """2""" },
    { "rate" : """11.95""" },
    { "rate" : """3""" },
    { "rate" : """2.95""" },
    { "rate" : """5""" },
    { "rate" : """11.5""" },
    { "rate" : """2.95""" },
    { "rate" : """11.99""" },
    { "rate" : """2.9""" },
    { "rate" : """4.99""" },
    { "rate" : """9.99""" },
    { "rate" : """1.9""" },
    { "rate" : """1.999""" },
    { "rate" : """3.9999""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """11""" },
    { "rate" : """17""" },
    { "rate" : """4.8""" },
    { "rate" : """6.4""" },
    { "rate" : """1.5""" },
    { "rate" : """5""" },
    { "rate" : """1.75""" },
    { "rate" : """2.49""" },
    { "rate" : """6""" },
    { "rate" : """2.5""" },
    { "rate" : """17.48""" },
    { "rate" : """6""" },
    { "rate" : """8.5""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """6.592""" },
    { "rate" : """1.5""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """3.5""" },
    { "rate" : """11.1111""" },
    { "rate" : """1""" },
    { "rate" : """2.99""" },
    { "rate" : """2""" },
    { "rate" : """6.5""" },
    { "rate" : """5.99999""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """4.999""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5.5""" },
    { "rate" : """3""" },
    { "rate" : """5.9""" },
    { "rate" : """2.99999""" },
    { "rate" : """4""" },
    { "rate" : """19""" },
    { "rate" : """1.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """6.59""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """5.75""" },
    { "rate" : """1""" },
    { "rate" : """1.98""" },
    { "rate" : """6""" },
    { "rate" : """2.98""" },
    { "rate" : """1.98""" },
    { "rate" : """6.58""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """4.34""" },
    { "rate" : """4.98""" },
    { "rate" : """3.5""" },
    { "rate" : """2.99""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """2.98""" },
    { "rate" : """4.89""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """9.98""" },
    { "rate" : """5""" },
    { "rate" : """8.98""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """3.8""" },
    { "rate" : """1.9""" },
    { "rate" : """3.9""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """2.8""" },
    { "rate" : """6""" },
    { "rate" : """14""" },
    { "rate" : """4.99999""" },
    { "rate" : """5.9""" },
    { "rate" : """4.9999""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """5.99999""" },
    { "rate" : """5.67""" },
    { "rate" : """6""" },
    { "rate" : """9.99999""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """5.9999""" },
    { "rate" : """5""" },
    { "rate" : """6.99999""" },
    { "rate" : """5""" },
    { "rate" : """7.99999""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """7""" },
    { "rate" : """4.99""" },
    { "rate" : """6""" },
    { "rate" : """14""" },
    { "rate" : """5.9""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """14""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """4.8""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6.99""" },
    { "rate" : """8""" },
    { "rate" : """7.9""" },
    { "rate" : """7.99999""" },
    { "rate" : """5""" },
    { "rate" : """7.5""" },
    { "rate" : """8""" },
    { "rate" : """1.99999""" },
    { "rate" : """7.9989""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """7.5""" },
    { "rate" : """7.99""" },
    { "rate" : """9""" },
    { "rate" : """2.999""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """6.5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7.959""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7.99979""" },
    { "rate" : """7""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.75""" },
    { "rate" : """6""" },
    { "rate" : """2.8""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """5.88889""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """14""" },
    { "rate" : """8.5""" },
    { "rate" : """7.5""" },
    { "rate" : """11.98""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """17""" },
    { "rate" : """6""" },
    { "rate" : """13""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """6.59""" },
    { "rate" : """8.99999""" },
    { "rate" : """5.99998""" },
    { "rate" : """4.99999""" },
    { "rate" : """5.5""" },
    { "rate" : """5.9""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """7""" },
    { "rate" : """17""" },
    { "rate" : """6""" },
    { "rate" : """14.428""" },
    { "rate" : """12""" },
    { "rate" : """14""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """4.5""" },
    { "rate" : """4.8""" },
    { "rate" : """2.79""" },
    { "rate" : """5.9""" },
    { "rate" : """5.9""" },
    { "rate" : """12""" },
    { "rate" : """3""" },
    { "rate" : """11.99""" },
    { "rate" : """2.9""" },
    { "rate" : """13""" },
    { "rate" : """7""" },
    { "rate" : """14""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """8.9""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """3.4""" },
    { "rate" : """4.98""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5.4""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """2.15""" },
    { "rate" : """6.9""" },
    { "rate" : """8""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """19.9""" },
    { "rate" : """5.9""" },
    { "rate" : """4.9""" },
    { "rate" : """4.75""" },
    { "rate" : """4.99""" },
    { "rate" : """9""" },
    { "rate" : """8.4""" },
    { "rate" : """2.8""" },
    { "rate" : """4.788""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """4.98""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """1.8""" },
    { "rate" : """4.5""" },
    { "rate" : """8.5""" },
    { "rate" : """10""" },
    { "rate" : """4.99999""" },
    { "rate" : """6.91667""" },
    { "rate" : """6.83333""" },
    { "rate" : """1.96389""" },
    { "rate" : """9.75""" },
    { "rate" : """4.75""" },
    { "rate" : """6""" },
    { "rate" : """19""" },
    { "rate" : """12.5""" },
    { "rate" : """18""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """7.2""" },
    { "rate" : """4.9""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """4.7""" },
    { "rate" : """0.99999""" },
    { "rate" : """11""" },
    { "rate" : """6.5""" },
    { "rate" : """0.9""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """4.75""" },
    { "rate" : """10""" },
    { "rate" : """0.99999""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4.975""" },
    { "rate" : """0.89999""" },
    { "rate" : """4.3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """4.99""" },
    { "rate" : """0.99999""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """5.5""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """0.9989""" },
    { "rate" : """14.59""" },
    { "rate" : """0.999""" },
    { "rate" : """5""" },
    { "rate" : """0.9""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """5.99999""" },
    { "rate" : """13""" },
    { "rate" : """0.989""" },
    { "rate" : """0.97999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12.9""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """2.8""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """6.5""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """1.99999""" },
    { "rate" : """7.99""" },
    { "rate" : """6.99""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """5.99""" },
    { "rate" : """9.99""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """2.99""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """8.33333""" },
    { "rate" : """2""" },
    { "rate" : """17""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """18""" },
    { "rate" : """5""" },
    { "rate" : """0.9""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """2.8""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """2.69979""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5.99999""" },
    { "rate" : """19.989""" },
    { "rate" : """5.99""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """5.99999""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """11.31""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """5.9""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5.9789""" },
    { "rate" : """5.99999""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """5.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """4.99""" },
    { "rate" : """9.99999""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """4.9999""" },
    { "rate" : """4.99""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """7.96""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5.5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """4.95""" },
    { "rate" : """7""" },
    { "rate" : """2.9""" },
    { "rate" : """5""" },
    { "rate" : """1.99""" },
    { "rate" : """5""" },
    { "rate" : """6.59""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """1.99995""" },
    { "rate" : """2.8""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """6.59""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """0.499""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """4.9""" },
    { "rate" : """4.9""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """3.23""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """3.24""" },
    { "rate" : """1""" },
    { "rate" : """3.25""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """3.25""" },
    { "rate" : """1""" },
    { "rate" : """2.5""" },
    { "rate" : """1""" },
    { "rate" : """11.99""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """6.7""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """16.17""" },
    { "rate" : """2""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.995""" },
    { "rate" : """1""" },
    { "rate" : """3.5""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """0.9""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """0.9""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """3.31""" },
    { "rate" : """3.30999""" },
    { "rate" : """2""" },
    { "rate" : """3.25""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """1.68""" },
    { "rate" : """1.68999""" },
    { "rate" : """6.5""" },
    { "rate" : """2.99999""" },
    { "rate" : """1.99999""" },
    { "rate" : """3.24999""" },
    { "rate" : """11.99999""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """9.9999""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """9.9975""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """7.4""" },
    { "rate" : """9.99999""" },
    { "rate" : """1.99""" },
    { "rate" : """7""" },
    { "rate" : """9.85""" },
    { "rate" : """9.995""" },
    { "rate" : """9.9""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """3.225""" },
    { "rate" : """1.99""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """9.94444""" },
    { "rate" : """10""" },
    { "rate" : """19""" },
    { "rate" : """19.89999""" },
    { "rate" : """7""" },
    { "rate" : """5.8""" },
    { "rate" : """18.99""" },
    { "rate" : """1.9753""" },
    { "rate" : """1.99999""" },
    { "rate" : """5.99""" },
    { "rate" : """1.44444""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """1""" },
    { "rate" : """13.72""" },
    { "rate" : """0.975""" },
    { "rate" : """2.8""" },
    { "rate" : """15""" },
    { "rate" : """1.9""" },
    { "rate" : """9.9""" },
    { "rate" : """15""" },
    { "rate" : """4.9""" },
    { "rate" : """1.94444""" },
    { "rate" : """0.99999""" },
    { "rate" : """9.94""" },
    { "rate" : """2""" },
    { "rate" : """9.95""" },
    { "rate" : """5""" },
    { "rate" : """17""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """1.99999""" },
    { "rate" : """3.25""" },
    { "rate" : """1.94444""" },
    { "rate" : """6""" },
    { "rate" : """1.99""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """7.5""" },
    { "rate" : """8.33333""" },
    { "rate" : """3.88889""" },
    { "rate" : """1.99""" },
    { "rate" : """8.33333""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """1.99999""" },
    { "rate" : """3.25""" },
    { "rate" : """4""" },
    { "rate" : """8.99444""" },
    { "rate" : """13""" },
    { "rate" : """2""" },
    { "rate" : """1.9""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """1.94444""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """7.99979""" },
    { "rate" : """1.5""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """8.88888""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """4.798""" },
    { "rate" : """7.463""" },
    { "rate" : """3.358""" },
    { "rate" : """4.99722""" },
    { "rate" : """10""" },
    { "rate" : """5.99999""" },
    { "rate" : """16.66667""" },
    { "rate" : """11.5""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """4.99""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """19""" },
    { "rate" : """4.99999""" },
    { "rate" : """10""" },
    { "rate" : """4.99989""" },
    { "rate" : """4.85""" },
    { "rate" : """3.25""" },
    { "rate" : """8.99""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """4.99955""" },
    { "rate" : """6.66665""" },
    { "rate" : """2.88""" },
    { "rate" : """8.75""" },
    { "rate" : """1""" },
    { "rate" : """8.9999""" },
    { "rate" : """9""" },
    { "rate" : """7.5""" },
    { "rate" : """2.95""" },
    { "rate" : """0.9""" },
    { "rate" : """13.72""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """3.25""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """1.5""" },
    { "rate" : """8.95""" },
    { "rate" : """8""" },
    { "rate" : """2.99999""" },
    { "rate" : """4""" },
    { "rate" : """7.44444""" },
    { "rate" : """6.75""" },
    { "rate" : """7""" },
    { "rate" : """3.25""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """1.5""" },
    { "rate" : """5""" },
    { "rate" : """6.9""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.5""" },
    { "rate" : """11.99998""" },
    { "rate" : """2.99998""" },
    { "rate" : """3.49999""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """6.59""" },
    { "rate" : """12""" },
    { "rate" : """3.49""" },
    { "rate" : """3.49999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """2.8""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """3.25""" },
    { "rate" : """6.95""" },
    { "rate" : """3.5""" },
    { "rate" : """3.99999""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """8.94""" },
    { "rate" : """3.99989""" },
    { "rate" : """3.48999""" },
    { "rate" : """3.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """8""" },
    { "rate" : """7.5""" },
    { "rate" : """13.72""" },
    { "rate" : """6.59""" },
    { "rate" : """3.99444""" },
    { "rate" : """7.6""" },
    { "rate" : """4""" },
    { "rate" : """7.87599""" },
    { "rate" : """3.5""" },
    { "rate" : """12.5""" },
    { "rate" : """20""" },
    { "rate" : """8.99999""" },
    { "rate" : """3.99""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """3.99""" },
    { "rate" : """3.49""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """0.31111""" },
    { "rate" : """6""" },
    { "rate" : """16""" },
    { "rate" : """4""" },
    { "rate" : """3.9999""" },
    { "rate" : """3.99""" },
    { "rate" : """5""" },
    { "rate" : """8.9975""" },
    { "rate" : """3.99""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """3.49""" },
    { "rate" : """3.25""" },
    { "rate" : """3.99""" },
    { "rate" : """3.493""" },
    { "rate" : """5""" },
    { "rate" : """7.99""" },
    { "rate" : """1.49""" },
    { "rate" : """3.49""" },
    { "rate" : """16.17""" },
    { "rate" : """4.98""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """3.42222""" },
    { "rate" : """1.5""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """3.5""" },
    { "rate" : """1.5""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """3.99999""" },
    { "rate" : """4""" },
    { "rate" : """7.95""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """5.99999""" },
    { "rate" : """3""" },
    { "rate" : """2.8""" },
    { "rate" : """2.8""" },
    { "rate" : """3.99999""" },
    { "rate" : """3.9888""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """3.7999""" },
    { "rate" : """3.999""" },
    { "rate" : """4""" },
    { "rate" : """1.5""" },
    { "rate" : """4.9""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """2.7""" },
    { "rate" : """8.9""" },
    { "rate" : """9""" },
    { "rate" : """3.99998""" },
    { "rate" : """3.99999""" },
    { "rate" : """1""" },
    { "rate" : """3.99""" },
    { "rate" : """3.9""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """3.99998""" },
    { "rate" : """3.5""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """3.99""" },
    { "rate" : """2.8""" },
    { "rate" : """8.5""" },
    { "rate" : """3""" },
    { "rate" : """1.4""" },
    { "rate" : """3.5""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """3.25""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """3.99""" },
    { "rate" : """9.989""" },
    { "rate" : """1.5""" },
    { "rate" : """3.9""" },
    { "rate" : """2.8""" },
    { "rate" : """5""" },
    { "rate" : """8.9999""" },
    { "rate" : """3""" },
    { "rate" : """3.45""" },
    { "rate" : """3.5""" },
    { "rate" : """9""" },
    { "rate" : """8.9999""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """3.89""" },
    { "rate" : """5""" },
    { "rate" : """5.99999""" },
    { "rate" : """5.999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """2.99931""" },
    { "rate" : """3""" },
    { "rate" : """4.993""" },
    { "rate" : """4.5""" },
    { "rate" : """3.2""" },
    { "rate" : """1.4""" },
    { "rate" : """3.7""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """2.5""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """7.99999""" },
    { "rate" : """12""" },
    { "rate" : """3.8""" },
    { "rate" : """0.99""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """3.99979""" },
    { "rate" : """2.98""" },
    { "rate" : """4""" },
    { "rate" : """8.9999""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """4.9999""" },
    { "rate" : """8""" },
    { "rate" : """8.9999""" },
    { "rate" : """8""" },
    { "rate" : """8.99""" },
    { "rate" : """1""" },
    { "rate" : """5.8""" },
    { "rate" : """3.9999""" },
    { "rate" : """8.99998""" },
    { "rate" : """8.99""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """3.777""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """6.9""" },
    { "rate" : """8""" },
    { "rate" : """3.99999""" },
    { "rate" : """4.9""" },
    { "rate" : """8""" },
    { "rate" : """7.9975""" },
    { "rate" : """8""" },
    { "rate" : """7.99998""" },
    { "rate" : """7.99""" },
    { "rate" : """4.89""" },
    { "rate" : """7.9999""" },
    { "rate" : """8""" },
    { "rate" : """7.75""" },
    { "rate" : """8""" },
    { "rate" : """3.25""" },
    { "rate" : """3.45""" },
    { "rate" : """3.99""" },
    { "rate" : """1""" },
    { "rate" : """4.5""" },
    { "rate" : """4.9""" },
    { "rate" : """4.8""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """4.5""" },
    { "rate" : """12.5""" },
    { "rate" : """8""" },
    { "rate" : """3.8""" },
    { "rate" : """12.5""" },
    { "rate" : """4.8999""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """12.5""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """12.5""" },
    { "rate" : """4""" },
    { "rate" : """0.995""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """12.5""" },
    { "rate" : """0.9975""" },
    { "rate" : """12.5""" },
    { "rate" : """12.5""" },
    { "rate" : """12.5""" },
    { "rate" : """7.99999""" },
    { "rate" : """12.999""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6.99""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6.99995""" },
    { "rate" : """6.99999""" },
    { "rate" : """7""" },
    { "rate" : """12.5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """6.99998""" },
    { "rate" : """7""" },
    { "rate" : """4.95""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """6.99975""" },
    { "rate" : """3.25""" },
    { "rate" : """7""" },
    { "rate" : """4.99998""" },
    { "rate" : """7""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """9.88""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """6.99999""" },
    { "rate" : """4.899""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """4.74""" },
    { "rate" : """6.99999""" },
    { "rate" : """6.9""" },
    { "rate" : """3.25""" },
    { "rate" : """10""" },
    { "rate" : """6.998""" },
    { "rate" : """4.9""" },
    { "rate" : """4.8""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """0.9975""" },
    { "rate" : """3.24""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """4.95""" },
    { "rate" : """1""" },
    { "rate" : """6.9""" },
    { "rate" : """7""" },
    { "rate" : """4.975""" },
    { "rate" : """3.4""" },
    { "rate" : """0.9""" },
    { "rate" : """6.99""" },
    { "rate" : """6.9""" },
    { "rate" : """19.9""" },
    { "rate" : """7""" },
    { "rate" : """0.99999""" },
    { "rate" : """3.491""" },
    { "rate" : """4.8""" },
    { "rate" : """6.99999""" },
    { "rate" : """2.8""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """3.25""" },
    { "rate" : """5""" },
    { "rate" : """0.9""" },
    { "rate" : """6.9""" },
    { "rate" : """4.8""" },
    { "rate" : """1.3""" },
    { "rate" : """4.5""" },
    { "rate" : """5.75""" },
    { "rate" : """5.5""" },
    { "rate" : """9""" },
    { "rate" : """0.999""" },
    { "rate" : """9.99999""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """0.99""" },
    { "rate" : """4.99999""" },
    { "rate" : """6.9999""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """3.25""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """6.99""" },
    { "rate" : """4.99999""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """6.55""" },
    { "rate" : """4.89""" },
    { "rate" : """6.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """13""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """12.99999""" },
    { "rate" : """3.49""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.975""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4.9997""" },
    { "rate" : """4.89""" },
    { "rate" : """3.5""" },
    { "rate" : """5.89999""" },
    { "rate" : """5.5""" },
    { "rate" : """11.9989""" },
    { "rate" : """12""" },
    { "rate" : """4.99""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """9""" },
    { "rate" : """6.49""" },
    { "rate" : """5.999""" },
    { "rate" : """6.5""" },
    { "rate" : """5.5""" },
    { "rate" : """9.9""" },
    { "rate" : """6.5""" },
    { "rate" : """6.5""" },
    { "rate" : """2.5""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """4.5""" },
    { "rate" : """6""" },
    { "rate" : """6.5""" },
    { "rate" : """9.9""" },
    { "rate" : """4.89999""" },
    { "rate" : """6.99999""" },
    { "rate" : """4.49999""" },
    { "rate" : """4.99987""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """4.98""" },
    { "rate" : """5.99998""" },
    { "rate" : """9""" },
    { "rate" : """8.75""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """4.49""" },
    { "rate" : """6.5""" },
    { "rate" : """6.5""" },
    { "rate" : """4.5""" },
    { "rate" : """8.99""" },
    { "rate" : """6.468""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7.5""" },
    { "rate" : """8.99999""" },
    { "rate" : """6.49999""" },
    { "rate" : """10""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6.49""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """1.2""" },
    { "rate" : """8""" },
    { "rate" : """4.99""" },
    { "rate" : """4.89""" },
    { "rate" : """12.95""" },
    { "rate" : """19.89""" },
    { "rate" : """5.99""" },
    { "rate" : """6.99""" },
    { "rate" : """5.79""" },
    { "rate" : """4.99""" },
    { "rate" : """9.99""" },
    { "rate" : """13""" },
    { "rate" : """5.99""" },
    { "rate" : """6.99""" },
    { "rate" : """7.99""" },
    { "rate" : """6""" },
    { "rate" : """8.33333""" },
    { "rate" : """4.99""" },
    { "rate" : """6""" },
    { "rate" : """7.99999""" },
    { "rate" : """4.2""" },
    { "rate" : """12""" },
    { "rate" : """3.5""" },
    { "rate" : """6.5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """9.99998""" },
    { "rate" : """6.49""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """5.9""" },
    { "rate" : """6.5""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """3.499""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """6.5""" },
    { "rate" : """12.99""" },
    { "rate" : """4.5""" },
    { "rate" : """6.49""" },
    { "rate" : """5.965""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """8.5""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """4.5""" },
    { "rate" : """3.99""" },
    { "rate" : """4.5""" },
    { "rate" : """4.5""" },
    { "rate" : """2.5""" },
    { "rate" : """8.99999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """5.999""" },
    { "rate" : """2.99""" },
    { "rate" : """11""" },
    { "rate" : """5.97""" },
    { "rate" : """7.1""" },
    { "rate" : """7.99979""" },
    { "rate" : """5.98""" },
    { "rate" : """3.49998""" },
    { "rate" : """9""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """5.99999""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """6.495""" },
    { "rate" : """5.99989""" },
    { "rate" : """7.99999""" },
    { "rate" : """7.98""" },
    { "rate" : """5.95""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5.94999""" },
    { "rate" : """5.99""" },
    { "rate" : """12""" },
    { "rate" : """5.95""" },
    { "rate" : """10.4995""" },
    { "rate" : """5.99979""" },
    { "rate" : """5.5""" },
    { "rate" : """7.95""" },
    { "rate" : """7.99999""" },
    { "rate" : """9""" },
    { "rate" : """7.5""" },
    { "rate" : """10""" },
    { "rate" : """6.5""" },
    { "rate" : """5.95""" },
    { "rate" : """5""" },
    { "rate" : """3.4""" },
    { "rate" : """6.5""" },
    { "rate" : """6""" },
    { "rate" : """7.94444""" },
    { "rate" : """5.5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """3.5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10.9""" },
    { "rate" : """9""" },
    { "rate" : """21.9""" },
    { "rate" : """2.8""" },
    { "rate" : """3.5""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """21.9""" },
    { "rate" : """8.9""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """8.5""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """6.5""" },
    { "rate" : """4""" },
    { "rate" : """8.99999""" },
    { "rate" : """7""" },
    { "rate" : """3.5""" },
    { "rate" : """2.999""" },
    { "rate" : """9""" },
    { "rate" : """6.49""" },
    { "rate" : """2.99""" },
    { "rate" : """5.89""" },
    { "rate" : """4.99999""" },
    { "rate" : """2""" },
    { "rate" : """4.999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """8.99999""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """3.55""" },
    { "rate" : """4.975""" },
    { "rate" : """10""" },
    { "rate" : """2.8""" },
    { "rate" : """4.975""" },
    { "rate" : """13""" },
    { "rate" : """5.83333""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """6.5""" },
    { "rate" : """5.98""" },
    { "rate" : """4.99""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """8.9""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """6""" },
    { "rate" : """5.8""" },
    { "rate" : """6""" },
    { "rate" : """5.99999""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5.99999""" },
    { "rate" : """6""" },
    { "rate" : """5.9393""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """4.99""" },
    { "rate" : """6""" },
    { "rate" : """5.9975""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9.889""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """8.25""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """17.99""" },
    { "rate" : """5""" },
    { "rate" : """11.9899""" },
    { "rate" : """9.979""" },
    { "rate" : """4.99""" },
    { "rate" : """5.99""" },
    { "rate" : """3.5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """9.5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5.89999""" },
    { "rate" : """5.97999""" },
    { "rate" : """5.99998""" },
    { "rate" : """5.999""" },
    { "rate" : """5""" },
    { "rate" : """5.9""" },
    { "rate" : """9.989""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """9.98""" },
    { "rate" : """5""" },
    { "rate" : """5.9999""" },
    { "rate" : """5.9""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """3.5""" },
    { "rate" : """4.9999""" },
    { "rate" : """4.999""" },
    { "rate" : """5.9999""" },
    { "rate" : """6""" },
    { "rate" : """2.5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """3.64""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5.7896""" },
    { "rate" : """14.75""" },
    { "rate" : """4.75""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """5.9999""" },
    { "rate" : """3""" },
    { "rate" : """9.5""" },
    { "rate" : """3""" },
    { "rate" : """2.9975""" },
    { "rate" : """6""" },
    { "rate" : """0.1""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5.999""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """5.9998""" },
    { "rate" : """5.99999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5.9""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """7.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """9.9""" },
    { "rate" : """4.99998""" },
    { "rate" : """10""" },
    { "rate" : """9.95""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5.99999""" },
    { "rate" : """9""" },
    { "rate" : """5.99""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """2.975""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """11.999""" },
    { "rate" : """3.5""" },
    { "rate" : """3.4999""" },
    { "rate" : """4.999""" },
    { "rate" : """10""" },
    { "rate" : """4.999""" },
    { "rate" : """11""" },
    { "rate" : """3""" },
    { "rate" : """2.985""" },
    { "rate" : """3""" },
    { "rate" : """3.495""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """2.8""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """4.95""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """15.14""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """2.8""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """2.7""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """10.9""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """4.9999""" },
    { "rate" : """3""" },
    { "rate" : """2.2""" },
    { "rate" : """11.9999""" },
    { "rate" : """6.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """10.5""" },
    { "rate" : """3.65""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """8.5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """25""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """20""" },
    { "rate" : """9.998""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """9.5""" },
    { "rate" : """13.72""" },
    { "rate" : """4.59""" },
    { "rate" : """9""" },
    { "rate" : """24.9""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """4.95""" },
    { "rate" : """9.95""" },
    { "rate" : """9""" },
    { "rate" : """14.875""" },
    { "rate" : """14.95""" },
    { "rate" : """4.99""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """13.72""" },
    { "rate" : """9""" },
    { "rate" : """19""" },
    { "rate" : """7""" },
    { "rate" : """1.7""" },
    { "rate" : """4.6""" },
    { "rate" : """9.9""" },
    { "rate" : """4.89999""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """9.9998""" },
    { "rate" : """2.8""" },
    { "rate" : """5""" },
    { "rate" : """21.5""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9.98999""" },
    { "rate" : """24.89""" },
    { "rate" : """14.89""" },
    { "rate" : """4.99""" },
    { "rate" : """20.99""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """4.999""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """2.8""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """0.9""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """9.5""" },
    { "rate" : """12""" },
    { "rate" : """9.98""" },
    { "rate" : """10""" },
    { "rate" : """23.9""" },
    { "rate" : """1.1999""" },
    { "rate" : """15""" },
    { "rate" : """9.95""" },
    { "rate" : """23.58""" },
    { "rate" : """8""" },
    { "rate" : """19""" },
    { "rate" : """9.5""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """17""" },
    { "rate" : """9.96""" },
    { "rate" : """16.18""" },
    { "rate" : """8""" },
    { "rate" : """15.14""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """9""" },
    { "rate" : """17""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """23.58""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """13.72""" },
    { "rate" : """9""" },
    { "rate" : """13.72""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """13.72""" },
    { "rate" : """9.5""" },
    { "rate" : """17.48""" },
    { "rate" : """9.98""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """18""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """8.65""" },
    { "rate" : """20.45""" },
    { "rate" : """17.48""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """15.14""" },
    { "rate" : """17.48""" },
    { "rate" : """9""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """9""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15""" },
    { "rate" : """13.72""" },
    { "rate" : """23.58""" },
    { "rate" : """9""" },
    { "rate" : """10.73""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """12.26""" },
    { "rate" : """9.999""" },
    { "rate" : """18""" },
    { "rate" : """13.72""" },
    { "rate" : """17""" },
    { "rate" : """17.48""" },
    { "rate" : """5""" },
    { "rate" : """10.745""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.8""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """11""" },
    { "rate" : """3.64""" },
    { "rate" : """9.99997""" },
    { "rate" : """15.14""" },
    { "rate" : """13.72""" },
    { "rate" : """4.987""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """8.64""" },
    { "rate" : """17.48""" },
    { "rate" : """15""" },
    { "rate" : """3.64""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """3.64""" },
    { "rate" : """4""" },
    { "rate" : """13.72""" },
    { "rate" : """14.99999""" },
    { "rate" : """14.925""" },
    { "rate" : """14""" },
    { "rate" : """3.24""" },
    { "rate" : """11""" },
    { "rate" : """4.95""" },
    { "rate" : """17.5""" },
    { "rate" : """15.14""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """10.73""" },
    { "rate" : """6""" },
    { "rate" : """4.9393""" },
    { "rate" : """8.8""" },
    { "rate" : """8.64""" },
    { "rate" : """4.5""" },
    { "rate" : """13.72""" },
    { "rate" : """12.46""" },
    { "rate" : """10.8""" },
    { "rate" : """9.5""" },
    { "rate" : """14.99999""" },
    { "rate" : """12.99999""" },
    { "rate" : """17.48""" },
    { "rate" : """4.95""" },
    { "rate" : """10""" },
    { "rate" : """12.26""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """9.99""" },
    { "rate" : """4.9999""" },
    { "rate" : """4.9""" },
    { "rate" : """9.89""" },
    { "rate" : """4.99999""" },
    { "rate" : """12.98""" },
    { "rate" : """4.95""" },
    { "rate" : """4.89""" },
    { "rate" : """10.89""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4.999""" },
    { "rate" : """15.14""" },
    { "rate" : """17.48""" },
    { "rate" : """10""" },
    { "rate" : """15.14""" },
    { "rate" : """17.49""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """15""" },
    { "rate" : """17.48""" },
    { "rate" : """8.8""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """15""" },
    { "rate" : """4.9999""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """17.48""" },
    { "rate" : """10""" },
    { "rate" : """3.64""" },
    { "rate" : """14""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """4.91""" },
    { "rate" : """14.9""" },
    { "rate" : """8.8""" },
    { "rate" : """18""" },
    { "rate" : """4.9""" },
    { "rate" : """4.89""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """3.65""" },
    { "rate" : """3.24""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """14.9""" },
    { "rate" : """10.73""" },
    { "rate" : """4.95""" },
    { "rate" : """17.48""" },
    { "rate" : """10.79999""" },
    { "rate" : """10""" },
    { "rate" : """10.73""" },
    { "rate" : """17.48""" },
    { "rate" : """4.98""" },
    { "rate" : """14.87""" },
    { "rate" : """10.73""" },
    { "rate" : """3.24""" },
    { "rate" : """7.9""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """14""" },
    { "rate" : """4.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """4.8""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """9.99989""" },
    { "rate" : """5""" },
    { "rate" : """15.14""" },
    { "rate" : """3.24""" },
    { "rate" : """8.8""" },
    { "rate" : """15.14""" },
    { "rate" : """12.27""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """4.99""" },
    { "rate" : """12.26""" },
    { "rate" : """16.17""" },
    { "rate" : """5.79""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """5.79""" },
    { "rate" : """5.79""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """4""" },
    { "rate" : """20.45""" },
    { "rate" : """4.9999""" },
    { "rate" : """5.79""" },
    { "rate" : """3.64""" },
    { "rate" : """12.26""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """8.64""" },
    { "rate" : """12.26""" },
    { "rate" : """5.79""" },
    { "rate" : """5""" },
    { "rate" : """15.14""" },
    { "rate" : """8.64""" },
    { "rate" : """14""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """9.96""" },
    { "rate" : """3.5""" },
    { "rate" : """3.64""" },
    { "rate" : """8.7""" },
    { "rate" : """8.8""" },
    { "rate" : """8.64""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """5.79""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """8.64""" },
    { "rate" : """9""" },
    { "rate" : """4.99""" },
    { "rate" : """16.17""" },
    { "rate" : """4.95""" },
    { "rate" : """4.5""" },
    { "rate" : """14""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """8.64""" },
    { "rate" : """15.14""" },
    { "rate" : """8.64""" },
    { "rate" : """8.8""" },
    { "rate" : """8.64""" },
    { "rate" : """10""" },
    { "rate" : """8.64""" },
    { "rate" : """9""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """9""" },
    { "rate" : """24""" },
    { "rate" : """3.5""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """3.24""" },
    { "rate" : """12.9""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """115""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """9.99""" },
    { "rate" : """3.24""" },
    { "rate" : """13""" },
    { "rate" : """9.96""" },
    { "rate" : """12""" },
    { "rate" : """15.14""" },
    { "rate" : """20.45""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """20.45""" },
    { "rate" : """15.14""" },
    { "rate" : """13.72""" },
    { "rate" : """8.89""" },
    { "rate" : """13.75""" },
    { "rate" : """0.49999""" },
    { "rate" : """9.98999""" },
    { "rate" : """14.99""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """15.14""" },
    { "rate" : """4.5""" },
    { "rate" : """9""" },
    { "rate" : """23.58""" },
    { "rate" : """15.14""" },
    { "rate" : """4.99999""" },
    { "rate" : """15.14""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """15.14""" },
    { "rate" : """0.1""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """9.98""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """15.14""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """9.99""" },
    { "rate" : """14.98""" },
    { "rate" : """8.8""" },
    { "rate" : """20.45""" },
    { "rate" : """20.45""" },
    { "rate" : """20.45""" },
    { "rate" : """9.96""" },
    { "rate" : """20.45""" },
    { "rate" : """13.72""" },
    { "rate" : """20.45""" },
    { "rate" : """20.45""" },
    { "rate" : """9.96""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """20.45""" },
    { "rate" : """9.99""" },
    { "rate" : """20.45""" },
    { "rate" : """20.45""" },
    { "rate" : """9.96""" },
    { "rate" : """15.14""" },
    { "rate" : """20.45""" },
    { "rate" : """1""" },
    { "rate" : """9.96""" },
    { "rate" : """20.45""" },
    { "rate" : """20.45""" },
    { "rate" : """8.8""" },
    { "rate" : """15.14""" },
    { "rate" : """20.45""" },
    { "rate" : """20.45""" },
    { "rate" : """8.8""" },
    { "rate" : """23.58""" },
    { "rate" : """13.72""" },
    { "rate" : """15.14""" },
    { "rate" : """8.8""" },
    { "rate" : """23.58""" },
    { "rate" : """20.45""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """20.45""" },
    { "rate" : """20.45""" },
    { "rate" : """23.58""" },
    { "rate" : """15.14""" },
    { "rate" : """23.58""" },
    { "rate" : """8.8""" },
    { "rate" : """23.58""" },
    { "rate" : """3.64""" },
    { "rate" : """15.14""" },
    { "rate" : """9.96""" },
    { "rate" : """23.58""" },
    { "rate" : """15.14""" },
    { "rate" : """20.45""" },
    { "rate" : """23.58""" },
    { "rate" : """3.64""" },
    { "rate" : """14""" },
    { "rate" : """20.45""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """3.24""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """8.8""" },
    { "rate" : """0.5""" },
    { "rate" : """20.45""" },
    { "rate" : """20.45""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """15.14""" },
    { "rate" : """10""" },
    { "rate" : """15.14""" },
    { "rate" : """8.8""" },
    { "rate" : """15.14""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """15.14""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """12.26""" },
    { "rate" : """16.17""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """23.58""" },
    { "rate" : """16.17""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """9.96""" },
    { "rate" : """0.5""" },
    { "rate" : """16.17""" },
    { "rate" : """10""" },
    { "rate" : """0.475""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """23.58""" },
    { "rate" : """15.14""" },
    { "rate" : """12.26""" },
    { "rate" : """16.17""" },
    { "rate" : """23.58""" },
    { "rate" : """16.17""" },
    { "rate" : """0.499""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """8.8""" },
    { "rate" : """16.17""" },
    { "rate" : """15.14""" },
    { "rate" : """16.17""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """23.58""" },
    { "rate" : """12.26""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """23.58""" },
    { "rate" : """13.11""" },
    { "rate" : """15.14""" },
    { "rate" : """12.46""" },
    { "rate" : """23.58""" },
    { "rate" : """12.46""" },
    { "rate" : """15.14""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """16.17""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """12.5""" },
    { "rate" : """23.58""" },
    { "rate" : """3.64""" },
    { "rate" : """10.73""" },
    { "rate" : """23.58""" },
    { "rate" : """9.99999""" },
    { "rate" : """10.73""" },
    { "rate" : """15.14""" },
    { "rate" : """23.58""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """23.58""" },
    { "rate" : """3.64""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """23.58""" },
    { "rate" : """9.96""" },
    { "rate" : """12.26""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """10.73""" },
    { "rate" : """9.96""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """13""" },
    { "rate" : """23.58""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """24""" },
    { "rate" : """5""" },
    { "rate" : """23.58""" },
    { "rate" : """8""" },
    { "rate" : """23.58""" },
    { "rate" : """9.96""" },
    { "rate" : """12.26""" },
    { "rate" : """5""" },
    { "rate" : """18""" },
    { "rate" : """23.58""" },
    { "rate" : """9.96""" },
    { "rate" : """21""" },
    { "rate" : """24""" },
    { "rate" : """24""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """12.26""" },
    { "rate" : """9.99""" },
    { "rate" : """12.26""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """5.79""" },
    { "rate" : """5.79""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """23.58""" },
    { "rate" : """5.79""" },
    { "rate" : """3.64""" },
    { "rate" : """5.79""" },
    { "rate" : """23.58""" },
    { "rate" : """24""" },
    { "rate" : """5.79""" },
    { "rate" : """5.79""" },
    { "rate" : """12.26""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """12.5""" },
    { "rate" : """2.69999""" },
    { "rate" : """9.96""" },
    { "rate" : """2.7""" },
    { "rate" : """2.7""" },
    { "rate" : """9.99998""" },
    { "rate" : """17.48""" },
    { "rate" : """12.2""" },
    { "rate" : """18""" },
    { "rate" : """23.58""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """17.48""" },
    { "rate" : """17.5""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """23.58""" },
    { "rate" : """5.79""" },
    { "rate" : """12.46""" },
    { "rate" : """16.17""" },
    { "rate" : """9.96""" },
    { "rate" : """23.58""" },
    { "rate" : """2""" },
    { "rate" : """17.48""" },
    { "rate" : """23.58""" },
    { "rate" : """16.17""" },
    { "rate" : """12.26""" },
    { "rate" : """9.98656""" },
    { "rate" : """9.96""" },
    { "rate" : """4.99895""" },
    { "rate" : """9.96""" },
    { "rate" : """20.45""" },
    { "rate" : """5""" },
    { "rate" : """23.58""" },
    { "rate" : """16.17""" },
    { "rate" : """23.58""" },
    { "rate" : """16.17""" },
    { "rate" : """23.58""" },
    { "rate" : """3.75""" },
    { "rate" : """9.96""" },
    { "rate" : """23.58""" },
    { "rate" : """12.26""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """20.45""" },
    { "rate" : """5.79""" },
    { "rate" : """5.79""" },
    { "rate" : """3.64""" },
    { "rate" : """23.58""" },
    { "rate" : """20.45""" },
    { "rate" : """23.58""" },
    { "rate" : """3.64""" },
    { "rate" : """20.45""" },
    { "rate" : """5.79""" },
    { "rate" : """9.96""" },
    { "rate" : """17.48""" },
    { "rate" : """9.96""" },
    { "rate" : """13""" },
    { "rate" : """9.99""" },
    { "rate" : """16.17""" },
    { "rate" : """17.48""" },
    { "rate" : """15.14""" },
    { "rate" : """9.96""" },
    { "rate" : """15.14""" },
    { "rate" : """5.79""" },
    { "rate" : """12.26""" },
    { "rate" : """16.17""" },
    { "rate" : """23.58""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """23.58""" },
    { "rate" : """12.26""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """23.58""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.64""" },
    { "rate" : """16.17""" },
    { "rate" : """5.79""" },
    { "rate" : """5.79""" },
    { "rate" : """9.99""" },
    { "rate" : """19.999""" },
    { "rate" : """12.318""" },
    { "rate" : """20.45""" },
    { "rate" : """12.26""" },
    { "rate" : """9.99""" },
    { "rate" : """24""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """16.17""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """9.99""" },
    { "rate" : """23.59""" },
    { "rate" : """20.45""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """13""" },
    { "rate" : """12.28""" },
    { "rate" : """20.45""" },
    { "rate" : """3.64""" },
    { "rate" : """12.26""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """3.64""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """12.26""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """12.26""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """20.45""" },
    { "rate" : """3.64""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """9.95""" },
    { "rate" : """3.64""" },
    { "rate" : """24.99""" },
    { "rate" : """20.45""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """8.99999""" },
    { "rate" : """12.26""" },
    { "rate" : """0.99979""" },
    { "rate" : """13.11""" },
    { "rate" : """23.58""" },
    { "rate" : """14.99""" },
    { "rate" : """0.0899""" },
    { "rate" : """23.58""" },
    { "rate" : """12.26""" },
    { "rate" : """14.998""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """0.98999""" },
    { "rate" : """13.11""" },
    { "rate" : """3.64""" },
    { "rate" : """13.11""" },
    { "rate" : """0.99""" },
    { "rate" : """4.99""" },
    { "rate" : """13.11""" },
    { "rate" : """13""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """16.17""" },
    { "rate" : """23.58""" },
    { "rate" : """12.26""" },
    { "rate" : """16.17""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """5""" },
    { "rate" : """12.66""" },
    { "rate" : """3.64""" },
    { "rate" : """16.17""" },
    { "rate" : """20.45""" },
    { "rate" : """1.5""" },
    { "rate" : """3.67""" },
    { "rate" : """1.499""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.49""" },
    { "rate" : """1.49999""" },
    { "rate" : """1.5""" },
    { "rate" : """0.98""" },
    { "rate" : """0.99""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """12.5""" },
    { "rate" : """20.45""" },
    { "rate" : """9""" },
    { "rate" : """16.17""" },
    { "rate" : """15""" },
    { "rate" : """13.11""" },
    { "rate" : """0.95""" },
    { "rate" : """23.58""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """11.99""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """23.99""" },
    { "rate" : """20.45""" },
    { "rate" : """23""" },
    { "rate" : """9.999""" },
    { "rate" : """11""" },
    { "rate" : """13""" },
    { "rate" : """0.999""" },
    { "rate" : """9.96""" },
    { "rate" : """24""" },
    { "rate" : """4""" },
    { "rate" : """29.99999""" },
    { "rate" : """24""" },
    { "rate" : """0.8""" },
    { "rate" : """24""" },
    { "rate" : """23""" },
    { "rate" : """0.99""" },
    { "rate" : """29.99999""" },
    { "rate" : """24""" },
    { "rate" : """10""" },
    { "rate" : """11.99999""" },
    { "rate" : """23.99999""" },
    { "rate" : """20.45""" },
    { "rate" : """20.45""" },
    { "rate" : """16.17""" },
    { "rate" : """14""" },
    { "rate" : """25""" },
    { "rate" : """20.45""" },
    { "rate" : """16.17""" },
    { "rate" : """0.989""" },
    { "rate" : """24""" },
    { "rate" : """10.99""" },
    { "rate" : """0.9999""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """20.45""" },
    { "rate" : """10.73""" },
    { "rate" : """0.9""" },
    { "rate" : """24""" },
    { "rate" : """13.11""" },
    { "rate" : """10.73""" },
    { "rate" : """24""" },
    { "rate" : """20.5""" },
    { "rate" : """10.73""" },
    { "rate" : """24""" },
    { "rate" : """11.8""" },
    { "rate" : """13.11""" },
    { "rate" : """12.5""" },
    { "rate" : """23.58""" },
    { "rate" : """4.75""" },
    { "rate" : """18.98""" },
    { "rate" : """23.58""" },
    { "rate" : """20.45""" },
    { "rate" : """10.1""" },
    { "rate" : """20.5""" },
    { "rate" : """9.96""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """12.26""" },
    { "rate" : """20.45""" },
    { "rate" : """11.99""" },
    { "rate" : """20.45""" },
    { "rate" : """11.111""" },
    { "rate" : """18.98""" },
    { "rate" : """0.99""" },
    { "rate" : """18.98""" },
    { "rate" : """9.9""" },
    { "rate" : """12.46""" },
    { "rate" : """18.98""" },
    { "rate" : """13.11""" },
    { "rate" : """4""" },
    { "rate" : """9.96""" },
    { "rate" : """20.45""" },
    { "rate" : """9.96""" },
    { "rate" : """20.5""" },
    { "rate" : """22""" },
    { "rate" : """18.98""" },
    { "rate" : """20.45""" },
    { "rate" : """0.98""" },
    { "rate" : """9.96""" },
    { "rate" : """8.5""" },
    { "rate" : """12.46""" },
    { "rate" : """10.73""" },
    { "rate" : """12.46""" },
    { "rate" : """0.88""" },
    { "rate" : """12.46""" },
    { "rate" : """18.98""" },
    { "rate" : """4""" },
    { "rate" : """24""" },
    { "rate" : """9""" },
    { "rate" : """23""" },
    { "rate" : """14.99""" },
    { "rate" : """9.96""" },
    { "rate" : """9.99999""" },
    { "rate" : """18.98""" },
    { "rate" : """9.96""" },
    { "rate" : """18.98""" },
    { "rate" : """11.99999""" },
    { "rate" : """18.98""" },
    { "rate" : """12.46""" },
    { "rate" : """0.99""" },
    { "rate" : """18""" },
    { "rate" : """12.46""" },
    { "rate" : """9.96""" },
    { "rate" : """25""" },
    { "rate" : """24""" },
    { "rate" : """20.45""" },
    { "rate" : """12.46""" },
    { "rate" : """11.99979""" },
    { "rate" : """20.45""" },
    { "rate" : """11""" },
    { "rate" : """25""" },
    { "rate" : """20.45""" },
    { "rate" : """12""" },
    { "rate" : """11.99""" },
    { "rate" : """0.9""" },
    { "rate" : """12.46""" },
    { "rate" : """15""" },
    { "rate" : """12.5""" },
    { "rate" : """14.5""" },
    { "rate" : """16.17""" },
    { "rate" : """12.46""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """25""" },
    { "rate" : """3.64""" },
    { "rate" : """16.17""" },
    { "rate" : """20.45""" },
    { "rate" : """20.45""" },
    { "rate" : """10.73""" },
    { "rate" : """12.46""" },
    { "rate" : """23.58""" },
    { "rate" : """24""" },
    { "rate" : """12.46""" },
    { "rate" : """23.99""" },
    { "rate" : """20.45""" },
    { "rate" : """20.45""" },
    { "rate" : """12.46""" },
    { "rate" : """26""" },
    { "rate" : """25""" },
    { "rate" : """24""" },
    { "rate" : """24""" },
    { "rate" : """24.898""" },
    { "rate" : """23.99""" },
    { "rate" : """11""" },
    { "rate" : """23.98""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """11.98999""" },
    { "rate" : """16.17""" },
    { "rate" : """24""" },
    { "rate" : """23.58""" },
    { "rate" : """0.988""" },
    { "rate" : """16.17""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """12.46""" },
    { "rate" : """8.64""" },
    { "rate" : """0.98989""" },
    { "rate" : """9.96""" },
    { "rate" : """23.9""" },
    { "rate" : """11.9""" },
    { "rate" : """25.9""" },
    { "rate" : """16.17""" },
    { "rate" : """0.95""" },
    { "rate" : """9.96""" },
    { "rate" : """12.46""" },
    { "rate" : """24""" },
    { "rate" : """23.99998""" },
    { "rate" : """10.73""" },
    { "rate" : """24""" },
    { "rate" : """25""" },
    { "rate" : """9.99""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """0.99""" },
    { "rate" : """11.5""" },
    { "rate" : """19.99""" },
    { "rate" : """11.2""" },
    { "rate" : """3.64""" },
    { "rate" : """0.95""" },
    { "rate" : """12.585""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """0.99998""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15.14""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """0.998""" },
    { "rate" : """9.96""" },
    { "rate" : """11""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """15.14""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """18.98""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """18.98""" },
    { "rate" : """19""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """18.98""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """10""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """3.64""" },
    { "rate" : """18.98""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """18.998""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """18.98""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """3.64""" },
    { "rate" : """12""" },
    { "rate" : """16.17""" },
    { "rate" : """18.98""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """18.98""" },
    { "rate" : """3.64""" },
    { "rate" : """12.46""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """3.64""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """12.46""" },
    { "rate" : """18.98""" },
    { "rate" : """9.99""" },
    { "rate" : """9.99""" },
    { "rate" : """16.17""" },
    { "rate" : """10""" },
    { "rate" : """12.5""" },
    { "rate" : """3.64""" },
    { "rate" : """14.999""" },
    { "rate" : """15""" },
    { "rate" : """3.64""" },
    { "rate" : """4.1""" },
    { "rate" : """9.96""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """3.98""" },
    { "rate" : """0.89979""" },
    { "rate" : """3.89979""" },
    { "rate" : """0.499""" },
    { "rate" : """0.9""" },
    { "rate" : """3.77777""" },
    { "rate" : """0.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """3.64""" },
    { "rate" : """13""" },
    { "rate" : """3.64""" },
    { "rate" : """12.26""" },
    { "rate" : """11""" },
    { "rate" : """3.64""" },
    { "rate" : """18.98""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """15""" },
    { "rate" : """14.99999""" },
    { "rate" : """16.17""" },
    { "rate" : """3.64""" },
    { "rate" : """18.98""" },
    { "rate" : """3.64""" },
    { "rate" : """18.99999""" },
    { "rate" : """16.17""" },
    { "rate" : """11.98""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """18.98""" },
    { "rate" : """12.26""" },
    { "rate" : """16.17""" },
    { "rate" : """9.99""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """11.99""" },
    { "rate" : """18.98""" },
    { "rate" : """18.99""" },
    { "rate" : """18.98""" },
    { "rate" : """15""" },
    { "rate" : """18.9998""" },
    { "rate" : """3.64""" },
    { "rate" : """18.98""" },
    { "rate" : """9.97""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """11.5""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """12.26""" },
    { "rate" : """4.99999""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """12.46""" },
    { "rate" : """15""" },
    { "rate" : """3.64""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """12.46""" },
    { "rate" : """3.64""" },
    { "rate" : """14""" },
    { "rate" : """12.46""" },
    { "rate" : """11.25""" },
    { "rate" : """10.73""" },
    { "rate" : """3.64""" },
    { "rate" : """11""" },
    { "rate" : """12.46""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """12.46""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """14""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """1""" },
    { "rate" : """14.99999""" },
    { "rate" : """10.73""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """9.9899""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """13""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """10.73""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """10.73""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """10""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """13.64""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """13""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """15.14""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """13.11""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """8.8""" },
    { "rate" : """12.5""" },
    { "rate" : """8.8""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """3.64""" },
    { "rate" : """13""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """3.64""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """3.64""" },
    { "rate" : """16.17""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """12""" },
    { "rate" : """14.9""" },
    { "rate" : """15.14""" },
    { "rate" : """14.9""" },
    { "rate" : """3.64""" },
    { "rate" : """15""" },
    { "rate" : """16""" },
    { "rate" : """10""" },
    { "rate" : """15.75""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """8.64""" },
    { "rate" : """12.26""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """8.64""" },
    { "rate" : """23.58""" },
    { "rate" : """8.64""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """8.64""" },
    { "rate" : """23.58""" },
    { "rate" : """16""" },
    { "rate" : """12.26""" },
    { "rate" : """23.58""" },
    { "rate" : """8.8""" },
    { "rate" : """4""" },
    { "rate" : """19.99""" },
    { "rate" : """9.5""" },
    { "rate" : """8.8""" },
    { "rate" : """12""" },
    { "rate" : """9.97""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """11.99999""" },
    { "rate" : """13""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """23.58""" },
    { "rate" : """12.26""" },
    { "rate" : """9.96""" },
    { "rate" : """10.1""" },
    { "rate" : """10.8""" },
    { "rate" : """15.5""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """9""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """10.73""" },
    { "rate" : """4""" },
    { "rate" : """14.99""" },
    { "rate" : """12.45""" },
    { "rate" : """9.98""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """13.11""" },
    { "rate" : """16""" },
    { "rate" : """13.11""" },
    { "rate" : """8""" },
    { "rate" : """13.11""" },
    { "rate" : """13.99""" },
    { "rate" : """13.11""" },
    { "rate" : """11.9""" },
    { "rate" : """13.11""" },
    { "rate" : """10.9""" },
    { "rate" : """12.46""" },
    { "rate" : """15""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """14.925""" },
    { "rate" : """8.8""" },
    { "rate" : """12.26""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """12.26""" },
    { "rate" : """13.11""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """12.26""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """3.64""" },
    { "rate" : """23.58""" },
    { "rate" : """9.96""" },
    { "rate" : """13.11""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """11.98999""" },
    { "rate" : """14.2""" },
    { "rate" : """3.99999""" },
    { "rate" : """1.9999""" },
    { "rate" : """8.64""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """1.599""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """8.8""" },
    { "rate" : """1.99998""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.85""" },
    { "rate" : """25""" },
    { "rate" : """1.99""" },
    { "rate" : """1.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """1.9999""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """12.26""" },
    { "rate" : """1.99999""" },
    { "rate" : """15""" },
    { "rate" : """1.99999""" },
    { "rate" : """9.99""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """8.8""" },
    { "rate" : """3.64""" },
    { "rate" : """11.86""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """15.14""" },
    { "rate" : """9.96""" },
    { "rate" : """11""" },
    { "rate" : """3.64""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """15""" },
    { "rate" : """9.9""" },
    { "rate" : """12.26""" },
    { "rate" : """10.73""" },
    { "rate" : """22""" },
    { "rate" : """23.58""" },
    { "rate" : """14.97""" },
    { "rate" : """8.8""" },
    { "rate" : """12.26""" },
    { "rate" : """9.96""" },
    { "rate" : """9.99""" },
    { "rate" : """9.99""" },
    { "rate" : """16""" },
    { "rate" : """15""" },
    { "rate" : """12.26""" },
    { "rate" : """10.73""" },
    { "rate" : """12.26""" },
    { "rate" : """16.16""" },
    { "rate" : """11.11""" },
    { "rate" : """9.96""" },
    { "rate" : """17.48""" },
    { "rate" : """18.98""" },
    { "rate" : """14.99999""" },
    { "rate" : """9.9""" },
    { "rate" : """3.64""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """16.17""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """9.999""" },
    { "rate" : """18.98""" },
    { "rate" : """10""" },
    { "rate" : """17""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """18""" },
    { "rate" : """8.8""" },
    { "rate" : """12.26""" },
    { "rate" : """13""" },
    { "rate" : """11.9""" },
    { "rate" : """15""" },
    { "rate" : """16.17""" },
    { "rate" : """16.92""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """17""" },
    { "rate" : """9""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """23.58""" },
    { "rate" : """9.96""" },
    { "rate" : """8.64""" },
    { "rate" : """3.64""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """8.64""" },
    { "rate" : """12.26""" },
    { "rate" : """16.17""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """10""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """12.99""" },
    { "rate" : """19.89""" },
    { "rate" : """14.89""" },
    { "rate" : """12""" },
    { "rate" : """19.98""" },
    { "rate" : """16.17""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """9.96""" },
    { "rate" : """11.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """8.8""" },
    { "rate" : """16.17""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """9.99""" },
    { "rate" : """9.96""" },
    { "rate" : """23.58""" },
    { "rate" : """8.8""" },
    { "rate" : """9.1""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """12.26""" },
    { "rate" : """3.64""" },
    { "rate" : """8.88""" },
    { "rate" : """12.26""" },
    { "rate" : """9.96""" },
    { "rate" : """12""" },
    { "rate" : """15.14""" },
    { "rate" : """17""" },
    { "rate" : """23.58""" },
    { "rate" : """16.17""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """8.64""" },
    { "rate" : """3.64""" },
    { "rate" : """9""" },
    { "rate" : """16""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """8.99""" },
    { "rate" : """3.64""" },
    { "rate" : """10""" },
    { "rate" : """8.64""" },
    { "rate" : """3.64""" },
    { "rate" : """9""" },
    { "rate" : """3.64""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """9""" },
    { "rate" : """16.17""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """8.99""" },
    { "rate" : """9""" },
    { "rate" : """17""" },
    { "rate" : """3.64""" },
    { "rate" : """16.17""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """3.64""" },
    { "rate" : """16.17""" },
    { "rate" : """3.64""" },
    { "rate" : """8.64""" },
    { "rate" : """3.64""" },
    { "rate" : """15.14""" },
    { "rate" : """3.64""" },
    { "rate" : """16.17""" },
    { "rate" : """15.14""" },
    { "rate" : """8.64""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """15.14""" },
    { "rate" : """3.64""" },
    { "rate" : """16.17""" },
    { "rate" : """8.64""" },
    { "rate" : """3.64""" },
    { "rate" : """15.14""" },
    { "rate" : """24""" },
    { "rate" : """9""" },
    { "rate" : """3.64""" },
    { "rate" : """16.17""" },
    { "rate" : """15.14""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """17""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """23.58""" },
    { "rate" : """8.85""" },
    { "rate" : """15""" },
    { "rate" : """8.85""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """16.17""" },
    { "rate" : """3.64""" },
    { "rate" : """11.9""" },
    { "rate" : """11.9""" },
    { "rate" : """3.64""" },
    { "rate" : """16.17""" },
    { "rate" : """3.64""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """17""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """17""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """8.64""" },
    { "rate" : """3.64""" },
    { "rate" : """15.14""" },
    { "rate" : """16.17""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """23.58""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """3.64""" },
    { "rate" : """11.96""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """8.99""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """23.58""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """9""" },
    { "rate" : """12.26""" },
    { "rate" : """23.58""" },
    { "rate" : """16.17""" },
    { "rate" : """19.99999""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """8.64""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """19.99999""" },
    { "rate" : """10.348""" },
    { "rate" : """12.418""" },
    { "rate" : """16.89""" },
    { "rate" : """3.64""" },
    { "rate" : """18.98""" },
    { "rate" : """8.89""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """8.8""" },
    { "rate" : """16.17""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """3.64""" },
    { "rate" : """23.58""" },
    { "rate" : """16.17""" },
    { "rate" : """23.58""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """12.5""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """9.96""" },
    { "rate" : """12.26""" },
    { "rate" : """14.89""" },
    { "rate" : """23.58""" },
    { "rate" : """20""" },
    { "rate" : """17.48""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """17.48""" },
    { "rate" : """8.64""" },
    { "rate" : """17.48""" },
    { "rate" : """10""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """20""" },
    { "rate" : """23.58""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """17.48""" },
    { "rate" : """9.98""" },
    { "rate" : """17.48""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """8.88""" },
    { "rate" : """17.48""" },
    { "rate" : """8.6""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """19""" },
    { "rate" : """8.64""" },
    { "rate" : """10""" },
    { "rate" : """14.428""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """8.99""" },
    { "rate" : """16.17""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """8.64""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """8.64""" },
    { "rate" : """16.17""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """11.98""" },
    { "rate" : """16.17""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """8.64""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """8.64""" },
    { "rate" : """3.64""" },
    { "rate" : """8.64""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """20""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """17""" },
    { "rate" : """9""" },
    { "rate" : """3.64""" },
    { "rate" : """8.64""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """7.99999""" },
    { "rate" : """10""" },
    { "rate" : """13.89""" },
    { "rate" : """3.64""" },
    { "rate" : """10""" },
    { "rate" : """7.9""" },
    { "rate" : """10""" },
    { "rate" : """8.79""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """7.97999""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """8.8""" },
    { "rate" : """4.5""" },
    { "rate" : """9.96""" },
    { "rate" : """7.98""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """14.98""" },
    { "rate" : """8.8""" },
    { "rate" : """23.58""" },
    { "rate" : """8.7999""" },
    { "rate" : """9.96""" },
    { "rate" : """8.78""" },
    { "rate" : """7.8999""" },
    { "rate" : """7.99988""" },
    { "rate" : """20""" },
    { "rate" : """8.64""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """8.64""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """8.64""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """12.26""" },
    { "rate" : """16.17""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """16.17""" },
    { "rate" : """1.5""" },
    { "rate" : """10""" },
    { "rate" : """8.64""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """1.99999""" },
    { "rate" : """15""" },
    { "rate" : """9.99999""" },
    { "rate" : """8.85""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """7.79999""" },
    { "rate" : """9.96""" },
    { "rate" : """8.79999""" },
    { "rate" : """12.26""" },
    { "rate" : """25""" },
    { "rate" : """8""" },
    { "rate" : """2.99""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """8.64""" },
    { "rate" : """7.99999""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """7.99999""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """7.99""" },
    { "rate" : """2.99""" },
    { "rate" : """16.17""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """7.99999""" },
    { "rate" : """12.26""" },
    { "rate" : """7.99""" },
    { "rate" : """7.992""" },
    { "rate" : """16.17""" },
    { "rate" : """7.95""" },
    { "rate" : """8.64""" },
    { "rate" : """16.1""" },
    { "rate" : """7.99999""" },
    { "rate" : """8.99999""" },
    { "rate" : """15.17""" },
    { "rate" : """2.99""" },
    { "rate" : """0.1""" },
    { "rate" : """5.99999""" },
    { "rate" : """8.64""" },
    { "rate" : """2.99999""" },
    { "rate" : """16.17""" },
    { "rate" : """8.64""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """9""" },
    { "rate" : """8.8""" },
    { "rate" : """14.99""" },
    { "rate" : """3.64""" },
    { "rate" : """6""" },
    { "rate" : """10.73""" },
    { "rate" : """8.64""" },
    { "rate" : """8.8""" },
    { "rate" : """13.72""" },
    { "rate" : """17""" },
    { "rate" : """14.79""" },
    { "rate" : """13.72""" },
    { "rate" : """16.17""" },
    { "rate" : """13.11""" },
    { "rate" : """13.72""" },
    { "rate" : """9.99""" },
    { "rate" : """3""" },
    { "rate" : """14.775""" },
    { "rate" : """6.4""" },
    { "rate" : """13.999""" },
    { "rate" : """16.99""" },
    { "rate" : """9.99""" },
    { "rate" : """9.7""" },
    { "rate" : """9.99""" },
    { "rate" : """11.6""" },
    { "rate" : """8.64""" },
    { "rate" : """25""" },
    { "rate" : """4.99""" },
    { "rate" : """3.99""" },
    { "rate" : """14.99""" },
    { "rate" : """8.99""" },
    { "rate" : """8.64""" },
    { "rate" : """16.17""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9""" },
    { "rate" : """14.99""" },
    { "rate" : """13.72""" },
    { "rate" : """14.99""" },
    { "rate" : """8.99""" },
    { "rate" : """14.53341""" },
    { "rate" : """16.17""" },
    { "rate" : """3""" },
    { "rate" : """8.8""" },
    { "rate" : """8.64""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """9.99""" },
    { "rate" : """8""" },
    { "rate" : """10.73""" },
    { "rate" : """9""" },
    { "rate" : """8.64""" },
    { "rate" : """9""" },
    { "rate" : """14.55""" },
    { "rate" : """0.01""" },
    { "rate" : """8.64""" },
    { "rate" : """15""" },
    { "rate" : """20""" },
    { "rate" : """8.5""" },
    { "rate" : """13.99""" },
    { "rate" : """14""" },
    { "rate" : """25""" },
    { "rate" : """24""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """9.811""" },
    { "rate" : """20""" },
    { "rate" : """16.55""" },
    { "rate" : """13.11""" },
    { "rate" : """7.9999""" },
    { "rate" : """13.72""" },
    { "rate" : """8.72""" },
    { "rate" : """16.17""" },
    { "rate" : """4.9999""" },
    { "rate" : """10""" },
    { "rate" : """8.64""" },
    { "rate" : """4.99""" },
    { "rate" : """8.64""" },
    { "rate" : """19""" },
    { "rate" : """6""" },
    { "rate" : """4.99989""" },
    { "rate" : """27""" },
    { "rate" : """3""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """9.99""" },
    { "rate" : """13.71""" },
    { "rate" : """18""" },
    { "rate" : """3""" },
    { "rate" : """9.99""" },
    { "rate" : """5.99""" },
    { "rate" : """6""" },
    { "rate" : """8.8""" },
    { "rate" : """4""" },
    { "rate" : """17""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """4.9998""" },
    { "rate" : """13.72""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """19.402""" },
    { "rate" : """15""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """8.64""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """8.8""" },
    { "rate" : """14.5""" },
    { "rate" : """5""" },
    { "rate" : """7.77""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """23.58""" },
    { "rate" : """23.57""" },
    { "rate" : """12""" },
    { "rate" : """8.64""" },
    { "rate" : """13""" },
    { "rate" : """15""" },
    { "rate" : """9.59999""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """8.8""" },
    { "rate" : """8.85""" },
    { "rate" : """6""" },
    { "rate" : """7.96""" },
    { "rate" : """3.64""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """3""" },
    { "rate" : """16.17""" },
    { "rate" : """9.2""" },
    { "rate" : """6""" },
    { "rate" : """9.507""" },
    { "rate" : """8.64""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """1.996""" },
    { "rate" : """1.98""" },
    { "rate" : """1.9""" },
    { "rate" : """9.6""" },
    { "rate" : """1.975""" },
    { "rate" : """1.99""" },
    { "rate" : """3""" },
    { "rate" : """1.95""" },
    { "rate" : """4.99999""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """18.96""" },
    { "rate" : """2""" },
    { "rate" : """16.99999""" },
    { "rate" : """1.95""" },
    { "rate" : """20""" },
    { "rate" : """2""" },
    { "rate" : """11.97""" },
    { "rate" : """2""" },
    { "rate" : """14.9999""" },
    { "rate" : """1.89999""" },
    { "rate" : """1.985""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3.64""" },
    { "rate" : """8""" },
    { "rate" : """1.99999""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """8.64""" },
    { "rate" : """9.96""" },
    { "rate" : """19.99999""" },
    { "rate" : """18.98""" },
    { "rate" : """16""" },
    { "rate" : """3.25""" },
    { "rate" : """1.998""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """0.01""" },
    { "rate" : """6""" },
    { "rate" : """3.24999""" },
    { "rate" : """9.96""" },
    { "rate" : """3.2""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """2""" },
    { "rate" : """10.73""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """3.25""" },
    { "rate" : """2""" },
    { "rate" : """3.24899""" },
    { "rate" : """6.955""" },
    { "rate" : """3.2""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """1.9""" },
    { "rate" : """4.9999""" },
    { "rate" : """7.99999""" },
    { "rate" : """3.25""" },
    { "rate" : """2""" },
    { "rate" : """24""" },
    { "rate" : """3""" },
    { "rate" : """9.96""" },
    { "rate" : """2""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """10.73""" },
    { "rate" : """3.64""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """6.5""" },
    { "rate" : """9.96""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """13.11""" },
    { "rate" : """3.64""" },
    { "rate" : """9.9999""" },
    { "rate" : """7.5""" },
    { "rate" : """4.99""" },
    { "rate" : """9.5""" },
    { "rate" : """1.98""" },
    { "rate" : """1.99""" },
    { "rate" : """23.58""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """1.9""" },
    { "rate" : """17.48""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """3.64""" },
    { "rate" : """8.64""" },
    { "rate" : """1.93""" },
    { "rate" : """9.96""" },
    { "rate" : """19""" },
    { "rate" : """2""" },
    { "rate" : """16.17""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """16.17""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """17.48""" },
    { "rate" : """16.17""" },
    { "rate" : """23.58""" },
    { "rate" : """1.9""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """8.8""" },
    { "rate" : """22.99999""" },
    { "rate" : """8.75""" },
    { "rate" : """6""" },
    { "rate" : """17.48""" },
    { "rate" : """4.5""" },
    { "rate" : """1.99979""" },
    { "rate" : """1.9999""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """23.57""" },
    { "rate" : """16.17""" },
    { "rate" : """23""" },
    { "rate" : """9""" },
    { "rate" : """9.96""" },
    { "rate" : """20""" },
    { "rate" : """16""" },
    { "rate" : """23.58""" },
    { "rate" : """8.64""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """9.9""" },
    { "rate" : """13""" },
    { "rate" : """9.9""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """2.99""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """8.64""" },
    { "rate" : """1.88""" },
    { "rate" : """23""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """23.58""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """18.98""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """14.9""" },
    { "rate" : """8.8""" },
    { "rate" : """7.9""" },
    { "rate" : """1""" },
    { "rate" : """3.64""" },
    { "rate" : """14.99999""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """7""" },
    { "rate" : """13.11""" },
    { "rate" : """14.9""" },
    { "rate" : """14.99998""" },
    { "rate" : """10""" },
    { "rate" : """1.9""" },
    { "rate" : """6.99999""" },
    { "rate" : """3""" },
    { "rate" : """7.3""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """3.64""" },
    { "rate" : """2""" },
    { "rate" : """0.5""" },
    { "rate" : """7.48777""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """14.999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """7.48999""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """13.72""" },
    { "rate" : """0.88""" },
    { "rate" : """1.99999""" },
    { "rate" : """5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.99799""" },
    { "rate" : """9.89999""" },
    { "rate" : """17.48""" },
    { "rate" : """20""" },
    { "rate" : """14.99998""" },
    { "rate" : """7.49999""" },
    { "rate" : """8""" },
    { "rate" : """1.99989""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """16.17""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """1.5""" },
    { "rate" : """15.17""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """2""" },
    { "rate" : """1.5""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """9.96""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """1.49999""" },
    { "rate" : """13.72""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """16.17""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """18.98""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """1.45""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """2""" },
    { "rate" : """1.5""" },
    { "rate" : """1""" },
    { "rate" : """9.96""" },
    { "rate" : """14.1""" },
    { "rate" : """14.89""" },
    { "rate" : """1.9999""" },
    { "rate" : """1.5""" },
    { "rate" : """23.58""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """9.5""" },
    { "rate" : """13.11""" },
    { "rate" : """4""" },
    { "rate" : """18.99999""" },
    { "rate" : """1.49999""" },
    { "rate" : """8.64""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """12.89""" },
    { "rate" : """8.64""" },
    { "rate" : """10.73""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """1.4999""" },
    { "rate" : """8.64""" },
    { "rate" : """23.58""" },
    { "rate" : """0.99999""" },
    { "rate" : """1.4999""" },
    { "rate" : """8.8""" },
    { "rate" : """1.999""" },
    { "rate" : """20""" },
    { "rate" : """23.57""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """1""" },
    { "rate" : """23.58""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """7.953""" },
    { "rate" : """8.8""" },
    { "rate" : """3.9""" },
    { "rate" : """1.5""" },
    { "rate" : """12""" },
    { "rate" : """8.99999""" },
    { "rate" : """1.99999""" },
    { "rate" : """10""" },
    { "rate" : """7.99999""" },
    { "rate" : """8.64""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """12.9""" },
    { "rate" : """14.99""" },
    { "rate" : """1.99999""" },
    { "rate" : """9.99""" },
    { "rate" : """13.99""" },
    { "rate" : """16.99""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """9.95999""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """17""" },
    { "rate" : """14.5""" },
    { "rate" : """1.9""" },
    { "rate" : """8.64""" },
    { "rate" : """1""" },
    { "rate" : """1.5""" },
    { "rate" : """2""" },
    { "rate" : """1.5""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """7.75""" },
    { "rate" : """3""" },
    { "rate" : """16.17""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """1.75""" },
    { "rate" : """5""" },
    { "rate" : """6.9999""" },
    { "rate" : """2""" },
    { "rate" : """4.9999""" },
    { "rate" : """2""" },
    { "rate" : """8.888""" },
    { "rate" : """2""" },
    { "rate" : """8.5""" },
    { "rate" : """3""" },
    { "rate" : """9.96""" },
    { "rate" : """2.98""" },
    { "rate" : """1.99""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """9.9""" },
    { "rate" : """9.96""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """18.98""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """13.72""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.8""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """20""" },
    { "rate" : """2""" },
    { "rate" : """7.4""" },
    { "rate" : """1.5""" },
    { "rate" : """1.49""" },
    { "rate" : """14""" },
    { "rate" : """2""" },
    { "rate" : """7.489""" },
    { "rate" : """8.99995""" },
    { "rate" : """8.64""" },
    { "rate" : """13.72""" },
    { "rate" : """8""" },
    { "rate" : """1.5""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """1.4""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """3.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1""" },
    { "rate" : """14.75""" },
    { "rate" : """6""" },
    { "rate" : """1.9""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """0.9""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """8.64""" },
    { "rate" : """2""" },
    { "rate" : """1.99599""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """14""" },
    { "rate" : """4""" },
    { "rate" : """8.64""" },
    { "rate" : """10""" },
    { "rate" : """7.5""" },
    { "rate" : """8.64""" },
    { "rate" : """15""" },
    { "rate" : """8.8""" },
    { "rate" : """1.5""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """1.5""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """10.73""" },
    { "rate" : """9.96""" },
    { "rate" : """9.8""" },
    { "rate" : """2""" },
    { "rate" : """16.17""" },
    { "rate" : """1.5""" },
    { "rate" : """16.17""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """1""" },
    { "rate" : """1.5""" },
    { "rate" : """0.99979""" },
    { "rate" : """8""" },
    { "rate" : """1.49979""" },
    { "rate" : """16.17""" },
    { "rate" : """8.8""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """1.5""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """9.99979""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """10.73""" },
    { "rate" : """8.64""" },
    { "rate" : """4""" },
    { "rate" : """8.64""" },
    { "rate" : """12""" },
    { "rate" : """11""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """13""" },
    { "rate" : """11.99999""" },
    { "rate" : """11.99998""" },
    { "rate" : """1.5""" },
    { "rate" : """9.6""" },
    { "rate" : """0.1""" },
    { "rate" : """1.5""" },
    { "rate" : """1.96""" },
    { "rate" : """8.5""" },
    { "rate" : """1.5""" },
    { "rate" : """14.17""" },
    { "rate" : """10""" },
    { "rate" : """0.99999""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """16.17""" },
    { "rate" : """15""" },
    { "rate" : """10.64""" },
    { "rate" : """1.5""" },
    { "rate" : """13.72""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """0.9999""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """18.98""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """2""" },
    { "rate" : """16.17""" },
    { "rate" : """0.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """1.5""" },
    { "rate" : """1""" },
    { "rate" : """9.91""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """15.99999""" },
    { "rate" : """8""" },
    { "rate" : """1.5""" },
    { "rate" : """1""" },
    { "rate" : """1.5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """0.99999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """17""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """1.99""" },
    { "rate" : """9.6""" },
    { "rate" : """8.79999""" },
    { "rate" : """1.98999""" },
    { "rate" : """17""" },
    { "rate" : """8.64""" },
    { "rate" : """16.15""" },
    { "rate" : """2""" },
    { "rate" : """1.499""" },
    { "rate" : """14""" },
    { "rate" : """1.5""" },
    { "rate" : """15""" },
    { "rate" : """1.49989""" },
    { "rate" : """14.98""" },
    { "rate" : """1.49""" },
    { "rate" : """0.99999""" },
    { "rate" : """9.95""" },
    { "rate" : """19""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """3.64""" },
    { "rate" : """10.73""" },
    { "rate" : """1.5""" },
    { "rate" : """1""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """0.99999""" },
    { "rate" : """6""" },
    { "rate" : """0.99999""" },
    { "rate" : """8.8""" },
    { "rate" : """0.99999""" },
    { "rate" : """16.17""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """19.5""" },
    { "rate" : """8.7""" },
    { "rate" : """1""" },
    { "rate" : """1.5""" },
    { "rate" : """5""" },
    { "rate" : """9.95""" },
    { "rate" : """2""" },
    { "rate" : """1.5""" },
    { "rate" : """8.8""" },
    { "rate" : """1.5""" },
    { "rate" : """1.6""" },
    { "rate" : """1""" },
    { "rate" : """19""" },
    { "rate" : """1.4999""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """9.3""" },
    { "rate" : """8""" },
    { "rate" : """8.99999""" },
    { "rate" : """2""" },
    { "rate" : """1.49999""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """3.9999""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """1.49885""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """9.5""" },
    { "rate" : """9.96""" },
    { "rate" : """21.58""" },
    { "rate" : """1.5""" },
    { "rate" : """2.0001""" },
    { "rate" : """8.5""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """1.4999""" },
    { "rate" : """8""" },
    { "rate" : """9.999""" },
    { "rate" : """7.99""" },
    { "rate" : """9""" },
    { "rate" : """8.8""" },
    { "rate" : """1.999""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """6.5""" },
    { "rate" : """18.98""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """1.95""" },
    { "rate" : """3.6""" },
    { "rate" : """9""" },
    { "rate" : """1.99999""" },
    { "rate" : """14""" },
    { "rate" : """17.48""" },
    { "rate" : """20""" },
    { "rate" : """16.17""" },
    { "rate" : """20""" },
    { "rate" : """18.98""" },
    { "rate" : """3.64""" },
    { "rate" : """8.99979""" },
    { "rate" : """3""" },
    { "rate" : """16.17""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """2.2""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """9.6""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """8.9""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """18""" },
    { "rate" : """1""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """1""" },
    { "rate" : """9.9""" },
    { "rate" : """3.64""" },
    { "rate" : """10.73""" },
    { "rate" : """3.1""" },
    { "rate" : """15""" },
    { "rate" : """16.5""" },
    { "rate" : """2""" },
    { "rate" : """16""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """13""" },
    { "rate" : """16.5""" },
    { "rate" : """9.5""" },
    { "rate" : """16.17""" },
    { "rate" : """18""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """0.999""" },
    { "rate" : """7.5""" },
    { "rate" : """7.9998""" },
    { "rate" : """10""" },
    { "rate" : """7.5""" },
    { "rate" : """7""" },
    { "rate" : """7.5""" },
    { "rate" : """7.9999""" },
    { "rate" : """7""" },
    { "rate" : """8.8""" },
    { "rate" : """18.98""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """14""" },
    { "rate" : """8.8""" },
    { "rate" : """7.99999""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """8.8""" },
    { "rate" : """18.98""" },
    { "rate" : """8""" },
    { "rate" : """9.95""" },
    { "rate" : """6.5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """15.9""" },
    { "rate" : """18.98""" },
    { "rate" : """8.99""" },
    { "rate" : """15""" },
    { "rate" : """8.99""" },
    { "rate" : """7.99""" },
    { "rate" : """16.99""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """17.48""" },
    { "rate" : """5.99999""" },
    { "rate" : """8.8""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """4""" },
    { "rate" : """3.9""" },
    { "rate" : """9.96""" },
    { "rate" : """8.7""" },
    { "rate" : """18.97""" },
    { "rate" : """20""" },
    { "rate" : """19.99""" },
    { "rate" : """19.99""" },
    { "rate" : """16""" },
    { "rate" : """8.99999""" },
    { "rate" : """9.5""" },
    { "rate" : """10""" },
    { "rate" : """18.98""" },
    { "rate" : """23.56""" },
    { "rate" : """7.99""" },
    { "rate" : """0.99""" },
    { "rate" : """8.98""" },
    { "rate" : """17.47""" },
    { "rate" : """5""" },
    { "rate" : """9.5""" },
    { "rate" : """19""" },
    { "rate" : """8.8""" },
    { "rate" : """9""" },
    { "rate" : """0.9""" },
    { "rate" : """20""" },
    { "rate" : """3""" },
    { "rate" : """16""" },
    { "rate" : """3""" },
    { "rate" : """17.48""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """7.95999""" },
    { "rate" : """8.89999""" },
    { "rate" : """3""" },
    { "rate" : """0.99999""" },
    { "rate" : """20""" },
    { "rate" : """16.17""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """18.98""" },
    { "rate" : """2.99999""" },
    { "rate" : """2""" },
    { "rate" : """7.5""" },
    { "rate" : """7.99""" },
    { "rate" : """10""" },
    { "rate" : """3.64""" },
    { "rate" : """2.99""" },
    { "rate" : """3""" },
    { "rate" : """9.96""" },
    { "rate" : """2.99999""" },
    { "rate" : """5.9""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """3.64""" },
    { "rate" : """7""" },
    { "rate" : """17.48""" },
    { "rate" : """8.8""" },
    { "rate" : """0.9999""" },
    { "rate" : """8""" },
    { "rate" : """18.97""" },
    { "rate" : """16.99""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """0.999""" },
    { "rate" : """3""" },
    { "rate" : """7.99998""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """3""" },
    { "rate" : """0.75""" },
    { "rate" : """2.99""" },
    { "rate" : """6.99999""" },
    { "rate" : """0.75""" },
    { "rate" : """3.64""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """18""" },
    { "rate" : """18.98""" },
    { "rate" : """17.48""" },
    { "rate" : """20""" },
    { "rate" : """0.5""" },
    { "rate" : """3""" },
    { "rate" : """0.5""" },
    { "rate" : """7.999""" },
    { "rate" : """7.49""" },
    { "rate" : """10""" },
    { "rate" : """0.75""" },
    { "rate" : """0.75""" },
    { "rate" : """5""" },
    { "rate" : """15.98""" },
    { "rate" : """9.89""" },
    { "rate" : """0.9""" },
    { "rate" : """17.46""" },
    { "rate" : """14.98""" },
    { "rate" : """18.98""" },
    { "rate" : """16.17""" },
    { "rate" : """18.97""" },
    { "rate" : """17.48""" },
    { "rate" : """2.98""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """17""" },
    { "rate" : """0.74953""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """0.9999""" },
    { "rate" : """8.4999""" },
    { "rate" : """18.4999""" },
    { "rate" : """16.999""" },
    { "rate" : """19.499""" },
    { "rate" : """0.74999""" },
    { "rate" : """19.999""" },
    { "rate" : """9.99""" },
    { "rate" : """14.9""" },
    { "rate" : """9.99""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """18.98""" },
    { "rate" : """16.17""" },
    { "rate" : """19.9""" },
    { "rate" : """17.48""" },
    { "rate" : """16.9""" },
    { "rate" : """14.9""" },
    { "rate" : """0.5""" },
    { "rate" : """2.99""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """18.98""" },
    { "rate" : """18.9""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """9.6""" },
    { "rate" : """3""" },
    { "rate" : """0.5""" },
    { "rate" : """18""" },
    { "rate" : """1""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """3.64""" },
    { "rate" : """17""" },
    { "rate" : """17.48""" },
    { "rate" : """2""" },
    { "rate" : """16.17""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """2.99""" },
    { "rate" : """2""" },
    { "rate" : """14""" },
    { "rate" : """9.99999""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """17""" },
    { "rate" : """10""" },
    { "rate" : """18.98""" },
    { "rate" : """8.8""" },
    { "rate" : """0.74999""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """9.254""" },
    { "rate" : """10.189""" },
    { "rate" : """8.8""" },
    { "rate" : """3.64""" },
    { "rate" : """3""" },
    { "rate" : """0.99999""" },
    { "rate" : """17.48""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """19.99""" },
    { "rate" : """3.64""" },
    { "rate" : """8.8""" },
    { "rate" : """20""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """3.64""" },
    { "rate" : """2""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """18.98""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """3.64""" },
    { "rate" : """10.73""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """8.79""" },
    { "rate" : """17.48""" },
    { "rate" : """2""" },
    { "rate" : """23.58""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """1.99999""" },
    { "rate" : """18.98""" },
    { "rate" : """8.6""" },
    { "rate" : """2.99""" },
    { "rate" : """9.9965""" },
    { "rate" : """3.64""" },
    { "rate" : """3""" },
    { "rate" : """20""" },
    { "rate" : """0.74""" },
    { "rate" : """16.17""" },
    { "rate" : """3""" },
    { "rate" : """23.57""" },
    { "rate" : """17.48""" },
    { "rate" : """16.17""" },
    { "rate" : """3.64""" },
    { "rate" : """0.49""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """3.64""" },
    { "rate" : """0.74""" },
    { "rate" : """18.97""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """3.64""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """3.64""" },
    { "rate" : """1""" },
    { "rate" : """9.99999""" },
    { "rate" : """1""" },
    { "rate" : """0.5""" },
    { "rate" : """19.9999""" },
    { "rate" : """18.98""" },
    { "rate" : """0.7499""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """2.9999""" },
    { "rate" : """16.17""" },
    { "rate" : """17.48""" },
    { "rate" : """18.98""" },
    { "rate" : """3.64""" },
    { "rate" : """1.95""" },
    { "rate" : """1.999""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """16.17""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """8.8""" },
    { "rate" : """3""" },
    { "rate" : """4.99999""" },
    { "rate" : """5.71""" },
    { "rate" : """0.59""" },
    { "rate" : """11.99999""" },
    { "rate" : """3.64""" },
    { "rate" : """16.17""" },
    { "rate" : """18.9""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """5.70999""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """3.64""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.7""" },
    { "rate" : """4.5""" },
    { "rate" : """5.7""" },
    { "rate" : """8.7""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """18.98""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """4.9""" },
    { "rate" : """19""" },
    { "rate" : """14""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """0.489""" },
    { "rate" : """8.5""" },
    { "rate" : """0.74999""" },
    { "rate" : """18.9""" },
    { "rate" : """14.99999""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """17""" },
    { "rate" : """4""" },
    { "rate" : """0.735""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """0.6""" },
    { "rate" : """16.17""" },
    { "rate" : """0.5""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """18.99999""" },
    { "rate" : """10""" },
    { "rate" : """10.447""" },
    { "rate" : """18.98""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """3.64""" },
    { "rate" : """17.48""" },
    { "rate" : """4.7999""" },
    { "rate" : """10""" },
    { "rate" : """0.74999""" },
    { "rate" : """10""" },
    { "rate" : """23.58""" },
    { "rate" : """0.5""" },
    { "rate" : """9.96""" },
    { "rate" : """0.7""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49""" },
    { "rate" : """3.99999""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """23.58""" },
    { "rate" : """8""" },
    { "rate" : """13.651""" },
    { "rate" : """9.96""" },
    { "rate" : """4.92""" },
    { "rate" : """18.98""" },
    { "rate" : """17.48""" },
    { "rate" : """9.95999""" },
    { "rate" : """4""" },
    { "rate" : """16.17""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.74985""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """3""" },
    { "rate" : """9.9999""" },
    { "rate" : """16""" },
    { "rate" : """0.74989""" },
    { "rate" : """3""" },
    { "rate" : """13.11""" },
    { "rate" : """2.5""" },
    { "rate" : """2.99""" },
    { "rate" : """9.96""" },
    { "rate" : """13.11""" },
    { "rate" : """3""" },
    { "rate" : """16.17""" },
    { "rate" : """23.58""" },
    { "rate" : """16.17""" },
    { "rate" : """15""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """9.95998""" },
    { "rate" : """0.49""" },
    { "rate" : """9.96""" },
    { "rate" : """0.5""" },
    { "rate" : """4.5""" },
    { "rate" : """4""" },
    { "rate" : """0.5""" },
    { "rate" : """0.6""" },
    { "rate" : """0.6999""" },
    { "rate" : """23.58""" },
    { "rate" : """8.8""" },
    { "rate" : """3.99999""" },
    { "rate" : """3.9975""" },
    { "rate" : """9.96""" },
    { "rate" : """8.6""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """3.9""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """0.5""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """8.25""" },
    { "rate" : """13.11""" },
    { "rate" : """4""" },
    { "rate" : """13.11""" },
    { "rate" : """0.5""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """16.17""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """16.16999""" },
    { "rate" : """9.96""" },
    { "rate" : """3.99999""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """5.738""" },
    { "rate" : """6""" },
    { "rate" : """4.9999""" },
    { "rate" : """0.5""" },
    { "rate" : """4""" },
    { "rate" : """3.63""" },
    { "rate" : """19.5""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """4""" },
    { "rate" : """13.11""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """0.61""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.698""" },
    { "rate" : """16.17""" },
    { "rate" : """6""" },
    { "rate" : """0.69799""" },
    { "rate" : """9.96""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """0.68989""" },
    { "rate" : """0.49989""" },
    { "rate" : """0.48999""" },
    { "rate" : """0.59999""" },
    { "rate" : """2.9""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """7.5""" },
    { "rate" : """7.98999""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """5""" },
    { "rate" : """5.675""" },
    { "rate" : """0.499""" },
    { "rate" : """12.9""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """9.96""" },
    { "rate" : """10.99999""" },
    { "rate" : """0.5""" },
    { "rate" : """2.5""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """13.11""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """5.9""" },
    { "rate" : """9.96""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """0.49""" },
    { "rate" : """12""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """17.5""" },
    { "rate" : """5""" },
    { "rate" : """3.99999""" },
    { "rate" : """10""" },
    { "rate" : """4.9999""" },
    { "rate" : """7.2""" },
    { "rate" : """0.5""" },
    { "rate" : """8.8""" },
    { "rate" : """23.58""" },
    { "rate" : """4""" },
    { "rate" : """3.49""" },
    { "rate" : """4.9975""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """13.1""" },
    { "rate" : """15""" },
    { "rate" : """23.58""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """9.99""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """23.58""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """23.58""" },
    { "rate" : """6""" },
    { "rate" : """14.99""" },
    { "rate" : """13.71""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """3.5""" },
    { "rate" : """13.72""" },
    { "rate" : """13.11""" },
    { "rate" : """3.99""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """0.52""" },
    { "rate" : """4.98""" },
    { "rate" : """4.9""" },
    { "rate" : """0.45""" },
    { "rate" : """9.99""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """3.4""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """13.11""" },
    { "rate" : """9.96""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """6""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """23.58""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """23.58""" },
    { "rate" : """9.96""" },
    { "rate" : """5.5""" },
    { "rate" : """10""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """15.25""" },
    { "rate" : """8.85""" },
    { "rate" : """4.5""" },
    { "rate" : """13.72""" },
    { "rate" : """4.99979""" },
    { "rate" : """13.72""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """0.5""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """1.99999""" },
    { "rate" : """5.5""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """4.99""" },
    { "rate" : """15""" },
    { "rate" : """0.48""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """13.11""" },
    { "rate" : """18.98""" },
    { "rate" : """19""" },
    { "rate" : """3.64""" },
    { "rate" : """11.99999""" },
    { "rate" : """16.17""" },
    { "rate" : """10.99999""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """23.58""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """14.99999""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """15.1""" },
    { "rate" : """14.99999""" },
    { "rate" : """8""" },
    { "rate" : """14.99999""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """14.99998""" },
    { "rate" : """19""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """3.99999""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """17.99999""" },
    { "rate" : """10""" },
    { "rate" : """9.9999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """14.9998""" },
    { "rate" : """15""" },
    { "rate" : """13.974""" },
    { "rate" : """14.99998""" },
    { "rate" : """12.437""" },
    { "rate" : """20""" },
    { "rate" : """4""" },
    { "rate" : """14.64""" },
    { "rate" : """6""" },
    { "rate" : """9.96""" },
    { "rate" : """16""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """16""" },
    { "rate" : """9.95""" },
    { "rate" : """8.64""" },
    { "rate" : """3""" },
    { "rate" : """13.11""" },
    { "rate" : """13.72""" },
    { "rate" : """4.8""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """4.99989""" },
    { "rate" : """14""" },
    { "rate" : """3""" },
    { "rate" : """14.99""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """9.56""" },
    { "rate" : """14.998""" },
    { "rate" : """8.64""" },
    { "rate" : """4.8""" },
    { "rate" : """0.44""" },
    { "rate" : """14.99999""" },
    { "rate" : """8.64""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """7""" },
    { "rate" : """8.8""" },
    { "rate" : """3.2""" },
    { "rate" : """3.2""" },
    { "rate" : """4""" },
    { "rate" : """15.14""" },
    { "rate" : """9.8""" },
    { "rate" : """23.58""" },
    { "rate" : """15""" },
    { "rate" : """13.72""" },
    { "rate" : """3""" },
    { "rate" : """3.2""" },
    { "rate" : """3.2""" },
    { "rate" : """15""" },
    { "rate" : """18.98""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """3.2""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """3.2""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """3.2""" },
    { "rate" : """12.99""" },
    { "rate" : """8.64""" },
    { "rate" : """14.99""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """15""" },
    { "rate" : """3.19999""" },
    { "rate" : """9.96""" },
    { "rate" : """6""" },
    { "rate" : """3.2""" },
    { "rate" : """12""" },
    { "rate" : """0.44""" },
    { "rate" : """4.99998""" },
    { "rate" : """16.17""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """8.99999""" },
    { "rate" : """3.1999""" },
    { "rate" : """2""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """0.45""" },
    { "rate" : """10""" },
    { "rate" : """3.2""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """3.2""" },
    { "rate" : """9.5""" },
    { "rate" : """14.9""" },
    { "rate" : """12.5""" },
    { "rate" : """3.19999""" },
    { "rate" : """8.8""" },
    { "rate" : """14""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.6""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """3.2""" },
    { "rate" : """8.64""" },
    { "rate" : """15""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """0.4999""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """4.999""" },
    { "rate" : """13.979""" },
    { "rate" : """8.8""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """7.99999""" },
    { "rate" : """3.2""" },
    { "rate" : """4""" },
    { "rate" : """8.8""" },
    { "rate" : """15""" },
    { "rate" : """3.2""" },
    { "rate" : """14""" },
    { "rate" : """9.96""" },
    { "rate" : """3.2""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """0.47""" },
    { "rate" : """0.49""" },
    { "rate" : """8.8""" },
    { "rate" : """9.104""" },
    { "rate" : """10""" },
    { "rate" : """8.79999""" },
    { "rate" : """3.1""" },
    { "rate" : """8.8""" },
    { "rate" : """0.49979""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """16.17""" },
    { "rate" : """8.8""" },
    { "rate" : """3""" },
    { "rate" : """3.2""" },
    { "rate" : """8.8""" },
    { "rate" : """3.19""" },
    { "rate" : """4.99""" },
    { "rate" : """20.57""" },
    { "rate" : """0.49989""" },
    { "rate" : """0.48""" },
    { "rate" : """8.7""" },
    { "rate" : """3.2""" },
    { "rate" : """13.11""" },
    { "rate" : """3.2""" },
    { "rate" : """8.7""" },
    { "rate" : """8.799""" },
    { "rate" : """4.4989""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """3.2""" },
    { "rate" : """3.2""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """3.2""" },
    { "rate" : """9.96""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """4.3""" },
    { "rate" : """4.4""" },
    { "rate" : """0.44""" },
    { "rate" : """18.99998""" },
    { "rate" : """13.72""" },
    { "rate" : """3.98""" },
    { "rate" : """3.9""" },
    { "rate" : """14.99998""" },
    { "rate" : """17""" },
    { "rate" : """8.5""" },
    { "rate" : """20""" },
    { "rate" : """3.2""" },
    { "rate" : """3""" },
    { "rate" : """3.9""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """13.72""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.3""" },
    { "rate" : """0.5""" },
    { "rate" : """18.5""" },
    { "rate" : """9.96""" },
    { "rate" : """4.9""" },
    { "rate" : """0.4""" },
    { "rate" : """1.99999""" },
    { "rate" : """999""" },
    { "rate" : """5""" },
    { "rate" : """16.17""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """0.39""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """8""" },
    { "rate" : """17.99998""" },
    { "rate" : """5.99999""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """4.99""" },
    { "rate" : """9.99""" },
    { "rate" : """16.17""" },
    { "rate" : """4""" },
    { "rate" : """13.11""" },
    { "rate" : """1.777""" },
    { "rate" : """1.8""" },
    { "rate" : """5""" },
    { "rate" : """1.8""" },
    { "rate" : """5""" },
    { "rate" : """1.8""" },
    { "rate" : """10""" },
    { "rate" : """1.89999""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """23.58""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """3.99975""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """3.99""" },
    { "rate" : """1.8""" },
    { "rate" : """19.9""" },
    { "rate" : """8""" },
    { "rate" : """9.6""" },
    { "rate" : """16.17""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """8.8""" },
    { "rate" : """4.97""" },
    { "rate" : """1""" },
    { "rate" : """3.8885""" },
    { "rate" : """1.8""" },
    { "rate" : """5""" },
    { "rate" : """1.8""" },
    { "rate" : """4""" },
    { "rate" : """7.99""" },
    { "rate" : """5""" },
    { "rate" : """1.89999""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4.9""" },
    { "rate" : """7.25""" },
    { "rate" : """7.89""" },
    { "rate" : """3.99985""" },
    { "rate" : """3.9""" },
    { "rate" : """13.11""" },
    { "rate" : """7.9""" },
    { "rate" : """9""" },
    { "rate" : """9.6""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """13""" },
    { "rate" : """3.5""" },
    { "rate" : """1.89""" },
    { "rate" : """7""" },
    { "rate" : """1.848""" },
    { "rate" : """3.89999""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """16""" },
    { "rate" : """10""" },
    { "rate" : """14.5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """1.89""" },
    { "rate" : """3.9999""" },
    { "rate" : """18""" },
    { "rate" : """20""" },
    { "rate" : """12.46""" },
    { "rate" : """1.75""" },
    { "rate" : """3""" },
    { "rate" : """5.3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.9""" },
    { "rate" : """3""" },
    { "rate" : """2.9975""" },
    { "rate" : """15.4""" },
    { "rate" : """2.95""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """2.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """2.985""" },
    { "rate" : """12.46""" },
    { "rate" : """20""" },
    { "rate" : """4.999""" },
    { "rate" : """9.96""" },
    { "rate" : """2.9999""" },
    { "rate" : """2.9999""" },
    { "rate" : """4.9999""" },
    { "rate" : """2.9999""" },
    { "rate" : """6""" },
    { "rate" : """2.999""" },
    { "rate" : """2.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """2.99999""" },
    { "rate" : """2.89""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """20""" },
    { "rate" : """15.14""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """4.99999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.8999""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """1.8""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """1.9""" },
    { "rate" : """2.5""" },
    { "rate" : """4""" },
    { "rate" : """4.5""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """1.98""" },
    { "rate" : """12.46""" },
    { "rate" : """2.5""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """2.49999""" },
    { "rate" : """5.542""" },
    { "rate" : """1.99999""" },
    { "rate" : """7""" },
    { "rate" : """2.5""" },
    { "rate" : """1.99""" },
    { "rate" : """2.5""" },
    { "rate" : """2.49999""" },
    { "rate" : """1.9975""" },
    { "rate" : """10""" },
    { "rate" : """1.98888""" },
    { "rate" : """4.89""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """8.999""" },
    { "rate" : """3.49999""" },
    { "rate" : """8.639""" },
    { "rate" : """3.4975""" },
    { "rate" : """2""" },
    { "rate" : """3.5""" },
    { "rate" : """1.99999""" },
    { "rate" : """3.49999""" },
    { "rate" : """23.58""" },
    { "rate" : """2.5""" },
    { "rate" : """6""" },
    { "rate" : """3.49699""" },
    { "rate" : """1.9""" },
    { "rate" : """1.99""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """9.99""" },
    { "rate" : """2.499""" },
    { "rate" : """3.5""" },
    { "rate" : """2.5""" },
    { "rate" : """9.96""" },
    { "rate" : """3.49899""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.9998""" },
    { "rate" : """3""" },
    { "rate" : """12.46""" },
    { "rate" : """1.98""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """4.5""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """2.25""" },
    { "rate" : """1.99""" },
    { "rate" : """12.46""" },
    { "rate" : """9.96""" },
    { "rate" : """3.5""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """2.5""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """9.9999""" },
    { "rate" : """1.999""" },
    { "rate" : """3.49979""" },
    { "rate" : """4""" },
    { "rate" : """1.975""" },
    { "rate" : """3.49""" },
    { "rate" : """4.9""" },
    { "rate" : """1.975""" },
    { "rate" : """2.975""" },
    { "rate" : """15""" },
    { "rate" : """1.99""" },
    { "rate" : """8.8""" },
    { "rate" : """3.49999""" },
    { "rate" : """14.5""" },
    { "rate" : """2""" },
    { "rate" : """3.497""" },
    { "rate" : """9.96""" },
    { "rate" : """1.99999""" },
    { "rate" : """3.5""" },
    { "rate" : """1.98999""" },
    { "rate" : """14""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """1""" },
    { "rate" : """1.9995""" },
    { "rate" : """1.99""" },
    { "rate" : """16.17""" },
    { "rate" : """2.49989""" },
    { "rate" : """1.97""" },
    { "rate" : """10""" },
    { "rate" : """3.4997""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """9.96""" },
    { "rate" : """13.11""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """20""" },
    { "rate" : """2.5""" },
    { "rate" : """3.5""" },
    { "rate" : """1.8""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """2.4999""" },
    { "rate" : """2.4""" },
    { "rate" : """1.99992""" },
    { "rate" : """3.5""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """13.8""" },
    { "rate" : """18.9999""" },
    { "rate" : """8.8""" },
    { "rate" : """1.99""" },
    { "rate" : """5""" },
    { "rate" : """1.9""" },
    { "rate" : """14.9""" },
    { "rate" : """3""" },
    { "rate" : """1.99998""" },
    { "rate" : """5""" },
    { "rate" : """12.45999""" },
    { "rate" : """3""" },
    { "rate" : """1.9""" },
    { "rate" : """4.4""" },
    { "rate" : """1.8""" },
    { "rate" : """1.95""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """0.45""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """3""" },
    { "rate" : """20.45""" },
    { "rate" : """10.73""" },
    { "rate" : """6""" },
    { "rate" : """18.98""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.6""" },
    { "rate" : """3.5""" },
    { "rate" : """7.9""" },
    { "rate" : """19.99""" },
    { "rate" : """3.5""" },
    { "rate" : """9.96""" },
    { "rate" : """8.7""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """9.5""" },
    { "rate" : """4.9""" },
    { "rate" : """14.99""" },
    { "rate" : """3.45""" },
    { "rate" : """3""" },
    { "rate" : """20""" },
    { "rate" : """9.96""" },
    { "rate" : """4.9999""" },
    { "rate" : """3.4975""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """16.16""" },
    { "rate" : """4.9999""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """1.9988""" },
    { "rate" : """3.5""" },
    { "rate" : """20""" },
    { "rate" : """1.99""" },
    { "rate" : """8""" },
    { "rate" : """2.99""" },
    { "rate" : """4.98""" },
    { "rate" : """15""" },
    { "rate" : """1.98""" },
    { "rate" : """16.17""" },
    { "rate" : """9.96""" },
    { "rate" : """16""" },
    { "rate" : """15""" },
    { "rate" : """1.99""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """4.99""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """16.99""" },
    { "rate" : """4.99""" },
    { "rate" : """12.46""" },
    { "rate" : """6""" },
    { "rate" : """5.99999""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """7.99999""" },
    { "rate" : """14.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """1.8""" },
    { "rate" : """18.98""" },
    { "rate" : """10.1""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """16.167""" },
    { "rate" : """1""" },
    { "rate" : """9.96""" },
    { "rate" : """3.5""" },
    { "rate" : """7.9""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """16.17""" },
    { "rate" : """3""" },
    { "rate" : """7.6""" },
    { "rate" : """16.17""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """14.9""" },
    { "rate" : """14.99999""" },
    { "rate" : """19""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """23.58""" },
    { "rate" : """20""" },
    { "rate" : """4""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """16""" },
    { "rate" : """4.3""" },
    { "rate" : """2""" },
    { "rate" : """4.7""" },
    { "rate" : """3""" },
    { "rate" : """1.99999""" },
    { "rate" : """19""" },
    { "rate" : """4.79""" },
    { "rate" : """4.78""" },
    { "rate" : """2.9""" },
    { "rate" : """3.99""" },
    { "rate" : """3.49""" },
    { "rate" : """0.1""" },
    { "rate" : """6""" },
    { "rate" : """11""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """20.45""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """12""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49975""" },
    { "rate" : """2""" },
    { "rate" : """0.48""" },
    { "rate" : """0.49989""" },
    { "rate" : """8.8""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """0.48""" },
    { "rate" : """3.3""" },
    { "rate" : """2""" },
    { "rate" : """0.49989""" },
    { "rate" : """19""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """0.5""" },
    { "rate" : """3.5""" },
    { "rate" : """8""" },
    { "rate" : """23.58""" },
    { "rate" : """0.5""" },
    { "rate" : """15""" },
    { "rate" : """0.497""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """8.8""" },
    { "rate" : """6""" },
    { "rate" : """0.5""" },
    { "rate" : """20""" },
    { "rate" : """0.49""" },
    { "rate" : """0.5""" },
    { "rate" : """6""" },
    { "rate" : """0.49779""" },
    { "rate" : """8.7""" },
    { "rate" : """9.96""" },
    { "rate" : """3.5""" },
    { "rate" : """8""" },
    { "rate" : """0.49999""" },
    { "rate" : """16.9""" },
    { "rate" : """0.5""" },
    { "rate" : """12.46""" },
    { "rate" : """0.5""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """2""" },
    { "rate" : """8.8""" },
    { "rate" : """20""" },
    { "rate" : """0.48""" },
    { "rate" : """12.46""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """0.49899""" },
    { "rate" : """12.46""" },
    { "rate" : """19.899""" },
    { "rate" : """10""" },
    { "rate" : """0.4998""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.48""" },
    { "rate" : """0.49999""" },
    { "rate" : """2""" },
    { "rate" : """10.73""" },
    { "rate" : """0.4999""" },
    { "rate" : """1.99""" },
    { "rate" : """2.25""" },
    { "rate" : """0.495""" },
    { "rate" : """24""" },
    { "rate" : """2.2""" },
    { "rate" : """22.46""" },
    { "rate" : """2.25""" },
    { "rate" : """19.46""" },
    { "rate" : """7.14""" },
    { "rate" : """2.24""" },
    { "rate" : """15""" },
    { "rate" : """0.499""" },
    { "rate" : """15.14""" },
    { "rate" : """5""" },
    { "rate" : """24.9998""" },
    { "rate" : """10.73""" },
    { "rate" : """2.25""" },
    { "rate" : """18""" },
    { "rate" : """2.2""" },
    { "rate" : """19""" },
    { "rate" : """2.25""" },
    { "rate" : """12""" },
    { "rate" : """2.25""" },
    { "rate" : """16.17""" },
    { "rate" : """2.24999""" },
    { "rate" : """2.25""" },
    { "rate" : """13.98""" },
    { "rate" : """2.249""" },
    { "rate" : """5""" },
    { "rate" : """2.99999""" },
    { "rate" : """3""" },
    { "rate" : """7.8""" },
    { "rate" : """12""" },
    { "rate" : """2.24999""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """19""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.2475""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """2.24""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """20""" },
    { "rate" : """2.2499""" },
    { "rate" : """2""" },
    { "rate" : """7.99999""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """20""" },
    { "rate" : """1.4""" },
    { "rate" : """7""" },
    { "rate" : """1.4""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """24""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """10.5""" },
    { "rate" : """18""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """0.9999""" },
    { "rate" : """3.95""" },
    { "rate" : """14.999""" },
    { "rate" : """0.9999""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """12.46""" },
    { "rate" : """0.5""" },
    { "rate" : """16.17""" },
    { "rate" : """0.9""" },
    { "rate" : """0.99""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """7.9""" },
    { "rate" : """0.99979""" },
    { "rate" : """1.99""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """0.89""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """16.17""" },
    { "rate" : """0.99""" },
    { "rate" : """8""" },
    { "rate" : """1.99999""" },
    { "rate" : """12.44""" },
    { "rate" : """1.4""" },
    { "rate" : """12.46""" },
    { "rate" : """7.5""" },
    { "rate" : """12""" },
    { "rate" : """14.99999""" },
    { "rate" : """0.89999""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """7.9999""" },
    { "rate" : """2.99""" },
    { "rate" : """7.99""" },
    { "rate" : """5""" },
    { "rate" : """1.4""" },
    { "rate" : """0.97999""" },
    { "rate" : """14.99""" },
    { "rate" : """19.99""" },
    { "rate" : """20""" },
    { "rate" : """12.46""" },
    { "rate" : """8""" },
    { "rate" : """0.98999""" },
    { "rate" : """12.46""" },
    { "rate" : """12""" },
    { "rate" : """8.8""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """12.46""" },
    { "rate" : """5.8""" },
    { "rate" : """13""" },
    { "rate" : """23.58""" },
    { "rate" : """8.8""" },
    { "rate" : """0.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """7.99""" },
    { "rate" : """9.99""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """7.99""" },
    { "rate" : """0.99999""" },
    { "rate" : """15""" },
    { "rate" : """0.9999""" },
    { "rate" : """22.78""" },
    { "rate" : """15.14""" },
    { "rate" : """24""" },
    { "rate" : """15.14""" },
    { "rate" : """24.99999""" },
    { "rate" : """15.14""" },
    { "rate" : """1.3""" },
    { "rate" : """0.45""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """8.992""" },
    { "rate" : """0.99""" },
    { "rate" : """8.5""" },
    { "rate" : """3""" },
    { "rate" : """0.4""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.9""" },
    { "rate" : """9""" },
    { "rate" : """15.23""" },
    { "rate" : """0.5""" },
    { "rate" : """16.99""" },
    { "rate" : """38.99999""" },
    { "rate" : """0.9""" },
    { "rate" : """7.8""" },
    { "rate" : """20.45""" },
    { "rate" : """18.9""" },
    { "rate" : """25""" },
    { "rate" : """23.58""" },
    { "rate" : """16.17""" },
    { "rate" : """25""" },
    { "rate" : """0.94999""" },
    { "rate" : """0.99998""" },
    { "rate" : """11.99""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9999""" },
    { "rate" : """14""" },
    { "rate" : """24.99999""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """25""" },
    { "rate" : """6""" },
    { "rate" : """12.46""" },
    { "rate" : """24.9998""" },
    { "rate" : """0.99969""" },
    { "rate" : """15.14""" },
    { "rate" : """9.5""" },
    { "rate" : """12""" },
    { "rate" : """15.14""" },
    { "rate" : """16.17""" },
    { "rate" : """0.89""" },
    { "rate" : """7""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """8.63""" },
    { "rate" : """7""" },
    { "rate" : """8.48999""" },
    { "rate" : """15.14""" },
    { "rate" : """8.64""" },
    { "rate" : """8""" },
    { "rate" : """20.45""" },
    { "rate" : """25""" },
    { "rate" : """23.99""" },
    { "rate" : """4""" },
    { "rate" : """8.63""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """7.99""" },
    { "rate" : """9.5""" },
    { "rate" : """8.63999""" },
    { "rate" : """7.9""" },
    { "rate" : """5.5""" },
    { "rate" : """8""" },
    { "rate" : """7.9""" },
    { "rate" : """8.5""" },
    { "rate" : """20""" },
    { "rate" : """9.96""" },
    { "rate" : """9.5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7.99999""" },
    { "rate" : """8.25""" },
    { "rate" : """12.45999""" },
    { "rate" : """7.8999""" },
    { "rate" : """12.46""" },
    { "rate" : """8.64""" },
    { "rate" : """8""" },
    { "rate" : """0.99998""" },
    { "rate" : """15.14""" },
    { "rate" : """8.25""" },
    { "rate" : """15""" },
    { "rate" : """30""" },
    { "rate" : """7.9""" },
    { "rate" : """1.4""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """7.9""" },
    { "rate" : """12.46""" },
    { "rate" : """6.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """3.99999""" },
    { "rate" : """0.35""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """7.99999""" },
    { "rate" : """18.99999""" },
    { "rate" : """7.98""" },
    { "rate" : """7.88999""" },
    { "rate" : """3.99999""" },
    { "rate" : """15.14""" },
    { "rate" : """8.4999""" },
    { "rate" : """24.9""" },
    { "rate" : """8.64""" },
    { "rate" : """0.89""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """6.85""" },
    { "rate" : """5""" },
    { "rate" : """12.459""" },
    { "rate" : """8.6395""" },
    { "rate" : """1.39""" },
    { "rate" : """6""" },
    { "rate" : """1.3""" },
    { "rate" : """0.98999""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """8.39979""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """8""" },
    { "rate" : """7.99979""" },
    { "rate" : """8""" },
    { "rate" : """7.9""" },
    { "rate" : """12""" },
    { "rate" : """8.64""" },
    { "rate" : """12.46""" },
    { "rate" : """8.64""" },
    { "rate" : """15""" },
    { "rate" : """8.8""" },
    { "rate" : """15.14""" },
    { "rate" : """9""" },
    { "rate" : """6.84""" },
    { "rate" : """0.99969""" },
    { "rate" : """8""" },
    { "rate" : """7.79999""" },
    { "rate" : """6""" },
    { "rate" : """7.98""" },
    { "rate" : """22""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """8.99999""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """8.64""" },
    { "rate" : """4""" },
    { "rate" : """7.99998""" },
    { "rate" : """6""" },
    { "rate" : """5.99999""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """15.14""" },
    { "rate" : """7.9""" },
    { "rate" : """10.73""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """23.58""" },
    { "rate" : """7.4""" },
    { "rate" : """9.96""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """8.64""" },
    { "rate" : """16.17""" },
    { "rate" : """10""" },
    { "rate" : """23.58""" },
    { "rate" : """8.99998""" },
    { "rate" : """7.99""" },
    { "rate" : """20""" },
    { "rate" : """7.99999""" },
    { "rate" : """8.8""" },
    { "rate" : """7.999""" },
    { "rate" : """20.45""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """7.99""" },
    { "rate" : """6""" },
    { "rate" : """8.44""" },
    { "rate" : """7.5""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """20""" },
    { "rate" : """8.64""" },
    { "rate" : """15.14""" },
    { "rate" : """1.4""" },
    { "rate" : """10.73""" },
    { "rate" : """15""" },
    { "rate" : """23.58""" },
    { "rate" : """17.48""" },
    { "rate" : """10""" },
    { "rate" : """7.975""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.9""" },
    { "rate" : """8""" },
    { "rate" : """7.25""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """7.39""" },
    { "rate" : """8.64""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """7""" },
    { "rate" : """0.5""" },
    { "rate" : """20.45""" },
    { "rate" : """15""" },
    { "rate" : """0.5""" },
    { "rate" : """12""" },
    { "rate" : """12.14""" },
    { "rate" : """29""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """15.14""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """20.45""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """1.4""" },
    { "rate" : """0.5""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """0.5""" },
    { "rate" : """2""" },
    { "rate" : """8.64""" },
    { "rate" : """7""" },
    { "rate" : """23.58""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """2""" },
    { "rate" : """0.5""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """15.14""" },
    { "rate" : """10""" },
    { "rate" : """1.99979""" },
    { "rate" : """15.14""" },
    { "rate" : """11.99979""" },
    { "rate" : """9.96""" },
    { "rate" : """8.4""" },
    { "rate" : """17.48""" },
    { "rate" : """14""" },
    { "rate" : """7.2""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """23.58""" },
    { "rate" : """36""" },
    { "rate" : """1""" },
    { "rate" : """8.64""" },
    { "rate" : """2""" },
    { "rate" : """8.64""" },
    { "rate" : """2""" },
    { "rate" : """1.99989""" },
    { "rate" : """0.5""" },
    { "rate" : """20""" },
    { "rate" : """7.99999""" },
    { "rate" : """12.46""" },
    { "rate" : """8""" },
    { "rate" : """1.9999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """30""" },
    { "rate" : """0.49""" },
    { "rate" : """8.64""" },
    { "rate" : """15.14""" },
    { "rate" : """8.64""" },
    { "rate" : """9.96""" },
    { "rate" : """1.75""" },
    { "rate" : """0.49""" },
    { "rate" : """9.5""" },
    { "rate" : """0.5""" },
    { "rate" : """9.95""" },
    { "rate" : """1.98999""" },
    { "rate" : """0.49899""" },
    { "rate" : """10""" },
    { "rate" : """25""" },
    { "rate" : """14""" },
    { "rate" : """0.49""" },
    { "rate" : """8.47""" },
    { "rate" : """30""" },
    { "rate" : """15.14""" },
    { "rate" : """0.5""" },
    { "rate" : """24""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49999""" },
    { "rate" : """2""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """2""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """15""" },
    { "rate" : """0.5""" },
    { "rate" : """4.99""" },
    { "rate" : """8""" },
    { "rate" : """3.9999""" },
    { "rate" : """0.49999""" },
    { "rate" : """9.88""" },
    { "rate" : """0.5""" },
    { "rate" : """9.96""" },
    { "rate" : """0.5""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """7.5""" },
    { "rate" : """16.17""" },
    { "rate" : """8""" },
    { "rate" : """25""" },
    { "rate" : """23.58""" },
    { "rate" : """17.48""" },
    { "rate" : """8""" },
    { "rate" : """39.98998""" },
    { "rate" : """7.19""" },
    { "rate" : """22""" },
    { "rate" : """7.99""" },
    { "rate" : """8.39""" },
    { "rate" : """0.49999""" },
    { "rate" : """1.999""" },
    { "rate" : """1""" },
    { "rate" : """9.5""" },
    { "rate" : """4""" },
    { "rate" : """10.73""" },
    { "rate" : """25""" },
    { "rate" : """2""" },
    { "rate" : """0.49""" },
    { "rate" : """24""" },
    { "rate" : """15.13999""" },
    { "rate" : """2""" },
    { "rate" : """15.14""" },
    { "rate" : """0.49979""" },
    { "rate" : """0.5""" },
    { "rate" : """18.98""" },
    { "rate" : """4""" },
    { "rate" : """39.99998""" },
    { "rate" : """15""" },
    { "rate" : """24.99998""" },
    { "rate" : """27""" },
    { "rate" : """23.58""" },
    { "rate" : """39.99999""" },
    { "rate" : """0.4995""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """3.64""" },
    { "rate" : """12.46""" },
    { "rate" : """7.95""" },
    { "rate" : """15.14""" },
    { "rate" : """0.499""" },
    { "rate" : """15.14""" },
    { "rate" : """16.17""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """20""" },
    { "rate" : """4.99""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """0.4""" },
    { "rate" : """8""" },
    { "rate" : """16.17""" },
    { "rate" : """9.96""" },
    { "rate" : """5.99""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """7.25""" },
    { "rate" : """10""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15""" },
    { "rate" : """4.99999""" },
    { "rate" : """8""" },
    { "rate" : """16""" },
    { "rate" : """17.48""" },
    { "rate" : """10.73""" },
    { "rate" : """0.5""" },
    { "rate" : """1.4""" },
    { "rate" : """24.9""" },
    { "rate" : """24""" },
    { "rate" : """14.99""" },
    { "rate" : """1.9""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """8""" },
    { "rate" : """15.14""" },
    { "rate" : """9.96""" },
    { "rate" : """1.9""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6.5""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """23.5""" },
    { "rate" : """1.99""" },
    { "rate" : """3""" },
    { "rate" : """15.14""" },
    { "rate" : """7.49999""" },
    { "rate" : """0.5""" },
    { "rate" : """13.49999""" },
    { "rate" : """15.14""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """10.73""" },
    { "rate" : """15.14""" },
    { "rate" : """1.7499""" },
    { "rate" : """5""" },
    { "rate" : """2.25""" },
    { "rate" : """3""" },
    { "rate" : """12.17""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """4.8""" },
    { "rate" : """20""" },
    { "rate" : """23.57""" },
    { "rate" : """2.90666""" },
    { "rate" : """3.99""" },
    { "rate" : """18.89""" },
    { "rate" : """16.16""" },
    { "rate" : """3""" },
    { "rate" : """16.17""" },
    { "rate" : """6.99999""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """39""" },
    { "rate" : """11.99999""" },
    { "rate" : """7.75""" },
    { "rate" : """3""" },
    { "rate" : """15.14""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """2.9999""" },
    { "rate" : """38""" },
    { "rate" : """3.64""" },
    { "rate" : """20""" },
    { "rate" : """12""" },
    { "rate" : """19.99999""" },
    { "rate" : """7.95""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """3.99999""" },
    { "rate" : """2.99""" },
    { "rate" : """2.99999""" },
    { "rate" : """23.58""" },
    { "rate" : """3""" },
    { "rate" : """2.935""" },
    { "rate" : """35""" },
    { "rate" : """23.58""" },
    { "rate" : """2""" },
    { "rate" : """16.17""" },
    { "rate" : """23.58""" },
    { "rate" : """0.5""" },
    { "rate" : """1.9""" },
    { "rate" : """0.5""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """1.39""" },
    { "rate" : """12""" },
    { "rate" : """23.58""" },
    { "rate" : """2.99999""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """1.9""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """2.98888""" },
    { "rate" : """2.99""" },
    { "rate" : """14.5""" },
    { "rate" : """15""" },
    { "rate" : """14.42""" },
    { "rate" : """14.9998""" },
    { "rate" : """9.96""" },
    { "rate" : """16""" },
    { "rate" : """23.58""" },
    { "rate" : """15""" },
    { "rate" : """14.5""" },
    { "rate" : """15""" },
    { "rate" : """10.73""" },
    { "rate" : """14""" },
    { "rate" : """7""" },
    { "rate" : """2.8""" },
    { "rate" : """15""" },
    { "rate" : """6.99""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """13""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """7.95""" },
    { "rate" : """2.91666""" },
    { "rate" : """14.99999""" },
    { "rate" : """14.9""" },
    { "rate" : """14.98""" },
    { "rate" : """8.99999""" },
    { "rate" : """14""" },
    { "rate" : """7.9""" },
    { "rate" : """23.57""" },
    { "rate" : """15""" },
    { "rate" : """14.99999""" },
    { "rate" : """12.46""" },
    { "rate" : """14.99999""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """5.3""" },
    { "rate" : """2.5""" },
    { "rate" : """15""" },
    { "rate" : """12.46""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """14.9899""" },
    { "rate" : """14.5""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """20.45""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """20.45""" },
    { "rate" : """15""" },
    { "rate" : """2.8""" },
    { "rate" : """6.55""" },
    { "rate" : """2.5""" },
    { "rate" : """14.5""" },
    { "rate" : """2.8""" },
    { "rate" : """4.8""" },
    { "rate" : """2.9""" },
    { "rate" : """3.64""" },
    { "rate" : """14.95""" },
    { "rate" : """14""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """14.875""" },
    { "rate" : """12.507""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """0.5""" },
    { "rate" : """30""" },
    { "rate" : """3.64""" },
    { "rate" : """15""" },
    { "rate" : """25""" },
    { "rate" : """23.58""" },
    { "rate" : """6.55""" },
    { "rate" : """12.46""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """0.5""" },
    { "rate" : """0.4""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """12.46""" },
    { "rate" : """14.99999""" },
    { "rate" : """3.99999""" },
    { "rate" : """2.99999""" },
    { "rate" : """2.5""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """14.5""" },
    { "rate" : """15""" },
    { "rate" : """20.45""" },
    { "rate" : """4""" },
    { "rate" : """23.58""" },
    { "rate" : """10.73""" },
    { "rate" : """14.99998""" },
    { "rate" : """14.91111""" },
    { "rate" : """10.73""" },
    { "rate" : """8.11111""" },
    { "rate" : """4""" },
    { "rate" : """7.999""" },
    { "rate" : """14.999""" },
    { "rate" : """0.48787""" },
    { "rate" : """7.25""" },
    { "rate" : """14.99""" },
    { "rate" : """4.879""" },
    { "rate" : """7""" },
    { "rate" : """14""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """8.79""" },
    { "rate" : """23""" },
    { "rate" : """9.96""" },
    { "rate" : """12.418""" },
    { "rate" : """7""" },
    { "rate" : """8.9""" },
    { "rate" : """4.99""" },
    { "rate" : """6.55""" },
    { "rate" : """3.64""" },
    { "rate" : """6.55""" },
    { "rate" : """12.46""" },
    { "rate" : """15.14""" },
    { "rate" : """6.55""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """17""" },
    { "rate" : """16.17""" },
    { "rate" : """17.48""" },
    { "rate" : """15.14""" },
    { "rate" : """12.46""" },
    { "rate" : """15.14""" },
    { "rate" : """0.498""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """0.5""" },
    { "rate" : """14.9998""" },
    { "rate" : """14""" },
    { "rate" : """11.5""" },
    { "rate" : """7.75""" },
    { "rate" : """1.3""" },
    { "rate" : """14""" },
    { "rate" : """0.4""" },
    { "rate" : """2.9""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """3.99""" },
    { "rate" : """0.49""" },
    { "rate" : """15.14""" },
    { "rate" : """0.49""" },
    { "rate" : """0.49""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """23.58""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """15.14""" },
    { "rate" : """10""" },
    { "rate" : """1.4""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """14.99""" },
    { "rate" : """14.99999""" },
    { "rate" : """2.8999""" },
    { "rate" : """0.49""" },
    { "rate" : """3.989""" },
    { "rate" : """17.4""" },
    { "rate" : """7.5""" },
    { "rate" : """12""" },
    { "rate" : """12.55""" },
    { "rate" : """9.025""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """9.9999""" },
    { "rate" : """13""" },
    { "rate" : """6.55""" },
    { "rate" : """14.9998""" },
    { "rate" : """14.99999""" },
    { "rate" : """7.5""" },
    { "rate" : """10""" },
    { "rate" : """10.5""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """10.73""" },
    { "rate" : """6.55""" },
    { "rate" : """12.46""" },
    { "rate" : """7.75""" },
    { "rate" : """14.99""" },
    { "rate" : """0.4899""" },
    { "rate" : """7.74""" },
    { "rate" : """24""" },
    { "rate" : """14.9""" },
    { "rate" : """15""" },
    { "rate" : """14.99999""" },
    { "rate" : """12""" },
    { "rate" : """0.48""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """20.45""" },
    { "rate" : """14""" },
    { "rate" : """14.99999""" },
    { "rate" : """15""" },
    { "rate" : """14.9""" },
    { "rate" : """15""" },
    { "rate" : """14.99999""" },
    { "rate" : """24.99999""" },
    { "rate" : """20.19""" },
    { "rate" : """14.99999""" },
    { "rate" : """0.471""" },
    { "rate" : """7.999""" },
    { "rate" : """9.99""" },
    { "rate" : """0.49999""" },
    { "rate" : """9.96""" },
    { "rate" : """14""" },
    { "rate" : """13""" },
    { "rate" : """11""" },
    { "rate" : """15.99999""" },
    { "rate" : """12.46""" },
    { "rate" : """0.485""" },
    { "rate" : """23""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """2.8""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """19.99""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """14.998""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """14.9""" },
    { "rate" : """10""" },
    { "rate" : """0.4""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """22""" },
    { "rate" : """9""" },
    { "rate" : """0.4""" },
    { "rate" : """9.96""" },
    { "rate" : """7.5""" },
    { "rate" : """14""" },
    { "rate" : """17.48""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """12.46""" },
    { "rate" : """16.17""" },
    { "rate" : """10.73""" },
    { "rate" : """15""" },
    { "rate" : """18""" },
    { "rate" : """19.99""" },
    { "rate" : """13""" },
    { "rate" : """8.79""" },
    { "rate" : """2.25""" },
    { "rate" : """9.96""" },
    { "rate" : """7.5""" },
    { "rate" : """15""" },
    { "rate" : """2.99999""" },
    { "rate" : """18.98""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """0.4""" },
    { "rate" : """3.64""" },
    { "rate" : """12.45559""" },
    { "rate" : """9.97""" },
    { "rate" : """3""" },
    { "rate" : """2.99""" },
    { "rate" : """0.4""" },
    { "rate" : """14""" },
    { "rate" : """18.7""" },
    { "rate" : """12.46""" },
    { "rate" : """14.95""" },
    { "rate" : """17.48""" },
    { "rate" : """15""" },
    { "rate" : """3.99""" },
    { "rate" : """10.935""" },
    { "rate" : """7.5""" },
    { "rate" : """8""" },
    { "rate" : """10.5""" },
    { "rate" : """18.98""" },
    { "rate" : """10""" },
    { "rate" : """14.999""" },
    { "rate" : """2""" },
    { "rate" : """12.46""" },
    { "rate" : """15""" },
    { "rate" : """23.58""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """12.46""" },
    { "rate" : """10.73""" },
    { "rate" : """5""" },
    { "rate" : """7.99979""" },
    { "rate" : """8""" },
    { "rate" : """14.99""" },
    { "rate" : """8""" },
    { "rate" : """1.97999""" },
    { "rate" : """14.99998""" },
    { "rate" : """12.46""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """0.4""" },
    { "rate" : """15""" },
    { "rate" : """14.99999""" },
    { "rate" : """10.73""" },
    { "rate" : """12.46""" },
    { "rate" : """6""" },
    { "rate" : """3.64""" },
    { "rate" : """23.58""" },
    { "rate" : """15""" },
    { "rate" : """14.99999""" },
    { "rate" : """13.56""" },
    { "rate" : """7.99""" },
    { "rate" : """15.14""" },
    { "rate" : """23.58""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """19""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """14.89""" },
    { "rate" : """20""" },
    { "rate" : """24""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.99998""" },
    { "rate" : """5""" },
    { "rate" : """23.58""" },
    { "rate" : """1.99999""" },
    { "rate" : """7.9""" },
    { "rate" : """1.9""" },
    { "rate" : """14.5""" },
    { "rate" : """4.95""" },
    { "rate" : """4.89999""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """2""" },
    { "rate" : """0.4""" },
    { "rate" : """1.9""" },
    { "rate" : """4.95""" },
    { "rate" : """4.949""" },
    { "rate" : """2.8""" },
    { "rate" : """15.14""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """4.5""" },
    { "rate" : """17""" },
    { "rate" : """3.89""" },
    { "rate" : """4""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """12.26""" },
    { "rate" : """3.99999""" },
    { "rate" : """15.12""" },
    { "rate" : """4.94""" },
    { "rate" : """4.85""" },
    { "rate" : """4""" },
    { "rate" : """4.9999""" },
    { "rate" : """9.96""" },
    { "rate" : """1.975""" },
    { "rate" : """1.9""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """17.48""" },
    { "rate" : """2.93499""" },
    { "rate" : """4.9""" },
    { "rate" : """14.99998""" },
    { "rate" : """2.99999""" },
    { "rate" : """3""" },
    { "rate" : """4.99""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """4.99999""" },
    { "rate" : """15""" },
    { "rate" : """3.99998""" },
    { "rate" : """2.79""" },
    { "rate" : """4""" },
    { "rate" : """9.96""" },
    { "rate" : """2""" },
    { "rate" : """23.58""" },
    { "rate" : """1.5""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """3.99999""" },
    { "rate" : """12""" },
    { "rate" : """4.9""" },
    { "rate" : """9""" },
    { "rate" : """2.99999""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """10.1""" },
    { "rate" : """1.99""" },
    { "rate" : """3.98999""" },
    { "rate" : """5.49999""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4.87999""" },
    { "rate" : """2""" },
    { "rate" : """4.94899""" },
    { "rate" : """13.4""" },
    { "rate" : """14.9""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """3.95""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """4.9""" },
    { "rate" : """0.4""" },
    { "rate" : """3.925""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """4.9""" },
    { "rate" : """2.5""" },
    { "rate" : """9.96""" },
    { "rate" : """20""" },
    { "rate" : """15.14""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """2.9339""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """20""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """4.94""" },
    { "rate" : """15.999""" },
    { "rate" : """4""" },
    { "rate" : """9.96""" },
    { "rate" : """3.999""" },
    { "rate" : """14.99999""" },
    { "rate" : """2.93333""" },
    { "rate" : """10""" },
    { "rate" : """4.975""" },
    { "rate" : """4.9488""" },
    { "rate" : """23.58""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """4.95""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """3.64""" },
    { "rate" : """10.73""" },
    { "rate" : """8.5""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """23.5""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """7.5""" },
    { "rate" : """9.96""" },
    { "rate" : """3.5""" },
    { "rate" : """12.46""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """3.99999""" },
    { "rate" : """14.99""" },
    { "rate" : """9""" },
    { "rate" : """3.99""" },
    { "rate" : """7.99999""" },
    { "rate" : """11""" },
    { "rate" : """15""" },
    { "rate" : """3.99999""" },
    { "rate" : """7""" },
    { "rate" : """3.99999""" },
    { "rate" : """14.99999""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """5.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """17.48""" },
    { "rate" : """5""" },
    { "rate" : """4.899""" },
    { "rate" : """4.799""" },
    { "rate" : """14.99998""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """8.99998""" },
    { "rate" : """14.99998""" },
    { "rate" : """4.78999""" },
    { "rate" : """12.99999""" },
    { "rate" : """5""" },
    { "rate" : """3.95""" },
    { "rate" : """3.64""" },
    { "rate" : """10.73""" },
    { "rate" : """8""" },
    { "rate" : """14.9""" },
    { "rate" : """8""" },
    { "rate" : """24""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """10.73""" },
    { "rate" : """12.46""" },
    { "rate" : """4.8""" },
    { "rate" : """10.64""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """14.99""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """15.14""" },
    { "rate" : """10.73""" },
    { "rate" : """9.96""" },
    { "rate" : """4.9""" },
    { "rate" : """3.5""" },
    { "rate" : """3.64""" },
    { "rate" : """12""" },
    { "rate" : """10.73""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """14.9888""" },
    { "rate" : """16.17""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """16""" },
    { "rate" : """8.85""" },
    { "rate" : """12.25""" },
    { "rate" : """10.5""" },
    { "rate" : """9.96""" },
    { "rate" : """9.99""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """0.4""" },
    { "rate" : """5""" },
    { "rate" : """10.73""" },
    { "rate" : """15""" },
    { "rate" : """4.7""" },
    { "rate" : """5""" },
    { "rate" : """14.99999""" },
    { "rate" : """12.26""" },
    { "rate" : """12.46""" },
    { "rate" : """4.9""" },
    { "rate" : """1""" },
    { "rate" : """8.99""" },
    { "rate" : """3.7""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """8.99""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """0.4""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """8.8""" },
    { "rate" : """3""" },
    { "rate" : """4.49""" },
    { "rate" : """8.8""" },
    { "rate" : """12.46""" },
    { "rate" : """4.899""" },
    { "rate" : """8.8""" },
    { "rate" : """4.5""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """8.2""" },
    { "rate" : """0.7""" },
    { "rate" : """15""" },
    { "rate" : """0.8""" },
    { "rate" : """0.9""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """0.95""" },
    { "rate" : """12.46""" },
    { "rate" : """0.8""" },
    { "rate" : """0.94""" },
    { "rate" : """22""" },
    { "rate" : """0.9""" },
    { "rate" : """0.8""" },
    { "rate" : """0.8""" },
    { "rate" : """1.999""" },
    { "rate" : """0.8""" },
    { "rate" : """0.85""" },
    { "rate" : """3""" },
    { "rate" : """0.07999""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9.96""" },
    { "rate" : """2.975""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9""" },
    { "rate" : """3.5""" },
    { "rate" : """3.9""" },
    { "rate" : """0.97""" },
    { "rate" : """0.4""" },
    { "rate" : """0.89999""" },
    { "rate" : """9.96""" },
    { "rate" : """3.45""" },
    { "rate" : """0.398""" },
    { "rate" : """9.91""" },
    { "rate" : """0.8""" },
    { "rate" : """0.945""" },
    { "rate" : """9.6""" },
    { "rate" : """9.94""" },
    { "rate" : """0.75""" },
    { "rate" : """9.96""" },
    { "rate" : """0.96""" },
    { "rate" : """0.94999""" },
    { "rate" : """0.95""" },
    { "rate" : """8.9999""" },
    { "rate" : """0.94""" },
    { "rate" : """0.94""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """0.8999""" },
    { "rate" : """0.899""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """12.46""" },
    { "rate" : """0.85""" },
    { "rate" : """9.96""" },
    { "rate" : """3.38""" },
    { "rate" : """12.45""" },
    { "rate" : """8.7""" },
    { "rate" : """4.89999""" },
    { "rate" : """0.85""" },
    { "rate" : """9.95""" },
    { "rate" : """9""" },
    { "rate" : """5.9""" },
    { "rate" : """3.48""" },
    { "rate" : """9""" },
    { "rate" : """8.5""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """9.95""" },
    { "rate" : """10""" },
    { "rate" : """2.99999""" },
    { "rate" : """9.95""" },
    { "rate" : """6""" },
    { "rate" : """9.93999""" },
    { "rate" : """8.96""" },
    { "rate" : """8""" },
    { "rate" : """2.9""" },
    { "rate" : """5.99979""" },
    { "rate" : """8""" },
    { "rate" : """14""" },
    { "rate" : """8.8""" },
    { "rate" : """7.9988""" },
    { "rate" : """8""" },
    { "rate" : """4.7""" },
    { "rate" : """5.99999""" },
    { "rate" : """10""" },
    { "rate" : """9.9999""" },
    { "rate" : """9.9998""" },
    { "rate" : """4.94""" },
    { "rate" : """7.95""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """7.99999""" },
    { "rate" : """3.9""" },
    { "rate" : """4.7""" },
    { "rate" : """8.8""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """7.96""" },
    { "rate" : """15.14""" },
    { "rate" : """16.17""" },
    { "rate" : """24""" },
    { "rate" : """7.94""" },
    { "rate" : """8.8""" },
    { "rate" : """5.9""" },
    { "rate" : """4.96""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """5.9""" },
    { "rate" : """4.94999""" },
    { "rate" : """6""" },
    { "rate" : """7.99999""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """4.5""" },
    { "rate" : """8.8""" },
    { "rate" : """15.14""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """5.99999""" },
    { "rate" : """7.99998""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """16""" },
    { "rate" : """0.5""" },
    { "rate" : """0.75""" },
    { "rate" : """0.75""" },
    { "rate" : """0.75""" },
    { "rate" : """0.66""" },
    { "rate" : """0.95""" },
    { "rate" : """6""" },
    { "rate" : """0.96""" },
    { "rate" : """0.94""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """0.871""" },
    { "rate" : """12.46""" },
    { "rate" : """0.95""" },
    { "rate" : """10""" },
    { "rate" : """3.24""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """8.8""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """8.79""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """2.5""" },
    { "rate" : """4.5""" },
    { "rate" : """7.96""" },
    { "rate" : """5.9""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """8.8""" },
    { "rate" : """1""" },
    { "rate" : """0.8""" },
    { "rate" : """1""" },
    { "rate" : """5.99""" },
    { "rate" : """9.99999""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """0.9""" },
    { "rate" : """5.9""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """0.75""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """0.99""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """3.24""" },
    { "rate" : """9.96""" },
    { "rate" : """1""" },
    { "rate" : """1.4""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """3.49""" },
    { "rate" : """3.64""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """9.98""" },
    { "rate" : """9.94""" },
    { "rate" : """5.98""" },
    { "rate" : """12.46""" },
    { "rate" : """0.95""" },
    { "rate" : """17.48""" },
    { "rate" : """6""" },
    { "rate" : """7.95""" },
    { "rate" : """12.46""" },
    { "rate" : """3.24""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """3.25""" },
    { "rate" : """9.96""" },
    { "rate" : """0.5""" },
    { "rate" : """17.48""" },
    { "rate" : """12.46""" },
    { "rate" : """0.75""" },
    { "rate" : """6""" },
    { "rate" : """3.24""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """3.25""" },
    { "rate" : """1""" },
    { "rate" : """3.24""" },
    { "rate" : """6""" },
    { "rate" : """7.8""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """7.99999""" },
    { "rate" : """5""" },
    { "rate" : """3.75""" },
    { "rate" : """4.5""" },
    { "rate" : """1.167""" },
    { "rate" : """3.7""" },
    { "rate" : """7.9""" },
    { "rate" : """3.75""" },
    { "rate" : """5""" },
    { "rate" : """3.75""" },
    { "rate" : """9""" },
    { "rate" : """3.75""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """14""" },
    { "rate" : """1""" },
    { "rate" : """3.75""" },
    { "rate" : """3.75""" },
    { "rate" : """3.74999""" },
    { "rate" : """0.8""" },
    { "rate" : """5""" },
    { "rate" : """17.48""" },
    { "rate" : """3.5""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """2.99999""" },
    { "rate" : """21""" },
    { "rate" : """3.7""" },
    { "rate" : """3.74998""" },
    { "rate" : """6.99""" },
    { "rate" : """9.95""" },
    { "rate" : """17.48""" },
    { "rate" : """2.99998""" },
    { "rate" : """4.98""" },
    { "rate" : """3.74999""" },
    { "rate" : """7.75""" },
    { "rate" : """7.5""" },
    { "rate" : """7.8999""" },
    { "rate" : """3""" },
    { "rate" : """17.48""" },
    { "rate" : """3.7""" },
    { "rate" : """15.14""" },
    { "rate" : """18""" },
    { "rate" : """3.64""" },
    { "rate" : """7.998""" },
    { "rate" : """13""" },
    { "rate" : """3""" },
    { "rate" : """16""" },
    { "rate" : """13.72""" },
    { "rate" : """3""" },
    { "rate" : """3.75""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """3.75""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """3.7""" },
    { "rate" : """5.99""" },
    { "rate" : """3.24""" },
    { "rate" : """3.75""" },
    { "rate" : """15.14""" },
    { "rate" : """7""" },
    { "rate" : """8.1""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3.75""" },
    { "rate" : """18.98""" },
    { "rate" : """12.46""" },
    { "rate" : """3""" },
    { "rate" : """2.99""" },
    { "rate" : """2.8""" },
    { "rate" : """3.5""" },
    { "rate" : """4.99""" },
    { "rate" : """2.8""" },
    { "rate" : """4.25""" },
    { "rate" : """7.99""" },
    { "rate" : """3.7""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """15""" },
    { "rate" : """3.7""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """3.24""" },
    { "rate" : """3.64""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """3.24""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """2.9""" },
    { "rate" : """3.7""" },
    { "rate" : """9.97""" },
    { "rate" : """3.24""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """0.98""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """15.14""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """6.999""" },
    { "rate" : """10""" },
    { "rate" : """6.98""" },
    { "rate" : """12.46""" },
    { "rate" : """7.99""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """7.99""" },
    { "rate" : """8""" },
    { "rate" : """7.99999""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """3.64""" },
    { "rate" : """0.5""" },
    { "rate" : """3.9""" },
    { "rate" : """8""" },
    { "rate" : """0.49979""" },
    { "rate" : """0.4975""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """4.99998""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """0.49749""" },
    { "rate" : """9.96""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """14""" },
    { "rate" : """7.935""" },
    { "rate" : """3""" },
    { "rate" : """0.5""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """9.8""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """0.5""" },
    { "rate" : """17.48""" },
    { "rate" : """7.89""" },
    { "rate" : """5""" },
    { "rate" : """7.99979""" },
    { "rate" : """1""" },
    { "rate" : """14.9""" },
    { "rate" : """7.77777""" },
    { "rate" : """7.4975""" },
    { "rate" : """1""" },
    { "rate" : """7.4""" },
    { "rate" : """2.99992""" },
    { "rate" : """9.96""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """3.24""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.1""" },
    { "rate" : """7.39""" },
    { "rate" : """1""" },
    { "rate" : """3.99998""" },
    { "rate" : """13.9999""" },
    { "rate" : """1""" },
    { "rate" : """4.9999""" },
    { "rate" : """13.99""" },
    { "rate" : """30""" },
    { "rate" : """29.99999""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """13.72""" },
    { "rate" : """16.17""" },
    { "rate" : """13.5""" },
    { "rate" : """9""" },
    { "rate" : """7.5""" },
    { "rate" : """8""" },
    { "rate" : """30""" },
    { "rate" : """0.99979""" },
    { "rate" : """1""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """3.24""" },
    { "rate" : """26.17""" },
    { "rate" : """1""" },
    { "rate" : """30""" },
    { "rate" : """9.96""" },
    { "rate" : """0.1""" },
    { "rate" : """25""" },
    { "rate" : """29""" },
    { "rate" : """7.99999""" },
    { "rate" : """13""" },
    { "rate" : """4.99999""" },
    { "rate" : """16.17""" },
    { "rate" : """0.99999""" },
    { "rate" : """7""" },
    { "rate" : """0.99999""" },
    { "rate" : """7.9999""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """21""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """12.46""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """30""" },
    { "rate" : """0.8""" },
    { "rate" : """0.9""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """0.99995""" },
    { "rate" : """6.99""" },
    { "rate" : """12""" },
    { "rate" : """30""" },
    { "rate" : """3.64""" },
    { "rate" : """16.17""" },
    { "rate" : """3.24""" },
    { "rate" : """24.99""" },
    { "rate" : """3.25""" },
    { "rate" : """0.5""" },
    { "rate" : """9.96""" },
    { "rate" : """6.95""" },
    { "rate" : """8.95""" },
    { "rate" : """30""" },
    { "rate" : """4.8""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """0.5""" },
    { "rate" : """7""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """3.24""" },
    { "rate" : """30""" },
    { "rate" : """3.24""" },
    { "rate" : """0.5""" },
    { "rate" : """7""" },
    { "rate" : """0.79999""" },
    { "rate" : """0.9999""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """20""" },
    { "rate" : """30""" },
    { "rate" : """17""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.8""" },
    { "rate" : """0.5""" },
    { "rate" : """4.5""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """29.99999""" },
    { "rate" : """16.17""" },
    { "rate" : """14""" },
    { "rate" : """6.5""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """0.99""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.9""" },
    { "rate" : """8""" },
    { "rate" : """0.98999""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """5""" },
    { "rate" : """11.97""" },
    { "rate" : """10""" },
    { "rate" : """29.998""" },
    { "rate" : """14.85""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """5.9""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """9.95""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """0.99999""" },
    { "rate" : """7.3975""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """13.99""" },
    { "rate" : """14""" },
    { "rate" : """18""" },
    { "rate" : """8""" },
    { "rate" : """13.99""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """29.66666""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """11.99998""" },
    { "rate" : """10""" },
    { "rate" : """9.3""" },
    { "rate" : """18""" },
    { "rate" : """28.993""" },
    { "rate" : """8""" },
    { "rate" : """3.64""" },
    { "rate" : """12""" },
    { "rate" : """12.46""" },
    { "rate" : """7.99""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """7.99999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """0.01""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.91""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.975""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.95""" },
    { "rate" : """1.99999""" },
    { "rate" : """13.5""" },
    { "rate" : """1.99899""" },
    { "rate" : """2""" },
    { "rate" : """1.9999""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """29.99998""" },
    { "rate" : """15""" },
    { "rate" : """7.39""" },
    { "rate" : """11.99""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """9.89999""" },
    { "rate" : """10""" },
    { "rate" : """1.75""" },
    { "rate" : """7""" },
    { "rate" : """1.12""" },
    { "rate" : """1.74444""" },
    { "rate" : """1.75""" },
    { "rate" : """30""" },
    { "rate" : """1.8""" },
    { "rate" : """12.46""" },
    { "rate" : """1.78""" },
    { "rate" : """1.12""" },
    { "rate" : """1.5""" },
    { "rate" : """1.8""" },
    { "rate" : """12.46""" },
    { "rate" : """1.75""" },
    { "rate" : """3.64""" },
    { "rate" : """10""" },
    { "rate" : """1.25""" },
    { "rate" : """12.46""" },
    { "rate" : """1.79999""" },
    { "rate" : """1.77989""" },
    { "rate" : """21""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """17.48""" },
    { "rate" : """16.17""" },
    { "rate" : """15""" },
    { "rate" : """12.46""" },
    { "rate" : """12.4599""" },
    { "rate" : """13.72""" },
    { "rate" : """4.99999""" },
    { "rate" : """18""" },
    { "rate" : """6.55""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """16.17""" },
    { "rate" : """6""" },
    { "rate" : """28.9989""" },
    { "rate" : """15""" },
    { "rate" : """4.7""" },
    { "rate" : """13.11""" },
    { "rate" : """5.98""" },
    { "rate" : """9.423""" },
    { "rate" : """14.9""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """3.64""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """12""" },
    { "rate" : """1.11""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """16.17""" },
    { "rate" : """10""" },
    { "rate" : """1.12""" },
    { "rate" : """3.64""" },
    { "rate" : """8""" },
    { "rate" : """7.1""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """7.55""" },
    { "rate" : """3.6""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """33""" },
    { "rate" : """10""" },
    { "rate" : """1.12""" },
    { "rate" : """10""" },
    { "rate" : """25""" },
    { "rate" : """6.55""" },
    { "rate" : """3.64""" },
    { "rate" : """9.99979""" },
    { "rate" : """0.1""" },
    { "rate" : """4.8999""" },
    { "rate" : """4.5""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """4.49999""" },
    { "rate" : """6""" },
    { "rate" : """1.1""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """20""" },
    { "rate" : """12.49""" },
    { "rate" : """8.25""" },
    { "rate" : """18.98""" },
    { "rate" : """6.55""" },
    { "rate" : """13.11""" },
    { "rate" : """30""" },
    { "rate" : """7.35""" },
    { "rate" : """2.99999""" },
    { "rate" : """9.99998""" },
    { "rate" : """8.9""" },
    { "rate" : """7.59999""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """9.9998""" },
    { "rate" : """10""" },
    { "rate" : """3.64""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """3.6""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """7""" },
    { "rate" : """13.11""" },
    { "rate" : """9.8""" },
    { "rate" : """1.12""" },
    { "rate" : """16.17""" },
    { "rate" : """1.12""" },
    { "rate" : """7.9999""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.99998""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """16.17""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.24""" },
    { "rate" : """6.55""" },
    { "rate" : """7.58""" },
    { "rate" : """2.99999""" },
    { "rate" : """8""" },
    { "rate" : """6.99""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12.46""" },
    { "rate" : """3""" },
    { "rate" : """6.55""" },
    { "rate" : """16.15""" },
    { "rate" : """8""" },
    { "rate" : """1.1""" },
    { "rate" : """10""" },
    { "rate" : """30""" },
    { "rate" : """14""" },
    { "rate" : """0.29999""" },
    { "rate" : """3""" },
    { "rate" : """2.9""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.89999""" },
    { "rate" : """3""" },
    { "rate" : """30""" },
    { "rate" : """2.99999""" },
    { "rate" : """2.99999""" },
    { "rate" : """12.49""" },
    { "rate" : """1.118""" },
    { "rate" : """6.55""" },
    { "rate" : """23.58""" },
    { "rate" : """3.64""" },
    { "rate" : """8.99999""" },
    { "rate" : """16.17""" },
    { "rate" : """7""" },
    { "rate" : """6.55""" },
    { "rate" : """13""" },
    { "rate" : """15""" },
    { "rate" : """18""" },
    { "rate" : """5""" },
    { "rate" : """10.935""" },
    { "rate" : """16.17""" },
    { "rate" : """3.64""" },
    { "rate" : """7.99""" },
    { "rate" : """30""" },
    { "rate" : """0.275""" },
    { "rate" : """13.5""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """16""" },
    { "rate" : """25""" },
    { "rate" : """3.24""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """3.25""" },
    { "rate" : """16.17""" },
    { "rate" : """12""" },
    { "rate" : """3.24""" },
    { "rate" : """10""" },
    { "rate" : """30""" },
    { "rate" : """3.64""" },
    { "rate" : """18""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """14.99999""" },
    { "rate" : """2.9""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """12.46""" },
    { "rate" : """3""" },
    { "rate" : """36""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7.5""" },
    { "rate" : """16.17""" },
    { "rate" : """1.4""" },
    { "rate" : """1""" },
    { "rate" : """1.5""" },
    { "rate" : """0.5""" },
    { "rate" : """1.47998""" },
    { "rate" : """18.98""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """22""" },
    { "rate" : """1.4995""" },
    { "rate" : """2""" },
    { "rate" : """16.17""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.24999""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """0.49999""" },
    { "rate" : """1.99999""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """1.5""" },
    { "rate" : """2""" },
    { "rate" : """1.9999""" },
    { "rate" : """5""" },
    { "rate" : """1.4859""" },
    { "rate" : """14.99999""" },
    { "rate" : """1.995""" },
    { "rate" : """4.998""" },
    { "rate" : """3""" },
    { "rate" : """0.98999""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """30""" },
    { "rate" : """2.998""" },
    { "rate" : """1""" },
    { "rate" : """4.99999""" },
    { "rate" : """28""" },
    { "rate" : """0.6""" },
    { "rate" : """0.5""" },
    { "rate" : """12.46""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """13.5""" },
    { "rate" : """4.9""" },
    { "rate" : """8""" },
    { "rate" : """18.98""" },
    { "rate" : """9.96""" },
    { "rate" : """12.46""" },
    { "rate" : """3.64""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """4.9999""" },
    { "rate" : """8""" },
    { "rate" : """3.24""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.49""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """32""" },
    { "rate" : """4.99999""" },
    { "rate" : """9""" },
    { "rate" : """4.5""" },
    { "rate" : """13.5""" },
    { "rate" : """9.95""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """3.24""" },
    { "rate" : """4.99998""" },
    { "rate" : """18.98""" },
    { "rate" : """25""" },
    { "rate" : """13.5""" },
    { "rate" : """8""" },
    { "rate" : """13""" },
    { "rate" : """12.46""" },
    { "rate" : """12.99""" },
    { "rate" : """15.925""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """4.8""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """9.99998""" },
    { "rate" : """8.99979""" },
    { "rate" : """10""" },
    { "rate" : """9.99998""" },
    { "rate" : """9.87999""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """9.9999""" },
    { "rate" : """8""" },
    { "rate" : """4.5""" },
    { "rate" : """8.99999""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """9.89""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99998""" },
    { "rate" : """30""" },
    { "rate" : """8.5""" },
    { "rate" : """12.45""" },
    { "rate" : """29.99""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.701""" },
    { "rate" : """8.9""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.49998""" },
    { "rate" : """4.99998""" },
    { "rate" : """13.5""" },
    { "rate" : """16.17""" },
    { "rate" : """8""" },
    { "rate" : """9.999""" },
    { "rate" : """9.999""" },
    { "rate" : """4.99""" },
    { "rate" : """12.5""" },
    { "rate" : """10""" },
    { "rate" : """8.99""" },
    { "rate" : """0.5""" },
    { "rate" : """4.9""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """7.99""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """10.99""" },
    { "rate" : """9.99""" },
    { "rate" : """9.5""" },
    { "rate" : """3.64""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """0.9""" },
    { "rate" : """16.17""" },
    { "rate" : """18.98""" },
    { "rate" : """3.64""" },
    { "rate" : """10.73""" },
    { "rate" : """15.14""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """9.8""" },
    { "rate" : """30""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """3.64""" },
    { "rate" : """8.955""" },
    { "rate" : """3""" },
    { "rate" : """8.99999""" },
    { "rate" : """12""" },
    { "rate" : """3.24""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """26""" },
    { "rate" : """4.5""" },
    { "rate" : """30""" },
    { "rate" : """9.4999""" },
    { "rate" : """0.5""" },
    { "rate" : """18""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """3.64""" },
    { "rate" : """16.17""" },
    { "rate" : """10.73""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """16.17""" },
    { "rate" : """13.5""" },
    { "rate" : """3.64""" },
    { "rate" : """3.24""" },
    { "rate" : """3.64""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """13.4""" },
    { "rate" : """3.24""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """4.5""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """9""" },
    { "rate" : """0.5""" },
    { "rate" : """30""" },
    { "rate" : """9.94""" },
    { "rate" : """10""" },
    { "rate" : """8.75""" },
    { "rate" : """16.17""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """3.64""" },
    { "rate" : """16.17""" },
    { "rate" : """12""" },
    { "rate" : """7.9999""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """30""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """7.72""" },
    { "rate" : """8""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """3.64""" },
    { "rate" : """7.99999""" },
    { "rate" : """10""" },
    { "rate" : """7.99999""" },
    { "rate" : """1""" },
    { "rate" : """13.5""" },
    { "rate" : """9.4""" },
    { "rate" : """30""" },
    { "rate" : """10""" },
    { "rate" : """29.99999""" },
    { "rate" : """0.5""" },
    { "rate" : """15.13""" },
    { "rate" : """3.24""" },
    { "rate" : """1.491""" },
    { "rate" : """9.99""" },
    { "rate" : """12.98""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """0.5""" },
    { "rate" : """3.24""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """7.5""" },
    { "rate" : """3.24""" },
    { "rate" : """0.5""" },
    { "rate" : """30""" },
    { "rate" : """3.64""" },
    { "rate" : """30""" },
    { "rate" : """30""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """2""" },
    { "rate" : """3.64""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """16.17""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """12.5""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """1.99999""" },
    { "rate" : """13.49""" },
    { "rate" : """10""" },
    { "rate" : """30""" },
    { "rate" : """13.5""" },
    { "rate" : """2""" },
    { "rate" : """3.64""" },
    { "rate" : """13.49""" },
    { "rate" : """1.9999""" },
    { "rate" : """7.98""" },
    { "rate" : """1.99999""" },
    { "rate" : """30""" },
    { "rate" : """3.64""" },
    { "rate" : """16.17""" },
    { "rate" : """1.999""" },
    { "rate" : """3.64""" },
    { "rate" : """1.2""" },
    { "rate" : """1.99999""" },
    { "rate" : """7.99""" },
    { "rate" : """2""" },
    { "rate" : """1.24""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """1.8795""" },
    { "rate" : """16.17""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7.9999""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """1.95""" },
    { "rate" : """12.4""" },
    { "rate" : """1.98""" },
    { "rate" : """7""" },
    { "rate" : """13.4""" },
    { "rate" : """12.46""" },
    { "rate" : """8.99999""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """6.6""" },
    { "rate" : """1""" },
    { "rate" : """9.99999""" },
    { "rate" : """11.99999""" },
    { "rate" : """1""" },
    { "rate" : """0.49""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """30""" },
    { "rate" : """12.39""" },
    { "rate" : """16.17""" },
    { "rate" : """5""" },
    { "rate" : """16""" },
    { "rate" : """9.95""" },
    { "rate" : """8.9992""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """0.6""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """8.99""" },
    { "rate" : """16.17""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """30""" },
    { "rate" : """16.17""" },
    { "rate" : """8.99999""" },
    { "rate" : """29""" },
    { "rate" : """13.4""" },
    { "rate" : """3.24""" },
    { "rate" : """16.17""" },
    { "rate" : """29.99998""" },
    { "rate" : """7""" },
    { "rate" : """9.999""" },
    { "rate" : """25""" },
    { "rate" : """0.5""" },
    { "rate" : """16""" },
    { "rate" : """29""" },
    { "rate" : """4""" },
    { "rate" : """13.39""" },
    { "rate" : """3.99999""" },
    { "rate" : """15.14""" },
    { "rate" : """0.99999""" },
    { "rate" : """4""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """16.17""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """12.46""" },
    { "rate" : """11.72""" },
    { "rate" : """7.72""" },
    { "rate" : """16.17""" },
    { "rate" : """3.24""" },
    { "rate" : """7""" },
    { "rate" : """3.64""" },
    { "rate" : """0.48""" },
    { "rate" : """8.5""" },
    { "rate" : """16.17""" },
    { "rate" : """10.73""" },
    { "rate" : """12.26""" },
    { "rate" : """0.99""" },
    { "rate" : """12.46""" },
    { "rate" : """0.9999""" },
    { "rate" : """7""" },
    { "rate" : """1.23""" },
    { "rate" : """30""" },
    { "rate" : """5.8""" },
    { "rate" : """7""" },
    { "rate" : """16.17""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """8.99999""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """4.64""" },
    { "rate" : """10""" },
    { "rate" : """1.5555""" },
    { "rate" : """5""" },
    { "rate" : """1.9""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """16.17""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.98888""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """16.17""" },
    { "rate" : """0.9999""" },
    { "rate" : """15.58""" },
    { "rate" : """54""" },
    { "rate" : """12""" },
    { "rate" : """1.9975""" },
    { "rate" : """5.9995""" },
    { "rate" : """0.479""" },
    { "rate" : """1.97""" },
    { "rate" : """1.98999""" },
    { "rate" : """1.99998""" },
    { "rate" : """1.9999""" },
    { "rate" : """5.99949""" },
    { "rate" : """1.999""" },
    { "rate" : """1.9""" },
    { "rate" : """4.999""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99""" },
    { "rate" : """7""" },
    { "rate" : """0.75""" },
    { "rate" : """0.98""" },
    { "rate" : """7""" },
    { "rate" : """12.46""" },
    { "rate" : """0.9999""" },
    { "rate" : """1""" },
    { "rate" : """7.999""" },
    { "rate" : """3.24""" },
    { "rate" : """5""" },
    { "rate" : """0.525""" },
    { "rate" : """0.5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """0.49999""" },
    { "rate" : """16.17""" },
    { "rate" : """0.5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """6.99""" },
    { "rate" : """2""" },
    { "rate" : """1.95""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.98""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """4.975""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """1.99999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """1.99999""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """12.4""" },
    { "rate" : """7.5""" },
    { "rate" : """0.99999""" },
    { "rate" : """7.77778""" },
    { "rate" : """7.9""" },
    { "rate" : """1""" },
    { "rate" : """9.959""" },
    { "rate" : """10""" },
    { "rate" : """4.9999""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4.99999""" },
    { "rate" : """1""" },
    { "rate" : """3.24""" },
    { "rate" : """2""" },
    { "rate" : """1.4""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """20""" },
    { "rate" : """15""" },
    { "rate" : """1.49""" },
    { "rate" : """17.48""" },
    { "rate" : """15.14""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """14.99999""" },
    { "rate" : """4""" },
    { "rate" : """3.99999""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3.75""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3.7""" },
    { "rate" : """3.9999""" },
    { "rate" : """6.7777""" },
    { "rate" : """0.75""" },
    { "rate" : """5""" },
    { "rate" : """18.75""" },
    { "rate" : """6""" },
    { "rate" : """15.5""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """15.14""" },
    { "rate" : """3.9999""" },
    { "rate" : """3.9""" },
    { "rate" : """5""" },
    { "rate" : """7.95""" },
    { "rate" : """3.24""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7.98""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """7.99979""" },
    { "rate" : """6.84""" },
    { "rate" : """7.89999""" },
    { "rate" : """6.49999""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """7.9999""" },
    { "rate" : """7.99999""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7.99""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.9988""" },
    { "rate" : """1""" },
    { "rate" : """8.99999""" },
    { "rate" : """1.48""" },
    { "rate" : """8.99999""" },
    { "rate" : """7.77""" },
    { "rate" : """3.99999""" },
    { "rate" : """8""" },
    { "rate" : """11.99998""" },
    { "rate" : """1.4""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """3.9""" },
    { "rate" : """0.5""" },
    { "rate" : """7.99999""" },
    { "rate" : """6.5""" },
    { "rate" : """1""" },
    { "rate" : """3.5""" },
    { "rate" : """16.17""" },
    { "rate" : """6.5""" },
    { "rate" : """0.5""" },
    { "rate" : """3.24""" },
    { "rate" : """8""" },
    { "rate" : """17.48""" },
    { "rate" : """1.25""" },
    { "rate" : """8""" },
    { "rate" : """7.99""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """7.999""" },
    { "rate" : """5""" },
    { "rate" : """7.999""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """7.9""" },
    { "rate" : """20""" },
    { "rate" : """15.14""" },
    { "rate" : """0.4""" },
    { "rate" : """15.99999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """16""" },
    { "rate" : """3.24""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """9.99""" },
    { "rate" : """1.47999""" },
    { "rate" : """6.5""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """7.96""" },
    { "rate" : """10""" },
    { "rate" : """6.14""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """3.24""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """7.9999""" },
    { "rate" : """7.989""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """9.93""" },
    { "rate" : """17.482""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """13.11""" },
    { "rate" : """0.5""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """9.99999""" },
    { "rate" : """13.11""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """9.99""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """3.24""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6.4""" },
    { "rate" : """14.5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """4.5""" },
    { "rate" : """15.14""" },
    { "rate" : """1""" },
    { "rate" : """7.99""" },
    { "rate" : """0.99999""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """7.9999""" },
    { "rate" : """3.24""" },
    { "rate" : """1.99999""" },
    { "rate" : """13.11""" },
    { "rate" : """6.5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """13.11""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """1.99""" },
    { "rate" : """2""" },
    { "rate" : """9.99999""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """15.14""" },
    { "rate" : """5""" },
    { "rate" : """9.11""" },
    { "rate" : """13.11""" },
    { "rate" : """1.99995""" },
    { "rate" : """0.001""" },
    { "rate" : """7.99""" },
    { "rate" : """13.11""" },
    { "rate" : """16.17""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """1.9999""" },
    { "rate" : """2""" },
    { "rate" : """13.11""" },
    { "rate" : """0.0002""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """3.24""" },
    { "rate" : """7""" },
    { "rate" : """12.796""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """8.8""" },
    { "rate" : """1.48999""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """6.25""" },
    { "rate" : """9.99""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """3.24""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """14.9999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """15.14""" },
    { "rate" : """4.99""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """6.5""" },
    { "rate" : """3.24""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.24""" },
    { "rate" : """8.5""" },
    { "rate" : """8""" },
    { "rate" : """18""" },
    { "rate" : """9.95""" },
    { "rate" : """15.75""" },
    { "rate" : """16""" },
    { "rate" : """16.17""" },
    { "rate" : """8""" },
    { "rate" : """9.998""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """12.26""" },
    { "rate" : """8""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """8.9""" },
    { "rate" : """1""" },
    { "rate" : """7.99999""" },
    { "rate" : """7.25""" },
    { "rate" : """12""" },
    { "rate" : """8.8""" },
    { "rate" : """15""" },
    { "rate" : """12.26""" },
    { "rate" : """5""" },
    { "rate" : """12.2""" },
    { "rate" : """8.9""" },
    { "rate" : """9.99""" },
    { "rate" : """16""" },
    { "rate" : """12""" },
    { "rate" : """15.9999""" },
    { "rate" : """10""" },
    { "rate" : """12.26""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """6.48""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """12.26""" },
    { "rate" : """12.25""" },
    { "rate" : """15.99999""" },
    { "rate" : """15.14""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """16""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """7.7""" },
    { "rate" : """3.24""" },
    { "rate" : """5""" },
    { "rate" : """10.99""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10.99""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """5""" },
    { "rate" : """4.9999""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """5""" },
    { "rate" : """15.14""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4.98999""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """10.73""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """15.14""" },
    { "rate" : """17.48""" },
    { "rate" : """10.73""" },
    { "rate" : """13.11""" },
    { "rate" : """3""" },
    { "rate" : """3.24""" },
    { "rate" : """7""" },
    { "rate" : """16.15""" },
    { "rate" : """4.9""" },
    { "rate" : """4.99989""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """3.999""" },
    { "rate" : """8""" },
    { "rate" : """7.99979""" },
    { "rate" : """5""" },
    { "rate" : """3.9999""" },
    { "rate" : """8""" },
    { "rate" : """4.98""" },
    { "rate" : """9.96""" },
    { "rate" : """4.5""" },
    { "rate" : """8.8""" },
    { "rate" : """7.99999""" },
    { "rate" : """4.99998""" },
    { "rate" : """9.95""" },
    { "rate" : """4.879""" },
    { "rate" : """1""" },
    { "rate" : """9.98""" },
    { "rate" : """6.49999""" },
    { "rate" : """4.998""" },
    { "rate" : """0.49999""" },
    { "rate" : """9.96""" },
    { "rate" : """13.72""" },
    { "rate" : """2.99999""" },
    { "rate" : """4.9999""" },
    { "rate" : """10""" },
    { "rate" : """3.98""" },
    { "rate" : """7""" },
    { "rate" : """7.999""" },
    { "rate" : """16""" },
    { "rate" : """15.998""" },
    { "rate" : """17""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """6.4""" },
    { "rate" : """8""" },
    { "rate" : """12.26""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """7.5""" },
    { "rate" : """7.99997""" },
    { "rate" : """7.99979""" },
    { "rate" : """7.98""" },
    { "rate" : """7.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """20.45""" },
    { "rate" : """9""" },
    { "rate" : """7.97999""" },
    { "rate" : """7.99999""" },
    { "rate" : """7.96""" },
    { "rate" : """7.9999""" },
    { "rate" : """5""" },
    { "rate" : """7.999""" },
    { "rate" : """4.99999""" },
    { "rate" : """7.999""" },
    { "rate" : """7.49999""" },
    { "rate" : """6.5""" },
    { "rate" : """7.98""" },
    { "rate" : """16.17""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7.9999""" },
    { "rate" : """7.9""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """16""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """7.99""" },
    { "rate" : """12.25999""" },
    { "rate" : """5""" },
    { "rate" : """7.99999""" },
    { "rate" : """5""" },
    { "rate" : """6.9""" },
    { "rate" : """20.45""" },
    { "rate" : """18.98""" },
    { "rate" : """10""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """20""" },
    { "rate" : """5.99999""" },
    { "rate" : """7.99998""" },
    { "rate" : """7.98""" },
    { "rate" : """7.9""" },
    { "rate" : """20""" },
    { "rate" : """10.73""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """16""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """4.99""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """8.8""" },
    { "rate" : """4""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """12.45999""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """2.5""" },
    { "rate" : """1""" },
    { "rate" : """17.48""" },
    { "rate" : """3""" },
    { "rate" : """9.99""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.99""" },
    { "rate" : """9.99""" },
    { "rate" : """4.99""" },
    { "rate" : """9.99""" },
    { "rate" : """1.99""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """10.73""" },
    { "rate" : """10""" },
    { "rate" : """7.8""" },
    { "rate" : """4.6""" },
    { "rate" : """16""" },
    { "rate" : """3.5""" },
    { "rate" : """7""" },
    { "rate" : """4.999""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """15.14""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """0.9""" },
    { "rate" : """0.49999""" },
    { "rate" : """6""" },
    { "rate" : """0.75""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """9.99""" },
    { "rate" : """1.5""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1.9""" },
    { "rate" : """0.9998""" },
    { "rate" : """1.9999""" },
    { "rate" : """0.99997""" },
    { "rate" : """3""" },
    { "rate" : """0.99""" },
    { "rate" : """4""" },
    { "rate" : """0.99""" },
    { "rate" : """4""" },
    { "rate" : """0.99997""" },
    { "rate" : """4.99""" },
    { "rate" : """4.5""" },
    { "rate" : """0.975""" },
    { "rate" : """0.8""" },
    { "rate" : """14""" },
    { "rate" : """3.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """12.26""" },
    { "rate" : """8.75""" },
    { "rate" : """4.96999""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """13.11""" },
    { "rate" : """12.26""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.26""" },
    { "rate" : """9.33""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """12.26""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """9.5""" },
    { "rate" : """4""" },
    { "rate" : """9.99999""" },
    { "rate" : """17.48""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """14""" },
    { "rate" : """9.11""" },
    { "rate" : """9.96""" },
    { "rate" : """1""" },
    { "rate" : """7.95""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.98""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """9.95999""" },
    { "rate" : """9.95""" },
    { "rate" : """4""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """13.11""" },
    { "rate" : """12.46""" },
    { "rate" : """4.9999""" },
    { "rate" : """9.98""" },
    { "rate" : """10.73""" },
    { "rate" : """13.11""" },
    { "rate" : """9.9""" },
    { "rate" : """4.99""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """4.99999""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """5.9""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """4.99""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """0.89999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """4.49""" },
    { "rate" : """3""" },
    { "rate" : """0.99""" },
    { "rate" : """1""" },
    { "rate" : """12.46""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """4.97""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """13.11""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """0.99""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """15.14""" },
    { "rate" : """8""" },
    { "rate" : """0.99999""" },
    { "rate" : """1.5""" },
    { "rate" : """17.48""" },
    { "rate" : """10""" },
    { "rate" : """12.26""" },
    { "rate" : """15.14""" },
    { "rate" : """1.9""" },
    { "rate" : """1.5""" },
    { "rate" : """10""" },
    { "rate" : """1.9885""" },
    { "rate" : """1.998""" },
    { "rate" : """1.9""" },
    { "rate" : """12.46""" },
    { "rate" : """1""" },
    { "rate" : """13.72""" },
    { "rate" : """1.9""" },
    { "rate" : """4""" },
    { "rate" : """9.96""" },
    { "rate" : """1.49999""" },
    { "rate" : """9.9""" },
    { "rate" : """1.89999""" },
    { "rate" : """2.99""" },
    { "rate" : """13.72""" },
    { "rate" : """1.2""" },
    { "rate" : """1.4""" },
    { "rate" : """1""" },
    { "rate" : """0.99""" },
    { "rate" : """0.99999""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """0.98999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """11.11""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """13.11""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """17.48""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """12.46""" },
    { "rate" : """2.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """12.26""" },
    { "rate" : """3.2""" },
    { "rate" : """3.2""" },
    { "rate" : """3.2""" },
    { "rate" : """9""" },
    { "rate" : """3.2""" },
    { "rate" : """3.2""" },
    { "rate" : """3.15""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """9.96""" },
    { "rate" : """3.2""" },
    { "rate" : """3.184""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """3.19998""" },
    { "rate" : """3.2""" },
    { "rate" : """25""" },
    { "rate" : """15""" },
    { "rate" : """0.8""" },
    { "rate" : """20""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """1.5""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """3.19999""" },
    { "rate" : """3.1""" },
    { "rate" : """3.1""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """3.19""" },
    { "rate" : """8.8""" },
    { "rate" : """3.18888""" },
    { "rate" : """14.99""" },
    { "rate" : """9.99""" },
    { "rate" : """9.96""" },
    { "rate" : """0.88888""" },
    { "rate" : """8.88888""" },
    { "rate" : """2.88888""" },
    { "rate" : """9.5""" },
    { "rate" : """0.88888""" },
    { "rate" : """11.11111""" },
    { "rate" : """20""" },
    { "rate" : """12""" },
    { "rate" : """11.11""" },
    { "rate" : """3.2""" },
    { "rate" : """12""" },
    { "rate" : """3.19999""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """3.2""" },
    { "rate" : """13.11""" },
    { "rate" : """17.48""" },
    { "rate" : """9.99999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """3.2""" },
    { "rate" : """3.2""" },
    { "rate" : """12""" },
    { "rate" : """3.2""" },
    { "rate" : """19""" },
    { "rate" : """3.2""" },
    { "rate" : """3.2""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """2.8""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """3.19""" },
    { "rate" : """3.2""" },
    { "rate" : """3.2""" },
    { "rate" : """3.1999""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """19.99""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """2""" },
    { "rate" : """3.2""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """3.2""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """13.11""" },
    { "rate" : """3.2""" },
    { "rate" : """11.99""" },
    { "rate" : """6""" },
    { "rate" : """10.73""" },
    { "rate" : """4""" },
    { "rate" : """12.26""" },
    { "rate" : """11.99""" },
    { "rate" : """20""" },
    { "rate" : """12""" },
    { "rate" : """3.22""" },
    { "rate" : """12""" },
    { "rate" : """3.2""" },
    { "rate" : """3.19""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """3.2""" },
    { "rate" : """11.99999""" },
    { "rate" : """6""" },
    { "rate" : """9.96""" },
    { "rate" : """2""" },
    { "rate" : """10.73""" },
    { "rate" : """6""" },
    { "rate" : """10.73""" },
    { "rate" : """2""" },
    { "rate" : """10.73""" },
    { "rate" : """9.96""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """5.99999""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """10.73""" },
    { "rate" : """13.11""" },
    { "rate" : """13.72""" },
    { "rate" : """11.94""" },
    { "rate" : """3""" },
    { "rate" : """3.2""" },
    { "rate" : """3""" },
    { "rate" : """9.96""" },
    { "rate" : """13.11""" },
    { "rate" : """11.99999""" },
    { "rate" : """2.89999""" },
    { "rate" : """9.96""" },
    { "rate" : """3.12""" },
    { "rate" : """3""" },
    { "rate" : """12.46""" },
    { "rate" : """16.17""" },
    { "rate" : """10.73""" },
    { "rate" : """13.11""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """13.11""" },
    { "rate" : """3""" },
    { "rate" : """9.96""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """5.9""" },
    { "rate" : """12.26""" },
    { "rate" : """11.99998""" },
    { "rate" : """3.15""" },
    { "rate" : """5""" },
    { "rate" : """11.9999""" },
    { "rate" : """17.48""" },
    { "rate" : """12""" },
    { "rate" : """12.26""" },
    { "rate" : """9.96""" },
    { "rate" : """9.5""" },
    { "rate" : """2.9""" },
    { "rate" : """2.9999""" },
    { "rate" : """8.5""" },
    { "rate" : """13.11""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """13""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """11.497""" },
    { "rate" : """8.8""" },
    { "rate" : """19""" },
    { "rate" : """13.11""" },
    { "rate" : """15.14""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """12.26""" },
    { "rate" : """13.11""" },
    { "rate" : """11.99999""" },
    { "rate" : """8.8""" },
    { "rate" : """1""" },
    { "rate" : """9.96""" },
    { "rate" : """15.14""" },
    { "rate" : """17.48""" },
    { "rate" : """9.96""" },
    { "rate" : """12.46""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """9.99998""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """13.72""" },
    { "rate" : """4""" },
    { "rate" : """15.14""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """12.26""" },
    { "rate" : """4""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """10.73""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """17.48""" },
    { "rate" : """13.71""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """10.73""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """10.73""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.676""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """11""" },
    { "rate" : """20""" },
    { "rate" : """17.99999""" },
    { "rate" : """13.7""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """17.48""" },
    { "rate" : """10.73""" },
    { "rate" : """10.7""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """1""" },
    { "rate" : """17.48""" },
    { "rate" : """14.5""" },
    { "rate" : """13.72""" },
    { "rate" : """9.96""" },
    { "rate" : """17.48""" },
    { "rate" : """13""" },
    { "rate" : """4""" },
    { "rate" : """0.99""" },
    { "rate" : """13.65""" },
    { "rate" : """9.96""" },
    { "rate" : """13.7""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.95""" },
    { "rate" : """6""" },
    { "rate" : """8.8""" },
    { "rate" : """13.01""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """1""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """17.48""" },
    { "rate" : """12.26""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """1""" },
    { "rate" : """13.72""" },
    { "rate" : """17.48""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """10.73""" },
    { "rate" : """13.11""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """17.47999""" },
    { "rate" : """12""" },
    { "rate" : """14.98999""" },
    { "rate" : """9.99999""" },
    { "rate" : """12.25999""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """12.26""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """12.26""" },
    { "rate" : """10.73""" },
    { "rate" : """6""" },
    { "rate" : """10.73""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """15.25""" },
    { "rate" : """6""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """24.5""" },
    { "rate" : """17""" },
    { "rate" : """6""" },
    { "rate" : """9.96""" },
    { "rate" : """9.99998""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """17.48""" },
    { "rate" : """12.26""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """17.48""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """10.73""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """16.17""" },
    { "rate" : """10.73""" },
    { "rate" : """29.96""" },
    { "rate" : """27.9""" },
    { "rate" : """9.99""" },
    { "rate" : """10.73""" },
    { "rate" : """25.48""" },
    { "rate" : """10.5""" },
    { "rate" : """9.96""" },
    { "rate" : """10.5""" },
    { "rate" : """15""" },
    { "rate" : """9.1""" },
    { "rate" : """9.95""" },
    { "rate" : """16.94""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """17.48""" },
    { "rate" : """4""" },
    { "rate" : """16.17""" },
    { "rate" : """25""" },
    { "rate" : """20""" },
    { "rate" : """12.26""" },
    { "rate" : """25""" },
    { "rate" : """17.5""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """9""" },
    { "rate" : """3.99899""" },
    { "rate" : """2.5""" },
    { "rate" : """8.8""" },
    { "rate" : """17.48""" },
    { "rate" : """8.8""" },
    { "rate" : """16.16""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """6.5""" },
    { "rate" : """16.17""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """24.999""" },
    { "rate" : """10.73""" },
    { "rate" : """13.11""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """16""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """17.48""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """13.72""" },
    { "rate" : """15""" },
    { "rate" : """18""" },
    { "rate" : """12.26""" },
    { "rate" : """8.8""" },
    { "rate" : """9.89""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """9""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """12.26""" },
    { "rate" : """12.25""" },
    { "rate" : """12.25""" },
    { "rate" : """17.5""" },
    { "rate" : """9""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """9.96""" },
    { "rate" : """25""" },
    { "rate" : """12.26""" },
    { "rate" : """10.73""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """10.73""" },
    { "rate" : """8.8""" },
    { "rate" : """12.26""" },
    { "rate" : """9.5""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """12.26""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """9.999""" },
    { "rate" : """30""" },
    { "rate" : """9.96""" },
    { "rate" : """12.26""" },
    { "rate" : """24.9""" },
    { "rate" : """2""" },
    { "rate" : """12.26""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """2""" },
    { "rate" : """14""" },
    { "rate" : """9""" },
    { "rate" : """12.26""" },
    { "rate" : """9.96""" },
    { "rate" : """13.11""" },
    { "rate" : """13.72""" },
    { "rate" : """12.26""" },
    { "rate" : """12.25999""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """12.26""" },
    { "rate" : """10.73""" },
    { "rate" : """10.8""" },
    { "rate" : """8.8""" },
    { "rate" : """12.26""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """9.7""" },
    { "rate" : """9.96""" },
    { "rate" : """12.25""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """2""" },
    { "rate" : """13.11""" },
    { "rate" : """24.99999""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """9.96""" },
    { "rate" : """0.1""" },
    { "rate" : """8.8""" },
    { "rate" : """19.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """9.9""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """20""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """2.5""" },
    { "rate" : """25""" },
    { "rate" : """10""" },
    { "rate" : """12.26""" },
    { "rate" : """0.0002""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """20""" },
    { "rate" : """9.05""" },
    { "rate" : """9.96""" },
    { "rate" : """13.10999""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """20""" },
    { "rate" : """9.96""" },
    { "rate" : """9""" },
    { "rate" : """20""" },
    { "rate" : """9.96""" },
    { "rate" : """9.99""" },
    { "rate" : """13.10998""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """19.99""" },
    { "rate" : """7.96""" },
    { "rate" : """10""" },
    { "rate" : """24.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """12.26""" },
    { "rate" : """9.96""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """25""" },
    { "rate" : """9.96""" },
    { "rate" : """9""" },
    { "rate" : """17.82""" },
    { "rate" : """1.99""" },
    { "rate" : """17""" },
    { "rate" : """14.5""" },
    { "rate" : """9.91""" },
    { "rate" : """19.91""" },
    { "rate" : """13.11""" },
    { "rate" : """20""" },
    { "rate" : """9.96""" },
    { "rate" : """19.9""" },
    { "rate" : """2""" },
    { "rate" : """25""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """25""" },
    { "rate" : """9""" },
    { "rate" : """10.73""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """22.61""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """10.73""" },
    { "rate" : """8.8""" },
    { "rate" : """9.99997""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """25""" },
    { "rate" : """8.8""" },
    { "rate" : """25""" },
    { "rate" : """2""" },
    { "rate" : """3.9""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """20""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """25""" },
    { "rate" : """20""" },
    { "rate" : """8.8""" },
    { "rate" : """1.995""" },
    { "rate" : """20""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """2""" },
    { "rate" : """25""" },
    { "rate" : """12.26""" },
    { "rate" : """13""" },
    { "rate" : """24.99999""" },
    { "rate" : """24""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """1.99998""" },
    { "rate" : """7""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """8.8""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """20""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """1.5""" },
    { "rate" : """9.96""" },
    { "rate" : """13""" },
    { "rate" : """10.73""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """17""" },
    { "rate" : """8.8""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """10.73""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """9.99998""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """9.96""" },
    { "rate" : """23""" },
    { "rate" : """9.96""" },
    { "rate" : """20""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """22.5""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """2""" },
    { "rate" : """8.8""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """10.73""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """9.96""" },
    { "rate" : """9.9""" },
    { "rate" : """9.5""" },
    { "rate" : """10""" },
    { "rate" : """1.9""" },
    { "rate" : """8.8""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """2""" },
    { "rate" : """19.99997""" },
    { "rate" : """11.5""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """2""" },
    { "rate" : """11""" },
    { "rate" : """1.9""" },
    { "rate" : """9.96""" },
    { "rate" : """2""" },
    { "rate" : """9.95""" },
    { "rate" : """8.5""" },
    { "rate" : """9.96""" },
    { "rate" : """2""" },
    { "rate" : """20""" },
    { "rate" : """60""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """7.5""" },
    { "rate" : """10.73""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """35""" },
    { "rate" : """30""" },
    { "rate" : """4""" },
    { "rate" : """9.96""" },
    { "rate" : """19""" },
    { "rate" : """30""" },
    { "rate" : """10.73""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """10.73""" },
    { "rate" : """1.95""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """10.73""" },
    { "rate" : """8.8""" },
    { "rate" : """14""" },
    { "rate" : """14.95""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """1.999""" },
    { "rate" : """1.99999""" },
    { "rate" : """8.8""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.7""" },
    { "rate" : """8.8""" },
    { "rate" : """1.99997""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """1.999""" },
    { "rate" : """13.72""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """15""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """8.5""" },
    { "rate" : """13.11""" },
    { "rate" : """13.72""" },
    { "rate" : """15""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """15""" },
    { "rate" : """13.72""" },
    { "rate" : """9.8""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """10.73""" },
    { "rate" : """13""" },
    { "rate" : """8.8""" },
    { "rate" : """1.8""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """11.73""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """13.72""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """9.8""" },
    { "rate" : """10.73""" },
    { "rate" : """9""" },
    { "rate" : """9.999""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """2.49""" },
    { "rate" : """11.5""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """1.999""" },
    { "rate" : """13.71999""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """13.72""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """15""" },
    { "rate" : """8.6""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """0.99""" },
    { "rate" : """11""" },
    { "rate" : """9.1""" },
    { "rate" : """8.8""" },
    { "rate" : """15""" },
    { "rate" : """13.11""" },
    { "rate" : """12.46""" },
    { "rate" : """15""" },
    { "rate" : """13.11""" },
    { "rate" : """14""" },
    { "rate" : """12.46""" },
    { "rate" : """9.3""" },
    { "rate" : """10""" },
    { "rate" : """9.99998""" },
    { "rate" : """8.8""" },
    { "rate" : """15""" },
    { "rate" : """8.8""" },
    { "rate" : """9.8""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """9.9999""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """4""" },
    { "rate" : """14.789""" },
    { "rate" : """12.46""" },
    { "rate" : """2.5""" },
    { "rate" : """12""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """14""" },
    { "rate" : """9.99996""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """9.5""" },
    { "rate" : """8.8""" },
    { "rate" : """9.98""" },
    { "rate" : """9.9""" },
    { "rate" : """8.8""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """9""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """13.11""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """13.03""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """9.999""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """14.99""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """9.8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12.25""" },
    { "rate" : """13.11""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """6.999""" },
    { "rate" : """1""" },
    { "rate" : """6.99""" },
    { "rate" : """6.99999""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """6.99998""" },
    { "rate" : """6.5""" },
    { "rate" : """6.99998""" },
    { "rate" : """1""" },
    { "rate" : """6.99999""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6.9""" },
    { "rate" : """6.99997""" },
    { "rate" : """6.55""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """23.58""" },
    { "rate" : """6""" },
    { "rate" : """6.99999""" },
    { "rate" : """23.58""" },
    { "rate" : """6.5""" },
    { "rate" : """6.99999""" },
    { "rate" : """23.58""" },
    { "rate" : """7.99999""" },
    { "rate" : """1.75""" },
    { "rate" : """1.75""" },
    { "rate" : """1.75""" },
    { "rate" : """1.5""" },
    { "rate" : """1.75""" },
    { "rate" : """6.4""" },
    { "rate" : """1.74""" },
    { "rate" : """1.71""" },
    { "rate" : """1.75""" },
    { "rate" : """1.74999""" },
    { "rate" : """1.73""" },
    { "rate" : """5""" },
    { "rate" : """1.6""" },
    { "rate" : """1.74999""" },
    { "rate" : """1.75""" },
    { "rate" : """1.73""" },
    { "rate" : """23.58""" },
    { "rate" : """1.75""" },
    { "rate" : """1.75""" },
    { "rate" : """9""" },
    { "rate" : """4.99999""" },
    { "rate" : """6.9""" },
    { "rate" : """1.75""" },
    { "rate" : """1.7""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1.75""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """6.99996""" },
    { "rate" : """1.74999""" },
    { "rate" : """23.58""" },
    { "rate" : """1.7499""" },
    { "rate" : """6.9998""" },
    { "rate" : """1.75""" },
    { "rate" : """1.75""" },
    { "rate" : """23.58""" },
    { "rate" : """0.49""" },
    { "rate" : """1.7""" },
    { "rate" : """1.75""" },
    { "rate" : """23""" },
    { "rate" : """6""" },
    { "rate" : """14.5""" },
    { "rate" : """3.9""" },
    { "rate" : """1.75""" },
    { "rate" : """1.75""" },
    { "rate" : """1.75""" },
    { "rate" : """1.75""" },
    { "rate" : """7""" },
    { "rate" : """1.7499""" },
    { "rate" : """6.98888""" },
    { "rate" : """1.74""" },
    { "rate" : """1.73""" },
    { "rate" : """1.74999""" },
    { "rate" : """23.58""" },
    { "rate" : """5""" },
    { "rate" : """1.525""" },
    { "rate" : """1""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """10""" },
    { "rate" : """9.9999""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """10""" },
    { "rate" : """15.14""" },
    { "rate" : """4""" },
    { "rate" : """15.13999""" },
    { "rate" : """13.72""" },
    { "rate" : """1.74999""" },
    { "rate" : """1.74""" },
    { "rate" : """9.99998""" },
    { "rate" : """1.7""" },
    { "rate" : """14.99998""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """1.74""" },
    { "rate" : """23.58""" },
    { "rate" : """4""" },
    { "rate" : """1.72999""" },
    { "rate" : """1.6""" },
    { "rate" : """15""" },
    { "rate" : """9.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """1.74""" },
    { "rate" : """4.99998""" },
    { "rate" : """1.74999""" },
    { "rate" : """1""" },
    { "rate" : """9.99998""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """2.75""" },
    { "rate" : """5""" },
    { "rate" : """1.725""" },
    { "rate" : """1.6""" },
    { "rate" : """10""" },
    { "rate" : """1.74999""" },
    { "rate" : """1""" },
    { "rate" : """1.7""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """1.7""" },
    { "rate" : """3.99""" },
    { "rate" : """3.99899""" },
    { "rate" : """13.72""" },
    { "rate" : """3.9""" },
    { "rate" : """3.98""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """11.55555""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """12.46""" },
    { "rate" : """3.9""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """3.999""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3.999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """8.9""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """3.9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """4.99999""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """4.95""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """0.9""" },
    { "rate" : """2.9""" },
    { "rate" : """4.9""" },
    { "rate" : """9.99""" },
    { "rate" : """4.99""" },
    { "rate" : """3.49""" },
    { "rate" : """3.75""" },
    { "rate" : """4""" },
    { "rate" : """8.5""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """4.9""" },
    { "rate" : """4.9""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """3.999""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """12.45""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """3.99""" },
    { "rate" : """14""" },
    { "rate" : """3.9""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """0.9988""" },
    { "rate" : """0.99899""" },
    { "rate" : """4.98888""" },
    { "rate" : """0.9988""" },
    { "rate" : """0.995""" },
    { "rate" : """0.9987""" },
    { "rate" : """4.99999""" },
    { "rate" : """0.995""" },
    { "rate" : """10""" },
    { "rate" : """7.9""" },
    { "rate" : """7.89999""" },
    { "rate" : """7.9""" },
    { "rate" : """7.8""" },
    { "rate" : """0.5""" },
    { "rate" : """0.4798""" },
    { "rate" : """0.4""" },
    { "rate" : """7""" },
    { "rate" : """7.99""" },
    { "rate" : """7.9""" },
    { "rate" : """4.99999""" },
    { "rate" : """15""" },
    { "rate" : """13.72""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """0.74999""" },
    { "rate" : """7.9""" },
    { "rate" : """0.75""" },
    { "rate" : """10""" },
    { "rate" : """0.9""" },
    { "rate" : """0.8""" },
    { "rate" : """0.79999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """4.99998""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """7.89999""" },
    { "rate" : """0.88""" },
    { "rate" : """0.975""" },
    { "rate" : """4""" },
    { "rate" : """4.3""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """7.99""" },
    { "rate" : """0.5""" },
    { "rate" : """9.99""" },
    { "rate" : """7.49999""" },
    { "rate" : """3.999""" },
    { "rate" : """7.79""" },
    { "rate" : """0.9555""" },
    { "rate" : """0.5""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """13.72""" },
    { "rate" : """0.85""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """0.49899""" },
    { "rate" : """0.74999""" },
    { "rate" : """7.5""" },
    { "rate" : """7.99""" },
    { "rate" : """0.69999""" },
    { "rate" : """4""" },
    { "rate" : """3.999""" },
    { "rate" : """9.99""" },
    { "rate" : """0.9""" },
    { "rate" : """0.75""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """4.999""" },
    { "rate" : """12.9""" },
    { "rate" : """4.99999""" },
    { "rate" : """4""" },
    { "rate" : """7.91""" },
    { "rate" : """5.99999""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """13.72""" },
    { "rate" : """4.9""" },
    { "rate" : """7.99""" },
    { "rate" : """6""" },
    { "rate" : """15.9999""" },
    { "rate" : """6""" },
    { "rate" : """16.17""" },
    { "rate" : """5""" },
    { "rate" : """18.88""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """15.55555""" },
    { "rate" : """7.89""" },
    { "rate" : """5""" },
    { "rate" : """0.69""" },
    { "rate" : """7.9555""" },
    { "rate" : """7.99""" },
    { "rate" : """16.17""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """6.9999""" },
    { "rate" : """5""" },
    { "rate" : """7.9""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """7.9""" },
    { "rate" : """7.8""" },
    { "rate" : """4.99999""" },
    { "rate" : """13""" },
    { "rate" : """0.7""" },
    { "rate" : """7.998""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """16.16""" },
    { "rate" : """7.7""" },
    { "rate" : """7""" },
    { "rate" : """4.5""" },
    { "rate" : """12""" },
    { "rate" : """0.49""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """13""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """13.11""" },
    { "rate" : """8""" },
    { "rate" : """12.999""" },
    { "rate" : """6""" },
    { "rate" : """17.48""" },
    { "rate" : """3""" },
    { "rate" : """13""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """17.48""" },
    { "rate" : """16.17""" },
    { "rate" : """6""" },
    { "rate" : """0.1""" },
    { "rate" : """12""" },
    { "rate" : """17.48""" },
    { "rate" : """12.46""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """13""" },
    { "rate" : """4.9""" },
    { "rate" : """4.9999""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """4.5""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """4.97999""" },
    { "rate" : """13""" },
    { "rate" : """4.9""" },
    { "rate" : """4.75""" },
    { "rate" : """17.48""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.83997""" },
    { "rate" : """3""" },
    { "rate" : """4.97998""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """15.14""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.998""" },
    { "rate" : """23.58""" },
    { "rate" : """4.59999""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """17.48""" },
    { "rate" : """5""" },
    { "rate" : """0.7""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """13.72""" },
    { "rate" : """6""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.985""" },
    { "rate" : """12.9999""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """4.9999""" },
    { "rate" : """1""" },
    { "rate" : """13""" },
    { "rate" : """4.8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.698""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """9.99979""" },
    { "rate" : """9.9""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """17.48""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """4.9999""" },
    { "rate" : """4.98""" },
    { "rate" : """4.9""" },
    { "rate" : """4.999""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """9.9999""" },
    { "rate" : """16.17""" },
    { "rate" : """12.46""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """9.99""" },
    { "rate" : """12.46""" },
    { "rate" : """7.99999""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """5.99999""" },
    { "rate" : """11""" },
    { "rate" : """12.46""" },
    { "rate" : """5.9999""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5.9""" },
    { "rate" : """3""" },
    { "rate" : """13""" },
    { "rate" : """13""" },
    { "rate" : """13""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """12.46""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """9.9""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """7.99999""" },
    { "rate" : """10""" },
    { "rate" : """9.999""" },
    { "rate" : """13.11""" },
    { "rate" : """12.46""" },
    { "rate" : """15""" },
    { "rate" : """9.9""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """2.999""" },
    { "rate" : """5.99""" },
    { "rate" : """15""" },
    { "rate" : """7.54""" },
    { "rate" : """6""" },
    { "rate" : """13""" },
    { "rate" : """9""" },
    { "rate" : """0.5""" },
    { "rate" : """8.8""" },
    { "rate" : """2""" },
    { "rate" : """7.9""" },
    { "rate" : """0.5""" },
    { "rate" : """12.46""" },
    { "rate" : """7.89999""" },
    { "rate" : """12.46""" },
    { "rate" : """9.99999""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """12.46""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """11.99999""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """12.46""" },
    { "rate" : """6.55""" },
    { "rate" : """8.8""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """3.99""" },
    { "rate" : """7.8""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """14.99999""" },
    { "rate" : """12.99999""" },
    { "rate" : """8""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """6.55""" },
    { "rate" : """8.55""" },
    { "rate" : """3""" },
    { "rate" : """13.11""" },
    { "rate" : """4""" },
    { "rate" : """12.46""" },
    { "rate" : """4.99999""" },
    { "rate" : """17.48""" },
    { "rate" : """4""" },
    { "rate" : """13""" },
    { "rate" : """14.44444""" },
    { "rate" : """12.99999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """14""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """12.5""" },
    { "rate" : """13""" },
    { "rate" : """11.99""" },
    { "rate" : """11.85""" },
    { "rate" : """14""" },
    { "rate" : """11.89999""" },
    { "rate" : """14.999""" },
    { "rate" : """11.84""" },
    { "rate" : """13""" },
    { "rate" : """8.8""" },
    { "rate" : """8.88888""" },
    { "rate" : """12.99""" },
    { "rate" : """8.8""" },
    { "rate" : """1""" },
    { "rate" : """13.11""" },
    { "rate" : """8.8""" },
    { "rate" : """5.99999""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """23.58""" },
    { "rate" : """8""" },
    { "rate" : """12.26""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """7.9""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """13.11""" },
    { "rate" : """6""" },
    { "rate" : """7.8995""" },
    { "rate" : """14.7999""" },
    { "rate" : """14.9999""" },
    { "rate" : """4""" },
    { "rate" : """8.8""" },
    { "rate" : """3""" },
    { "rate" : """8.8""" },
    { "rate" : """6.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """5.99""" },
    { "rate" : """12.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """6""" },
    { "rate" : """5.99998""" },
    { "rate" : """14.9999""" },
    { "rate" : """8.8""" },
    { "rate" : """11.99999""" },
    { "rate" : """14.99""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """14.9""" },
    { "rate" : """9.9""" },
    { "rate" : """6.5""" },
    { "rate" : """8.8""" },
    { "rate" : """6""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """6.99998""" },
    { "rate" : """14""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """12.26""" },
    { "rate" : """23.58""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """7.59""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """5.99979""" },
    { "rate" : """12.26""" },
    { "rate" : """5.9999""" },
    { "rate" : """15""" },
    { "rate" : """9.2""" },
    { "rate" : """12.26""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """0.49999""" },
    { "rate" : """5.99999""" },
    { "rate" : """11.99999""" },
    { "rate" : """9""" },
    { "rate" : """5.999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6.5""" },
    { "rate" : """5.5""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """3.99999""" },
    { "rate" : """4""" },
    { "rate" : """3.99979""" },
    { "rate" : """13.11""" },
    { "rate" : """4""" },
    { "rate" : """3.99999""" },
    { "rate" : """6.4""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """6.99998""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """13.72""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """7.2""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """5.8""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """5.8""" },
    { "rate" : """7""" },
    { "rate" : """8.8""" },
    { "rate" : """0.4""" },
    { "rate" : """0.45999""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7.55979""" },
    { "rate" : """8.8""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """15.14""" },
    { "rate" : """13.72""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """2.49""" },
    { "rate" : """12.26""" },
    { "rate" : """13.72""" },
    { "rate" : """2.48""" },
    { "rate" : """2.4""" },
    { "rate" : """7.6""" },
    { "rate" : """2.45""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """3.33""" },
    { "rate" : """4.499""" },
    { "rate" : """10""" },
    { "rate" : """10.73""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """3.99""" },
    { "rate" : """9.99""" },
    { "rate" : """3.99999""" },
    { "rate" : """11.99""" },
    { "rate" : """10.72""" },
    { "rate" : """8.8""" },
    { "rate" : """12.26""" },
    { "rate" : """12""" },
    { "rate" : """10.73""" },
    { "rate" : """5.9""" },
    { "rate" : """2.337""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """4.48""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """12.26""" },
    { "rate" : """12.8""" },
    { "rate" : """23.58""" },
    { "rate" : """13.11""" },
    { "rate" : """13.9""" },
    { "rate" : """4""" },
    { "rate" : """13.11""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """13.1""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """3.99899""" },
    { "rate" : """13.719""" },
    { "rate" : """15""" },
    { "rate" : """8.8""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """7.99""" },
    { "rate" : """5.99999""" },
    { "rate" : """10.73""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """5.95""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """13.11""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """13.11111""" },
    { "rate" : """12""" },
    { "rate" : """7.79999""" },
    { "rate" : """3.5""" },
    { "rate" : """5.999""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """11.99""" },
    { "rate" : """9.9""" },
    { "rate" : """13.1""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """2.9""" },
    { "rate" : """12""" },
    { "rate" : """13.55555""" },
    { "rate" : """9.9""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """9.46""" },
    { "rate" : """6.99999""" },
    { "rate" : """13.72""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """3.99999""" },
    { "rate" : """10""" },
    { "rate" : """17.48""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """7.78""" },
    { "rate" : """6""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.99999""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """4.99999""" },
    { "rate" : """6""" },
    { "rate" : """12.46""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """5.99999""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """3.99978""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """9.999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """9.99""" },
    { "rate" : """9.99""" },
    { "rate" : """12.26""" },
    { "rate" : """0.4""" },
    { "rate" : """4""" },
    { "rate" : """11""" },
    { "rate" : """9.9""" },
    { "rate" : """9.9""" },
    { "rate" : """8.9""" },
    { "rate" : """12""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """9.99999""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """0.4""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """11""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """5.99""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """13.11""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """14""" },
    { "rate" : """13.72""" },
    { "rate" : """4""" },
    { "rate" : """3.9999""" },
    { "rate" : """11.989""" },
    { "rate" : """3.99""" },
    { "rate" : """12""" },
    { "rate" : """11.46""" },
    { "rate" : """11.8""" },
    { "rate" : """9.99999""" },
    { "rate" : """9""" },
    { "rate" : """11.99999""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """3.9999""" },
    { "rate" : """5""" },
    { "rate" : """3.95""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """7.9""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """11.9""" },
    { "rate" : """4.99""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """6""" },
    { "rate" : """2.99""" },
    { "rate" : """6""" },
    { "rate" : """4.5""" },
    { "rate" : """13.11""" },
    { "rate" : """11""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """3.99999""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """9.96""" },
    { "rate" : """23.58""" },
    { "rate" : """5.5""" },
    { "rate" : """2.99""" },
    { "rate" : """13""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """9.96""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """2.9""" },
    { "rate" : """0.5""" },
    { "rate" : """4.8""" },
    { "rate" : """11""" },
    { "rate" : """12""" },
    { "rate" : """23.58""" },
    { "rate" : """11""" },
    { "rate" : """12.46""" },
    { "rate" : """12""" },
    { "rate" : """3.99999""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """2.99969""" },
    { "rate" : """4""" },
    { "rate" : """4.99979""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """3""" },
    { "rate" : """0.9999""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """0.998""" },
    { "rate" : """13""" },
    { "rate" : """0.997""" },
    { "rate" : """0.87""" },
    { "rate" : """0.5""" },
    { "rate" : """0.86999""" },
    { "rate" : """0.89979""" },
    { "rate" : """2.89999""" },
    { "rate" : """2.9""" },
    { "rate" : """0.879""" },
    { "rate" : """23.58""" },
    { "rate" : """0.75""" },
    { "rate" : """6""" },
    { "rate" : """11.99999""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """13.11""" },
    { "rate" : """6""" },
    { "rate" : """9.96""" },
    { "rate" : """14""" },
    { "rate" : """2.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """13.72""" },
    { "rate" : """15""" },
    { "rate" : """14""" },
    { "rate" : """6""" },
    { "rate" : """20""" },
    { "rate" : """7.5""" },
    { "rate" : """9.95""" },
    { "rate" : """4.99999""" },
    { "rate" : """23.58""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """14""" },
    { "rate" : """13.9999""" },
    { "rate" : """0.4""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """5.99999""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """0.4""" },
    { "rate" : """9.48""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """13.999""" },
    { "rate" : """13.33333""" },
    { "rate" : """14.5""" },
    { "rate" : """3""" },
    { "rate" : """13.9""" },
    { "rate" : """13.89999""" },
    { "rate" : """1""" },
    { "rate" : """9.89999""" },
    { "rate" : """10.73""" },
    { "rate" : """1""" },
    { "rate" : """9.96""" },
    { "rate" : """12.46""" },
    { "rate" : """14""" },
    { "rate" : """23.58""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """20""" },
    { "rate" : """9.96""" },
    { "rate" : """6""" },
    { "rate" : """13.72""" },
    { "rate" : """9""" },
    { "rate" : """23.57""" },
    { "rate" : """13.72""" },
    { "rate" : """9.9""" },
    { "rate" : """23.57""" },
    { "rate" : """19.9999""" },
    { "rate" : """10""" },
    { "rate" : """0.39""" },
    { "rate" : """9.96""" },
    { "rate" : """12.26""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """9.99999""" },
    { "rate" : """15""" },
    { "rate" : """8.96""" },
    { "rate" : """13.11""" },
    { "rate" : """0.39""" },
    { "rate" : """14.99999""" },
    { "rate" : """18.98""" },
    { "rate" : """0.49931""" },
    { "rate" : """8.8""" },
    { "rate" : """12""" },
    { "rate" : """8.8""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """8.8""" },
    { "rate" : """15""" },
    { "rate" : """0.49""" },
    { "rate" : """0.38999""" },
    { "rate" : """0.3659""" },
    { "rate" : """5.89999""" },
    { "rate" : """8.8""" },
    { "rate" : """12""" },
    { "rate" : """13.11""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """12.26""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """12.26""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """11""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """2.99""" },
    { "rate" : """5""" },
    { "rate" : """11.99""" },
    { "rate" : """12.1""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """8.79""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """4.95""" },
    { "rate" : """4.9999""" },
    { "rate" : """12""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """11.99999""" },
    { "rate" : """4.9""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """16.17""" },
    { "rate" : """9""" },
    { "rate" : """18.98""" },
    { "rate" : """12""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """13.72""" },
    { "rate" : """1""" },
    { "rate" : """6.6""" },
    { "rate" : """9""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """13""" },
    { "rate" : """7.77777""" },
    { "rate" : """12""" },
    { "rate" : """12.99999""" },
    { "rate" : """10.5""" },
    { "rate" : """9.999""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """12.72""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """11.11111""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """8.99999""" },
    { "rate" : """12.46""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5.9""" },
    { "rate" : """10""" },
    { "rate" : """6.55""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """6.55""" },
    { "rate" : """8.8""" },
    { "rate" : """18.98""" },
    { "rate" : """2""" },
    { "rate" : """6.49""" },
    { "rate" : """17.48""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """23.58""" },
    { "rate" : """11.5""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """9.9""" },
    { "rate" : """8.9""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """9.72""" },
    { "rate" : """9.9""" },
    { "rate" : """11.99""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """9.96""" },
    { "rate" : """9.95""" },
    { "rate" : """11.99999""" },
    { "rate" : """23.57999""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """23.58""" },
    { "rate" : """4""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """9.959""" },
    { "rate" : """18.98""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """13.72""" },
    { "rate" : """15.14""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """12.169""" },
    { "rate" : """20""" },
    { "rate" : """9.96""" },
    { "rate" : """9.9""" },
    { "rate" : """16.17""" },
    { "rate" : """2.99985""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """5.5""" },
    { "rate" : """6""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """13.72""" },
    { "rate" : """9.96""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """3.89""" },
    { "rate" : """11""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """0.987""" },
    { "rate" : """1""" },
    { "rate" : """8.799""" },
    { "rate" : """0.998""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """11.999""" },
    { "rate" : """11.89""" },
    { "rate" : """23.58""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """7.9""" },
    { "rate" : """0.97999""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """0.9999""" },
    { "rate" : """9.96""" },
    { "rate" : """0.99979""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """11.99""" },
    { "rate" : """2.5""" },
    { "rate" : """9.96""" },
    { "rate" : """9.8""" },
    { "rate" : """23.58""" },
    { "rate" : """9.96""" },
    { "rate" : """8.999""" },
    { "rate" : """8.8""" },
    { "rate" : """8.79""" },
    { "rate" : """7""" },
    { "rate" : """9.5""" },
    { "rate" : """9.96""" },
    { "rate" : """12.44""" },
    { "rate" : """23.58""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9.94""" },
    { "rate" : """2.5""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """2.5""" },
    { "rate" : """13.69""" },
    { "rate" : """9""" },
    { "rate" : """23.58""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """0.35""" },
    { "rate" : """13""" },
    { "rate" : """0.4""" },
    { "rate" : """0.43979""" },
    { "rate" : """0.93979""" },
    { "rate" : """12.99999""" },
    { "rate" : """1""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """9.5""" },
    { "rate" : """0.42""" },
    { "rate" : """0.4""" },
    { "rate" : """0.35""" },
    { "rate" : """12.46""" },
    { "rate" : """9.96""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """0.419""" },
    { "rate" : """1""" },
    { "rate" : """15.14""" },
    { "rate" : """2.5""" },
    { "rate" : """1""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """4.9""" },
    { "rate" : """4.8999""" },
    { "rate" : """4.1""" },
    { "rate" : """3.99""" },
    { "rate" : """23.58""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """9.99979""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2.5""" },
    { "rate" : """0.9998""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99""" },
    { "rate" : """0.9999""" },
    { "rate" : """1""" },
    { "rate" : """0.1""" },
    { "rate" : """0.4""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.999""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """9.96""" },
    { "rate" : """1""" },
    { "rate" : """0.99""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """12.26""" },
    { "rate" : """4.9""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """11.99999""" },
    { "rate" : """12.46""" },
    { "rate" : """1""" },
    { "rate" : """12.26""" },
    { "rate" : """4.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """23""" },
    { "rate" : """1""" },
    { "rate" : """0.4""" },
    { "rate" : """0.4""" },
    { "rate" : """16.17""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """9.96""" },
    { "rate" : """0.99999""" },
    { "rate" : """15""" },
    { "rate" : """0.99999""" },
    { "rate" : """12""" },
    { "rate" : """2.5""" },
    { "rate" : """13""" },
    { "rate" : """0.45""" },
    { "rate" : """0.3999""" },
    { "rate" : """23.58""" },
    { "rate" : """0.4""" },
    { "rate" : """0.97223""" },
    { "rate" : """0.97223""" },
    { "rate" : """5""" },
    { "rate" : """0.45""" },
    { "rate" : """1""" },
    { "rate" : """0.48""" },
    { "rate" : """0.9""" },
    { "rate" : """1""" },
    { "rate" : """0.999""" },
    { "rate" : """0.43""" },
    { "rate" : """0.9""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """0.99""" },
    { "rate" : """23.58""" },
    { "rate" : """0.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """7.89999""" },
    { "rate" : """2.99998""" },
    { "rate" : """1""" },
    { "rate" : """9.95999""" },
    { "rate" : """7.99999""" },
    { "rate" : """1""" },
    { "rate" : """7.8998""" },
    { "rate" : """7.99999""" },
    { "rate" : """7.9""" },
    { "rate" : """7.99998""" },
    { "rate" : """2.5""" },
    { "rate" : """7.99799""" },
    { "rate" : """0.9""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.9""" },
    { "rate" : """7.9""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """7.95""" },
    { "rate" : """7.9""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """7.9999""" },
    { "rate" : """9.96""" },
    { "rate" : """7.935""" },
    { "rate" : """8""" },
    { "rate" : """7.9999""" },
    { "rate" : """16.17""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """7.75""" },
    { "rate" : """2.5""" },
    { "rate" : """7.9""" },
    { "rate" : """7.999""" },
    { "rate" : """0.4999""" },
    { "rate" : """0.975""" },
    { "rate" : """0.4999""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """2.49""" },
    { "rate" : """7.9899""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """0.5""" },
    { "rate" : """5.889""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.9999""" },
    { "rate" : """7.8""" },
    { "rate" : """5""" },
    { "rate" : """9.93999""" },
    { "rate" : """0.89999""" },
    { "rate" : """0.8""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.85""" },
    { "rate" : """7.8""" },
    { "rate" : """0.5""" },
    { "rate" : """2.5""" },
    { "rate" : """0.3999""" },
    { "rate" : """0.49""" },
    { "rate" : """7.9""" },
    { "rate" : """12""" },
    { "rate" : """0.4""" },
    { "rate" : """0.39""" },
    { "rate" : """0.38999""" },
    { "rate" : """7.8999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.475""" },
    { "rate" : """1""" },
    { "rate" : """0.99""" },
    { "rate" : """0.49""" },
    { "rate" : """0.48888""" },
    { "rate" : """0.888""" },
    { "rate" : """0.888""" },
    { "rate" : """0.8499""" },
    { "rate" : """0.39999""" },
    { "rate" : """0.7999""" },
    { "rate" : """0.38989""" },
    { "rate" : """0.3999""" },
    { "rate" : """8""" },
    { "rate" : """13.72""" },
    { "rate" : """9.96""" },
    { "rate" : """2.5""" },
    { "rate" : """9.96""" },
    { "rate" : """0.38""" },
    { "rate" : """0.77777""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """18.98""" },
    { "rate" : """1""" },
    { "rate" : """7.99999""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """13.72""" },
    { "rate" : """0.9975""" },
    { "rate" : """9.96""" },
    { "rate" : """1""" },
    { "rate" : """0.44""" },
    { "rate" : """7.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """0.77777""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """11.11111""" },
    { "rate" : """1""" },
    { "rate" : """0.98999""" },
    { "rate" : """0.99""" },
    { "rate" : """7.989""" },
    { "rate" : """0.97""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.475""" },
    { "rate" : """0.425""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """0.97223""" },
    { "rate" : """0.9999""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """8.798""" },
    { "rate" : """2.4999""" },
    { "rate" : """4.99999""" },
    { "rate" : """7.9""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """0.999""" },
    { "rate" : """14""" },
    { "rate" : """1""" },
    { "rate" : """18.98""" },
    { "rate" : """13.99999""" },
    { "rate" : """0.75""" },
    { "rate" : """12""" },
    { "rate" : """8.8""" },
    { "rate" : """14""" },
    { "rate" : """4""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """4.9""" },
    { "rate" : """13.11""" },
    { "rate" : """2.5""" },
    { "rate" : """1""" },
    { "rate" : """16.17""" },
    { "rate" : """12""" },
    { "rate" : """3.64""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """12.5""" },
    { "rate" : """5""" },
    { "rate" : """0.49999""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """18.98""" },
    { "rate" : """4.99998""" },
    { "rate" : """12.46""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """13""" },
    { "rate" : """12.99""" },
    { "rate" : """11.99""" },
    { "rate" : """0.99""" },
    { "rate" : """12.26""" },
    { "rate" : """4.9999""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """11.11111""" },
    { "rate" : """4.99999""" },
    { "rate" : """13""" },
    { "rate" : """1""" },
    { "rate" : """9.96""" },
    { "rate" : """14""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """4.46""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """18.98""" },
    { "rate" : """9.96""" },
    { "rate" : """11""" },
    { "rate" : """0.99979""" },
    { "rate" : """12""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """2.5""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """0.9987""" },
    { "rate" : """11.11111""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """10.73""" },
    { "rate" : """12.26""" },
    { "rate" : """13.72""" },
    { "rate" : """10.73""" },
    { "rate" : """9.96""" },
    { "rate" : """12.46""" },
    { "rate" : """18.98""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """6""" },
    { "rate" : """9.96""" },
    { "rate" : """12""" },
    { "rate" : """0.2999""" },
    { "rate" : """0.9999""" },
    { "rate" : """10""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.44799""" },
    { "rate" : """0.33""" },
    { "rate" : """9.96""" },
    { "rate" : """6.55""" },
    { "rate" : """0.33333""" },
    { "rate" : """10.73001""" },
    { "rate" : """9.5""" },
    { "rate" : """9""" },
    { "rate" : """8.7979""" },
    { "rate" : """4""" },
    { "rate" : """5.9998""" },
    { "rate" : """6""" },
    { "rate" : """9.96""" },
    { "rate" : """0.99999""" },
    { "rate" : """10""" },
    { "rate" : """9.94""" },
    { "rate" : """9""" },
    { "rate" : """0.7""" },
    { "rate" : """2.48""" },
    { "rate" : """14.99999""" },
    { "rate" : """0.4""" },
    { "rate" : """9.5""" },
    { "rate" : """9.49999""" },
    { "rate" : """0.33""" },
    { "rate" : """10""" },
    { "rate" : """0.888""" },
    { "rate" : """0.38""" },
    { "rate" : """9.5""" },
    { "rate" : """9.5""" },
    { "rate" : """15""" },
    { "rate" : """0.3""" },
    { "rate" : """7""" },
    { "rate" : """2.49999""" },
    { "rate" : """2.5""" },
    { "rate" : """8""" },
    { "rate" : """2.49999""" },
    { "rate" : """9.5""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """12""" },
    { "rate" : """9.95""" },
    { "rate" : """2.5""" },
    { "rate" : """9""" },
    { "rate" : """2.5""" },
    { "rate" : """13""" },
    { "rate" : """12""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """12.46""" },
    { "rate" : """2.5""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """2.49999""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """12.46""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """2.4""" },
    { "rate" : """8""" },
    { "rate" : """2.49999""" },
    { "rate" : """5""" },
    { "rate" : """2.48""" },
    { "rate" : """9.4""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """0.999""" },
    { "rate" : """8""" },
    { "rate" : """9.5""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """11.89""" },
    { "rate" : """2.25""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """0.99999""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """0.987""" },
    { "rate" : """12""" },
    { "rate" : """11.99""" },
    { "rate" : """12""" },
    { "rate" : """2.49995""" },
    { "rate" : """11.989""" },
    { "rate" : """5""" },
    { "rate" : """0.99""" },
    { "rate" : """12""" },
    { "rate" : """0.9""" },
    { "rate" : """9.96""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.98""" },
    { "rate" : """12""" },
    { "rate" : """0.9799""" },
    { "rate" : """0.995""" },
    { "rate" : """0.89999""" },
    { "rate" : """12""" },
    { "rate" : """0.97""" },
    { "rate" : """12""" },
    { "rate" : """0.9""" },
    { "rate" : """12""" },
    { "rate" : """12.46""" },
    { "rate" : """13.72""" },
    { "rate" : """0.49""" },
    { "rate" : """9.96""" },
    { "rate" : """0.6969""" },
    { "rate" : """2.5""" },
    { "rate" : """15""" },
    { "rate" : """0.99999""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """9.96""" },
    { "rate" : """2.5""" },
    { "rate" : """11.99999""" },
    { "rate" : """2.5""" },
    { "rate" : """9.5""" },
    { "rate" : """0.9995""" },
    { "rate" : """13""" },
    { "rate" : """0.999""" },
    { "rate" : """0.49""" },
    { "rate" : """0.48""" },
    { "rate" : """2.5""" },
    { "rate" : """9.96""" },
    { "rate" : """0.49""" },
    { "rate" : """8""" },
    { "rate" : """0.48979""" },
    { "rate" : """2.5""" },
    { "rate" : """12""" },
    { "rate" : """11.5""" },
    { "rate" : """0.999""" },
    { "rate" : """15""" },
    { "rate" : """0.99999""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """11.9""" },
    { "rate" : """0.95""" },
    { "rate" : """0.3""" },
    { "rate" : """9.5""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """14""" },
    { "rate" : """9.96""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """9.96""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """14.5""" },
    { "rate" : """13""" },
    { "rate" : """15""" },
    { "rate" : """2.5""" },
    { "rate" : """11""" },
    { "rate" : """12""" },
    { "rate" : """13.72""" },
    { "rate" : """2.5""" },
    { "rate" : """13.11""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10.73""" },
    { "rate" : """12.26""" },
    { "rate" : """0.8""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.999""" },
    { "rate" : """12.46""" },
    { "rate" : """23.58""" },
    { "rate" : """11.99999""" },
    { "rate" : """11.99""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """0.99""" },
    { "rate" : """1""" },
    { "rate" : """6.55""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """11.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """1""" },
    { "rate" : """2.49""" },
    { "rate" : """12.46""" },
    { "rate" : """0.32998""" },
    { "rate" : """0.32""" },
    { "rate" : """0.91""" },
    { "rate" : """0.5""" },
    { "rate" : """1""" },
    { "rate" : """0.5""" },
    { "rate" : """0.33""" },
    { "rate" : """9.5""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """0.32""" },
    { "rate" : """13.7""" },
    { "rate" : """0.27""" },
    { "rate" : """1""" },
    { "rate" : """11.99998""" },
    { "rate" : """13.69999""" },
    { "rate" : """5.78999""" },
    { "rate" : """7.9""" },
    { "rate" : """1""" },
    { "rate" : """0.3""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """12.46""" },
    { "rate" : """0.99979""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """0.31""" },
    { "rate" : """11""" },
    { "rate" : """5.79""" },
    { "rate" : """11""" },
    { "rate" : """5.5""" },
    { "rate" : """5.779""" },
    { "rate" : """0.9999""" },
    { "rate" : """11.999""" },
    { "rate" : """1""" },
    { "rate" : """0.888""" },
    { "rate" : """11.11111""" },
    { "rate" : """5.5""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """5.79""" },
    { "rate" : """12""" },
    { "rate" : """14.99""" },
    { "rate" : """8.88888""" },
    { "rate" : """0.99999""" },
    { "rate" : """2.49999""" },
    { "rate" : """9""" },
    { "rate" : """4.99999""" },
    { "rate" : """11.11111""" },
    { "rate" : """2.499""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """9.9599""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5.79""" },
    { "rate" : """9.96""" },
    { "rate" : """5.6789""" },
    { "rate" : """8""" },
    { "rate" : """13.72""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """0.5""" },
    { "rate" : """4""" },
    { "rate" : """10.73""" },
    { "rate" : """1""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """10.73""" },
    { "rate" : """9.5""" },
    { "rate" : """2.5""" },
    { "rate" : """1""" },
    { "rate" : """11.99999""" },
    { "rate" : """5""" },
    { "rate" : """0.8""" },
    { "rate" : """13""" },
    { "rate" : """9.96""" },
    { "rate" : """6""" },
    { "rate" : """0.3""" },
    { "rate" : """2.49""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """11""" },
    { "rate" : """13.11""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """11""" },
    { "rate" : """12""" },
    { "rate" : """12.46""" },
    { "rate" : """11""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """0.9""" },
    { "rate" : """5.79""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """9.5""" },
    { "rate" : """6""" },
    { "rate" : """0.99999""" },
    { "rate" : """10""" },
    { "rate" : """0.973""" },
    { "rate" : """5""" },
    { "rate" : """0.98999""" },
    { "rate" : """0.29999""" },
    { "rate" : """9.99999""" },
    { "rate" : """13.11""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """0.7""" },
    { "rate" : """13.72""" },
    { "rate" : """12.46""" },
    { "rate" : """0.98""" },
    { "rate" : """9""" },
    { "rate" : """18.9""" },
    { "rate" : """13.11""" },
    { "rate" : """0.5""" },
    { "rate" : """0.99""" },
    { "rate" : """0.9992""" },
    { "rate" : """0.85""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """2.3""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """2.5""" },
    { "rate" : """0.9999""" },
    { "rate" : """12""" },
    { "rate" : """1.95""" },
    { "rate" : """9.5""" },
    { "rate" : """1.5""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """0.5""" },
    { "rate" : """1.4888""" },
    { "rate" : """0.25""" },
    { "rate" : """9.96""" },
    { "rate" : """13.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """9""" },
    { "rate" : """2.49999""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """11.99997""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """4.99""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.95999""" },
    { "rate" : """1.5""" },
    { "rate" : """1""" },
    { "rate" : """11.5""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """0.999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1.49999""" },
    { "rate" : """3.99888""" },
    { "rate" : """9.4""" },
    { "rate" : """7.99""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """9""" },
    { "rate" : """1.899""" },
    { "rate" : """1.5""" },
    { "rate" : """0.5""" },
    { "rate" : """14.89""" },
    { "rate" : """4.5""" },
    { "rate" : """2.47""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """4.999""" },
    { "rate" : """23.58""" },
    { "rate" : """12""" },
    { "rate" : """23""" },
    { "rate" : """12""" },
    { "rate" : """8.5""" },
    { "rate" : """12""" },
    { "rate" : """4.9""" },
    { "rate" : """9.96""" },
    { "rate" : """11""" },
    { "rate" : """0.98999""" },
    { "rate" : """9.96""" },
    { "rate" : """0.96999""" },
    { "rate" : """0.99979""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """11.11111""" },
    { "rate" : """11.11""" },
    { "rate" : """0.44444""" },
    { "rate" : """10.73""" },
    { "rate" : """8.88888""" },
    { "rate" : """0.99999""" },
    { "rate" : """14.72""" },
    { "rate" : """23.58""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """9.5""" },
    { "rate" : """10""" },
    { "rate" : """13.7""" },
    { "rate" : """4.9999""" },
    { "rate" : """23.58""" },
    { "rate" : """15""" },
    { "rate" : """13.58""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """9.4""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """0.99""" },
    { "rate" : """0.98""" },
    { "rate" : """8.8""" },
    { "rate" : """11.99""" },
    { "rate" : """35""" },
    { "rate" : """8""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """0.9999""" },
    { "rate" : """9.96""" },
    { "rate" : """9""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """23.58""" },
    { "rate" : """13""" },
    { "rate" : """12""" },
    { "rate" : """0.99999""" },
    { "rate" : """12""" },
    { "rate" : """0.9999""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.973""" },
    { "rate" : """11.9""" },
    { "rate" : """5""" },
    { "rate" : """0.99898""" },
    { "rate" : """5""" },
    { "rate" : """0.989""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """0.99989""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """0.99""" },
    { "rate" : """9.5""" },
    { "rate" : """12.25""" },
    { "rate" : """4.5""" },
    { "rate" : """4""" },
    { "rate" : """9.5""" },
    { "rate" : """13.5""" },
    { "rate" : """8.9""" },
    { "rate" : """5.9""" },
    { "rate" : """0.99""" },
    { "rate" : """0.999""" },
    { "rate" : """9.96""" },
    { "rate" : """13.61""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """0.998""" },
    { "rate" : """9""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """3.9""" },
    { "rate" : """2""" },
    { "rate" : """0.9""" },
    { "rate" : """1.5""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """1.987""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12.259""" },
    { "rate" : """1.9999""" },
    { "rate" : """9.96""" },
    { "rate" : """13.72""" },
    { "rate" : """13.11""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """8""" },
    { "rate" : """18.98""" },
    { "rate" : """9.9""" },
    { "rate" : """10.99""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """0.9""" },
    { "rate" : """9""" },
    { "rate" : """1.49""" },
    { "rate" : """8""" },
    { "rate" : """0.73989""" },
    { "rate" : """9.96""" },
    { "rate" : """13""" },
    { "rate" : """12""" },
    { "rate" : """1.74""" },
    { "rate" : """1.75""" },
    { "rate" : """11.9""" },
    { "rate" : """1.73""" },
    { "rate" : """1.74999""" },
    { "rate" : """1.74979""" },
    { "rate" : """1.75""" },
    { "rate" : """1.75""" },
    { "rate" : """23""" },
    { "rate" : """1.75""" },
    { "rate" : """1.7""" },
    { "rate" : """1.75""" },
    { "rate" : """1.75""" },
    { "rate" : """1.75""" },
    { "rate" : """1.74999""" },
    { "rate" : """1.741""" },
    { "rate" : """1.75""" },
    { "rate" : """1.7499""" },
    { "rate" : """9.96""" },
    { "rate" : """1.7499""" },
    { "rate" : """1.74""" },
    { "rate" : """1.75""" },
    { "rate" : """1.75""" },
    { "rate" : """1.75""" },
    { "rate" : """1.72""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """3""" },
    { "rate" : """12.46""" },
    { "rate" : """2.5""" },
    { "rate" : """1.75""" },
    { "rate" : """14.99""" },
    { "rate" : """1.75""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """0.5""" },
    { "rate" : """1""" },
    { "rate" : """0.975""" },
    { "rate" : """2.5""" },
    { "rate" : """23.58""" },
    { "rate" : """1.99979""" },
    { "rate" : """1.74989""" },
    { "rate" : """10""" },
    { "rate" : """0.75""" },
    { "rate" : """6""" },
    { "rate" : """1.7""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """1.74999""" },
    { "rate" : """0.73999""" },
    { "rate" : """1.74""" },
    { "rate" : """1.525""" },
    { "rate" : """4.5""" },
    { "rate" : """1.74""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """1.489""" },
    { "rate" : """1""" },
    { "rate" : """0.73""" },
    { "rate" : """0.5""" },
    { "rate" : """1.7""" },
    { "rate" : """1.74""" },
    { "rate" : """0.2998""" },
    { "rate" : """0.28""" },
    { "rate" : """9.96""" },
    { "rate" : """12.26""" },
    { "rate" : """2.5""" },
    { "rate" : """0.27999""" },
    { "rate" : """9.96""" },
    { "rate" : """0.31999""" },
    { "rate" : """16.17""" },
    { "rate" : """8""" },
    { "rate" : """16.17""" },
    { "rate" : """9.96""" },
    { "rate" : """0.27777""" },
    { "rate" : """15""" },
    { "rate" : """12.4""" },
    { "rate" : """0.99999""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """2.49""" },
    { "rate" : """14.9""" },
    { "rate" : """9.9979""" },
    { "rate" : """0.97""" },
    { "rate" : """9.96""" },
    { "rate" : """0.26999""" },
    { "rate" : """8""" },
    { "rate" : """11""" },
    { "rate" : """13""" },
    { "rate" : """9.99""" },
    { "rate" : """0.49""" },
    { "rate" : """4.99""" },
    { "rate" : """7.9""" },
    { "rate" : """10.73""" },
    { "rate" : """11""" },
    { "rate" : """10.73""" },
    { "rate" : """8.8""" },
    { "rate" : """20""" },
    { "rate" : """12.26""" },
    { "rate" : """9.96""" },
    { "rate" : """0.99999""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """12.99999""" },
    { "rate" : """10.99999""" },
    { "rate" : """14.8""" },
    { "rate" : """9.96""" },
    { "rate" : """2.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """5""" },
    { "rate" : """0.288""" },
    { "rate" : """13.11""" },
    { "rate" : """0.88""" },
    { "rate" : """0.288""" },
    { "rate" : """9.95""" },
    { "rate" : """2""" },
    { "rate" : """4.99979""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """13.11""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """14.9""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """3.99998""" },
    { "rate" : """1.5""" },
    { "rate" : """2""" },
    { "rate" : """1.999""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """1.9975""" },
    { "rate" : """2""" },
    { "rate" : """1.999""" },
    { "rate" : """1.9998""" },
    { "rate" : """0.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.99999""" },
    { "rate" : """0.48""" },
    { "rate" : """1.5""" },
    { "rate" : """0.3""" },
    { "rate" : """0.4""" },
    { "rate" : """11""" },
    { "rate" : """2""" },
    { "rate" : """0.44999""" },
    { "rate" : """1.98999""" },
    { "rate" : """15""" },
    { "rate" : """1.9""" },
    { "rate" : """13.5""" },
    { "rate" : """1.888""" },
    { "rate" : """0.9998""" },
    { "rate" : """3.75""" },
    { "rate" : """10.8999""" },
    { "rate" : """9.96""" },
    { "rate" : """0.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """10.73""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.487""" },
    { "rate" : """0.47899""" },
    { "rate" : """1.2""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """3.5""" },
    { "rate" : """1.98""" },
    { "rate" : """0.98888""" },
    { "rate" : """0.289""" },
    { "rate" : """1.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """1.25""" },
    { "rate" : """1.987""" },
    { "rate" : """0.987""" },
    { "rate" : """13.5""" },
    { "rate" : """2""" },
    { "rate" : """3.8""" },
    { "rate" : """0.4""" },
    { "rate" : """7.5""" },
    { "rate" : """0.44899""" },
    { "rate" : """1.99998""" },
    { "rate" : """0.4""" },
    { "rate" : """9.96""" },
    { "rate" : """12.46""" },
    { "rate" : """9.96""" },
    { "rate" : """0.45""" },
    { "rate" : """0.4""" },
    { "rate" : """10.73""" },
    { "rate" : """0.4""" },
    { "rate" : """15""" },
    { "rate" : """0.4""" },
    { "rate" : """0.27""" },
    { "rate" : """0.4""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """1""" },
    { "rate" : """8.88899""" },
    { "rate" : """9""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """8.99998""" },
    { "rate" : """0.35""" },
    { "rate" : """9.96""" },
    { "rate" : """1.9999""" },
    { "rate" : """1.5""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """0.39999""" },
    { "rate" : """8""" },
    { "rate" : """0.399""" },
    { "rate" : """9.96""" },
    { "rate" : """0.35""" },
    { "rate" : """6.55""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """1.99979""" },
    { "rate" : """11.99999""" },
    { "rate" : """5.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """4.99""" },
    { "rate" : """7.99999""" },
    { "rate" : """13.72""" },
    { "rate" : """23.58""" },
    { "rate" : """0.38999""" },
    { "rate" : """7.953""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """6.55""" },
    { "rate" : """9.96""" },
    { "rate" : """9.99999""" },
    { "rate" : """12.44998""" },
    { "rate" : """7.94999""" },
    { "rate" : """7.88999""" },
    { "rate" : """12.24998""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """0.4""" },
    { "rate" : """10""" },
    { "rate" : """30""" },
    { "rate" : """0.4""" },
    { "rate" : """9.99""" },
    { "rate" : """20""" },
    { "rate" : """0.9999""" },
    { "rate" : """4""" },
    { "rate" : """0.48999""" },
    { "rate" : """0.39999""" },
    { "rate" : """0.39899""" },
    { "rate" : """0.3999""" },
    { "rate" : """0.97999""" },
    { "rate" : """0.8""" },
    { "rate" : """0.98998""" },
    { "rate" : """0.35""" },
    { "rate" : """9.96""" },
    { "rate" : """4.99999""" },
    { "rate" : """14""" },
    { "rate" : """12.99999""" },
    { "rate" : """0.47""" },
    { "rate" : """9.96""" },
    { "rate" : """0.5""" },
    { "rate" : """9.96""" },
    { "rate" : """9.5""" },
    { "rate" : """9.96""" },
    { "rate" : """0.5""" },
    { "rate" : """0.99979""" },
    { "rate" : """0.44455""" },
    { "rate" : """0.47999""" },
    { "rate" : """0.38999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49""" },
    { "rate" : """0.4""" },
    { "rate" : """0.5""" },
    { "rate" : """12.1""" },
    { "rate" : """0.5""" },
    { "rate" : """3.89998""" },
    { "rate" : """1.19999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """1.99""" },
    { "rate" : """0.4""" },
    { "rate" : """0.9999""" },
    { "rate" : """1.9999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.97999""" },
    { "rate" : """0.9999""" },
    { "rate" : """9.99""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """0.9999""" },
    { "rate" : """23.58""" },
    { "rate" : """13.72""" },
    { "rate" : """2""" },
    { "rate" : """13.11""" },
    { "rate" : """0.5""" },
    { "rate" : """2""" },
    { "rate" : """0.49""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """0.47""" },
    { "rate" : """12.46""" },
    { "rate" : """2""" },
    { "rate" : """6.55""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """0.99""" },
    { "rate" : """8""" },
    { "rate" : """0.49989""" },
    { "rate" : """23.58""" },
    { "rate" : """0.5""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """6.55""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """0.99998""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """20""" },
    { "rate" : """9.96""" },
    { "rate" : """2""" },
    { "rate" : """9.95999""" },
    { "rate" : """3""" },
    { "rate" : """3.99""" },
    { "rate" : """4""" },
    { "rate" : """0.987""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.4487""" },
    { "rate" : """0.44455""" },
    { "rate" : """0.3987""" },
    { "rate" : """10""" },
    { "rate" : """4.995""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """3.89899""" },
    { "rate" : """0.99899""" },
    { "rate" : """0.388""" },
    { "rate" : """8""" },
    { "rate" : """0.388""" },
    { "rate" : """0.388""" },
    { "rate" : """0.5""" },
    { "rate" : """0.388""" },
    { "rate" : """0.98""" },
    { "rate" : """3.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """2""" },
    { "rate" : """3.64""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """23.57""" },
    { "rate" : """2.9999""" },
    { "rate" : """3.88""" },
    { "rate" : """3.8""" },
    { "rate" : """15""" },
    { "rate" : """0.95""" },
    { "rate" : """0.5""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """1.99999""" },
    { "rate" : """4.89999""" },
    { "rate" : """0.48999""" },
    { "rate" : """13.11""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.64""" },
    { "rate" : """3""" },
    { "rate" : """3.64""" },
    { "rate" : """3.899""" },
    { "rate" : """0.5""" },
    { "rate" : """1.25""" },
    { "rate" : """0.973""" },
    { "rate" : """11""" },
    { "rate" : """3.9999""" },
    { "rate" : """0.488""" },
    { "rate" : """3.89999""" },
    { "rate" : """0.4975""" },
    { "rate" : """0.4""" },
    { "rate" : """13.9""" },
    { "rate" : """2""" },
    { "rate" : """24.99999""" },
    { "rate" : """0.4""" },
    { "rate" : """0.9""" },
    { "rate" : """19""" },
    { "rate" : """0.98""" },
    { "rate" : """1.985""" },
    { "rate" : """25""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """3.9""" },
    { "rate" : """12""" },
    { "rate" : """3.9""" },
    { "rate" : """0.49""" },
    { "rate" : """3.99999""" },
    { "rate" : """3.6""" },
    { "rate" : """0.49""" },
    { "rate" : """0.99""" },
    { "rate" : """15""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.989""" },
    { "rate" : """13.11""" },
    { "rate" : """13.72""" },
    { "rate" : """3.64""" },
    { "rate" : """16.17""" },
    { "rate" : """12.26""" },
    { "rate" : """13.11""" },
    { "rate" : """3.64""" },
    { "rate" : """16.17""" },
    { "rate" : """0.4999""" },
    { "rate" : """0.5""" },
    { "rate" : """4""" },
    { "rate" : """0.999""" },
    { "rate" : """0.5""" },
    { "rate" : """3.64""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """8""" },
    { "rate" : """10.9""" },
    { "rate" : """1.9899""" },
    { "rate" : """1.9999""" },
    { "rate" : """0.9""" },
    { "rate" : """10""" },
    { "rate" : """0.99972""" },
    { "rate" : """0.5""" },
    { "rate" : """19.49""" },
    { "rate" : """9.5""" },
    { "rate" : """9.98""" },
    { "rate" : """11.11111""" },
    { "rate" : """5.55""" },
    { "rate" : """4""" },
    { "rate" : """11.11111""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """1.5""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """4""" },
    { "rate" : """0.489""" },
    { "rate" : """10.73""" },
    { "rate" : """11""" },
    { "rate" : """6.55""" },
    { "rate" : """0.5""" },
    { "rate" : """9.8""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.25""" },
    { "rate" : """1.99""" },
    { "rate" : """0.5""" },
    { "rate" : """8.8""" },
    { "rate" : """0.4899""" },
    { "rate" : """2""" },
    { "rate" : """3.9""" },
    { "rate" : """10.73""" },
    { "rate" : """17.48""" },
    { "rate" : """0.4""" },
    { "rate" : """2""" },
    { "rate" : """0.5""" },
    { "rate" : """12.26""" },
    { "rate" : """0.4899""" },
    { "rate" : """3.89""" },
    { "rate" : """0.39""" },
    { "rate" : """2""" },
    { "rate" : """0.4999""" },
    { "rate" : """0.48999""" },
    { "rate" : """0.5""" },
    { "rate" : """13.11""" },
    { "rate" : """0.48""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49""" },
    { "rate" : """12.46""" },
    { "rate" : """0.49999""" },
    { "rate" : """10.73""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """0.495""" },
    { "rate" : """13.95""" },
    { "rate" : """0.48""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """0.044""" },
    { "rate" : """8.8""" },
    { "rate" : """7.77""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """6.55""" },
    { "rate" : """15""" },
    { "rate" : """13""" },
    { "rate" : """12""" },
    { "rate" : """0.3""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """17.48""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """6.55""" },
    { "rate" : """7.9723""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """8.8""" },
    { "rate" : """7.8""" },
    { "rate" : """13.11""" },
    { "rate" : """8.5""" },
    { "rate" : """7.99999""" },
    { "rate" : """7.9""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """0.9""" },
    { "rate" : """8""" },
    { "rate" : """7.9""" },
    { "rate" : """6""" },
    { "rate" : """0.44""" },
    { "rate" : """0.99""" },
    { "rate" : """0.44""" },
    { "rate" : """0.5""" },
    { "rate" : """0.2999""" },
    { "rate" : """8""" },
    { "rate" : """7.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.49999""" },
    { "rate" : """9.99999""" },
    { "rate" : """7.99998""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """7.9""" },
    { "rate" : """3.64""" },
    { "rate" : """12""" },
    { "rate" : """0.89999""" },
    { "rate" : """7.89999""" },
    { "rate" : """7.9""" },
    { "rate" : """6.55""" },
    { "rate" : """8.8""" },
    { "rate" : """17""" },
    { "rate" : """12""" },
    { "rate" : """8.99999""" },
    { "rate" : """0.39972""" },
    { "rate" : """9.99999""" },
    { "rate" : """11.5""" },
    { "rate" : """20.45""" },
    { "rate" : """11.5""" },
    { "rate" : """7.9999""" },
    { "rate" : """11.5""" },
    { "rate" : """0.479""" },
    { "rate" : """12.26""" },
    { "rate" : """17.48""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """0.01""" },
    { "rate" : """0.47999""" },
    { "rate" : """0.37999""" },
    { "rate" : """0.34999""" },
    { "rate" : """0.34999""" },
    { "rate" : """0.37999""" },
    { "rate" : """0.26999""" },
    { "rate" : """15.14""" },
    { "rate" : """7.9""" },
    { "rate" : """10""" },
    { "rate" : """15.5""" },
    { "rate" : """20""" },
    { "rate" : """8""" },
    { "rate" : """3.64""" },
    { "rate" : """0.5""" },
    { "rate" : """7.79999""" },
    { "rate" : """9.49999""" },
    { "rate" : """2.49999""" },
    { "rate" : """8""" },
    { "rate" : """13""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """4""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """0.97""" },
    { "rate" : """13.72""" },
    { "rate" : """7.9998""" },
    { "rate" : """17.48""" },
    { "rate" : """7.99""" },
    { "rate" : """3.64""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """17.48""" },
    { "rate" : """6.55""" },
    { "rate" : """3.64""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """17.48""" },
    { "rate" : """12.46""" },
    { "rate" : """4""" },
    { "rate" : """15.14""" },
    { "rate" : """6.55""" },
    { "rate" : """12.46""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """0.49""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12.26""" },
    { "rate" : """17.48""" },
    { "rate" : """0.5""" },
    { "rate" : """12.26""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """0.3999""" },
    { "rate" : """9.99999""" },
    { "rate" : """10.73""" },
    { "rate" : """0.38""" },
    { "rate" : """20.45""" },
    { "rate" : """10.73""" },
    { "rate" : """12""" },
    { "rate" : """9.9999""" },
    { "rate" : """0.25""" },
    { "rate" : """0.25""" },
    { "rate" : """0.25""" },
    { "rate" : """0.25""" },
    { "rate" : """13""" },
    { "rate" : """13.72""" },
    { "rate" : """17.45""" },
    { "rate" : """0.7""" },
    { "rate" : """12""" },
    { "rate" : """17.48""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """6.55""" },
    { "rate" : """20""" },
    { "rate" : """9""" },
    { "rate" : """0.33""" },
    { "rate" : """0.99996""" },
    { "rate" : """0.46999""" },
    { "rate" : """0.39999""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """13.11""" },
    { "rate" : """12""" },
    { "rate" : """9.99999""" },
    { "rate" : """12.46""" },
    { "rate" : """3.6""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """13.72""" },
    { "rate" : """3.8""" },
    { "rate" : """10.73""" },
    { "rate" : """0.5""" },
    { "rate" : """17.48""" },
    { "rate" : """20.45""" },
    { "rate" : """12""" },
    { "rate" : """13.11""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """0.38999""" },
    { "rate" : """13""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """15""" },
    { "rate" : """17.48""" },
    { "rate" : """10""" },
    { "rate" : """3.64""" },
    { "rate" : """11.11111""" },
    { "rate" : """11.11111""" },
    { "rate" : """3.63""" },
    { "rate" : """12.46""" },
    { "rate" : """9.98999""" },
    { "rate" : """12""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """8""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """17.47""" },
    { "rate" : """8""" },
    { "rate" : """0.5""" },
    { "rate" : """2.5""" },
    { "rate" : """14.8""" },
    { "rate" : """17.4""" },
    { "rate" : """0.49999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3.64""" },
    { "rate" : """10.73""" },
    { "rate" : """6.55""" },
    { "rate" : """9.99""" },
    { "rate" : """9.995""" },
    { "rate" : """0.5""" },
    { "rate" : """16""" },
    { "rate" : """8""" },
    { "rate" : """0.497""" },
    { "rate" : """0.5""" },
    { "rate" : """11.66666""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10.73""" },
    { "rate" : """20.45""" },
    { "rate" : """10.73""" },
    { "rate" : """12.46""" },
    { "rate" : """4.5""" },
    { "rate" : """23.58""" },
    { "rate" : """6.55""" },
    { "rate" : """0.4""" },
    { "rate" : """9.999""" },
    { "rate" : """11""" },
    { "rate" : """8.5""" },
    { "rate" : """20""" },
    { "rate" : """12.45""" },
    { "rate" : """17.48""" },
    { "rate" : """8""" },
    { "rate" : """13.11""" },
    { "rate" : """3.64""" },
    { "rate" : """3.88""" },
    { "rate" : """13.72""" },
    { "rate" : """10.73""" },
    { "rate" : """3.64""" },
    { "rate" : """12.45""" },
    { "rate" : """19.72""" },
    { "rate" : """7.72""" },
    { "rate" : """12.46""" },
    { "rate" : """10.73""" },
    { "rate" : """8""" },
    { "rate" : """12.46""" },
    { "rate" : """10.73""" },
    { "rate" : """0.3""" },
    { "rate" : """17.48""" },
    { "rate" : """10.73""" },
    { "rate" : """7.99999""" },
    { "rate" : """20""" },
    { "rate" : """3.63""" },
    { "rate" : """9.99999""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """13.25""" },
    { "rate" : """0.5""" },
    { "rate" : """12.26""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.64""" },
    { "rate" : """10.73""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99""" },
    { "rate" : """12.46""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """12.46""" },
    { "rate" : """4""" },
    { "rate" : """10.73""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.4""" },
    { "rate" : """8.4""" },
    { "rate" : """8.4""" },
    { "rate" : """8.4""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """0.99""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """0.39998""" },
    { "rate" : """13.11""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """13.11""" },
    { "rate" : """12.46""" },
    { "rate" : """9.9""" },
    { "rate" : """15""" },
    { "rate" : """8.8""" },
    { "rate" : """9""" },
    { "rate" : """3.85""" },
    { "rate" : """12""" },
    { "rate" : """12.46""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """8.49""" },
    { "rate" : """9.99979""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """3.6""" },
    { "rate" : """0.5""" },
    { "rate" : """10.99999""" },
    { "rate" : """8""" },
    { "rate" : """9.98""" },
    { "rate" : """8.8""" },
    { "rate" : """0.25""" },
    { "rate" : """10.73""" },
    { "rate" : """16.17""" },
    { "rate" : """17.48""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """4.99979""" },
    { "rate" : """10""" },
    { "rate" : """9.5""" },
    { "rate" : """9.5""" },
    { "rate" : """8.8""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """24.99999""" },
    { "rate" : """12""" },
    { "rate" : """12.26""" },
    { "rate" : """0.24999""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """0.39879""" },
    { "rate" : """0.00084""" },
    { "rate" : """12""" },
    { "rate" : """9.4""" },
    { "rate" : """0.3999""" },
    { "rate" : """13.11""" },
    { "rate" : """0.39972""" },
    { "rate" : """3.8""" },
    { "rate" : """4""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """23.58""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """0.3999""" },
    { "rate" : """12.46""" },
    { "rate" : """11""" },
    { "rate" : """8""" },
    { "rate" : """10.73""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """13""" },
    { "rate" : """3.5""" },
    { "rate" : """3.89999""" },
    { "rate" : """3.64""" },
    { "rate" : """10.73""" },
    { "rate" : """6.55""" },
    { "rate" : """17.48""" },
    { "rate" : """13.72""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """13.11""" },
    { "rate" : """13""" },
    { "rate" : """13.11""" },
    { "rate" : """0.34999""" },
    { "rate" : """4""" },
    { "rate" : """0.38999""" },
    { "rate" : """8.8""" },
    { "rate" : """13""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.4999""" },
    { "rate" : """0.4""" },
    { "rate" : """0.5""" },
    { "rate" : """10.73""" },
    { "rate" : """0.49999""" },
    { "rate" : """13.11""" },
    { "rate" : """0.4989""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49999""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """4""" },
    { "rate" : """8.8""" },
    { "rate" : """11.989""" },
    { "rate" : """10.73""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """12.45""" },
    { "rate" : """10.73""" },
    { "rate" : """12.46""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """0.33""" },
    { "rate" : """12.46""" },
    { "rate" : """12""" },
    { "rate" : """13.11""" },
    { "rate" : """4.99888""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """15""" },
    { "rate" : """4.65""" },
    { "rate" : """13""" },
    { "rate" : """3.64""" },
    { "rate" : """13.71""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.49999""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10.73""" },
    { "rate" : """10""" },
    { "rate" : """4.98""" },
    { "rate" : """10.25""" },
    { "rate" : """13.72""" },
    { "rate" : """4.5""" },
    { "rate" : """4.9999""" },
    { "rate" : """4.9""" },
    { "rate" : """11.11111""" },
    { "rate" : """5""" },
    { "rate" : """4.6""" },
    { "rate" : """4.2""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """10.99899""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """13.10999""" },
    { "rate" : """2.99999""" },
    { "rate" : """13.10999""" },
    { "rate" : """3.99999""" },
    { "rate" : """4""" },
    { "rate" : """11.5""" },
    { "rate" : """13.7""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """7.9""" },
    { "rate" : """13.72""" },
    { "rate" : """3.64""" },
    { "rate" : """10.5""" },
    { "rate" : """3.95""" },
    { "rate" : """10.73""" },
    { "rate" : """8.7499""" },
    { "rate" : """10""" },
    { "rate" : """17.48""" },
    { "rate" : """8.8""" },
    { "rate" : """17.48""" },
    { "rate" : """13.11""" },
    { "rate" : """13.72""" },
    { "rate" : """1""" },
    { "rate" : """10.73""" },
    { "rate" : """0.5""" },
    { "rate" : """10.73""" },
    { "rate" : """0.5""" },
    { "rate" : """3.64""" },
    { "rate" : """0.5""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """7.8""" },
    { "rate" : """4""" },
    { "rate" : """12.26""" },
    { "rate" : """17.48""" },
    { "rate" : """12.26""" },
    { "rate" : """25""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """0.5""" },
    { "rate" : """0.35""" },
    { "rate" : """0.5""" },
    { "rate" : """3""" },
    { "rate" : """12.46""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """11.99999""" },
    { "rate" : """12""" },
    { "rate" : """4.987""" },
    { "rate" : """8.73999""" },
    { "rate" : """7.8""" },
    { "rate" : """8.99999""" },
    { "rate" : """8.8""" },
    { "rate" : """11.1""" },
    { "rate" : """10.73""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """11.98""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """13.71""" },
    { "rate" : """10.7299""" },
    { "rate" : """3""" },
    { "rate" : """13.7""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """13.11""" },
    { "rate" : """11.999""" },
    { "rate" : """2.99""" },
    { "rate" : """13.72""" },
    { "rate" : """7.7999""" },
    { "rate" : """0.5""" },
    { "rate" : """13.5""" },
    { "rate" : """8.8""" },
    { "rate" : """17.48""" },
    { "rate" : """12""" },
    { "rate" : """12.26""" },
    { "rate" : """10.4999""" },
    { "rate" : """4""" },
    { "rate" : """10.72""" },
    { "rate" : """0.49999""" },
    { "rate" : """8.79""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8.79999""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """0.49999""" },
    { "rate" : """8.8""" },
    { "rate" : """8.73""" },
    { "rate" : """12.45""" },
    { "rate" : """2.99972""" },
    { "rate" : """17.48""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """8.79999""" },
    { "rate" : """8.798""" },
    { "rate" : """8.8""" },
    { "rate" : """13.11""" },
    { "rate" : """8.749""" },
    { "rate" : """8.8""" },
    { "rate" : """12.72""" },
    { "rate" : """5""" },
    { "rate" : """10.73""" },
    { "rate" : """4.9999""" },
    { "rate" : """0.485""" },
    { "rate" : """12""" },
    { "rate" : """8.5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """0.4""" },
    { "rate" : """8.78""" },
    { "rate" : """17.48""" },
    { "rate" : """0.49999""" },
    { "rate" : """11""" },
    { "rate" : """12""" },
    { "rate" : """11""" },
    { "rate" : """8.8""" },
    { "rate" : """7.9""" },
    { "rate" : """12""" },
    { "rate" : """8.7""" },
    { "rate" : """17.48""" },
    { "rate" : """0.49""" },
    { "rate" : """17""" },
    { "rate" : """7.89999""" },
    { "rate" : """13.11""" },
    { "rate" : """10.73""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """18""" },
    { "rate" : """0.5""" },
    { "rate" : """8.74""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """0.25""" },
    { "rate" : """6.99999""" },
    { "rate" : """13""" },
    { "rate" : """9.99999""" },
    { "rate" : """8.49999""" },
    { "rate" : """6.95""" },
    { "rate" : """17.45""" },
    { "rate" : """6.898""" },
    { "rate" : """13.7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """16.99""" },
    { "rate" : """13""" },
    { "rate" : """8.8""" },
    { "rate" : """4.49999""" },
    { "rate" : """8""" },
    { "rate" : """4.7""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """8.74989""" },
    { "rate" : """4.3""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.69""" },
    { "rate" : """4.5""" },
    { "rate" : """12.99999""" },
    { "rate" : """8""" },
    { "rate" : """0.39""" },
    { "rate" : """0.39""" },
    { "rate" : """17.48""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """0.25""" },
    { "rate" : """4.99999""" },
    { "rate" : """8.7""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """10.73""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7.5""" },
    { "rate" : """8""" },
    { "rate" : """7.9""" },
    { "rate" : """8.74939""" },
    { "rate" : """7.5""" },
    { "rate" : """8.25""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """13.6""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """11""" },
    { "rate" : """0.5""" },
    { "rate" : """3.5""" },
    { "rate" : """0.39""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """8.4""" },
    { "rate" : """10.7""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8.7""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """8.7""" },
    { "rate" : """7""" },
    { "rate" : """4.99""" },
    { "rate" : """17""" },
    { "rate" : """12""" },
    { "rate" : """8.7""" },
    { "rate" : """17.48""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10.73""" },
    { "rate" : """17.48""" },
    { "rate" : """0.7""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """12.5""" },
    { "rate" : """0.95""" },
    { "rate" : """0.49989""" },
    { "rate" : """0.959""" },
    { "rate" : """0.4999""" },
    { "rate" : """17.48""" },
    { "rate" : """12.45""" },
    { "rate" : """0.6""" },
    { "rate" : """12.26""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """0.9""" },
    { "rate" : """0.85""" },
    { "rate" : """0.8999""" },
    { "rate" : """12""" },
    { "rate" : """10.73""" },
    { "rate" : """8.5""" },
    { "rate" : """6.55""" },
    { "rate" : """15""" },
    { "rate" : """8.7""" },
    { "rate" : """10""" },
    { "rate" : """12.45""" },
    { "rate" : """17.48""" },
    { "rate" : """13.11""" },
    { "rate" : """17.48""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """0.56789""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """17.48""" },
    { "rate" : """2""" },
    { "rate" : """1.999""" },
    { "rate" : """13""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """17.48""" },
    { "rate" : """1.98899""" },
    { "rate" : """1.99""" },
    { "rate" : """8""" },
    { "rate" : """1.99995""" },
    { "rate" : """1.9999""" },
    { "rate" : """12.26""" },
    { "rate" : """13.11""" },
    { "rate" : """12.999""" },
    { "rate" : """17.48""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """17.48""" },
    { "rate" : """1.999""" },
    { "rate" : """2""" },
    { "rate" : """1.999""" },
    { "rate" : """200""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.99999""" },
    { "rate" : """0.90999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.9999""" },
    { "rate" : """1.987""" },
    { "rate" : """8""" },
    { "rate" : """13""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """0.49999""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """17.48""" },
    { "rate" : """8.739""" },
    { "rate" : """13.11""" },
    { "rate" : """8.74""" },
    { "rate" : """19.5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """17.48""" },
    { "rate" : """23.58""" },
    { "rate" : """12""" },
    { "rate" : """13.1""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """17.48""" },
    { "rate" : """5""" },
    { "rate" : """10.73""" },
    { "rate" : """23.58""" },
    { "rate" : """1""" },
    { "rate" : """13.11""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """10.73""" },
    { "rate" : """23""" },
    { "rate" : """10.99""" },
    { "rate" : """8.7""" },
    { "rate" : """0.49""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """23.58""" },
    { "rate" : """5""" },
    { "rate" : """0.49679""" },
    { "rate" : """0.4""" },
    { "rate" : """0.4""" },
    { "rate" : """0.49599""" },
    { "rate" : """15""" },
    { "rate" : """13.09""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """8.7""" },
    { "rate" : """10.7""" },
    { "rate" : """9.9""" },
    { "rate" : """13.11""" },
    { "rate" : """11.8""" },
    { "rate" : """0.4""" },
    { "rate" : """17.48""" },
    { "rate" : """0.4""" },
    { "rate" : """0.49998""" },
    { "rate" : """0.29999""" },
    { "rate" : """0.34999""" },
    { "rate" : """10.73""" },
    { "rate" : """17.48""" },
    { "rate" : """0.33999""" },
    { "rate" : """0.39999""" },
    { "rate" : """0.4""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.45""" },
    { "rate" : """0.34987""" },
    { "rate" : """0.45""" },
    { "rate" : """12.26""" },
    { "rate" : """0.5""" },
    { "rate" : """13.11""" },
    { "rate" : """0.4""" },
    { "rate" : """10.73""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """10.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """13.11""" },
    { "rate" : """4""" },
    { "rate" : """3.75""" },
    { "rate" : """3.99999""" },
    { "rate" : """4""" },
    { "rate" : """3.9""" },
    { "rate" : """18.6""" },
    { "rate" : """4""" },
    { "rate" : """4.9""" },
    { "rate" : """12""" },
    { "rate" : """10.73""" },
    { "rate" : """0.38999""" },
    { "rate" : """0.39999""" },
    { "rate" : """15""" },
    { "rate" : """0.5""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """0.39999""" },
    { "rate" : """0.37999""" },
    { "rate" : """0.39899""" },
    { "rate" : """13.11""" },
    { "rate" : """8.49999""" },
    { "rate" : """0.38""" },
    { "rate" : """13""" },
    { "rate" : """13.1""" },
    { "rate" : """17""" },
    { "rate" : """0.39""" },
    { "rate" : """0.43999""" },
    { "rate" : """13.095""" },
    { "rate" : """5""" },
    { "rate" : """0.48999""" },
    { "rate" : """0.489""" },
    { "rate" : """0.48888""" },
    { "rate" : """3.74999""" },
    { "rate" : """12""" },
    { "rate" : """0.39""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """0.44997""" },
    { "rate" : """0.49998""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """0.38""" },
    { "rate" : """0.39799""" },
    { "rate" : """10""" },
    { "rate" : """0.49979""" },
    { "rate" : """0.34997""" },
    { "rate" : """0.37989""" },
    { "rate" : """0.48899""" },
    { "rate" : """13.11""" },
    { "rate" : """0.34999""" },
    { "rate" : """0.5""" },
    { "rate" : """13""" },
    { "rate" : """4.89999""" },
    { "rate" : """4.74999""" },
    { "rate" : """9.99999""" },
    { "rate" : """4.9798""" },
    { "rate" : """4.979""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """17.48""" },
    { "rate" : """12.26""" },
    { "rate" : """0.5""" },
    { "rate" : """13.11""" },
    { "rate" : """17.48""" },
    { "rate" : """11""" },
    { "rate" : """12""" },
    { "rate" : """0.49""" },
    { "rate" : """11.97999""" },
    { "rate" : """0.045""" },
    { "rate" : """11.89999""" },
    { "rate" : """11.99""" },
    { "rate" : """11.9""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """4.88888""" },
    { "rate" : """9.9999""" },
    { "rate" : """12""" },
    { "rate" : """0.42""" },
    { "rate" : """0.488""" },
    { "rate" : """0.49""" },
    { "rate" : """11""" },
    { "rate" : """0.438""" },
    { "rate" : """11.89""" },
    { "rate" : """11""" },
    { "rate" : """11.95""" },
    { "rate" : """11.99999""" },
    { "rate" : """4.9799""" },
    { "rate" : """12""" },
    { "rate" : """4.5""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """10.99998""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """11.99998""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """17.47999""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """0.4899""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """11.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.99""" },
    { "rate" : """12""" },
    { "rate" : """17.48""" },
    { "rate" : """0.44999""" },
    { "rate" : """0.4""" },
    { "rate" : """11""" },
    { "rate" : """0.48""" },
    { "rate" : """0.45678""" },
    { "rate" : """6.55""" },
    { "rate" : """10.98""" },
    { "rate" : """12.26""" },
    { "rate" : """10.73""" },
    { "rate" : """0.4""" },
    { "rate" : """0.4""" },
    { "rate" : """11.99""" },
    { "rate" : """0.47999""" },
    { "rate" : """0.48979""" },
    { "rate" : """13.11""" },
    { "rate" : """0.45999""" },
    { "rate" : """0.43999""" },
    { "rate" : """0.44""" },
    { "rate" : """12""" },
    { "rate" : """3""" },
    { "rate" : """23""" },
    { "rate" : """3""" },
    { "rate" : """0.34567""" },
    { "rate" : """11""" },
    { "rate" : """10.73""" },
    { "rate" : """8.5""" },
    { "rate" : """7.77777""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.7888""" },
    { "rate" : """0.458""" },
    { "rate" : """11.11111""" },
    { "rate" : """13.11""" },
    { "rate" : """0.4""" },
    { "rate" : """0.438""" },
    { "rate" : """14.99""" },
    { "rate" : """8.8""" },
    { "rate" : """30""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """11.98""" },
    { "rate" : """13""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """5.99979""" },
    { "rate" : """11""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """5.98""" },
    { "rate" : """10.73""" },
    { "rate" : """12.26""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """0.3""" },
    { "rate" : """15""" },
    { "rate" : """4.98""" },
    { "rate" : """5""" },
    { "rate" : """11.99985""" },
    { "rate" : """4.97989""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """6""" },
    { "rate" : """12.26""" },
    { "rate" : """6""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """13.71""" },
    { "rate" : """13.11""" },
    { "rate" : """4""" },
    { "rate" : """11.4""" },
    { "rate" : """11.25""" },
    { "rate" : """11.99""" },
    { "rate" : """9.99""" },
    { "rate" : """6""" },
    { "rate" : """5.999""" },
    { "rate" : """11.9""" },
    { "rate" : """11.9999""" },
    { "rate" : """12.26""" },
    { "rate" : """11.99999""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """0.3""" },
    { "rate" : """2.9""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """12.25999""" },
    { "rate" : """5.5""" },
    { "rate" : """4.5""" },
    { "rate" : """4.97899""" },
    { "rate" : """18.5""" },
    { "rate" : """4""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """0.34""" },
    { "rate" : """11""" },
    { "rate" : """0.5""" },
    { "rate" : """12.25""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """4.97299""" },
    { "rate" : """12.2572""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """0.5""" },
    { "rate" : """11.7""" },
    { "rate" : """4.9""" },
    { "rate" : """13.11""" },
    { "rate" : """13.72""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """11.9""" },
    { "rate" : """10""" },
    { "rate" : """19.99999""" },
    { "rate" : """18""" },
    { "rate" : """10""" },
    { "rate" : """17""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """0.35""" },
    { "rate" : """11.9""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """14.9""" },
    { "rate" : """5""" },
    { "rate" : """0.3""" },
    { "rate" : """20""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """14.99""" },
    { "rate" : """11""" },
    { "rate" : """11.99999""" },
    { "rate" : """15""" },
    { "rate" : """11""" },
    { "rate" : """0.4""" },
    { "rate" : """0.5""" },
    { "rate" : """12.26""" },
    { "rate" : """11.9998""" },
    { "rate" : """11""" },
    { "rate" : """6.55""" },
    { "rate" : """10.73""" },
    { "rate" : """12""" },
    { "rate" : """10.73""" },
    { "rate" : """6.55""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10.73""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """15""" },
    { "rate" : """12.22222""" },
    { "rate" : """11""" },
    { "rate" : """4.97989""" },
    { "rate" : """12.26""" },
    { "rate" : """0.39999""" },
    { "rate" : """23""" },
    { "rate" : """0.4""" },
    { "rate" : """4""" },
    { "rate" : """0.3""" },
    { "rate" : """0.33333""" },
    { "rate" : """0.39997""" },
    { "rate" : """11.99995""" },
    { "rate" : """0.5""" },
    { "rate" : """7""" },
    { "rate" : """0.38""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """0.9998""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """0.9""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """11.7""" },
    { "rate" : """12.26""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49998""" },
    { "rate" : """1""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49997""" },
    { "rate" : """0.8""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.5""" },
    { "rate" : """1""" },
    { "rate" : """0.972""" },
    { "rate" : """0.4987""" },
    { "rate" : """0.472""" },
    { "rate" : """15""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """0.5""" },
    { "rate" : """0.4""" },
    { "rate" : """0.4""" },
    { "rate" : """0.99979""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """6.74998""" },
    { "rate" : """12""" },
    { "rate" : """11""" },
    { "rate" : """4.98998""" },
    { "rate" : """0.47499""" },
    { "rate" : """0.47777""" },
    { "rate" : """13.72""" },
    { "rate" : """4.98""" },
    { "rate" : """0.45""" },
    { "rate" : """11.9999""" },
    { "rate" : """0.47498""" },
    { "rate" : """13""" },
    { "rate" : """11.99999""" },
    { "rate" : """12""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.49""" },
    { "rate" : """0.4""" },
    { "rate" : """12""" },
    { "rate" : """11.99999""" },
    { "rate" : """12.26""" },
    { "rate" : """11.95""" },
    { "rate" : """12.26""" },
    { "rate" : """11.75""" },
    { "rate" : """11""" },
    { "rate" : """9.5""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """12.26""" },
    { "rate" : """11.9999""" },
    { "rate" : """12.13""" },
    { "rate" : """13.72""" },
    { "rate" : """11""" },
    { "rate" : """11.9""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """19.99999""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """11.99998""" },
    { "rate" : """11.99999""" },
    { "rate" : """11.9999""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """3.2""" },
    { "rate" : """12.26""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """2.99998""" },
    { "rate" : """3.2""" },
    { "rate" : """5""" },
    { "rate" : """4.97979""" },
    { "rate" : """6""" },
    { "rate" : """3.09999""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """6.55""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """4.5""" },
    { "rate" : """3.2""" },
    { "rate" : """17.48""" },
    { "rate" : """5""" },
    { "rate" : """3.2""" },
    { "rate" : """3.19999""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """5.99999""" },
    { "rate" : """14""" },
    { "rate" : """5.99998""" },
    { "rate" : """6""" },
    { "rate" : """14.5""" },
    { "rate" : """3.2""" },
    { "rate" : """3.1""" },
    { "rate" : """11.999""" },
    { "rate" : """4.99998""" },
    { "rate" : """0.49""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """5.9""" },
    { "rate" : """6.55""" },
    { "rate" : """13.11""" },
    { "rate" : """13""" },
    { "rate" : """3.2""" },
    { "rate" : """6""" },
    { "rate" : """4.99""" },
    { "rate" : """11.11111""" },
    { "rate" : """4.89999""" },
    { "rate" : """5.99999""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """0.39""" },
    { "rate" : """7.5""" },
    { "rate" : """14""" },
    { "rate" : """6.55""" },
    { "rate" : """0.5""" },
    { "rate" : """3""" },
    { "rate" : """15.88998""" },
    { "rate" : """6""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """4.98999""" },
    { "rate" : """10""" },
    { "rate" : """15.99999""" },
    { "rate" : """8""" },
    { "rate" : """1.1""" },
    { "rate" : """1""" },
    { "rate" : """13""" },
    { "rate" : """16.17""" },
    { "rate" : """10""" },
    { "rate" : """6.55""" },
    { "rate" : """1.8""" },
    { "rate" : """4.889""" },
    { "rate" : """11.88""" },
    { "rate" : """1.48999""" },
    { "rate" : """1.9""" },
    { "rate" : """1.12""" },
    { "rate" : """1.5""" },
    { "rate" : """16""" },
    { "rate" : """1.9""" },
    { "rate" : """3.2""" },
    { "rate" : """3.2""" },
    { "rate" : """1.12""" },
    { "rate" : """0.49998""" },
    { "rate" : """12.26""" },
    { "rate" : """6.55""" },
    { "rate" : """14.99""" },
    { "rate" : """12""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """16""" },
    { "rate" : """13.11""" },
    { "rate" : """1.945""" },
    { "rate" : """0.499""" },
    { "rate" : """1.5""" },
    { "rate" : """3.2""" },
    { "rate" : """9.95""" },
    { "rate" : """0.5""" },
    { "rate" : """4.9""" },
    { "rate" : """4.999""" },
    { "rate" : """4.999""" },
    { "rate" : """1""" },
    { "rate" : """4.99999""" },
    { "rate" : """12.25""" },
    { "rate" : """0.49998""" },
    { "rate" : """0.99999""" },
    { "rate" : """23.58""" },
    { "rate" : """5""" },
    { "rate" : """9.9999""" },
    { "rate" : """0.99""" },
    { "rate" : """1.48""" },
    { "rate" : """23.56""" },
    { "rate" : """1.9996""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """3.2""" },
    { "rate" : """18.98""" },
    { "rate" : """13""" },
    { "rate" : """0.48999""" },
    { "rate" : """14.99999""" },
    { "rate" : """0.47999""" },
    { "rate" : """4.99""" },
    { "rate" : """0.49998""" },
    { "rate" : """0.49""" },
    { "rate" : """0.4""" },
    { "rate" : """1.95""" },
    { "rate" : """1.68""" },
    { "rate" : """0.35""" },
    { "rate" : """1""" },
    { "rate" : """1.11999""" },
    { "rate" : """1.5""" },
    { "rate" : """1.12""" },
    { "rate" : """5""" },
    { "rate" : """0.44998""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49""" },
    { "rate" : """5""" },
    { "rate" : """11.99999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49""" },
    { "rate" : """0.49998""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """12.9""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """8.7""" },
    { "rate" : """1.5""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """4.99979""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49999""" },
    { "rate" : """8.7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """4.9999""" },
    { "rate" : """5""" },
    { "rate" : """11.9999""" },
    { "rate" : """5.99998""" },
    { "rate" : """4.9999""" },
    { "rate" : """9.96""" },
    { "rate" : """3.1""" },
    { "rate" : """5""" },
    { "rate" : """9.99""" },
    { "rate" : """5""" },
    { "rate" : """12.99""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """1.972""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1.5""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """9.96""" },
    { "rate" : """4.99972""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """13.99""" },
    { "rate" : """13.11""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """12.99999""" },
    { "rate" : """13.99999""" },
    { "rate" : """10""" },
    { "rate" : """14.99""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """12.9""" },
    { "rate" : """14""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """23.58""" },
    { "rate" : """13.33333""" },
    { "rate" : """4.98999""" },
    { "rate" : """1.49999""" },
    { "rate" : """8.88888""" },
    { "rate" : """13.99998""" },
    { "rate" : """5.84998""" },
    { "rate" : """13.33333""" },
    { "rate" : """4.99979""" },
    { "rate" : """13.72""" },
    { "rate" : """3.1""" },
    { "rate" : """14""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """4.89999""" },
    { "rate" : """6""" },
    { "rate" : """16""" },
    { "rate" : """4""" },
    { "rate" : """0.04555""" },
    { "rate" : """0.5""" },
    { "rate" : """0.499""" },
    { "rate" : """0.49""" },
    { "rate" : """13.11""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """12""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """6""" },
    { "rate" : """4.987""" },
    { "rate" : """14""" },
    { "rate" : """0.5""" },
    { "rate" : """1.987""" },
    { "rate" : """10""" },
    { "rate" : """4.99999""" },
    { "rate" : """13.72""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.75""" },
    { "rate" : """1.5""" },
    { "rate" : """12.46""" },
    { "rate" : """13.98999""" },
    { "rate" : """13.11""" },
    { "rate" : """16.17""" },
    { "rate" : """23.58""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """13.72""" },
    { "rate" : """3.2""" },
    { "rate" : """2""" },
    { "rate" : """1.987""" },
    { "rate" : """4.5""" },
    { "rate" : """0.4499""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """4.99989""" },
    { "rate" : """1.79899""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.8""" },
    { "rate" : """11.5""" },
    { "rate" : """5""" },
    { "rate" : """15.99999""" },
    { "rate" : """2""" },
    { "rate" : """3.2""" },
    { "rate" : """13.72""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """1.99988""" },
    { "rate" : """6""" },
    { "rate" : """4.99998""" },
    { "rate" : """2""" },
    { "rate" : """1.5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """1.8""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """0.45""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """25""" },
    { "rate" : """1.99995""" },
    { "rate" : """4.99995""" },
    { "rate" : """12.26""" },
    { "rate" : """8""" },
    { "rate" : """5.99999""" },
    { "rate" : """1.99999""" },
    { "rate" : """3.99989""" },
    { "rate" : """4.9999""" },
    { "rate" : """1.49999""" },
    { "rate" : """1.49989""" },
    { "rate" : """2""" },
    { "rate" : """1.99989""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """1.5""" },
    { "rate" : """12.25999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """0.973""" },
    { "rate" : """5.999""" },
    { "rate" : """11.9999""" },
    { "rate" : """12""" },
    { "rate" : """23.58""" },
    { "rate" : """1.12""" },
    { "rate" : """6""" },
    { "rate" : """4.9""" },
    { "rate" : """9.5""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """4.95""" },
    { "rate" : """5""" },
    { "rate" : """3.2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.9""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """13.72""" },
    { "rate" : """1""" },
    { "rate" : """1.999""" },
    { "rate" : """4.9999""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """1.9""" },
    { "rate" : """2""" },
    { "rate" : """7.5""" },
    { "rate" : """11.9""" },
    { "rate" : """7.5""" },
    { "rate" : """11.98""" },
    { "rate" : """1.9999""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """5.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """4.99""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """1.99999""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """13.72""" },
    { "rate" : """15""" },
    { "rate" : """11.99972""" },
    { "rate" : """5.9""" },
    { "rate" : """9.5""" },
    { "rate" : """1.9999""" },
    { "rate" : """5.95""" },
    { "rate" : """11""" },
    { "rate" : """8""" },
    { "rate" : """7.99""" },
    { "rate" : """3.9""" },
    { "rate" : """9""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """12.25""" },
    { "rate" : """1.8""" },
    { "rate" : """2""" },
    { "rate" : """3.75""" },
    { "rate" : """8""" },
    { "rate" : """4.9999""" },
    { "rate" : """8""" },
    { "rate" : """7.49999""" },
    { "rate" : """20""" },
    { "rate" : """2""" },
    { "rate" : """1.9999""" },
    { "rate" : """20""" },
    { "rate" : """3.64""" },
    { "rate" : """8""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """9.9""" },
    { "rate" : """0.5""" },
    { "rate" : """9.99""" },
    { "rate" : """16.17""" },
    { "rate" : """3.19""" },
    { "rate" : """4.99""" },
    { "rate" : """13.11""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """1.12""" },
    { "rate" : """5""" },
    { "rate" : """23.58""" },
    { "rate" : """4.98999""" },
    { "rate" : """6.74""" },
    { "rate" : """1.9""" },
    { "rate" : """12.25""" },
    { "rate" : """8""" },
    { "rate" : """7.9""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7.99999""" },
    { "rate" : """7.9987""" },
    { "rate" : """7.9""" },
    { "rate" : """7.989""" },
    { "rate" : """7.9889""" },
    { "rate" : """1.99979""" },
    { "rate" : """8""" },
    { "rate" : """7.99""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """7.99999""" },
    { "rate" : """7.89999""" },
    { "rate" : """7.8""" },
    { "rate" : """7.9""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """7.999""" },
    { "rate" : """1.9999""" },
    { "rate" : """8""" },
    { "rate" : """11.99999""" },
    { "rate" : """1.98999""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.9999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """0.1""" },
    { "rate" : """10""" },
    { "rate" : """4.99999""" },
    { "rate" : """3.64""" },
    { "rate" : """0.14987""" },
    { "rate" : """1.5""" },
    { "rate" : """6.55""" },
    { "rate" : """12.46""" },
    { "rate" : """0.17""" },
    { "rate" : """0.15""" },
    { "rate" : """2""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """1.999""" },
    { "rate" : """0.09877""" },
    { "rate" : """12""" },
    { "rate" : """13.72""" },
    { "rate" : """1.12""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """2""" },
    { "rate" : """0.5""" },
    { "rate" : """3.2""" },
    { "rate" : """5.99999""" },
    { "rate" : """12.46""" },
    { "rate" : """1.98""" },
    { "rate" : """0.3""" },
    { "rate" : """0.4987""" },
    { "rate" : """1.99999""" },
    { "rate" : """0.4899""" },
    { "rate" : """0.47999""" },
    { "rate" : """0.372""" },
    { "rate" : """4.99972""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """13.09998""" },
    { "rate" : """1.99999""" },
    { "rate" : """10""" },
    { "rate" : """9.99998""" },
    { "rate" : """16.17""" },
    { "rate" : """10""" },
    { "rate" : """9.99998""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """1.12""" },
    { "rate" : """1.12""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.99""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """13.72""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """0.5""" },
    { "rate" : """2""" },
    { "rate" : """13.11""" },
    { "rate" : """3.99998""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """3.2""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """0.499""" },
    { "rate" : """17.45""" },
    { "rate" : """0.49899""" },
    { "rate" : """0.499""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """0.48999""" },
    { "rate" : """0.48999""" },
    { "rate" : """0.48999""" },
    { "rate" : """0.44899""" },
    { "rate" : """0.5""" },
    { "rate" : """13.11""" },
    { "rate" : """0.09998""" },
    { "rate" : """4""" },
    { "rate" : """12.25999""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.5""" },
    { "rate" : """1.49999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.49""" },
    { "rate" : """15""" },
    { "rate" : """1.9""" },
    { "rate" : """0.5""" },
    { "rate" : """23.5""" },
    { "rate" : """0.49989""" },
    { "rate" : """9.99998""" },
    { "rate" : """0.44987""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """11.99998""" },
    { "rate" : """0.5""" },
    { "rate" : """13.11""" },
    { "rate" : """1.9""" },
    { "rate" : """0.44""" },
    { "rate" : """0.25""" },
    { "rate" : """9.74998""" },
    { "rate" : """9.99999""" },
    { "rate" : """4.99""" },
    { "rate" : """1.12""" },
    { "rate" : """9.49""" },
    { "rate" : """9.9""" },
    { "rate" : """15""" },
    { "rate" : """3.75""" },
    { "rate" : """11.11111""" },
    { "rate" : """0.38998""" },
    { "rate" : """0.47""" },
    { "rate" : """9.99972""" },
    { "rate" : """11.9999""" },
    { "rate" : """0.45999""" },
    { "rate" : """0.48989""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """0.4899""" },
    { "rate" : """0.4""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """0.472""" },
    { "rate" : """0.49989""" },
    { "rate" : """0.5""" },
    { "rate" : """0.499""" },
    { "rate" : """0.48999""" },
    { "rate" : """0.49972""" },
    { "rate" : """0.5""" },
    { "rate" : """0.499""" },
    { "rate" : """0.48999""" },
    { "rate" : """0.4989""" },
    { "rate" : """13.72""" },
    { "rate" : """0.48999""" },
    { "rate" : """0.48999""" },
    { "rate" : """6""" },
    { "rate" : """1.99999""" },
    { "rate" : """17.48""" },
    { "rate" : """1.12""" },
    { "rate" : """2""" },
    { "rate" : """12.26""" },
    { "rate" : """2""" },
    { "rate" : """23.58""" },
    { "rate" : """5.95""" },
    { "rate" : """0.44987""" },
    { "rate" : """3.2""" },
    { "rate" : """0.44889""" },
    { "rate" : """0.15""" },
    { "rate" : """5""" },
    { "rate" : """0.3""" },
    { "rate" : """9.999""" },
    { "rate" : """5.9995""" },
    { "rate" : """12.26""" },
    { "rate" : """15.999""" },
    { "rate" : """4.999""" },
    { "rate" : """0.48999""" },
    { "rate" : """0.472""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """0.29998""" },
    { "rate" : """1.5""" },
    { "rate" : """3.2""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """1.9999""" },
    { "rate" : """4.95""" },
    { "rate" : """3.19999""" },
    { "rate" : """2""" },
    { "rate" : """5.99999""" },
    { "rate" : """0.48999""" },
    { "rate" : """0.34""" },
    { "rate" : """2""" },
    { "rate" : """0.449""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """3.1""" },
    { "rate" : """6""" },
    { "rate" : """23""" },
    { "rate" : """1.9999""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """0.49""" },
    { "rate" : """0.45""" },
    { "rate" : """9""" },
    { "rate" : """13.11""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """0.42999""" },
    { "rate" : """0.48999""" },
    { "rate" : """0.4""" },
    { "rate" : """0.49""" },
    { "rate" : """23.58""" },
    { "rate" : """1.11999""" },
    { "rate" : """0.43""" },
    { "rate" : """16""" },
    { "rate" : """12.26""" },
    { "rate" : """0.427""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """13.11""" },
    { "rate" : """8""" },
    { "rate" : """3.2""" },
    { "rate" : """8""" },
    { "rate" : """7.9""" },
    { "rate" : """7""" },
    { "rate" : """0.4""" },
    { "rate" : """0.5""" },
    { "rate" : """1.12""" },
    { "rate" : """0.44""" },
    { "rate" : """7""" },
    { "rate" : """0.36889""" },
    { "rate" : """23.5""" },
    { "rate" : """4.8""" },
    { "rate" : """0.47999""" },
    { "rate" : """7.9""" },
    { "rate" : """6.99999""" },
    { "rate" : """10.73""" },
    { "rate" : """0.34""" },
    { "rate" : """0.39999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.41""" },
    { "rate" : """0.45""" },
    { "rate" : """0.4""" },
    { "rate" : """15""" },
    { "rate" : """0.5""" },
    { "rate" : """0.472""" },
    { "rate" : """0.4""" },
    { "rate" : """7.7722""" },
    { "rate" : """0.48""" },
    { "rate" : """10""" },
    { "rate" : """23.58""" },
    { "rate" : """0.4""" },
    { "rate" : """0.5""" },
    { "rate" : """0.499""" },
    { "rate" : """3.15""" },
    { "rate" : """0.44999""" },
    { "rate" : """0.45""" },
    { "rate" : """0.42""" },
    { "rate" : """0.5""" },
    { "rate" : """7.9""" },
    { "rate" : """0.5""" },
    { "rate" : """1""" },
    { "rate" : """0.5""" },
    { "rate" : """0.465""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.44899""" },
    { "rate" : """0.48998""" },
    { "rate" : """4.9""" },
    { "rate" : """20""" },
    { "rate" : """3.9""" },
    { "rate" : """1.11999""" },
    { "rate" : """13.72""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """0.4""" },
    { "rate" : """23.5""" },
    { "rate" : """0.3""" },
    { "rate" : """3.2""" },
    { "rate" : """3""" },
    { "rate" : """11""" },
    { "rate" : """6.5""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """4.5""" },
    { "rate" : """23.5""" },
    { "rate" : """13.72""" },
    { "rate" : """12.26""" },
    { "rate" : """0.44999""" },
    { "rate" : """0.49998""" },
    { "rate" : """4""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.1""" },
    { "rate" : """0.5""" },
    { "rate" : """0.3""" },
    { "rate" : """23.58""" },
    { "rate" : """0.489""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.35""" },
    { "rate" : """0.29989""" },
    { "rate" : """0.38""" },
    { "rate" : """0.42""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """0.35""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.29998""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3.2""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """7.99""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """3.2""" },
    { "rate" : """11""" },
    { "rate" : """0.09889""" },
    { "rate" : """5""" },
    { "rate" : """0.09""" },
    { "rate" : """3""" },
    { "rate" : """12.26""" },
    { "rate" : """12""" },
    { "rate" : """12.26""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """3.2""" },
    { "rate" : """0.19989""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """3""" },
    { "rate" : """9.95""" },
    { "rate" : """13.10999""" },
    { "rate" : """0.6999""" },
    { "rate" : """13.044""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """7.98""" },
    { "rate" : """3.9999""" },
    { "rate" : """13.72""" },
    { "rate" : """9.75""" },
    { "rate" : """0.288""" },
    { "rate" : """3.2""" },
    { "rate" : """3.2""" },
    { "rate" : """4""" },
    { "rate" : """13.72""" },
    { "rate" : """10.73""" },
    { "rate" : """3""" },
    { "rate" : """23.58""" },
    { "rate" : """13.72""" },
    { "rate" : """3.2""" },
    { "rate" : """0.1""" },
    { "rate" : """0.15""" },
    { "rate" : """0.1""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """0.0989""" },
    { "rate" : """3.2""" },
    { "rate" : """13.11""" },
    { "rate" : """16""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """8.88889""" },
    { "rate" : """13.10999""" },
    { "rate" : """13.72""" },
    { "rate" : """23.58""" },
    { "rate" : """9.9""" },
    { "rate" : """4.9""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """13.1""" },
    { "rate" : """7.9""" },
    { "rate" : """13.11""" },
    { "rate" : """5.9""" },
    { "rate" : """11.9""" },
    { "rate" : """11.9""" },
    { "rate" : """11.5""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """16.17""" },
    { "rate" : """5.8""" },
    { "rate" : """0.499""" },
    { "rate" : """13""" },
    { "rate" : """16""" },
    { "rate" : """9.9""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """12.9""" },
    { "rate" : """15""" },
    { "rate" : """12.05""" },
    { "rate" : """13""" },
    { "rate" : """12.88""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """5.9""" },
    { "rate" : """2""" },
    { "rate" : """8.9""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """6.88""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """3.2""" },
    { "rate" : """5""" },
    { "rate" : """8.72""" },
    { "rate" : """12""" },
    { "rate" : """11.99999""" },
    { "rate" : """5""" },
    { "rate" : """3.2""" },
    { "rate" : """12.45""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """12.46""" },
    { "rate" : """0.00042""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """12""" },
    { "rate" : """7.99999""" },
    { "rate" : """16""" },
    { "rate" : """9.9""" },
    { "rate" : """8.8""" },
    { "rate" : """4.49""" },
    { "rate" : """8.79999""" },
    { "rate" : """8.8""" },
    { "rate" : """12""" },
    { "rate" : """7.99972""" },
    { "rate" : """16.17""" },
    { "rate" : """9.9""" },
    { "rate" : """16""" },
    { "rate" : """12.26""" },
    { "rate" : """6""" },
    { "rate" : """7.95""" },
    { "rate" : """1""" },
    { "rate" : """3.2""" },
    { "rate" : """12.25""" },
    { "rate" : """4.95""" },
    { "rate" : """11""" },
    { "rate" : """13.7""" },
    { "rate" : """0.4""" },
    { "rate" : """14.95""" },
    { "rate" : """3.2""" },
    { "rate" : """15""" },
    { "rate" : """8.8""" },
    { "rate" : """15.9999""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """8.7""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """7.9999""" },
    { "rate" : """7.99""" },
    { "rate" : """12.98""" },
    { "rate" : """0.2""" },
    { "rate" : """0.34987""" },
    { "rate" : """0.34""" },
    { "rate" : """0.05""" },
    { "rate" : """0.27999""" },
    { "rate" : """0.28""" },
    { "rate" : """12.99998""" },
    { "rate" : """5""" },
    { "rate" : """0.3""" },
    { "rate" : """11.99998""" },
    { "rate" : """0.2""" },
    { "rate" : """0.4""" },
    { "rate" : """0.4""" },
    { "rate" : """23.58""" },
    { "rate" : """12.96999""" },
    { "rate" : """4.99998""" },
    { "rate" : """0.39989""" },
    { "rate" : """0.47""" },
    { "rate" : """0.5""" },
    { "rate" : """3.2""" },
    { "rate" : """15.55""" },
    { "rate" : """0.4987""" },
    { "rate" : """0.4""" },
    { "rate" : """0.29999""" },
    { "rate" : """0.29999""" },
    { "rate" : """0.49979""" },
    { "rate" : """8.8""" },
    { "rate" : """12.11""" },
    { "rate" : """11.99999""" },
    { "rate" : """4.5""" },
    { "rate" : """13.9""" },
    { "rate" : """1.9999""" },
    { "rate" : """0.24988""" },
    { "rate" : """0.288""" },
    { "rate" : """10""" },
    { "rate" : """0.25""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.99996""" },
    { "rate" : """0.27899""" },
    { "rate" : """6""" },
    { "rate" : """0.4""" },
    { "rate" : """0.49998""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.4""" },
    { "rate" : """0.5""" },
    { "rate" : """0.39989""" },
    { "rate" : """0.5""" },
    { "rate" : """13.71""" },
    { "rate" : """0.4989""" },
    { "rate" : """0.49989""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.49998""" },
    { "rate" : """0.5""" },
    { "rate" : """0.3""" },
    { "rate" : """0.45""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.29989""" },
    { "rate" : """0.4989""" },
    { "rate" : """13.72""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.09998""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """3.2""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """0.99999""" },
    { "rate" : """4""" },
    { "rate" : """15.599""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99989""" },
    { "rate" : """18.98""" },
    { "rate" : """1""" },
    { "rate" : """13.72""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.9987""" },
    { "rate" : """0.24999""" },
    { "rate" : """18.98""" },
    { "rate" : """0.25""" },
    { "rate" : """13.11""" },
    { "rate" : """0.975""" },
    { "rate" : """0.9999""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """10.99999""" },
    { "rate" : """15.99989""" },
    { "rate" : """18.98""" },
    { "rate" : """0.46999""" },
    { "rate" : """0.39999""" },
    { "rate" : """0.38998""" },
    { "rate" : """0.43999""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """0.39""" },
    { "rate" : """0.4""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.4""" },
    { "rate" : """0.45""" },
    { "rate" : """0.4""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.4699""" },
    { "rate" : """0.44""" },
    { "rate" : """0.8""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """18.98""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """0.35""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """18.98""" },
    { "rate" : """1""" },
    { "rate" : """13.72""" },
    { "rate" : """13.11""" },
    { "rate" : """1""" },
    { "rate" : """0.98999""" },
    { "rate" : """9.99""" },
    { "rate" : """12""" },
    { "rate" : """12.26""" },
    { "rate" : """1""" },
    { "rate" : """11""" },
    { "rate" : """13.11""" },
    { "rate" : """23.58""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.09998""" },
    { "rate" : """0.97""" },
    { "rate" : """0.49""" },
    { "rate" : """0.79999""" },
    { "rate" : """13""" },
    { "rate" : """0.972""" },
    { "rate" : """0.472""" },
    { "rate" : """0.5""" },
    { "rate" : """1.99""" },
    { "rate" : """15""" },
    { "rate" : """0.5""" },
    { "rate" : """12.26""" },
    { "rate" : """0.4987""" },
    { "rate" : """2""" },
    { "rate" : """13.11""" },
    { "rate" : """0.49989""" },
    { "rate" : """0.49999""" },
    { "rate" : """13.5""" },
    { "rate" : """12.3""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """4""" },
    { "rate" : """0.4""" },
    { "rate" : """16""" },
    { "rate" : """0.96""" },
    { "rate" : """0.5""" },
    { "rate" : """0.48999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.19998""" },
    { "rate" : """0.49""" },
    { "rate" : """0.4989""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.95""" },
    { "rate" : """4""" },
    { "rate" : """0.5""" },
    { "rate" : """2""" },
    { "rate" : """0.19999""" },
    { "rate" : """0.09998""" },
    { "rate" : """0.47""" },
    { "rate" : """0.499""" },
    { "rate" : """0.19""" },
    { "rate" : """0.45""" },
    { "rate" : """0.99999""" },
    { "rate" : """13.11""" },
    { "rate" : """4""" },
    { "rate" : """0.99999""" },
    { "rate" : """7.5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """0.2227""" },
    { "rate" : """0.472""" },
    { "rate" : """0.5""" },
    { "rate" : """0.973""" },
    { "rate" : """0.5""" },
    { "rate" : """0.33""" },
    { "rate" : """0.31""" },
    { "rate" : """18.98""" },
    { "rate" : """13.5""" },
    { "rate" : """0.75""" },
    { "rate" : """0.4""" },
    { "rate" : """0.40999""" },
    { "rate" : """0.4999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.99""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.4999""" },
    { "rate" : """0.48999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.46899""" },
    { "rate" : """3.95""" },
    { "rate" : """18.98""" },
    { "rate" : """18.25""" },
    { "rate" : """10""" },
    { "rate" : """4.99999""" },
    { "rate" : """7.5""" },
    { "rate" : """9.96""" },
    { "rate" : """0.45""" },
    { "rate" : """0.4098""" },
    { "rate" : """0.49989""" },
    { "rate" : """9""" },
    { "rate" : """0.19998""" },
    { "rate" : """0.325""" },
    { "rate" : """4""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """9.96""" },
    { "rate" : """0.0017""" },
    { "rate" : """0.5""" },
    { "rate" : """9.96""" },
    { "rate" : """0.5""" },
    { "rate" : """9.96""" },
    { "rate" : """11.99""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """7.99998""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """8.79""" },
    { "rate" : """9.99""" },
    { "rate" : """9.99""" },
    { "rate" : """14.99""" },
    { "rate" : """11""" },
    { "rate" : """13.33333""" },
    { "rate" : """13.33""" },
    { "rate" : """3.99""" },
    { "rate" : """9.96""" },
    { "rate" : """7""" },
    { "rate" : """9.96""" },
    { "rate" : """4.99998""" },
    { "rate" : """11""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """14""" },
    { "rate" : """9.96""" },
    { "rate" : """13.25""" },
    { "rate" : """4""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """12.26""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.9""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """9.96""" },
    { "rate" : """0.989""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """0.4999""" },
    { "rate" : """18""" },
    { "rate" : """7""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """12""" },
    { "rate" : """0.99999""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """7""" },
    { "rate" : """10.73""" },
    { "rate" : """11.5""" },
    { "rate" : """9.96""" },
    { "rate" : """3.195""" },
    { "rate" : """0.5""" },
    { "rate" : """9.96""" },
    { "rate" : """0.5""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """12.26""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """6""" },
    { "rate" : """9.96""" },
    { "rate" : """9.959""" },
    { "rate" : """9.99998""" },
    { "rate" : """0.01""" },
    { "rate" : """7.44998""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """13.3""" },
    { "rate" : """9.96""" },
    { "rate" : """23.58""" },
    { "rate" : """9.96""" },
    { "rate" : """15.14""" },
    { "rate" : """13.33""" },
    { "rate" : """16""" },
    { "rate" : """15""" },
    { "rate" : """12.26""" },
    { "rate" : """0.9""" },
    { "rate" : """0.5""" },
    { "rate" : """9.95""" },
    { "rate" : """3.199""" },
    { "rate" : """0.4989""" },
    { "rate" : """0.989""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """12.9""" },
    { "rate" : """9.96""" },
    { "rate" : """13.11""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """0.05""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """9.96""" },
    { "rate" : """0.99999""" },
    { "rate" : """23.58""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """9.95999""" },
    { "rate" : """12""" },
    { "rate" : """7.99999""" },
    { "rate" : """15""" },
    { "rate" : """4.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """0.49""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.9""" },
    { "rate" : """0.2""" },
    { "rate" : """3""" },
    { "rate" : """0.9""" },
    { "rate" : """0.4""" },
    { "rate" : """3.1""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """3.199""" },
    { "rate" : """2.9""" },
    { "rate" : """8.99""" },
    { "rate" : """11.899""" },
    { "rate" : """9.99""" },
    { "rate" : """3.19899""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.1922""" },
    { "rate" : """9.96""" },
    { "rate" : """4.79999""" },
    { "rate" : """11.98""" },
    { "rate" : """18.97""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """0.93""" },
    { "rate" : """0.99""" },
    { "rate" : """1.167""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """7""" },
    { "rate" : """9.95""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """9.96""" },
    { "rate" : """6""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """20""" },
    { "rate" : """6""" },
    { "rate" : """9.95""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """0.49999""" },
    { "rate" : """14.5""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """13""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """7.9""" },
    { "rate" : """10""" },
    { "rate" : """18.96999""" },
    { "rate" : """7.99989""" },
    { "rate" : """7.9999""" },
    { "rate" : """8""" },
    { "rate" : """7.99999""" },
    { "rate" : """6.2""" },
    { "rate" : """8""" },
    { "rate" : """7.99989""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """0.5""" },
    { "rate" : """12.5""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """5.9""" },
    { "rate" : """7.8999""" },
    { "rate" : """8""" },
    { "rate" : """0.48""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.49999""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """7.99979""" },
    { "rate" : """7.95""" },
    { "rate" : """5""" },
    { "rate" : """0.45""" },
    { "rate" : """8""" },
    { "rate" : """0.5""" },
    { "rate" : """13.11""" },
    { "rate" : """7.99""" },
    { "rate" : """0.44""" },
    { "rate" : """6""" },
    { "rate" : """1.999""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """20""" },
    { "rate" : """3.927""" },
    { "rate" : """18.95""" },
    { "rate" : """18.7298""" },
    { "rate" : """7.99999""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """13.72""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """7.999""" },
    { "rate" : """7""" },
    { "rate" : """13.72""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """7.9""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """7.99""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """6""" },
    { "rate" : """0.01""" },
    { "rate" : """7.99999""" },
    { "rate" : """5""" },
    { "rate" : """0.49979""" },
    { "rate" : """9.96""" },
    { "rate" : """0.45""" },
    { "rate" : """13.72""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.27999""" },
    { "rate" : """0.279""" },
    { "rate" : """5""" },
    { "rate" : """9.99998""" },
    { "rate" : """0.26999""" },
    { "rate" : """0.45888""" },
    { "rate" : """3.9""" },
    { "rate" : """7.97998""" },
    { "rate" : """0.25""" },
    { "rate" : """0.4""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """11.9""" },
    { "rate" : """9.89999""" },
    { "rate" : """5""" },
    { "rate" : """9.79999""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1.5""" },
    { "rate" : """0.23456""" },
    { "rate" : """0.3""" },
    { "rate" : """11.5""" },
    { "rate" : """9.95""" },
    { "rate" : """8""" },
    { "rate" : """4.9""" },
    { "rate" : """0.39999""" },
    { "rate" : """0.4""" },
    { "rate" : """7.89999""" },
    { "rate" : """17""" },
    { "rate" : """6.85""" },
    { "rate" : """9.5""" },
    { "rate" : """0.39""" },
    { "rate" : """0.39989""" },
    { "rate" : """4.98999""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """0.4998""" },
    { "rate" : """19.95""" },
    { "rate" : """0.45""" },
    { "rate" : """0.39""" },
    { "rate" : """7.5""" },
    { "rate" : """8""" },
    { "rate" : """9.99""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """9.95""" },
    { "rate" : """7.9998""" },
    { "rate" : """9.94""" },
    { "rate" : """9.95""" },
    { "rate" : """6.99999""" },
    { "rate" : """7""" },
    { "rate" : """7.999""" },
    { "rate" : """18.97""" },
    { "rate" : """11.99""" },
    { "rate" : """4.98""" },
    { "rate" : """7""" },
    { "rate" : """6.8""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """7.99""" },
    { "rate" : """5""" },
    { "rate" : """6.9""" },
    { "rate" : """7.9""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """13.33333""" },
    { "rate" : """9.95""" },
    { "rate" : """12.26""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """0.1""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """0.29999""" },
    { "rate" : """4.5""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.25""" },
    { "rate" : """0.485""" },
    { "rate" : """9.96""" },
    { "rate" : """0.5""" },
    { "rate" : """4.9999""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """0.27999""" },
    { "rate" : """12""" },
    { "rate" : """4.99999""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.2799""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """0.45""" },
    { "rate" : """0.45""" },
    { "rate" : """0.4999""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """0.2""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.4""" },
    { "rate" : """0.49999""" },
    { "rate" : """9.96""" },
    { "rate" : """0.2""" },
    { "rate" : """7.9""" },
    { "rate" : """0.39""" },
    { "rate" : """0.5""" },
    { "rate" : """6.5""" },
    { "rate" : """17.48""" },
    { "rate" : """4.95""" },
    { "rate" : """7""" },
    { "rate" : """0.5""" },
    { "rate" : """4.5""" },
    { "rate" : """12.26""" },
    { "rate" : """0.27999""" },
    { "rate" : """5""" },
    { "rate" : """0.27999""" },
    { "rate" : """9.99999""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """0.4999""" },
    { "rate" : """5""" },
    { "rate" : """0.975""" },
    { "rate" : """1""" },
    { "rate" : """7.5""" },
    { "rate" : """10.73""" },
    { "rate" : """0.2888""" },
    { "rate" : """0.99998""" },
    { "rate" : """1""" },
    { "rate" : """11.99999""" },
    { "rate" : """4.55""" },
    { "rate" : """5""" },
    { "rate" : """0.88""" },
    { "rate" : """13""" },
    { "rate" : """11.8""" },
    { "rate" : """0.28""" },
    { "rate" : """0.99999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """9.96""" },
    { "rate" : """8.5""" },
    { "rate" : """0.27""" },
    { "rate" : """0.4""" },
    { "rate" : """4.9""" },
    { "rate" : """12.46""" },
    { "rate" : """0.2""" },
    { "rate" : """0.85""" },
    { "rate" : """7.9""" },
    { "rate" : """0.28""" },
    { "rate" : """6""" },
    { "rate" : """0.28""" },
    { "rate" : """5""" },
    { "rate" : """12.4""" },
    { "rate" : """0.8""" },
    { "rate" : """0.9""" },
    { "rate" : """8""" },
    { "rate" : """7.5""" },
    { "rate" : """5""" },
    { "rate" : """0.3999""" },
    { "rate" : """0.27988""" },
    { "rate" : """0.79989""" },
    { "rate" : """0.4""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.35""" },
    { "rate" : """0.27""" },
    { "rate" : """6.5""" },
    { "rate" : """7.5""" },
    { "rate" : """7""" },
    { "rate" : """4.95""" },
    { "rate" : """0.3""" },
    { "rate" : """10""" },
    { "rate" : """7.5""" },
    { "rate" : """7.9""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """0.24999""" },
    { "rate" : """0.04898""" },
    { "rate" : """4.87""" },
    { "rate" : """3.35""" },
    { "rate" : """3.35""" },
    { "rate" : """4.89998""" },
    { "rate" : """5""" },
    { "rate" : """7.99""" },
    { "rate" : """12.45998""" },
    { "rate" : """7""" },
    { "rate" : """11.99998""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """4.99""" },
    { "rate" : """9.96""" },
    { "rate" : """4.98999""" },
    { "rate" : """13""" },
    { "rate" : """7.99""" },
    { "rate" : """7.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """7.9""" },
    { "rate" : """9.96""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """7.1""" },
    { "rate" : """0.34998""" },
    { "rate" : """0.35""" },
    { "rate" : """0.4""" },
    { "rate" : """0.5""" },
    { "rate" : """0.38998""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49998""" },
    { "rate" : """0.5""" },
    { "rate" : """0.40999""" },
    { "rate" : """0.40999""" },
    { "rate" : """0.40999""" },
    { "rate" : """8""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """7.95""" },
    { "rate" : """0.39""" },
    { "rate" : """0.39""" },
    { "rate" : """5""" },
    { "rate" : """0.39""" },
    { "rate" : """3.35""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """0.39999""" },
    { "rate" : """0.34999""" },
    { "rate" : """0.059""" },
    { "rate" : """17.48""" },
    { "rate" : """0.35""" },
    { "rate" : """0.34998""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """0.47999""" },
    { "rate" : """0.4999""" },
    { "rate" : """6""" },
    { "rate" : """0.48""" },
    { "rate" : """0.46998""" },
    { "rate" : """7.99998""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """0.18999""" },
    { "rate" : """5""" },
    { "rate" : """9.44998""" },
    { "rate" : """3.35""" },
    { "rate" : """9.49999""" },
    { "rate" : """0.16999""" },
    { "rate" : """9.49999""" },
    { "rate" : """12.5""" },
    { "rate" : """9.5""" },
    { "rate" : """8""" },
    { "rate" : """0.09998""" },
    { "rate" : """4.75""" },
    { "rate" : """0.18999""" },
    { "rate" : """4""" },
    { "rate" : """14""" },
    { "rate" : """9.4""" },
    { "rate" : """9.96""" },
    { "rate" : """9""" },
    { "rate" : """9.4""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """0.49""" },
    { "rate" : """0.4""" },
    { "rate" : """12""" },
    { "rate" : """0.01""" },
    { "rate" : """12.69""" },
    { "rate" : """13""" },
    { "rate" : """4.95""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """12.26""" },
    { "rate" : """9.96""" },
    { "rate" : """9.38""" },
    { "rate" : """9.5""" },
    { "rate" : """25""" },
    { "rate" : """13""" },
    { "rate" : """30""" },
    { "rate" : """9.96""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """6.9""" },
    { "rate" : """9.95""" },
    { "rate" : """5""" },
    { "rate" : """19""" },
    { "rate" : """10.73""" },
    { "rate" : """13.1""" },
    { "rate" : """9.5""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.35""" },
    { "rate" : """9.96""" },
    { "rate" : """4.88""" },
    { "rate" : """9.96""" },
    { "rate" : """18""" },
    { "rate" : """17.48""" },
    { "rate" : """10""" },
    { "rate" : """10.73""" },
    { "rate" : """9.95""" },
    { "rate" : """3.99""" },
    { "rate" : """13.37""" },
    { "rate" : """0.17299""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7.8""" },
    { "rate" : """0.01""" },
    { "rate" : """3.35""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """3.35""" },
    { "rate" : """3.99999""" },
    { "rate" : """10""" },
    { "rate" : """3.97""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """4.5""" },
    { "rate" : """14.99995""" },
    { "rate" : """10.73""" },
    { "rate" : """3.99""" },
    { "rate" : """17.48""" },
    { "rate" : """19""" },
    { "rate" : """5""" },
    { "rate" : """4.87995""" },
    { "rate" : """9.5""" },
    { "rate" : """3.99995""" },
    { "rate" : """4.99995""" },
    { "rate" : """0.01""" },
    { "rate" : """9.96""" },
    { "rate" : """9.5""" },
    { "rate" : """9.5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """0.16999""" },
    { "rate" : """4.5""" },
    { "rate" : """3.3""" },
    { "rate" : """9.49""" },
    { "rate" : """0.17""" },
    { "rate" : """7.5""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """0.06""" },
    { "rate" : """5""" },
    { "rate" : """4.25""" },
    { "rate" : """3.35""" },
    { "rate" : """7.9""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """4.99""" },
    { "rate" : """3.333""" },
    { "rate" : """0.18""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.9999""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """12""" },
    { "rate" : """9.5""" },
    { "rate" : """4.9""" },
    { "rate" : """9.5""" },
    { "rate" : """9.96""" },
    { "rate" : """11.9""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """12.46""" },
    { "rate" : """9""" },
    { "rate" : """17.48""" },
    { "rate" : """9.5""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """9.5""" },
    { "rate" : """8""" },
    { "rate" : """18""" },
    { "rate" : """17.48""" },
    { "rate" : """1.75""" },
    { "rate" : """1.75""" },
    { "rate" : """1.75""" },
    { "rate" : """1.74""" },
    { "rate" : """1.75""" },
    { "rate" : """1.74""" },
    { "rate" : """1.65""" },
    { "rate" : """1.74999""" },
    { "rate" : """1.7""" },
    { "rate" : """1.75""" },
    { "rate" : """1.741""" },
    { "rate" : """1.75""" },
    { "rate" : """1.74999""" },
    { "rate" : """1.74999""" },
    { "rate" : """1.73999""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """1.525""" },
    { "rate" : """1.74987""" },
    { "rate" : """1.7""" },
    { "rate" : """1.7""" },
    { "rate" : """5""" },
    { "rate" : """1.7""" },
    { "rate" : """1.74""" },
    { "rate" : """1.74995""" },
    { "rate" : """1.71999""" },
    { "rate" : """1.73333""" },
    { "rate" : """1.74998""" },
    { "rate" : """1.74999""" },
    { "rate" : """1.74""" },
    { "rate" : """1.74""" },
    { "rate" : """1.74""" },
    { "rate" : """1.74""" },
    { "rate" : """23.58""" },
    { "rate" : """1.5""" },
    { "rate" : """10""" },
    { "rate" : """1.739""" },
    { "rate" : """11""" },
    { "rate" : """10.73""" },
    { "rate" : """1.7""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """0.08888""" },
    { "rate" : """6""" },
    { "rate" : """1.7""" },
    { "rate" : """12.46""" },
    { "rate" : """19""" },
    { "rate" : """1.6""" },
    { "rate" : """1.725""" },
    { "rate" : """14.99999""" },
    { "rate" : """1.748""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """15.99998""" },
    { "rate" : """12.9999""" },
    { "rate" : """8""" },
    { "rate" : """7.99998""" },
    { "rate" : """8""" },
    { "rate" : """18.97""" },
    { "rate" : """9.99998""" },
    { "rate" : """14""" },
    { "rate" : """12.9999""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """9.4""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.45""" },
    { "rate" : """0.5""" },
    { "rate" : """0.35""" },
    { "rate" : """0.4""" },
    { "rate" : """0.3987""" },
    { "rate" : """0.39998""" },
    { "rate" : """4.99""" },
    { "rate" : """9.96""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """0.45""" },
    { "rate" : """7""" },
    { "rate" : """9.89998""" },
    { "rate" : """9.5""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """10.73""" },
    { "rate" : """9.96""" },
    { "rate" : """17.48""" },
    { "rate" : """11.9999""" },
    { "rate" : """13.72""" },
    { "rate" : """9.96""" },
    { "rate" : """9.99999""" },
    { "rate" : """10.72999""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.95999""" },
    { "rate" : """4.9""" },
    { "rate" : """9.5""" },
    { "rate" : """12.46""" },
    { "rate" : """0.5""" },
    { "rate" : """0.45""" },
    { "rate" : """0.49""" },
    { "rate" : """0.4""" },
    { "rate" : """0.5""" },
    { "rate" : """13.72""" },
    { "rate" : """0.4""" },
    { "rate" : """13.72""" },
    { "rate" : """0.4""" },
    { "rate" : """0.4""" },
    { "rate" : """9""" },
    { "rate" : """9.75""" },
    { "rate" : """5""" },
    { "rate" : """0.39998""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """0.74998""" },
    { "rate" : """0.87999""" },
    { "rate" : """1.24999""" },
    { "rate" : """0.85""" },
    { "rate" : """12.46""" },
    { "rate" : """14.96""" },
    { "rate" : """1.25""" },
    { "rate" : """7.49999""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """8""" },
    { "rate" : """12.5""" },
    { "rate" : """1.24998""" },
    { "rate" : """1.25""" },
    { "rate" : """0.39998""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.45""" },
    { "rate" : """0.4""" },
    { "rate" : """0.495""" },
    { "rate" : """0.49""" },
    { "rate" : """0.498""" },
    { "rate" : """9.5""" },
    { "rate" : """1.25""" },
    { "rate" : """1.23""" },
    { "rate" : """0.5""" },
    { "rate" : """6.9""" },
    { "rate" : """6.49999""" },
    { "rate" : """6.99999""" },
    { "rate" : """5.99998""" },
    { "rate" : """6.99""" },
    { "rate" : """6.9998""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """6.9""" },
    { "rate" : """0.85""" },
    { "rate" : """3.5""" },
    { "rate" : """13""" },
    { "rate" : """6""" },
    { "rate" : """6.999""" },
    { "rate" : """7""" },
    { "rate" : """0.75""" },
    { "rate" : """9.96""" },
    { "rate" : """6.95""" },
    { "rate" : """4.95""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """6.9""" },
    { "rate" : """0.5987""" },
    { "rate" : """7""" },
    { "rate" : """0.7""" },
    { "rate" : """1""" },
    { "rate" : """0.49""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """6.99""" },
    { "rate" : """6.99""" },
    { "rate" : """6.9""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """6.999""" },
    { "rate" : """4.5""" },
    { "rate" : """6.9""" },
    { "rate" : """11""" },
    { "rate" : """19""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """17.48""" },
    { "rate" : """18.9999""" },
    { "rate" : """6.95""" },
    { "rate" : """12.99999""" },
    { "rate" : """12.46""" },
    { "rate" : """1.24""" },
    { "rate" : """13""" },
    { "rate" : """6.99998""" },
    { "rate" : """14.5""" },
    { "rate" : """20""" },
    { "rate" : """9.5""" },
    { "rate" : """9.96""" },
    { "rate" : """1.24""" },
    { "rate" : """6.99""" },
    { "rate" : """7""" },
    { "rate" : """9.96""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """14.8""" },
    { "rate" : """7""" },
    { "rate" : """9.49""" },
    { "rate" : """13.72""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """14.9""" },
    { "rate" : """13""" },
    { "rate" : """19.95""" },
    { "rate" : """25""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9.5""" },
    { "rate" : """7""" },
    { "rate" : """13.72""" },
    { "rate" : """7""" },
    { "rate" : """6.98""" },
    { "rate" : """6.99998""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """6.9""" },
    { "rate" : """6.99""" },
    { "rate" : """12.41""" },
    { "rate" : """12.5""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """7""" },
    { "rate" : """9.49""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """7""" },
    { "rate" : """6.75""" },
    { "rate" : """9.96""" },
    { "rate" : """8.5""" },
    { "rate" : """7""" },
    { "rate" : """13.11""" },
    { "rate" : """15""" },
    { "rate" : """7.5""" },
    { "rate" : """12.46""" },
    { "rate" : """12""" },
    { "rate" : """13""" },
    { "rate" : """12.46""" },
    { "rate" : """6.8""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """12.999""" },
    { "rate" : """6.5""" },
    { "rate" : """18.96""" },
    { "rate" : """6.9""" },
    { "rate" : """12.96""" },
    { "rate" : """6.3""" },
    { "rate" : """6.95""" },
    { "rate" : """5""" },
    { "rate" : """6.9""" },
    { "rate" : """7.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """6.9999""" },
    { "rate" : """5""" },
    { "rate" : """9.5""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """6.4""" },
    { "rate" : """9.96""" },
    { "rate" : """7.69989""" },
    { "rate" : """11""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """2.5""" },
    { "rate" : """11""" },
    { "rate" : """1.5""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """6.5""" },
    { "rate" : """9.5""" },
    { "rate" : """5.5""" },
    { "rate" : """17.47""" },
    { "rate" : """17.48""" },
    { "rate" : """10""" },
    { "rate" : """6.6""" },
    { "rate" : """7""" },
    { "rate" : """7.69999""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """17.45""" },
    { "rate" : """5""" },
    { "rate" : """3.9""" },
    { "rate" : """1.4""" },
    { "rate" : """2.999""" },
    { "rate" : """7.66679""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """15""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """17""" },
    { "rate" : """17""" },
    { "rate" : """7.69999""" },
    { "rate" : """7.699""" },
    { "rate" : """12.99""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """3.5""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """10.73""" },
    { "rate" : """16""" },
    { "rate" : """2.999""" },
    { "rate" : """3.5""" },
    { "rate" : """17.48""" },
    { "rate" : """3.5""" },
    { "rate" : """7""" },
    { "rate" : """9.96""" },
    { "rate" : """17.48""" },
    { "rate" : """3.5""" },
    { "rate" : """9.96""" },
    { "rate" : """13""" },
    { "rate" : """14.95""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """6.98""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """16.17""" },
    { "rate" : """17.48""" },
    { "rate" : """14.5""" },
    { "rate" : """3.5""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7.5""" },
    { "rate" : """7.6""" },
    { "rate" : """3.64""" },
    { "rate" : """23.58""" },
    { "rate" : """12.45""" },
    { "rate" : """17.48""" },
    { "rate" : """0.5""" },
    { "rate" : """1.25""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """17.47""" },
    { "rate" : """3.5""" },
    { "rate" : """15""" },
    { "rate" : """7.69998""" },
    { "rate" : """17.48""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """13""" },
    { "rate" : """7""" },
    { "rate" : """3.45""" },
    { "rate" : """12.46""" },
    { "rate" : """2.99999""" },
    { "rate" : """3.9999""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """2.95""" },
    { "rate" : """6.9""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """6.99""" },
    { "rate" : """12""" },
    { "rate" : """17""" },
    { "rate" : """17.46999""" },
    { "rate" : """2""" },
    { "rate" : """17.48""" },
    { "rate" : """7.69999""" },
    { "rate" : """13""" },
    { "rate" : """15""" },
    { "rate" : """12.46""" },
    { "rate" : """3""" },
    { "rate" : """17""" },
    { "rate" : """7""" },
    { "rate" : """6.8""" },
    { "rate" : """12""" },
    { "rate" : """12.46""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """17.48""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """0.99999""" },
    { "rate" : """17.48""" },
    { "rate" : """3.499""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.99199""" },
    { "rate" : """0.99979""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """3.5""" },
    { "rate" : """1""" },
    { "rate" : """3.64""" },
    { "rate" : """0.987""" },
    { "rate" : """0.99989""" },
    { "rate" : """12.46""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.9""" },
    { "rate" : """12.46""" },
    { "rate" : """17.48""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """0.9""" },
    { "rate" : """0.973""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """0.99995""" },
    { "rate" : """2.99995""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """3.49999""" },
    { "rate" : """8""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """0.98999""" },
    { "rate" : """0.8""" },
    { "rate" : """3.5""" },
    { "rate" : """17.48""" },
    { "rate" : """3.5""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """13.72""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """13.72""" },
    { "rate" : """9.85""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """13.72""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """7.5""" },
    { "rate" : """17.4""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """6.5""" },
    { "rate" : """0.9998""" },
    { "rate" : """12""" },
    { "rate" : """3.5""" },
    { "rate" : """3""" },
    { "rate" : """8.8""" },
    { "rate" : """13.71""" },
    { "rate" : """1""" },
    { "rate" : """15.5""" },
    { "rate" : """1""" },
    { "rate" : """7.5""" },
    { "rate" : """13.11""" },
    { "rate" : """1.5""" },
    { "rate" : """3.5""" },
    { "rate" : """10""" },
    { "rate" : """0.09""" },
    { "rate" : """13.11""" },
    { "rate" : """3.5""" },
    { "rate" : """0.5""" },
    { "rate" : """1""" },
    { "rate" : """13.11""" },
    { "rate" : """0.49999""" },
    { "rate" : """3.5""" },
    { "rate" : """0.49989""" },
    { "rate" : """13.11""" },
    { "rate" : """7""" },
    { "rate" : """14.95""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """0.49""" },
    { "rate" : """0.4""" },
    { "rate" : """0.39998""" },
    { "rate" : """0.485""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """3""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """1""" },
    { "rate" : """3.64""" },
    { "rate" : """13.72""" },
    { "rate" : """0.48999""" },
    { "rate" : """0.42""" },
    { "rate" : """0.427""" },
    { "rate" : """0.77772""" },
    { "rate" : """0.85""" },
    { "rate" : """13.11""" },
    { "rate" : """0.4""" },
    { "rate" : """0.4""" },
    { "rate" : """0.39""" },
    { "rate" : """0.4""" },
    { "rate" : """0.44987""" },
    { "rate" : """0.99""" },
    { "rate" : """10""" },
    { "rate" : """6.99""" },
    { "rate" : """7.6""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """9.95""" },
    { "rate" : """0.98""" },
    { "rate" : """0.9""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """6.99""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """7.5""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """0.79999""" },
    { "rate" : """5.5""" },
    { "rate" : """12.9999""" },
    { "rate" : """5.99999""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5.9""" },
    { "rate" : """6.95""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """5.9999""" },
    { "rate" : """6.9999""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """9.4""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """14.999""" },
    { "rate" : """6""" },
    { "rate" : """5.9""" },
    { "rate" : """5.9""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """9.96""" },
    { "rate" : """9.5""" },
    { "rate" : """14""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """3.5""" },
    { "rate" : """13.72""" },
    { "rate" : """5.44998""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.99999""" },
    { "rate" : """13.11""" },
    { "rate" : """6.99999""" },
    { "rate" : """15""" },
    { "rate" : """0.9""" },
    { "rate" : """3.8""" },
    { "rate" : """12.99""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """14.49998""" },
    { "rate" : """13.11""" },
    { "rate" : """0.875""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """9.5""" },
    { "rate" : """0.99""" },
    { "rate" : """0.99999""" },
    { "rate" : """15""" },
    { "rate" : """6.99989""" },
    { "rate" : """15""" },
    { "rate" : """13.11""" },
    { "rate" : """13.1""" },
    { "rate" : """9.99999""" },
    { "rate" : """16.17""" },
    { "rate" : """7.6668""" },
    { "rate" : """18.98""" },
    { "rate" : """0.487""" },
    { "rate" : """6.5""" },
    { "rate" : """0.1""" },
    { "rate" : """0.5""" },
    { "rate" : """0.7""" },
    { "rate" : """0.78699""" },
    { "rate" : """0.1""" },
    { "rate" : """3.24""" },
    { "rate" : """0.5""" },
    { "rate" : """3.24""" },
    { "rate" : """10.73""" },
    { "rate" : """0.779""" },
    { "rate" : """11.99""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """13""" },
    { "rate" : """3.24""" },
    { "rate" : """16""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """10.73""" },
    { "rate" : """16.16999""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """4.99999""" },
    { "rate" : """17.48""" },
    { "rate" : """13.72""" },
    { "rate" : """17.5""" },
    { "rate" : """7""" },
    { "rate" : """7.67979""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """3.24""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """14.5""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """7.6""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10.72""" },
    { "rate" : """14.99""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """17.48""" },
    { "rate" : """6.99""" },
    { "rate" : """15.14""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """14""" },
    { "rate" : """9.5""" },
    { "rate" : """7.6""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """14.99999""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """16.17""" },
    { "rate" : """9.96""" },
    { "rate" : """14.999""" },
    { "rate" : """15""" },
    { "rate" : """4.999""" },
    { "rate" : """3.64""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """9.99998""" },
    { "rate" : """4.99998""" },
    { "rate" : """4.98""" },
    { "rate" : """3""" },
    { "rate" : """4.9898""" },
    { "rate" : """6.99998""" },
    { "rate" : """4""" },
    { "rate" : """17""" },
    { "rate" : """17.48""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """17.48""" },
    { "rate" : """16.17""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """3.99998""" },
    { "rate" : """6.98""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """13.11""" },
    { "rate" : """11""" },
    { "rate" : """14""" },
    { "rate" : """10.73""" },
    { "rate" : """6""" },
    { "rate" : """9.5""" },
    { "rate" : """9.96""" },
    { "rate" : """9.999""" },
    { "rate" : """3.24""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """3.24""" },
    { "rate" : """6.9""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """0.4""" },
    { "rate" : """0.35""" },
    { "rate" : """0.07998""" },
    { "rate" : """0.39999""" },
    { "rate" : """0.3""" },
    { "rate" : """16.17""" },
    { "rate" : """6""" },
    { "rate" : """4.5""" },
    { "rate" : """16.17""" },
    { "rate" : """6.99""" },
    { "rate" : """11""" },
    { "rate" : """9.7""" },
    { "rate" : """17.48""" },
    { "rate" : """13.71""" },
    { "rate" : """6.8""" },
    { "rate" : """16.16""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.975""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.99997""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """0.989""" },
    { "rate" : """17.48""" },
    { "rate" : """0.9999""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99899""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """6.95""" },
    { "rate" : """0.9999""" },
    { "rate" : """15""" },
    { "rate" : """17.48""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """4.5678""" },
    { "rate" : """0.9999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """0.9999""" },
    { "rate" : """1""" },
    { "rate" : """0.78999""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """4.99""" },
    { "rate" : """1""" },
    { "rate" : """10.73""" },
    { "rate" : """17.48""" },
    { "rate" : """6.99""" },
    { "rate" : """10.73""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.9997""" },
    { "rate" : """10.73""" },
    { "rate" : """0.97""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """2.99""" },
    { "rate" : """1""" },
    { "rate" : """6.89""" },
    { "rate" : """0.7""" },
    { "rate" : """1""" },
    { "rate" : """0.6""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """7.5""" },
    { "rate" : """9.96""" },
    { "rate" : """14.99999""" },
    { "rate" : """0.07998""" },
    { "rate" : """10""" },
    { "rate" : """4.99998""" },
    { "rate" : """1""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """1""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """17.48""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """0.99""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """9.5""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """17.48""" },
    { "rate" : """3.5""" },
    { "rate" : """1""" },
    { "rate" : """15.14""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """0.987""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """17.48""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """14.9""" },
    { "rate" : """13.11""" },
    { "rate" : """10.7""" },
    { "rate" : """1""" },
    { "rate" : """0.99""" },
    { "rate" : """0.93""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """4.9""" },
    { "rate" : """9.96""" },
    { "rate" : """9.8""" },
    { "rate" : """9.96""" },
    { "rate" : """15.14""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """17.48""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """3.24""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """5.55555""" },
    { "rate" : """17.48""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.99""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.95""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """9.96""" },
    { "rate" : """9""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """4.999""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """5.45""" },
    { "rate" : """3.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """17.47""" },
    { "rate" : """9.95999""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """14.8""" },
    { "rate" : """9.95""" },
    { "rate" : """9.96""" },
    { "rate" : """9.95""" },
    { "rate" : """9.96""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """9.96""" },
    { "rate" : """9.95""" },
    { "rate" : """14.95""" },
    { "rate" : """4.95""" },
    { "rate" : """14.95""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """9.95""" },
    { "rate" : """4.77229""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """9.91""" },
    { "rate" : """9.95""" },
    { "rate" : """13""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """14.9999""" },
    { "rate" : """7.99998""" },
    { "rate" : """7.98999""" },
    { "rate" : """7.99998""" },
    { "rate" : """9""" },
    { "rate" : """7.99989""" },
    { "rate" : """7.99979""" },
    { "rate" : """7.9""" },
    { "rate" : """7.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """7.999""" },
    { "rate" : """7.87""" },
    { "rate" : """7.9""" },
    { "rate" : """7.9""" },
    { "rate" : """17.48""" },
    { "rate" : """9.96""" },
    { "rate" : """7.9999""" },
    { "rate" : """9.96""" },
    { "rate" : """12.26""" },
    { "rate" : """7.96""" },
    { "rate" : """7.99""" },
    { "rate" : """10.73""" },
    { "rate" : """8.8""" },
    { "rate" : """6""" },
    { "rate" : """13.11""" },
    { "rate" : """7.89999""" },
    { "rate" : """10.73""" },
    { "rate" : """15""" },
    { "rate" : """10.73""" },
    { "rate" : """7.9""" },
    { "rate" : """7.9""" },
    { "rate" : """7.95""" },
    { "rate" : """7.99998""" },
    { "rate" : """7.9""" },
    { "rate" : """4.99998""" },
    { "rate" : """9.94998""" },
    { "rate" : """9.96""" },
    { "rate" : """4.94998""" },
    { "rate" : """7.99""" },
    { "rate" : """0.001""" },
    { "rate" : """0.0002""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """7.9""" },
    { "rate" : """9.96""" },
    { "rate" : """0.66""" },
    { "rate" : """1""" },
    { "rate" : """0.0002""" },
    { "rate" : """0.63""" },
    { "rate" : """7.25""" },
    { "rate" : """7.9999""" },
    { "rate" : """9.9599""" },
    { "rate" : """3""" },
    { "rate" : """0.5""" },
    { "rate" : """1.99998""" },
    { "rate" : """6.8""" },
    { "rate" : """3.24""" },
    { "rate" : """6.9""" },
    { "rate" : """9.95""" },
    { "rate" : """7.9999""" },
    { "rate" : """7.498""" },
    { "rate" : """7.5""" },
    { "rate" : """9.95""" },
    { "rate" : """4.998""" },
    { "rate" : """7.9""" },
    { "rate" : """4.5""" },
    { "rate" : """11.4""" },
    { "rate" : """9.9""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """1.99729""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """7""" },
    { "rate" : """16.99999""" },
    { "rate" : """1.99""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """13""" },
    { "rate" : """1.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """4""" },
    { "rate" : """19.99998""" },
    { "rate" : """9.5""" },
    { "rate" : """23.58""" },
    { "rate" : """3.9""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """9.96""" },
    { "rate" : """1""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """1.98999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9.89998""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9.5""" },
    { "rate" : """9.9""" },
    { "rate" : """9.96""" },
    { "rate" : """4.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """9""" },
    { "rate" : """13.11""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """9.95""" },
    { "rate" : """0.48""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """12.22222""" },
    { "rate" : """7""" },
    { "rate" : """4.99999""" },
    { "rate" : """0.45""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """0.45""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """8""" },
    { "rate" : """9.5""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """0.45""" },
    { "rate" : """0.499""" },
    { "rate" : """0.49999""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """1.5""" },
    { "rate" : """9.96""" },
    { "rate" : """4.99""" },
    { "rate" : """4.99999""" },
    { "rate" : """9.94999""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """0.06998""" },
    { "rate" : """23.58""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """0.2""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """0.44998""" },
    { "rate" : """12""" },
    { "rate" : """0.49998""" },
    { "rate" : """0.48""" },
    { "rate" : """0.4999""" },
    { "rate" : """0.49""" },
    { "rate" : """9.96""" },
    { "rate" : """7""" },
    { "rate" : """0.48999""" },
    { "rate" : """0.07777""" },
    { "rate" : """20""" },
    { "rate" : """0.4""" },
    { "rate" : """0.4""" },
    { "rate" : """1.997""" },
    { "rate" : """0.45""" },
    { "rate" : """9.96""" },
    { "rate" : """23.58""" },
    { "rate" : """0.4998""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """4.9""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """4.998""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """23.5""" },
    { "rate" : """9.96""" },
    { "rate" : """17.48""" },
    { "rate" : """8.799""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """9.99995""" },
    { "rate" : """9.9""" },
    { "rate" : """4.99999""" },
    { "rate" : """3.64""" },
    { "rate" : """1.99999""" },
    { "rate" : """2.99999""" },
    { "rate" : """9.999""" },
    { "rate" : """10.73""" },
    { "rate" : """6.55""" },
    { "rate" : """3.64""" },
    { "rate" : """10""" },
    { "rate" : """4.9999""" },
    { "rate" : """9.96""" },
    { "rate" : """9.95""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """4.9678""" },
    { "rate" : """10""" },
    { "rate" : """4.99999""" },
    { "rate" : """10""" },
    { "rate" : """9.999""" },
    { "rate" : """9.96""" },
    { "rate" : """17.48""" },
    { "rate" : """9.96""" },
    { "rate" : """6.5""" },
    { "rate" : """9.96""" },
    { "rate" : """9.5""" },
    { "rate" : """9.5""" },
    { "rate" : """9.4""" },
    { "rate" : """20""" },
    { "rate" : """9.8""" },
    { "rate" : """9.89""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """17""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """4.9999""" },
    { "rate" : """23.58""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """17""" },
    { "rate" : """0.4""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """0.39998""" },
    { "rate" : """6.54""" },
    { "rate" : """10""" },
    { "rate" : """13.71""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """9.95""" },
    { "rate" : """13.11""" },
    { "rate" : """17.47""" },
    { "rate" : """0.43999""" },
    { "rate" : """0.49""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """9.5""" },
    { "rate" : """0.18""" },
    { "rate" : """0.488""" },
    { "rate" : """9.99999""" },
    { "rate" : """10.73""" },
    { "rate" : """9.4""" },
    { "rate" : """0.489""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """10.73""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """9.96""" },
    { "rate" : """10.6""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """13.72""" },
    { "rate" : """0.44987""" },
    { "rate" : """0.1987""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """9.99""" },
    { "rate" : """17.48""" },
    { "rate" : """9.99999""" },
    { "rate" : """6.95""" },
    { "rate" : """9.5""" },
    { "rate" : """9.96""" },
    { "rate" : """19.99999""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """17.48""" },
    { "rate" : """13.11""" },
    { "rate" : """9.96""" },
    { "rate" : """0.43899""" },
    { "rate" : """13.71""" },
    { "rate" : """10""" },
    { "rate" : """9.8""" },
    { "rate" : """17.48""" },
    { "rate" : """9.99998""" },
    { "rate" : """10.73""" },
    { "rate" : """9.96""" },
    { "rate" : """20""" },
    { "rate" : """0.45""" },
    { "rate" : """9.8""" },
    { "rate" : """9.99989""" },
    { "rate" : """10.73""" },
    { "rate" : """0.4""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9.5""" },
    { "rate" : """9.5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """3""" },
    { "rate" : """10.73""" },
    { "rate" : """13""" },
    { "rate" : """9.8""" },
    { "rate" : """6.9999""" },
    { "rate" : """9.99""" },
    { "rate" : """17.48""" },
    { "rate" : """9.96""" },
    { "rate" : """0.44""" },
    { "rate" : """0.068""" },
    { "rate" : """0.15""" },
    { "rate" : """0.07""" },
    { "rate" : """0.43""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """17.48""" },
    { "rate" : """9.96""" },
    { "rate" : """9.95""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """17.48""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """17.48""" },
    { "rate" : """5""" },
    { "rate" : """9.9""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9.9""" },
    { "rate" : """13.11""" },
    { "rate" : """9""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """10.73""" },
    { "rate" : """17.48""" },
    { "rate" : """13.11""" },
    { "rate" : """9.5""" },
    { "rate" : """9.9""" },
    { "rate" : """9.495""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """4.5""" },
    { "rate" : """0.48""" },
    { "rate" : """9.96""" },
    { "rate" : """17""" },
    { "rate" : """10.73""" },
    { "rate" : """12.46""" },
    { "rate" : """9.96""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.989""" },
    { "rate" : """11""" },
    { "rate" : """3.64""" },
    { "rate" : """3.63999""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """5.84""" },
    { "rate" : """17.48""" },
    { "rate" : """9.955""" },
    { "rate" : """11.5""" },
    { "rate" : """4.9""" },
    { "rate" : """16""" },
    { "rate" : """9.96""" },
    { "rate" : """9.99""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """4.98""" },
    { "rate" : """10.99""" },
    { "rate" : """4""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.99""" },
    { "rate" : """9.99""" },
    { "rate" : """9""" },
    { "rate" : """4.99999""" },
    { "rate" : """10.73""" },
    { "rate" : """13.11""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """9.99""" },
    { "rate" : """9.96""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """9.95999""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """9.96""" },
    { "rate" : """10.72""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """7""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """15.95""" },
    { "rate" : """10""" },
    { "rate" : """10.73""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """9.99998""" },
    { "rate" : """13.11""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """9.8""" },
    { "rate" : """9.99""" },
    { "rate" : """9.9999""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """9.9""" },
    { "rate" : """13.11""" },
    { "rate" : """9.9""" },
    { "rate" : """9.9""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """8""" },
    { "rate" : """14.9""" },
    { "rate" : """8""" },
    { "rate" : """11""" },
    { "rate" : """7.99998""" },
    { "rate" : """4""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """8.96""" },
    { "rate" : """3.97998""" },
    { "rate" : """3""" },
    { "rate" : """9.96""" },
    { "rate" : """0.39999""" },
    { "rate" : """8.99999""" },
    { "rate" : """9.5""" },
    { "rate" : """13.11""" },
    { "rate" : """11""" },
    { "rate" : """13""" },
    { "rate" : """15""" },
    { "rate" : """20""" },
    { "rate" : """4.6""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """9.5""" },
    { "rate" : """7.99""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """3.99998""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """1.99998""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """0.23456""" },
    { "rate" : """5""" },
    { "rate" : """1.88999""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.4999""" },
    { "rate" : """0.5""" },
    { "rate" : """16.17""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """0.4987""" },
    { "rate" : """8""" },
    { "rate" : """0.075""" },
    { "rate" : """0.45""" },
    { "rate" : """0.5""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """0.48899""" },
    { "rate" : """4""" },
    { "rate" : """0.05""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """0.49998""" },
    { "rate" : """14.71""" },
    { "rate" : """8""" },
    { "rate" : """0.49999""" },
    { "rate" : """7.77777""" },
    { "rate" : """13.11""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49999""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5.99999""" },
    { "rate" : """12""" },
    { "rate" : """0.499""" },
    { "rate" : """7""" },
    { "rate" : """5.6789""" },
    { "rate" : """4.99997""" },
    { "rate" : """5""" },
    { "rate" : """9.4999""" },
    { "rate" : """0.4""" },
    { "rate" : """3.33333""" },
    { "rate" : """6.9""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.49998""" },
    { "rate" : """6.99999""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.5""" },
    { "rate" : """6.5""" },
    { "rate" : """0.49""" },
    { "rate" : """3.64""" },
    { "rate" : """0.49999""" },
    { "rate" : """9.9888""" },
    { "rate" : """10.99999""" },
    { "rate" : """0.495""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """6.99999""" },
    { "rate" : """0.49998""" },
    { "rate" : """3.639""" },
    { "rate" : """9.4""" },
    { "rate" : """8.3""" },
    { "rate" : """8""" },
    { "rate" : """6.55""" },
    { "rate" : """7.99""" },
    { "rate" : """1""" },
    { "rate" : """0.999""" },
    { "rate" : """0.99998""" },
    { "rate" : """0.8""" },
    { "rate" : """7""" },
    { "rate" : """9.96""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """3.2""" },
    { "rate" : """5""" },
    { "rate" : """0.49999""" },
    { "rate" : """8.6""" },
    { "rate" : """5""" },
    { "rate" : """0.4999""" },
    { "rate" : """0.06""" },
    { "rate" : """0.9999""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """4.999""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """0.4999""" },
    { "rate" : """0.9999""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """9""" },
    { "rate" : """9.95""" },
    { "rate" : """0.8""" },
    { "rate" : """13""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.49999""" },
    { "rate" : """8.99998""" },
    { "rate" : """13.1""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """9.4""" },
    { "rate" : """9.5""" },
    { "rate" : """7.9""" },
    { "rate" : """10""" },
    { "rate" : """10.9""" },
    { "rate" : """23.58""" },
    { "rate" : """3.64""" },
    { "rate" : """0.95""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """8.64""" },
    { "rate" : """11.4""" },
    { "rate" : """8""" },
    { "rate" : """8.64""" },
    { "rate" : """4.17""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """7""" },
    { "rate" : """8.5""" },
    { "rate" : """0.99989""" },
    { "rate" : """9.9""" },
    { "rate" : """0.99999""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """8.64""" },
    { "rate" : """0.95""" },
    { "rate" : """6.55""" },
    { "rate" : """0.04998""" },
    { "rate" : """0.99979""" },
    { "rate" : """8""" },
    { "rate" : """12.26""" },
    { "rate" : """7.99""" },
    { "rate" : """11""" },
    { "rate" : """7.9""" },
    { "rate" : """3.64""" },
    { "rate" : """8""" },
    { "rate" : """4.9""" },
    { "rate" : """3.64""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """9.99""" },
    { "rate" : """10.9""" },
    { "rate" : """1""" },
    { "rate" : """8.64""" },
    { "rate" : """1""" },
    { "rate" : """23""" },
    { "rate" : """0.99999""" },
    { "rate" : """7""" },
    { "rate" : """23.58""" },
    { "rate" : """0.98999""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """1.4999""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """0.7""" },
    { "rate" : """4""" },
    { "rate" : """0.75""" },
    { "rate" : """8""" },
    { "rate" : """3.63""" },
    { "rate" : """1""" },
    { "rate" : """9.4""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.999""" },
    { "rate" : """3""" },
    { "rate" : """13.11""" },
    { "rate" : """1""" },
    { "rate" : """12.26""" },
    { "rate" : """6.55""" },
    { "rate" : """12.46""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """1.89999""" },
    { "rate" : """3.999""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """17.48""" },
    { "rate" : """5""" },
    { "rate" : """9.999""" },
    { "rate" : """7""" },
    { "rate" : """0.09698""" },
    { "rate" : """0.5""" },
    { "rate" : """0.4""" },
    { "rate" : """0.04998""" },
    { "rate" : """9.5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.97888""" },
    { "rate" : """0.9999""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """23.58""" },
    { "rate" : """3.64""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """9.49998""" },
    { "rate" : """0.03""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """0.9""" },
    { "rate" : """3.64""" },
    { "rate" : """10.73""" },
    { "rate" : """23.58""" },
    { "rate" : """9""" },
    { "rate" : """7.9""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """3.64""" },
    { "rate" : """8""" },
    { "rate" : """9.99""" },
    { "rate" : """5""" },
    { "rate" : """8.64""" },
    { "rate" : """7""" },
    { "rate" : """23.58""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """0.95""" },
    { "rate" : """6.99999""" },
    { "rate" : """10""" },
    { "rate" : """3.64""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.9999""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """3.64""" },
    { "rate" : """4.99""" },
    { "rate" : """0.973""" },
    { "rate" : """0.975""" },
    { "rate" : """9.96""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """13.11""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """3.67""" },
    { "rate" : """12.49""" },
    { "rate" : """1.35""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """0.999""" },
    { "rate" : """13.72""" },
    { "rate" : """3.64""" },
    { "rate" : """6.99998""" },
    { "rate" : """6""" },
    { "rate" : """1.8""" },
    { "rate" : """9.96""" },
    { "rate" : """13.11""" },
    { "rate" : """8.64""" },
    { "rate" : """9""" },
    { "rate" : """13.72""" },
    { "rate" : """7""" },
    { "rate" : """12.26""" },
    { "rate" : """2.4""" },
    { "rate" : """9.999""" },
    { "rate" : """8.64""" },
    { "rate" : """10.73""" },
    { "rate" : """4.999""" },
    { "rate" : """21""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """9.999""" },
    { "rate" : """6.999""" },
    { "rate" : """9.5""" },
    { "rate" : """8.64""" },
    { "rate" : """10""" },
    { "rate" : """8.64""" },
    { "rate" : """9.5""" },
    { "rate" : """9.999""" },
    { "rate" : """4.99""" },
    { "rate" : """0.9999""" },
    { "rate" : """8.64""" },
    { "rate" : """3.64""" },
    { "rate" : """12.46""" },
    { "rate" : """3.64""" },
    { "rate" : """0.75""" },
    { "rate" : """8.64""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.95""" },
    { "rate" : """0.7""" },
    { "rate" : """23.5""" },
    { "rate" : """0.98999""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """8.64""" },
    { "rate" : """9.99999""" },
    { "rate" : """5.75""" },
    { "rate" : """8""" },
    { "rate" : """13.72""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """8.64""" },
    { "rate" : """7.9""" },
    { "rate" : """0.8987""" },
    { "rate" : """0.85""" },
    { "rate" : """9.69999""" },
    { "rate" : """0.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """0.99999""" },
    { "rate" : """8.64""" },
    { "rate" : """5""" },
    { "rate" : """9.499""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """12.26""" },
    { "rate" : """5""" },
    { "rate" : """8.64""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8.64""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """9.5""" },
    { "rate" : """0.99""" },
    { "rate" : """0.95""" },
    { "rate" : """9""" },
    { "rate" : """7.5""" },
    { "rate" : """6.5""" },
    { "rate" : """23.58""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """7.99999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """0.988""" },
    { "rate" : """0.7""" },
    { "rate" : """7.9""" },
    { "rate" : """4.9""" },
    { "rate" : """12.4""" },
    { "rate" : """7.5""" },
    { "rate" : """4.2""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """4.8""" },
    { "rate" : """6.9""" },
    { "rate" : """9.4""" },
    { "rate" : """4.99999""" },
    { "rate" : """8.5""" },
    { "rate" : """8.3""" },
    { "rate" : """8.2""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """4.9999""" },
    { "rate" : """8.64""" },
    { "rate" : """13.11""" },
    { "rate" : """0.99999""" },
    { "rate" : """4.99""" },
    { "rate" : """7.99""" },
    { "rate" : """7""" },
    { "rate" : """23.58""" },
    { "rate" : """8.64""" },
    { "rate" : """0.9""" },
    { "rate" : """0.97""" },
    { "rate" : """7""" },
    { "rate" : """8.63""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """9.5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """0.888""" },
    { "rate" : """8""" },
    { "rate" : """10.73""" },
    { "rate" : """12.25""" },
    { "rate" : """23.57""" },
    { "rate" : """13""" },
    { "rate" : """7""" },
    { "rate" : """9.96""" },
    { "rate" : """18""" },
    { "rate" : """0.03""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """7.5""" },
    { "rate" : """16.17""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """10.73""" },
    { "rate" : """23.58""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """10.73""" },
    { "rate" : """8""" },
    { "rate" : """10.73""" },
    { "rate" : """19""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """13.71""" },
    { "rate" : """8""" },
    { "rate" : """0.99999""" },
    { "rate" : """4.99998""" },
    { "rate" : """7""" },
    { "rate" : """4.99999""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """0.6""" },
    { "rate" : """9.96""" },
    { "rate" : """23.58""" },
    { "rate" : """7.9999""" },
    { "rate" : """8.64""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """9.95""" },
    { "rate" : """9.9599""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """9.96""" },
    { "rate" : """8.64""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """9.9""" },
    { "rate" : """9.96""" },
    { "rate" : """6.99999""" },
    { "rate" : """9.95""" },
    { "rate" : """9.96""" },
    { "rate" : """9.5""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.5""" },
    { "rate" : """9.95999""" },
    { "rate" : """0.9""" },
    { "rate" : """9.91""" },
    { "rate" : """9.9""" },
    { "rate" : """9.96""" },
    { "rate" : """18.97999""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """4.99""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """9""" },
    { "rate" : """9.96""" },
    { "rate" : """9.89999""" },
    { "rate" : """9.5""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """0.98888""" },
    { "rate" : """12.26""" },
    { "rate" : """0.34987""" },
    { "rate" : """9.88999""" },
    { "rate" : """0.32998""" },
    { "rate" : """8.5""" },
    { "rate" : """9.96""" },
    { "rate" : """0.33988""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """9.96""" },
    { "rate" : """9""" },
    { "rate" : """9.96""" },
    { "rate" : """9.95""" },
    { "rate" : """9.95998""" },
    { "rate" : """10""" },
    { "rate" : """4.99998""" },
    { "rate" : """9.96""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.8""" },
    { "rate" : """0.99998""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """3.64""" },
    { "rate" : """0.9""" },
    { "rate" : """0.99989""" },
    { "rate" : """8""" },
    { "rate" : """0.8""" },
    { "rate" : """0.99""" },
    { "rate" : """9.96""" },
    { "rate" : """0.9""" },
    { "rate" : """0.7""" },
    { "rate" : """9.96""" },
    { "rate" : """17.48""" },
    { "rate" : """3.64""" },
    { "rate" : """13.72""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """0.9""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """17.48""" },
    { "rate" : """9.94""" },
    { "rate" : """9.95998""" },
    { "rate" : """10.73""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.5""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """6""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """7""" },
    { "rate" : """0.955""" },
    { "rate" : """9.96""" },
    { "rate" : """0.79999""" },
    { "rate" : """9.96""" },
    { "rate" : """4""" },
    { "rate" : """0.999""" },
    { "rate" : """9.96""" },
    { "rate" : """9.95""" },
    { "rate" : """4.99""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9""" },
    { "rate" : """0.7""" },
    { "rate" : """13.11""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.95""" },
    { "rate" : """0.999""" },
    { "rate" : """9.95""" },
    { "rate" : """11""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """10.73""" },
    { "rate" : """0.49998""" },
    { "rate" : """0.5""" },
    { "rate" : """0.89989""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7.99999""" },
    { "rate" : """9.85""" },
    { "rate" : """0.4""" },
    { "rate" : """7.9""" },
    { "rate" : """0.5""" },
    { "rate" : """0.8""" },
    { "rate" : """7.5""" },
    { "rate" : """9.96""" },
    { "rate" : """9.95""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """0.79""" },
    { "rate" : """7""" },
    { "rate" : """9.95""" },
    { "rate" : """9.9555""" },
    { "rate" : """9.55""" },
    { "rate" : """0.6""" },
    { "rate" : """9.96""" },
    { "rate" : """7.99""" },
    { "rate" : """9.96""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.39999""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """4.99998""" },
    { "rate" : """7.9""" },
    { "rate" : """4""" },
    { "rate" : """0.8999""" },
    { "rate" : """0.375""" },
    { "rate" : """12.26""" },
    { "rate" : """0.4""" },
    { "rate" : """0.49998""" },
    { "rate" : """0.4""" },
    { "rate" : """7.5""" },
    { "rate" : """0.5""" },
    { "rate" : """9.9599""" },
    { "rate" : """9.96""" },
    { "rate" : """9.75""" },
    { "rate" : """9""" },
    { "rate" : """0.7""" },
    { "rate" : """0.49989""" },
    { "rate" : """7.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """5.79""" },
    { "rate" : """9.9""" },
    { "rate" : """16.17""" },
    { "rate" : """7.99""" },
    { "rate" : """9.96""" },
    { "rate" : """3.99""" },
    { "rate" : """5.5""" },
    { "rate" : """0.35""" },
    { "rate" : """0.79999""" },
    { "rate" : """0.8""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """9.47999""" },
    { "rate" : """4""" },
    { "rate" : """9.49""" },
    { "rate" : """7.9""" },
    { "rate" : """0.4999""" },
    { "rate" : """7.99""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """9.95""" },
    { "rate" : """5""" },
    { "rate" : """9.95999""" },
    { "rate" : """16.17""" },
    { "rate" : """0.49999""" },
    { "rate" : """9.96""" },
    { "rate" : """0.89899""" },
    { "rate" : """7.5""" },
    { "rate" : """4""" },
    { "rate" : """9.94""" },
    { "rate" : """9.96""" },
    { "rate" : """7""" },
    { "rate" : """3.99999""" },
    { "rate" : """5""" },
    { "rate" : """9.5""" },
    { "rate" : """8.8""" },
    { "rate" : """0.75""" },
    { "rate" : """9.96""" },
    { "rate" : """4""" },
    { "rate" : """3.97998""" },
    { "rate" : """0.49""" },
    { "rate" : """7.99999""" },
    { "rate" : """3.99999""" },
    { "rate" : """16.16""" },
    { "rate" : """9.5""" },
    { "rate" : """9.5""" },
    { "rate" : """0.33""" },
    { "rate" : """5.79""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """4.5""" },
    { "rate" : """0.4""" },
    { "rate" : """0.4""" },
    { "rate" : """0.49""" },
    { "rate" : """0.5999""" },
    { "rate" : """0.7777""" },
    { "rate" : """13.11""" },
    { "rate" : """4""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """3.8""" },
    { "rate" : """0.49899""" },
    { "rate" : """0.39899""" },
    { "rate" : """0.39899""" },
    { "rate" : """7.99999""" },
    { "rate" : """9.9599""" },
    { "rate" : """7.9""" },
    { "rate" : """3.5""" },
    { "rate" : """4""" },
    { "rate" : """9.96""" },
    { "rate" : """5.79""" },
    { "rate" : """9.96""" },
    { "rate" : """5.79""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """0.75999""" },
    { "rate" : """0.75999""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.95""" },
    { "rate" : """9.96""" },
    { "rate" : """3.9999""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """5.79""" },
    { "rate" : """7.9""" },
    { "rate" : """7.5""" },
    { "rate" : """0.48998""" },
    { "rate" : """8""" },
    { "rate" : """12.26""" },
    { "rate" : """8.8""" },
    { "rate" : """0.5""" },
    { "rate" : """9.9""" },
    { "rate" : """16.17""" },
    { "rate" : """0.49998""" },
    { "rate" : """0.6""" },
    { "rate" : """0.4""" },
    { "rate" : """9.95""" },
    { "rate" : """3.7""" },
    { "rate" : """13.11""" },
    { "rate" : """18.98""" },
    { "rate" : """16.17""" },
    { "rate" : """9""" },
    { "rate" : """3.9""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """0.48""" },
    { "rate" : """0.58""" },
    { "rate" : """0.338""" },
    { "rate" : """9""" },
    { "rate" : """9.96""" },
    { "rate" : """6""" },
    { "rate" : """9.5""" },
    { "rate" : """7.5""" },
    { "rate" : """9.96""" },
    { "rate" : """1.9""" },
    { "rate" : """9.95998""" },
    { "rate" : """0.78888""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """10""" },
    { "rate" : """0.59""" },
    { "rate" : """9.95""" },
    { "rate" : """7.9""" },
    { "rate" : """8.8""" },
    { "rate" : """0.3798""" },
    { "rate" : """0.99998""" },
    { "rate" : """0.8""" },
    { "rate" : """13.11""" },
    { "rate" : """8.8""" },
    { "rate" : """0.8""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """9.05""" },
    { "rate" : """5""" },
    { "rate" : """4.97""" },
    { "rate" : """10""" },
    { "rate" : """7.99""" },
    { "rate" : """11""" },
    { "rate" : """12""" },
    { "rate" : """8.99""" },
    { "rate" : """3.98""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """0.5987""" },
    { "rate" : """12""" },
    { "rate" : """9.95""" },
    { "rate" : """6""" },
    { "rate" : """9.5""" },
    { "rate" : """9""" },
    { "rate" : """8.8""" },
    { "rate" : """0.6""" },
    { "rate" : """8.8""" },
    { "rate" : """6""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """0.33""" },
    { "rate" : """12.99998""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """9.93""" },
    { "rate" : """0.68""" },
    { "rate" : """0.34""" },
    { "rate" : """4""" },
    { "rate" : """9.95""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """9.9599""" },
    { "rate" : """9""" },
    { "rate" : """9.95""" },
    { "rate" : """0.6""" },
    { "rate" : """9""" },
    { "rate" : """6.99""" },
    { "rate" : """10""" },
    { "rate" : """9.959""" },
    { "rate" : """9.5""" },
    { "rate" : """4""" },
    { "rate" : """9.9""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.5""" },
    { "rate" : """4""" },
    { "rate" : """8.8""" },
    { "rate" : """8.99999""" },
    { "rate" : """12.26""" },
    { "rate" : """9.9596""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """0.3""" },
    { "rate" : """9.7""" },
    { "rate" : """6.1""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """6""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """11.99""" },
    { "rate" : """12.44445""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """3.9""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """1.4""" },
    { "rate" : """1""" },
    { "rate" : """1.44""" },
    { "rate" : """1.46""" },
    { "rate" : """1.337""" },
    { "rate" : """18.98""" },
    { "rate" : """1.4""" },
    { "rate" : """12""" },
    { "rate" : """0.33999""" },
    { "rate" : """9.9""" },
    { "rate" : """18.98""" },
    { "rate" : """1.33""" },
    { "rate" : """20""" },
    { "rate" : """3.9999""" },
    { "rate" : """16.17""" },
    { "rate" : """8.64""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """1.4399""" },
    { "rate" : """4""" },
    { "rate" : """0.95""" },
    { "rate" : """8""" },
    { "rate" : """10.73""" },
    { "rate" : """1.3599""" },
    { "rate" : """8.64""" },
    { "rate" : """8.8""" },
    { "rate" : """15""" },
    { "rate" : """13""" },
    { "rate" : """1.45""" },
    { "rate" : """9.99998""" },
    { "rate" : """9.96""" },
    { "rate" : """0.94998""" },
    { "rate" : """0.75""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """0.99998""" },
    { "rate" : """1""" },
    { "rate" : """0.75""" },
    { "rate" : """0.8987""" },
    { "rate" : """6""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """18.98""" },
    { "rate" : """1.2345""" },
    { "rate" : """0.9999""" },
    { "rate" : """4.99998""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99998""" },
    { "rate" : """3.985""" },
    { "rate" : """6""" },
    { "rate" : """13.72""" },
    { "rate" : """4.99999""" },
    { "rate" : """8.8""" },
    { "rate" : """18.98""" },
    { "rate" : """3.99999""" },
    { "rate" : """7.5""" },
    { "rate" : """4""" },
    { "rate" : """0.5""" },
    { "rate" : """11.99999""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """0.8""" },
    { "rate" : """6.5""" },
    { "rate" : """1""" },
    { "rate" : """0.99899""" },
    { "rate" : """0.49998""" },
    { "rate" : """0.5""" },
    { "rate" : """0.498""" },
    { "rate" : """0.4""" },
    { "rate" : """0.9999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """4.99""" },
    { "rate" : """0.8""" },
    { "rate" : """1""" },
    { "rate" : """0.75""" },
    { "rate" : """1""" },
    { "rate" : """0.9""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """3.999""" },
    { "rate" : """1""" },
    { "rate" : """9.999""" },
    { "rate" : """1""" },
    { "rate" : """8.64""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """9.95998""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """7.9""" },
    { "rate" : """3.99946""" },
    { "rate" : """0.998""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """12.25""" },
    { "rate" : """8.8""" },
    { "rate" : """0.999""" },
    { "rate" : """4""" },
    { "rate" : """8.8""" },
    { "rate" : """9.95""" },
    { "rate" : """9""" },
    { "rate" : """0.99989""" },
    { "rate" : """0.95""" },
    { "rate" : """0.89998""" },
    { "rate" : """12""" },
    { "rate" : """4.99""" },
    { "rate" : """0.9""" },
    { "rate" : """4.99""" },
    { "rate" : """10""" },
    { "rate" : """0.85""" },
    { "rate" : """0.84""" },
    { "rate" : """9.96""" },
    { "rate" : """0.3""" },
    { "rate" : """9.96""" },
    { "rate" : """13.11""" },
    { "rate" : """23.58""" },
    { "rate" : """8.64""" },
    { "rate" : """18.98""" },
    { "rate" : """16.17""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """3""" },
    { "rate" : """12.26""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """0.49998""" },
    { "rate" : """8.5""" },
    { "rate" : """0.8""" },
    { "rate" : """18.98""" },
    { "rate" : """0.1""" },
    { "rate" : """0.1""" },
    { "rate" : """1.3""" },
    { "rate" : """8.8""" },
    { "rate" : """0.49998""" },
    { "rate" : """4.69999""" },
    { "rate" : """3.99999""" },
    { "rate" : """2.999""" },
    { "rate" : """0.1""" },
    { "rate" : """9.96""" },
    { "rate" : """0.07798""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """16.16999""" },
    { "rate" : """9.96""" },
    { "rate" : """17.99""" },
    { "rate" : """7.99""" },
    { "rate" : """8.8""" },
    { "rate" : """3.999""" },
    { "rate" : """16""" },
    { "rate" : """9.9999""" },
    { "rate" : """8""" },
    { "rate" : """10.73""" },
    { "rate" : """12.26""" },
    { "rate" : """2""" },
    { "rate" : """12.46""" },
    { "rate" : """6""" },
    { "rate" : """9.96""" },
    { "rate" : """12.26""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """3""" },
    { "rate" : """8.8""" },
    { "rate" : """1""" },
    { "rate" : """23.58""" },
    { "rate" : """0.9999""" },
    { "rate" : """12.26""" },
    { "rate" : """9.96""" },
    { "rate" : """9""" },
    { "rate" : """0.99989""" },
    { "rate" : """3.98""" },
    { "rate" : """3.9""" },
    { "rate" : """10.73""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """9.96""" },
    { "rate" : """3.99999""" },
    { "rate" : """0.29""" },
    { "rate" : """9.96""" },
    { "rate" : """9.5""" },
    { "rate" : """0.22""" },
    { "rate" : """2.99999""" },
    { "rate" : """18.98""" },
    { "rate" : """4""" },
    { "rate" : """0.25999""" },
    { "rate" : """3.5999""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """3.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """9.48""" },
    { "rate" : """0.48""" },
    { "rate" : """0.4899""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """0.15""" },
    { "rate" : """0.25""" },
    { "rate" : """8.8""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """4.8""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """3.45""" },
    { "rate" : """7.5""" },
    { "rate" : """8.5""" },
    { "rate" : """7.5""" },
    { "rate" : """9.5""" },
    { "rate" : """7.99""" },
    { "rate" : """9.48""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """1.24""" },
    { "rate" : """0.99998""" },
    { "rate" : """9.5""" },
    { "rate" : """6.5""" },
    { "rate" : """1.9""" },
    { "rate" : """1.99999""" },
    { "rate" : """8""" },
    { "rate" : """8.98""" },
    { "rate" : """2""" },
    { "rate" : """18.98""" },
    { "rate" : """1.899""" },
    { "rate" : """8.8""" },
    { "rate" : """2""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """1.99995""" },
    { "rate" : """6.99""" },
    { "rate" : """8.64""" },
    { "rate" : """10""" },
    { "rate" : """18.98""" },
    { "rate" : """1.2""" },
    { "rate" : """1.5""" },
    { "rate" : """8.64""" },
    { "rate" : """1.337""" },
    { "rate" : """1.337""" },
    { "rate" : """5""" },
    { "rate" : """4.337""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """1.99899""" },
    { "rate" : """3.3""" },
    { "rate" : """0.18989""" },
    { "rate" : """8.8""" },
    { "rate" : """3.9899""" },
    { "rate" : """3""" },
    { "rate" : """17.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """7.989""" },
    { "rate" : """4.98999""" },
    { "rate" : """0.3""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """1.99989""" },
    { "rate" : """8""" },
    { "rate" : """1.998""" },
    { "rate" : """1.4""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """3.9""" },
    { "rate" : """3.2""" },
    { "rate" : """9.99999""" },
    { "rate" : """9""" },
    { "rate" : """1.9899""" },
    { "rate" : """12.2""" },
    { "rate" : """3.2""" },
    { "rate" : """9.9""" },
    { "rate" : """9.4""" },
    { "rate" : """3.19999""" },
    { "rate" : """9""" },
    { "rate" : """4.95""" },
    { "rate" : """7""" },
    { "rate" : """4.95""" },
    { "rate" : """9.96""" },
    { "rate" : """3.18999""" },
    { "rate" : """8.8""" },
    { "rate" : """1.99""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """3.199""" },
    { "rate" : """1.99999""" },
    { "rate" : """9""" },
    { "rate" : """9.96""" },
    { "rate" : """3.2""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """10.6""" },
    { "rate" : """3.9""" },
    { "rate" : """9.96""" },
    { "rate" : """1.99999""" },
    { "rate" : """0.189""" },
    { "rate" : """0.00039""" },
    { "rate" : """1.99999""" },
    { "rate" : """9.9""" },
    { "rate" : """8.8""" },
    { "rate" : """1.75999""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """18.98""" },
    { "rate" : """9.96""" },
    { "rate" : """1.5""" },
    { "rate" : """12""" },
    { "rate" : """5.8""" },
    { "rate" : """9.96""" },
    { "rate" : """1.9999""" },
    { "rate" : """18.98""" },
    { "rate" : """12""" },
    { "rate" : """11.99979""" },
    { "rate" : """1.99979""" },
    { "rate" : """12""" },
    { "rate" : """6.5""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """0.48""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """0.2353""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """8.79""" },
    { "rate" : """7.9""" },
    { "rate" : """9.95987""" },
    { "rate" : """3.19999""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """1.88""" },
    { "rate" : """12""" },
    { "rate" : """1.95""" },
    { "rate" : """0.2353""" },
    { "rate" : """9""" },
    { "rate" : """3.2""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """11.9""" },
    { "rate" : """12.26""" },
    { "rate" : """1.99""" },
    { "rate" : """0.48""" },
    { "rate" : """0.48""" },
    { "rate" : """0.2353""" },
    { "rate" : """0.48""" },
    { "rate" : """0.48""" },
    { "rate" : """1.99""" },
    { "rate" : """3""" },
    { "rate" : """11.8""" },
    { "rate" : """12""" },
    { "rate" : """5.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """3.2""" },
    { "rate" : """1""" },
    { "rate" : """11.5""" },
    { "rate" : """0.99""" },
    { "rate" : """11""" },
    { "rate" : """0.99998""" },
    { "rate" : """5.99""" },
    { "rate" : """5.99998""" },
    { "rate" : """7.5""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """5.7""" },
    { "rate" : """9.9999""" },
    { "rate" : """12.26""" },
    { "rate" : """0.97998""" },
    { "rate" : """0.18898""" },
    { "rate" : """12""" },
    { "rate" : """0.9""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """3.2""" },
    { "rate" : """0.9""" },
    { "rate" : """7.9""" },
    { "rate" : """5.97998""" },
    { "rate" : """3.2""" },
    { "rate" : """6.49""" },
    { "rate" : """5""" },
    { "rate" : """0.0002""" },
    { "rate" : """18.98""" },
    { "rate" : """0.99999""" },
    { "rate" : """18""" },
    { "rate" : """1.9""" },
    { "rate" : """6""" },
    { "rate" : """3.2""" },
    { "rate" : """12""" },
    { "rate" : """0.99997""" },
    { "rate" : """10""" },
    { "rate" : """10.73""" },
    { "rate" : """11.99""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """12.46""" },
    { "rate" : """4""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """5.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """0.28999""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """7.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.987""" },
    { "rate" : """7.99""" },
    { "rate" : """0.48""" },
    { "rate" : """6""" },
    { "rate" : """0.99899""" },
    { "rate" : """2""" },
    { "rate" : """0.48""" },
    { "rate" : """5.75""" },
    { "rate" : """1""" },
    { "rate" : """1.25""" },
    { "rate" : """0.2353""" },
    { "rate" : """4.99""" },
    { "rate" : """1""" },
    { "rate" : """0.48""" },
    { "rate" : """0.2353""" },
    { "rate" : """18""" },
    { "rate" : """1.5""" },
    { "rate" : """0.35""" },
    { "rate" : """0.7""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """0.95999""" },
    { "rate" : """8.8""" },
    { "rate" : """1""" },
    { "rate" : """9.96""" },
    { "rate" : """7.99975""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """7.99999""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """7.99999""" },
    { "rate" : """1.9999""" },
    { "rate" : """7.99972""" },
    { "rate" : """1""" },
    { "rate" : """7.88999""" },
    { "rate" : """8""" },
    { "rate" : """7.8""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """10.73""" },
    { "rate" : """18.98""" },
    { "rate" : """7.88999""" },
    { "rate" : """7.96""" },
    { "rate" : """13.72""" },
    { "rate" : """7.75""" },
    { "rate" : """12.26""" },
    { "rate" : """7.95""" },
    { "rate" : """8""" },
    { "rate" : """10.73""" },
    { "rate" : """13.11""" },
    { "rate" : """10.73""" },
    { "rate" : """12.46""" },
    { "rate" : """7.99999""" },
    { "rate" : """7.9999""" },
    { "rate" : """7.95""" },
    { "rate" : """7.99978""" },
    { "rate" : """13.72""" },
    { "rate" : """7.99""" },
    { "rate" : """7.9""" },
    { "rate" : """18.98""" },
    { "rate" : """23.58""" },
    { "rate" : """17""" },
    { "rate" : """18.98""" },
    { "rate" : """7.9999""" },
    { "rate" : """4.99""" },
    { "rate" : """7.987""" },
    { "rate" : """23.58""" },
    { "rate" : """9""" },
    { "rate" : """7.94998""" },
    { "rate" : """10.73""" },
    { "rate" : """7.99""" },
    { "rate" : """11""" },
    { "rate" : """11.9999""" },
    { "rate" : """7.98""" },
    { "rate" : """9.96""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """10.72""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """7.9999""" },
    { "rate" : """12.26""" },
    { "rate" : """11.11111""" },
    { "rate" : """8.8""" },
    { "rate" : """1""" },
    { "rate" : """5.5""" },
    { "rate" : """5.99998""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """13.11""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """10.73""" },
    { "rate" : """10.5""" },
    { "rate" : """18.98""" },
    { "rate" : """3.99""" },
    { "rate" : """6""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """3.2""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """11.99999""" },
    { "rate" : """12.26""" },
    { "rate" : """10.72""" },
    { "rate" : """0.99999""" },
    { "rate" : """10.73""" },
    { "rate" : """5""" },
    { "rate" : """0.89999""" },
    { "rate" : """13.11""" },
    { "rate" : """8.8""" },
    { "rate" : """1""" },
    { "rate" : """1.5""" },
    { "rate" : """1.75""" },
    { "rate" : """6.49999""" },
    { "rate" : """1.4""" },
    { "rate" : """13.72""" },
    { "rate" : """5.88999""" },
    { "rate" : """2""" },
    { "rate" : """8.8""" },
    { "rate" : """1""" },
    { "rate" : """13.11""" },
    { "rate" : """8.79999""" },
    { "rate" : """1.74""" },
    { "rate" : """1.73998""" },
    { "rate" : """0.98""" },
    { "rate" : """1.74""" },
    { "rate" : """1.749""" },
    { "rate" : """3.18""" },
    { "rate" : """1.75""" },
    { "rate" : """2.5""" },
    { "rate" : """1.74999""" },
    { "rate" : """1.74""" },
    { "rate" : """1.74999""" },
    { "rate" : """1.5555""" },
    { "rate" : """0.9""" },
    { "rate" : """12.98""" },
    { "rate" : """12.26""" },
    { "rate" : """1.7395""" },
    { "rate" : """11.98999""" },
    { "rate" : """6""" },
    { "rate" : """8.78""" },
    { "rate" : """1.75""" },
    { "rate" : """1.7499""" },
    { "rate" : """10""" },
    { "rate" : """1.75""" },
    { "rate" : """88""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """1.55556""" },
    { "rate" : """15""" },
    { "rate" : """1.7""" },
    { "rate" : """2.48""" },
    { "rate" : """12""" },
    { "rate" : """18.98""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """18.98""" },
    { "rate" : """3.1""" },
    { "rate" : """12.99998""" },
    { "rate" : """1.7""" },
    { "rate" : """0.999""" },
    { "rate" : """3""" },
    { "rate" : """2.98998""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """3.8""" },
    { "rate" : """8""" },
    { "rate" : """1.69999""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """8.79999""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """2.99""" },
    { "rate" : """9.96""" },
    { "rate" : """13.11""" },
    { "rate" : """0.4706""" },
    { "rate" : """1.75""" },
    { "rate" : """4""" },
    { "rate" : """0.96""" },
    { "rate" : """3.2""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """8.8""" },
    { "rate" : """8.9""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """3.9""" },
    { "rate" : """2.99999""" },
    { "rate" : """10""" },
    { "rate" : """5.98""" },
    { "rate" : """12.97999""" },
    { "rate" : """3.99888""" },
    { "rate" : """13""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.98""" },
    { "rate" : """1.74998""" },
    { "rate" : """1.74999""" },
    { "rate" : """13.11""" },
    { "rate" : """0.4706""" },
    { "rate" : """8""" },
    { "rate" : """0.9999""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """0.2""" },
    { "rate" : """0.9""" },
    { "rate" : """12.26""" },
    { "rate" : """12.25999""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.96""" },
    { "rate" : """0.96""" },
    { "rate" : """4""" },
    { "rate" : """12.2596""" },
    { "rate" : """0.4706""" },
    { "rate" : """12.19998""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.96""" },
    { "rate" : """12.26""" },
    { "rate" : """1.525""" },
    { "rate" : """8""" },
    { "rate" : """12.26""" },
    { "rate" : """0.18999""" },
    { "rate" : """1""" },
    { "rate" : """9.5""" },
    { "rate" : """2.49""" },
    { "rate" : """13.11""" },
    { "rate" : """13.71999""" },
    { "rate" : """18""" },
    { "rate" : """10.73""" },
    { "rate" : """6""" },
    { "rate" : """3.2""" },
    { "rate" : """1.74999""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """1.74""" },
    { "rate" : """18""" },
    { "rate" : """6.42""" },
    { "rate" : """12.26""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.5""" },
    { "rate" : """11.11""" },
    { "rate" : """17""" },
    { "rate" : """8""" },
    { "rate" : """12.26""" },
    { "rate" : """13.11""" },
    { "rate" : """13.71""" },
    { "rate" : """12.85""" },
    { "rate" : """13.11""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """10.73""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """8.64""" },
    { "rate" : """1.75""" },
    { "rate" : """12.01""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """0.75""" },
    { "rate" : """0.4706""" },
    { "rate" : """12.26""" },
    { "rate" : """12.25999""" },
    { "rate" : """6.5""" },
    { "rate" : """12.26""" },
    { "rate" : """12""" },
    { "rate" : """0.89""" },
    { "rate" : """12.26""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.89""" },
    { "rate" : """12.2""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9""" },
    { "rate" : """0.8888""" },
    { "rate" : """0.8""" },
    { "rate" : """9.5""" },
    { "rate" : """12.26""" },
    { "rate" : """13.11""" },
    { "rate" : """3.2""" },
    { "rate" : """12""" },
    { "rate" : """13.11""" },
    { "rate" : """12.26""" },
    { "rate" : """12.46""" },
    { "rate" : """12.26""" },
    { "rate" : """13.11""" },
    { "rate" : """1.73""" },
    { "rate" : """12.2""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """12.26""" },
    { "rate" : """13.1""" },
    { "rate" : """2""" },
    { "rate" : """5.99999""" },
    { "rate" : """11.99999""" },
    { "rate" : """5.25""" },
    { "rate" : """4.99999""" },
    { "rate" : """1.75""" },
    { "rate" : """0.85""" },
    { "rate" : """9.96""" },
    { "rate" : """1.7""" },
    { "rate" : """6""" },
    { "rate" : """12.26""" },
    { "rate" : """9.96""" },
    { "rate" : """0.9998""" },
    { "rate" : """12.25999""" },
    { "rate" : """12.26""" },
    { "rate" : """12""" },
    { "rate" : """0.98""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """13.11""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """13.11""" },
    { "rate" : """6""" },
    { "rate" : """0.8""" },
    { "rate" : """17.99999""" },
    { "rate" : """12.26""" },
    { "rate" : """12.5""" },
    { "rate" : """8.99999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12.26""" },
    { "rate" : """0.23456""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """9.4""" },
    { "rate" : """0.82""" },
    { "rate" : """13.11""" },
    { "rate" : """12""" },
    { "rate" : """1.75""" },
    { "rate" : """1.72""" },
    { "rate" : """1.72""" },
    { "rate" : """7.92""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """12""" },
    { "rate" : """11.95""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """13.11""" },
    { "rate" : """8.8""" },
    { "rate" : """6""" },
    { "rate" : """12.26""" },
    { "rate" : """12.25""" },
    { "rate" : """12.25""" },
    { "rate" : """0.99999""" },
    { "rate" : """13.11""" },
    { "rate" : """0.95""" },
    { "rate" : """6""" },
    { "rate" : """13.72""" },
    { "rate" : """12.26""" },
    { "rate" : """18""" },
    { "rate" : """2""" },
    { "rate" : """12.25999""" },
    { "rate" : """12.05556""" },
    { "rate" : """3.899""" },
    { "rate" : """12.26""" },
    { "rate" : """6""" },
    { "rate" : """0.81""" },
    { "rate" : """8.3334""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """12.26""" },
    { "rate" : """10.73""" },
    { "rate" : """4.89998""" },
    { "rate" : """13""" },
    { "rate" : """13.11""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """0.973""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """18.98""" },
    { "rate" : """23.58""" },
    { "rate" : """12""" },
    { "rate" : """11.99998""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """10.73""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7.96""" },
    { "rate" : """12""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """12.46""" },
    { "rate" : """12.26""" },
    { "rate" : """18.98""" },
    { "rate" : """0.99989""" },
    { "rate" : """11.99""" },
    { "rate" : """12.26""" },
    { "rate" : """13.11""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """0.4706""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """12.26""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """4""" },
    { "rate" : """13.11""" },
    { "rate" : """12.26""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """18""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """8.79""" },
    { "rate" : """8.75""" },
    { "rate" : """11.5""" },
    { "rate" : """12""" },
    { "rate" : """16""" },
    { "rate" : """9.5""" },
    { "rate" : """5.5""" },
    { "rate" : """11""" },
    { "rate" : """18.98""" },
    { "rate" : """12""" },
    { "rate" : """13.11""" },
    { "rate" : """4.9999""" },
    { "rate" : """12.26""" },
    { "rate" : """0.9""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """11.99""" },
    { "rate" : """11.88""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """5.5""" },
    { "rate" : """8""" },
    { "rate" : """0.99979""" },
    { "rate" : """8""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """4""" },
    { "rate" : """9.8""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """12.25""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """11.5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """12.26""" },
    { "rate" : """10.73""" },
    { "rate" : """13.11""" },
    { "rate" : """12.26""" },
    { "rate" : """12.25""" },
    { "rate" : """9.93""" },
    { "rate" : """0.25""" },
    { "rate" : """0.85""" },
    { "rate" : """2.99999""" },
    { "rate" : """9""" },
    { "rate" : """13.11""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """12.26""" },
    { "rate" : """0.999""" },
    { "rate" : """2.99999""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """3""" },
    { "rate" : """14.26""" },
    { "rate" : """7.89""" },
    { "rate" : """12.26""" },
    { "rate" : """4.9""" },
    { "rate" : """2.95""" },
    { "rate" : """12.26""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """5.5""" },
    { "rate" : """12.25""" },
    { "rate" : """9.25""" },
    { "rate" : """11""" },
    { "rate" : """12.26""" },
    { "rate" : """7""" },
    { "rate" : """4.99""" },
    { "rate" : """10""" },
    { "rate" : """12.25""" },
    { "rate" : """5.5""" },
    { "rate" : """10""" },
    { "rate" : """6.9""" },
    { "rate" : """15""" },
    { "rate" : """13""" },
    { "rate" : """12.25999""" },
    { "rate" : """12""" },
    { "rate" : """11""" },
    { "rate" : """13.7""" },
    { "rate" : """12.01""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """13.044""" },
    { "rate" : """12.99999""" },
    { "rate" : """12.26""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5.9999""" },
    { "rate" : """2""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """0.4706""" },
    { "rate" : """11.26""" },
    { "rate" : """10""" },
    { "rate" : """12.26""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """13.11""" },
    { "rate" : """8""" },
    { "rate" : """4.99""" },
    { "rate" : """11.9""" },
    { "rate" : """12""" },
    { "rate" : """4.95""" },
    { "rate" : """13.11""" },
    { "rate" : """13.7""" },
    { "rate" : """12.26""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """6.55""" },
    { "rate" : """0.00084""" },
    { "rate" : """10""" },
    { "rate" : """12.1""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """12.25""" },
    { "rate" : """0.2699""" },
    { "rate" : """12.24""" },
    { "rate" : """2""" },
    { "rate" : """0.25""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.4706""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """6.55""" },
    { "rate" : """0.5""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """12.26""" },
    { "rate" : """9.92""" },
    { "rate" : """5.5""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12.26""" },
    { "rate" : """12.2""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """18.98""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.25""" },
    { "rate" : """7.99973""" },
    { "rate" : """0.39""" },
    { "rate" : """0.5""" },
    { "rate" : """6.55""" },
    { "rate" : """0.25""" },
    { "rate" : """0.5""" },
    { "rate" : """0.96""" },
    { "rate" : """9.89""" },
    { "rate" : """0.96""" },
    { "rate" : """0.4706""" },
    { "rate" : """5.98""" },
    { "rate" : """12.25""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.92""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """9.99999""" },
    { "rate" : """13""" },
    { "rate" : """12.26""" },
    { "rate" : """13.72""" },
    { "rate" : """14.9""" },
    { "rate" : """12.25""" },
    { "rate" : """7.9""" },
    { "rate" : """5.55555""" },
    { "rate" : """18""" },
    { "rate" : """12.2599""" },
    { "rate" : """8.8""" },
    { "rate" : """12""" },
    { "rate" : """9.89999""" },
    { "rate" : """9.9999""" },
    { "rate" : """13.719""" },
    { "rate" : """16.17""" },
    { "rate" : """6""" },
    { "rate" : """13.72""" },
    { "rate" : """7.5""" },
    { "rate" : """12.5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """9.99996""" },
    { "rate" : """10""" },
    { "rate" : """9.99997""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """13.72""" },
    { "rate" : """7""" },
    { "rate" : """6.5""" },
    { "rate" : """16.17""" },
    { "rate" : """8.8""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """5.5""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """6.5""" },
    { "rate" : """1.95""" },
    { "rate" : """18.98""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """10.73""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """10.69999""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """16.17""" },
    { "rate" : """11.99999""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """6""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """10.73""" },
    { "rate" : """8""" },
    { "rate" : """5.5""" },
    { "rate" : """0.4706""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5.98""" },
    { "rate" : """9.77""" },
    { "rate" : """13.11""" },
    { "rate" : """5.9899""" },
    { "rate" : """4.95""" },
    { "rate" : """5.95""" },
    { "rate" : """8""" },
    { "rate" : """0.96""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """12.25""" },
    { "rate" : """13.11""" },
    { "rate" : """18.98""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """8.8""" },
    { "rate" : """12""" },
    { "rate" : """7.99999""" },
    { "rate" : """9.99""" },
    { "rate" : """17.95""" },
    { "rate" : """13""" },
    { "rate" : """6""" },
    { "rate" : """7.9876""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """17.64""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """9.99999""" },
    { "rate" : """8""" },
    { "rate" : """7.99998""" },
    { "rate" : """5.99998""" },
    { "rate" : """4.99998""" },
    { "rate" : """1""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.4987""" },
    { "rate" : """0.48899""" },
    { "rate" : """0.5""" },
    { "rate" : """0.4706""" },
    { "rate" : """7.89999""" },
    { "rate" : """0.5""" },
    { "rate" : """13.72""" },
    { "rate" : """0.4""" },
    { "rate" : """0.5""" },
    { "rate" : """0.4998""" },
    { "rate" : """0.4986""" },
    { "rate" : """2""" },
    { "rate" : """11""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.48""" },
    { "rate" : """0.49989""" },
    { "rate" : """0.498""" },
    { "rate" : """5.9""" },
    { "rate" : """0.49901""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """18.98""" },
    { "rate" : """0.35""" },
    { "rate" : """8""" },
    { "rate" : """0.4999""" },
    { "rate" : """6""" },
    { "rate" : """9.99998""" },
    { "rate" : """0.01""" },
    { "rate" : """6""" },
    { "rate" : """13.72""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """2""" },
    { "rate" : """0.34998""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """9.84321""" },
    { "rate" : """5.9""" },
    { "rate" : """5.99998""" },
    { "rate" : """8""" },
    { "rate" : """0.4""" },
    { "rate" : """0.49""" },
    { "rate" : """8.5""" },
    { "rate" : """0.4999""" },
    { "rate" : """9.99""" },
    { "rate" : """7.99""" },
    { "rate" : """8.79""" },
    { "rate" : """0.3987""" },
    { "rate" : """0.3""" },
    { "rate" : """0.3998""" },
    { "rate" : """7.999""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """0.35""" },
    { "rate" : """5""" },
    { "rate" : """7.9""" },
    { "rate" : """7.99999""" },
    { "rate" : """8""" },
    { "rate" : """7.4888""" },
    { "rate" : """0.96""" },
    { "rate" : """8""" },
    { "rate" : """7.89999""" },
    { "rate" : """8""" },
    { "rate" : """7.99""" },
    { "rate" : """7.99998""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.96""" },
    { "rate" : """4.9999""" },
    { "rate" : """7.8899""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """7.99999""" },
    { "rate" : """7""" },
    { "rate" : """7.96""" },
    { "rate" : """0.3""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.333""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """0.29998""" },
    { "rate" : """7.999""" },
    { "rate" : """0.3989""" },
    { "rate" : """7.99979""" },
    { "rate" : """7.99998""" },
    { "rate" : """0.38""" },
    { "rate" : """10""" },
    { "rate" : """7.89999""" },
    { "rate" : """10.73""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """0.22222""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """0.4706""" },
    { "rate" : """6""" },
    { "rate" : """7.9""" },
    { "rate" : """0.4706""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """7.99""" },
    { "rate" : """7""" },
    { "rate" : """0.49""" },
    { "rate" : """7.8""" },
    { "rate" : """7.99""" },
    { "rate" : """8""" },
    { "rate" : """10.73""" },
    { "rate" : """0.39998""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """0.96""" },
    { "rate" : """6""" },
    { "rate" : """6.5""" },
    { "rate" : """6""" },
    { "rate" : """7.975""" },
    { "rate" : """7.98765""" },
    { "rate" : """7.99998""" },
    { "rate" : """8.3334""" },
    { "rate" : """7.99998""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """9.99998""" },
    { "rate" : """0.3""" },
    { "rate" : """5.99998""" },
    { "rate" : """9.99998""" },
    { "rate" : """7.8""" },
    { "rate" : """7.99999""" },
    { "rate" : """12""" },
    { "rate" : """0.2""" },
    { "rate" : """7.99989""" },
    { "rate" : """5""" },
    { "rate" : """5.98""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """7.99999""" },
    { "rate" : """7""" },
    { "rate" : """7.99999""" },
    { "rate" : """7.999""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """7.5""" },
    { "rate" : """5.99""" },
    { "rate" : """7.99""" },
    { "rate" : """7.99""" },
    { "rate" : """5.9""" },
    { "rate" : """8""" },
    { "rate" : """7.49""" },
    { "rate" : """8""" },
    { "rate" : """7.99""" },
    { "rate" : """12""" },
    { "rate" : """8.8""" },
    { "rate" : """13.11""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """9.55""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """7.77777""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """9.99""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7.99999""" },
    { "rate" : """5.95""" },
    { "rate" : """0.4706""" },
    { "rate" : """5.99999""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """16.17""" },
    { "rate" : """10.73""" },
    { "rate" : """18.98""" },
    { "rate" : """13.11""" },
    { "rate" : """9.99""" },
    { "rate" : """19.98""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """4.99""" },
    { "rate" : """1.99999""" },
    { "rate" : """0.96""" },
    { "rate" : """1.99798""" },
    { "rate" : """8.8""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """7.8""" },
    { "rate" : """2.39""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """12.459""" },
    { "rate" : """8""" },
    { "rate" : """13.72""" },
    { "rate" : """6""" },
    { "rate" : """10.73""" },
    { "rate" : """8""" },
    { "rate" : """11""" },
    { "rate" : """18.98""" },
    { "rate" : """6""" },
    { "rate" : """10.73""" },
    { "rate" : """5.9""" },
    { "rate" : """10.73""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """12.46""" },
    { "rate" : """7.9""" },
    { "rate" : """13.11""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """0.95""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """2.38""" },
    { "rate" : """10""" },
    { "rate" : """0.9""" },
    { "rate" : """0.7""" },
    { "rate" : """10""" },
    { "rate" : """0.9""" },
    { "rate" : """1""" },
    { "rate" : """0.39998""" },
    { "rate" : """5""" },
    { "rate" : """9.9""" },
    { "rate" : """1.99899""" },
    { "rate" : """0.4706""" },
    { "rate" : """13.11""" },
    { "rate" : """0.94989""" },
    { "rate" : """13.11""" },
    { "rate" : """10.73""" },
    { "rate" : """0.98""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """18.97999""" },
    { "rate" : """6""" },
    { "rate" : """5.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """5.99999""" },
    { "rate" : """10""" },
    { "rate" : """7.99999""" },
    { "rate" : """8""" },
    { "rate" : """2.37979""" },
    { "rate" : """1""" },
    { "rate" : """2.1""" },
    { "rate" : """0.9899""" },
    { "rate" : """7.98""" },
    { "rate" : """13""" },
    { "rate" : """6""" },
    { "rate" : """7.88""" },
    { "rate" : """10""" },
    { "rate" : """0.9""" },
    { "rate" : """8""" },
    { "rate" : """7.5""" },
    { "rate" : """5.99""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """6.5""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """0.99""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """17.98""" },
    { "rate" : """8.8""" },
    { "rate" : """0.7""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """11.98""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """0.4706""" },
    { "rate" : """13.1""" },
    { "rate" : """7.8""" },
    { "rate" : """10.73""" },
    { "rate" : """6.55""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """9.99955""" },
    { "rate" : """0.4706""" },
    { "rate" : """2.1337""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """1.899""" },
    { "rate" : """13.72""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """1.33""" },
    { "rate" : """2.34""" },
    { "rate" : """0.99989""" },
    { "rate" : """1.99989""" },
    { "rate" : """6""" },
    { "rate" : """0.89996""" },
    { "rate" : """5.999""" },
    { "rate" : """1.99996""" },
    { "rate" : """1.89""" },
    { "rate" : """12""" },
    { "rate" : """1.89""" },
    { "rate" : """0.94""" },
    { "rate" : """0.38998""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """9.95""" },
    { "rate" : """0.4706""" },
    { "rate" : """6""" },
    { "rate" : """10.73""" },
    { "rate" : """12""" },
    { "rate" : """0.9999""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.9995""" },
    { "rate" : """0.99988""" },
    { "rate" : """0.973""" },
    { "rate" : """0.95""" },
    { "rate" : """0.99""" },
    { "rate" : """0.96""" },
    { "rate" : """9.99""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """0.89""" },
    { "rate" : """1.8""" },
    { "rate" : """0.99999""" },
    { "rate" : """8.55""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """0.4706""" },
    { "rate" : """2.35""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """13.1""" },
    { "rate" : """0.989""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """9.98""" },
    { "rate" : """0.95""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1.2""" },
    { "rate" : """16.17""" },
    { "rate" : """13.11""" },
    { "rate" : """0.99998""" },
    { "rate" : """8.64""" },
    { "rate" : """10.73""" },
    { "rate" : """18.98""" },
    { "rate" : """9""" },
    { "rate" : """23.58""" },
    { "rate" : """13.11""" },
    { "rate" : """0.95""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """9.8""" },
    { "rate" : """8""" },
    { "rate" : """0.99979""" },
    { "rate" : """18.98""" },
    { "rate" : """16""" },
    { "rate" : """10""" },
    { "rate" : """12.5""" },
    { "rate" : """8""" },
    { "rate" : """0.8""" },
    { "rate" : """1""" },
    { "rate" : """17.48""" },
    { "rate" : """0.4706""" },
    { "rate" : """2""" },
    { "rate" : """9.99""" },
    { "rate" : """9""" },
    { "rate" : """5.1""" },
    { "rate" : """10.73""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """0.999""" },
    { "rate" : """11""" },
    { "rate" : """12""" },
    { "rate" : """0.7""" },
    { "rate" : """13""" },
    { "rate" : """13.11""" },
    { "rate" : """16.17""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """13.11""" },
    { "rate" : """4.9""" },
    { "rate" : """6""" },
    { "rate" : """16.17""" },
    { "rate" : """8.64""" },
    { "rate" : """10.73""" },
    { "rate" : """16.17""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10.33333""" },
    { "rate" : """1.25""" },
    { "rate" : """0.9989""" },
    { "rate" : """15""" },
    { "rate" : """9.99998""" },
    { "rate" : """0.399""" },
    { "rate" : """5.99998""" },
    { "rate" : """7.99998""" },
    { "rate" : """7.98888""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.98888""" },
    { "rate" : """10.73""" },
    { "rate" : """0.29998""" },
    { "rate" : """0.39998""" },
    { "rate" : """0.35""" },
    { "rate" : """0.85""" },
    { "rate" : """0.9899""" },
    { "rate" : """16.17""" },
    { "rate" : """13.11""" },
    { "rate" : """9.5""" },
    { "rate" : """9.8""" },
    { "rate" : """13""" },
    { "rate" : """0.5""" },
    { "rate" : """0.89999""" },
    { "rate" : """0.4706""" },
    { "rate" : """4.95""" },
    { "rate" : """16.17""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """12.46""" },
    { "rate" : """6.79""" },
    { "rate" : """0.49998""" },
    { "rate" : """0.8""" },
    { "rate" : """6""" },
    { "rate" : """0.98""" },
    { "rate" : """0.6""" },
    { "rate" : """10.73""" },
    { "rate" : """0.47""" },
    { "rate" : """10""" },
    { "rate" : """0.68""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """6.55""" },
    { "rate" : """8""" },
    { "rate" : """0.45""" },
    { "rate" : """16""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """0.3""" },
    { "rate" : """8""" },
    { "rate" : """11""" },
    { "rate" : """16.66666""" },
    { "rate" : """1.25""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """7.9""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """0.4706""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """0.37772""" },
    { "rate" : """0.97722""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """9.5""" },
    { "rate" : """9.5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """8""" },
    { "rate" : """16.17""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.85999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4.99997""" },
    { "rate" : """5""" },
    { "rate" : """4.99998""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """4.59999""" },
    { "rate" : """7.99998""" },
    { "rate" : """4.99999""" },
    { "rate" : """13.11""" },
    { "rate" : """16.17""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """0.4""" },
    { "rate" : """0.4706""" },
    { "rate" : """6""" },
    { "rate" : """0.4""" },
    { "rate" : """11""" },
    { "rate" : """6.55""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """0.998""" },
    { "rate" : """8""" },
    { "rate" : """7.999""" },
    { "rate" : """2""" },
    { "rate" : """9.999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """0.48999""" },
    { "rate" : """4.9""" },
    { "rate" : """7.9""" },
    { "rate" : """0.4""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """0.3""" },
    { "rate" : """0.96""" },
    { "rate" : """0.4""" },
    { "rate" : """9""" },
    { "rate" : """0.48""" },
    { "rate" : """0.9""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.237""" },
    { "rate" : """0.39""" },
    { "rate" : """0.27""" },
    { "rate" : """0.39""" },
    { "rate" : """10.73""" },
    { "rate" : """16.17""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """0.36899""" },
    { "rate" : """0.26666""" },
    { "rate" : """0.34989""" },
    { "rate" : """0.19899""" },
    { "rate" : """10.73""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """0.4""" },
    { "rate" : """11.99""" },
    { "rate" : """2""" },
    { "rate" : """0.48199""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """0.34""" },
    { "rate" : """0.3""" },
    { "rate" : """12""" },
    { "rate" : """0.9995""" },
    { "rate" : """0.45""" },
    { "rate" : """11.99999""" },
    { "rate" : """12""" },
    { "rate" : """0.05""" },
    { "rate" : """9.5""" },
    { "rate" : """0.45""" },
    { "rate" : """5""" },
    { "rate" : """11.99999""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """7.95""" },
    { "rate" : """10""" },
    { "rate" : """9.98""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """0.4""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """0.987""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """11.99998""" },
    { "rate" : """0.99999""" },
    { "rate" : """6""" },
    { "rate" : """8.8""" },
    { "rate" : """12""" },
    { "rate" : """9.5""" },
    { "rate" : """9.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """0.26998""" },
    { "rate" : """4.5""" },
    { "rate" : """4""" },
    { "rate" : """0.96""" },
    { "rate" : """5""" },
    { "rate" : """0.4""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.89999""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.5""" },
    { "rate" : """8""" },
    { "rate" : """9.99999""" },
    { "rate" : """11.99999""" },
    { "rate" : """4.95""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """0.95""" },
    { "rate" : """0.39999""" },
    { "rate" : """16.17""" },
    { "rate" : """12""" },
    { "rate" : """0.39996""" },
    { "rate" : """4.99996""" },
    { "rate" : """13.11""" },
    { "rate" : """0.23699""" },
    { "rate" : """9.99996""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """0.28997""" },
    { "rate" : """4.99995""" },
    { "rate" : """5""" },
    { "rate" : """0.98""" },
    { "rate" : """4.89""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """4.99996""" },
    { "rate" : """18""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """11.99999""" },
    { "rate" : """0.9999""" },
    { "rate" : """16.17""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """8.64""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """6.55""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """6""" },
    { "rate" : """11.9""" },
    { "rate" : """0.96""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """0.4706""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """11.9998""" },
    { "rate" : """16.17""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """0.39999""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """13""" },
    { "rate" : """0.9""" },
    { "rate" : """12""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """4.99888""" },
    { "rate" : """1""" },
    { "rate" : """0.4706""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """0.38""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """8.8""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """0.96""" },
    { "rate" : """9""" },
    { "rate" : """14.95999""" },
    { "rate" : """15""" },
    { "rate" : """11""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """9.9899""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """16.17""" },
    { "rate" : """12""" },
    { "rate" : """0.22772""" },
    { "rate" : """16.17""" },
    { "rate" : """0.37772""" },
    { "rate" : """0.09998""" },
    { "rate" : """0.26998""" },
    { "rate" : """0.29998""" },
    { "rate" : """12""" },
    { "rate" : """4.98998""" },
    { "rate" : """15""" },
    { "rate" : """0.44""" },
    { "rate" : """11.99998""" },
    { "rate" : """6.55""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """14.99998""" },
    { "rate" : """7.99998""" },
    { "rate" : """9""" },
    { "rate" : """16.17""" },
    { "rate" : """8.99998""" },
    { "rate" : """0.96""" },
    { "rate" : """13.11""" },
    { "rate" : """9""" },
    { "rate" : """16.17""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """16.17""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """16""" },
    { "rate" : """8.64""" },
    { "rate" : """9.96""" },
    { "rate" : """13.11""" },
    { "rate" : """12""" },
    { "rate" : """16.17""" },
    { "rate" : """9""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """11.99996""" },
    { "rate" : """8.8""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """4.99998""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """11""" },
    { "rate" : """15""" },
    { "rate" : """0.4706""" },
    { "rate" : """8""" },
    { "rate" : """4.99998""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """10.99""" },
    { "rate" : """14.9""" },
    { "rate" : """8""" },
    { "rate" : """11.95""" },
    { "rate" : """9.95""" },
    { "rate" : """10.73""" },
    { "rate" : """11.9999""" },
    { "rate" : """0.24998""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """16.16999""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """11""" },
    { "rate" : """14.95""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """11.995""" },
    { "rate" : """9.9""" },
    { "rate" : """11.99996""" },
    { "rate" : """0.38""" },
    { "rate" : """8""" },
    { "rate" : """13.11""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """9.5""" },
    { "rate" : """12.99998""" },
    { "rate" : """8""" },
    { "rate" : """0.28998""" },
    { "rate" : """12.99998""" },
    { "rate" : """0.38""" },
    { "rate" : """10""" },
    { "rate" : """4.98""" },
    { "rate" : """9""" },
    { "rate" : """8.5""" },
    { "rate" : """0.29997""" },
    { "rate" : """9.96""" },
    { "rate" : """7""" },
    { "rate" : """4.9899""" },
    { "rate" : """0.28998""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """0.2""" },
    { "rate" : """19.9999""" },
    { "rate" : """0.28998""" },
    { "rate" : """9.98888""" },
    { "rate" : """7.99999""" },
    { "rate" : """7.999""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """13.11""" },
    { "rate" : """3.00001""" },
    { "rate" : """4.999""" },
    { "rate" : """7.99998""" },
    { "rate" : """0.29997""" },
    { "rate" : """11.999""" },
    { "rate" : """13""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """8.99""" },
    { "rate" : """4.99998""" },
    { "rate" : """5""" },
    { "rate" : """0.9999""" },
    { "rate" : """5""" },
    { "rate" : """4.9999""" },
    { "rate" : """5""" },
    { "rate" : """0.75""" },
    { "rate" : """9.96""" },
    { "rate" : """18.98""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.4706""" },
    { "rate" : """5""" },
    { "rate" : """0.4706""" },
    { "rate" : """5""" },
    { "rate" : """5.9""" },
    { "rate" : """0.73998""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """0.99997""" },
    { "rate" : """9""" },
    { "rate" : """11.95""" },
    { "rate" : """0.74""" },
    { "rate" : """9""" },
    { "rate" : """7.95""" },
    { "rate" : """7.95""" },
    { "rate" : """0.9""" },
    { "rate" : """14.5""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.49998""" },
    { "rate" : """0.49998""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """1""" },
    { "rate" : """11.9999""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.989""" },
    { "rate" : """0.74999""" },
    { "rate" : """0.29""" },
    { "rate" : """0.75999""" },
    { "rate" : """12""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """13.1""" },
    { "rate" : """8""" },
    { "rate" : """0.29""" },
    { "rate" : """0.98""" },
    { "rate" : """0.35""" },
    { "rate" : """0.6""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """0.99""" },
    { "rate" : """8.49999""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """0.77""" },
    { "rate" : """9""" },
    { "rate" : """10.5""" },
    { "rate" : """16""" },
    { "rate" : """9.5""" },
    { "rate" : """16.16999""" },
    { "rate" : """0.76""" },
    { "rate" : """0.4706""" },
    { "rate" : """16.16""" },
    { "rate" : """12""" },
    { "rate" : """0.75""" },
    { "rate" : """16.17""" },
    { "rate" : """9.96""" },
    { "rate" : """13.11""" },
    { "rate" : """16.17""" },
    { "rate" : """9.96""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """9.96""" },
    { "rate" : """0.74998""" },
    { "rate" : """0.388""" },
    { "rate" : """9.99999""" },
    { "rate" : """14.99999""" },
    { "rate" : """13.11""" },
    { "rate" : """12.46""" },
    { "rate" : """0.4706""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """7""" },
    { "rate" : """8.8""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """8.8""" },
    { "rate" : """2""" },
    { "rate" : """10.73""" },
    { "rate" : """10""" },
    { "rate" : """10.73""" },
    { "rate" : """9.96""" },
    { "rate" : """12""" },
    { "rate" : """14.9999""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """5.99999""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5.98""" },
    { "rate" : """15.9""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """9.99999""" },
    { "rate" : """5.99998""" },
    { "rate" : """5.555""" },
    { "rate" : """5.9998""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """0.4706""" },
    { "rate" : """10""" },
    { "rate" : """5.8""" },
    { "rate" : """5.89999""" },
    { "rate" : """6""" },
    { "rate" : """16.16""" },
    { "rate" : """6""" },
    { "rate" : """5.9999""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """5.9""" },
    { "rate" : """6""" },
    { "rate" : """5.99999""" },
    { "rate" : """6.55""" },
    { "rate" : """11.5""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5.79""" },
    { "rate" : """5.99""" },
    { "rate" : """13.11""" },
    { "rate" : """16.17""" },
    { "rate" : """4.99999""" },
    { "rate" : """12.46""" },
    { "rate" : """16.17""" },
    { "rate" : """5.99998""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """0.4706""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.4706""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """4""" },
    { "rate" : """13.72""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5.99999""" },
    { "rate" : """15.99""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """11""" },
    { "rate" : """8.7""" },
    { "rate" : """5.2""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """0.19""" },
    { "rate" : """0.00084""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """0.5""" },
    { "rate" : """4.9999""" },
    { "rate" : """0.5""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.4706""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """13.72""" },
    { "rate" : """7.99""" },
    { "rate" : """0.59999""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """4.5""" },
    { "rate" : """0.39972""" },
    { "rate" : """0.3""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """7.99999""" },
    { "rate" : """13.05""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """10.72""" },
    { "rate" : """0.2""" },
    { "rate" : """1.95""" },
    { "rate" : """5.78998""" },
    { "rate" : """16.17""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """4.87""" },
    { "rate" : """5""" },
    { "rate" : """4.8""" },
    { "rate" : """4""" },
    { "rate" : """5.78""" },
    { "rate" : """15""" },
    { "rate" : """8.75""" },
    { "rate" : """10""" },
    { "rate" : """5.9""" },
    { "rate" : """9.96""" },
    { "rate" : """5.99997""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """4.49""" },
    { "rate" : """8.7""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """5.3""" },
    { "rate" : """10.73""" },
    { "rate" : """5""" },
    { "rate" : """12.3""" },
    { "rate" : """6""" },
    { "rate" : """14.8""" },
    { "rate" : """7.9""" },
    { "rate" : """7.8""" },
    { "rate" : """7.9""" },
    { "rate" : """13.11""" },
    { "rate" : """13.7""" },
    { "rate" : """10.73""" },
    { "rate" : """6""" },
    { "rate" : """13.11""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.4706""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """13""" },
    { "rate" : """5.9""" },
    { "rate" : """5.99999""" },
    { "rate" : """7.9""" },
    { "rate" : """13.72""" },
    { "rate" : """8.9""" },
    { "rate" : """0.238""" },
    { "rate" : """9.96""" },
    { "rate" : """6.55""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """13.11""" },
    { "rate" : """16""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """9.95996""" },
    { "rate" : """10.72888""" },
    { "rate" : """8.88""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """16.17""" },
    { "rate" : """1.9999""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """9""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """9.99999""" },
    { "rate" : """11.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """10.73""" },
    { "rate" : """6""" },
    { "rate" : """5.9""" },
    { "rate" : """8.8""" },
    { "rate" : """5.99998""" },
    { "rate" : """9.99""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """9.9999""" },
    { "rate" : """8""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """7.99999""" },
    { "rate" : """8""" },
    { "rate" : """15.9""" },
    { "rate" : """12""" },
    { "rate" : """12.46""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """13""" },
    { "rate" : """14""" },
    { "rate" : """16.17""" },
    { "rate" : """6""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """13.11""" },
    { "rate" : """9""" },
    { "rate" : """13.1""" },
    { "rate" : """14.99999""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """16""" },
    { "rate" : """15.99999""" },
    { "rate" : """16.17""" },
    { "rate" : """2""" },
    { "rate" : """16.17""" },
    { "rate" : """7""" },
    { "rate" : """15.89""" },
    { "rate" : """16.17""" },
    { "rate" : """13.11""" },
    { "rate" : """14""" },
    { "rate" : """16.17""" },
    { "rate" : """11.11""" },
    { "rate" : """2""" },
    { "rate" : """3.99999""" },
    { "rate" : """12.9898""" },
    { "rate" : """5.99999""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """9.66""" },
    { "rate" : """13.11""" },
    { "rate" : """9.9""" },
    { "rate" : """12.95""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """5.99""" },
    { "rate" : """12.99""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """13.11""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """13.72""" },
    { "rate" : """16.17""" },
    { "rate" : """4""" },
    { "rate" : """9.96""" },
    { "rate" : """4""" },
    { "rate" : """13.1""" },
    { "rate" : """10.72""" },
    { "rate" : """12""" },
    { "rate" : """13""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """13.1""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.4706""" },
    { "rate" : """7.9""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """5.9999""" },
    { "rate" : """7.9999""" },
    { "rate" : """8.9999""" },
    { "rate" : """12.99""" },
    { "rate" : """13.109""" },
    { "rate" : """7.98""" },
    { "rate" : """5.9999""" },
    { "rate" : """5""" },
    { "rate" : """8.9999""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """16.17""" },
    { "rate" : """5.99""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """8.7""" },
    { "rate" : """9""" },
    { "rate" : """12.99""" },
    { "rate" : """10.73""" },
    { "rate" : """7.6""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """4.99999""" },
    { "rate" : """10""" },
    { "rate" : """9.987""" },
    { "rate" : """6.8""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """10.73""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """13.1091""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """7""" },
    { "rate" : """5.99999""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """16.17""" },
    { "rate" : """4.7""" },
    { "rate" : """5""" },
    { "rate" : """9.9999""" },
    { "rate" : """4""" },
    { "rate" : """10.73""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """5.9""" },
    { "rate" : """5""" },
    { "rate" : """13.1""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """3.33""" },
    { "rate" : """4.95""" },
    { "rate" : """15""" },
    { "rate" : """3.23988""" },
    { "rate" : """6""" },
    { "rate" : """12.5""" },
    { "rate" : """8""" },
    { "rate" : """13""" },
    { "rate" : """6""" },
    { "rate" : """3.5""" },
    { "rate" : """7""" },
    { "rate" : """13.11""" },
    { "rate" : """15""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """12.99999""" },
    { "rate" : """12.98""" },
    { "rate" : """7.32""" },
    { "rate" : """3.24""" },
    { "rate" : """3.33""" },
    { "rate" : """10.58""" },
    { "rate" : """3.333""" },
    { "rate" : """8.8""" },
    { "rate" : """12.99998""" },
    { "rate" : """15""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """13.09999""" },
    { "rate" : """13""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """3.24""" },
    { "rate" : """4""" },
    { "rate" : """13.11""" },
    { "rate" : """0.4706""" },
    { "rate" : """13.09999""" },
    { "rate" : """4.9999""" },
    { "rate" : """12.4599""" },
    { "rate" : """0.96""" },
    { "rate" : """6.55""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """3.24""" },
    { "rate" : """15""" },
    { "rate" : """9.99""" },
    { "rate" : """15""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13""" },
    { "rate" : """3""" },
    { "rate" : """6.87""" },
    { "rate" : """4""" },
    { "rate" : """0.96""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """12.9899""" },
    { "rate" : """3.24""" },
    { "rate" : """5""" },
    { "rate" : """6.98998""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """11.5""" },
    { "rate" : """3.24""" },
    { "rate" : """13.11""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """12.46""" },
    { "rate" : """13""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """13.11""" },
    { "rate" : """3.24""" },
    { "rate" : """7""" },
    { "rate" : """13""" },
    { "rate" : """13.11""" },
    { "rate" : """10.73""" },
    { "rate" : """5""" },
    { "rate" : """12.99999""" },
    { "rate" : """13.1""" },
    { "rate" : """0.9999""" },
    { "rate" : """13.10908""" },
    { "rate" : """13""" },
    { "rate" : """0.96""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.8""" },
    { "rate" : """13.1""" },
    { "rate" : """0.99998""" },
    { "rate" : """0.75""" },
    { "rate" : """0.975""" },
    { "rate" : """7.999""" },
    { "rate" : """16.17""" },
    { "rate" : """4.999""" },
    { "rate" : """0.46998""" },
    { "rate" : """0.49998""" },
    { "rate" : """12.999""" },
    { "rate" : """10.73""" },
    { "rate" : """12.98998""" },
    { "rate" : """0.69998""" },
    { "rate" : """13""" },
    { "rate" : """0.999""" },
    { "rate" : """0.75""" },
    { "rate" : """0.8""" },
    { "rate" : """7""" },
    { "rate" : """12.2552""" },
    { "rate" : """0.799""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.7""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.99979""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.7""" },
    { "rate" : """0.79""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.989""" },
    { "rate" : """0.999""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.989""" },
    { "rate" : """0.99""" },
    { "rate" : """0.78989""" },
    { "rate" : """13.11""" },
    { "rate" : """0.78989""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.99989""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """0.98999""" },
    { "rate" : """0.7""" },
    { "rate" : """10.71999""" },
    { "rate" : """0.98899""" },
    { "rate" : """0.8""" },
    { "rate" : """0.4706""" },
    { "rate" : """10.7""" },
    { "rate" : """9""" },
    { "rate" : """0.95""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """0.75""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.29998""" },
    { "rate" : """0.47""" },
    { "rate" : """0.75""" },
    { "rate" : """0.7""" },
    { "rate" : """0.98""" },
    { "rate" : """0.98998""" },
    { "rate" : """0.75""" },
    { "rate" : """1""" },
    { "rate" : """8.8""" },
    { "rate" : """0.78999""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """0.5""" },
    { "rate" : """15""" },
    { "rate" : """13.72""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.6998""" },
    { "rate" : """0.94999""" },
    { "rate" : """0.6""" },
    { "rate" : """0.4""" },
    { "rate" : """0.3979""" },
    { "rate" : """0.5""" },
    { "rate" : """0.3""" },
    { "rate" : """0.5""" },
    { "rate" : """6.9""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """13.72""" },
    { "rate" : """0.4""" },
    { "rate" : """0.6""" },
    { "rate" : """13.11""" },
    { "rate" : """8.8""" },
    { "rate" : """1""" },
    { "rate" : """10.73""" },
    { "rate" : """13.11""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """0.75999""" },
    { "rate" : """0.75999""" },
    { "rate" : """8.8""" },
    { "rate" : """0.35999""" },
    { "rate" : """8.8""" },
    { "rate" : """13.11""" },
    { "rate" : """1""" },
    { "rate" : """10.73""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """9.99998""" },
    { "rate" : """12.99998""" },
    { "rate" : """8.9""" },
    { "rate" : """13""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """10.73""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.4706""" },
    { "rate" : """5""" },
    { "rate" : """11.5""" },
    { "rate" : """12.46""" },
    { "rate" : """12.999""" },
    { "rate" : """13""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """12.26""" },
    { "rate" : """0.5""" },
    { "rate" : """0.91""" },
    { "rate" : """5.8""" },
    { "rate" : """8.8""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """4.9""" },
    { "rate" : """2""" },
    { "rate" : """13.11""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """13.11""" },
    { "rate" : """14.5""" },
    { "rate" : """9""" },
    { "rate" : """14""" },
    { "rate" : """6""" },
    { "rate" : """12.26""" },
    { "rate" : """16.17""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """15.9998""" },
    { "rate" : """16""" },
    { "rate" : """15""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """0.5""" },
    { "rate" : """0.08998""" },
    { "rate" : """0.4706""" },
    { "rate" : """15""" },
    { "rate" : """16""" },
    { "rate" : """0.75""" },
    { "rate" : """0.238""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """16.16""" },
    { "rate" : """8.78""" },
    { "rate" : """16.16""" },
    { "rate" : """13.1""" },
    { "rate" : """2.5""" },
    { "rate" : """13.10998""" },
    { "rate" : """0.1998""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """2.5""" },
    { "rate" : """8""" },
    { "rate" : """7.99""" },
    { "rate" : """8.8""" },
    { "rate" : """2.5""" },
    { "rate" : """14.9999""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """12.99999""" },
    { "rate" : """16.17""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """0.4706""" },
    { "rate" : """2""" },
    { "rate" : """11""" },
    { "rate" : """12""" },
    { "rate" : """13.11""" },
    { "rate" : """15""" },
    { "rate" : """13.89""" },
    { "rate" : """2.5""" },
    { "rate" : """12""" },
    { "rate" : """16""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.49""" },
    { "rate" : """2.5""" },
    { "rate" : """12""" },
    { "rate" : """0.2""" },
    { "rate" : """13.11""" },
    { "rate" : """3.24""" },
    { "rate" : """14""" },
    { "rate" : """0.3987""" },
    { "rate" : """13""" },
    { "rate" : """0.24987""" },
    { "rate" : """23.58""" },
    { "rate" : """0.4987""" },
    { "rate" : """2.5""" },
    { "rate" : """0.4706""" },
    { "rate" : """2.5""" },
    { "rate" : """0.49869""" },
    { "rate" : """0.39998""" },
    { "rate" : """0.49""" },
    { "rate" : """0.32""" },
    { "rate" : """2.5""" },
    { "rate" : """11.99996""" },
    { "rate" : """12.99998""" },
    { "rate" : """4.99997""" },
    { "rate" : """3.33334""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """0.04998""" },
    { "rate" : """11""" },
    { "rate" : """12""" },
    { "rate" : """13.9""" },
    { "rate" : """11""" },
    { "rate" : """11""" },
    { "rate" : """9""" },
    { "rate" : """6.99998""" },
    { "rate" : """11.48""" },
    { "rate" : """15.99997""" },
    { "rate" : """0.4706""" },
    { "rate" : """10""" },
    { "rate" : """4.66""" },
    { "rate" : """0.338""" },
    { "rate" : """0.398""" },
    { "rate" : """11.99995""" },
    { "rate" : """12.99999""" },
    { "rate" : """5""" },
    { "rate" : """16.16999""" },
    { "rate" : """23.58""" },
    { "rate" : """4.9""" },
    { "rate" : """11.9""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.4706""" },
    { "rate" : """6.9""" },
    { "rate" : """12.46""" },
    { "rate" : """3.24""" },
    { "rate" : """13.11""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """12.46""" },
    { "rate" : """16""" },
    { "rate" : """6.99999""" },
    { "rate" : """12""" },
    { "rate" : """13""" },
    { "rate" : """12.9""" },
    { "rate" : """13.09""" },
    { "rate" : """14.99999""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """13.10899""" },
    { "rate" : """6""" },
    { "rate" : """14.5""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """23.58""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """0.96""" },
    { "rate" : """13.11""" },
    { "rate" : """13""" },
    { "rate" : """13.11""" },
    { "rate" : """4.8""" },
    { "rate" : """2""" },
    { "rate" : """12.26""" },
    { "rate" : """11.99999""" },
    { "rate" : """12.46""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """0.5""" },
    { "rate" : """9""" },
    { "rate" : """13""" },
    { "rate" : """13.5""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """15.9999""" },
    { "rate" : """11.99999""" },
    { "rate" : """2.5""" },
    { "rate" : """13.1""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """10.73""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """11.99999""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """14.99999""" },
    { "rate" : """11.99999""" },
    { "rate" : """12""" },
    { "rate" : """16""" },
    { "rate" : """13""" },
    { "rate" : """9.25""" },
    { "rate" : """13.1099""" },
    { "rate" : """13""" },
    { "rate" : """16""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """13""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """20""" },
    { "rate" : """13.11""" },
    { "rate" : """16""" },
    { "rate" : """5""" },
    { "rate" : """12.4""" },
    { "rate" : """2.5""" },
    { "rate" : """0.2""" },
    { "rate" : """9.99""" },
    { "rate" : """12""" },
    { "rate" : """14""" },
    { "rate" : """12.26""" },
    { "rate" : """6.999""" },
    { "rate" : """12.2552""" },
    { "rate" : """8""" },
    { "rate" : """11""" },
    { "rate" : """12""" },
    { "rate" : """13""" },
    { "rate" : """6""" },
    { "rate" : """5.98888""" },
    { "rate" : """12""" },
    { "rate" : """8.8""" },
    { "rate" : """12.26""" },
    { "rate" : """11.9""" },
    { "rate" : """12""" },
    { "rate" : """10.99999""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """7""" },
    { "rate" : """23.58""" },
    { "rate" : """12.26""" },
    { "rate" : """7""" },
    { "rate" : """11.95""" },
    { "rate" : """12.26""" },
    { "rate" : """12.46""" },
    { "rate" : """12.26""" },
    { "rate" : """12""" },
    { "rate" : """12.26""" },
    { "rate" : """23.58""" },
    { "rate" : """6""" },
    { "rate" : """13""" },
    { "rate" : """9.96""" },
    { "rate" : """7""" },
    { "rate" : """11.99998""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """4.99999""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """16.17""" },
    { "rate" : """17.48""" },
    { "rate" : """7""" },
    { "rate" : """16.17""" },
    { "rate" : """16""" },
    { "rate" : """20""" },
    { "rate" : """13.11""" },
    { "rate" : """0.34""" },
    { "rate" : """12.2""" },
    { "rate" : """8""" },
    { "rate" : """11.95""" },
    { "rate" : """17.56""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """9""" },
    { "rate" : """11""" },
    { "rate" : """8""" },
    { "rate" : """11""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """16""" },
    { "rate" : """2.5""" },
    { "rate" : """12.46""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """12.26""" },
    { "rate" : """6""" },
    { "rate" : """12.26""" },
    { "rate" : """1.73999""" },
    { "rate" : """1.74""" },
    { "rate" : """1.5""" },
    { "rate" : """6.1""" },
    { "rate" : """7""" },
    { "rate" : """11""" },
    { "rate" : """1.74868""" },
    { "rate" : """11.99""" },
    { "rate" : """1.73998""" },
    { "rate" : """13""" },
    { "rate" : """4""" },
    { "rate" : """12.26""" },
    { "rate" : """1.68997""" },
    { "rate" : """12.25999""" },
    { "rate" : """0.24""" },
    { "rate" : """13.11""" },
    { "rate" : """17.48""" },
    { "rate" : """14""" },
    { "rate" : """4.99""" },
    { "rate" : """12.5""" },
    { "rate" : """0.4""" },
    { "rate" : """1.7""" },
    { "rate" : """10""" },
    { "rate" : """0.4706""" },
    { "rate" : """1.7""" },
    { "rate" : """1.73""" },
    { "rate" : """1.74""" },
    { "rate" : """1.74999""" },
    { "rate" : """12.26""" },
    { "rate" : """16.17""" },
    { "rate" : """4""" },
    { "rate" : """13""" },
    { "rate" : """1.45""" },
    { "rate" : """5""" },
    { "rate" : """1.744""" },
    { "rate" : """9.96""" },
    { "rate" : """12.99999""" },
    { "rate" : """12.9999""" },
    { "rate" : """15.99999""" },
    { "rate" : """0.4995""" },
    { "rate" : """5.99999""" },
    { "rate" : """10""" },
    { "rate" : """11.99999""" },
    { "rate" : """1.749""" },
    { "rate" : """0.96""" },
    { "rate" : """23""" },
    { "rate" : """1.74""" },
    { "rate" : """1.7""" },
    { "rate" : """13.1""" },
    { "rate" : """12.26""" },
    { "rate" : """1.749""" },
    { "rate" : """12.99998""" },
    { "rate" : """1.72""" },
    { "rate" : """16.17""" },
    { "rate" : """5""" },
    { "rate" : """1.74""" },
    { "rate" : """1.74888""" },
    { "rate" : """0.4""" },
    { "rate" : """1.739""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """3.64""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5.5""" },
    { "rate" : """3.63998""" },
    { "rate" : """1.74772""" },
    { "rate" : """13""" },
    { "rate" : """1""" },
    { "rate" : """0.999""" },
    { "rate" : """0.4987""" },
    { "rate" : """1.6987""" },
    { "rate" : """4.99999""" },
    { "rate" : """0.4706""" },
    { "rate" : """5""" },
    { "rate" : """0.09998""" },
    { "rate" : """5""" },
    { "rate" : """2.49999""" },
    { "rate" : """3.64""" },
    { "rate" : """0.75999""" },
    { "rate" : """4.99""" },
    { "rate" : """4.79999""" },
    { "rate" : """1""" },
    { "rate" : """3.64""" },
    { "rate" : """1.74989""" },
    { "rate" : """6.25""" },
    { "rate" : """5.99""" },
    { "rate" : """0.9""" },
    { "rate" : """12.26""" },
    { "rate" : """5.98""" },
    { "rate" : """4.94""" },
    { "rate" : """12.26""" },
    { "rate" : """1.7""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """4.5""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """1.69""" },
    { "rate" : """12.26""" },
    { "rate" : """2""" },
    { "rate" : """1.74997""" },
    { "rate" : """13""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6.24999""" },
    { "rate" : """4.99999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """0.44999""" },
    { "rate" : """6""" },
    { "rate" : """11""" },
    { "rate" : """0.1""" },
    { "rate" : """11""" },
    { "rate" : """3.6599""" },
    { "rate" : """12.2599""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """1.74""" },
    { "rate" : """8.7""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """1.74""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """1.74""" },
    { "rate" : """0.4706""" },
    { "rate" : """6""" },
    { "rate" : """1.73""" },
    { "rate" : """12.26""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """3.2""" },
    { "rate" : """5.9999""" },
    { "rate" : """13""" },
    { "rate" : """12.26""" },
    { "rate" : """23.57""" },
    { "rate" : """1.74899""" },
    { "rate" : """6.99999""" },
    { "rate" : """2""" },
    { "rate" : """4.9""" },
    { "rate" : """12.46""" },
    { "rate" : """0.23""" },
    { "rate" : """6""" },
    { "rate" : """5.9""" },
    { "rate" : """6.2499""" },
    { "rate" : """5""" },
    { "rate" : """11.5""" },
    { "rate" : """3.64""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """8.69""" },
    { "rate" : """0.4""" },
    { "rate" : """0.5""" },
    { "rate" : """4""" },
    { "rate" : """4.99999""" },
    { "rate" : """8.99999""" },
    { "rate" : """5.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """5""" },
    { "rate" : """5.99999""" },
    { "rate" : """6.55""" },
    { "rate" : """12.46""" },
    { "rate" : """6""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.4706""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """13""" },
    { "rate" : """12""" },
    { "rate" : """6.55""" },
    { "rate" : """23.58""" },
    { "rate" : """12.26""" },
    { "rate" : """0.4706""" },
    { "rate" : """12""" },
    { "rate" : """12.46""" },
    { "rate" : """2""" },
    { "rate" : """17.48""" },
    { "rate" : """13""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """12.26""" },
    { "rate" : """12""" },
    { "rate" : """0.4706""" },
    { "rate" : """13.26""" },
    { "rate" : """11.65""" },
    { "rate" : """12.11""" },
    { "rate" : """7""" },
    { "rate" : """13""" },
    { "rate" : """3.72""" },
    { "rate" : """12.5""" },
    { "rate" : """14""" },
    { "rate" : """4""" },
    { "rate" : """12.99999""" },
    { "rate" : """5""" },
    { "rate" : """0.3388""" },
    { "rate" : """12.9552""" },
    { "rate" : """0.195""" },
    { "rate" : """0.1999""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """0.4706""" },
    { "rate" : """7""" },
    { "rate" : """13.72""" },
    { "rate" : """12.26""" },
    { "rate" : """12.46""" },
    { "rate" : """9.96""" },
    { "rate" : """13.72""" },
    { "rate" : """17.48""" },
    { "rate" : """13.72""" },
    { "rate" : """5.999""" },
    { "rate" : """12.99""" },
    { "rate" : """5.999""" },
    { "rate" : """5""" },
    { "rate" : """8.999""" },
    { "rate" : """3.99""" },
    { "rate" : """5""" },
    { "rate" : """14.99""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """17.48""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """9.99""" },
    { "rate" : """13.11""" },
    { "rate" : """17.48""" },
    { "rate" : """23.58""" },
    { "rate" : """17.48""" },
    { "rate" : """4""" },
    { "rate" : """12.99""" },
    { "rate" : """6.55""" },
    { "rate" : """0.96""" },
    { "rate" : """7""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """13.11""" },
    { "rate" : """7""" },
    { "rate" : """6.55""" },
    { "rate" : """7""" },
    { "rate" : """14.5""" },
    { "rate" : """13.99""" },
    { "rate" : """12.7""" },
    { "rate" : """6""" },
    { "rate" : """7.77""" },
    { "rate" : """12.46""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """9.55""" },
    { "rate" : """8.8""" },
    { "rate" : """6""" },
    { "rate" : """12.2552""" },
    { "rate" : """0.4706""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """17.48""" },
    { "rate" : """9.9""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """4.97998""" },
    { "rate" : """0.96""" },
    { "rate" : """5""" },
    { "rate" : """4.98""" },
    { "rate" : """12.46""" },
    { "rate" : """17.48""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """6.99""" },
    { "rate" : """0.15""" },
    { "rate" : """0.15""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """12.9""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """4.9""" },
    { "rate" : """6.8""" },
    { "rate" : """4.99997""" },
    { "rate" : """4.99996""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """4.8""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """17.48""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.98""" },
    { "rate" : """5.99999""" },
    { "rate" : """0.0002""" },
    { "rate" : """0.0002""" },
    { "rate" : """7""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """17.48""" },
    { "rate" : """16.17""" },
    { "rate" : """12.24""" },
    { "rate" : """4.5""" },
    { "rate" : """4.5""" },
    { "rate" : """0.19""" },
    { "rate" : """0.19""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """6.5""" },
    { "rate" : """6.99""" },
    { "rate" : """7""" },
    { "rate" : """0.4706""" },
    { "rate" : """7""" },
    { "rate" : """0.96""" },
    { "rate" : """12""" },
    { "rate" : """4.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """12.99999""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """6.99999""" },
    { "rate" : """12""" },
    { "rate" : """11.95""" },
    { "rate" : """12""" },
    { "rate" : """5.5""" },
    { "rate" : """4.8""" },
    { "rate" : """6.5""" },
    { "rate" : """11.5""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """13""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """6.95""" },
    { "rate" : """0.5""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.987""" },
    { "rate" : """0.4981""" },
    { "rate" : """12""" },
    { "rate" : """0.96""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.98999""" },
    { "rate" : """14""" },
    { "rate" : """12.26""" },
    { "rate" : """11.99998""" },
    { "rate" : """17.48""" },
    { "rate" : """4.99998""" },
    { "rate" : """0.5""" },
    { "rate" : """6.99998""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """0.986""" },
    { "rate" : """0.5""" },
    { "rate" : """11.9""" },
    { "rate" : """5""" },
    { "rate" : """6.99""" },
    { "rate" : """11.99999""" },
    { "rate" : """6.9""" },
    { "rate" : """12.55552""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """13""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """17.48""" },
    { "rate" : """0.4706""" },
    { "rate" : """7""" },
    { "rate" : """4.99996""" },
    { "rate" : """12.46""" },
    { "rate" : """0.22772""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """17.48""" },
    { "rate" : """0.5""" },
    { "rate" : """0.75""" },
    { "rate" : """0.79999""" },
    { "rate" : """2""" },
    { "rate" : """4.9""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.09998""" },
    { "rate" : """11.99997""" },
    { "rate" : """9.95998""" },
    { "rate" : """6.99998""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """0.75""" },
    { "rate" : """7""" },
    { "rate" : """4.99""" },
    { "rate" : """11.99999""" },
    { "rate" : """17.48""" },
    { "rate" : """12.99999""" },
    { "rate" : """13""" },
    { "rate" : """11.99""" },
    { "rate" : """7""" },
    { "rate" : """17.48""" },
    { "rate" : """15.48""" },
    { "rate" : """12""" },
    { "rate" : """11.99998""" },
    { "rate" : """14.99""" },
    { "rate" : """13""" },
    { "rate" : """0.4706""" },
    { "rate" : """6""" },
    { "rate" : """12.46""" },
    { "rate" : """11.8""" },
    { "rate" : """5""" },
    { "rate" : """16.17""" },
    { "rate" : """4.99""" },
    { "rate" : """17.48""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12.46""" },
    { "rate" : """17.47""" },
    { "rate" : """12.45""" },
    { "rate" : """6.55""" },
    { "rate" : """12.46""" },
    { "rate" : """12.26""" },
    { "rate" : """6.55""" },
    { "rate" : """12.46""" },
    { "rate" : """11.98""" },
    { "rate" : """4.98""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """12.46""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """13.07""" },
    { "rate" : """11.9""" },
    { "rate" : """9.99998""" },
    { "rate" : """0.96""" },
    { "rate" : """17.47""" },
    { "rate" : """12.95""" },
    { "rate" : """0.75999""" },
    { "rate" : """10""" },
    { "rate" : """0.00999""" },
    { "rate" : """1.5""" },
    { "rate" : """0.99""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """12.46""" },
    { "rate" : """1.49""" },
    { "rate" : """12""" },
    { "rate" : """12.45""" },
    { "rate" : """8.8""" },
    { "rate" : """4.89""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """4.5""" },
    { "rate" : """12""" },
    { "rate" : """9""" },
    { "rate" : """11.99997""" },
    { "rate" : """6.99972""" },
    { "rate" : """6.99911""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """9.96""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """0.19""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """6.99""" },
    { "rate" : """12.46""" },
    { "rate" : """9.96""" },
    { "rate" : """13""" },
    { "rate" : """17.4""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """6.9999""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """6.99999""" },
    { "rate" : """11.99""" },
    { "rate" : """13""" },
    { "rate" : """13""" },
    { "rate" : """12.99""" },
    { "rate" : """11.5""" },
    { "rate" : """9.99""" },
    { "rate" : """11.99""" },
    { "rate" : """6.98999""" },
    { "rate" : """4.99995""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """9.96""" },
    { "rate" : """7""" },
    { "rate" : """11.9""" },
    { "rate" : """1.4987""" },
    { "rate" : """1.9""" },
    { "rate" : """0.4706""" },
    { "rate" : """1.99""" },
    { "rate" : """1.49""" },
    { "rate" : """4.99999""" },
    { "rate" : """12""" },
    { "rate" : """12.46""" },
    { "rate" : """16.17""" },
    { "rate" : """0.96""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """0.4706""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """18.98""" },
    { "rate" : """4.99""" },
    { "rate" : """6.99""" },
    { "rate" : """6""" },
    { "rate" : """18.98""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """12.4""" },
    { "rate" : """12.46""" },
    { "rate" : """18.98""" },
    { "rate" : """9.96""" },
    { "rate" : """0.4706""" },
    { "rate" : """7.88""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """15.99""" },
    { "rate" : """8""" },
    { "rate" : """13.11""" },
    { "rate" : """4.99""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.96""" },
    { "rate" : """9.98""" },
    { "rate" : """12.46""" },
    { "rate" : """7""" },
    { "rate" : """4.9999""" },
    { "rate" : """16""" },
    { "rate" : """16""" },
    { "rate" : """8""" },
    { "rate" : """17""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """13.11""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """16""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """12.46""" },
    { "rate" : """0.8888""" },
    { "rate" : """6""" },
    { "rate" : """4.95""" },
    { "rate" : """0.87999""" },
    { "rate" : """7""" },
    { "rate" : """4.8""" },
    { "rate" : """9.98""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """7.5""" },
    { "rate" : """5.9""" },
    { "rate" : """4.99""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """16""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """16.17""" },
    { "rate" : """4.9""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7.8""" },
    { "rate" : """5""" },
    { "rate" : """9.99""" },
    { "rate" : """12""" },
    { "rate" : """4.99998""" },
    { "rate" : """15.99998""" },
    { "rate" : """5""" },
    { "rate" : """4.99998""" },
    { "rate" : """4.99998""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """16""" },
    { "rate" : """3.999""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """0.4706""" },
    { "rate" : """18.97""" },
    { "rate" : """0.3""" },
    { "rate" : """0.25998""" },
    { "rate" : """13.11""" },
    { "rate" : """4.99998""" },
    { "rate" : """0.86998""" },
    { "rate" : """13.11""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.99989""" },
    { "rate" : """13.11""" },
    { "rate" : """16.17""" },
    { "rate" : """0.998""" },
    { "rate" : """0.2""" },
    { "rate" : """0.9""" },
    { "rate" : """8.98""" },
    { "rate" : """16""" },
    { "rate" : """0.9""" },
    { "rate" : """23.58""" },
    { "rate" : """0.47""" },
    { "rate" : """0.89999""" },
    { "rate" : """0.2987""" },
    { "rate" : """0.87""" },
    { "rate" : """0.97998""" },
    { "rate" : """12""" },
    { "rate" : """9.99998""" },
    { "rate" : """12.46""" },
    { "rate" : """12.45998""" },
    { "rate" : """12""" },
    { "rate" : """0.5""" },
    { "rate" : """4.99""" },
    { "rate" : """0.48998""" },
    { "rate" : """0.49998""" },
    { "rate" : """0.4""" },
    { "rate" : """0.288""" },
    { "rate" : """5.999""" },
    { "rate" : """0.388""" },
    { "rate" : """12.46""" },
    { "rate" : """13.10999""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """11.99""" },
    { "rate" : """16.16""" },
    { "rate" : """6.96""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """9""" },
    { "rate" : """9.96""" },
    { "rate" : """7""" },
    { "rate" : """9.99946""" },
    { "rate" : """8""" },
    { "rate" : """0.3""" },
    { "rate" : """9.95998""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """10.73""" },
    { "rate" : """7""" },
    { "rate" : """4.99999""" },
    { "rate" : """9.99998""" },
    { "rate" : """0.3""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """14.46""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """9.999""" },
    { "rate" : """0.4""" },
    { "rate" : """2""" },
    { "rate" : """13.11""" },
    { "rate" : """0.28""" },
    { "rate" : """10""" },
    { "rate" : """0.29999""" },
    { "rate" : """4.99999""" },
    { "rate" : """0.29""" },
    { "rate" : """12""" },
    { "rate" : """12.46""" },
    { "rate" : """9.5""" },
    { "rate" : """9.99997""" },
    { "rate" : """0.3""" },
    { "rate" : """8.78888""" },
    { "rate" : """8.8""" },
    { "rate" : """0.3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """7.99999""" },
    { "rate" : """8""" },
    { "rate" : """0.29999""" },
    { "rate" : """7""" },
    { "rate" : """0.29999""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.95""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """0.47""" },
    { "rate" : """0.33""" },
    { "rate" : """10""" },
    { "rate" : """10.04""" },
    { "rate" : """9""" },
    { "rate" : """0.289""" },
    { "rate" : """10""" },
    { "rate" : """9.999""" },
    { "rate" : """9.999""" },
    { "rate" : """6.999""" },
    { "rate" : """9.95""" },
    { "rate" : """9.989""" },
    { "rate" : """12.46""" },
    { "rate" : """9.97""" },
    { "rate" : """0.28999""" },
    { "rate" : """7""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """9.8""" },
    { "rate" : """7""" },
    { "rate" : """9.96""" },
    { "rate" : """9.9""" },
    { "rate" : """13.11""" },
    { "rate" : """12.46""" },
    { "rate" : """0.3""" },
    { "rate" : """23.58""" },
    { "rate" : """5""" },
    { "rate" : """10.73""" },
    { "rate" : """6.99""" },
    { "rate" : """9.5""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """8.8""" },
    { "rate" : """0.2""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """0.3""" },
    { "rate" : """10.73""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """12.46""" },
    { "rate" : """10.73""" },
    { "rate" : """0.3""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.3""" },
    { "rate" : """1""" },
    { "rate" : """12.46""" },
    { "rate" : """1""" },
    { "rate" : """9.99""" },
    { "rate" : """1""" },
    { "rate" : """0.99998""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """9.96""" },
    { "rate" : """0.998""" },
    { "rate" : """0.89""" },
    { "rate" : """8.75""" },
    { "rate" : """8.79""" },
    { "rate" : """7.99998""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9""" },
    { "rate" : """17""" },
    { "rate" : """0.8""" },
    { "rate" : """1""" },
    { "rate" : """0.3""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """16""" },
    { "rate" : """4.99998""" },
    { "rate" : """1""" },
    { "rate" : """9.999""" },
    { "rate" : """8.8""" },
    { "rate" : """1""" },
    { "rate" : """0.4706""" },
    { "rate" : """1""" },
    { "rate" : """10.73""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """9.5""" },
    { "rate" : """8.7""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """0.9999""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """6.6""" },
    { "rate" : """10""" },
    { "rate" : """0.99""" },
    { "rate" : """12.46""" },
    { "rate" : """0.4706""" },
    { "rate" : """1""" },
    { "rate" : """8.79999""" },
    { "rate" : """0.8888""" },
    { "rate" : """7""" },
    { "rate" : """0.99998""" },
    { "rate" : """4.9""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """4.4""" },
    { "rate" : """4""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.75""" },
    { "rate" : """0.9999""" },
    { "rate" : """16""" },
    { "rate" : """12.46""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """16""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """12.45999""" },
    { "rate" : """0.3""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """0.3""" },
    { "rate" : """10""" },
    { "rate" : """0.29998""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """0.029""" },
    { "rate" : """0.29999""" },
    { "rate" : """5.9999""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """0.3""" },
    { "rate" : """0.3""" },
    { "rate" : """12.45""" },
    { "rate" : """8""" },
    { "rate" : """14.9""" },
    { "rate" : """0.4""" },
    { "rate" : """0.649""" },
    { "rate" : """0.59998""" },
    { "rate" : """0.4706""" },
    { "rate" : """8.8""" },
    { "rate" : """0.6""" },
    { "rate" : """0.675""" },
    { "rate" : """12.46""" },
    { "rate" : """0.6""" },
    { "rate" : """0.5""" },
    { "rate" : """8.8""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.9999""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """0.285""" },
    { "rate" : """0.2""" },
    { "rate" : """0.2""" },
    { "rate" : """0.87""" },
    { "rate" : """0.58""" },
    { "rate" : """0.9""" },
    { "rate" : """0.6""" },
    { "rate" : """8.7""" },
    { "rate" : """0.699""" },
    { "rate" : """9.9899""" },
    { "rate" : """0.44""" },
    { "rate" : """0.03""" },
    { "rate" : """8.8""" },
    { "rate" : """0.3""" },
    { "rate" : """7""" },
    { "rate" : """4.99""" },
    { "rate" : """8""" },
    { "rate" : """0.3""" },
    { "rate" : """9""" },
    { "rate" : """7.95""" },
    { "rate" : """9.99""" },
    { "rate" : """6.5""" },
    { "rate" : """11""" },
    { "rate" : """9.96""" },
    { "rate" : """12.46""" },
    { "rate" : """0.69""" },
    { "rate" : """7""" },
    { "rate" : """0.29999""" },
    { "rate" : """0.29999""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """0.3""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """0.699""" },
    { "rate" : """8.8""" },
    { "rate" : """0.65""" },
    { "rate" : """6.99999""" },
    { "rate" : """0.26""" },
    { "rate" : """0.2999""" },
    { "rate" : """2""" },
    { "rate" : """8.8""" },
    { "rate" : """7.99999""" },
    { "rate" : """20""" },
    { "rate" : """0.3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9.9""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.96""" },
    { "rate" : """5""" },
    { "rate" : """4.99998""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4.89""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """0.96""" },
    { "rate" : """14""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.96""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """6.55""" },
    { "rate" : """7""" },
    { "rate" : """6.99999""" },
    { "rate" : """5""" },
    { "rate" : """0.3""" },
    { "rate" : """8""" },
    { "rate" : """0.3""" },
    { "rate" : """6.99998""" },
    { "rate" : """0.2888""" },
    { "rate" : """0.39999""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.002""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """0.0002""" },
    { "rate" : """0.0002""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.95""" },
    { "rate" : """0.69888""" },
    { "rate" : """6.55""" },
    { "rate" : """0.2""" },
    { "rate" : """5""" },
    { "rate" : """0.28888""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """4.999""" },
    { "rate" : """0.29998""" },
    { "rate" : """8.8""" },
    { "rate" : """6.998""" },
    { "rate" : """4.88""" },
    { "rate" : """0.65""" },
    { "rate" : """5""" },
    { "rate" : """7.9998""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """6.55""" },
    { "rate" : """6.5""" },
    { "rate" : """4.9""" },
    { "rate" : """8""" },
    { "rate" : """7.98998""" },
    { "rate" : """0.2989""" },
    { "rate" : """0.689""" },
    { "rate" : """0.48""" },
    { "rate" : """15""" },
    { "rate" : """4.85""" },
    { "rate" : """0.96""" },
    { "rate" : """0.87""" },
    { "rate" : """0.99998""" },
    { "rate" : """0.03""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """0.99998""" },
    { "rate" : """0.4706""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """7.5""" },
    { "rate" : """0.3""" },
    { "rate" : """0.4706""" },
    { "rate" : """7""" },
    { "rate" : """6.9""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """0.3""" },
    { "rate" : """0.74""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """9.9899""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """0.29999""" },
    { "rate" : """8""" },
    { "rate" : """0.599""" },
    { "rate" : """0.7""" },
    { "rate" : """0.3""" },
    { "rate" : """16.16998""" },
    { "rate" : """0.68""" },
    { "rate" : """0.4706""" },
    { "rate" : """6.9999""" },
    { "rate" : """6.8""" },
    { "rate" : """0.7""" },
    { "rate" : """0.6""" },
    { "rate" : """8""" },
    { "rate" : """18.98""" },
    { "rate" : """8.79""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """8""" },
    { "rate" : """7.99""" },
    { "rate" : """6.9""" },
    { "rate" : """2""" },
    { "rate" : """8.79999""" },
    { "rate" : """0.29""" },
    { "rate" : """1""" },
    { "rate" : """4.98998""" },
    { "rate" : """0.289""" },
    { "rate" : """0.08998""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """0.3""" },
    { "rate" : """0.3""" },
    { "rate" : """8""" },
    { "rate" : """0.87""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """0.6""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """0.9""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """0.99999""" },
    { "rate" : """8""" },
    { "rate" : """3.99999""" },
    { "rate" : """0.99998""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """12.99998""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7.9""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """18.98""" },
    { "rate" : """0.3""" },
    { "rate" : """0.999""" },
    { "rate" : """0.9""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """9.96""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """0.99""" },
    { "rate" : """9.9""" },
    { "rate" : """0.4""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """0.685""" },
    { "rate" : """0.3""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.8""" },
    { "rate" : """6""" },
    { "rate" : """0.4""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """7.999""" },
    { "rate" : """0.4706""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """8.79999""" },
    { "rate" : """0.03999""" },
    { "rate" : """9.96""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """0.3""" },
    { "rate" : """0.29999""" },
    { "rate" : """0.3""" },
    { "rate" : """0.3""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """0.35""" },
    { "rate" : """0.5""" },
    { "rate" : """0.2999""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """16.5""" },
    { "rate" : """0.29999""" },
    { "rate" : """8.888""" },
    { "rate" : """1""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.99""" },
    { "rate" : """0.59999""" },
    { "rate" : """0.3""" },
    { "rate" : """7""" },
    { "rate" : """0.3""" },
    { "rate" : """5""" },
    { "rate" : """0.4""" },
    { "rate" : """2""" },
    { "rate" : """8.887""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """16.17""" },
    { "rate" : """12.46""" },
    { "rate" : """0.31""" },
    { "rate" : """8.75""" },
    { "rate" : """8.8""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.3999""" },
    { "rate" : """1.98999""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.3""" },
    { "rate" : """6.6666""" },
    { "rate" : """14""" },
    { "rate" : """0.3""" },
    { "rate" : """14.999""" },
    { "rate" : """8.888""" },
    { "rate" : """20""" },
    { "rate" : """0.4""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """16.17""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """4.99999""" },
    { "rate" : """8""" },
    { "rate" : """0.84""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """0.5""" },
    { "rate" : """3""" },
    { "rate" : """0.4706""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """8.8""" },
    { "rate" : """0.69""" },
    { "rate" : """0.2""" },
    { "rate" : """4.99997""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """0.398""" },
    { "rate" : """0.688""" },
    { "rate" : """3.989""" },
    { "rate" : """0.9899""" },
    { "rate" : """4.99998""" },
    { "rate" : """18.98""" },
    { "rate" : """0.4""" },
    { "rate" : """0.4""" },
    { "rate" : """0.01""" },
    { "rate" : """11.8""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """0.25""" },
    { "rate" : """0.25""" },
    { "rate" : """1.5""" },
    { "rate" : """9.9""" },
    { "rate" : """8""" },
    { "rate" : """7.5""" },
    { "rate" : """0.4""" },
    { "rate" : """0.4""" },
    { "rate" : """8.95""" },
    { "rate" : """16""" },
    { "rate" : """0.39""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """4.8999""" },
    { "rate" : """18.98""" },
    { "rate" : """7""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """0.39998""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """11""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """16.17""" },
    { "rate" : """8.8""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """0.48""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """0.96""" },
    { "rate" : """8""" },
    { "rate" : """0.87""" },
    { "rate" : """0.69999""" },
    { "rate" : """0.73999""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7.99917""" },
    { "rate" : """0.96""" },
    { "rate" : """7""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """9.9""" },
    { "rate" : """8""" },
    { "rate" : """9.9""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """18.98""" },
    { "rate" : """3.64""" },
    { "rate" : """12.46""" },
    { "rate" : """10.1""" },
    { "rate" : """8""" },
    { "rate" : """0.4706""" },
    { "rate" : """3.64""" },
    { "rate" : """3.639""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """18.98""" },
    { "rate" : """3.64""" },
    { "rate" : """3.63999""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """3.64""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """0.69999""" },
    { "rate" : """8.8""" },
    { "rate" : """7.99989""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """12.46""" },
    { "rate" : """18.9""" },
    { "rate" : """16""" },
    { "rate" : """3.64""" },
    { "rate" : """8.8""" },
    { "rate" : """3.64""" },
    { "rate" : """7""" },
    { "rate" : """18.99""" },
    { "rate" : """6.99""" },
    { "rate" : """8""" },
    { "rate" : """0.49""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """8.8""" },
    { "rate" : """0.32999""" },
    { "rate" : """4.5""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """16""" },
    { "rate" : """3.64""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """0.01""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """8.8""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """7.999""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """7.95""" },
    { "rate" : """6.9""" },
    { "rate" : """6""" },
    { "rate" : """12.5""" },
    { "rate" : """3.63898""" },
    { "rate" : """8.8""" },
    { "rate" : """7.98888""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """12.2552""" },
    { "rate" : """3.63888""" },
    { "rate" : """7""" },
    { "rate" : """0.4706""" },
    { "rate" : """8""" },
    { "rate" : """18.98""" },
    { "rate" : """6.99""" },
    { "rate" : """4.999""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """8.25""" },
    { "rate" : """8.79998""" },
    { "rate" : """3.63998""" },
    { "rate" : """9.99998""" },
    { "rate" : """9.99998""" },
    { "rate" : """6.9""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """9.99998""" },
    { "rate" : """4.99999""" },
    { "rate" : """12.24998""" },
    { "rate" : """3""" },
    { "rate" : """8.79999""" },
    { "rate" : """0.4706""" },
    { "rate" : """5""" },
    { "rate" : """7.95""" },
    { "rate" : """8""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """9.95""" },
    { "rate" : """8.8""" },
    { "rate" : """18.98""" },
    { "rate" : """16.17""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """23.58""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """18.98""" },
    { "rate" : """12.26""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """0.1""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """4.99999""" },
    { "rate" : """13.11""" },
    { "rate" : """15""" },
    { "rate" : """7.99""" },
    { "rate" : """3.63""" },
    { "rate" : """9.95""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """11.99999""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """13.11""" },
    { "rate" : """3.5""" },
    { "rate" : """0.4706""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6.55""" },
    { "rate" : """16""" },
    { "rate" : """15""" },
    { "rate" : """15.5""" },
    { "rate" : """6.54999""" },
    { "rate" : """15""" },
    { "rate" : """16""" },
    { "rate" : """3.3""" },
    { "rate" : """5.8""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """3.639""" },
    { "rate" : """8.8""" },
    { "rate" : """16""" },
    { "rate" : """6.549""" },
    { "rate" : """16""" },
    { "rate" : """7""" },
    { "rate" : """0.08""" },
    { "rate" : """8.8""" },
    { "rate" : """0.5""" },
    { "rate" : """4""" },
    { "rate" : """6.55""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """0.4706""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """13.72""" },
    { "rate" : """15.9""" },
    { "rate" : """15.99998""" },
    { "rate" : """14""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """0.78""" },
    { "rate" : """7""" },
    { "rate" : """0.79999""" },
    { "rate" : """0.4""" },
    { "rate" : """0.08""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.8""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """0.8""" },
    { "rate" : """7""" },
    { "rate" : """0.79""" },
    { "rate" : """4""" },
    { "rate" : """0.5""" },
    { "rate" : """0.4""" },
    { "rate" : """0.47""" },
    { "rate" : """6.9""" },
    { "rate" : """4""" },
    { "rate" : """9.99999""" },
    { "rate" : """16""" },
    { "rate" : """3.63999""" },
    { "rate" : """7""" },
    { "rate" : """9.99997""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """8.8""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """18.98""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """13.11""" },
    { "rate" : """6.95""" },
    { "rate" : """7.98""" },
    { "rate" : """6.8""" },
    { "rate" : """18.98""" },
    { "rate" : """6.5""" },
    { "rate" : """12""" },
    { "rate" : """18.98""" },
    { "rate" : """7""" },
    { "rate" : """16""" },
    { "rate" : """15.99997""" },
    { "rate" : """4""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """15.95""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """18.98""" },
    { "rate" : """15.99999""" },
    { "rate" : """13.72""" },
    { "rate" : """9""" },
    { "rate" : """23.58""" },
    { "rate" : """18.98""" },
    { "rate" : """3.99""" },
    { "rate" : """14.99999""" },
    { "rate" : """12""" },
    { "rate" : """9.99""" },
    { "rate" : """15""" },
    { "rate" : """0.4""" },
    { "rate" : """18.98""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.45""" },
    { "rate" : """0.39999""" },
    { "rate" : """12""" },
    { "rate" : """8.8""" },
    { "rate" : """9.98998""" },
    { "rate" : """3.98998""" },
    { "rate" : """0.5""" },
    { "rate" : """0.4""" },
    { "rate" : """0.08998""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """3.62""" },
    { "rate" : """13.72""" },
    { "rate" : """4""" },
    { "rate" : """8.8""" },
    { "rate" : """4""" },
    { "rate" : """16""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """18""" },
    { "rate" : """18.98""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """8.7""" },
    { "rate" : """13""" },
    { "rate" : """15""" },
    { "rate" : """15.5""" },
    { "rate" : """13""" },
    { "rate" : """15""" },
    { "rate" : """12.26""" },
    { "rate" : """13.72""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """16""" },
    { "rate" : """16""" },
    { "rate" : """5""" },
    { "rate" : """9.99946""" },
    { "rate" : """8.8""" },
    { "rate" : """6""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """7""" },
    { "rate" : """8.2""" },
    { "rate" : """9.9""" },
    { "rate" : """12.26""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """9.5""" },
    { "rate" : """8.8""" },
    { "rate" : """12.26""" },
    { "rate" : """5""" },
    { "rate" : """12.25""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """13.11""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5.79""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """5.79""" },
    { "rate" : """5.79""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """0.4706""" },
    { "rate" : """2""" },
    { "rate" : """5.5""" },
    { "rate" : """6""" },
    { "rate" : """4.2""" },
    { "rate" : """5""" },
    { "rate" : """5.787""" },
    { "rate" : """5""" },
    { "rate" : """6.9998""" },
    { "rate" : """15.998""" },
    { "rate" : """17""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """16""" },
    { "rate" : """18.98""" },
    { "rate" : """15""" },
    { "rate" : """7.99""" },
    { "rate" : """4.89999""" },
    { "rate" : """13.7""" },
    { "rate" : """6.9""" },
    { "rate" : """8.7""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """9.9""" },
    { "rate" : """5.79""" },
    { "rate" : """8.7""" },
    { "rate" : """15""" },
    { "rate" : """18.98""" },
    { "rate" : """4.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """15""" },
    { "rate" : """4.7""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """12.26""" },
    { "rate" : """4.8""" },
    { "rate" : """9.8""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """3""" },
    { "rate" : """3.95""" },
    { "rate" : """9.96""" },
    { "rate" : """4.98""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """5.58""" },
    { "rate" : """7""" },
    { "rate" : """5.79""" },
    { "rate" : """5.78""" },
    { "rate" : """4.1""" },
    { "rate" : """12.26""" },
    { "rate" : """0.4706""" },
    { "rate" : """12.2599""" },
    { "rate" : """8.8""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """9.9""" },
    { "rate" : """16""" },
    { "rate" : """5""" },
    { "rate" : """6.99999""" },
    { "rate" : """13.72""" },
    { "rate" : """4.9999""" },
    { "rate" : """16""" },
    { "rate" : """12""" },
    { "rate" : """5.79""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """0.4706""" },
    { "rate" : """6.99999""" },
    { "rate" : """6.99997""" },
    { "rate" : """6.5""" },
    { "rate" : """8.8""" },
    { "rate" : """5.79""" },
    { "rate" : """8.8""" },
    { "rate" : """14""" },
    { "rate" : """8.8""" },
    { "rate" : """5.79""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """4.5""" },
    { "rate" : """18.98""" },
    { "rate" : """5.79""" },
    { "rate" : """13.72""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """23.58""" },
    { "rate" : """13.71999""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """8.5""" },
    { "rate" : """15""" },
    { "rate" : """5.79""" },
    { "rate" : """4.9999""" },
    { "rate" : """10.7""" },
    { "rate" : """4.99""" },
    { "rate" : """16""" },
    { "rate" : """4.5""" },
    { "rate" : """8""" },
    { "rate" : """23.58""" },
    { "rate" : """5""" },
    { "rate" : """0.1""" },
    { "rate" : """6.99999""" },
    { "rate" : """5.79""" },
    { "rate" : """12.26""" },
    { "rate" : """8.79888""" },
    { "rate" : """5.79""" },
    { "rate" : """10""" },
    { "rate" : """18.85""" },
    { "rate" : """5.79""" },
    { "rate" : """7""" },
    { "rate" : """3.64""" },
    { "rate" : """5""" },
    { "rate" : """23.58""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """5.79""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """4.5""" },
    { "rate" : """8.5""" },
    { "rate" : """4""" },
    { "rate" : """6.5""" },
    { "rate" : """7.99""" },
    { "rate" : """18.98""" },
    { "rate" : """8.8""" },
    { "rate" : """15.14""" },
    { "rate" : """13.72""" },
    { "rate" : """13.69999""" },
    { "rate" : """13.72""" },
    { "rate" : """6.99999""" },
    { "rate" : """4.95""" },
    { "rate" : """15.14""" },
    { "rate" : """18.98""" },
    { "rate" : """5.79""" },
    { "rate" : """5""" },
    { "rate" : """9.85""" },
    { "rate" : """15.13""" },
    { "rate" : """8.8""" },
    { "rate" : """18.98""" },
    { "rate" : """12.5""" },
    { "rate" : """0.96""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.9""" },
    { "rate" : """13""" },
    { "rate" : """6.89""" },
    { "rate" : """18.98""" },
    { "rate" : """4.99""" },
    { "rate" : """15.14""" },
    { "rate" : """13.72""" },
    { "rate" : """4.99""" },
    { "rate" : """6.99""" },
    { "rate" : """18.98""" },
    { "rate" : """23.5""" },
    { "rate" : """4""" },
    { "rate" : """16.17""" },
    { "rate" : """13.72""" },
    { "rate" : """12.99999""" },
    { "rate" : """5.45""" },
    { "rate" : """13.72""" },
    { "rate" : """4.99""" },
    { "rate" : """0.4706""" },
    { "rate" : """6.99998""" },
    { "rate" : """9.96""" },
    { "rate" : """18.98""" },
    { "rate" : """1.25""" },
    { "rate" : """0.4706""" },
    { "rate" : """1.8""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.9892""" },
    { "rate" : """15""" },
    { "rate" : """8.98""" },
    { "rate" : """5""" },
    { "rate" : """1.99999""" },
    { "rate" : """11""" },
    { "rate" : """13.72""" },
    { "rate" : """6.95""" },
    { "rate" : """7""" },
    { "rate" : """13.11""" },
    { "rate" : """5.79""" },
    { "rate" : """15""" },
    { "rate" : """0.99899""" },
    { "rate" : """4.79998""" },
    { "rate" : """6.88998""" },
    { "rate" : """1.9""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """1.95959""" },
    { "rate" : """5.87996""" },
    { "rate" : """4.8""" },
    { "rate" : """13""" },
    { "rate" : """13""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1.49""" },
    { "rate" : """4.9""" },
    { "rate" : """12""" },
    { "rate" : """13.72""" },
    { "rate" : """11""" },
    { "rate" : """6.99""" },
    { "rate" : """10.73""" },
    { "rate" : """13""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """15.99999""" },
    { "rate" : """13.72""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """0.95""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.9""" },
    { "rate" : """0.4706""" },
    { "rate" : """4.89""" },
    { "rate" : """2""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.9""" },
    { "rate" : """0.84998""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """13""" },
    { "rate" : """0.99999""" },
    { "rate" : """5""" },
    { "rate" : """0.82""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """8.5""" },
    { "rate" : """15""" },
    { "rate" : """9.88""" },
    { "rate" : """16.17""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """0.85""" },
    { "rate" : """0.8988""" },
    { "rate" : """5""" },
    { "rate" : """1.88""" },
    { "rate" : """8.8""" },
    { "rate" : """0.95""" },
    { "rate" : """1.6""" },
    { "rate" : """2""" },
    { "rate" : """0.4706""" },
    { "rate" : """4""" },
    { "rate" : """0.4706""" },
    { "rate" : """5""" },
    { "rate" : """1.9""" },
    { "rate" : """4.49999""" },
    { "rate" : """13.72""" },
    { "rate" : """12.26""" },
    { "rate" : """4.9999""" },
    { "rate" : """0.87""" },
    { "rate" : """5.79""" },
    { "rate" : """0.9""" },
    { "rate" : """0.88888""" },
    { "rate" : """1.99999""" },
    { "rate" : """0.5""" },
    { "rate" : """4.8""" },
    { "rate" : """5""" },
    { "rate" : """5.79""" },
    { "rate" : """1.5""" },
    { "rate" : """0.87""" },
    { "rate" : """7""" },
    { "rate" : """1.87""" },
    { "rate" : """4.49""" },
    { "rate" : """13.72""" },
    { "rate" : """7.75""" },
    { "rate" : """8.79""" },
    { "rate" : """15.95""" },
    { "rate" : """1.99998""" },
    { "rate" : """5""" },
    { "rate" : """0.9998""" },
    { "rate" : """1.5""" },
    { "rate" : """16.17""" },
    { "rate" : """1.99999""" },
    { "rate" : """12.26""" },
    { "rate" : """13.72""" },
    { "rate" : """9.9""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """5.79""" },
    { "rate" : """16.17""" },
    { "rate" : """13.11""" },
    { "rate" : """1.5""" },
    { "rate" : """16""" },
    { "rate" : """5""" },
    { "rate" : """16.17""" },
    { "rate" : """2""" },
    { "rate" : """0.4706""" },
    { "rate" : """13.72""" },
    { "rate" : """1.9""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """13.72""" },
    { "rate" : """12.26""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """2""" },
    { "rate" : """1.99986""" },
    { "rate" : """0.4706""" },
    { "rate" : """2""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """7""" },
    { "rate" : """13.72""" },
    { "rate" : """6""" },
    { "rate" : """9.99999""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """0.4706""" },
    { "rate" : """1.99999""" },
    { "rate" : """15.14""" },
    { "rate" : """15""" },
    { "rate" : """16""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """5.79""" },
    { "rate" : """7.99999""" },
    { "rate" : """5.78999""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """4.632""" },
    { "rate" : """4.632""" },
    { "rate" : """4.632""" },
    { "rate" : """4.632""" },
    { "rate" : """4.632""" },
    { "rate" : """4.632""" },
    { "rate" : """4.632""" },
    { "rate" : """4.632""" },
    { "rate" : """4.632""" },
    { "rate" : """4.632""" },
    { "rate" : """12.112""" },
    { "rate" : """12.112""" },
    { "rate" : """12.112""" },
    { "rate" : """12.112""" },
    { "rate" : """12.112""" },
    { "rate" : """12.112""" },
    { "rate" : """12.112""" },
    { "rate" : """12.112""" },
    { "rate" : """12.112""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """1.9""" },
    { "rate" : """0.4706""" },
    { "rate" : """1.99999""" },
    { "rate" : """12.26""" },
    { "rate" : """6.5""" },
    { "rate" : """13.72""" },
    { "rate" : """9.96""" },
    { "rate" : """3""" },
    { "rate" : """12.26""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """5.79""" },
    { "rate" : """2""" },
    { "rate" : """13""" },
    { "rate" : """13.11""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """5.79""" },
    { "rate" : """11""" },
    { "rate" : """5.3""" },
    { "rate" : """12""" },
    { "rate" : """15.99""" },
    { "rate" : """5.78""" },
    { "rate" : """12.98998""" },
    { "rate" : """12.99999""" },
    { "rate" : """10.9""" },
    { "rate" : """0.96""" },
    { "rate" : """13""" },
    { "rate" : """13""" },
    { "rate" : """13.72""" },
    { "rate" : """2""" },
    { "rate" : """0.4706""" },
    { "rate" : """5""" },
    { "rate" : """4.97998""" },
    { "rate" : """4.5""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """4.999""" },
    { "rate" : """2""" },
    { "rate" : """4.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """5""" },
    { "rate" : """10.73""" },
    { "rate" : """2""" },
    { "rate" : """5.79""" },
    { "rate" : """12.26""" },
    { "rate" : """4.98996""" },
    { "rate" : """1.995""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2.00001""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """0.4706""" },
    { "rate" : """4.5""" },
    { "rate" : """7""" },
    { "rate" : """16""" },
    { "rate" : """5""" },
    { "rate" : """1.995""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """1.999""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """13""" },
    { "rate" : """2""" },
    { "rate" : """12.26""" },
    { "rate" : """8""" },
    { "rate" : """1.9999""" },
    { "rate" : """13.11""" },
    { "rate" : """0.4706""" },
    { "rate" : """15.5""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """16""" },
    { "rate" : """5.79""" },
    { "rate" : """15.14""" },
    { "rate" : """17.4""" },
    { "rate" : """7""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """1.9999""" },
    { "rate" : """16""" },
    { "rate" : """13.1""" },
    { "rate" : """5.29""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """8.7""" },
    { "rate" : """18.98""" },
    { "rate" : """6.17""" },
    { "rate" : """9.26""" },
    { "rate" : """12.72""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.5""" },
    { "rate" : """18.99""" },
    { "rate" : """0.4706""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """0.4706""" },
    { "rate" : """15""" },
    { "rate" : """10.73""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """1.99999""" },
    { "rate" : """5""" },
    { "rate" : """14.4""" },
    { "rate" : """9.1""" },
    { "rate" : """1.7""" },
    { "rate" : """6""" },
    { "rate" : """0.4706""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.9""" },
    { "rate" : """0.99""" },
    { "rate" : """12.46""" },
    { "rate" : """0.999""" },
    { "rate" : """8""" },
    { "rate" : """0.99899""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """12.112""" },
    { "rate" : """12.112""" },
    { "rate" : """12.112""" },
    { "rate" : """12.112""" },
    { "rate" : """12.112""" },
    { "rate" : """12.112""" },
    { "rate" : """12.112""" },
    { "rate" : """12.112""" },
    { "rate" : """12.112""" },
    { "rate" : """12.112""" },
    { "rate" : """13""" },
    { "rate" : """15.139""" },
    { "rate" : """1""" },
    { "rate" : """10.73""" },
    { "rate" : """0.99888""" },
    { "rate" : """13.11""" },
    { "rate" : """12""" },
    { "rate" : """0.55""" },
    { "rate" : """0.79999""" },
    { "rate" : """8""" },
    { "rate" : """20""" },
    { "rate" : """0.87""" },
    { "rate" : """0.88""" },
    { "rate" : """2""" },
    { "rate" : """0.998""" },
    { "rate" : """0.99998""" },
    { "rate" : """2""" },
    { "rate" : """10.73""" },
    { "rate" : """3""" },
    { "rate" : """9.99999""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """0.4706""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """12.26""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.666""" },
    { "rate" : """13.72""" },
    { "rate" : """10.73""" },
    { "rate" : """12.26""" },
    { "rate" : """0.59""" },
    { "rate" : """15.14""" },
    { "rate" : """0.99""" },
    { "rate" : """12.26""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """10.73""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """13""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """0.78""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """1""" },
    { "rate" : """0.98""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """0.34998""" },
    { "rate" : """2""" },
    { "rate" : """1.75""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.729""" },
    { "rate" : """12""" },
    { "rate" : """5.79""" },
    { "rate" : """9.9999""" },
    { "rate" : """2""" },
    { "rate" : """0.8""" },
    { "rate" : """0.99999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """13.72""" },
    { "rate" : """0.5""" },
    { "rate" : """1.9998""" },
    { "rate" : """10.73""" },
    { "rate" : """1""" },
    { "rate" : """0.98""" },
    { "rate" : """1""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """10.5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """6.999""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """18""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """4.499""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """10.73""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """15.14""" },
    { "rate" : """5.4999""" },
    { "rate" : """0.96""" },
    { "rate" : """0.96""" },
    { "rate" : """10.73""" },
    { "rate" : """7""" },
    { "rate" : """3.64""" },
    { "rate" : """13.11""" },
    { "rate" : """8""" },
    { "rate" : """10.73""" },
    { "rate" : """15.14""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """4.5""" },
    { "rate" : """18""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """0.99998""" },
    { "rate" : """4.5""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.96""" },
    { "rate" : """1.95""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """10.73""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """0.9999""" },
    { "rate" : """8.8""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """18.98""" },
    { "rate" : """4""" },
    { "rate" : """15.14""" },
    { "rate" : """10.73""" },
    { "rate" : """3.64""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """0.5""" },
    { "rate" : """3.64""" },
    { "rate" : """12""" },
    { "rate" : """16""" },
    { "rate" : """12.46""" },
    { "rate" : """4""" },
    { "rate" : """0.99999""" },
    { "rate" : """4.49999""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """3.64""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.96""" },
    { "rate" : """13.11""" },
    { "rate" : """4.49999""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """13.11""" },
    { "rate" : """5.78""" },
    { "rate" : """11.98998""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """12""" },
    { "rate" : """10.72""" },
    { "rate" : """14""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """9.99""" },
    { "rate" : """10.73""" },
    { "rate" : """8.8""" },
    { "rate" : """11.99""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """10.72""" },
    { "rate" : """12""" },
    { "rate" : """10.73""" },
    { "rate" : """12""" },
    { "rate" : """0.99999""" },
    { "rate" : """7.998""" },
    { "rate" : """9.98""" },
    { "rate" : """11.9""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """11.999""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.5""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.4706""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """0.46998""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """4.63""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9999""" },
    { "rate" : """11.99999""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """0.99""" },
    { "rate" : """0.96""" },
    { "rate" : """0.98""" },
    { "rate" : """5""" },
    { "rate" : """5.79""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """0.95""" },
    { "rate" : """0.8""" },
    { "rate" : """11""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """10.488""" },
    { "rate" : """10.488""" },
    { "rate" : """10.488""" },
    { "rate" : """10.488""" },
    { "rate" : """10.488""" },
    { "rate" : """10.488""" },
    { "rate" : """10.488""" },
    { "rate" : """10.488""" },
    { "rate" : """10.488""" },
    { "rate" : """10.488""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """4.5""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """4""" },
    { "rate" : """0.96""" },
    { "rate" : """4""" },
    { "rate" : """0.96""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """9.9988""" },
    { "rate" : """11.99""" },
    { "rate" : """9.9""" },
    { "rate" : """5.79""" },
    { "rate" : """1.95""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """17""" },
    { "rate" : """5""" },
    { "rate" : """5.79""" },
    { "rate" : """8.8""" },
    { "rate" : """1""" },
    { "rate" : """13""" },
    { "rate" : """3.11""" },
    { "rate" : """1""" },
    { "rate" : """13.11""" },
    { "rate" : """12.46""" },
    { "rate" : """1""" },
    { "rate" : """10.73""" },
    { "rate" : """11.9998""" },
    { "rate" : """1""" },
    { "rate" : """11.9999""" },
    { "rate" : """11.99999""" },
    { "rate" : """0.89999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """11.99""" },
    { "rate" : """0.97""" },
    { "rate" : """11.99999""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """8.8""" },
    { "rate" : """1""" },
    { "rate" : """0.99""" },
    { "rate" : """12.46""" },
    { "rate" : """8""" },
    { "rate" : """8.6""" },
    { "rate" : """4""" },
    { "rate" : """8.7""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """10.73""" },
    { "rate" : """13.5""" },
    { "rate" : """12.46""" },
    { "rate" : """9.5""" },
    { "rate" : """7.99986""" },
    { "rate" : """0.9999""" },
    { "rate" : """13.1""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """0.987""" },
    { "rate" : """8""" },
    { "rate" : """10.5""" },
    { "rate" : """4""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """16""" },
    { "rate" : """8""" },
    { "rate" : """12.46""" },
    { "rate" : """7.99""" },
    { "rate" : """12.46""" },
    { "rate" : """15.14""" },
    { "rate" : """0.98""" },
    { "rate" : """0.95""" },
    { "rate" : """3.99999""" },
    { "rate" : """8""" },
    { "rate" : """3.89""" },
    { "rate" : """8.8""" },
    { "rate" : """0.99999""" },
    { "rate" : """14.91""" },
    { "rate" : """10.73""" },
    { "rate" : """8""" },
    { "rate" : """0.99999""" },
    { "rate" : """10""" },
    { "rate" : """0.34998""" },
    { "rate" : """14""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.96""" },
    { "rate" : """0.96""" },
    { "rate" : """0.99989""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """0.9999""" },
    { "rate" : """4.75""" },
    { "rate" : """1""" },
    { "rate" : """4.99999""" },
    { "rate" : """0.2""" },
    { "rate" : """14.96""" },
    { "rate" : """4.99997""" },
    { "rate" : """0.5""" },
    { "rate" : """0.9999""" },
    { "rate" : """5""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.8""" },
    { "rate" : """0.99998""" },
    { "rate" : """4""" },
    { "rate" : """8.9""" },
    { "rate" : """10.73""" },
    { "rate" : """0.99""" },
    { "rate" : """12""" },
    { "rate" : """8.64""" },
    { "rate" : """0.938""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """8.6399""" },
    { "rate" : """0.96""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """4.999""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """4.85""" },
    { "rate" : """5""" },
    { "rate" : """4.98""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.9""" },
    { "rate" : """4.99""" },
    { "rate" : """12.46""" },
    { "rate" : """8.64""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """8.55""" },
    { "rate" : """8.8""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.8""" },
    { "rate" : """4""" },
    { "rate" : """8.639""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """0.4706""" },
    { "rate" : """4.75""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """5.99""" },
    { "rate" : """4.999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """8.63""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.46""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.4706""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.5""" },
    { "rate" : """12.26""" },
    { "rate" : """0.73998""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """0.99""" },
    { "rate" : """10.73""" },
    { "rate" : """12.99999""" },
    { "rate" : """5""" },
    { "rate" : """0.99997""" },
    { "rate" : """10""" },
    { "rate" : """12.48998""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """3.98998""" },
    { "rate" : """5""" },
    { "rate" : """8.64""" },
    { "rate" : """1""" },
    { "rate" : """0.75""" },
    { "rate" : """5.79""" },
    { "rate" : """5.79""" },
    { "rate" : """5.79""" },
    { "rate" : """5.79""" },
    { "rate" : """5.79""" },
    { "rate" : """5.79""" },
    { "rate" : """5.79""" },
    { "rate" : """6.99""" },
    { "rate" : """5.79""" },
    { "rate" : """5.79""" },
    { "rate" : """5.79""" },
    { "rate" : """5.79""" },
    { "rate" : """7""" },
    { "rate" : """4.98""" },
    { "rate" : """5""" },
    { "rate" : """4.98998""" },
    { "rate" : """12.26""" },
    { "rate" : """7""" },
    { "rate" : """0.75""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """6.99999""" },
    { "rate" : """5.79""" },
    { "rate" : """8.64""" },
    { "rate" : """5.78999""" },
    { "rate" : """10.73""" },
    { "rate" : """1""" },
    { "rate" : """4.99999""" },
    { "rate" : """5.79""" },
    { "rate" : """5.79""" },
    { "rate" : """4.98998""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """5.79""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """6.9""" },
    { "rate" : """7""" },
    { "rate" : """5.7""" },
    { "rate" : """0.74987""" },
    { "rate" : """6.987""" },
    { "rate" : """0.4706""" },
    { "rate" : """5""" },
    { "rate" : """6.99""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """6""" },
    { "rate" : """0.008""" },
    { "rate" : """5""" },
    { "rate" : """5.79""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """5.79""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99998""" },
    { "rate" : """0.99""" },
    { "rate" : """6.99999""" },
    { "rate" : """1""" },
    { "rate" : """5.79""" },
    { "rate" : """0.78998""" },
    { "rate" : """13.72""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """6.5""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.999""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """0.01""" },
    { "rate" : """5.79""" },
    { "rate" : """6.99998""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """0.8""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.63799""" },
    { "rate" : """10.73""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """3.62999""" },
    { "rate" : """3.64""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """3.59998""" },
    { "rate" : """1""" },
    { "rate" : """3.64""" },
    { "rate" : """8""" },
    { "rate" : """0.99999""" },
    { "rate" : """3.63""" },
    { "rate" : """6.6666""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9""" },
    { "rate" : """0.96""" },
    { "rate" : """0.99999""" },
    { "rate" : """3.63899""" },
    { "rate" : """10.73""" },
    { "rate" : """3.5""" },
    { "rate" : """5.99""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """3.639""" },
    { "rate" : """12.46""" },
    { "rate" : """6.5""" },
    { "rate" : """3.62""" },
    { "rate" : """0.99998""" },
    { "rate" : """0.99998""" },
    { "rate" : """6""" },
    { "rate" : """3.53""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """4.98998""" },
    { "rate" : """1""" },
    { "rate" : """3.5""" },
    { "rate" : """1""" },
    { "rate" : """5.5""" },
    { "rate" : """3.63""" },
    { "rate" : """7""" },
    { "rate" : """5.7""" },
    { "rate" : """9""" },
    { "rate" : """3.63994""" },
    { "rate" : """9.99""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """4.95""" },
    { "rate" : """5.24""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """6.5""" },
    { "rate" : """0.99999""" },
    { "rate" : """8""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.95""" },
    { "rate" : """6.55""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """6.5""" },
    { "rate" : """5.79""" },
    { "rate" : """1""" },
    { "rate" : """5.79""" },
    { "rate" : """5""" },
    { "rate" : """5.99999""" },
    { "rate" : """6""" },
    { "rate" : """5.79""" },
    { "rate" : """6""" },
    { "rate" : """6.79""" },
    { "rate" : """0.9998""" },
    { "rate" : """4.989""" },
    { "rate" : """0.99999""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """5.79""" },
    { "rate" : """8""" },
    { "rate" : """5.78""" },
    { "rate" : """3.63""" },
    { "rate" : """1""" },
    { "rate" : """4.99899""" },
    { "rate" : """0.95""" },
    { "rate" : """4.99""" },
    { "rate" : """0.98""" },
    { "rate" : """15""" },
    { "rate" : """6.98888""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """3.62""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """5.79""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """1""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """3.52999""" },
    { "rate" : """3.639""" },
    { "rate" : """9.9""" },
    { "rate" : """10.73""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8.62""" },
    { "rate" : """7""" },
    { "rate" : """0.9""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """0.99899""" },
    { "rate" : """10.73""" },
    { "rate" : """0.89999""" },
    { "rate" : """1""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """6.5""" },
    { "rate" : """6.5""" },
    { "rate" : """3.63888""" },
    { "rate" : """5""" },
    { "rate" : """8.98888""" },
    { "rate" : """0.99999""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """3.45""" },
    { "rate" : """5.79""" },
    { "rate" : """11.5""" },
    { "rate" : """0.9995""" },
    { "rate" : """6.79""" },
    { "rate" : """3.4""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """2.75""" },
    { "rate" : """0.4706""" },
    { "rate" : """3.63999""" },
    { "rate" : """4.9999""" },
    { "rate" : """7.9999""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """5.79""" },
    { "rate" : """5""" },
    { "rate" : """3.9999""" },
    { "rate" : """3.6""" },
    { "rate" : """3.63""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """3.62""" },
    { "rate" : """5.79""" },
    { "rate" : """8.8""" },
    { "rate" : """5.79""" },
    { "rate" : """0.99999""" },
    { "rate" : """3.63""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """2.99996""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6.95""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.84998""" },
    { "rate" : """1""" },
    { "rate" : """9.96""" },
    { "rate" : """0.99999""" },
    { "rate" : """12.46""" },
    { "rate" : """5.79""" },
    { "rate" : """7""" },
    { "rate" : """3.5""" },
    { "rate" : """0.4706""" },
    { "rate" : """9.96""" },
    { "rate" : """0.998""" },
    { "rate" : """12.46""" },
    { "rate" : """3.63""" },
    { "rate" : """0.9""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """0.9""" },
    { "rate" : """6.5""" },
    { "rate" : """5.79""" },
    { "rate" : """8""" },
    { "rate" : """5.79""" },
    { "rate" : """1.89999""" },
    { "rate" : """0.01""" },
    { "rate" : """1.85""" },
    { "rate" : """1.9""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """4.99""" },
    { "rate" : """0.4706""" },
    { "rate" : """9""" },
    { "rate" : """0.4706""" },
    { "rate" : """2""" },
    { "rate" : """1.88799""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """8.8""" },
    { "rate" : """3""" },
    { "rate" : """9.5""" },
    { "rate" : """1""" },
    { "rate" : """4.79""" },
    { "rate" : """5""" },
    { "rate" : """5.79""" },
    { "rate" : """8""" },
    { "rate" : """1.96""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """6.55""" },
    { "rate" : """0.99""" },
    { "rate" : """0.99""" },
    { "rate" : """0.99""" },
    { "rate" : """12.46""" },
    { "rate" : """0.99""" },
    { "rate" : """1.5""" },
    { "rate" : """0.85""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """0.9999""" },
    { "rate" : """9.96""" },
    { "rate" : """14.96""" },
    { "rate" : """0.99999""" },
    { "rate" : """13.8""" },
    { "rate" : """1.9""" },
    { "rate" : """7""" },
    { "rate" : """5.79""" },
    { "rate" : """8""" },
    { "rate" : """1.87""" },
    { "rate" : """8.99""" },
    { "rate" : """1""" },
    { "rate" : """0.987""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """1""" },
    { "rate" : """17.48""" },
    { "rate" : """0.89999""" },
    { "rate" : """10.73""" },
    { "rate" : """0.98888""" },
    { "rate" : """5""" },
    { "rate" : """0.4706""" },
    { "rate" : """1""" },
    { "rate" : """0.9999""" },
    { "rate" : """17.48""" },
    { "rate" : """9""" },
    { "rate" : """17.48""" },
    { "rate" : """15""" },
    { "rate" : """18.98""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """4.9""" },
    { "rate" : """9""" },
    { "rate" : """0.989""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """17.48""" },
    { "rate" : """0.75""" },
    { "rate" : """4.95""" },
    { "rate" : """0.98""" },
    { "rate" : """1""" },
    { "rate" : """17.47""" },
    { "rate" : """0.99989""" },
    { "rate" : """6""" },
    { "rate" : """17.4999""" },
    { "rate" : """13.11""" },
    { "rate" : """0.79998""" },
    { "rate" : """0.8""" },
    { "rate" : """0.98""" },
    { "rate" : """0.9""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.84""" },
    { "rate" : """0.8""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9""" },
    { "rate" : """10.73""" },
    { "rate" : """0.4706""" },
    { "rate" : """17.48""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """17.48""" },
    { "rate" : """10""" },
    { "rate" : """17.48""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """0.4706""" },
    { "rate" : """17.48""" },
    { "rate" : """0.87""" },
    { "rate" : """4""" },
    { "rate" : """15.14""" },
    { "rate" : """1""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """0.99""" },
    { "rate" : """10.73""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """17.48""" },
    { "rate" : """0.9""" },
    { "rate" : """4""" },
    { "rate" : """0.8""" },
    { "rate" : """17.48""" },
    { "rate" : """10.73""" },
    { "rate" : """12.46""" },
    { "rate" : """0.7""" },
    { "rate" : """10""" },
    { "rate" : """1.88""" },
    { "rate" : """9.99999""" },
    { "rate" : """8.8""" },
    { "rate" : """4.98""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """1.85""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """0.98888""" },
    { "rate" : """8.8""" },
    { "rate" : """8.78888""" },
    { "rate" : """0.99986""" },
    { "rate" : """0.98888""" },
    { "rate" : """5""" },
    { "rate" : """0.98888""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """0.9999""" },
    { "rate" : """4.9999""" },
    { "rate" : """10.73""" },
    { "rate" : """9.99914""" },
    { "rate" : """7.98""" },
    { "rate" : """1.888""" },
    { "rate" : """7.5""" },
    { "rate" : """9""" },
    { "rate" : """0.973""" },
    { "rate" : """0.96""" },
    { "rate" : """8""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """13.72""" },
    { "rate" : """6.99999""" },
    { "rate" : """0.9899""" },
    { "rate" : """7.69989""" },
    { "rate" : """7.99999""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """0.4706""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """7.99""" },
    { "rate" : """12.99""" },
    { "rate" : """7""" },
    { "rate" : """13.72""" },
    { "rate" : """7.39997""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """16.16""" },
    { "rate" : """2""" },
    { "rate" : """0.98""" },
    { "rate" : """12""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """7.4""" },
    { "rate" : """13.11""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """17.99999""" },
    { "rate" : """0.99""" },
    { "rate" : """13.11""" },
    { "rate" : """10.72""" },
    { "rate" : """8.8""" },
    { "rate" : """1.5""" },
    { "rate" : """15""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """16""" },
    { "rate" : """8""" },
    { "rate" : """4.99998""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """1.89999""" },
    { "rate" : """13.11""" },
    { "rate" : """8.8""" },
    { "rate" : """2.5""" },
    { "rate" : """2""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """2""" },
    { "rate" : """13.98""" },
    { "rate" : """10.71""" },
    { "rate" : """6.55""" },
    { "rate" : """0.96""" },
    { "rate" : """9.99""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """1.4""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """1.8""" },
    { "rate" : """8""" },
    { "rate" : """9.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """1.3""" },
    { "rate" : """5.24""" },
    { "rate" : """5.24""" },
    { "rate" : """5.24""" },
    { "rate" : """5.24""" },
    { "rate" : """5.24""" },
    { "rate" : """5.24""" },
    { "rate" : """5.24""" },
    { "rate" : """5.24""" },
    { "rate" : """10.73""" },
    { "rate" : """12.45""" },
    { "rate" : """10.7299""" },
    { "rate" : """2""" },
    { "rate" : """0.4706""" },
    { "rate" : """6""" },
    { "rate" : """5.99""" },
    { "rate" : """1.49""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """1.8""" },
    { "rate" : """10.7""" },
    { "rate" : """10.73""" },
    { "rate" : """8""" },
    { "rate" : """10.73""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """15.14""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """23.58""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """0.4706""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """18.98""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """12.46""" },
    { "rate" : """9.96""" },
    { "rate" : """10.72888""" },
    { "rate" : """10.73""" },
    { "rate" : """9""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """10.72888""" },
    { "rate" : """18.98""" },
    { "rate" : """10.73""" },
    { "rate" : """12.46""" },
    { "rate" : """10.73""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """10.7""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """16""" },
    { "rate" : """9.96""" },
    { "rate" : """15.14""" },
    { "rate" : """13.11""" },
    { "rate" : """0.4706""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """11""" },
    { "rate" : """15""" },
    { "rate" : """8.5""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """5.99999""" },
    { "rate" : """10.69999""" },
    { "rate" : """15.14""" },
    { "rate" : """8.7""" },
    { "rate" : """6.95""" },
    { "rate" : """5""" },
    { "rate" : """23.58""" },
    { "rate" : """9.499""" },
    { "rate" : """8""" },
    { "rate" : """0.96""" },
    { "rate" : """8""" },
    { "rate" : """14.77""" },
    { "rate" : """13.72""" },
    { "rate" : """9.9""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """0.0005""" },
    { "rate" : """15.14""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """6.55""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """18.98""" },
    { "rate" : """10""" },
    { "rate" : """0.28888""" },
    { "rate" : """0.96""" },
    { "rate" : """5""" },
    { "rate" : """14.5""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """18.98""" },
    { "rate" : """7""" },
    { "rate" : """10.73""" },
    { "rate" : """6.55""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """9.96""" },
    { "rate" : """0.27998""" },
    { "rate" : """0.285""" },
    { "rate" : """13.11""" },
    { "rate" : """9.96""" },
    { "rate" : """15.14""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """15.888""" },
    { "rate" : """14.98""" },
    { "rate" : """6.98""" },
    { "rate" : """8.79""" },
    { "rate" : """10.72""" },
    { "rate" : """11""" },
    { "rate" : """8.8""" },
    { "rate" : """13.11""" },
    { "rate" : """15.14""" },
    { "rate" : """0.288""" },
    { "rate" : """7""" },
    { "rate" : """0.28""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """9""" },
    { "rate" : """4.98""" },
    { "rate" : """0.28799""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """18.9""" },
    { "rate" : """9.96""" },
    { "rate" : """5.23""" },
    { "rate" : """10.73""" },
    { "rate" : """3""" },
    { "rate" : """8.8""" },
    { "rate" : """14.99999""" },
    { "rate" : """5""" },
    { "rate" : """0.69999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.8""" },
    { "rate" : """0.7""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.99999""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """1""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """15""" },
    { "rate" : """0.45""" },
    { "rate" : """0.28""" },
    { "rate" : """0.99""" },
    { "rate" : """0.47""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """0.4706""" },
    { "rate" : """2""" },
    { "rate" : """0.49998""" },
    { "rate" : """0.98998""" },
    { "rate" : """0.7""" },
    { "rate" : """14.98998""" },
    { "rate" : """0.5""" },
    { "rate" : """0.69""" },
    { "rate" : """0.4706""" },
    { "rate" : """14.99999""" },
    { "rate" : """17.47""" },
    { "rate" : """8.8""" },
    { "rate" : """0.999""" },
    { "rate" : """2""" },
    { "rate" : """0.99999""" },
    { "rate" : """8""" },
    { "rate" : """0.96""" },
    { "rate" : """5""" },
    { "rate" : """0.46999""" },
    { "rate" : """14.99999""" },
    { "rate" : """0.36999""" },
    { "rate" : """8.8""" },
    { "rate" : """0.98""" },
    { "rate" : """13.72""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """13.7""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """0.99""" },
    { "rate" : """13.72""" },
    { "rate" : """10.5""" },
    { "rate" : """18.98""" },
    { "rate" : """7.4""" },
    { "rate" : """8.8""" },
    { "rate" : """1""" },
    { "rate" : """7.8""" },
    { "rate" : """9.99999""" },
    { "rate" : """7.7""" },
    { "rate" : """6.5""" },
    { "rate" : """0.5""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """14.98""" },
    { "rate" : """9.98""" },
    { "rate" : """13.72""" },
    { "rate" : """8.7999""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """0.59999""" },
    { "rate" : """23.57""" },
    { "rate" : """11""" },
    { "rate" : """6.99""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """9""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """15""" },
    { "rate" : """0.21""" },
    { "rate" : """9.96""" },
    { "rate" : """0.28799""" },
    { "rate" : """0.68""" },
    { "rate" : """10""" },
    { "rate" : """0.6""" },
    { "rate" : """0.6899""" },
    { "rate" : """0.28887""" },
    { "rate" : """10.72888""" },
    { "rate" : """14.98888""" },
    { "rate" : """0.68888""" },
    { "rate" : """10.72888""" },
    { "rate" : """10.72""" },
    { "rate" : """9.95""" },
    { "rate" : """8.8""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """0.4706""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """10.73""" },
    { "rate" : """3.24""" },
    { "rate" : """5""" },
    { "rate" : """4.987""" },
    { "rate" : """3.24""" },
    { "rate" : """4.4999""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """11.55""" },
    { "rate" : """4.99996""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """4.98998""" },
    { "rate" : """7""" },
    { "rate" : """10.73""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """4.9""" },
    { "rate" : """8.8""" },
    { "rate" : """4.99999""" },
    { "rate" : """0.96""" },
    { "rate" : """4.99""" },
    { "rate" : """10""" },
    { "rate" : """3.24""" },
    { "rate" : """4.9""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """8.7""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """10.1""" },
    { "rate" : """0.96""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """3.24""" },
    { "rate" : """5""" },
    { "rate" : """11.98998""" },
    { "rate" : """3.24""" },
    { "rate" : """4.5""" },
    { "rate" : """2""" },
    { "rate" : """0.96""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """8.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """10.73""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.95""" },
    { "rate" : """3.23""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """20""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """8.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """3.24""" },
    { "rate" : """4.9""" },
    { "rate" : """4.99""" },
    { "rate" : """11.98""" },
    { "rate" : """4.98""" },
    { "rate" : """17.98""" },
    { "rate" : """3.23888""" },
    { "rate" : """4.98""" },
    { "rate" : """8.78888""" },
    { "rate" : """13.72""" },
    { "rate" : """3.1""" },
    { "rate" : """15.13888""" },
    { "rate" : """12.46""" },
    { "rate" : """3.24""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """15""" },
    { "rate" : """8.9""" },
    { "rate" : """8.8""" },
    { "rate" : """12.26""" },
    { "rate" : """11""" },
    { "rate" : """12.26""" },
    { "rate" : """4.2""" },
    { "rate" : """13.72""" },
    { "rate" : """9.8""" },
    { "rate" : """12.46""" },
    { "rate" : """17.48""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.96""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.24""" },
    { "rate" : """4.98""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """9.96""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """4.99""" },
    { "rate" : """14.9""" },
    { "rate" : """11.99""" },
    { "rate" : """12.26""" },
    { "rate" : """18""" },
    { "rate" : """9.96""" },
    { "rate" : """11""" },
    { "rate" : """18.98""" },
    { "rate" : """5""" },
    { "rate" : """23.5""" },
    { "rate" : """10""" },
    { "rate" : """11.99999""" },
    { "rate" : """4.9""" },
    { "rate" : """13.71""" },
    { "rate" : """9.96""" },
    { "rate" : """4.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """7.4""" },
    { "rate" : """12.26""" },
    { "rate" : """11""" },
    { "rate" : """13.11""" },
    { "rate" : """20""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """19.98888""" },
    { "rate" : """2""" },
    { "rate" : """4.95""" },
    { "rate" : """11.9""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """19.5""" },
    { "rate" : """13.11""" },
    { "rate" : """11""" },
    { "rate" : """8.8""" },
    { "rate" : """12.26""" },
    { "rate" : """0.8""" },
    { "rate" : """10""" },
    { "rate" : """10.99999""" },
    { "rate" : """0.79""" },
    { "rate" : """12.26""" },
    { "rate" : """0.7899""" },
    { "rate" : """0.8""" },
    { "rate" : """0.78888""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.79999""" },
    { "rate" : """0.43999""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """4.9""" },
    { "rate" : """4.99999""" },
    { "rate" : """0.9""" },
    { "rate" : """4.98""" },
    { "rate" : """0.3""" },
    { "rate" : """0.9""" },
    { "rate" : """0.3""" },
    { "rate" : """10.73""" },
    { "rate" : """4.99""" },
    { "rate" : """0.29""" },
    { "rate" : """0.74899""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.4706""" },
    { "rate" : """8.8""" },
    { "rate" : """0.9""" },
    { "rate" : """0.3""" },
    { "rate" : """4.98999""" },
    { "rate" : """4.5""" },
    { "rate" : """0.3""" },
    { "rate" : """4.8""" },
    { "rate" : """0.75""" },
    { "rate" : """13""" },
    { "rate" : """0.29998""" },
    { "rate" : """0.44998""" },
    { "rate" : """0.29""" },
    { "rate" : """8.8""" },
    { "rate" : """9.98998""" },
    { "rate" : """4.99""" },
    { "rate" : """13.5""" },
    { "rate" : """0.735""" },
    { "rate" : """13.11""" },
    { "rate" : """6""" },
    { "rate" : """12.26""" },
    { "rate" : """0.28""" },
    { "rate" : """13.11""" },
    { "rate" : """18""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """18.97""" },
    { "rate" : """13.71888""" },
    { "rate" : """10.98888""" },
    { "rate" : """0.3""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """0.25""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """9.968""" },
    { "rate" : """4.89999""" },
    { "rate" : """0.74987""" },
    { "rate" : """13.71""" },
    { "rate" : """7.98""" },
    { "rate" : """12.25""" },
    { "rate" : """17.99""" },
    { "rate" : """13.72""" },
    { "rate" : """7.99""" },
    { "rate" : """0.75""" },
    { "rate" : """13.11""" },
    { "rate" : """8.8""" },
    { "rate" : """18.98""" },
    { "rate" : """13.72""" },
    { "rate" : """0.4706""" },
    { "rate" : """7.99999""" },
    { "rate" : """12""" },
    { "rate" : """0.7""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """8""" },
    { "rate" : """4.99""" },
    { "rate" : """0.7""" },
    { "rate" : """3""" },
    { "rate" : """3.22""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """20""" },
    { "rate" : """0.3""" },
    { "rate" : """4""" },
    { "rate" : """0.44999""" },
    { "rate" : """8""" },
    { "rate" : """13.71""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """3.24""" },
    { "rate" : """20""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.3""" },
    { "rate" : """3.24""" },
    { "rate" : """8""" },
    { "rate" : """0.3""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """0.3""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """2""" },
    { "rate" : """6.99""" },
    { "rate" : """6.54""" },
    { "rate" : """13.72""" },
    { "rate" : """0.3""" },
    { "rate" : """11""" },
    { "rate" : """8.3""" },
    { "rate" : """3.23""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """7.04""" },
    { "rate" : """7.04""" },
    { "rate" : """7.04""" },
    { "rate" : """7.04""" },
    { "rate" : """8.79""" },
    { "rate" : """0.4706""" },
    { "rate" : """8.7""" },
    { "rate" : """13.72""" },
    { "rate" : """3.24""" },
    { "rate" : """8.5""" },
    { "rate" : """10.99899""" },
    { "rate" : """12""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """8.79""" },
    { "rate" : """7""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """6.55""" },
    { "rate" : """15.13999""" },
    { "rate" : """0.3""" },
    { "rate" : """4.8""" },
    { "rate" : """3.24""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """0.96""" },
    { "rate" : """10.5""" },
    { "rate" : """4.99""" },
    { "rate" : """9.9""" },
    { "rate" : """4.95""" },
    { "rate" : """13.1""" },
    { "rate" : """4.88""" },
    { "rate" : """6.55""" },
    { "rate" : """13.72""" },
    { "rate" : """3.24""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """10.719""" },
    { "rate" : """9.89""" },
    { "rate" : """9.8999""" },
    { "rate" : """14.98""" },
    { "rate" : """0.3""" },
    { "rate" : """3.24""" },
    { "rate" : """0.8999""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """4.979""" },
    { "rate" : """4.99911""" },
    { "rate" : """9.99973""" },
    { "rate" : """13.72""" },
    { "rate" : """7""" },
    { "rate" : """19.99""" },
    { "rate" : """19.99""" },
    { "rate" : """13.72""" },
    { "rate" : """12.46""" },
    { "rate" : """4.4""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """9.99""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4.98997""" },
    { "rate" : """11.99""" },
    { "rate" : """0.3""" },
    { "rate" : """15.14""" },
    { "rate" : """7.38""" },
    { "rate" : """12""" },
    { "rate" : """14.9999""" },
    { "rate" : """6.5""" },
    { "rate" : """0.3""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """6.54""" },
    { "rate" : """4""" },
    { "rate" : """0.29""" },
    { "rate" : """14.9""" },
    { "rate" : """12.46""" },
    { "rate" : """14.9""" },
    { "rate" : """8.8""" },
    { "rate" : """13.11""" },
    { "rate" : """6.55""" },
    { "rate" : """0.749""" },
    { "rate" : """6.55""" },
    { "rate" : """7""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """0.45""" },
    { "rate" : """17.48""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """0.96""" },
    { "rate" : """0.3""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """7.5""" },
    { "rate" : """12""" },
    { "rate" : """0.9""" },
    { "rate" : """11.95""" },
    { "rate" : """7.99""" },
    { "rate" : """12.9""" },
    { "rate" : """7.8""" },
    { "rate" : """4.9""" },
    { "rate" : """7.9""" },
    { "rate" : """14.8""" },
    { "rate" : """7.8""" },
    { "rate" : """0.75""" },
    { "rate" : """0.7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """15.14""" },
    { "rate" : """7.75""" },
    { "rate" : """8.8""" },
    { "rate" : """6.55""" },
    { "rate" : """8""" },
    { "rate" : """14.8999""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """24""" },
    { "rate" : """6.55""" },
    { "rate" : """0.24""" },
    { "rate" : """0.4""" },
    { "rate" : """0.25""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """0.3""" },
    { "rate" : """0.455""" },
    { "rate" : """8.8""" },
    { "rate" : """0.29998""" },
    { "rate" : """0.389""" },
    { "rate" : """0.25""" },
    { "rate" : """0.2999""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """0.29999""" },
    { "rate" : """0.2""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """15.14""" },
    { "rate" : """0.4706""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """9.79""" },
    { "rate" : """14.8""" },
    { "rate" : """9.2""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """13.72""" },
    { "rate" : """12.9""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """16""" },
    { "rate" : """0.96""" },
    { "rate" : """13.11""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """4.9""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """14.7""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """15.98998""" },
    { "rate" : """8.8""" },
    { "rate" : """15.98""" },
    { "rate" : """6.55""" },
    { "rate" : """13.72""" },
    { "rate" : """15.99999""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """0.78997""" },
    { "rate" : """0.78998""" },
    { "rate" : """0.4706""" },
    { "rate" : """13.72""" },
    { "rate" : """0.85""" },
    { "rate" : """12.46""" },
    { "rate" : """6.55""" },
    { "rate" : """0.78999""" },
    { "rate" : """0.79999""" },
    { "rate" : """17.47""" },
    { "rate" : """13.05""" },
    { "rate" : """0.7898""" },
    { "rate" : """18.98""" },
    { "rate" : """12.26""" },
    { "rate" : """6.55""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """13.11""" },
    { "rate" : """11.8""" },
    { "rate" : """12""" },
    { "rate" : """6.55""" },
    { "rate" : """8""" },
    { "rate" : """6.55""" },
    { "rate" : """10.73""" },
    { "rate" : """6.55""" },
    { "rate" : """12.26""" },
    { "rate" : """8.8""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """10.73""" },
    { "rate" : """6.55""" },
    { "rate" : """13""" },
    { "rate" : """8.8""" },
    { "rate" : """15""" },
    { "rate" : """13""" },
    { "rate" : """6.55""" },
    { "rate" : """8""" },
    { "rate" : """4.9""" },
    { "rate" : """17""" },
    { "rate" : """11.9""" },
    { "rate" : """13.72""" },
    { "rate" : """7""" },
    { "rate" : """13.11""" },
    { "rate" : """1""" },
    { "rate" : """0.45554""" },
    { "rate" : """9.99""" },
    { "rate" : """13.72""" },
    { "rate" : """13.11""" },
    { "rate" : """8""" },
    { "rate" : """16.17""" },
    { "rate" : """10.5""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """16""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """15.77999""" },
    { "rate" : """8.8""" },
    { "rate" : """6.55""" },
    { "rate" : """7.99999""" },
    { "rate" : """9.9999""" },
    { "rate" : """5""" },
    { "rate" : """15.5""" },
    { "rate" : """4.999""" },
    { "rate" : """5""" },
    { "rate" : """10.7""" },
    { "rate" : """9.5""" },
    { "rate" : """20""" },
    { "rate" : """13.11""" },
    { "rate" : """15.9879""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """13.109""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """15.1""" },
    { "rate" : """16""" },
    { "rate" : """13.72""" },
    { "rate" : """13.11""" },
    { "rate" : """0.96""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """14""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """4.95""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """15.5""" },
    { "rate" : """13""" },
    { "rate" : """12""" },
    { "rate" : """13""" },
    { "rate" : """4.99996""" },
    { "rate" : """12""" },
    { "rate" : """4.5""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """6.55""" },
    { "rate" : """4.9999""" },
    { "rate" : """10.73""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """10.73""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """12.42""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """8.8""" },
    { "rate" : """6.55""" },
    { "rate" : """17""" },
    { "rate" : """0.45555""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """2""" },
    { "rate" : """12.45""" },
    { "rate" : """12.26""" },
    { "rate" : """13.71""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """10.73""" },
    { "rate" : """10.71""" },
    { "rate" : """13.72""" },
    { "rate" : """0.4706""" },
    { "rate" : """13.11""" },
    { "rate" : """12.46""" },
    { "rate" : """10.73""" },
    { "rate" : """16.17""" },
    { "rate" : """10.73""" },
    { "rate" : """3""" },
    { "rate" : """16""" },
    { "rate" : """13""" },
    { "rate" : """10.73""" },
    { "rate" : """6.55""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """11.98888""" },
    { "rate" : """6.54888""" },
    { "rate" : """13.71888""" },
    { "rate" : """12.26""" },
    { "rate" : """3.75""" },
    { "rate" : """13.11""" },
    { "rate" : """12.46""" },
    { "rate" : """10.73""" },
    { "rate" : """13.11""" },
    { "rate" : """14""" },
    { "rate" : """10.73""" },
    { "rate" : """13.11""" },
    { "rate" : """11.99""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """7.99""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """6.54998""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """10.73""" },
    { "rate" : """12.46""" },
    { "rate" : """3""" },
    { "rate" : """12.26""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """13.11""" },
    { "rate" : """12""" },
    { "rate" : """17""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """12""" },
    { "rate" : """4.99946""" },
    { "rate" : """10""" },
    { "rate" : """6.55""" },
    { "rate" : """12.46""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """12.26""" },
    { "rate" : """6.55""" },
    { "rate" : """10.72""" },
    { "rate" : """12.45888""" },
    { "rate" : """6.54888""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """10.73""" },
    { "rate" : """12.5""" },
    { "rate" : """12""" },
    { "rate" : """18.98""" },
    { "rate" : """13.72""" },
    { "rate" : """12.45888""" },
    { "rate" : """6.54888""" },
    { "rate" : """13.72""" },
    { "rate" : """12.46""" },
    { "rate" : """18.98""" },
    { "rate" : """16.17""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """12.26""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """0.465""" },
    { "rate" : """12""" },
    { "rate" : """10.73""" },
    { "rate" : """12.26""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """10.5""" },
    { "rate" : """11.99""" },
    { "rate" : """0.4""" },
    { "rate" : """12""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """10.73""" },
    { "rate" : """18.98""" },
    { "rate" : """12""" },
    { "rate" : """12.26""" },
    { "rate" : """10.73""" },
    { "rate" : """4""" },
    { "rate" : """12.26""" },
    { "rate" : """14""" },
    { "rate" : """10.73""" },
    { "rate" : """6.55""" },
    { "rate" : """12""" },
    { "rate" : """6.54""" },
    { "rate" : """10.73""" },
    { "rate" : """15""" },
    { "rate" : """18.98""" },
    { "rate" : """12""" },
    { "rate" : """12.25""" },
    { "rate" : """13.72""" },
    { "rate" : """12.26""" },
    { "rate" : """10.5""" },
    { "rate" : """11.25""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """10.73""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """13.72""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """3""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """12.26""" },
    { "rate" : """4.98888""" },
    { "rate" : """16""" },
    { "rate" : """10.7""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """20""" },
    { "rate" : """6""" },
    { "rate" : """10.7""" },
    { "rate" : """12.26""" },
    { "rate" : """10.69999""" },
    { "rate" : """6.54999""" },
    { "rate" : """10""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """6.3""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """23.56""" },
    { "rate" : """23.55999""" },
    { "rate" : """14""" },
    { "rate" : """5.99""" },
    { "rate" : """6.5""" },
    { "rate" : """6""" },
    { "rate" : """5.99999""" },
    { "rate" : """10.73""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5.99999""" },
    { "rate" : """1""" },
    { "rate" : """0.9""" },
    { "rate" : """0.99999""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """2.98""" },
    { "rate" : """7.98""" },
    { "rate" : """13.72""" },
    { "rate" : """10.73""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """13.71999""" },
    { "rate" : """5""" },
    { "rate" : """13.1""" },
    { "rate" : """13.72""" },
    { "rate" : """8""" },
    { "rate" : """0.68888""" },
    { "rate" : """0.5""" },
    { "rate" : """0.7""" },
    { "rate" : """0.09999""" },
    { "rate" : """0.9""" },
    { "rate" : """6.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """0.68888""" },
    { "rate" : """0.8999""" },
    { "rate" : """5.98999""" },
    { "rate" : """5.9998""" },
    { "rate" : """13.72""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """13.7""" },
    { "rate" : """5.98""" },
    { "rate" : """13.099""" },
    { "rate" : """6""" },
    { "rate" : """11""" },
    { "rate" : """2.99""" },
    { "rate" : """3""" },
    { "rate" : """7.5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """5.3""" },
    { "rate" : """3""" },
    { "rate" : """3.24""" },
    { "rate" : """1""" },
    { "rate" : """23.58""" },
    { "rate" : """3.24""" },
    { "rate" : """10""" },
    { "rate" : """3.23999""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """13.72""" },
    { "rate" : """3.24""" },
    { "rate" : """3""" },
    { "rate" : """3.24""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """3.23999""" },
    { "rate" : """13.72""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """3.21""" },
    { "rate" : """3.24""" },
    { "rate" : """6""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """3.24""" },
    { "rate" : """3.2""" },
    { "rate" : """23.58""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """12.26""" },
    { "rate" : """6.24""" },
    { "rate" : """3.24""" },
    { "rate" : """11.55""" },
    { "rate" : """18.98""" },
    { "rate" : """3.24""" },
    { "rate" : """13.72""" },
    { "rate" : """3.2""" },
    { "rate" : """10.73""" },
    { "rate" : """13.71""" },
    { "rate" : """12.46""" },
    { "rate" : """10.73""" },
    { "rate" : """13.7""" },
    { "rate" : """13.5""" },
    { "rate" : """6.55""" },
    { "rate" : """23.58""" },
    { "rate" : """12.26""" },
    { "rate" : """13.72""" },
    { "rate" : """12.26""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """11.69""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """16""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """23.58""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """13.7""" },
    { "rate" : """5""" },
    { "rate" : """4.98""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """13.72""" },
    { "rate" : """0.47999""" },
    { "rate" : """0.47998""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """7.99""" },
    { "rate" : """12.26""" },
    { "rate" : """16.17""" },
    { "rate" : """16.15""" },
    { "rate" : """10""" },
    { "rate" : """7.5""" },
    { "rate" : """13.7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """0.47""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """9.98998""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4.98998""" },
    { "rate" : """16.17""" },
    { "rate" : """8""" },
    { "rate" : """12.26""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """1.9""" },
    { "rate" : """1.55""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.3""" },
    { "rate" : """2""" },
    { "rate" : """1.98998""" },
    { "rate" : """2""" },
    { "rate" : """1.99998""" },
    { "rate" : """1.98""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """9""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """1.5""" },
    { "rate" : """3.64""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.52""" },
    { "rate" : """23.52""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """3.62""" },
    { "rate" : """23.58""" },
    { "rate" : """4.9""" },
    { "rate" : """1.88""" },
    { "rate" : """1.9""" },
    { "rate" : """9.75""" },
    { "rate" : """3.64""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """12""" },
    { "rate" : """1.9""" },
    { "rate" : """16.17""" },
    { "rate" : """2""" },
    { "rate" : """1.5""" },
    { "rate" : """1.99989""" },
    { "rate" : """13.71999""" },
    { "rate" : """1.9999""" },
    { "rate" : """2""" },
    { "rate" : """5.99""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """1.98998""" },
    { "rate" : """2""" },
    { "rate" : """1.5""" },
    { "rate" : """1.99999""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """1.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """3.625""" },
    { "rate" : """7.99999""" },
    { "rate" : """2""" },
    { "rate" : """5.49""" },
    { "rate" : """5.45""" },
    { "rate" : """5""" },
    { "rate" : """5.48""" },
    { "rate" : """1.99""" },
    { "rate" : """1.88888""" },
    { "rate" : """13.95""" },
    { "rate" : """5.5""" },
    { "rate" : """3.64""" },
    { "rate" : """10""" },
    { "rate" : """5.3""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """5.5""" },
    { "rate" : """0.8""" },
    { "rate" : """0.8879""" },
    { "rate" : """0.888""" },
    { "rate" : """0.8""" },
    { "rate" : """2""" },
    { "rate" : """1.9""" },
    { "rate" : """0.8879""" },
    { "rate" : """0.88""" },
    { "rate" : """10""" },
    { "rate" : """3.64""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """1.88""" },
    { "rate" : """0.47""" },
    { "rate" : """11""" },
    { "rate" : """5.5""" },
    { "rate" : """2""" },
    { "rate" : """0.9""" },
    { "rate" : """5.4999""" },
    { "rate" : """1.9999""" },
    { "rate" : """1.95""" },
    { "rate" : """2""" },
    { "rate" : """6.55""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """15.72""" },
    { "rate" : """16.17""" },
    { "rate" : """3.64""" },
    { "rate" : """1.5""" },
    { "rate" : """6.55""" },
    { "rate" : """16.17""" },
    { "rate" : """5.4""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5.4""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """3.64""" },
    { "rate" : """11.5""" },
    { "rate" : """5""" },
    { "rate" : """16""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.78""" },
    { "rate" : """8.8""" },
    { "rate" : """8.2""" },
    { "rate" : """8.77998""" },
    { "rate" : """8.79""" },
    { "rate" : """8.8""" },
    { "rate" : """11.95""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """23.58""" },
    { "rate" : """12.26""" },
    { "rate" : """0.96""" },
    { "rate" : """10""" },
    { "rate" : """18.98""" },
    { "rate" : """8""" },
    { "rate" : """5.48""" },
    { "rate" : """8.78""" },
    { "rate" : """25.17""" },
    { "rate" : """8.79999""" },
    { "rate" : """8""" },
    { "rate" : """12.46""" },
    { "rate" : """9.99999""" },
    { "rate" : """5.39999""" },
    { "rate" : """8""" },
    { "rate" : """3.59999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """16.17""" },
    { "rate" : """5.49999""" },
    { "rate" : """13.72""" },
    { "rate" : """16.16999""" },
    { "rate" : """16.17""" },
    { "rate" : """8""" },
    { "rate" : """12.26""" },
    { "rate" : """13.71""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """12.26""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """7.99""" },
    { "rate" : """12""" },
    { "rate" : """13.72""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """5.4""" },
    { "rate" : """50""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """12.46""" },
    { "rate" : """6.55""" },
    { "rate" : """13.72""" },
    { "rate" : """19.9999""" },
    { "rate" : """9.96""" },
    { "rate" : """6.55""" },
    { "rate" : """4.99999""" },
    { "rate" : """3.59998""" },
    { "rate" : """7.98999""" },
    { "rate" : """4.97999""" },
    { "rate" : """6.54999""" },
    { "rate" : """3.99999""" },
    { "rate" : """6.55""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """5.49""" },
    { "rate" : """13.5""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5.49998""" },
    { "rate" : """4.99999""" },
    { "rate" : """13.72""" },
    { "rate" : """18.98""" },
    { "rate" : """12.26""" },
    { "rate" : """4.5""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """23.58""" },
    { "rate" : """9.96""" },
    { "rate" : """20.72""" },
    { "rate" : """9.95999""" },
    { "rate" : """9.9""" },
    { "rate" : """8""" },
    { "rate" : """7.5""" },
    { "rate" : """5.4""" },
    { "rate" : """11.98999""" },
    { "rate" : """9""" },
    { "rate" : """13.72""" },
    { "rate" : """12.26""" },
    { "rate" : """0.4706""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """7.9""" },
    { "rate" : """11""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """7.89""" },
    { "rate" : """23.56""" },
    { "rate" : """7.98""" },
    { "rate" : """23.55999""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """8""" },
    { "rate" : """13.72""" },
    { "rate" : """6.85""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """13.5""" },
    { "rate" : """23.58""" },
    { "rate" : """12.25""" },
    { "rate" : """5.49""" },
    { "rate" : """12""" },
    { "rate" : """13.72""" },
    { "rate" : """12.26""" },
    { "rate" : """23.58""" },
    { "rate" : """8""" },
    { "rate" : """11.9""" },
    { "rate" : """12.26""" },
    { "rate" : """12.99""" },
    { "rate" : """8.85""" },
    { "rate" : """18.98""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """0.96""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """16.17""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """7.99""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """13""" },
    { "rate" : """13""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """15.14""" },
    { "rate" : """9.96""" },
    { "rate" : """6.55""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """0.9""" },
    { "rate" : """0.97998""" },
    { "rate" : """12""" },
    { "rate" : """0.9""" },
    { "rate" : """8""" },
    { "rate" : """0.89999""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """13""" },
    { "rate" : """1""" },
    { "rate" : """0.9999""" },
    { "rate" : """1""" },
    { "rate" : """0.99989""" },
    { "rate" : """1""" },
    { "rate" : """13.72""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.99899""" },
    { "rate" : """0.99""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """0.99999""" },
    { "rate" : """13.72""" },
    { "rate" : """3""" },
    { "rate" : """0.4706""" },
    { "rate" : """16""" },
    { "rate" : """12""" },
    { "rate" : """16""" },
    { "rate" : """16""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """18.96""" },
    { "rate" : """7.98""" },
    { "rate" : """18.98""" },
    { "rate" : """6.55""" },
    { "rate" : """0.75""" },
    { "rate" : """0.99899""" },
    { "rate" : """18.98""" },
    { "rate" : """5""" },
    { "rate" : """14.98888""" },
    { "rate" : """12.25999""" },
    { "rate" : """9.95888""" },
    { "rate" : """13.72""" },
    { "rate" : """0.98""" },
    { "rate" : """6""" },
    { "rate" : """13.72""" },
    { "rate" : """18""" },
    { "rate" : """4.98""" },
    { "rate" : """6.54888""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """5""" },
    { "rate" : """0.9""" },
    { "rate" : """13.72""" },
    { "rate" : """0.8""" },
    { "rate" : """6.55""" },
    { "rate" : """8""" },
    { "rate" : """6.55""" },
    { "rate" : """18.98""" },
    { "rate" : """8.99996""" },
    { "rate" : """13.72""" },
    { "rate" : """18""" },
    { "rate" : """0.6""" },
    { "rate" : """12""" },
    { "rate" : """13.72""" },
    { "rate" : """0.98""" },
    { "rate" : """0.97""" },
    { "rate" : """0.97999""" },
    { "rate" : """13.72""" },
    { "rate" : """0.49999""" },
    { "rate" : """13.72""" },
    { "rate" : """0.9798""" },
    { "rate" : """13.72""" },
    { "rate" : """0.89999""" },
    { "rate" : """13.72""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.85""" },
    { "rate" : """0.9""" },
    { "rate" : """9.96""" },
    { "rate" : """6.55""" },
    { "rate" : """15""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """18.98""" },
    { "rate" : """16.17""" },
    { "rate" : """6.55""" },
    { "rate" : """12.46""" },
    { "rate" : """0.8""" },
    { "rate" : """0.75""" },
    { "rate" : """9.96""" },
    { "rate" : """12.46""" },
    { "rate" : """15.14""" },
    { "rate" : """6.55""" },
    { "rate" : """9.96""" },
    { "rate" : """0.99999""" },
    { "rate" : """13.72""" },
    { "rate" : """12.258""" },
    { "rate" : """0.87""" },
    { "rate" : """12.46""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """6.55""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99998""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """8.584""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9.2""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99998""" },
    { "rate" : """13""" },
    { "rate" : """13.72""" },
    { "rate" : """18.98""" },
    { "rate" : """6.55""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """16""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """13.72""" },
    { "rate" : """4.98""" },
    { "rate" : """0.75""" },
    { "rate" : """8.8""" },
    { "rate" : """11""" },
    { "rate" : """8.8""" },
    { "rate" : """7.96""" },
    { "rate" : """6.55""" },
    { "rate" : """8.79999""" },
    { "rate" : """10.99999""" },
    { "rate" : """0.4706""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """0.95""" },
    { "rate" : """7.5""" },
    { "rate" : """0.65""" },
    { "rate" : """8.8""" },
    { "rate" : """0.9""" },
    { "rate" : """0.973""" },
    { "rate" : """1""" },
    { "rate" : """4.5""" },
    { "rate" : """4.9""" },
    { "rate" : """1""" },
    { "rate" : """23""" },
    { "rate" : """0.987""" },
    { "rate" : """0.98""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.97299""" },
    { "rate" : """8""" },
    { "rate" : """0.999""" },
    { "rate" : """0.99999""" },
    { "rate" : """4.8""" },
    { "rate" : """0.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """10""" },
    { "rate" : """0.97""" },
    { "rate" : """1""" },
    { "rate" : """0.99""" },
    { "rate" : """0.9""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """8.8""" },
    { "rate" : """12.46""" },
    { "rate" : """9.96""" },
    { "rate" : """0.99999""" },
    { "rate" : """1.5""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """1.49999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """9.96""" },
    { "rate" : """13""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.9""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """23.56""" },
    { "rate" : """10.99""" },
    { "rate" : """0.9""" },
    { "rate" : """0.99899""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """16.17""" },
    { "rate" : """8""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.45""" },
    { "rate" : """0.5""" },
    { "rate" : """0.45""" },
    { "rate" : """5""" },
    { "rate" : """0.99996""" },
    { "rate" : """0.99996""" },
    { "rate" : """23.58""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.79999""" },
    { "rate" : """0.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """8.78""" },
    { "rate" : """8.8""" },
    { "rate" : """8.78""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """23""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """6.99999""" },
    { "rate" : """0.999""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """1""" },
    { "rate" : """13.7""" },
    { "rate" : """16""" },
    { "rate" : """9.96""" },
    { "rate" : """6.55""" },
    { "rate" : """13.72""" },
    { "rate" : """0.99999""" },
    { "rate" : """7""" },
    { "rate" : """23.58""" },
    { "rate" : """13.72""" },
    { "rate" : """8.5""" },
    { "rate" : """23.58""" },
    { "rate" : """8.7""" },
    { "rate" : """6.55""" },
    { "rate" : """6.5""" },
    { "rate" : """8.79999""" },
    { "rate" : """13.72""" },
    { "rate" : """0.8""" },
    { "rate" : """8""" },
    { "rate" : """0.99""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """13.72""" },
    { "rate" : """16.17""" },
    { "rate" : """6.99""" },
    { "rate" : """1""" },
    { "rate" : """0.6987""" },
    { "rate" : """13.72""" },
    { "rate" : """0.6987""" },
    { "rate" : """0.6987""" },
    { "rate" : """0.95""" },
    { "rate" : """13.5""" },
    { "rate" : """1""" },
    { "rate" : """0.9""" },
    { "rate" : """8.69998""" },
    { "rate" : """8.7""" },
    { "rate" : """13.72""" },
    { "rate" : """1""" },
    { "rate" : """7.8""" },
    { "rate" : """0.99""" },
    { "rate" : """8.77998""" },
    { "rate" : """9.98997""" },
    { "rate" : """6.55""" },
    { "rate" : """13.72""" },
    { "rate" : """8.78""" },
    { "rate" : """10""" },
    { "rate" : """0.99998""" },
    { "rate" : """0.99999""" },
    { "rate" : """6.55""" },
    { "rate" : """1""" },
    { "rate" : """9.9""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """9.99999""" },
    { "rate" : """20.4""" },
    { "rate" : """6.55""" },
    { "rate" : """20.39999""" },
    { "rate" : """8.88""" },
    { "rate" : """5""" },
    { "rate" : """12.39""" },
    { "rate" : """8.8""" },
    { "rate" : """6.4""" },
    { "rate" : """6.55""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """6.55""" },
    { "rate" : """13.6""" },
    { "rate" : """16.17""" },
    { "rate" : """4.98998""" },
    { "rate" : """4.98997""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """11.99924""" },
    { "rate" : """5""" },
    { "rate" : """11.98""" },
    { "rate" : """11.88888""" },
    { "rate" : """18.97888""" },
    { "rate" : """3.24""" },
    { "rate" : """8""" },
    { "rate" : """3.23999""" },
    { "rate" : """8.79888""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """20.45""" },
    { "rate" : """12""" },
    { "rate" : """8.79""" },
    { "rate" : """4.975""" },
    { "rate" : """6.5""" },
    { "rate" : """6.55""" },
    { "rate" : """4.99""" },
    { "rate" : """10""" },
    { "rate" : """3.88""" },
    { "rate" : """12""" },
    { "rate" : """13.71""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """12.46""" },
    { "rate" : """11.99999""" },
    { "rate" : """6.55""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """11.98997""" },
    { "rate" : """12""" },
    { "rate" : """3.24""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """3.24""" },
    { "rate" : """14""" },
    { "rate" : """12.4""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """8.79""" },
    { "rate" : """1.5""" },
    { "rate" : """13.71""" },
    { "rate" : """6.549""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """12.46""" },
    { "rate" : """12""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """6.55""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """13.7""" },
    { "rate" : """13""" },
    { "rate" : """8.79""" },
    { "rate" : """5""" },
    { "rate" : """6.74""" },
    { "rate" : """13.72""" },
    { "rate" : """11""" },
    { "rate" : """12.46""" },
    { "rate" : """3.24""" },
    { "rate" : """12.46""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """3.24""" },
    { "rate" : """0.4706""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """8.5""" },
    { "rate" : """15.9""" },
    { "rate" : """4.99999""" },
    { "rate" : """6.98""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """0.4706""" },
    { "rate" : """23.58""" },
    { "rate" : """6.912""" },
    { "rate" : """6.912""" },
    { "rate" : """6.912""" },
    { "rate" : """6.912""" },
    { "rate" : """6.912""" },
    { "rate" : """6.912""" },
    { "rate" : """6.912""" },
    { "rate" : """6.912""" },
    { "rate" : """6.912""" },
    { "rate" : """6.912""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """4.9""" },
    { "rate" : """4.5""" },
    { "rate" : """8.8""" },
    { "rate" : """4.99996""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """11.98""" },
    { "rate" : """4.98998""" },
    { "rate" : """4.99999""" },
    { "rate" : """12""" },
    { "rate" : """4.49999""" },
    { "rate" : """3.24""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """23.56""" },
    { "rate" : """23.5""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """13.7""" },
    { "rate" : """3.24""" },
    { "rate" : """8""" },
    { "rate" : """4.99998""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """11""" },
    { "rate" : """20.5""" },
    { "rate" : """4.97""" },
    { "rate" : """11.97""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """7""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.46996""" },
    { "rate" : """0.3987""" },
    { "rate" : """5""" },
    { "rate" : """0.17998""" },
    { "rate" : """0.4""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """8.584""" },
    { "rate" : """8.584""" },
    { "rate" : """8.584""" },
    { "rate" : """8.584""" },
    { "rate" : """8.584""" },
    { "rate" : """8.584""" },
    { "rate" : """8.584""" },
    { "rate" : """8.584""" },
    { "rate" : """8.584""" },
    { "rate" : """8.584""" },
    { "rate" : """12""" },
    { "rate" : """0.48999""" },
    { "rate" : """13""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """10.72999""" },
    { "rate" : """7.98998""" },
    { "rate" : """10""" },
    { "rate" : """0.47998""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """13.72""" },
    { "rate" : """8.64""" },
    { "rate" : """3.24""" },
    { "rate" : """23.58""" },
    { "rate" : """8""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """8.64""" },
    { "rate" : """10.73""" },
    { "rate" : """8.29998""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """8.64""" },
    { "rate" : """7.95""" },
    { "rate" : """8.64""" },
    { "rate" : """0.39997""" },
    { "rate" : """7.98997""" },
    { "rate" : """9.8""" },
    { "rate" : """7.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.79999""" },
    { "rate" : """4.99999""" },
    { "rate" : """8.75""" },
    { "rate" : """8.29997""" },
    { "rate" : """0.39997""" },
    { "rate" : """9""" },
    { "rate" : """0.15""" },
    { "rate" : """8.62""" },
    { "rate" : """0.0002""" },
    { "rate" : """9.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """9.99""" },
    { "rate" : """23.58""" },
    { "rate" : """5""" },
    { "rate" : """7.99""" },
    { "rate" : """8.64""" },
    { "rate" : """8.63999""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """3.24""" },
    { "rate" : """8.63""" },
    { "rate" : """10.73""" },
    { "rate" : """8.64""" },
    { "rate" : """4""" },
    { "rate" : """8.63999""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """0.49""" },
    { "rate" : """0.4""" },
    { "rate" : """4.9""" },
    { "rate" : """9.99""" },
    { "rate" : """9""" },
    { "rate" : """3.24""" },
    { "rate" : """9.98""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """0.48""" },
    { "rate" : """9.78999""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """11""" },
    { "rate" : """11.5""" },
    { "rate" : """11.5""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """8.63""" },
    { "rate" : """9.9""" },
    { "rate" : """8.64""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """23.58""" },
    { "rate" : """3.24""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """4.99964""" },
    { "rate" : """7.99964""" },
    { "rate" : """8.6""" },
    { "rate" : """8""" },
    { "rate" : """4.525""" },
    { "rate" : """10""" },
    { "rate" : """0.389""" },
    { "rate" : """5""" },
    { "rate" : """3.24""" },
    { "rate" : """10""" },
    { "rate" : """23.58""" },
    { "rate" : """3.64""" },
    { "rate" : """11.5""" },
    { "rate" : """4.99""" },
    { "rate" : """18.98""" },
    { "rate" : """4.25""" },
    { "rate" : """8.64""" },
    { "rate" : """4.5""" },
    { "rate" : """8.64""" },
    { "rate" : """4.5""" },
    { "rate" : """3.24""" },
    { "rate" : """16.17""" },
    { "rate" : """3.24""" },
    { "rate" : """12.46""" },
    { "rate" : """8.64""" },
    { "rate" : """3.24""" },
    { "rate" : """4.48998""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """11.999""" },
    { "rate" : """1.12""" },
    { "rate" : """4.48""" },
    { "rate" : """3.64""" },
    { "rate" : """6""" },
    { "rate" : """3.64""" },
    { "rate" : """4.5""" },
    { "rate" : """4.5""" },
    { "rate" : """23""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """23""" },
    { "rate" : """15""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """10.73""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """0.87""" },
    { "rate" : """2""" },
    { "rate" : """1.11""" },
    { "rate" : """0.6""" },
    { "rate" : """1.12""" },
    { "rate" : """2""" },
    { "rate" : """1.98998""" },
    { "rate" : """2""" },
    { "rate" : """0.59999""" },
    { "rate" : """8.6""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """2""" },
    { "rate" : """1.99998""" },
    { "rate" : """1.95""" },
    { "rate" : """8""" },
    { "rate" : """4.5""" },
    { "rate" : """8.63""" },
    { "rate" : """4.5""" },
    { "rate" : """1.9999""" },
    { "rate" : """8""" },
    { "rate" : """1.8""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """1.99""" },
    { "rate" : """5""" },
    { "rate" : """16.17""" },
    { "rate" : """18.98""" },
    { "rate" : """12.46""" },
    { "rate" : """1.999""" },
    { "rate" : """8.64""" },
    { "rate" : """4.99999""" },
    { "rate" : """9""" },
    { "rate" : """2""" },
    { "rate" : """8.4""" },
    { "rate" : """8.3""" },
    { "rate" : """12.46""" },
    { "rate" : """4.5""" },
    { "rate" : """8""" },
    { "rate" : """1.5""" },
    { "rate" : """4.99""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.55""" },
    { "rate" : """12.24""" },
    { "rate" : """1.95""" },
    { "rate" : """8.5""" },
    { "rate" : """3.64""" },
    { "rate" : """4.9999""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """8.64""" },
    { "rate" : """4.45""" },
    { "rate" : """3.64""" },
    { "rate" : """10.73""" },
    { "rate" : """4.94""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8.64""" },
    { "rate" : """8.6""" },
    { "rate" : """4.4""" },
    { "rate" : """8.63""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """12.45999""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """8.64""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """9.49""" },
    { "rate" : """12.39998""" },
    { "rate" : """12.45999""" },
    { "rate" : """4.49964""" },
    { "rate" : """10""" },
    { "rate" : """8.6""" },
    { "rate" : """7.99999""" },
    { "rate" : """12.45999""" },
    { "rate" : """12.44""" },
    { "rate" : """4.25""" },
    { "rate" : """5""" },
    { "rate" : """8.64""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """17.99""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """8.64""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """4.99""" },
    { "rate" : """16.17""" },
    { "rate" : """8.64""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """7.99""" },
    { "rate" : """3.64""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """12.46""" },
    { "rate" : """9.99899""" },
    { "rate" : """15""" },
    { "rate" : """16.17""" },
    { "rate" : """8.64""" },
    { "rate" : """3.63""" },
    { "rate" : """8""" },
    { "rate" : """4.99998""" },
    { "rate" : """4.49""" },
    { "rate" : """8.8""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """4.5""" },
    { "rate" : """4.5""" },
    { "rate" : """4.99""" },
    { "rate" : """4.98999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.15""" },
    { "rate" : """8.8""" },
    { "rate" : """23.58""" },
    { "rate" : """4.4999""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """5""" },
    { "rate" : """4.999""" },
    { "rate" : """16.17""" },
    { "rate" : """18.97999""" },
    { "rate" : """18.98""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """8""" },
    { "rate" : """8.64""" },
    { "rate" : """8.6""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """10.73""" },
    { "rate" : """5""" },
    { "rate" : """8.6399""" },
    { "rate" : """9.999""" },
    { "rate" : """4.88""" },
    { "rate" : """5""" },
    { "rate" : """8.64""" },
    { "rate" : """4.485""" },
    { "rate" : """4.995""" },
    { "rate" : """18.98""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """8.8""" },
    { "rate" : """8.64""" },
    { "rate" : """3.64""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """8.64""" },
    { "rate" : """12""" },
    { "rate" : """8.64""" },
    { "rate" : """12.46""" },
    { "rate" : """8.63""" },
    { "rate" : """8.64""" },
    { "rate" : """10.72""" },
    { "rate" : """8.64""" },
    { "rate" : """8.8""" },
    { "rate" : """3.64""" },
    { "rate" : """8.8""" },
    { "rate" : """3.64""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """4.5""" },
    { "rate" : """1.99999""" },
    { "rate" : """8.64""" },
    { "rate" : """5""" },
    { "rate" : """23.58""" },
    { "rate" : """8.63""" },
    { "rate" : """13.71999""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """12.25999""" },
    { "rate" : """9""" },
    { "rate" : """8.5""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.3""" },
    { "rate" : """0.29999""" },
    { "rate" : """12.46""" },
    { "rate" : """12.2""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.49899""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """12.4""" },
    { "rate" : """0.4999""" },
    { "rate" : """8.64""" },
    { "rate" : """12.46""" },
    { "rate" : """0.99998""" },
    { "rate" : """0.96""" },
    { "rate" : """8.4""" },
    { "rate" : """1.98""" },
    { "rate" : """4.98""" },
    { "rate" : """12.2""" },
    { "rate" : """8.6399""" },
    { "rate" : """4.99""" },
    { "rate" : """0.49""" },
    { "rate" : """0.48""" },
    { "rate" : """13.72""" },
    { "rate" : """0.498""" },
    { "rate" : """13.7""" },
    { "rate" : """0.499""" },
    { "rate" : """12.46""" },
    { "rate" : """1.99""" },
    { "rate" : """4.99999""" },
    { "rate" : """9.9999""" },
    { "rate" : """18.49""" },
    { "rate" : """12.46""" },
    { "rate" : """8.64""" },
    { "rate" : """8""" },
    { "rate" : """0.5""" },
    { "rate" : """23.58""" },
    { "rate" : """16.17""" },
    { "rate" : """12.46""" },
    { "rate" : """3.64""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """16.17""" },
    { "rate" : """3.64""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """0.5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """0.499""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """0.4706""" },
    { "rate" : """8.6""" },
    { "rate" : """0.5""" },
    { "rate" : """8.64""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """2""" },
    { "rate" : """4.99""" },
    { "rate" : """4.98999""" },
    { "rate" : """0.5""" },
    { "rate" : """23.56""" },
    { "rate" : """5""" },
    { "rate" : """8.64""" },
    { "rate" : """18.98""" },
    { "rate" : """5""" },
    { "rate" : """1.99""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """8.64""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """9""" },
    { "rate" : """3.64""" },
    { "rate" : """0.29998""" },
    { "rate" : """0.5""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """3.64""" },
    { "rate" : """12.46""" },
    { "rate" : """7.9""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """0.479""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """23.58""" },
    { "rate" : """12.46""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """3""" },
    { "rate" : """12.46""" },
    { "rate" : """4.975""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """0.5""" },
    { "rate" : """3.64""" },
    { "rate" : """12.25""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """23.58""" },
    { "rate" : """8.8""" },
    { "rate" : """12.4""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """12.46""" },
    { "rate" : """0.49999""" },
    { "rate" : """12.46""" },
    { "rate" : """12.45""" },
    { "rate" : """5""" },
    { "rate" : """0.78998""" },
    { "rate" : """0.8""" },
    { "rate" : """0.95""" },
    { "rate" : """0.5""" },
    { "rate" : """0.8""" },
    { "rate" : """12.46""" },
    { "rate" : """0.35""" },
    { "rate" : """0.8""" },
    { "rate" : """0.79999""" },
    { "rate" : """23.58""" },
    { "rate" : """0.79""" },
    { "rate" : """0.89""" },
    { "rate" : """3.49999""" },
    { "rate" : """3.49998""" },
    { "rate" : """3.49""" },
    { "rate" : """3.48998""" },
    { "rate" : """0.80999""" },
    { "rate" : """12.5""" },
    { "rate" : """12.49""" },
    { "rate" : """3.48""" },
    { "rate" : """3.49""" },
    { "rate" : """0.5""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """4.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.96""" },
    { "rate" : """3.5""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """10.17""" },
    { "rate" : """4""" },
    { "rate" : """3.49999""" },
    { "rate" : """18.98""" },
    { "rate" : """0.5""" },
    { "rate" : """3.4999""" },
    { "rate" : """8""" },
    { "rate" : """0.3""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """12.4599""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """18""" },
    { "rate" : """4.99998""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.63999""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """0.4987""" },
    { "rate" : """7.8""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """3.64""" },
    { "rate" : """6.55""" },
    { "rate" : """6.54999""" },
    { "rate" : """3.64""" },
    { "rate" : """12.46""" },
    { "rate" : """6.54999""" },
    { "rate" : """4.99996""" },
    { "rate" : """1""" },
    { "rate" : """3.64""" },
    { "rate" : """6.75""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """3.49999""" },
    { "rate" : """10""" },
    { "rate" : """3.49""" },
    { "rate" : """0.49999""" },
    { "rate" : """6.55""" },
    { "rate" : """2""" },
    { "rate" : """6.75""" },
    { "rate" : """6.5""" },
    { "rate" : """3.64""" },
    { "rate" : """0.5""" },
    { "rate" : """7.5""" },
    { "rate" : """6.74999""" },
    { "rate" : """3.64""" },
    { "rate" : """5""" },
    { "rate" : """4.1""" },
    { "rate" : """1.9""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """6.55""" },
    { "rate" : """3.63""" },
    { "rate" : """10.73""" },
    { "rate" : """1.12""" },
    { "rate" : """6.75""" },
    { "rate" : """6.55""" },
    { "rate" : """13.68""" },
    { "rate" : """23.48""" },
    { "rate" : """16.17""" },
    { "rate" : """7.499""" },
    { "rate" : """7""" },
    { "rate" : """6.75""" },
    { "rate" : """6.75""" },
    { "rate" : """5""" },
    { "rate" : """3.48""" },
    { "rate" : """8.8""" },
    { "rate" : """13.72""" },
    { "rate" : """8""" },
    { "rate" : """1.8""" },
    { "rate" : """13.7""" },
    { "rate" : """8""" },
    { "rate" : """18.98""" },
    { "rate" : """1.9995""" },
    { "rate" : """6.54""" },
    { "rate" : """6.75""" },
    { "rate" : """6.74""" },
    { "rate" : """3.64""" },
    { "rate" : """13.7""" },
    { "rate" : """4.99""" },
    { "rate" : """6.75""" },
    { "rate" : """10.73""" },
    { "rate" : """6.75""" },
    { "rate" : """12.46""" },
    { "rate" : """10.9""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.48999""" },
    { "rate" : """0.5""" },
    { "rate" : """11.99999""" },
    { "rate" : """6.74999""" },
    { "rate" : """3.64""" },
    { "rate" : """6.55""" },
    { "rate" : """8.8""" },
    { "rate" : """6.55""" },
    { "rate" : """0.5""" },
    { "rate" : """13.72""" },
    { "rate" : """3.64""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """4.98""" },
    { "rate" : """5.2""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """0.49888""" },
    { "rate" : """9.99""" },
    { "rate" : """9.98999""" },
    { "rate" : """7.98""" },
    { "rate" : """9.99""" },
    { "rate" : """6.75""" },
    { "rate" : """0.01""" },
    { "rate" : """9.8""" },
    { "rate" : """3.64""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """23.58""" },
    { "rate" : """23.56""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """3.64""" },
    { "rate" : """13.72""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """1.12""" },
    { "rate" : """6.25""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """6.75""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """0.7""" },
    { "rate" : """5""" },
    { "rate" : """7.8""" },
    { "rate" : """0.5""" },
    { "rate" : """6.5""" },
    { "rate" : """6.55""" },
    { "rate" : """3.64""" },
    { "rate" : """10.73""" },
    { "rate" : """0.7""" },
    { "rate" : """6.5""" },
    { "rate" : """1""" },
    { "rate" : """6.75""" },
    { "rate" : """4.99""" },
    { "rate" : """4""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """3.64""" },
    { "rate" : """3.5""" },
    { "rate" : """18.98""" },
    { "rate" : """19.99999""" },
    { "rate" : """13.09""" },
    { "rate" : """18.97999""" },
    { "rate" : """16.17""" },
    { "rate" : """4""" },
    { "rate" : """12.5""" },
    { "rate" : """3.64""" },
    { "rate" : """8""" },
    { "rate" : """12.46""" },
    { "rate" : """10.73""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """13.1""" },
    { "rate" : """4.5""" },
    { "rate" : """6.75""" },
    { "rate" : """8""" },
    { "rate" : """6.75""" },
    { "rate" : """18""" },
    { "rate" : """5""" },
    { "rate" : """5.5""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """0.45""" },
    { "rate" : """11.5""" },
    { "rate" : """12""" },
    { "rate" : """19""" },
    { "rate" : """5""" },
    { "rate" : """16.17""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """22""" },
    { "rate" : """22""" },
    { "rate" : """11.9""" },
    { "rate" : """0.5""" },
    { "rate" : """12.26""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """0.1""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """13.72""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2.49""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """23.58""" },
    { "rate" : """2.49""" },
    { "rate" : """2.48999""" },
    { "rate" : """10.73""" },
    { "rate" : """10""" },
    { "rate" : """3.64""" },
    { "rate" : """20""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2.45""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """10""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """2""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """13.11""" },
    { "rate" : """6.74998""" },
    { "rate" : """6.74""" },
    { "rate" : """7.9""" },
    { "rate" : """2.49999""" },
    { "rate" : """2.5""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """17.48""" },
    { "rate" : """2.5""" },
    { "rate" : """12.46""" },
    { "rate" : """23.58""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """13.9""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """12.46""" },
    { "rate" : """12""" },
    { "rate" : """18.98""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """1.12""" },
    { "rate" : """5.1""" },
    { "rate" : """5""" },
    { "rate" : """13.7""" },
    { "rate" : """7.75""" },
    { "rate" : """6.55""" },
    { "rate" : """18.98""" },
    { "rate" : """5""" },
    { "rate" : """4.98""" },
    { "rate" : """2.48""" },
    { "rate" : """4.98""" },
    { "rate" : """5""" },
    { "rate" : """7.99""" },
    { "rate" : """8.5""" },
    { "rate" : """17.48""" },
    { "rate" : """7.5""" },
    { "rate" : """8""" },
    { "rate" : """12.4""" },
    { "rate" : """4.97""" },
    { "rate" : """4.92""" },
    { "rate" : """10.73""" },
    { "rate" : """17.5""" },
    { "rate" : """3.64""" },
    { "rate" : """23.58""" },
    { "rate" : """5.5""" },
    { "rate" : """0.96""" },
    { "rate" : """4.99""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """6.5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """7.99999""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """12""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """7.98""" },
    { "rate" : """6""" },
    { "rate" : """16.17""" },
    { "rate" : """7.73""" },
    { "rate" : """12.46""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """8.9""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """4.9""" },
    { "rate" : """8.8""" },
    { "rate" : """6.99999""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """3.64""" },
    { "rate" : """6.99999""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """4.99999""" },
    { "rate" : """12.45""" },
    { "rate" : """7.99999""" },
    { "rate" : """6.74999""" },
    { "rate" : """7.76999""" },
    { "rate" : """4.9999""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """6.99999""" },
    { "rate" : """3.64""" },
    { "rate" : """12.46""" },
    { "rate" : """10.73""" },
    { "rate" : """8.8""" },
    { "rate" : """3.64""" },
    { "rate" : """4.8""" },
    { "rate" : """11.5""" },
    { "rate" : """8""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """0.4999""" },
    { "rate" : """0.49989""" },
    { "rate" : """0.49989""" },
    { "rate" : """0.49899""" },
    { "rate" : """12.46""" },
    { "rate" : """0.4999""" },
    { "rate" : """7.9898""" },
    { "rate" : """6.74""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """12.99""" },
    { "rate" : """7""" },
    { "rate" : """7.98""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """12.4""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """10.7""" },
    { "rate" : """12.4""" },
    { "rate" : """4.9""" },
    { "rate" : """8.75""" },
    { "rate" : """16.17""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """6.75""" },
    { "rate" : """13""" },
    { "rate" : """6.9999""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """13.11""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """12.45888""" },
    { "rate" : """8.79888""" },
    { "rate" : """10.72888""" },
    { "rate" : """12.45888""" },
    { "rate" : """6.75""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """6.75""" },
    { "rate" : """19.98777""" },
    { "rate" : """6.9""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6.99888""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """7""" },
    { "rate" : """13.72""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """13.71""" },
    { "rate" : """13.65""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """4.99""" },
    { "rate" : """4.99""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """6.54999""" },
    { "rate" : """13.719""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """5.95""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6.55""" },
    { "rate" : """9.999""" },
    { "rate" : """6.54""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """12.1999""" },
    { "rate" : """3.64""" },
    { "rate" : """6.55""" },
    { "rate" : """6""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """4.2""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """10.73""" },
    { "rate" : """7.23""" },
    { "rate" : """10.73""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """6.54""" },
    { "rate" : """6.89998""" },
    { "rate" : """4.8""" },
    { "rate" : """6.55""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """6.9999""" },
    { "rate" : """6.9""" },
    { "rate" : """8""" },
    { "rate" : """4.5""" },
    { "rate" : """6.9""" },
    { "rate" : """7.5""" },
    { "rate" : """7.25""" },
    { "rate" : """6.5""" },
    { "rate" : """6.999""" },
    { "rate" : """4.98""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """6.99999""" },
    { "rate" : """0.001""" },
    { "rate" : """5""" },
    { "rate" : """10.73""" },
    { "rate" : """0.001""" },
    { "rate" : """23.57""" },
    { "rate" : """7.7""" },
    { "rate" : """6.55""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """4""" },
    { "rate" : """13.11""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """10.73""" },
    { "rate" : """6.8""" },
    { "rate" : """8""" },
    { "rate" : """3.64""" },
    { "rate" : """18.98""" },
    { "rate" : """7""" },
    { "rate" : """10.73""" },
    { "rate" : """23.55""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """7.98""" },
    { "rate" : """7""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """11.99""" },
    { "rate" : """7""" },
    { "rate" : """12.46""" },
    { "rate" : """6.3""" },
    { "rate" : """11.98""" },
    { "rate" : """6.5""" },
    { "rate" : """16.17""" },
    { "rate" : """13.11""" },
    { "rate" : """23.58""" },
    { "rate" : """6.975""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """6.99888""" },
    { "rate" : """4.99""" },
    { "rate" : """12.46""" },
    { "rate" : """7.99888""" },
    { "rate" : """3.64""" },
    { "rate" : """16.17""" },
    { "rate" : """0.4706""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """22.99""" },
    { "rate" : """23.58""" },
    { "rate" : """12""" },
    { "rate" : """16.17""" },
    { "rate" : """5""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """12.46""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """6.4""" },
    { "rate" : """6.9999""" },
    { "rate" : """3.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """16.17""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """6.45""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """12.46""" },
    { "rate" : """7""" },
    { "rate" : """12.46""" },
    { "rate" : """4.99""" },
    { "rate" : """23""" },
    { "rate" : """8""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """12""" },
    { "rate" : """7.99""" },
    { "rate" : """12.4""" },
    { "rate" : """8""" },
    { "rate" : """7.98999""" },
    { "rate" : """23.58""" },
    { "rate" : """18.73""" },
    { "rate" : """5""" },
    { "rate" : """6.9""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """23.58""" },
    { "rate" : """6.5""" },
    { "rate" : """23.58""" },
    { "rate" : """23.5""" },
    { "rate" : """4.1""" },
    { "rate" : """8""" },
    { "rate" : """7.5""" },
    { "rate" : """2""" },
    { "rate" : """16.17""" },
    { "rate" : """8""" },
    { "rate" : """16.17""" },
    { "rate" : """5""" },
    { "rate" : """7.9""" },
    { "rate" : """5""" },
    { "rate" : """7.99999""" },
    { "rate" : """3.64""" },
    { "rate" : """4.9""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.63999""" },
    { "rate" : """3.64""" },
    { "rate" : """3.63""" },
    { "rate" : """2.5""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.63""" },
    { "rate" : """3.63""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """20""" },
    { "rate" : """6.99""" },
    { "rate" : """5""" },
    { "rate" : """3.6""" },
    { "rate" : """7.9""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """3.5""" },
    { "rate" : """3.99""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """20.45""" },
    { "rate" : """20.45""" },
    { "rate" : """20.45""" },
    { "rate" : """20.45""" },
    { "rate" : """20.45""" },
    { "rate" : """20.45""" },
    { "rate" : """20.45""" },
    { "rate" : """20.45""" },
    { "rate" : """20.45""" },
    { "rate" : """20.45""" },
    { "rate" : """8""" },
    { "rate" : """3.4""" },
    { "rate" : """3.64""" },
    { "rate" : """6""" },
    { "rate" : """7.99""" },
    { "rate" : """20.44999""" },
    { "rate" : """2.9""" },
    { "rate" : """6.55""" },
    { "rate" : """3.64""" },
    { "rate" : """4""" },
    { "rate" : """13.11""" },
    { "rate" : """3.64""" },
    { "rate" : """3.63799""" },
    { "rate" : """4.98""" },
    { "rate" : """7.239""" },
    { "rate" : """7""" },
    { "rate" : """3.6""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """4.99999""" },
    { "rate" : """8.5""" },
    { "rate" : """7.99999""" },
    { "rate" : """3.64""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """3.5""" },
    { "rate" : """8""" },
    { "rate" : """3.64""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """20.45""" },
    { "rate" : """9.99999""" },
    { "rate" : """13.11""" },
    { "rate" : """3.64""" },
    { "rate" : """23.58""" },
    { "rate" : """8""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """11.98""" },
    { "rate" : """12""" },
    { "rate" : """20.45""" },
    { "rate" : """9.99998""" },
    { "rate" : """3.64""" },
    { "rate" : """8""" },
    { "rate" : """5.99999""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """5.2""" },
    { "rate" : """4.15""" },
    { "rate" : """4.93""" },
    { "rate" : """18.7""" },
    { "rate" : """7.875""" },
    { "rate" : """22.1""" },
    { "rate" : """11.5""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """13.72""" },
    { "rate" : """7.8""" },
    { "rate" : """3.64""" },
    { "rate" : """9.89999""" },
    { "rate" : """3.64""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """8""" },
    { "rate" : """12.45999""" },
    { "rate" : """3.6""" },
    { "rate" : """8""" },
    { "rate" : """6.45""" },
    { "rate" : """13""" },
    { "rate" : """3.64""" },
    { "rate" : """7.89""" },
    { "rate" : """12.46""" },
    { "rate" : """7.9""" },
    { "rate" : """3.64""" },
    { "rate" : """8""" },
    { "rate" : """13.11""" },
    { "rate" : """12.46""" },
    { "rate" : """3.64""" },
    { "rate" : """6.55""" },
    { "rate" : """3.64""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """3.64""" },
    { "rate" : """16.17""" },
    { "rate" : """16.1699""" },
    { "rate" : """13""" },
    { "rate" : """13.72""" },
    { "rate" : """16.16989""" },
    { "rate" : """7.9999""" },
    { "rate" : """10""" },
    { "rate" : """13.1099""" },
    { "rate" : """3.64""" },
    { "rate" : """4.985""" },
    { "rate" : """5""" },
    { "rate" : """23""" },
    { "rate" : """7""" },
    { "rate" : """8.46""" },
    { "rate" : """3.64""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """3.64""" },
    { "rate" : """7""" },
    { "rate" : """23.58""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """3.639""" },
    { "rate" : """23.57""" },
    { "rate" : """23.56""" },
    { "rate" : """6.99""" },
    { "rate" : """5.987""" },
    { "rate" : """23.56999""" },
    { "rate" : """15""" },
    { "rate" : """14.8""" },
    { "rate" : """3.59""" },
    { "rate" : """5""" },
    { "rate" : """6.64""" },
    { "rate" : """4.94""" },
    { "rate" : """7.87""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """16.1699""" },
    { "rate" : """12.42""" },
    { "rate" : """23""" },
    { "rate" : """12""" },
    { "rate" : """12.46""" },
    { "rate" : """3.64""" },
    { "rate" : """23.58""" },
    { "rate" : """9.99999""" },
    { "rate" : """16""" },
    { "rate" : """3""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """3.5""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """11.99""" },
    { "rate" : """9""" },
    { "rate" : """15.99999""" },
    { "rate" : """7.99""" },
    { "rate" : """8.8""" },
    { "rate" : """8.79999""" },
    { "rate" : """3.64""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """4.99999""" },
    { "rate" : """3""" },
    { "rate" : """13.72""" },
    { "rate" : """3.64""" },
    { "rate" : """3.63999""" },
    { "rate" : """13.1""" },
    { "rate" : """6.55""" },
    { "rate" : """4.9999""" },
    { "rate" : """3.19999""" },
    { "rate" : """3.199""" },
    { "rate" : """3.2""" },
    { "rate" : """15.14""" },
    { "rate" : """3.19999""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """4.99899""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """3.64""" },
    { "rate" : """0.3""" },
    { "rate" : """7.999""" },
    { "rate" : """15""" },
    { "rate" : """23""" },
    { "rate" : """23.57""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """1.12""" },
    { "rate" : """3.6""" },
    { "rate" : """13""" },
    { "rate" : """12.46""" },
    { "rate" : """23""" },
    { "rate" : """6.55""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """11.9""" },
    { "rate" : """7""" },
    { "rate" : """23.57""" },
    { "rate" : """8.79""" },
    { "rate" : """19.5""" },
    { "rate" : """3.63888""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """8""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99998""" },
    { "rate" : """0.987""" },
    { "rate" : """1""" },
    { "rate" : """0.98699""" },
    { "rate" : """5""" },
    { "rate" : """0.95""" },
    { "rate" : """0.99999""" },
    { "rate" : """23""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """8""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """13.11""" },
    { "rate" : """3.64""" },
    { "rate" : """0.98""" },
    { "rate" : """12""" },
    { "rate" : """5.4""" },
    { "rate" : """1""" },
    { "rate" : """19""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """6.54999""" },
    { "rate" : """0.99899""" },
    { "rate" : """0.8""" },
    { "rate" : """1""" },
    { "rate" : """23.5""" },
    { "rate" : """0.99989""" },
    { "rate" : """0.9959""" },
    { "rate" : """0.29998""" },
    { "rate" : """3.64""" },
    { "rate" : """12.45""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """0.99""" },
    { "rate" : """1.12""" },
    { "rate" : """0.97""" },
    { "rate" : """13.11""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """3.64""" },
    { "rate" : """0.99""" },
    { "rate" : """12.2""" },
    { "rate" : """1.12""" },
    { "rate" : """23.58""" },
    { "rate" : """13.71999""" },
    { "rate" : """4""" },
    { "rate" : """3.6""" },
    { "rate" : """0.989""" },
    { "rate" : """13.72""" },
    { "rate" : """11.72""" },
    { "rate" : """13.11""" },
    { "rate" : """12.46""" },
    { "rate" : """13.72""" },
    { "rate" : """0.95""" },
    { "rate" : """6""" },
    { "rate" : """0.96""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.999""" },
    { "rate" : """12.46""" },
    { "rate" : """3.64""" },
    { "rate" : """13.72""" },
    { "rate" : """0.9999""" },
    { "rate" : """3.64""" },
    { "rate" : """1""" },
    { "rate" : """0.29""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """13.72""" },
    { "rate" : """1""" },
    { "rate" : """3.64""" },
    { "rate" : """0.99997""" },
    { "rate" : """13.72""" },
    { "rate" : """0.99999""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """9.9""" },
    { "rate" : """3.64""" },
    { "rate" : """1""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """6.55""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """1""" },
    { "rate" : """0.94""" },
    { "rate" : """1""" },
    { "rate" : """4.9""" },
    { "rate" : """3.64""" },
    { "rate" : """0.89999""" },
    { "rate" : """3.64""" },
    { "rate" : """13.72""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """11.9""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """12.9""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.9""" },
    { "rate" : """8.45""" },
    { "rate" : """0.91""" },
    { "rate" : """3.64""" },
    { "rate" : """0.9""" },
    { "rate" : """13.72""" },
    { "rate" : """0.8""" },
    { "rate" : """11""" },
    { "rate" : """8.5""" },
    { "rate" : """0.9""" },
    { "rate" : """4.5""" },
    { "rate" : """12.4199""" },
    { "rate" : """12""" },
    { "rate" : """3.5""" },
    { "rate" : """0.89""" },
    { "rate" : """4.48998""" },
    { "rate" : """0.989""" },
    { "rate" : """0.98998""" },
    { "rate" : """0.86998""" },
    { "rate" : """0.94""" },
    { "rate" : """0.94""" },
    { "rate" : """1.5""" },
    { "rate" : """3.64""" },
    { "rate" : """0.46667""" },
    { "rate" : """11""" },
    { "rate" : """8.5""" },
    { "rate" : """3.64""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """13.72""" },
    { "rate" : """9.99""" },
    { "rate" : """7.9999""" },
    { "rate" : """3.64""" },
    { "rate" : """10""" },
    { "rate" : """0.95""" },
    { "rate" : """0.99""" },
    { "rate" : """13.11""" },
    { "rate" : """9""" },
    { "rate" : """1.12""" },
    { "rate" : """0.9""" },
    { "rate" : """13.72""" },
    { "rate" : """13.11""" },
    { "rate" : """1.2""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """0.79999""" },
    { "rate" : """1.5""" },
    { "rate" : """1.12""" },
    { "rate" : """3.63999""" },
    { "rate" : """13.72""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """3.64""" },
    { "rate" : """0.4706""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """8""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """6.48998""" },
    { "rate" : """13.71""" },
    { "rate" : """8""" },
    { "rate" : """3.63999""" },
    { "rate" : """3.64""" },
    { "rate" : """7.5""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """0.888""" },
    { "rate" : """12.98997""" },
    { "rate" : """12""" },
    { "rate" : """13.11""" },
    { "rate" : """0.89996""" },
    { "rate" : """3.64""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """13.72""" },
    { "rate" : """7.833""" },
    { "rate" : """3.64""" },
    { "rate" : """13.11""" },
    { "rate" : """3.64""" },
    { "rate" : """8""" },
    { "rate" : """3.64""" },
    { "rate" : """0.87""" },
    { "rate" : """3.62""" },
    { "rate" : """3.64""" },
    { "rate" : """25""" },
    { "rate" : """6.14""" },
    { "rate" : """8""" },
    { "rate" : """13.11""" },
    { "rate" : """12.9""" },
    { "rate" : """0.88989""" },
    { "rate" : """0.9""" },
    { "rate" : """4.2""" },
    { "rate" : """0.89999""" },
    { "rate" : """0.88999""" },
    { "rate" : """13.71999""" },
    { "rate" : """11.7""" },
    { "rate" : """0.4706""" },
    { "rate" : """6.9999""" },
    { "rate" : """3.5""" },
    { "rate" : """10.9""" },
    { "rate" : """0.89999""" },
    { "rate" : """0.96""" },
    { "rate" : """3.64""" },
    { "rate" : """8""" },
    { "rate" : """13.11""" },
    { "rate" : """0.8""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """18.98""" },
    { "rate" : """13.72""" },
    { "rate" : """13.1""" },
    { "rate" : """13.72""" },
    { "rate" : """0.899""" },
    { "rate" : """3.63""" },
    { "rate" : """3.64""" },
    { "rate" : """7.99""" },
    { "rate" : """5""" },
    { "rate" : """0.96""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """13.11""" },
    { "rate" : """6.55""" },
    { "rate" : """13.1099""" },
    { "rate" : """6.98""" },
    { "rate" : """13.08""" },
    { "rate" : """13.72""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """6.55""" },
    { "rate" : """13.11""" },
    { "rate" : """9""" },
    { "rate" : """13""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """13.11""" },
    { "rate" : """6.55""" },
    { "rate" : """4.5""" },
    { "rate" : """12.46""" },
    { "rate" : """11.9""" },
    { "rate" : """13.72""" },
    { "rate" : """9""" },
    { "rate" : """0.4706""" },
    { "rate" : """18.98""" },
    { "rate" : """13.10999""" },
    { "rate" : """9""" },
    { "rate" : """8.99999""" },
    { "rate" : """6.55""" },
    { "rate" : """8.99999""" },
    { "rate" : """13.72""" },
    { "rate" : """11.2""" },
    { "rate" : """13.72""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """12.25999""" },
    { "rate" : """18.9""" },
    { "rate" : """3.64""" },
    { "rate" : """7.99""" },
    { "rate" : """8.99""" },
    { "rate" : """13.71999""" },
    { "rate" : """13.11""" },
    { "rate" : """4.97""" },
    { "rate" : """11.67""" },
    { "rate" : """7.99""" },
    { "rate" : """13.7""" },
    { "rate" : """7.9""" },
    { "rate" : """8""" },
    { "rate" : """6.55""" },
    { "rate" : """12""" },
    { "rate" : """13.72""" },
    { "rate" : """8.01""" },
    { "rate" : """23.58""" },
    { "rate" : """13.11""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """13.72""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6.55""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """13.11""" },
    { "rate" : """13.72""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """13.11""" },
    { "rate" : """7.5""" },
    { "rate" : """13.72""" },
    { "rate" : """9""" },
    { "rate" : """13.72""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """12""" },
    { "rate" : """13.11""" },
    { "rate" : """13.1067""" },
    { "rate" : """11.99999""" },
    { "rate" : """10.5""" },
    { "rate" : """13.72""" },
    { "rate" : """9""" },
    { "rate" : """16.17""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """0.8""" },
    { "rate" : """1""" },
    { "rate" : """0.79""" },
    { "rate" : """13.72""" },
    { "rate" : """12.2""" },
    { "rate" : """9.99999""" },
    { "rate" : """13""" },
    { "rate" : """0.4""" },
    { "rate" : """0.48""" },
    { "rate" : """12""" },
    { "rate" : """0.5""" },
    { "rate" : """0.39999""" },
    { "rate" : """0.49999""" },
    { "rate" : """7.5""" },
    { "rate" : """8.7""" },
    { "rate" : """20""" },
    { "rate" : """0.48""" },
    { "rate" : """0.4""" },
    { "rate" : """0.49998""" },
    { "rate" : """0.49998""" },
    { "rate" : """0.48""" },
    { "rate" : """0.499""" },
    { "rate" : """13.11""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """8.99""" },
    { "rate" : """7.99999""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """7.99""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """0.48218""" },
    { "rate" : """13.5""" },
    { "rate" : """0.49""" },
    { "rate" : """0.48999""" },
    { "rate" : """0.45998""" },
    { "rate" : """8.99998""" },
    { "rate" : """6.55""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """13.72""" },
    { "rate" : """7""" },
    { "rate" : """12.99999""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """12.2598""" },
    { "rate" : """8.5""" },
    { "rate" : """13.71""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """13.72""" },
    { "rate" : """9""" },
    { "rate" : """13.72""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """8.95""" },
    { "rate" : """8.95""" },
    { "rate" : """12""" },
    { "rate" : """13""" },
    { "rate" : """4.95""" },
    { "rate" : """4.95""" },
    { "rate" : """7.99""" },
    { "rate" : """7.979""" },
    { "rate" : """12.89""" },
    { "rate" : """12""" },
    { "rate" : """8.99999""" },
    { "rate" : """13.71""" },
    { "rate" : """13.109""" },
    { "rate" : """7.999""" },
    { "rate" : """4.98""" },
    { "rate" : """9.9""" },
    { "rate" : """6.999""" },
    { "rate" : """17.9""" },
    { "rate" : """8.9""" },
    { "rate" : """8""" },
    { "rate" : """13.719""" },
    { "rate" : """13""" },
    { "rate" : """6.55""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """13.72""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """7.9999""" },
    { "rate" : """6.55""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """8.99""" },
    { "rate" : """7.5""" },
    { "rate" : """12""" },
    { "rate" : """6.5""" },
    { "rate" : """7.6""" },
    { "rate" : """13.72""" },
    { "rate" : """4.99""" },
    { "rate" : """13""" },
    { "rate" : """13.7""" },
    { "rate" : """0.46667""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """7.5""" },
    { "rate" : """13.11""" },
    { "rate" : """13.72""" },
    { "rate" : """13.11""" },
    { "rate" : """13.72""" },
    { "rate" : """13.11""" },
    { "rate" : """7.8""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """7.99""" },
    { "rate" : """7.99""" },
    { "rate" : """12.8""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """8.84""" },
    { "rate" : """13.88""" },
    { "rate" : """7.99""" },
    { "rate" : """8.8""" },
    { "rate" : """13.72""" },
    { "rate" : """13.11""" },
    { "rate" : """15""" },
    { "rate" : """5.9""" },
    { "rate" : """5.9""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5.89999""" },
    { "rate" : """6""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """6""" },
    { "rate" : """2.49999""" },
    { "rate" : """5.97""" },
    { "rate" : """5.75""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """5.88""" },
    { "rate" : """6.55""" },
    { "rate" : """13.72""" },
    { "rate" : """2.5""" },
    { "rate" : """2.492""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.11""" },
    { "rate" : """5.8""" },
    { "rate" : """5.99999""" },
    { "rate" : """5.9""" },
    { "rate" : """5.9999""" },
    { "rate" : """13.72""" },
    { "rate" : """2.49999""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """5.98""" },
    { "rate" : """5.89""" },
    { "rate" : """2.48""" },
    { "rate" : """5.75999""" },
    { "rate" : """13.72""" },
    { "rate" : """13""" },
    { "rate" : """8.999""" },
    { "rate" : """2.42972""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.11""" },
    { "rate" : """13.71999""" },
    { "rate" : """2.5""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """12.45""" },
    { "rate" : """2.49""" },
    { "rate" : """13.11""" },
    { "rate" : """13.71""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """2.49999""" },
    { "rate" : """0.96""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.13""" },
    { "rate" : """13.72""" },
    { "rate" : """2.48""" },
    { "rate" : """13.72""" },
    { "rate" : """2""" },
    { "rate" : """13.72""" },
    { "rate" : """13.5""" },
    { "rate" : """1""" },
    { "rate" : """2.5""" },
    { "rate" : """6""" },
    { "rate" : """13""" },
    { "rate" : """9.99999""" },
    { "rate" : """2.45""" },
    { "rate" : """13.1""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """13.11""" },
    { "rate" : """2""" },
    { "rate" : """2.5""" },
    { "rate" : """6""" },
    { "rate" : """6.55""" },
    { "rate" : """13.72""" },
    { "rate" : """9""" },
    { "rate" : """0.96""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """0.09998""" },
    { "rate" : """6.9""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """7""" },
    { "rate" : """13.72""" },
    { "rate" : """6.85""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """6.9""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """6.54999""" },
    { "rate" : """6.55""" },
    { "rate" : """13.7199""" },
    { "rate" : """13.72""" },
    { "rate" : """11""" },
    { "rate" : """6.55""" },
    { "rate" : """6""" },
    { "rate" : """6.55""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """0.98835""" },
    { "rate" : """1""" },
    { "rate" : """0.8""" },
    { "rate" : """0.98835""" },
    { "rate" : """0.79999""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """4.9""" },
    { "rate" : """6.99999""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """13.11""" },
    { "rate" : """13.72""" },
    { "rate" : """2""" },
    { "rate" : """13""" },
    { "rate" : """12""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """3""" },
    { "rate" : """4.99933""" },
    { "rate" : """5""" },
    { "rate" : """2.99999""" },
    { "rate" : """7""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """4.99999""" },
    { "rate" : """13.11""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """13.5""" },
    { "rate" : """4.99""" },
    { "rate" : """0.4706""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """13.1""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """0.1999""" },
    { "rate" : """0.96""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.72""" },
    { "rate" : """9""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """13.49""" },
    { "rate" : """7""" },
    { "rate" : """13.11""" },
    { "rate" : """8""" },
    { "rate" : """4""" },
    { "rate" : """9.99999""" },
    { "rate" : """13.11""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """13.11""" },
    { "rate" : """8.8""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """4.99""" },
    { "rate" : """0.19999""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """14.99999""" },
    { "rate" : """16""" },
    { "rate" : """15.99""" },
    { "rate" : """15.99""" },
    { "rate" : """13.72""" },
    { "rate" : """16""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """13.72""" },
    { "rate" : """16""" },
    { "rate" : """4.9""" },
    { "rate" : """3.64""" },
    { "rate" : """15""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """9""" },
    { "rate" : """13.11""" },
    { "rate" : """8.99999""" },
    { "rate" : """9.5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """9.9""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """9.83875""" },
    { "rate" : """15.26799""" },
    { "rate" : """9.98""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """6.999""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """15.9""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.8""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """6""" },
    { "rate" : """9.9999""" },
    { "rate" : """3.64""" },
    { "rate" : """10""" },
    { "rate" : """4.98""" },
    { "rate" : """5""" },
    { "rate" : """9.9999""" },
    { "rate" : """9""" },
    { "rate" : """9.89999""" },
    { "rate" : """9.9""" },
    { "rate" : """15.72""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """9.5""" },
    { "rate" : """3.24""" },
    { "rate" : """13.72""" },
    { "rate" : """10.73""" },
    { "rate" : """3.64""" },
    { "rate" : """18.98""" },
    { "rate" : """9.98""" },
    { "rate" : """9.99999""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49826""" },
    { "rate" : """9""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49989""" },
    { "rate" : """0.49988""" },
    { "rate" : """0.49999""" },
    { "rate" : """13.11""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """0.4999""" },
    { "rate" : """3.24""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """13.999""" },
    { "rate" : """6""" },
    { "rate" : """3.64""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49989""" },
    { "rate" : """13.72""" },
    { "rate" : """9.9""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49""" },
    { "rate" : """0.45""" },
    { "rate" : """0.4999""" },
    { "rate" : """10""" },
    { "rate" : """3.24""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """3.64""" },
    { "rate" : """6.55""" },
    { "rate" : """9.9""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """15.99""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """0.48""" },
    { "rate" : """15.99""" },
    { "rate" : """12""" },
    { "rate" : """0.085""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """0.49""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """3.24""" },
    { "rate" : """7""" },
    { "rate" : """6.35""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """16""" },
    { "rate" : """10""" },
    { "rate" : """16""" },
    { "rate" : """0.48""" },
    { "rate" : """10""" },
    { "rate" : """10.73""" },
    { "rate" : """7.5""" },
    { "rate" : """0.49""" },
    { "rate" : """6.55""" },
    { "rate" : """16""" },
    { "rate" : """14.99""" },
    { "rate" : """13.11""" },
    { "rate" : """0.4987""" },
    { "rate" : """15.987""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """6.55""" },
    { "rate" : """15""" },
    { "rate" : """6.55""" },
    { "rate" : """7""" },
    { "rate" : """4.99996""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """13.11""" },
    { "rate" : """6""" },
    { "rate" : """13.7""" },
    { "rate" : """13.11""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """13.13""" },
    { "rate" : """13.13""" },
    { "rate" : """15.15""" },
    { "rate" : """16""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """16""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """6""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """15.99""" },
    { "rate" : """4.99999""" },
    { "rate" : """16""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """13.11""" },
    { "rate" : """16""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """0.4706""" },
    { "rate" : """15.4""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """3.64""" },
    { "rate" : """15.9""" },
    { "rate" : """12.6""" },
    { "rate" : """13""" },
    { "rate" : """13.71999""" },
    { "rate" : """6""" },
    { "rate" : """16.17""" },
    { "rate" : """4.9""" },
    { "rate" : """11.99""" },
    { "rate" : """2""" },
    { "rate" : """15.6""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """15.7""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """16.17""" },
    { "rate" : """0.18999""" },
    { "rate" : """9.99999""" },
    { "rate" : """4.8""" },
    { "rate" : """13.1099""" },
    { "rate" : """13.10989""" },
    { "rate" : """0.0002""" },
    { "rate" : """15.9""" },
    { "rate" : """11""" },
    { "rate" : """9.99""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """0.1""" },
    { "rate" : """13.11""" },
    { "rate" : """16""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """0.96""" },
    { "rate" : """6""" },
    { "rate" : """16.17""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """13.72""" },
    { "rate" : """4.5""" },
    { "rate" : """16.17""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """13.1""" },
    { "rate" : """9.99999""" },
    { "rate" : """1.5""" },
    { "rate" : """12""" },
    { "rate" : """5.99999""" },
    { "rate" : """9.99998""" },
    { "rate" : """13.72""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """7""" },
    { "rate" : """12.46""" },
    { "rate" : """12""" },
    { "rate" : """11.9""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12.46""" },
    { "rate" : """14.99999""" },
    { "rate" : """5.9999""" },
    { "rate" : """13.11""" },
    { "rate" : """12""" },
    { "rate" : """13""" },
    { "rate" : """12""" },
    { "rate" : """11""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """14""" },
    { "rate" : """9.95999""" },
    { "rate" : """12""" },
    { "rate" : """11.9999""" },
    { "rate" : """12""" },
    { "rate" : """11.9""" },
    { "rate" : """11.99""" },
    { "rate" : """11.8""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """13.7""" },
    { "rate" : """13.72""" },
    { "rate" : """4""" },
    { "rate" : """3.9""" },
    { "rate" : """16""" },
    { "rate" : """13.72""" },
    { "rate" : """3.99999""" },
    { "rate" : """4""" },
    { "rate" : """13.11""" },
    { "rate" : """11.98""" },
    { "rate" : """4.9""" },
    { "rate" : """11.9""" },
    { "rate" : """12.46""" },
    { "rate" : """9.96""" },
    { "rate" : """4""" },
    { "rate" : """4.9""" },
    { "rate" : """13.72""" },
    { "rate" : """13.11""" },
    { "rate" : """6.55""" },
    { "rate" : """13.11""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """4.9999""" },
    { "rate" : """13.72""" },
    { "rate" : """11.96""" },
    { "rate" : """4""" },
    { "rate" : """15.99""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """6""" },
    { "rate" : """4""" },
    { "rate" : """9.96""" },
    { "rate" : """12""" },
    { "rate" : """4.99""" },
    { "rate" : """5.99""" },
    { "rate" : """15.99""" },
    { "rate" : """13.71""" },
    { "rate" : """9.96""" },
    { "rate" : """12.46""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """11.98""" },
    { "rate" : """3.99999""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """13.72""" },
    { "rate" : """11.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7.77""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.96""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """12.46""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """8.99999""" },
    { "rate" : """14""" },
    { "rate" : """3.64""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """4""" },
    { "rate" : """3.64""" },
    { "rate" : """8.8""" },
    { "rate" : """9.95""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """3.5""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """6.55""" },
    { "rate" : """11.99""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """15""" },
    { "rate" : """12.46""" },
    { "rate" : """9.96""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """0.4706""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """3.64""" },
    { "rate" : """11.9""" },
    { "rate" : """5.99999""" },
    { "rate" : """12""" },
    { "rate" : """9.9""" },
    { "rate" : """6""" },
    { "rate" : """13""" },
    { "rate" : """14.99998""" },
    { "rate" : """4.999""" },
    { "rate" : """8.79999""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """12.46""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """9.999""" },
    { "rate" : """14""" },
    { "rate" : """12""" },
    { "rate" : """13.72""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """11""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """9.96""" },
    { "rate" : """13.11""" },
    { "rate" : """6.55""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """12.26""" },
    { "rate" : """13.11""" },
    { "rate" : """18.9799""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """14""" },
    { "rate" : """12.46""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """8.5""" },
    { "rate" : """12.45""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """5.9""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """11.99999""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """11.9""" },
    { "rate" : """4""" },
    { "rate" : """11""" },
    { "rate" : """3.99""" },
    { "rate" : """4.999""" },
    { "rate" : """3.7""" },
    { "rate" : """3.59""" },
    { "rate" : """12""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """14.97""" },
    { "rate" : """4.999""" },
    { "rate" : """11.11""" },
    { "rate" : """4.4""" },
    { "rate" : """12""" },
    { "rate" : """9.9""" },
    { "rate" : """3.3""" },
    { "rate" : """15.15""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """14.9999""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """14.99996""" },
    { "rate" : """12""" },
    { "rate" : """4.9998""" },
    { "rate" : """12.99""" },
    { "rate" : """6""" },
    { "rate" : """7.8""" },
    { "rate" : """14.99""" },
    { "rate" : """11.8""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """6.55""" },
    { "rate" : """13.71""" },
    { "rate" : """8.8""" },
    { "rate" : """12""" },
    { "rate" : """6.55""" },
    { "rate" : """9.9""" },
    { "rate" : """8.8""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """8.8""" },
    { "rate" : """11.5""" },
    { "rate" : """14.9""" },
    { "rate" : """11.5""" },
    { "rate" : """8.8""" },
    { "rate" : """12""" },
    { "rate" : """0.04999""" },
    { "rate" : """13.7""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """13.11""" },
    { "rate" : """13""" },
    { "rate" : """12""" },
    { "rate" : """3.64""" },
    { "rate" : """3.63""" },
    { "rate" : """13.72""" },
    { "rate" : """12.26""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """6.55""" },
    { "rate" : """9.9""" },
    { "rate" : """12""" },
    { "rate" : """3.64""" },
    { "rate" : """6""" },
    { "rate" : """16.17""" },
    { "rate" : """12.26""" },
    { "rate" : """4.4""" },
    { "rate" : """11.11""" },
    { "rate" : """6.55""" },
    { "rate" : """7""" },
    { "rate" : """16.16999""" },
    { "rate" : """4""" },
    { "rate" : """10.5""" },
    { "rate" : """5""" },
    { "rate" : """16.17""" },
    { "rate" : """8.8""" },
    { "rate" : """7.8""" },
    { "rate" : """14.99999""" },
    { "rate" : """8.8""" },
    { "rate" : """13.87""" },
    { "rate" : """3.64""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """3.64""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """13.72""" },
    { "rate" : """4.999""" },
    { "rate" : """16""" },
    { "rate" : """6.55""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """9.4999""" },
    { "rate" : """6.54995""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """12""" },
    { "rate" : """9""" },
    { "rate" : """16""" },
    { "rate" : """8.8""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """3.49999""" },
    { "rate" : """3.9""" },
    { "rate" : """9""" },
    { "rate" : """6.9""" },
    { "rate" : """9.96""" },
    { "rate" : """4""" },
    { "rate" : """3.9""" },
    { "rate" : """13.72""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """9.96""" },
    { "rate" : """2""" },
    { "rate" : """11.9""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """3.6399""" },
    { "rate" : """9.95""" },
    { "rate" : """4""" },
    { "rate" : """14.4999""" },
    { "rate" : """4""" },
    { "rate" : """8.1""" },
    { "rate" : """8.8""" },
    { "rate" : """9.1""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """12""" },
    { "rate" : """9.5""" },
    { "rate" : """9.5""" },
    { "rate" : """3.6""" },
    { "rate" : """16.17""" },
    { "rate" : """7""" },
    { "rate" : """6.55""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """12.5""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """9.9""" },
    { "rate" : """16.1""" },
    { "rate" : """12.26""" },
    { "rate" : """4""" },
    { "rate" : """6.55""" },
    { "rate" : """8.64""" },
    { "rate" : """9""" },
    { "rate" : """16.99""" },
    { "rate" : """13.1""" },
    { "rate" : """8.64""" },
    { "rate" : """4""" },
    { "rate" : """6.55""" },
    { "rate" : """3.99999""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """13.72""" },
    { "rate" : """13.11""" },
    { "rate" : """13""" },
    { "rate" : """8.8""" },
    { "rate" : """3.99999""" },
    { "rate" : """8.64""" },
    { "rate" : """16""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """8.64""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """7.5""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """15.99""" },
    { "rate" : """4""" },
    { "rate" : """9.98""" },
    { "rate" : """11.98""" },
    { "rate" : """14.98""" },
    { "rate" : """9.98""" },
    { "rate" : """9.98""" },
    { "rate" : """5.98""" },
    { "rate" : """6.53""" },
    { "rate" : """9.98""" },
    { "rate" : """13.7""" },
    { "rate" : """10""" },
    { "rate" : """6.55""" },
    { "rate" : """8.99""" },
    { "rate" : """13.11""" },
    { "rate" : """6.55""" },
    { "rate" : """9.99999""" },
    { "rate" : """12.46""" },
    { "rate" : """7.99998""" },
    { "rate" : """12.45""" },
    { "rate" : """12.46""" },
    { "rate" : """17.98""" },
    { "rate" : """12.44""" },
    { "rate" : """10.73""" },
    { "rate" : """12.4""" },
    { "rate" : """12.4599""" },
    { "rate" : """10""" },
    { "rate" : """8.64""" },
    { "rate" : """16.17""" },
    { "rate" : """6.55""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """6.55""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """6.55""" },
    { "rate" : """12.36""" },
    { "rate" : """16.17""" },
    { "rate" : """3.5""" },
    { "rate" : """11""" },
    { "rate" : """12.26""" },
    { "rate" : """9.5""" },
    { "rate" : """13.11""" },
    { "rate" : """9.5""" },
    { "rate" : """12.46""" },
    { "rate" : """16.17""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """16.17""" },
    { "rate" : """4""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """11.11""" },
    { "rate" : """6.55""" },
    { "rate" : """9.99999""" },
    { "rate" : """9""" },
    { "rate" : """6.55""" },
    { "rate" : """8.64""" },
    { "rate" : """8.8""" },
    { "rate" : """8.64""" },
    { "rate" : """6.55""" },
    { "rate" : """8""" },
    { "rate" : """8.6""" },
    { "rate" : """13.11""" },
    { "rate" : """2.5""" },
    { "rate" : """6.55""" },
    { "rate" : """2.5""" },
    { "rate" : """2.49""" },
    { "rate" : """2.48""" },
    { "rate" : """2.49""" },
    { "rate" : """2.47999""" },
    { "rate" : """2.5""" },
    { "rate" : """12""" },
    { "rate" : """13""" },
    { "rate" : """9.96""" },
    { "rate" : """8.7""" },
    { "rate" : """9.9""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9.89999""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """3.98""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """4.98""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """4.5""" },
    { "rate" : """9.9""" },
    { "rate" : """4.25""" },
    { "rate" : """0.45""" },
    { "rate" : """0.49896""" },
    { "rate" : """9""" },
    { "rate" : """0.497""" },
    { "rate" : """0.48989""" },
    { "rate" : """0.4""" },
    { "rate" : """5""" },
    { "rate" : """0.39999""" },
    { "rate" : """3""" },
    { "rate" : """9.96""" },
    { "rate" : """0.4""" },
    { "rate" : """0.47""" },
    { "rate" : """5""" },
    { "rate" : """0.49""" },
    { "rate" : """3.84996""" },
    { "rate" : """0.4987""" },
    { "rate" : """4.99998""" },
    { "rate" : """0.48888""" },
    { "rate" : """9.99""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """12""" },
    { "rate" : """8.64""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """3.84997""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """0.96""" },
    { "rate" : """4.99""" },
    { "rate" : """3.83""" },
    { "rate" : """0.38999""" },
    { "rate" : """10""" },
    { "rate" : """0.4899""" },
    { "rate" : """0.48""" },
    { "rate" : """0.47""" },
    { "rate" : """10""" },
    { "rate" : """0.48""" },
    { "rate" : """6.55""" },
    { "rate" : """0.48""" },
    { "rate" : """14.75""" },
    { "rate" : """3.9""" },
    { "rate" : """1.12""" },
    { "rate" : """1.11999""" },
    { "rate" : """10""" },
    { "rate" : """3.8399""" },
    { "rate" : """4.9999""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """1.1""" },
    { "rate" : """3.84""" },
    { "rate" : """8.99914""" },
    { "rate" : """6.99911""" },
    { "rate" : """3.6""" },
    { "rate" : """6.85""" },
    { "rate" : """6.55""" },
    { "rate" : """0.48""" },
    { "rate" : """0.38""" },
    { "rate" : """11.9999""" },
    { "rate" : """0.47""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """4.8""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """4.99999""" },
    { "rate" : """0.48999""" },
    { "rate" : """9""" },
    { "rate" : """8.5""" },
    { "rate" : """10.7""" },
    { "rate" : """10.69999""" },
    { "rate" : """8""" },
    { "rate" : """5.55""" },
    { "rate" : """7.99""" },
    { "rate" : """9.5""" },
    { "rate" : """7""" },
    { "rate" : """0.49""" },
    { "rate" : """7.98999""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """9.998""" },
    { "rate" : """0.4""" },
    { "rate" : """1.12""" },
    { "rate" : """13.11""" },
    { "rate" : """9.95998""" },
    { "rate" : """13.98625""" },
    { "rate" : """3.84998""" },
    { "rate" : """0.4""" },
    { "rate" : """9.96""" },
    { "rate" : """9.5""" },
    { "rate" : """10.59999""" },
    { "rate" : """6.55""" },
    { "rate" : """4.87""" },
    { "rate" : """9.96""" },
    { "rate" : """4""" },
    { "rate" : """16.17""" },
    { "rate" : """1.11""" },
    { "rate" : """9.96""" },
    { "rate" : """0.379""" },
    { "rate" : """6.99""" },
    { "rate" : """10.6999""" },
    { "rate" : """9.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """3.9999""" },
    { "rate" : """7.98""" },
    { "rate" : """9.95""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.45""" },
    { "rate" : """3.9999""" },
    { "rate" : """13.11""" },
    { "rate" : """7""" },
    { "rate" : """8.64""" },
    { "rate" : """0.45""" },
    { "rate" : """7""" },
    { "rate" : """0.4""" },
    { "rate" : """10""" },
    { "rate" : """0.399""" },
    { "rate" : """0.48999""" },
    { "rate" : """7""" },
    { "rate" : """0.4895""" },
    { "rate" : """9.9995""" },
    { "rate" : """13.1098""" },
    { "rate" : """6.55""" },
    { "rate" : """9.96""" },
    { "rate" : """6""" },
    { "rate" : """12.26""" },
    { "rate" : """13.11""" },
    { "rate" : """1.11999""" },
    { "rate" : """13.11""" },
    { "rate" : """1.12""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """12.26""" },
    { "rate" : """2.49998""" },
    { "rate" : """9.98""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """2.899""" },
    { "rate" : """4.499""" },
    { "rate" : """6.55""" },
    { "rate" : """13.11""" },
    { "rate" : """9.96""" },
    { "rate" : """9""" },
    { "rate" : """6.55""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """7.99998""" },
    { "rate" : """4.99989""" },
    { "rate" : """7.9""" },
    { "rate" : """7.9""" },
    { "rate" : """8.64""" },
    { "rate" : """7.9""" },
    { "rate" : """8""" },
    { "rate" : """13""" },
    { "rate" : """7""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """0.4706""" },
    { "rate" : """6.99999""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """7.99998""" },
    { "rate" : """4.9""" },
    { "rate" : """13.11""" },
    { "rate" : """6""" },
    { "rate" : """7.9""" },
    { "rate" : """8.64""" },
    { "rate" : """2.8""" },
    { "rate" : """2.6""" },
    { "rate" : """2.75""" },
    { "rate" : """8""" },
    { "rate" : """2.88999""" },
    { "rate" : """1.11987""" },
    { "rate" : """7.9""" },
    { "rate" : """7.98""" },
    { "rate" : """8""" },
    { "rate" : """11.9""" },
    { "rate" : """7.99964""" },
    { "rate" : """13.11""" },
    { "rate" : """4.99999""" },
    { "rate" : """2.85""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """1.1""" },
    { "rate" : """7.99""" },
    { "rate" : """8.99""" },
    { "rate" : """2""" },
    { "rate" : """7.9999""" },
    { "rate" : """7.98""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """7.99999""" },
    { "rate" : """8.63""" },
    { "rate" : """7.9""" },
    { "rate" : """0.4706""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """15.14""" },
    { "rate" : """13.11""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """4.4""" },
    { "rate" : """1""" },
    { "rate" : """7.975""" },
    { "rate" : """7.98""" },
    { "rate" : """7""" },
    { "rate" : """7.89""" },
    { "rate" : """8""" },
    { "rate" : """2.8""" },
    { "rate" : """12.26""" },
    { "rate" : """2""" },
    { "rate" : """9.96""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """7.9999""" },
    { "rate" : """9""" },
    { "rate" : """11.999""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """6.6""" },
    { "rate" : """7.95""" },
    { "rate" : """7.99""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """7.98""" },
    { "rate" : """8""" },
    { "rate" : """12.26""" },
    { "rate" : """3""" },
    { "rate" : """11.5""" },
    { "rate" : """7.98""" },
    { "rate" : """1.12""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """0.4706""" },
    { "rate" : """8""" },
    { "rate" : """4.99999""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """6.55""" },
    { "rate" : """13.1""" },
    { "rate" : """8""" },
    { "rate" : """13.72""" },
    { "rate" : """6""" },
    { "rate" : """13.72""" },
    { "rate" : """7""" },
    { "rate" : """12.26""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """12.26""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """8""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """8.6""" },
    { "rate" : """6.55""" },
    { "rate" : """13.72""" },
    { "rate" : """11""" },
    { "rate" : """4.9""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """13""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """13""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """3""" },
    { "rate" : """13""" },
    { "rate" : """6.55""" },
    { "rate" : """9""" },
    { "rate" : """12.26""" },
    { "rate" : """13.72""" },
    { "rate" : """12.24""" },
    { "rate" : """13.72""" },
    { "rate" : """6.53""" },
    { "rate" : """12""" },
    { "rate" : """12.44""" },
    { "rate" : """13.11""" },
    { "rate" : """8.79""" },
    { "rate" : """11.99""" },
    { "rate" : """9.96""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """15""" },
    { "rate" : """0.99996""" },
    { "rate" : """0.9""" },
    { "rate" : """12.4""" },
    { "rate" : """9.96""" },
    { "rate" : """0.92915""" },
    { "rate" : """10""" },
    { "rate" : """0.9""" },
    { "rate" : """3""" },
    { "rate" : """9.4599""" },
    { "rate" : """10""" },
    { "rate" : """0.99999""" },
    { "rate" : """8.63999""" },
    { "rate" : """8""" },
    { "rate" : """0.99""" },
    { "rate" : """12.5""" },
    { "rate" : """0.99997""" },
    { "rate" : """9""" },
    { "rate" : """0.99995""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """0.98""" },
    { "rate" : """7.9""" },
    { "rate" : """13.13""" },
    { "rate" : """4.49896""" },
    { "rate" : """0.97999""" },
    { "rate" : """1""" },
    { "rate" : """3.84995""" },
    { "rate" : """1""" },
    { "rate" : """9.96""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """4.45""" },
    { "rate" : """8.75""" },
    { "rate" : """6.8""" },
    { "rate" : """11.85""" },
    { "rate" : """13.699""" },
    { "rate" : """9.999""" },
    { "rate" : """4.49899""" },
    { "rate" : """9.96""" },
    { "rate" : """6.99""" },
    { "rate" : """12""" },
    { "rate" : """13.71999""" },
    { "rate" : """13.72""" },
    { "rate" : """8.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """0.99""" },
    { "rate" : """3.5""" },
    { "rate" : """8.9""" },
    { "rate" : """0.99""" },
    { "rate" : """0.4706""" },
    { "rate" : """12.45""" },
    { "rate" : """8.8""" },
    { "rate" : """20""" },
    { "rate" : """13""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """12.45""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """13.72""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """11.8""" },
    { "rate" : """10.73""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """13""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """5.99999""" },
    { "rate" : """6""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """3""" },
    { "rate" : """1.12""" },
    { "rate" : """1""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.9999""" },
    { "rate" : """4.2""" },
    { "rate" : """12.46""" },
    { "rate" : """6.55""" },
    { "rate" : """12.26""" },
    { "rate" : """11""" },
    { "rate" : """7""" },
    { "rate" : """19.99999""" },
    { "rate" : """12.46""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """7""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """9.98""" },
    { "rate" : """8.97999""" },
    { "rate" : """8.99999""" },
    { "rate" : """9""" },
    { "rate" : """4.5""" },
    { "rate" : """0.9899""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """3""" },
    { "rate" : """8.8""" },
    { "rate" : """6.55""" },
    { "rate" : """9.5""" },
    { "rate" : """10""" },
    { "rate" : """8.9999""" },
    { "rate" : """7""" },
    { "rate" : """9.74""" },
    { "rate" : """9""" },
    { "rate" : """8.7""" },
    { "rate" : """10""" },
    { "rate" : """9.5""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """0.98""" },
    { "rate" : """3""" },
    { "rate" : """13.11""" },
    { "rate" : """12.46""" },
    { "rate" : """7""" },
    { "rate" : """3.24""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """18.98""" },
    { "rate" : """12.26""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """0.97""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """3.24""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """9.6""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """0.9999""" },
    { "rate" : """13.11""" },
    { "rate" : """19.99""" },
    { "rate" : """0.09""" },
    { "rate" : """12""" },
    { "rate" : """6.55""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """0.7""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """3.24""" },
    { "rate" : """10""" },
    { "rate" : """9.25""" },
    { "rate" : """6.55""" },
    { "rate" : """9.75""" },
    { "rate" : """12.26""" },
    { "rate" : """23.49""" },
    { "rate" : """13.11""" },
    { "rate" : """8.5""" },
    { "rate" : """13.11""" },
    { "rate" : """21.5""" },
    { "rate" : """12.4""" },
    { "rate" : """23.5""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """23.5""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """10.1""" },
    { "rate" : """7.7""" },
    { "rate" : """12.12""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """6.55""" },
    { "rate" : """3""" },
    { "rate" : """6.5""" },
    { "rate" : """23""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """8.9999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """0.4706""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """0.99999""" },
    { "rate" : """8""" },
    { "rate" : """13.11""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6.55""" },
    { "rate" : """14.99""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """0.99998""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """12.46""" },
    { "rate" : """8""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """6.55""" },
    { "rate" : """9""" },
    { "rate" : """18""" },
    { "rate" : """9.95""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """0.89""" },
    { "rate" : """6.5""" },
    { "rate" : """8.7""" },
    { "rate" : """9.5""" },
    { "rate" : """0.9""" },
    { "rate" : """14.8""" },
    { "rate" : """12.45999""" },
    { "rate" : """6.54999""" },
    { "rate" : """0.88999""" },
    { "rate" : """6""" },
    { "rate" : """6.5""" },
    { "rate" : """0.95""" },
    { "rate" : """0.8699""" },
    { "rate" : """0.89""" },
    { "rate" : """6.55""" },
    { "rate" : """0.6""" },
    { "rate" : """0.9""" },
    { "rate" : """0.8""" },
    { "rate" : """0.8899""" },
    { "rate" : """0.19""" },
    { "rate" : """0.95""" },
    { "rate" : """6.565""" },
    { "rate" : """13.1""" },
    { "rate" : """8.24""" },
    { "rate" : """13""" },
    { "rate" : """0.87""" },
    { "rate" : """0.97""" },
    { "rate" : """0.8999""" },
    { "rate" : """3.24""" },
    { "rate" : """9.96""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """0.8""" },
    { "rate" : """6.55""" },
    { "rate" : """9.96""" },
    { "rate" : """6.55""" },
    { "rate" : """0.8999""" },
    { "rate" : """8.64""" },
    { "rate" : """0.969""" },
    { "rate" : """6.55""" },
    { "rate" : """0.4999""" },
    { "rate" : """0.87""" },
    { "rate" : """6.55""" },
    { "rate" : """9""" },
    { "rate" : """0.88""" },
    { "rate" : """11.58""" },
    { "rate" : """12.46""" },
    { "rate" : """3.24""" },
    { "rate" : """11.65""" },
    { "rate" : """11.979""" },
    { "rate" : """6.55""" },
    { "rate" : """11""" },
    { "rate" : """11.25""" },
    { "rate" : """11.8""" },
    { "rate" : """11.75""" },
    { "rate" : """11""" },
    { "rate" : """10.99999""" },
    { "rate" : """10""" },
    { "rate" : """11.98""" },
    { "rate" : """12.46""" },
    { "rate" : """6.5""" },
    { "rate" : """11.9""" },
    { "rate" : """11.99999""" },
    { "rate" : """6.55""" },
    { "rate" : """12.46""" },
    { "rate" : """9.99998""" },
    { "rate" : """11.99899""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6.55""" },
    { "rate" : """12.5""" },
    { "rate" : """9.5""" },
    { "rate" : """9""" },
    { "rate" : """6.5""" },
    { "rate" : """10.98998""" },
    { "rate" : """9.99924""" },
    { "rate" : """13.6""" },
    { "rate" : """6.55""" },
    { "rate" : """6.49999""" },
    { "rate" : """3.24""" },
    { "rate" : """10""" },
    { "rate" : """11.6666""" },
    { "rate" : """9.99""" },
    { "rate" : """8.89""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """6.55""" },
    { "rate" : """11.998""" },
    { "rate" : """6.55""" },
    { "rate" : """9""" },
    { "rate" : """0.15""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """9.5""" },
    { "rate" : """11""" },
    { "rate" : """6.55""" },
    { "rate" : """11.11""" },
    { "rate" : """9.9""" },
    { "rate" : """0.96""" },
    { "rate" : """11.25""" },
    { "rate" : """10.5""" },
    { "rate" : """11""" },
    { "rate" : """11.98""" },
    { "rate" : """18""" },
    { "rate" : """13.72""" },
    { "rate" : """9.99999""" },
    { "rate" : """10.73""" },
    { "rate" : """8""" },
    { "rate" : """10.73""" },
    { "rate" : """9.9""" },
    { "rate" : """2.999""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """9.99""" },
    { "rate" : """11.99""" },
    { "rate" : """4""" },
    { "rate" : """10.729""" },
    { "rate" : """3.472""" },
    { "rate" : """9.999""" },
    { "rate" : """2.9999""" },
    { "rate" : """11.96""" },
    { "rate" : """10.9""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """3.24""" },
    { "rate" : """6.55""" },
    { "rate" : """7.48""" },
    { "rate" : """10""" },
    { "rate" : """11.9999""" },
    { "rate" : """11.97""" },
    { "rate" : """9""" },
    { "rate" : """11.99799""" },
    { "rate" : """11.4""" },
    { "rate" : """11""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """9""" },
    { "rate" : """9.97""" },
    { "rate" : """9.5""" },
    { "rate" : """11.39999""" },
    { "rate" : """10.72""" },
    { "rate" : """13.72""" },
    { "rate" : """3.24""" },
    { "rate" : """8.95""" },
    { "rate" : """3.24""" },
    { "rate" : """6.52""" },
    { "rate" : """11.4""" },
    { "rate" : """2""" },
    { "rate" : """6.55""" },
    { "rate" : """3.24""" },
    { "rate" : """6.899""" },
    { "rate" : """10.72""" },
    { "rate" : """15.99""" },
    { "rate" : """1""" },
    { "rate" : """10.73""" },
    { "rate" : """15.98999""" },
    { "rate" : """10.7""" },
    { "rate" : """16.17""" },
    { "rate" : """10.73""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """3.24""" },
    { "rate" : """13""" },
    { "rate" : """16.17""" },
    { "rate" : """1""" },
    { "rate" : """7.9""" },
    { "rate" : """16.17""" },
    { "rate" : """15.99996""" },
    { "rate" : """18.98""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """4.99999""" },
    { "rate" : """10.1""" },
    { "rate" : """20""" },
    { "rate" : """4.98""" },
    { "rate" : """4.99""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """5.899""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10.73""" },
    { "rate" : """9""" },
    { "rate" : """4.97999""" },
    { "rate" : """6""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.99""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """9.96""" },
    { "rate" : """4.98998""" },
    { "rate" : """9.98998""" },
    { "rate" : """1""" },
    { "rate" : """9""" },
    { "rate" : """10.72""" },
    { "rate" : """4.9999""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """3.9""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """6.55""" },
    { "rate" : """9.96""" },
    { "rate" : """0.96""" },
    { "rate" : """4.89""" },
    { "rate" : """10""" },
    { "rate" : """6.45""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """6.55""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """12.25""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """10.72""" },
    { "rate" : """10.71""" },
    { "rate" : """13.71""" },
    { "rate" : """1""" },
    { "rate" : """12.26""" },
    { "rate" : """10.72""" },
    { "rate" : """5""" },
    { "rate" : """13.01""" },
    { "rate" : """5""" },
    { "rate" : """10.73""" },
    { "rate" : """12""" },
    { "rate" : """16.16""" },
    { "rate" : """3.24""" },
    { "rate" : """5""" },
    { "rate" : """23.23""" },
    { "rate" : """9""" },
    { "rate" : """9.5""" },
    { "rate" : """13.13""" },
    { "rate" : """6.5""" },
    { "rate" : """12.99""" },
    { "rate" : """5.5""" },
    { "rate" : """16.17""" },
    { "rate" : """3.24""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """13.7199""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """10.7299""" },
    { "rate" : """13.72""" },
    { "rate" : """9""" },
    { "rate" : """12.26""" },
    { "rate" : """13.72""" },
    { "rate" : """16.17""" },
    { "rate" : """10.73""" },
    { "rate" : """16.17""" },
    { "rate" : """4""" },
    { "rate" : """9.99999""" },
    { "rate" : """13.72""" },
    { "rate" : """9""" },
    { "rate" : """13""" },
    { "rate" : """9""" },
    { "rate" : """6.55""" },
    { "rate" : """3.24""" },
    { "rate" : """6.5""" },
    { "rate" : """9.96""" },
    { "rate" : """9.9""" },
    { "rate" : """16.17""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """16.17""" },
    { "rate" : """13.72""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """16.17""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """13.72""" },
    { "rate" : """6.5""" },
    { "rate" : """16.17""" },
    { "rate" : """4.2""" },
    { "rate" : """9.95999""" },
    { "rate" : """15.13""" },
    { "rate" : """5""" },
    { "rate" : """16.17""" },
    { "rate" : """13.72""" },
    { "rate" : """16.17""" },
    { "rate" : """8""" },
    { "rate" : """13.72""" },
    { "rate" : """13.37""" },
    { "rate" : """9.99998""" },
    { "rate" : """4.9""" },
    { "rate" : """18""" },
    { "rate" : """5""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """0.4706""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """16.17""" },
    { "rate" : """17.5""" },
    { "rate" : """4""" },
    { "rate" : """3.24""" },
    { "rate" : """10""" },
    { "rate" : """0.4706""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """10.6""" },
    { "rate" : """3.24""" },
    { "rate" : """5""" },
    { "rate" : """5.9""" },
    { "rate" : """19.26""" },
    { "rate" : """14.98""" },
    { "rate" : """16""" },
    { "rate" : """13.11""" },
    { "rate" : """10.73""" },
    { "rate" : """16""" },
    { "rate" : """16.17""" },
    { "rate" : """23""" },
    { "rate" : """5.88""" },
    { "rate" : """13.1""" },
    { "rate" : """16.17""" },
    { "rate" : """15""" },
    { "rate" : """9.49""" },
    { "rate" : """16.16999""" },
    { "rate" : """7.99999""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """4.99""" },
    { "rate" : """8""" },
    { "rate" : """9.8""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """19""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """12.26""" },
    { "rate" : """8.79999""" },
    { "rate" : """5.99""" },
    { "rate" : """13.11""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """12.26""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """10.7""" },
    { "rate" : """8.5""" },
    { "rate" : """7.9""" },
    { "rate" : """13.1099""" },
    { "rate" : """3.24""" },
    { "rate" : """13.72""" },
    { "rate" : """7""" },
    { "rate" : """13.72""" },
    { "rate" : """9""" },
    { "rate" : """9.9""" },
    { "rate" : """3.24""" },
    { "rate" : """13.72""" },
    { "rate" : """4.99999""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """15.14""" },
    { "rate" : """2""" },
    { "rate" : """3.24""" },
    { "rate" : """9.96""" },
    { "rate" : """7""" },
    { "rate" : """12.46""" },
    { "rate" : """5.78999""" },
    { "rate" : """7.89""" },
    { "rate" : """7.99999""" },
    { "rate" : """5.78887""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7.99999""" },
    { "rate" : """6.99""" },
    { "rate" : """3.24""" },
    { "rate" : """6.9""" },
    { "rate" : """7.9""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """9.96""" },
    { "rate" : """7""" },
    { "rate" : """3.24""" },
    { "rate" : """12.99""" },
    { "rate" : """6.75""" },
    { "rate" : """5.5""" },
    { "rate" : """6.9""" },
    { "rate" : """14.97""" },
    { "rate" : """6.99""" },
    { "rate" : """6.99""" },
    { "rate" : """7""" },
    { "rate" : """3.24""" },
    { "rate" : """13.13""" },
    { "rate" : """6.99""" },
    { "rate" : """10.72""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """8.8""" },
    { "rate" : """12""" },
    { "rate" : """6.99999""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """5.5""" },
    { "rate" : """6.95""" },
    { "rate" : """6.95""" },
    { "rate" : """6.9999""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """12.45999""" },
    { "rate" : """7""" },
    { "rate" : """6.55""" },
    { "rate" : """5.8""" },
    { "rate" : """4.89999""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """3.24""" },
    { "rate" : """6.49""" },
    { "rate" : """5.79""" },
    { "rate" : """5.79""" },
    { "rate" : """7""" },
    { "rate" : """6.55""" },
    { "rate" : """5.99""" },
    { "rate" : """5.899""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """9.8""" },
    { "rate" : """7""" },
    { "rate" : """5.79""" },
    { "rate" : """5""" },
    { "rate" : """6.985""" },
    { "rate" : """13.11""" },
    { "rate" : """6.5""" },
    { "rate" : """12.46""" },
    { "rate" : """12.99""" },
    { "rate" : """6""" },
    { "rate" : """12.98999""" },
    { "rate" : """3.24""" },
    { "rate" : """6.5""" },
    { "rate" : """6.55""" },
    { "rate" : """12.46""" },
    { "rate" : """8""" },
    { "rate" : """6.9""" },
    { "rate" : """8.8""" },
    { "rate" : """5.79""" },
    { "rate" : """6.55""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """6.55""" },
    { "rate" : """6.989""" },
    { "rate" : """6.5""" },
    { "rate" : """4.75""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """12.12""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """10.1""" },
    { "rate" : """10.73""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """13.2""" },
    { "rate" : """3.24""" },
    { "rate" : """6.55""" },
    { "rate" : """6.99""" },
    { "rate" : """1""" },
    { "rate" : """8.5""" },
    { "rate" : """9.98""" },
    { "rate" : """14""" },
    { "rate" : """5.79""" },
    { "rate" : """6.9""" },
    { "rate" : """6.55""" },
    { "rate" : """9.7""" },
    { "rate" : """12""" },
    { "rate" : """0.9""" },
    { "rate" : """9.96""" },
    { "rate" : """10.64""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.9599""" },
    { "rate" : """6.54""" },
    { "rate" : """7""" },
    { "rate" : """18""" },
    { "rate" : """0.98""" },
    { "rate" : """14.9""" },
    { "rate" : """0.97999""" },
    { "rate" : """0.97""" },
    { "rate" : """1""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.96999""" },
    { "rate" : """0.99999""" },
    { "rate" : """9""" },
    { "rate" : """6.5""" },
    { "rate" : """1""" },
    { "rate" : """0.8""" },
    { "rate" : """6.55""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.96""" },
    { "rate" : """6.5""" },
    { "rate" : """15""" },
    { "rate" : """6.5""" },
    { "rate" : """13.11""" },
    { "rate" : """9.96""" },
    { "rate" : """6.55""" },
    { "rate" : """0.99998""" },
    { "rate" : """10.73""" },
    { "rate" : """0.97998""" },
    { "rate" : """5.79""" },
    { "rate" : """6.5""" },
    { "rate" : """0.973""" },
    { "rate" : """6.98""" },
    { "rate" : """0.973""" },
    { "rate" : """7""" },
    { "rate" : """6.7""" },
    { "rate" : """6.55""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """5.79""" },
    { "rate" : """6.5""" },
    { "rate" : """6.55""" },
    { "rate" : """6.99""" },
    { "rate" : """10.73""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """7""" },
    { "rate" : """6.55""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """5.79""" },
    { "rate" : """15.14""" },
    { "rate" : """7.5""" },
    { "rate" : """10.73""" },
    { "rate" : """13.11""" },
    { "rate" : """6.55""" },
    { "rate" : """13.11""" },
    { "rate" : """6.55""" },
    { "rate" : """7""" },
    { "rate" : """13.71""" },
    { "rate" : """10.73""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """10.73""" },
    { "rate" : """5.79""" },
    { "rate" : """6""" },
    { "rate" : """13.11""" },
    { "rate" : """6.98998""" },
    { "rate" : """12.98998""" },
    { "rate" : """8.59998""" },
    { "rate" : """9.98998""" },
    { "rate" : """5.79""" },
    { "rate" : """8.8""" },
    { "rate" : """15.14""" },
    { "rate" : """15.9""" },
    { "rate" : """13.72""" },
    { "rate" : """6.5""" },
    { "rate" : """9.99""" },
    { "rate" : """13.72""" },
    { "rate" : """13""" },
    { "rate" : """12.12""" },
    { "rate" : """7.9""" },
    { "rate" : """13.11""" },
    { "rate" : """5.79""" },
    { "rate" : """6.06""" },
    { "rate" : """5.79""" },
    { "rate" : """5.79""" },
    { "rate" : """6.9""" },
    { "rate" : """9.96""" },
    { "rate" : """6.55""" },
    { "rate" : """10.73""" },
    { "rate" : """6.3""" },
    { "rate" : """12.89""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6""" },
    { "rate" : """6.55""" },
    { "rate" : """6.52""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """7""" },
    { "rate" : """13.11""" },
    { "rate" : """6.55""" },
    { "rate" : """5.79""" },
    { "rate" : """9.99""" },
    { "rate" : """0.05998""" },
    { "rate" : """13.9""" },
    { "rate" : """0.69999""" },
    { "rate" : """0.38887""" },
    { "rate" : """6""" },
    { "rate" : """8.8""" },
    { "rate" : """15""" },
    { "rate" : """6.5""" },
    { "rate" : """7""" },
    { "rate" : """6.99""" },
    { "rate" : """5.79""" },
    { "rate" : """6""" },
    { "rate" : """0.69999""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """0.7""" },
    { "rate" : """0.7""" },
    { "rate" : """0.48""" },
    { "rate" : """7.99999""" },
    { "rate" : """11""" },
    { "rate" : """11""" },
    { "rate" : """6""" },
    { "rate" : """13.72""" },
    { "rate" : """13.11""" },
    { "rate" : """6.9998""" },
    { "rate" : """7.99998""" },
    { "rate" : """4""" },
    { "rate" : """12.99""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """3""" },
    { "rate" : """0.7299""" },
    { "rate" : """8""" },
    { "rate" : """8.5""" },
    { "rate" : """9.99999""" },
    { "rate" : """10.73""" },
    { "rate" : """6.55""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """15.14""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """6.55""" },
    { "rate" : """0.5""" },
    { "rate" : """13.72""" },
    { "rate" : """13""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """5.79""" },
    { "rate" : """7.1""" },
    { "rate" : """8""" },
    { "rate" : """10.73""" },
    { "rate" : """0.68999""" },
    { "rate" : """7.98999""" },
    { "rate" : """8""" },
    { "rate" : """11""" },
    { "rate" : """8""" },
    { "rate" : """0.49998""" },
    { "rate" : """13.72""" },
    { "rate" : """0.05998""" },
    { "rate" : """0.5""" },
    { "rate" : """8""" },
    { "rate" : """13.72""" },
    { "rate" : """7.9998""" },
    { "rate" : """7.7""" },
    { "rate" : """6.889""" },
    { "rate" : """7.9999""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """0.48888""" },
    { "rate" : """0.48888""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """8.8""" },
    { "rate" : """20""" },
    { "rate" : """9.96""" },
    { "rate" : """0.67999""" },
    { "rate" : """6.5""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """6.48999""" },
    { "rate" : """6.4""" },
    { "rate" : """0.4""" },
    { "rate" : """0.4998""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """13.71""" },
    { "rate" : """19.98""" },
    { "rate" : """6.48""" },
    { "rate" : """0.6""" },
    { "rate" : """6.4""" },
    { "rate" : """6.5""" },
    { "rate" : """7.98""" },
    { "rate" : """7.499""" },
    { "rate" : """0.739""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """10.73""" },
    { "rate" : """0.48799""" },
    { "rate" : """8.8""" },
    { "rate" : """6.55""" },
    { "rate" : """6.06""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """5.65""" },
    { "rate" : """6.55""" },
    { "rate" : """8""" },
    { "rate" : """0.69999""" },
    { "rate" : """13.72""" },
    { "rate" : """9.96""" },
    { "rate" : """13.72""" },
    { "rate" : """8.79""" },
    { "rate" : """13.72""" },
    { "rate" : """0.96""" },
    { "rate" : """0.49""" },
    { "rate" : """0.4899""" },
    { "rate" : """16.46""" },
    { "rate" : """2.5""" },
    { "rate" : """0.69""" },
    { "rate" : """7""" },
    { "rate" : """6.55""" },
    { "rate" : """9.96""" },
    { "rate" : """15.14""" },
    { "rate" : """13.72""" },
    { "rate" : """6.55""" },
    { "rate" : """4.99999""" },
    { "rate" : """6.49999""" },
    { "rate" : """5""" },
    { "rate" : """17.32""" },
    { "rate" : """10.73""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """6.55""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.4706""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """6.5""" },
    { "rate" : """0.68""" },
    { "rate" : """14.11""" },
    { "rate" : """4.97""" },
    { "rate" : """6.3""" },
    { "rate" : """6.54""" },
    { "rate" : """6.9""" },
    { "rate" : """5""" },
    { "rate" : """9.999""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """4.95""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """8.79999""" },
    { "rate" : """9.96""" },
    { "rate" : """5.79""" },
    { "rate" : """6.99""" },
    { "rate" : """6.5499""" },
    { "rate" : """6.49999""" },
    { "rate" : """9.9999""" },
    { "rate" : """12""" },
    { "rate" : """0.96""" },
    { "rate" : """9.96""" },
    { "rate" : """12.99""" },
    { "rate" : """6.55""" },
    { "rate" : """1""" },
    { "rate" : """6.55""" },
    { "rate" : """8.99999""" },
    { "rate" : """10""" },
    { "rate" : """5.79""" },
    { "rate" : """9.99""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """9.96""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """5.79""" },
    { "rate" : """6.5""" },
    { "rate" : """9.96""" },
    { "rate" : """5.5""" },
    { "rate" : """10.73""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """5.98998""" },
    { "rate" : """6.55""" },
    { "rate" : """6.5""" },
    { "rate" : """7""" },
    { "rate" : """0.39""" },
    { "rate" : """0.39999""" },
    { "rate" : """4""" },
    { "rate" : """6.5""" },
    { "rate" : """0.39999""" },
    { "rate" : """3.99999""" },
    { "rate" : """0.4""" },
    { "rate" : """3.9""" },
    { "rate" : """6.5""" },
    { "rate" : """3.99999""" },
    { "rate" : """3.98""" },
    { "rate" : """15""" },
    { "rate" : """4.98""" },
    { "rate" : """14""" },
    { "rate" : """11.2""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """15.99""" },
    { "rate" : """16""" },
    { "rate" : """11.19999""" },
    { "rate" : """15.9""" },
    { "rate" : """2.5""" },
    { "rate" : """15.99""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """16""" },
    { "rate" : """4""" },
    { "rate" : """4.94998""" },
    { "rate" : """4.25""" },
    { "rate" : """15""" },
    { "rate" : """15.98""" },
    { "rate" : """3.99""" },
    { "rate" : """13""" },
    { "rate" : """15.9""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """13.11""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """6.489""" },
    { "rate" : """13.72""" },
    { "rate" : """15""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """15.99999""" },
    { "rate" : """0.9998""" },
    { "rate" : """16""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """16""" },
    { "rate" : """1""" },
    { "rate" : """8.7""" },
    { "rate" : """1""" },
    { "rate" : """9.87""" },
    { "rate" : """16""" },
    { "rate" : """16""" },
    { "rate" : """16""" },
    { "rate" : """15""" },
    { "rate" : """0.4706""" },
    { "rate" : """1.49""" },
    { "rate" : """1.9""" },
    { "rate" : """13.11""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """13.11""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """13.11""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """3.9""" },
    { "rate" : """9.5""" },
    { "rate" : """1.99989""" },
    { "rate" : """1.998""" },
    { "rate" : """9.96""" },
    { "rate" : """1.99""" },
    { "rate" : """9.96""" },
    { "rate" : """4""" },
    { "rate" : """1.99""" },
    { "rate" : """3.89999""" },
    { "rate" : """13.11""" },
    { "rate" : """3.98""" },
    { "rate" : """9.96""" },
    { "rate" : """6.55""" },
    { "rate" : """6""" },
    { "rate" : """16""" },
    { "rate" : """9.96""" },
    { "rate" : """0.99999""" },
    { "rate" : """4""" },
    { "rate" : """6.95""" },
    { "rate" : """9.96""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """10.73""" },
    { "rate" : """5.79""" },
    { "rate" : """1""" },
    { "rate" : """15.9999""" },
    { "rate" : """16""" },
    { "rate" : """13.11""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """6.55""" },
    { "rate" : """15""" },
    { "rate" : """1.99""" },
    { "rate" : """13.13""" },
    { "rate" : """13.11""" },
    { "rate" : """9.96""" },
    { "rate" : """6""" },
    { "rate" : """2""" },
    { "rate" : """4.99999""" },
    { "rate" : """5.8999""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """3.24""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """1.99999""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """16""" },
    { "rate" : """15""" },
    { "rate" : """5.88""" },
    { "rate" : """3.99999""" },
    { "rate" : """0.99""" },
    { "rate" : """13.11""" },
    { "rate" : """6""" },
    { "rate" : """3.24""" },
    { "rate" : """14""" },
    { "rate" : """5.9""" },
    { "rate" : """5.89""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """3.24""" },
    { "rate" : """4""" },
    { "rate" : """14""" },
    { "rate" : """7""" },
    { "rate" : """2.5""" },
    { "rate" : """3.95""" },
    { "rate" : """16""" },
    { "rate" : """9.999""" },
    { "rate" : """4""" },
    { "rate" : """4.999""" },
    { "rate" : """5.5""" },
    { "rate" : """15.999""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """3.24""" },
    { "rate" : """11.98""" },
    { "rate" : """3.5""" },
    { "rate" : """11.97999""" },
    { "rate" : """4""" },
    { "rate" : """9.96""" },
    { "rate" : """11.97""" },
    { "rate" : """6.55""" },
    { "rate" : """11.98""" },
    { "rate" : """11.99""" },
    { "rate" : """5.98""" },
    { "rate" : """3.5""" },
    { "rate" : """9.98""" },
    { "rate" : """4""" },
    { "rate" : """3.3""" },
    { "rate" : """11""" },
    { "rate" : """3.99""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """13""" },
    { "rate" : """14""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """15.5""" },
    { "rate" : """2""" },
    { "rate" : """13.11""" },
    { "rate" : """4.999""" },
    { "rate" : """13.11""" },
    { "rate" : """12""" },
    { "rate" : """11.99""" },
    { "rate" : """4.99899""" },
    { "rate" : """5""" },
    { "rate" : """4.97""" },
    { "rate" : """4.9699""" },
    { "rate" : """4.899""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """4.995""" },
    { "rate" : """15""" },
    { "rate" : """9.5""" },
    { "rate" : """3.24""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """9.99""" },
    { "rate" : """6.55""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """16""" },
    { "rate" : """11.9699""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """4.99999""" },
    { "rate" : """2.3""" },
    { "rate" : """2""" },
    { "rate" : """3.24""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """6.5""" },
    { "rate" : """3.24""" },
    { "rate" : """8.8""" },
    { "rate" : """14""" },
    { "rate" : """14.99999""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """3.24""" },
    { "rate" : """9.99999""" },
    { "rate" : """16""" },
    { "rate" : """13.11""" },
    { "rate" : """11.11""" },
    { "rate" : """12""" },
    { "rate" : """18.98""" },
    { "rate" : """15.89999""" },
    { "rate" : """13.11""" },
    { "rate" : """15.9999""" },
    { "rate" : """4.8888""" },
    { "rate" : """1""" },
    { "rate" : """1.4""" },
    { "rate" : """0.9""" },
    { "rate" : """0.89999""" },
    { "rate" : """16""" },
    { "rate" : """1.24999""" },
    { "rate" : """1.5""" },
    { "rate" : """0.05998""" },
    { "rate" : """1""" },
    { "rate" : """3.25""" },
    { "rate" : """0.4706""" },
    { "rate" : """1.5""" },
    { "rate" : """12.6""" },
    { "rate" : """3.2""" },
    { "rate" : """12""" },
    { "rate" : """2.1""" },
    { "rate" : """1.25""" },
    { "rate" : """6.25""" },
    { "rate" : """0.05""" },
    { "rate" : """17.48""" },
    { "rate" : """1""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """18.98""" },
    { "rate" : """17.48""" },
    { "rate" : """12""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """6.5""" },
    { "rate" : """12""" },
    { "rate" : """6.55""" },
    { "rate" : """1.4""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """16""" },
    { "rate" : """16""" },
    { "rate" : """16""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """17.46""" },
    { "rate" : """2""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """17.48""" },
    { "rate" : """3.24""" },
    { "rate" : """3""" },
    { "rate" : """13.11""" },
    { "rate" : """17.4""" },
    { "rate" : """15.999""" },
    { "rate" : """13.11""" },
    { "rate" : """17.48""" },
    { "rate" : """15""" },
    { "rate" : """16""" },
    { "rate" : """3.24""" },
    { "rate" : """13.11""" },
    { "rate" : """16""" },
    { "rate" : """6.5""" },
    { "rate" : """3.24""" },
    { "rate" : """1""" },
    { "rate" : """1.99""" },
    { "rate" : """3.3""" },
    { "rate" : """4""" },
    { "rate" : """13.11""" },
    { "rate" : """2""" },
    { "rate" : """3.24""" },
    { "rate" : """0.99999""" },
    { "rate" : """15.14""" },
    { "rate" : """6.55""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """11""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """1.5""" },
    { "rate" : """13.11""" },
    { "rate" : """12.26""" },
    { "rate" : """13.11""" },
    { "rate" : """12.26""" },
    { "rate" : """1.5""" },
    { "rate" : """10""" },
    { "rate" : """6.4999""" },
    { "rate" : """6""" },
    { "rate" : """4.9999""" },
    { "rate" : """1.97""" },
    { "rate" : """5.9999""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.99""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """1.969""" },
    { "rate" : """2.2""" },
    { "rate" : """4.99999""" },
    { "rate" : """4""" },
    { "rate" : """6.55""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """20.45""" },
    { "rate" : """12.5""" },
    { "rate" : """9.99""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """2.5""" },
    { "rate" : """7.99999""" },
    { "rate" : """4.8""" },
    { "rate" : """3.99""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """6.5""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """9.9899""" },
    { "rate" : """3.24""" },
    { "rate" : """9.99""" },
    { "rate" : """3.99""" },
    { "rate" : """11.95""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """20.45""" },
    { "rate" : """8""" },
    { "rate" : """19.99""" },
    { "rate" : """3.24""" },
    { "rate" : """6.55""" },
    { "rate" : """10.009""" },
    { "rate" : """10.73""" },
    { "rate" : """3.24""" },
    { "rate" : """11.9""" },
    { "rate" : """3.75""" },
    { "rate" : """3.24""" },
    { "rate" : """15.14""" },
    { "rate" : """4.99999""" },
    { "rate" : """3.24""" },
    { "rate" : """5""" },
    { "rate" : """8.6399""" },
    { "rate" : """12.49""" },
    { "rate" : """4""" },
    { "rate" : """11""" },
    { "rate" : """6.55""" },
    { "rate" : """14.988""" },
    { "rate" : """3.24""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """0.5""" },
    { "rate" : """0.75""" },
    { "rate" : """3""" },
    { "rate" : """6.55""" },
    { "rate" : """2.66981""" },
    { "rate" : """6.49999""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """19.98""" },
    { "rate" : """8""" },
    { "rate" : """7.97""" },
    { "rate" : """7.96999""" },
    { "rate" : """5""" },
    { "rate" : """8.64""" },
    { "rate" : """9.9""" },
    { "rate" : """12""" },
    { "rate" : """6.5""" },
    { "rate" : """8.64""" },
    { "rate" : """9.89999""" },
    { "rate" : """10""" },
    { "rate" : """7.9""" },
    { "rate" : """8.64""" },
    { "rate" : """6.55""" },
    { "rate" : """7.97""" },
    { "rate" : """7""" },
    { "rate" : """6.55""" },
    { "rate" : """7.998""" },
    { "rate" : """6.5""" },
    { "rate" : """2""" },
    { "rate" : """0.96""" },
    { "rate" : """4""" },
    { "rate" : """8.64""" },
    { "rate" : """9.9999""" },
    { "rate" : """7.5""" },
    { "rate" : """6.5""" },
    { "rate" : """15.14""" },
    { "rate" : """3.24""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """7.99999""" },
    { "rate" : """8""" },
    { "rate" : """9.5""" },
    { "rate" : """18.98""" },
    { "rate" : """2.499""" },
    { "rate" : """4.91""" },
    { "rate" : """7""" },
    { "rate" : """7.99924""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """6.55""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """3.24""" },
    { "rate" : """12""" },
    { "rate" : """7.95""" },
    { "rate" : """6.48998""" },
    { "rate" : """6.5""" },
    { "rate" : """8""" },
    { "rate" : """4.7""" },
    { "rate" : """5""" },
    { "rate" : """3.24""" },
    { "rate" : """5""" },
    { "rate" : """6.88""" },
    { "rate" : """4.98""" },
    { "rate" : """4.24""" },
    { "rate" : """8.64""" },
    { "rate" : """6.5""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """3.24""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """8""" },
    { "rate" : """3.24""" },
    { "rate" : """1""" },
    { "rate" : """4""" },
    { "rate" : """3.24""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """3.24""" },
    { "rate" : """6.06""" },
    { "rate" : """10""" },
    { "rate" : """4.9""" },
    { "rate" : """6.47""" },
    { "rate" : """10""" },
    { "rate" : """7.998""" },
    { "rate" : """8.64""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """6.3""" },
    { "rate" : """6.5""" },
    { "rate" : """11.99999""" },
    { "rate" : """8.64""" },
    { "rate" : """4.4""" },
    { "rate" : """6.5""" },
    { "rate" : """6.55""" },
    { "rate" : """10.73""" },
    { "rate" : """11.98999""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """8.59""" },
    { "rate" : """4.98998""" },
    { "rate" : """6.5""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """6.55""" },
    { "rate" : """10.7299""" },
    { "rate" : """0.2999""" },
    { "rate" : """8.5""" },
    { "rate" : """9.98""" },
    { "rate" : """0.00039""" },
    { "rate" : """8.64""" },
    { "rate" : """9.98""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """11.87""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """13.11""" },
    { "rate" : """6.55""" },
    { "rate" : """15.14""" },
    { "rate" : """8""" },
    { "rate" : """15.14""" },
    { "rate" : """8.64""" },
    { "rate" : """15.14""" },
    { "rate" : """8.64""" },
    { "rate" : """8.8""" },
    { "rate" : """9.5""" },
    { "rate" : """4.5""" },
    { "rate" : """2""" },
    { "rate" : """6.55""" },
    { "rate" : """12.25""" },
    { "rate" : """15.14""" },
    { "rate" : """8.64""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """6.55""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """7.7""" },
    { "rate" : """12.24""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.8""" },
    { "rate" : """1""" },
    { "rate" : """15.14""" },
    { "rate" : """0.9""" },
    { "rate" : """0.4""" },
    { "rate" : """5""" },
    { "rate" : """0.9899""" },
    { "rate" : """0.81215""" },
    { "rate" : """8""" },
    { "rate" : """0.7""" },
    { "rate" : """0.98""" },
    { "rate" : """0.9""" },
    { "rate" : """0.75""" },
    { "rate" : """0.87""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.998""" },
    { "rate" : """12.14""" },
    { "rate" : """11.55""" },
    { "rate" : """8""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15.14""" },
    { "rate" : """15""" },
    { "rate" : """9.95""" },
    { "rate" : """12.46""" },
    { "rate" : """14.89""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """13""" },
    { "rate" : """12.26""" },
    { "rate" : """11""" },
    { "rate" : """14""" },
    { "rate" : """10.99""" },
    { "rate" : """11.999""" },
    { "rate" : """12""" },
    { "rate" : """11.98999""" },
    { "rate" : """9.94999""" },
    { "rate" : """12.46""" },
    { "rate" : """15.14""" },
    { "rate" : """14.14""" },
    { "rate" : """5""" },
    { "rate" : """15.14""" },
    { "rate" : """0.48998""" },
    { "rate" : """0.49""" },
    { "rate" : """0.49""" },
    { "rate" : """0.47""" },
    { "rate" : """8.64""" },
    { "rate" : """0.48999""" },
    { "rate" : """0.39998""" },
    { "rate" : """0.47999""" },
    { "rate" : """0.4""" },
    { "rate" : """0.4""" },
    { "rate" : """0.48""" },
    { "rate" : """6.5""" },
    { "rate" : """0.475""" },
    { "rate" : """0.48""" },
    { "rate" : """10""" },
    { "rate" : """0.4""" },
    { "rate" : """14""" },
    { "rate" : """12""" },
    { "rate" : """0.498""" },
    { "rate" : """14""" },
    { "rate" : """14.999""" },
    { "rate" : """11""" },
    { "rate" : """4.9999""" },
    { "rate" : """3.99999""" },
    { "rate" : """11.97""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """4.89""" },
    { "rate" : """4""" },
    { "rate" : """3.5""" },
    { "rate" : """6.5""" },
    { "rate" : """0.45""" },
    { "rate" : """12.46""" },
    { "rate" : """14""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """4.99""" },
    { "rate" : """0.44""" },
    { "rate" : """4.99""" },
    { "rate" : """8.64""" },
    { "rate" : """4.99""" },
    { "rate" : """6.49""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """6.5""" },
    { "rate" : """0.43999""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """4.7""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """9.999""" },
    { "rate" : """4.99989""" },
    { "rate" : """12.26""" },
    { "rate" : """4.88""" },
    { "rate" : """2.987""" },
    { "rate" : """9.99""" },
    { "rate" : """0.48999""" },
    { "rate" : """0.47999""" },
    { "rate" : """0.44987""" },
    { "rate" : """11.9999""" },
    { "rate" : """8.64""" },
    { "rate" : """13.11""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """0.49""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """0.4""" },
    { "rate" : """11.8""" },
    { "rate" : """12""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """6""" },
    { "rate" : """11.98""" },
    { "rate" : """4.97999""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """12.9""" },
    { "rate" : """4.67""" },
    { "rate" : """0.49""" },
    { "rate" : """8""" },
    { "rate" : """8.64""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """0.49""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """9.9""" },
    { "rate" : """14.98""" },
    { "rate" : """9.99999""" },
    { "rate" : """6.49""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """0.49""" },
    { "rate" : """0.49799""" },
    { "rate" : """4.99""" },
    { "rate" : """0.39""" },
    { "rate" : """6.5""" },
    { "rate" : """4.4""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """4.9""" },
    { "rate" : """0.495""" },
    { "rate" : """0.45999""" },
    { "rate" : """12.46""" },
    { "rate" : """6.5""" },
    { "rate" : """1""" },
    { "rate" : """0.98""" },
    { "rate" : """0.3""" },
    { "rate" : """0.97999""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """8.6199""" },
    { "rate" : """0.9999""" },
    { "rate" : """13""" },
    { "rate" : """4.999""" },
    { "rate" : """4.98""" },
    { "rate" : """4.97999""" },
    { "rate" : """4.99""" },
    { "rate" : """14.98999""" },
    { "rate" : """0.97""" },
    { "rate" : """5""" },
    { "rate" : """0.449""" },
    { "rate" : """11.5""" },
    { "rate" : """12""" },
    { "rate" : """11.96""" },
    { "rate" : """9.95999""" },
    { "rate" : """11.99999""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """0.4798""" },
    { "rate" : """4.98564""" },
    { "rate" : """11.9""" },
    { "rate" : """11.99""" },
    { "rate" : """11.9999""" },
    { "rate" : """0.97""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """11""" },
    { "rate" : """0.4706""" },
    { "rate" : """7.64""" },
    { "rate" : """9.919""" },
    { "rate" : """9.96""" },
    { "rate" : """4.899""" },
    { "rate" : """15""" },
    { "rate" : """9.979""" },
    { "rate" : """11.99999""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """13.11""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """10.73""" },
    { "rate" : """11.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """8.3""" },
    { "rate" : """9""" },
    { "rate" : """15""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """6""" },
    { "rate" : """9.5""" },
    { "rate" : """14""" },
    { "rate" : """11.99""" },
    { "rate" : """9.96""" },
    { "rate" : """14.99""" },
    { "rate" : """15.14""" },
    { "rate" : """10""" },
    { "rate" : """9.95989""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """9.9""" },
    { "rate" : """11.9""" },
    { "rate" : """5""" },
    { "rate" : """11""" },
    { "rate" : """14.99""" },
    { "rate" : """4.99""" },
    { "rate" : """11.99999""" },
    { "rate" : """13.1""" },
    { "rate" : """12.26""" },
    { "rate" : """18.98""" },
    { "rate" : """2""" },
    { "rate" : """8.95""" },
    { "rate" : """12.26""" },
    { "rate" : """12.46""" },
    { "rate" : """6.5""" },
    { "rate" : """9.96""" },
    { "rate" : """13.11""" },
    { "rate" : """4.5""" },
    { "rate" : """4.98""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """11.99996""" },
    { "rate" : """12.25999""" },
    { "rate" : """12""" },
    { "rate" : """11.98""" },
    { "rate" : """12""" },
    { "rate" : """6.5""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """11.9""" },
    { "rate" : """13.46""" },
    { "rate" : """12.46""" },
    { "rate" : """12.26""" },
    { "rate" : """12.46""" },
    { "rate" : """6""" },
    { "rate" : """9.99999""" },
    { "rate" : """10.72""" },
    { "rate" : """14.98999""" },
    { "rate" : """9.98""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """0.96""" },
    { "rate" : """8.49""" },
    { "rate" : """6.5""" },
    { "rate" : """13.11""" },
    { "rate" : """8""" },
    { "rate" : """8.47""" },
    { "rate" : """12.99""" },
    { "rate" : """6.5""" },
    { "rate" : """13.11""" },
    { "rate" : """14.5""" },
    { "rate" : """8.47""" },
    { "rate" : """13.11""" },
    { "rate" : """7.5""" },
    { "rate" : """12.95""" },
    { "rate" : """6.499""" },
    { "rate" : """7.4""" },
    { "rate" : """8.48""" },
    { "rate" : """7.7999""" },
    { "rate" : """14.5""" },
    { "rate" : """8.4999""" },
    { "rate" : """6.5""" },
    { "rate" : """2""" },
    { "rate" : """8.398""" },
    { "rate" : """14""" },
    { "rate" : """7.895""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """4.998""" },
    { "rate" : """7.49999""" },
    { "rate" : """7.88""" },
    { "rate" : """7.8""" },
    { "rate" : """7.989""" },
    { "rate" : """7.5""" },
    { "rate" : """7""" },
    { "rate" : """7.48998""" },
    { "rate" : """5""" },
    { "rate" : """7.5""" },
    { "rate" : """6""" },
    { "rate" : """15""" },
    { "rate" : """7.48997""" },
    { "rate" : """7""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """7.5""" },
    { "rate" : """6.5""" },
    { "rate" : """6.5""" },
    { "rate" : """6""" },
    { "rate" : """6.5""" },
    { "rate" : """7.89""" },
    { "rate" : """7.8""" },
    { "rate" : """7.5""" },
    { "rate" : """7""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """14.9999""" },
    { "rate" : """6.9999""" },
    { "rate" : """6.99999""" },
    { "rate" : """5""" },
    { "rate" : """14.49""" },
    { "rate" : """4.9""" },
    { "rate" : """7.49998""" },
    { "rate" : """7.8""" },
    { "rate" : """6.99""" },
    { "rate" : """14.99""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """13.1""" },
    { "rate" : """2""" },
    { "rate" : """14.99""" },
    { "rate" : """13.1""" },
    { "rate" : """6.5""" },
    { "rate" : """6.99""" },
    { "rate" : """4""" },
    { "rate" : """12.4""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """6.48""" },
    { "rate" : """13.11""" },
    { "rate" : """6.7""" },
    { "rate" : """13.11""" },
    { "rate" : """15""" },
    { "rate" : """9.83""" },
    { "rate" : """6.24""" },
    { "rate" : """7""" },
    { "rate" : """13.55""" },
    { "rate" : """4.9""" },
    { "rate" : """13""" },
    { "rate" : """15""" },
    { "rate" : """13""" },
    { "rate" : """12.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """14.95""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """14.98""" },
    { "rate" : """2""" },
    { "rate" : """6.5""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """11.99""" },
    { "rate" : """11.98999""" },
    { "rate" : """4.99""" },
    { "rate" : """4.9""" },
    { "rate" : """15""" },
    { "rate" : """4.85""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """4.89""" },
    { "rate" : """12.12""" },
    { "rate" : """8""" },
    { "rate" : """13.09""" },
    { "rate" : """4.8999""" },
    { "rate" : """6.5""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """9.98""" },
    { "rate" : """6.5""" },
    { "rate" : """6.5""" },
    { "rate" : """13.5""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """5.98""" },
    { "rate" : """0.38888""" },
    { "rate" : """8""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """6.5""" },
    { "rate" : """10""" },
    { "rate" : """6.5""" },
    { "rate" : """15""" },
    { "rate" : """7.9""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """4.95""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """13.10999""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.98""" },
    { "rate" : """14""" },
    { "rate" : """9.98""" },
    { "rate" : """0.95""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """4.99999""" },
    { "rate" : """14""" },
    { "rate" : """6.5""" },
    { "rate" : """12.9998""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """7.99999""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9.998""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """13""" },
    { "rate" : """4.98""" },
    { "rate" : """0.96""" },
    { "rate" : """9""" },
    { "rate" : """11.78998""" },
    { "rate" : """13""" },
    { "rate" : """4.99999""" },
    { "rate" : """15""" },
    { "rate" : """11.89""" },
    { "rate" : """12""" },
    { "rate" : """4.99""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """7.99999""" },
    { "rate" : """8.997""" },
    { "rate" : """5.99996""" },
    { "rate" : """8.89""" },
    { "rate" : """8.79699""" },
    { "rate" : """8.75""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """23.58""" },
    { "rate" : """7.7""" },
    { "rate" : """11""" },
    { "rate" : """6.5""" },
    { "rate" : """9.88""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9.87999""" },
    { "rate" : """13.11""" },
    { "rate" : """6.4""" },
    { "rate" : """8.797""" },
    { "rate" : """8""" },
    { "rate" : """12.46""" },
    { "rate" : """8.7""" },
    { "rate" : """0.97""" },
    { "rate" : """7.5""" },
    { "rate" : """5""" },
    { "rate" : """4.75""" },
    { "rate" : """9.11""" },
    { "rate" : """7""" },
    { "rate" : """13""" },
    { "rate" : """12.26""" },
    { "rate" : """5""" },
    { "rate" : """4.95""" },
    { "rate" : """10.75""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """6""" },
    { "rate" : """7.87""" },
    { "rate" : """4.9899""" },
    { "rate" : """0.96""" },
    { "rate" : """8""" },
    { "rate" : """4.99989""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """4.9998""" },
    { "rate" : """0.97999""" },
    { "rate" : """10""" },
    { "rate" : """7.9""" },
    { "rate" : """12""" },
    { "rate" : """8.997""" },
    { "rate" : """10""" },
    { "rate" : """9.9799""" },
    { "rate" : """1""" },
    { "rate" : """3.4""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """4.48998""" },
    { "rate" : """8""" },
    { "rate" : """0.95""" },
    { "rate" : """12.46""" },
    { "rate" : """4.4899""" },
    { "rate" : """10""" },
    { "rate" : """13""" },
    { "rate" : """7""" },
    { "rate" : """4.5""" },
    { "rate" : """9.5""" },
    { "rate" : """7.999""" },
    { "rate" : """8""" },
    { "rate" : """9.99""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12.25""" },
    { "rate" : """0.95""" },
    { "rate" : """9.89""" },
    { "rate" : """10""" },
    { "rate" : """9.98999""" },
    { "rate" : """2""" },
    { "rate" : """9.98998""" },
    { "rate" : """9.9599""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """8.11538""" },
    { "rate" : """5""" },
    { "rate" : """4.97""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9.95""" },
    { "rate" : """7.999""" },
    { "rate" : """5.98""" },
    { "rate" : """9.88""" },
    { "rate" : """5.98""" },
    { "rate" : """8.69""" },
    { "rate" : """14.99""" },
    { "rate" : """4.999""" },
    { "rate" : """3""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """8.889""" },
    { "rate" : """6.4989""" },
    { "rate" : """13.11""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """18.98""" },
    { "rate" : """2""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """9.96""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """6.5""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """2.5""" },
    { "rate" : """4.85""" },
    { "rate" : """10""" },
    { "rate" : """8.1""" },
    { "rate" : """9.86""" },
    { "rate" : """14.99""" },
    { "rate" : """10.1""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """14.89""" },
    { "rate" : """10.73""" },
    { "rate" : """10.5""" },
    { "rate" : """4.95""" },
    { "rate" : """14.99""" },
    { "rate" : """14.7""" },
    { "rate" : """14.69999""" },
    { "rate" : """10.49""" },
    { "rate" : """7""" },
    { "rate" : """14.89""" },
    { "rate" : """12.26""" },
    { "rate" : """8.3""" },
    { "rate" : """13.11""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """6.49911""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """14.68999""" },
    { "rate" : """9.96""" },
    { "rate" : """13""" },
    { "rate" : """6""" },
    { "rate" : """12.46""" },
    { "rate" : """12.45999""" },
    { "rate" : """11.98998""" },
    { "rate" : """8.8""" },
    { "rate" : """14.89""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """19.96""" },
    { "rate" : """15.1398""" },
    { "rate" : """9.96""" },
    { "rate" : """9.9""" },
    { "rate" : """14""" },
    { "rate" : """9.5""" },
    { "rate" : """15""" },
    { "rate" : """13.11""" },
    { "rate" : """15""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """11""" },
    { "rate" : """12.46""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """4.99""" },
    { "rate" : """10""" },
    { "rate" : """9.96""" },
    { "rate" : """11.98""" },
    { "rate" : """6.5""" },
    { "rate" : """8""" },
    { "rate" : """13.898""" },
    { "rate" : """10.11""" },
    { "rate" : """7""" },
    { "rate" : """6.99999""" },
    { "rate" : """8""" },
    { "rate" : """9.99973""" },
    { "rate" : """7.89""" },
    { "rate" : """9.56""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """15.13899""" },
    { "rate" : """13.11""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """9""" },
    { "rate" : """13.11""" },
    { "rate" : """9""" },
    { "rate" : """4.4987""" },
    { "rate" : """4.49""" },
    { "rate" : """14""" },
    { "rate" : """3.89""" },
    { "rate" : """4""" },
    { "rate" : """3.88999""" },
    { "rate" : """9""" },
    { "rate" : """4.19997""" },
    { "rate" : """4.5""" },
    { "rate" : """4.2""" },
    { "rate" : """4.9""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """4.5""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """14.898""" },
    { "rate" : """15""" },
    { "rate" : """4.9""" },
    { "rate" : """13.05""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """4.49""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """12.46""" },
    { "rate" : """9.99""" },
    { "rate" : """9""" },
    { "rate" : """4.5""" },
    { "rate" : """4.5""" },
    { "rate" : """18.98""" },
    { "rate" : """13""" },
    { "rate" : """12""" },
    { "rate" : """11.99999""" },
    { "rate" : """4.5""" },
    { "rate" : """13.11""" },
    { "rate" : """15""" },
    { "rate" : """14.46""" },
    { "rate" : """9.99""" },
    { "rate" : """14.95""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """6.49999""" },
    { "rate" : """14.98""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """9.999""" },
    { "rate" : """9.99""" },
    { "rate" : """4.99999""" },
    { "rate" : """13""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """4.2""" },
    { "rate" : """11""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """8.8""" },
    { "rate" : """4.6""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """4.4""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6.5""" },
    { "rate" : """6.45""" },
    { "rate" : """4.49""" },
    { "rate" : """6.5""" },
    { "rate" : """9.95""" },
    { "rate" : """12""" },
    { "rate" : """25""" },
    { "rate" : """4.9899""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """4.89999""" },
    { "rate" : """4.9""" },
    { "rate" : """4.89998""" },
    { "rate" : """4.9""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """11.9996""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """4.4""" },
    { "rate" : """4.9""" },
    { "rate" : """9.99""" },
    { "rate" : """12.257""" },
    { "rate" : """10.73""" },
    { "rate" : """4.8""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """13.1""" },
    { "rate" : """9.87998""" },
    { "rate" : """6.5""" },
    { "rate" : """0.4""" },
    { "rate" : """15""" },
    { "rate" : """4.56665""" },
    { "rate" : """0.25""" },
    { "rate" : """0.24999""" },
    { "rate" : """0.49""" },
    { "rate" : """0.29999""" },
    { "rate" : """12.46""" },
    { "rate" : """9.85""" },
    { "rate" : """12.25""" },
    { "rate" : """18.98""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """0.4706""" },
    { "rate" : """9.95""" },
    { "rate" : """23.58""" },
    { "rate" : """2""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """8.75""" },
    { "rate" : """28.58""" },
    { "rate" : """23.58""" },
    { "rate" : """14.9""" },
    { "rate" : """30""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """4""" },
    { "rate" : """6.55""" },
    { "rate" : """14""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """23.58""" },
    { "rate" : """23.49""" },
    { "rate" : """6.489""" },
    { "rate" : """6.5""" },
    { "rate" : """99.99""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """18.98""" },
    { "rate" : """29.98""" },
    { "rate" : """4.18""" },
    { "rate" : """11.81""" },
    { "rate" : """9.489""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """3.99999""" },
    { "rate" : """8.24997""" },
    { "rate" : """8.33""" },
    { "rate" : """13.11""" },
    { "rate" : """6.55""" },
    { "rate" : """11""" },
    { "rate" : """19.44445""" },
    { "rate" : """6.55""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """14.99""" },
    { "rate" : """19.9899""" },
    { "rate" : """7.8""" },
    { "rate" : """4.49""" },
    { "rate" : """8""" },
    { "rate" : """6.55""" },
    { "rate" : """9.879""" },
    { "rate" : """12.15""" },
    { "rate" : """3""" },
    { "rate" : """6.55""" },
    { "rate" : """8.8""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """12.4""" },
    { "rate" : """10""" },
    { "rate" : """6.55""" },
    { "rate" : """7.99999""" },
    { "rate" : """3.99999""" },
    { "rate" : """12.46""" },
    { "rate" : """0.4706""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """17.98""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """13.11""" },
    { "rate" : """8""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """14.99""" },
    { "rate" : """4.899""" },
    { "rate" : """15""" },
    { "rate" : """3.64""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """15.1""" },
    { "rate" : """3.64""" },
    { "rate" : """18.98""" },
    { "rate" : """12.46""" },
    { "rate" : """9.99""" },
    { "rate" : """7""" },
    { "rate" : """4.99""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """5.99""" },
    { "rate" : """5.95""" },
    { "rate" : """6""" },
    { "rate" : """3.64""" },
    { "rate" : """5.98""" },
    { "rate" : """5.99999""" },
    { "rate" : """4.499""" },
    { "rate" : """10""" },
    { "rate" : """5.25""" },
    { "rate" : """15""" },
    { "rate" : """12.46""" },
    { "rate" : """18.98""" },
    { "rate" : """6""" },
    { "rate" : """8.24997""" },
    { "rate" : """6.55""" },
    { "rate" : """12.46""" },
    { "rate" : """3.64""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """7.77""" },
    { "rate" : """6""" },
    { "rate" : """23.58""" },
    { "rate" : """18.98""" },
    { "rate" : """6""" },
    { "rate" : """5.99999""" },
    { "rate" : """18.98""" },
    { "rate" : """5.88""" },
    { "rate" : """6""" },
    { "rate" : """5.9""" },
    { "rate" : """3.6""" },
    { "rate" : """4.998""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """5.9""" },
    { "rate" : """12.46""" },
    { "rate" : """14.98""" },
    { "rate" : """3.64""" },
    { "rate" : """6.55""" },
    { "rate" : """8.8""" },
    { "rate" : """23.58""" },
    { "rate" : """18.98""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """5.895""" },
    { "rate" : """6""" },
    { "rate" : """12.46""" },
    { "rate" : """5.9""" },
    { "rate" : """12.46""" },
    { "rate" : """6.99999""" },
    { "rate" : """18""" },
    { "rate" : """9.99""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """5.99999""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """6.9""" },
    { "rate" : """6.89999""" },
    { "rate" : """6.99998""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """5.92""" },
    { "rate" : """6.75""" },
    { "rate" : """18.18""" },
    { "rate" : """8.8""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """3.64""" },
    { "rate" : """7""" },
    { "rate" : """5.9""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6.89""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """18.98""" },
    { "rate" : """7.76999""" },
    { "rate" : """6.9""" },
    { "rate" : """6.99999""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """6.9""" },
    { "rate" : """6.999""" },
    { "rate" : """7""" },
    { "rate" : """5.999""" },
    { "rate" : """6.99999""" },
    { "rate" : """6.9999""" },
    { "rate" : """15""" },
    { "rate" : """12.46""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """0.4706""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """18.98""" },
    { "rate" : """23.58""" },
    { "rate" : """18.98""" },
    { "rate" : """12.99""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """10""" },
    { "rate" : """18.98""" },
    { "rate" : """13.72""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """14.5""" },
    { "rate" : """9""" },
    { "rate" : """0.0499""" },
    { "rate" : """12.46""" },
    { "rate" : """0.137""" },
    { "rate" : """0.148""" },
    { "rate" : """18.98""" },
    { "rate" : """10.9999""" },
    { "rate" : """0.08999""" },
    { "rate" : """13.59""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """5.5""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """13""" },
    { "rate" : """4.8""" },
    { "rate" : """18.98""" },
    { "rate" : """3.64""" },
    { "rate" : """9.95""" },
    { "rate" : """12.4""" },
    { "rate" : """12.4599""" },
    { "rate" : """12""" },
    { "rate" : """9.99999""" },
    { "rate" : """13.72""" },
    { "rate" : """13.7""" },
    { "rate" : """9.94999""" },
    { "rate" : """12.46""" },
    { "rate" : """12""" },
    { "rate" : """12.39""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.4999""" },
    { "rate" : """0.7""" },
    { "rate" : """4.99""" },
    { "rate" : """1""" },
    { "rate" : """4.99""" },
    { "rate" : """9""" },
    { "rate" : """0.9""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """6""" },
    { "rate" : """5.99999""" },
    { "rate" : """6""" },
    { "rate" : """0.49989""" },
    { "rate" : """0.49989""" },
    { "rate" : """12.46""" },
    { "rate" : """15""" },
    { "rate" : """5.8""" },
    { "rate" : """12.46""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """8.64""" },
    { "rate" : """8.59""" },
    { "rate" : """5.9""" },
    { "rate" : """8.64""" },
    { "rate" : """6.55""" },
    { "rate" : """8""" },
    { "rate" : """8.64""" },
    { "rate" : """10""" },
    { "rate" : """11.9""" },
    { "rate" : """4.98""" },
    { "rate" : """15""" },
    { "rate" : """4.9""" },
    { "rate" : """4.89999""" },
    { "rate" : """8.7""" },
    { "rate" : """12.26""" },
    { "rate" : """3.64""" },
    { "rate" : """5""" },
    { "rate" : """5.95""" },
    { "rate" : """15.98""" },
    { "rate" : """10.46""" },
    { "rate" : """12.46""" },
    { "rate" : """23.58""" },
    { "rate" : """8.8""" },
    { "rate" : """23.56""" },
    { "rate" : """8.8""" },
    { "rate" : """13""" },
    { "rate" : """23.55999""" },
    { "rate" : """14.98""" },
    { "rate" : """4.99""" },
    { "rate" : """17""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """4.999""" },
    { "rate" : """18""" },
    { "rate" : """23.58""" },
    { "rate" : """9.999""" },
    { "rate" : """4.999""" },
    { "rate" : """23.5""" },
    { "rate" : """23.5""" },
    { "rate" : """5.97999""" },
    { "rate" : """10""" },
    { "rate" : """9.999""" },
    { "rate" : """23.58""" },
    { "rate" : """9.999""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """5.9""" },
    { "rate" : """14.98""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """12.45""" },
    { "rate" : """0.99998""" },
    { "rate" : """0.99997""" },
    { "rate" : """0.98999""" },
    { "rate" : """0.5""" },
    { "rate" : """18""" },
    { "rate" : """0.64""" },
    { "rate" : """23.58""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """0.49999""" },
    { "rate" : """5""" },
    { "rate" : """5.9""" },
    { "rate" : """0.5""" },
    { "rate" : """0.99""" },
    { "rate" : """0.49""" },
    { "rate" : """0.99997""" },
    { "rate" : """18.98""" },
    { "rate" : """0.9899""" },
    { "rate" : """0.9""" },
    { "rate" : """5.899""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.89""" },
    { "rate" : """0.989""" },
    { "rate" : """5.9""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """22""" },
    { "rate" : """17""" },
    { "rate" : """14.9999""" },
    { "rate" : """12.46""" },
    { "rate" : """5.99999""" },
    { "rate" : """23.58""" },
    { "rate" : """13""" },
    { "rate" : """4.98998""" },
    { "rate" : """18.98""" },
    { "rate" : """5.99""" },
    { "rate" : """12.46""" },
    { "rate" : """15""" },
    { "rate" : """12.99999""" },
    { "rate" : """16.99999""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """20.4""" },
    { "rate" : """17.5""" },
    { "rate" : """5""" },
    { "rate" : """18.89""" },
    { "rate" : """12.46""" },
    { "rate" : """24.99""" },
    { "rate" : """6.55""" },
    { "rate" : """23""" },
    { "rate" : """13""" },
    { "rate" : """12.25""" },
    { "rate" : """3.64""" },
    { "rate" : """4.9999""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """3.64""" },
    { "rate" : """1""" },
    { "rate" : """0.4999""" },
    { "rate" : """0.5""" },
    { "rate" : """1""" },
    { "rate" : """0.49989""" },
    { "rate" : """1""" },
    { "rate" : """14.99999""" },
    { "rate" : """10""" },
    { "rate" : """23""" },
    { "rate" : """18.98""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """6.11""" },
    { "rate" : """0.56""" },
    { "rate" : """3.73""" },
    { "rate" : """5""" },
    { "rate" : """6.10999""" },
    { "rate" : """6.5""" },
    { "rate" : """0.55999""" },
    { "rate" : """6.5""" },
    { "rate" : """0.56""" },
    { "rate" : """6.53""" },
    { "rate" : """0.56""" },
    { "rate" : """6.5""" },
    { "rate" : """0.55999""" },
    { "rate" : """6.4999""" },
    { "rate" : """9.999""" },
    { "rate" : """6.5""" },
    { "rate" : """14""" },
    { "rate" : """6.5""" },
    { "rate" : """12""" },
    { "rate" : """0.56""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """6.55""" },
    { "rate" : """6.5""" },
    { "rate" : """6.49999""" },
    { "rate" : """8.8""" },
    { "rate" : """6.4""" },
    { "rate" : """0.55987""" },
    { "rate" : """8""" },
    { "rate" : """6.4987""" },
    { "rate" : """15""" },
    { "rate" : """12.26""" },
    { "rate" : """5""" },
    { "rate" : """15""" },
    { "rate" : """6.5""" },
    { "rate" : """18.98""" },
    { "rate" : """0.56""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """0.56""" },
    { "rate" : """14.99999""" },
    { "rate" : """10""" },
    { "rate" : """0.56""" },
    { "rate" : """6.5""" },
    { "rate" : """6.4999""" },
    { "rate" : """4.8""" },
    { "rate" : """6.49999""" },
    { "rate" : """18.98""" },
    { "rate" : """15""" },
    { "rate" : """18.97999""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """6.5""" },
    { "rate" : """6.4998""" },
    { "rate" : """13.11""" },
    { "rate" : """6.55""" },
    { "rate" : """9""" },
    { "rate" : """8.8""" },
    { "rate" : """12.46""" },
    { "rate" : """12.26""" },
    { "rate" : """0.7""" },
    { "rate" : """6.49""" },
    { "rate" : """12.26""" },
    { "rate" : """13.11""" },
    { "rate" : """0.5""" },
    { "rate" : """6.5""" },
    { "rate" : """8.8""" },
    { "rate" : """11.99999""" },
    { "rate" : """0.4987""" },
    { "rate" : """0.9""" },
    { "rate" : """0.46998""" },
    { "rate" : """0.99897""" },
    { "rate" : """0.5""" },
    { "rate" : """0.89999""" },
    { "rate" : """10""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9989""" },
    { "rate" : """0.49869""" },
    { "rate" : """15""" },
    { "rate" : """0.88""" },
    { "rate" : """5""" },
    { "rate" : """0.48""" },
    { "rate" : """12""" },
    { "rate" : """0.999""" },
    { "rate" : """0.95""" },
    { "rate" : """13.1""" },
    { "rate" : """13.11""" },
    { "rate" : """6.5""" },
    { "rate" : """0.47""" },
    { "rate" : """8.8""" },
    { "rate" : """3.64""" },
    { "rate" : """0.99""" },
    { "rate" : """4.9999""" },
    { "rate" : """0.99989""" },
    { "rate" : """12.26""" },
    { "rate" : """0.48""" },
    { "rate" : """0.99899""" },
    { "rate" : """6""" },
    { "rate" : """0.49""" },
    { "rate" : """14.99999""" },
    { "rate" : """6""" },
    { "rate" : """0.48""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """12.45""" },
    { "rate" : """0.8""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """11.99""" },
    { "rate" : """4.99999""" },
    { "rate" : """14.9999""" },
    { "rate" : """12.46""" },
    { "rate" : """11.88""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """6.48""" },
    { "rate" : """0.975""" },
    { "rate" : """0.4""" },
    { "rate" : """0.9""" },
    { "rate" : """5""" },
    { "rate" : """9.94""" },
    { "rate" : """9.94""" },
    { "rate" : """8""" },
    { "rate" : """7.99999""" },
    { "rate" : """14.99999""" },
    { "rate" : """13.09999""" },
    { "rate" : """5""" },
    { "rate" : """10.73""" },
    { "rate" : """6""" },
    { "rate" : """0.47""" },
    { "rate" : """12""" },
    { "rate" : """8.2""" },
    { "rate" : """0.47""" },
    { "rate" : """8""" },
    { "rate" : """0.9999""" },
    { "rate" : """11.75""" },
    { "rate" : """0.48""" },
    { "rate" : """3""" },
    { "rate" : """12.46""" },
    { "rate" : """4.9""" },
    { "rate" : """8.88""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """11.98""" },
    { "rate" : """0.56""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """23.58""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """8.8""" },
    { "rate" : """8.2""" },
    { "rate" : """12.25""" },
    { "rate" : """9.93""" },
    { "rate" : """3.64""" },
    { "rate" : """9""" },
    { "rate" : """0.99889""" },
    { "rate" : """8.799""" },
    { "rate" : """7""" },
    { "rate" : """9.5""" },
    { "rate" : """7.5""" },
    { "rate" : """9.999""" },
    { "rate" : """6.55""" },
    { "rate" : """4.95""" },
    { "rate" : """9.94998""" },
    { "rate" : """9.98998""" },
    { "rate" : """3.63""" },
    { "rate" : """0.98""" },
    { "rate" : """13.11""" },
    { "rate" : """12""" },
    { "rate" : """8.5""" },
    { "rate" : """12.46""" },
    { "rate" : """4.99""" },
    { "rate" : """0.95""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """0.99""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """8""" },
    { "rate" : """0.8""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """9.955""" },
    { "rate" : """0.89989""" },
    { "rate" : """9.99""" },
    { "rate" : """6.5""" },
    { "rate" : """9""" },
    { "rate" : """4.9998""" },
    { "rate" : """10.93""" },
    { "rate" : """9.934""" },
    { "rate" : """1""" },
    { "rate" : """12.26""" },
    { "rate" : """4.95""" },
    { "rate" : """6""" },
    { "rate" : """9.9899""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """0.4999""" },
    { "rate" : """1""" },
    { "rate" : """13.11""" },
    { "rate" : """10.73""" },
    { "rate" : """12.46""" },
    { "rate" : """0.5""" },
    { "rate" : """12.26""" },
    { "rate" : """12""" },
    { "rate" : """10.7""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """8.8""" },
    { "rate" : """9.9""" },
    { "rate" : """9""" },
    { "rate" : """0.9997""" },
    { "rate" : """0.5""" },
    { "rate" : """8.81""" },
    { "rate" : """6.55""" },
    { "rate" : """9.95999""" },
    { "rate" : """0.9899""" },
    { "rate" : """9.98998""" },
    { "rate" : """7""" },
    { "rate" : """0.5""" },
    { "rate" : """0.46""" },
    { "rate" : """9.99""" },
    { "rate" : """8.7""" },
    { "rate" : """9.8999""" },
    { "rate" : """6.5""" },
    { "rate" : """0.97""" },
    { "rate" : """18.98""" },
    { "rate" : """5""" },
    { "rate" : """9.97""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """11.98""" },
    { "rate" : """3.65""" },
    { "rate" : """0.974""" },
    { "rate" : """0.9""" },
    { "rate" : """5.5""" },
    { "rate" : """6""" },
    { "rate" : """5.01""" },
    { "rate" : """8.79999""" },
    { "rate" : """10""" },
    { "rate" : """0.9""" },
    { "rate" : """8.8""" },
    { "rate" : """6.48""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """12.46""" },
    { "rate" : """14.89""" },
    { "rate" : """10.73""" },
    { "rate" : """23.58""" },
    { "rate" : """12.46""" },
    { "rate" : """12.989""" },
    { "rate" : """10.73""" },
    { "rate" : """6.24""" },
    { "rate" : """1""" },
    { "rate" : """10.73""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """3.64""" },
    { "rate" : """12.26""" },
    { "rate" : """12.46""" },
    { "rate" : """6.65""" },
    { "rate" : """12.46""" },
    { "rate" : """6.55""" },
    { "rate" : """8.8""" },
    { "rate" : """12.26""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """6.55""" },
    { "rate" : """0.5""" },
    { "rate" : """12""" },
    { "rate" : """0.96""" },
    { "rate" : """6""" },
    { "rate" : """3.64""" },
    { "rate" : """10.73""" },
    { "rate" : """10""" },
    { "rate" : """10.73""" },
    { "rate" : """9.99999""" },
    { "rate" : """13.71""" },
    { "rate" : """2""" },
    { "rate" : """6.5""" },
    { "rate" : """3.64""" },
    { "rate" : """11.5""" },
    { "rate" : """9.99""" },
    { "rate" : """9.99999""" },
    { "rate" : """8.4999""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """12.26""" },
    { "rate" : """4.99999""" },
    { "rate" : """6.55""" },
    { "rate" : """13.72""" },
    { "rate" : """12.46""" },
    { "rate" : """12.98""" },
    { "rate" : """9.99""" },
    { "rate" : """9.99999""" },
    { "rate" : """10.73""" },
    { "rate" : """12.46""" },
    { "rate" : """9.98""" },
    { "rate" : """13.72""" },
    { "rate" : """12.26""" },
    { "rate" : """13.11""" },
    { "rate" : """8.8""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """12.26""" },
    { "rate" : """10.73""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """1""" },
    { "rate" : """6.55""" },
    { "rate" : """12.46""" },
    { "rate" : """6.55""" },
    { "rate" : """13.72""" },
    { "rate" : """6""" },
    { "rate" : """6.5""" },
    { "rate" : """8""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """6.5""" },
    { "rate" : """1""" },
    { "rate" : """23.58""" },
    { "rate" : """13.11""" },
    { "rate" : """12.26""" },
    { "rate" : """13.11""" },
    { "rate" : """6.55""" },
    { "rate" : """6""" },
    { "rate" : """23.58""" },
    { "rate" : """6.55""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """9.98""" },
    { "rate" : """0.5""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """12.46""" },
    { "rate" : """6.55""" },
    { "rate" : """2""" },
    { "rate" : """15""" },
    { "rate" : """15.489""" },
    { "rate" : """8.4""" },
    { "rate" : """13.11""" },
    { "rate" : """6.55""" },
    { "rate" : """9.997""" },
    { "rate" : """13.11""" },
    { "rate" : """12.46""" },
    { "rate" : """13.72""" },
    { "rate" : """12.46""" },
    { "rate" : """6.55""" },
    { "rate" : """15.48""" },
    { "rate" : """12.2""" },
    { "rate" : """15""" },
    { "rate" : """7.5""" },
    { "rate" : """6.49998""" },
    { "rate" : """15.48999""" },
    { "rate" : """13.11""" },
    { "rate" : """9.999""" },
    { "rate" : """15""" },
    { "rate" : """13""" },
    { "rate" : """6.55""" },
    { "rate" : """10.7""" },
    { "rate" : """10""" },
    { "rate" : """13.58""" },
    { "rate" : """6""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """11.99""" },
    { "rate" : """13""" },
    { "rate" : """4.99""" },
    { "rate" : """12""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """3.64""" },
    { "rate" : """10""" },
    { "rate" : """0.4706""" },
    { "rate" : """10""" },
    { "rate" : """12.26""" },
    { "rate" : """13.11""" },
    { "rate" : """12""" },
    { "rate" : """6.55""" },
    { "rate" : """0.9988""" },
    { "rate" : """7.5""" },
    { "rate" : """7""" },
    { "rate" : """6.99999""" },
    { "rate" : """7.5""" },
    { "rate" : """7.25""" },
    { "rate" : """9.95""" },
    { "rate" : """8.8""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """7.99999""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """7.25""" },
    { "rate" : """11""" },
    { "rate" : """4.89""" },
    { "rate" : """7""" },
    { "rate" : """13.11""" },
    { "rate" : """6.5""" },
    { "rate" : """7""" },
    { "rate" : """8.6""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """4.87999""" },
    { "rate" : """9.9999""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """13.72""" },
    { "rate" : """11.9999""" },
    { "rate" : """8.8""" },
    { "rate" : """23.58""" },
    { "rate" : """13.6999""" },
    { "rate" : """6.55""" },
    { "rate" : """12.26""" },
    { "rate" : """4.9""" },
    { "rate" : """0.56""" },
    { "rate" : """9.9999""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """12""" },
    { "rate" : """7.9999""" },
    { "rate" : """7.99""" },
    { "rate" : """10""" },
    { "rate" : """7.5""" },
    { "rate" : """7""" },
    { "rate" : """4.9""" },
    { "rate" : """13.72""" },
    { "rate" : """8.34777""" },
    { "rate" : """9""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """4.99999""" },
    { "rate" : """11.9999""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """8.777""" },
    { "rate" : """3.64""" },
    { "rate" : """0.5599""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """7.5""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """12.26""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4.98""" },
    { "rate" : """7""" },
    { "rate" : """4.98""" },
    { "rate" : """7.49999""" },
    { "rate" : """7.2""" },
    { "rate" : """4.99998""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """3.64""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """3.64""" },
    { "rate" : """7.5""" },
    { "rate" : """12.25""" },
    { "rate" : """9.99""" },
    { "rate" : """7.49""" },
    { "rate" : """9.99""" },
    { "rate" : """6.49""" },
    { "rate" : """4.99""" },
    { "rate" : """6""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """12.22""" },
    { "rate" : """7.49""" },
    { "rate" : """5""" },
    { "rate" : """9.98""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """23.58""" },
    { "rate" : """4.89""" },
    { "rate" : """5""" },
    { "rate" : """11.9899""" },
    { "rate" : """15""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """7.5""" },
    { "rate" : """10""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.7999""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9.8999""" },
    { "rate" : """9""" },
    { "rate" : """13.11""" },
    { "rate" : """4.5""" },
    { "rate" : """4.99""" },
    { "rate" : """13.72""" },
    { "rate" : """13.11""" },
    { "rate" : """12.25999""" },
    { "rate" : """6.4""" },
    { "rate" : """13.11""" },
    { "rate" : """4.96998""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """16.17""" },
    { "rate" : """12.45999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """4.99999""" },
    { "rate" : """13.1""" },
    { "rate" : """11.2""" },
    { "rate" : """4.999""" },
    { "rate" : """12""" },
    { "rate" : """9""" },
    { "rate" : """4.99998""" },
    { "rate" : """11.99""" },
    { "rate" : """4.97""" },
    { "rate" : """9.9""" },
    { "rate" : """8.8""" },
    { "rate" : """13.72""" },
    { "rate" : """7.499""" },
    { "rate" : """13.11""" },
    { "rate" : """0.56""" },
    { "rate" : """9.998""" },
    { "rate" : """13.72""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """5.98""" },
    { "rate" : """5.98999""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """0.97998""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.98999""" },
    { "rate" : """7.5""" },
    { "rate" : """0.9""" },
    { "rate" : """0.89""" },
    { "rate" : """6.499""" },
    { "rate" : """0.56001""" },
    { "rate" : """7.99""" },
    { "rate" : """7.98999""" },
    { "rate" : """9.9""" },
    { "rate" : """12.39""" },
    { "rate" : """11.11111""" },
    { "rate" : """12""" },
    { "rate" : """9.95""" },
    { "rate" : """5.98998""" },
    { "rate" : """10""" },
    { "rate" : """13.69999""" },
    { "rate" : """12""" },
    { "rate" : """5.88""" },
    { "rate" : """11.25""" },
    { "rate" : """10""" },
    { "rate" : """7.5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3.99""" },
    { "rate" : """10""" },
    { "rate" : """12.26""" },
    { "rate" : """4""" },
    { "rate" : """11.1""" },
    { "rate" : """3.98999""" },
    { "rate" : """0.55""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3.9989""" },
    { "rate" : """3.9798""" },
    { "rate" : """5.98""" },
    { "rate" : """3.95""" },
    { "rate" : """6""" },
    { "rate" : """0.5599""" },
    { "rate" : """4.9""" },
    { "rate" : """12""" },
    { "rate" : """3.99""" },
    { "rate" : """3.8999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5.5""" },
    { "rate" : """3.99""" },
    { "rate" : """3.8""" },
    { "rate" : """0.38888""" },
    { "rate" : """3.9799""" },
    { "rate" : """0.38887""" },
    { "rate" : """0.9""" },
    { "rate" : """0.95999""" },
    { "rate" : """0.8""" },
    { "rate" : """16.17""" },
    { "rate" : """0.5""" },
    { "rate" : """0.95""" },
    { "rate" : """0.6975""" },
    { "rate" : """0.95998""" },
    { "rate" : """0.9699""" },
    { "rate" : """0.7""" },
    { "rate" : """0.96""" },
    { "rate" : """10.6""" },
    { "rate" : """0.9""" },
    { "rate" : """11.9""" },
    { "rate" : """0.87""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9""" },
    { "rate" : """11.1111""" },
    { "rate" : """5.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """11.8""" },
    { "rate" : """5.99""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """16.17""" },
    { "rate" : """4.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """13.71""" },
    { "rate" : """10""" },
    { "rate" : """6.49""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """13.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """9.96""" },
    { "rate" : """4.98998""" },
    { "rate" : """4.9""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """5.99""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """11.46""" },
    { "rate" : """11.5""" },
    { "rate" : """23.58""" },
    { "rate" : """4.88""" },
    { "rate" : """23.58""" },
    { "rate" : """11""" },
    { "rate" : """11""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """11""" },
    { "rate" : """2.5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.87""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.5""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.89""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.9""" },
    { "rate" : """2.49998""" },
    { "rate" : """3""" },
    { "rate" : """9.99998""" },
    { "rate" : """2.99888""" },
    { "rate" : """9.96""" },
    { "rate" : """2.99""" },
    { "rate" : """2.95""" },
    { "rate" : """2.89""" },
    { "rate" : """13.1""" },
    { "rate" : """6""" },
    { "rate" : """7.5""" },
    { "rate" : """3""" },
    { "rate" : """2.5""" },
    { "rate" : """2.9""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """11.9899""" },
    { "rate" : """3""" },
    { "rate" : """2.5""" },
    { "rate" : """2.49""" },
    { "rate" : """6""" },
    { "rate" : """2.8""" },
    { "rate" : """2.8""" },
    { "rate" : """13.72""" },
    { "rate" : """11.66668""" },
    { "rate" : """2.9999""" },
    { "rate" : """2.5""" },
    { "rate" : """7.99""" },
    { "rate" : """2.95""" },
    { "rate" : """11""" },
    { "rate" : """5""" },
    { "rate" : """2.99999""" },
    { "rate" : """5.98""" },
    { "rate" : """3""" },
    { "rate" : """2.8""" },
    { "rate" : """2.95""" },
    { "rate" : """16.17""" },
    { "rate" : """13.72""" },
    { "rate" : """2.98""" },
    { "rate" : """7.9999""" },
    { "rate" : """11.55555""" },
    { "rate" : """8""" },
    { "rate" : """6.48999""" },
    { "rate" : """2.5""" },
    { "rate" : """10""" },
    { "rate" : """2.8""" },
    { "rate" : """3""" },
    { "rate" : """2.95""" },
    { "rate" : """2.75""" },
    { "rate" : """16.17""" },
    { "rate" : """2.49999""" },
    { "rate" : """3""" },
    { "rate" : """12.46""" },
    { "rate" : """3""" },
    { "rate" : """23.58""" },
    { "rate" : """7.5""" },
    { "rate" : """13.11""" },
    { "rate" : """12""" },
    { "rate" : """2.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """13.11""" },
    { "rate" : """23.58""" },
    { "rate" : """12.26""" },
    { "rate" : """7""" },
    { "rate" : """9.96""" },
    { "rate" : """12.46""" },
    { "rate" : """13.72""" },
    { "rate" : """12.26""" },
    { "rate" : """2.75""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """7.5""" },
    { "rate" : """8.8""" },
    { "rate" : """11.99""" },
    { "rate" : """5""" },
    { "rate" : """2.999""" },
    { "rate" : """23.58""" },
    { "rate" : """12.26""" },
    { "rate" : """16.17""" },
    { "rate" : """8.9""" },
    { "rate" : """9.96""" },
    { "rate" : """13.72""" },
    { "rate" : """9.1""" },
    { "rate" : """2.7""" },
    { "rate" : """2.74998""" },
    { "rate" : """4.9999""" },
    { "rate" : """12.46""" },
    { "rate" : """2.9999""" },
    { "rate" : """6""" },
    { "rate" : """5.999""" },
    { "rate" : """12""" },
    { "rate" : """5.99999""" },
    { "rate" : """11.99999""" },
    { "rate" : """2.59999""" },
    { "rate" : """4""" },
    { "rate" : """2.99""" },
    { "rate" : """2.5""" },
    { "rate" : """7.5""" },
    { "rate" : """2.98""" },
    { "rate" : """2.5""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """8.5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """14.9999""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """11.5""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """12.46""" },
    { "rate" : """6.86""" },
    { "rate" : """12.3""" },
    { "rate" : """4.9999""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """2.99998""" },
    { "rate" : """6.5""" },
    { "rate" : """11.49""" },
    { "rate" : """6.5""" },
    { "rate" : """16.17""" },
    { "rate" : """13.11""" },
    { "rate" : """11.49999""" },
    { "rate" : """3""" },
    { "rate" : """2.88""" },
    { "rate" : """9""" },
    { "rate" : """10.46""" },
    { "rate" : """10.72""" },
    { "rate" : """5.55""" },
    { "rate" : """6.55""" },
    { "rate" : """2.8""" },
    { "rate" : """6.4""" },
    { "rate" : """6.55""" },
    { "rate" : """12.26""" },
    { "rate" : """6.2""" },
    { "rate" : """7.4""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """2.49998""" },
    { "rate" : """6.55""" },
    { "rate" : """5.9999""" },
    { "rate" : """16.17""" },
    { "rate" : """12""" },
    { "rate" : """2.9""" },
    { "rate" : """0.498""" },
    { "rate" : """0.4""" },
    { "rate" : """0.45""" },
    { "rate" : """0.45""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7.6""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.44999""" },
    { "rate" : """0.4899""" },
    { "rate" : """0.3999""" },
    { "rate" : """0.45""" },
    { "rate" : """0.4""" },
    { "rate" : """0.42""" },
    { "rate" : """0.498""" },
    { "rate" : """0.49""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """0.49""" },
    { "rate" : """0.41""" },
    { "rate" : """6.55""" },
    { "rate" : """6.4""" },
    { "rate" : """8.17""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """23.58""" },
    { "rate" : """13.11""" },
    { "rate" : """5.99""" },
    { "rate" : """12.46""" },
    { "rate" : """7.4""" },
    { "rate" : """4.99""" },
    { "rate" : """2.999""" },
    { "rate" : """16.17""" },
    { "rate" : """3.5""" },
    { "rate" : """4""" },
    { "rate" : """2.99989""" },
    { "rate" : """16.17""" },
    { "rate" : """14.99999""" },
    { "rate" : """2.989""" },
    { "rate" : """2.998""" },
    { "rate" : """2.9""" },
    { "rate" : """8.8""" },
    { "rate" : """7.95""" },
    { "rate" : """2.99""" },
    { "rate" : """2.84""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """2.48""" },
    { "rate" : """9.99999""" },
    { "rate" : """4.99999""" },
    { "rate" : """15""" },
    { "rate" : """5.98""" },
    { "rate" : """8""" },
    { "rate" : """13.11""" },
    { "rate" : """15""" },
    { "rate" : """10.98""" },
    { "rate" : """8""" },
    { "rate" : """2.994""" },
    { "rate" : """16.72""" },
    { "rate" : """2.9""" },
    { "rate" : """5.9999""" },
    { "rate" : """15""" },
    { "rate" : """16.99999""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """13.10999""" },
    { "rate" : """23.5""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """12.25999""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """2.95""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """17""" },
    { "rate" : """14.9""" },
    { "rate" : """16.88""" },
    { "rate" : """3""" },
    { "rate" : """23.58""" },
    { "rate" : """16.71""" },
    { "rate" : """13.72""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """14.5""" },
    { "rate" : """16""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """0.4""" },
    { "rate" : """7.9499""" },
    { "rate" : """8""" },
    { "rate" : """2.991""" },
    { "rate" : """12.26""" },
    { "rate" : """13""" },
    { "rate" : """12.46""" },
    { "rate" : """8""" },
    { "rate" : """8.64""" },
    { "rate" : """8.64""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """7.99""" },
    { "rate" : """5""" },
    { "rate" : """8.64""" },
    { "rate" : """23.4999""" },
    { "rate" : """8.64""" },
    { "rate" : """7.9""" },
    { "rate" : """2.99999""" },
    { "rate" : """4.99998""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """7.49999""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """2.9999""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """2.98999""" },
    { "rate" : """9.95""" },
    { "rate" : """8.79999""" },
    { "rate" : """3""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """12.46""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """8.1""" },
    { "rate" : """2.5""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """9.96""" },
    { "rate" : """8.7998""" },
    { "rate" : """12.44""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """6.4499""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """12.29""" },
    { "rate" : """8.8""" },
    { "rate" : """6""" },
    { "rate" : """6.1""" },
    { "rate" : """8.8""" },
    { "rate" : """1""" },
    { "rate" : """0.1""" },
    { "rate" : """0.01""" },
    { "rate" : """0.1""" },
    { "rate" : """9.9""" },
    { "rate" : """8""" },
    { "rate" : """14""" },
    { "rate" : """7""" },
    { "rate" : """12.46""" },
    { "rate" : """5.2""" },
    { "rate" : """9.96""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """12.46""" },
    { "rate" : """4.98998""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """8""" },
    { "rate" : """8.98""" },
    { "rate" : """9.96""" },
    { "rate" : """8.5""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """8.4999""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """8.9999""" },
    { "rate" : """9""" },
    { "rate" : """9.96""" },
    { "rate" : """8.79998""" },
    { "rate" : """8.3""" },
    { "rate" : """10""" },
    { "rate" : """4.89""" },
    { "rate" : """7.99""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """12.46""" },
    { "rate" : """9.95999""" },
    { "rate" : """9.99999""" },
    { "rate" : """7.95""" },
    { "rate" : """7.95""" },
    { "rate" : """9""" },
    { "rate" : """12.46""" },
    { "rate" : """9""" },
    { "rate" : """8.79""" },
    { "rate" : """8.79""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """6.5""" },
    { "rate" : """6""" },
    { "rate" : """12.46""" },
    { "rate" : """6.49""" },
    { "rate" : """13.5""" },
    { "rate" : """6.4898""" },
    { "rate" : """4.99899""" },
    { "rate" : """6""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8888""" },
    { "rate" : """6.389""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """12.46""" },
    { "rate" : """4.8999""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8.98""" },
    { "rate" : """9.98""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """8.2""" },
    { "rate" : """10""" },
    { "rate" : """4.99""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """7.9999""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """0.96999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.75""" },
    { "rate" : """0.45""" },
    { "rate" : """0.97""" },
    { "rate" : """0.9""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """0.8""" },
    { "rate" : """12.46""" },
    { "rate" : """0.8999""" },
    { "rate" : """8.8""" },
    { "rate" : """0.89988""" },
    { "rate" : """3""" },
    { "rate" : """9""" },
    { "rate" : """12.46""" },
    { "rate" : """4""" },
    { "rate" : """12.46""" },
    { "rate" : """0.9""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """8.7""" },
    { "rate" : """8.79999""" },
    { "rate" : """7.98998""" },
    { "rate" : """4.99""" },
    { "rate" : """8.79""" },
    { "rate" : """12.46""" },
    { "rate" : """7.9""" },
    { "rate" : """7""" },
    { "rate" : """3.9999""" },
    { "rate" : """9.89998""" },
    { "rate" : """4.98998""" },
    { "rate" : """0.9""" },
    { "rate" : """4.99999""" },
    { "rate" : """0.97998""" },
    { "rate" : """10""" },
    { "rate" : """2.49""" },
    { "rate" : """14.4""" },
    { "rate" : """2.5""" },
    { "rate" : """8.799""" },
    { "rate" : """0.98""" },
    { "rate" : """0.88""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """4.95""" },
    { "rate" : """0.89""" },
    { "rate" : """8.95""" },
    { "rate" : """5""" },
    { "rate" : """8.7999""" },
    { "rate" : """4.99999""" },
    { "rate" : """9""" },
    { "rate" : """12.46""" },
    { "rate" : """0.75999""" },
    { "rate" : """9.96""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """2.5""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9698""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """6.98""" },
    { "rate" : """8.79999""" },
    { "rate" : """8.799""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """8.99""" },
    { "rate" : """0.98""" },
    { "rate" : """8.8""" },
    { "rate" : """12.45""" },
    { "rate" : """12.46""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """12.45999""" },
    { "rate" : """9.96""" },
    { "rate" : """9.9""" },
    { "rate" : """8""" },
    { "rate" : """9.8""" },
    { "rate" : """9.95999""" },
    { "rate" : """0.88""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9.5""" },
    { "rate" : """10""" },
    { "rate" : """4.9999""" },
    { "rate" : """23.579""" },
    { "rate" : """0.49999""" },
    { "rate" : """8.79999""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """12.46""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """12.46""" },
    { "rate" : """9""" },
    { "rate" : """9.8""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """0.8""" },
    { "rate" : """5""" },
    { "rate" : """23.58""" },
    { "rate" : """0.85""" },
    { "rate" : """0.89886""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.2""" },
    { "rate" : """22.5""" },
    { "rate" : """0.18999""" },
    { "rate" : """0.27""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """12.46""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """1.99""" },
    { "rate" : """8""" },
    { "rate" : """0.9""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.199""" },
    { "rate" : """9.9999""" },
    { "rate" : """6.95""" },
    { "rate" : """8.8""" },
    { "rate" : """6""" },
    { "rate" : """7.99999""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """0.97""" },
    { "rate" : """2.95""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """0.9""" },
    { "rate" : """9.9""" },
    { "rate" : """2""" },
    { "rate" : """0.9""" },
    { "rate" : """1.999""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """3.24""" },
    { "rate" : """12.46""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """9.95""" },
    { "rate" : """0.7""" },
    { "rate" : """9.8""" },
    { "rate" : """10""" },
    { "rate" : """9.98""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.24""" },
    { "rate" : """5""" },
    { "rate" : """9.99899""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9.98""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """9.99""" },
    { "rate" : """23.58""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """9.95""" },
    { "rate" : """9.5""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """9.9999""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """0.79999""" },
    { "rate" : """3.24""" },
    { "rate" : """10""" },
    { "rate" : """9.9799""" },
    { "rate" : """12.26""" },
    { "rate" : """23.58""" },
    { "rate" : """4.9999""" },
    { "rate" : """10""" },
    { "rate" : """23.58""" },
    { "rate" : """12.26""" },
    { "rate" : """9""" },
    { "rate" : """12.45""" },
    { "rate" : """13""" },
    { "rate" : """0.98""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """4.5""" },
    { "rate" : """12.459""" },
    { "rate" : """5""" },
    { "rate" : """4.98""" },
    { "rate" : """10""" },
    { "rate" : """12.2""" },
    { "rate" : """3.24""" },
    { "rate" : """4.4999""" },
    { "rate" : """4.25""" },
    { "rate" : """4.3""" },
    { "rate" : """4.5""" },
    { "rate" : """4.5""" },
    { "rate" : """3.14""" },
    { "rate" : """0.89""" },
    { "rate" : """4.5""" },
    { "rate" : """9""" },
    { "rate" : """7.9999""" },
    { "rate" : """0.89989""" },
    { "rate" : """23.58""" },
    { "rate" : """3.24""" },
    { "rate" : """4.48""" },
    { "rate" : """23.58""" },
    { "rate" : """9.998""" },
    { "rate" : """9.99""" },
    { "rate" : """23.58""" },
    { "rate" : """0.89""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.7""" },
    { "rate" : """4.5""" },
    { "rate" : """4.3""" },
    { "rate" : """4.5""" },
    { "rate" : """3""" },
    { "rate" : """9.88""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """17.48""" },
    { "rate" : """4.48999""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """10""" },
    { "rate" : """9.72223""" },
    { "rate" : """17.48""" },
    { "rate" : """9.99""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """9.5""" },
    { "rate" : """9.999""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """12.2599""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """17.48""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """1""" },
    { "rate" : """4.4998""" },
    { "rate" : """4.5""" },
    { "rate" : """9.5""" },
    { "rate" : """5""" },
    { "rate" : """9.99""" },
    { "rate" : """12.46""" },
    { "rate" : """3.24""" },
    { "rate" : """7.8""" },
    { "rate" : """9.999""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """8""" },
    { "rate" : """3.24""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """4.5""" },
    { "rate" : """7.99999""" },
    { "rate" : """17.47998""" },
    { "rate" : """12.46""" },
    { "rate" : """17.48""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """17.48""" },
    { "rate" : """10""" },
    { "rate" : """11.5""" },
    { "rate" : """4.5""" },
    { "rate" : """9.9""" },
    { "rate" : """8""" },
    { "rate" : """9.5""" },
    { "rate" : """9.6""" },
    { "rate" : """4.49""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """17.48""" },
    { "rate" : """4.99999""" },
    { "rate" : """17.48""" },
    { "rate" : """16.5""" },
    { "rate" : """17.47""" },
    { "rate" : """4""" },
    { "rate" : """8.5""" },
    { "rate" : """3.9998""" },
    { "rate" : """3.98""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """3.24""" },
    { "rate" : """16""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3.24""" },
    { "rate" : """12.46""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """8.7999""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """9.9""" },
    { "rate" : """17.4789""" },
    { "rate" : """3.24""" },
    { "rate" : """3.23""" },
    { "rate" : """3.9999""" },
    { "rate" : """17.48""" },
    { "rate" : """3.75""" },
    { "rate" : """3.999""" },
    { "rate" : """8.8""" },
    { "rate" : """15""" },
    { "rate" : """7.9""" },
    { "rate" : """3.01""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """12.46""" },
    { "rate" : """7""" },
    { "rate" : """8.8""" },
    { "rate" : """4.9989""" },
    { "rate" : """7.89999""" },
    { "rate" : """10""" },
    { "rate" : """3.99999""" },
    { "rate" : """7.888""" },
    { "rate" : """5""" },
    { "rate" : """9.9""" },
    { "rate" : """3.75""" },
    { "rate" : """3""" },
    { "rate" : """23.58""" },
    { "rate" : """3.24""" },
    { "rate" : """12.46""" },
    { "rate" : """3.95""" },
    { "rate" : """3.89999""" },
    { "rate" : """3.95""" },
    { "rate" : """9.95""" },
    { "rate" : """3.74998""" },
    { "rate" : """3.24""" },
    { "rate" : """3.8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3.24""" },
    { "rate" : """8.7""" },
    { "rate" : """5.555""" },
    { "rate" : """9.9888""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """3.99""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """12.46""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """0.3""" },
    { "rate" : """9.9""" },
    { "rate" : """3.99999""" },
    { "rate" : """9.5""" },
    { "rate" : """9.99999""" },
    { "rate" : """7.26""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """9.25""" },
    { "rate" : """5""" },
    { "rate" : """3.79""" },
    { "rate" : """4.8""" },
    { "rate" : """4""" },
    { "rate" : """8.8""" },
    { "rate" : """0.3""" },
    { "rate" : """0.34987""" },
    { "rate" : """8""" },
    { "rate" : """3.9899""" },
    { "rate" : """7.9999""" },
    { "rate" : """12.46""" },
    { "rate" : """0.34896""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """0.35""" },
    { "rate" : """3.24""" },
    { "rate" : """10""" },
    { "rate" : """6.55""" },
    { "rate" : """12.46""" },
    { "rate" : """12""" },
    { "rate" : """3""" },
    { "rate" : """12.46""" },
    { "rate" : """3.24""" },
    { "rate" : """3.24""" },
    { "rate" : """0.3""" },
    { "rate" : """8.4999""" },
    { "rate" : """9.99999""" },
    { "rate" : """8.5""" },
    { "rate" : """3.1""" },
    { "rate" : """10""" },
    { "rate" : """9.5""" },
    { "rate" : """4.9""" },
    { "rate" : """7.89""" },
    { "rate" : """8""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """4.9""" },
    { "rate" : """12.4""" },
    { "rate" : """4.99""" },
    { "rate" : """1.89998""" },
    { "rate" : """4.99""" },
    { "rate" : """2""" },
    { "rate" : """4.9""" },
    { "rate" : """1.2""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1.9""" },
    { "rate" : """4.99""" },
    { "rate" : """0.89""" },
    { "rate" : """0.87""" },
    { "rate" : """5""" },
    { "rate" : """3.23""" },
    { "rate" : """0.5""" },
    { "rate" : """2""" },
    { "rate" : """12.26""" },
    { "rate" : """4.89998""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """2.94999""" },
    { "rate" : """1""" },
    { "rate" : """4.99999""" },
    { "rate" : """11""" },
    { "rate" : """12.43999""" },
    { "rate" : """10""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """9.24999""" },
    { "rate" : """1.4""" },
    { "rate" : """2.48999""" },
    { "rate" : """7.99999""" },
    { "rate" : """1.89""" },
    { "rate" : """6.97999""" },
    { "rate" : """23.58""" },
    { "rate" : """1""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """7.99999""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """0.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.49999""" },
    { "rate" : """4.5""" },
    { "rate" : """12.25""" },
    { "rate" : """4.49999""" },
    { "rate" : """5""" },
    { "rate" : """3.24""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """1.8""" },
    { "rate" : """12.39""" },
    { "rate" : """4.98""" },
    { "rate" : """3.2""" },
    { "rate" : """2""" },
    { "rate" : """9.8765""" },
    { "rate" : """3.24""" },
    { "rate" : """12.46""" },
    { "rate" : """4""" },
    { "rate" : """12.46""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """3.3""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """3.24""" },
    { "rate" : """5""" },
    { "rate" : """9.98""" },
    { "rate" : """9.99""" },
    { "rate" : """12.26""" },
    { "rate" : """9.99""" },
    { "rate" : """9.99""" },
    { "rate" : """3.99999""" },
    { "rate" : """10""" },
    { "rate" : """12.26""" },
    { "rate" : """3.24""" },
    { "rate" : """10""" },
    { "rate" : """12.26""" },
    { "rate" : """12.46""" },
    { "rate" : """6""" },
    { "rate" : """4.999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """3.99""" },
    { "rate" : """11.99""" },
    { "rate" : """12.46""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """11.98""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """9.99989""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """3.24""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12.45""" },
    { "rate" : """9.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """9.98""" },
    { "rate" : """10""" },
    { "rate" : """9.99""" },
    { "rate" : """12.26""" },
    { "rate" : """12.46""" },
    { "rate" : """0.4706""" },
    { "rate" : """6.55""" },
    { "rate" : """9.8""" },
    { "rate" : """9.8999""" },
    { "rate" : """12.249""" },
    { "rate" : """9""" },
    { "rate" : """12.4499""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """12.26""" },
    { "rate" : """6.55""" },
    { "rate" : """12.46""" },
    { "rate" : """12.45""" },
    { "rate" : """7""" },
    { "rate" : """9""" },
    { "rate" : """12.26""" },
    { "rate" : """6.55""" },
    { "rate" : """9""" },
    { "rate" : """6.55""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """9.99999""" },
    { "rate" : """6.55""" },
    { "rate" : """4.99""" },
    { "rate" : """6.5""" },
    { "rate" : """6.55""" },
    { "rate" : """4.99999""" },
    { "rate" : """6.54999""" },
    { "rate" : """6""" },
    { "rate" : """8.7""" },
    { "rate" : """8.8""" },
    { "rate" : """6.55""" },
    { "rate" : """4.95""" },
    { "rate" : """9.9999""" },
    { "rate" : """7""" },
    { "rate" : """6.99999""" },
    { "rate" : """8.78""" },
    { "rate" : """7""" },
    { "rate" : """12.46""" },
    { "rate" : """3.5""" },
    { "rate" : """3.5""" },
    { "rate" : """2.95""" },
    { "rate" : """3.49999""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """3.5""" },
    { "rate" : """2.94999""" },
    { "rate" : """23.57999""" },
    { "rate" : """23.58""" },
    { "rate" : """3.5""" },
    { "rate" : """12.46""" },
    { "rate" : """6.5""" },
    { "rate" : """3.48""" },
    { "rate" : """7""" },
    { "rate" : """3.5""" },
    { "rate" : """2""" },
    { "rate" : """3.4""" },
    { "rate" : """1""" },
    { "rate" : """3.4999""" },
    { "rate" : """8""" },
    { "rate" : """4.7""" },
    { "rate" : """3.49999""" },
    { "rate" : """4.5""" },
    { "rate" : """6.4""" },
    { "rate" : """23.58""" },
    { "rate" : """12.46""" },
    { "rate" : """23.57999""" },
    { "rate" : """23.5""" },
    { "rate" : """12.46""" },
    { "rate" : """4.99""" },
    { "rate" : """8.8""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """6.99""" },
    { "rate" : """9.99""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """8.79""" },
    { "rate" : """6.54""" },
    { "rate" : """8.79""" },
    { "rate" : """7""" },
    { "rate" : """6.98999""" },
    { "rate" : """6.99999""" },
    { "rate" : """6.99""" },
    { "rate" : """8.8""" },
    { "rate" : """4.9""" },
    { "rate" : """7""" },
    { "rate" : """6.54969""" },
    { "rate" : """6.54999""" },
    { "rate" : """4.99""" },
    { "rate" : """6.54999""" },
    { "rate" : """12.46""" },
    { "rate" : """6.99999""" },
    { "rate" : """4.98""" },
    { "rate" : """6.99999""" },
    { "rate" : """6.85""" },
    { "rate" : """7""" },
    { "rate" : """0.4706""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """6.5""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """4.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """8.8""" },
    { "rate" : """3.33""" },
    { "rate" : """9.85""" },
    { "rate" : """3.64""" },
    { "rate" : """3.44""" },
    { "rate" : """3.4""" },
    { "rate" : """3.32999""" },
    { "rate" : """3.64""" },
    { "rate" : """8.8""" },
    { "rate" : """3.44""" },
    { "rate" : """8.8""" },
    { "rate" : """3.44""" },
    { "rate" : """3.5""" },
    { "rate" : """8.5""" },
    { "rate" : """3.64""" },
    { "rate" : """7""" },
    { "rate" : """6.9""" },
    { "rate" : """8.8""" },
    { "rate" : """3.5""" },
    { "rate" : """7""" },
    { "rate" : """12.46""" },
    { "rate" : """3.6""" },
    { "rate" : """3.64""" },
    { "rate" : """8.8""" },
    { "rate" : """3.3""" },
    { "rate" : """12.46""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """7""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """4""" },
    { "rate" : """3.64""" },
    { "rate" : """12.46""" },
    { "rate" : """6.549""" },
    { "rate" : """3.64""" },
    { "rate" : """7""" },
    { "rate" : """3.6""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.44""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """3.64""" },
    { "rate" : """4.99""" },
    { "rate" : """9.99""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3""" },
    { "rate" : """3.43999""" },
    { "rate" : """9.99""" },
    { "rate" : """6.48998""" },
    { "rate" : """3.64""" },
    { "rate" : """8.8""" },
    { "rate" : """3.64""" },
    { "rate" : """7""" },
    { "rate" : """3.5""" },
    { "rate" : """3.64""" },
    { "rate" : """8.6""" },
    { "rate" : """3.64""" },
    { "rate" : """3.3""" },
    { "rate" : """8.8""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """3.3""" },
    { "rate" : """8.8""" },
    { "rate" : """18.97999""" },
    { "rate" : """15""" },
    { "rate" : """3.64""" },
    { "rate" : """6""" },
    { "rate" : """3.4""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """17.46""" },
    { "rate" : """18.97""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """8.8""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """3.4""" },
    { "rate" : """6.67""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """6.99998""" },
    { "rate" : """7""" },
    { "rate" : """3.64""" },
    { "rate" : """7""" },
    { "rate" : """4.99""" },
    { "rate" : """3.4""" },
    { "rate" : """8.7""" },
    { "rate" : """3""" },
    { "rate" : """2.9999""" },
    { "rate" : """3.44""" },
    { "rate" : """6.99""" },
    { "rate" : """8.8""" },
    { "rate" : """18.98""" },
    { "rate" : """3""" },
    { "rate" : """3.425""" },
    { "rate" : """3""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """3.64""" },
    { "rate" : """3""" },
    { "rate" : """1.99999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """8.5""" },
    { "rate" : """18.98""" },
    { "rate" : """17.48""" },
    { "rate" : """3""" },
    { "rate" : """6.9""" },
    { "rate" : """17.48""" },
    { "rate" : """8""" },
    { "rate" : """17.48""" },
    { "rate" : """3.99999""" },
    { "rate" : """3.64""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """9.99""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """3.44""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3""" },
    { "rate" : """2.99999""" },
    { "rate" : """5""" },
    { "rate" : """1""" },
    { "rate" : """8.79""" },
    { "rate" : """3.64""" },
    { "rate" : """4.98""" },
    { "rate" : """7""" },
    { "rate" : """5.99998""" },
    { "rate" : """7.97""" },
    { "rate" : """6""" },
    { "rate" : """5.9""" },
    { "rate" : """5.99""" },
    { "rate" : """5.89999""" },
    { "rate" : """7""" },
    { "rate" : """5.99999""" },
    { "rate" : """5.99999""" },
    { "rate" : """0.4706""" },
    { "rate" : """5.99""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """17.99""" },
    { "rate" : """9.98""" },
    { "rate" : """5.98""" },
    { "rate" : """3.43""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """8.8""" },
    { "rate" : """15""" },
    { "rate" : """3.2""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """5.95""" },
    { "rate" : """5.99999""" },
    { "rate" : """6""" },
    { "rate" : """3.44""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """5.89""" },
    { "rate" : """6""" },
    { "rate" : """5.99""" },
    { "rate" : """5.998""" },
    { "rate" : """8.8""" },
    { "rate" : """3.4""" },
    { "rate" : """7""" },
    { "rate" : """5.95""" },
    { "rate" : """6""" },
    { "rate" : """12.46""" },
    { "rate" : """5.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """9.9777""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """6.99999""" },
    { "rate" : """6""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """9.97999""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """5.98""" },
    { "rate" : """6.99999""" },
    { "rate" : """6.99""" },
    { "rate" : """6""" },
    { "rate" : """3.64""" },
    { "rate" : """8.8""" },
    { "rate" : """5.99999""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """18.98""" },
    { "rate" : """5.88""" },
    { "rate" : """3.64""" },
    { "rate" : """8.6""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """12.46""" },
    { "rate" : """3.64""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """5.99999""" },
    { "rate" : """17.48""" },
    { "rate" : """16.99""" },
    { "rate" : """16.98999""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """8.8""" },
    { "rate" : """16.99999""" },
    { "rate" : """6""" },
    { "rate" : """5.97999""" },
    { "rate" : """7""" },
    { "rate" : """2.5""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """12""" },
    { "rate" : """8.8""" },
    { "rate" : """22""" },
    { "rate" : """16.9899""" },
    { "rate" : """8.8""" },
    { "rate" : """17.48""" },
    { "rate" : """17.48""" },
    { "rate" : """8.8""" },
    { "rate" : """17.48""" },
    { "rate" : """1""" },
    { "rate" : """15.99""" },
    { "rate" : """0.99999""" },
    { "rate" : """12.46""" },
    { "rate" : """12.99""" },
    { "rate" : """13.72""" },
    { "rate" : """13.7""" },
    { "rate" : """9.99999""" },
    { "rate" : """5.9999""" },
    { "rate" : """22""" },
    { "rate" : """8.8""" },
    { "rate" : """3""" },
    { "rate" : """3.44""" },
    { "rate" : """12.45""" },
    { "rate" : """12.44999""" },
    { "rate" : """20.48""" },
    { "rate" : """17.47999""" },
    { "rate" : """8.8""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """13.71""" },
    { "rate" : """3.99999""" },
    { "rate" : """4.9997""" },
    { "rate" : """3.64""" },
    { "rate" : """8.8""" },
    { "rate" : """7.9999""" },
    { "rate" : """5.999""" },
    { "rate" : """5.985""" },
    { "rate" : """1.1""" },
    { "rate" : """1""" },
    { "rate" : """1.09999""" },
    { "rate" : """0.5""" },
    { "rate" : """13.72""" },
    { "rate" : """3.64""" },
    { "rate" : """0.89999""" },
    { "rate" : """17.48""" },
    { "rate" : """13.72""" },
    { "rate" : """9.6""" },
    { "rate" : """14.98""" },
    { "rate" : """3.64""" },
    { "rate" : """2.89999""" },
    { "rate" : """8""" },
    { "rate" : """3""" },
    { "rate" : """3.44""" },
    { "rate" : """1""" },
    { "rate" : """13.7""" },
    { "rate" : """3.64""" },
    { "rate" : """6.99999""" },
    { "rate" : """8""" },
    { "rate" : """0.75999""" },
    { "rate" : """18.98""" },
    { "rate" : """3.63""" },
    { "rate" : """10.73""" },
    { "rate" : """8""" },
    { "rate" : """13.72""" },
    { "rate" : """3""" },
    { "rate" : """23.5""" },
    { "rate" : """23.58""" },
    { "rate" : """23""" },
    { "rate" : """21.99""" },
    { "rate" : """0.5""" },
    { "rate" : """21.98999""" },
    { "rate" : """23.57999""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """7.99999""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """9.96""" },
    { "rate" : """8.99""" },
    { "rate" : """2.5""" },
    { "rate" : """3""" },
    { "rate" : """3.99999""" },
    { "rate" : """8.98999""" },
    { "rate" : """6.8""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """5.85""" },
    { "rate" : """1""" },
    { "rate" : """13.72""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """2.1""" },
    { "rate" : """8.8""" },
    { "rate" : """2.99""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """3.44""" },
    { "rate" : """12.45""" },
    { "rate" : """5.99999""" },
    { "rate" : """5.9999""" },
    { "rate" : """1.99999""" },
    { "rate" : """12.99998""" },
    { "rate" : """9.96""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """8.8""" },
    { "rate" : """9.96""" },
    { "rate" : """6.99999""" },
    { "rate" : """3.64""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """5.999""" },
    { "rate" : """12.99""" },
    { "rate" : """12.333""" },
    { "rate" : """8.8""" },
    { "rate" : """13.71""" },
    { "rate" : """3.2""" },
    { "rate" : """3.64""" },
    { "rate" : """2""" },
    { "rate" : """8.6""" },
    { "rate" : """12.2""" },
    { "rate" : """8.8""" },
    { "rate" : """2.88""" },
    { "rate" : """5.99""" },
    { "rate" : """8.5""" },
    { "rate" : """6.89""" },
    { "rate" : """10.96""" },
    { "rate" : """5.9""" },
    { "rate" : """7.99""" },
    { "rate" : """19.99""" },
    { "rate" : """8.69""" },
    { "rate" : """12""" },
    { "rate" : """9.96""" },
    { "rate" : """12.46""" },
    { "rate" : """5.9""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """8.8""" },
    { "rate" : """0.99999""" },
    { "rate" : """6.998""" },
    { "rate" : """4.98""" },
    { "rate" : """1""" },
    { "rate" : """5.99988""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """7""" },
    { "rate" : """8.99""" },
    { "rate" : """6""" },
    { "rate" : """1""" },
    { "rate" : """5.9""" },
    { "rate" : """7""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """5.99999""" },
    { "rate" : """1""" },
    { "rate" : """5.95""" },
    { "rate" : """6""" },
    { "rate" : """12.46""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.72999""" },
    { "rate" : """5.999""" },
    { "rate" : """0.1""" },
    { "rate" : """10.73""" },
    { "rate" : """13.72""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """8.8""" },
    { "rate" : """13.72""" },
    { "rate" : """7""" },
    { "rate" : """0.4706""" },
    { "rate" : """5.9999""" },
    { "rate" : """13.71999""" },
    { "rate" : """4.89""" },
    { "rate" : """5.9777""" },
    { "rate" : """13.69""" },
    { "rate" : """7.9777""" },
    { "rate" : """6.9999""" },
    { "rate" : """13.71""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """11.99999""" },
    { "rate" : """5.96""" },
    { "rate" : """5.5""" },
    { "rate" : """6""" },
    { "rate" : """13.71999""" },
    { "rate" : """7.99999""" },
    { "rate" : """1""" },
    { "rate" : """0.5""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """9.96""" },
    { "rate" : """1""" },
    { "rate" : """8.79999""" },
    { "rate" : """7.999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """6""" },
    { "rate" : """18.98""" },
    { "rate" : """8.8""" },
    { "rate" : """5.99""" },
    { "rate" : """18.98""" },
    { "rate" : """6""" },
    { "rate" : """5.99995""" },
    { "rate" : """12""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """18.97999""" },
    { "rate" : """6""" },
    { "rate" : """18.98""" },
    { "rate" : """11.99""" },
    { "rate" : """8.8""" },
    { "rate" : """12.4599""" },
    { "rate" : """1""" },
    { "rate" : """9.9""" },
    { "rate" : """9.96""" },
    { "rate" : """12.46""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """6.987""" },
    { "rate" : """18.98""" },
    { "rate" : """9.96""" },
    { "rate" : """18.98""" },
    { "rate" : """9.96""" },
    { "rate" : """10""" },
    { "rate" : """9.95""" },
    { "rate" : """12.46""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """8.8""" },
    { "rate" : """8.99""" },
    { "rate" : """18.959""" },
    { "rate" : """8.8""" },
    { "rate" : """5.99999""" },
    { "rate" : """3""" },
    { "rate" : """2.99999""" },
    { "rate" : """2.99999""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.95""" },
    { "rate" : """4.48998""" },
    { "rate" : """9.96""" },
    { "rate" : """2.99996""" },
    { "rate" : """4.5""" },
    { "rate" : """4.49999""" },
    { "rate" : """4.5""" },
    { "rate" : """7""" },
    { "rate" : """18.98""" },
    { "rate" : """3.64""" },
    { "rate" : """11.88""" },
    { "rate" : """9.96""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """7.99""" },
    { "rate" : """6.88""" },
    { "rate" : """12.46""" },
    { "rate" : """5.88""" },
    { "rate" : """3.64""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """5.9""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """5.99998""" },
    { "rate" : """7.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """7.5""" },
    { "rate" : """8""" },
    { "rate" : """4.49""" },
    { "rate" : """7.999""" },
    { "rate" : """7.98""" },
    { "rate" : """8.8""" },
    { "rate" : """6""" },
    { "rate" : """6.99""" },
    { "rate" : """7""" },
    { "rate" : """5.99""" },
    { "rate" : """12.46""" },
    { "rate" : """9.8""" },
    { "rate" : """5.99998""" },
    { "rate" : """8.7""" },
    { "rate" : """12""" },
    { "rate" : """0.4706""" },
    { "rate" : """18.98""" },
    { "rate" : """7""" },
    { "rate" : """0.4706""" },
    { "rate" : """10.3""" },
    { "rate" : """8.8""" },
    { "rate" : """12""" },
    { "rate" : """5.99""" },
    { "rate" : """6.999""" },
    { "rate" : """5.98""" },
    { "rate" : """12""" },
    { "rate" : """5.5""" },
    { "rate" : """13.72""" },
    { "rate" : """15""" },
    { "rate" : """2""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """12.45999""" },
    { "rate" : """5.999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5.9""" },
    { "rate" : """4.99""" },
    { "rate" : """4.98999""" },
    { "rate" : """5.989""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """18.98""" },
    { "rate" : """5""" },
    { "rate" : """12.4""" },
    { "rate" : """5""" },
    { "rate" : """12.45999""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """5.14""" },
    { "rate" : """5.15""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """12""" },
    { "rate" : """8.8""" },
    { "rate" : """9.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.98998""" },
    { "rate" : """18.5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """8.8""" },
    { "rate" : """4.9""" },
    { "rate" : """4.999""" },
    { "rate" : """5""" },
    { "rate" : """4.98998""" },
    { "rate" : """4.99999""" },
    { "rate" : """5.14999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """8.49999""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """0.4706""" },
    { "rate" : """7""" },
    { "rate" : """8.8""" },
    { "rate" : """6.99999""" },
    { "rate" : """8.8""" },
    { "rate" : """7.8""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.7""" },
    { "rate" : """14.9989""" },
    { "rate" : """5""" },
    { "rate" : """18.98""" },
    { "rate" : """8.799""" },
    { "rate" : """14.14""" },
    { "rate" : """4.99999""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """14.14""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.7""" },
    { "rate" : """10""" },
    { "rate" : """14.9999""" },
    { "rate" : """14.998""" },
    { "rate" : """8.8""" },
    { "rate" : """1.5""" },
    { "rate" : """5.99999""" },
    { "rate" : """8.8""" },
    { "rate" : """1.5""" },
    { "rate" : """8.8""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """1.2""" },
    { "rate" : """1.1""" },
    { "rate" : """8.5""" },
    { "rate" : """8.8""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """1.16666""" },
    { "rate" : """1.99""" },
    { "rate" : """2""" },
    { "rate" : """18.98""" },
    { "rate" : """15""" },
    { "rate" : """5.5""" },
    { "rate" : """7.9""" },
    { "rate" : """12.99""" },
    { "rate" : """13.72""" },
    { "rate" : """13.72""" },
    { "rate" : """13.7""" },
    { "rate" : """8.8""" },
    { "rate" : """8.5""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """8.799""" },
    { "rate" : """13.72""" },
    { "rate" : """8.7""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """1.15""" },
    { "rate" : """8.5""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """12.26""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """13.71""" },
    { "rate" : """13.72""" },
    { "rate" : """12.46""" },
    { "rate" : """12""" },
    { "rate" : """12.45999""" },
    { "rate" : """10""" },
    { "rate" : """13.71998""" },
    { "rate" : """9.99999""" },
    { "rate" : """13.72""" },
    { "rate" : """13""" },
    { "rate" : """13.72""" },
    { "rate" : """12.26""" },
    { "rate" : """13.71999""" },
    { "rate" : """12.26""" },
    { "rate" : """12""" },
    { "rate" : """12.24""" },
    { "rate" : """12.25999""" },
    { "rate" : """12.2599""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """9.9999""" },
    { "rate" : """11.72""" },
    { "rate" : """12""" },
    { "rate" : """12.26""" },
    { "rate" : """14.999""" },
    { "rate" : """14.98999""" },
    { "rate" : """14.97998""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """13.71""" },
    { "rate" : """15""" },
    { "rate" : """14.98997""" },
    { "rate" : """14.9""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """14.89""" },
    { "rate" : """12.4599""" },
    { "rate" : """13.72""" },
    { "rate" : """14.99999""" },
    { "rate" : """12.45""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """14.98""" },
    { "rate" : """13.71999""" },
    { "rate" : """12.99""" },
    { "rate" : """14.999""" },
    { "rate" : """14.98969""" },
    { "rate" : """18.98""" },
    { "rate" : """13.719""" },
    { "rate" : """5.99""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """14.88999""" },
    { "rate" : """18.98""" },
    { "rate" : """8.8""" },
    { "rate" : """18.98""" },
    { "rate" : """6.7""" },
    { "rate" : """14.99999""" },
    { "rate" : """0.4706""" },
    { "rate" : """11.99""" },
    { "rate" : """5""" },
    { "rate" : """14.49""" },
    { "rate" : """12.44""" },
    { "rate" : """14.99""" },
    { "rate" : """8.8""" },
    { "rate" : """8.79999""" },
    { "rate" : """8.79""" },
    { "rate" : """1""" },
    { "rate" : """8.8""" },
    { "rate" : """11.88""" },
    { "rate" : """6.88""" },
    { "rate" : """14.88""" },
    { "rate" : """8.7""" },
    { "rate" : """6.5""" },
    { "rate" : """14.999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """8.79999""" },
    { "rate" : """8.8""" },
    { "rate" : """6.8""" },
    { "rate" : """11.9""" },
    { "rate" : """11.89999""" },
    { "rate" : """12""" },
    { "rate" : """11""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """12""" },
    { "rate" : """11.99""" },
    { "rate" : """11.99999""" },
    { "rate" : """8.8""" },
    { "rate" : """12""" },
    { "rate" : """11.8999""" },
    { "rate" : """11.5""" },
    { "rate" : """11""" },
    { "rate" : """12""" },
    { "rate" : """11.89999""" },
    { "rate" : """11.98""" },
    { "rate" : """12""" },
    { "rate" : """18""" },
    { "rate" : """0.96""" },
    { "rate" : """18.97999""" },
    { "rate" : """11.98""" },
    { "rate" : """4.9""" },
    { "rate" : """4.89998""" },
    { "rate" : """4.888""" },
    { "rate" : """18""" },
    { "rate" : """4.887""" },
    { "rate" : """11.88""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3.98998""" },
    { "rate" : """3.98997""" },
    { "rate" : """3.99""" },
    { "rate" : """5.34""" },
    { "rate" : """4.5""" },
    { "rate" : """4.99""" },
    { "rate" : """12.4599""" },
    { "rate" : """4""" },
    { "rate" : """19.99""" },
    { "rate" : """5""" },
    { "rate" : """4.49999""" },
    { "rate" : """12.45""" },
    { "rate" : """12.26""" },
    { "rate" : """19.9""" },
    { "rate" : """11.99""" },
    { "rate" : """12.26""" },
    { "rate" : """4.5""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """0.4""" },
    { "rate" : """0.39999""" },
    { "rate" : """0.39999""" },
    { "rate" : """0.4706""" },
    { "rate" : """3""" },
    { "rate" : """0.45""" },
    { "rate" : """12.26""" },
    { "rate" : """9.9""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """4.5""" },
    { "rate" : """6""" },
    { "rate" : """6.99999""" },
    { "rate" : """12""" },
    { "rate" : """0.499""" },
    { "rate" : """6.99""" },
    { "rate" : """7""" },
    { "rate" : """4.5""" },
    { "rate" : """0.48999""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """6.999""" },
    { "rate" : """3.98998""" },
    { "rate" : """6""" },
    { "rate" : """4.5""" },
    { "rate" : """10""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4.4""" },
    { "rate" : """9""" },
    { "rate" : """0.4706""" },
    { "rate" : """12""" },
    { "rate" : """3.5""" },
    { "rate" : """5.95""" },
    { "rate" : """0.96""" },
    { "rate" : """4.98""" },
    { "rate" : """4.88""" },
    { "rate" : """4.49999""" },
    { "rate" : """4.4""" },
    { "rate" : """3""" },
    { "rate" : """4.5""" },
    { "rate" : """4.93996""" },
    { "rate" : """4.9""" },
    { "rate" : """4.49999""" },
    { "rate" : """4.99""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """4.95""" },
    { "rate" : """5.99999""" },
    { "rate" : """4.98""" },
    { "rate" : """12.26""" },
    { "rate" : """4.9""" },
    { "rate" : """14.5""" },
    { "rate" : """4.98""" },
    { "rate" : """4.9""" },
    { "rate" : """5.99""" },
    { "rate" : """12""" },
    { "rate" : """5.5""" },
    { "rate" : """16.16""" },
    { "rate" : """12.26""" },
    { "rate" : """4.9""" },
    { "rate" : """4.9""" },
    { "rate" : """12""" },
    { "rate" : """4.89""" },
    { "rate" : """4.95""" },
    { "rate" : """10.9""" },
    { "rate" : """4.94""" },
    { "rate" : """9.99""" },
    { "rate" : """4.99""" },
    { "rate" : """4.94999""" },
    { "rate" : """3.9""" },
    { "rate" : """4.5""" },
    { "rate" : """8.9""" },
    { "rate" : """4.6""" },
    { "rate" : """1""" },
    { "rate" : """14.99""" },
    { "rate" : """14.99999""" },
    { "rate" : """3""" },
    { "rate" : """5.78""" },
    { "rate" : """5.99998""" },
    { "rate" : """5.78999""" },
    { "rate" : """5.5""" },
    { "rate" : """5.78""" },
    { "rate" : """5""" },
    { "rate" : """5.79""" },
    { "rate" : """4.99999""" },
    { "rate" : """5.45""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """11.99998""" },
    { "rate" : """5.79""" },
    { "rate" : """12""" },
    { "rate" : """1""" },
    { "rate" : """5.79""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """5.95""" },
    { "rate" : """4.9799""" },
    { "rate" : """4.75""" },
    { "rate" : """4.25""" },
    { "rate" : """9""" },
    { "rate" : """4.9499""" },
    { "rate" : """4.9""" },
    { "rate" : """3.6""" },
    { "rate" : """16.17""" },
    { "rate" : """5.5""" },
    { "rate" : """14""" },
    { "rate" : """10.73""" },
    { "rate" : """12.26""" },
    { "rate" : """4.98""" },
    { "rate" : """5.99""" },
    { "rate" : """4""" },
    { "rate" : """5.75""" },
    { "rate" : """9.5""" },
    { "rate" : """5.79""" },
    { "rate" : """6""" },
    { "rate" : """4.9""" },
    { "rate" : """4""" },
    { "rate" : """6""" },
    { "rate" : """5.79""" },
    { "rate" : """5.79""" },
    { "rate" : """4.98796""" },
    { "rate" : """4.5""" },
    { "rate" : """4.89999""" },
    { "rate" : """4.7""" },
    { "rate" : """10.73""" },
    { "rate" : """5.5""" },
    { "rate" : """4.987""" },
    { "rate" : """5.87""" },
    { "rate" : """5.99""" },
    { "rate" : """6""" },
    { "rate" : """4.69998""" },
    { "rate" : """5.79""" },
    { "rate" : """7.9""" },
    { "rate" : """5.94998""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """4.85""" },
    { "rate" : """12.26""" },
    { "rate" : """11.7""" },
    { "rate" : """5.99999""" },
    { "rate" : """5""" },
    { "rate" : """5.99""" },
    { "rate" : """5.79""" },
    { "rate" : """5.79""" },
    { "rate" : """4.39""" },
    { "rate" : """5.9""" },
    { "rate" : """5.79""" },
    { "rate" : """12.26""" },
    { "rate" : """10.73""" },
    { "rate" : """5.79""" },
    { "rate" : """10.73""" },
    { "rate" : """5.99999""" },
    { "rate" : """5.79""" },
    { "rate" : """11.99""" },
    { "rate" : """5.79""" },
    { "rate" : """5""" },
    { "rate" : """5.79""" },
    { "rate" : """11.98999""" },
    { "rate" : """5.79""" },
    { "rate" : """12.26""" },
    { "rate" : """5.98""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """5.85""" },
    { "rate" : """4.88999""" },
    { "rate" : """4.98""" },
    { "rate" : """5""" },
    { "rate" : """5.98""" },
    { "rate" : """4.75""" },
    { "rate" : """10.73""" },
    { "rate" : """12.26""" },
    { "rate" : """4.95""" },
    { "rate" : """12""" },
    { "rate" : """11.99""" },
    { "rate" : """10""" },
    { "rate" : """12.26""" },
    { "rate" : """4.98""" },
    { "rate" : """12.26""" },
    { "rate" : """10.73""" },
    { "rate" : """0.4706""" },
    { "rate" : """13.72""" },
    { "rate" : """10.72""" },
    { "rate" : """12.26""" },
    { "rate" : """4.89999""" },
    { "rate" : """4.6""" },
    { "rate" : """4.98""" },
    { "rate" : """4.97999""" },
    { "rate" : """8""" },
    { "rate" : """7.9""" },
    { "rate" : """10.99""" },
    { "rate" : """7.98""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7.5""" },
    { "rate" : """8""" },
    { "rate" : """4.87998""" },
    { "rate" : """6.99999""" },
    { "rate" : """7.98998""" },
    { "rate" : """8""" },
    { "rate" : """7.9""" },
    { "rate" : """7.99999""" },
    { "rate" : """7.88""" },
    { "rate" : """7.8""" },
    { "rate" : """4.98999""" },
    { "rate" : """7.99998""" },
    { "rate" : """8""" },
    { "rate" : """7.9""" },
    { "rate" : """0.96""" },
    { "rate" : """7.9999""" },
    { "rate" : """12.26""" },
    { "rate" : """11.99999""" },
    { "rate" : """8""" },
    { "rate" : """12.26""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """7.9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.73""" },
    { "rate" : """8""" },
    { "rate" : """7.99""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """8.8888""" },
    { "rate" : """8""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """2.48998""" },
    { "rate" : """2.48997""" },
    { "rate" : """2.49""" },
    { "rate" : """2.5""" },
    { "rate" : """8.8""" },
    { "rate" : """4.97999""" },
    { "rate" : """5""" },
    { "rate" : """9.9""" },
    { "rate" : """2.49999""" },
    { "rate" : """7.99998""" },
    { "rate" : """4.99998""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """3""" },
    { "rate" : """2.5""" },
    { "rate" : """12""" },
    { "rate" : """7.7""" },
    { "rate" : """2.4799""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """2.4""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """3.99999""" },
    { "rate" : """7.5""" },
    { "rate" : """2.5""" },
    { "rate" : """8""" },
    { "rate" : """11.5""" },
    { "rate" : """7""" },
    { "rate" : """13.72""" },
    { "rate" : """7""" },
    { "rate" : """2.5""" },
    { "rate" : """3""" },
    { "rate" : """13.11""" },
    { "rate" : """11.998""" },
    { "rate" : """8""" },
    { "rate" : """7.99""" },
    { "rate" : """2.49""" },
    { "rate" : """2.5""" },
    { "rate" : """8""" },
    { "rate" : """2.49""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.95""" },
    { "rate" : """1""" },
    { "rate" : """0.95""" },
    { "rate" : """2.5""" },
    { "rate" : """1""" },
    { "rate" : """2.5""" },
    { "rate" : """0.9975""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """2.4""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """7.9""" },
    { "rate" : """0.9899""" },
    { "rate" : """1""" },
    { "rate" : """0.9999""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """0.99998""" },
    { "rate" : """1""" },
    { "rate" : """6.969""" },
    { "rate" : """1""" },
    { "rate" : """7.89""" },
    { "rate" : """7.9""" },
    { "rate" : """2.4""" },
    { "rate" : """4.96""" },
    { "rate" : """0.9999""" },
    { "rate" : """2.5""" },
    { "rate" : """1""" },
    { "rate" : """9.9""" },
    { "rate" : """9.9""" },
    { "rate" : """0.3333""" },
    { "rate" : """0.9999""" },
    { "rate" : """1""" },
    { "rate" : """8.99""" },
    { "rate" : """0.9""" },
    { "rate" : """2.5""" },
    { "rate" : """2.5""" },
    { "rate" : """0.05""" },
    { "rate" : """6.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """0.99998""" },
    { "rate" : """0.96""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """0.95""" },
    { "rate" : """0.987""" },
    { "rate" : """0.9""" },
    { "rate" : """0.97""" },
    { "rate" : """0.7""" },
    { "rate" : """16.17""" },
    { "rate" : """12""" },
    { "rate" : """0.99989""" },
    { "rate" : """8.8""" },
    { "rate" : """0.75""" },
    { "rate" : """8""" },
    { "rate" : """0.99986""" },
    { "rate" : """0.99999""" },
    { "rate" : """8""" },
    { "rate" : """0.99989""" },
    { "rate" : """0.9999""" },
    { "rate" : """8""" },
    { "rate" : """1.17""" },
    { "rate" : """0.875""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9899""" },
    { "rate" : """0.99999""" },
    { "rate" : """4""" },
    { "rate" : """3.99999""" },
    { "rate" : """3.99998""" },
    { "rate" : """0.99999""" },
    { "rate" : """11.99""" },
    { "rate" : """12.46""" },
    { "rate" : """3.99""" },
    { "rate" : """4""" },
    { "rate" : """15""" },
    { "rate" : """4""" },
    { "rate" : """8.8""" },
    { "rate" : """0.9998""" },
    { "rate" : """2.99""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """16.17""" },
    { "rate" : """13.55""" },
    { "rate" : """12.46""" },
    { "rate" : """16.17""" },
    { "rate" : """13.71999""" },
    { "rate" : """4""" },
    { "rate" : """12.46""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.99""" },
    { "rate" : """0.6999""" },
    { "rate" : """0.9898""" },
    { "rate" : """3.9888""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """6.94999""" },
    { "rate" : """6.4""" },
    { "rate" : """6.48998""" },
    { "rate" : """6.99899""" },
    { "rate" : """6.99999""" },
    { "rate" : """6.9""" },
    { "rate" : """6""" },
    { "rate" : """6.5""" },
    { "rate" : """5.99999""" },
    { "rate" : """8""" },
    { "rate" : """6.98""" },
    { "rate" : """12.46""" },
    { "rate" : """6.9""" },
    { "rate" : """6.88""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """5.5""" },
    { "rate" : """12.4""" },
    { "rate" : """6.98""" },
    { "rate" : """6.97999""" },
    { "rate" : """1.166""" },
    { "rate" : """6.97""" },
    { "rate" : """5""" },
    { "rate" : """4.97""" },
    { "rate" : """6.5""" },
    { "rate" : """1.5""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """4.9""" },
    { "rate" : """1.49999""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.9998""" },
    { "rate" : """6""" },
    { "rate" : """1.7""" },
    { "rate" : """1.9""" },
    { "rate" : """0.4""" },
    { "rate" : """1.8999""" },
    { "rate" : """6.5""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.275""" },
    { "rate" : """1.8""" },
    { "rate" : """1.49998""" },
    { "rate" : """1.5""" },
    { "rate" : """10""" },
    { "rate" : """6.9""" },
    { "rate" : """8""" },
    { "rate" : """4.9998""" },
    { "rate" : """0.99888""" },
    { "rate" : """0.899""" },
    { "rate" : """16.17""" },
    { "rate" : """6.9""" },
    { "rate" : """6""" },
    { "rate" : """5.99999""" },
    { "rate" : """5.99999""" },
    { "rate" : """0.998""" },
    { "rate" : """0.99""" },
    { "rate" : """8.8""" },
    { "rate" : """9.98998""" },
    { "rate" : """0.8""" },
    { "rate" : """6.87""" },
    { "rate" : """7""" },
    { "rate" : """5.4""" },
    { "rate" : """4.9""" },
    { "rate" : """6.97777""" },
    { "rate" : """6.88""" },
    { "rate" : """0.9998""" },
    { "rate" : """3.998""" },
    { "rate" : """3.499""" },
    { "rate" : """6""" },
    { "rate" : """5.9""" },
    { "rate" : """3.9""" },
    { "rate" : """7""" },
    { "rate" : """0.9888""" },
    { "rate" : """0.45""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """10.73""" },
    { "rate" : """5""" },
    { "rate" : """4.93""" },
    { "rate" : """4.92999""" },
    { "rate" : """4.89999""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """4.99988""" },
    { "rate" : """4.75""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """4.74""" },
    { "rate" : """11""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """6.75""" },
    { "rate" : """4.94""" },
    { "rate" : """4.99""" },
    { "rate" : """4.5""" },
    { "rate" : """4.95""" },
    { "rate" : """6.9989""" },
    { "rate" : """2""" },
    { "rate" : """8.5""" },
    { "rate" : """9""" },
    { "rate" : """9.97""" },
    { "rate" : """4.17""" },
    { "rate" : """9.9""" },
    { "rate" : """4.8""" },
    { "rate" : """7""" },
    { "rate" : """10""" },
    { "rate" : """8.5""" },
    { "rate" : """9.9""" },
    { "rate" : """5""" },
    { "rate" : """10.99999""" },
    { "rate" : """6.55""" },
    { "rate" : """4.8""" },
    { "rate" : """9.9799""" },
    { "rate" : """4.99996""" },
    { "rate" : """12.99""" },
    { "rate" : """6.5""" },
    { "rate" : """16""" },
    { "rate" : """6.55""" },
    { "rate" : """6.5""" },
    { "rate" : """4.985""" },
    { "rate" : """8""" },
    { "rate" : """4.73998""" },
    { "rate" : """4.9""" },
    { "rate" : """4.99""" },
    { "rate" : """9""" },
    { "rate" : """8.98998""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.95""" },
    { "rate" : """4.79999""" },
    { "rate" : """6.5""" },
    { "rate" : """6.55""" },
    { "rate" : """5.99999""" },
    { "rate" : """5""" },
    { "rate" : """9.99999""" },
    { "rate" : """0.4706""" },
    { "rate" : """4.99999""" },
    { "rate" : """8.9""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99998""" },
    { "rate" : """7.999""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """9.5""" },
    { "rate" : """4.5""" },
    { "rate" : """10.73""" },
    { "rate" : """3.77""" },
    { "rate" : """4.9""" },
    { "rate" : """16.17""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """9""" },
    { "rate" : """23""" },
    { "rate" : """1.998""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """6.54998""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """9.98998""" },
    { "rate" : """8""" },
    { "rate" : """6.99999""" },
    { "rate" : """0.4706""" },
    { "rate" : """9""" },
    { "rate" : """4.999""" },
    { "rate" : """8.9999""" },
    { "rate" : """9.9""" },
    { "rate" : """10.73""" },
    { "rate" : """4.25""" },
    { "rate" : """10.73""" },
    { "rate" : """8.5""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """5.75""" },
    { "rate" : """10.73""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """10.73""" },
    { "rate" : """4.75""" },
    { "rate" : """9.88""" },
    { "rate" : """4.88""" },
    { "rate" : """4.88""" },
    { "rate" : """4.98999""" },
    { "rate" : """10""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.8""" },
    { "rate" : """8.8""" },
    { "rate" : """4.9""" },
    { "rate" : """19""" },
    { "rate" : """16""" },
    { "rate" : """9.85""" },
    { "rate" : """4.4""" },
    { "rate" : """18.99""" },
    { "rate" : """23.58""" },
    { "rate" : """5""" },
    { "rate" : """16.17""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """2.94999""" },
    { "rate" : """4.9""" },
    { "rate" : """23.58""" },
    { "rate" : """16""" },
    { "rate" : """16.17""" },
    { "rate" : """5""" },
    { "rate" : """0.96""" },
    { "rate" : """1.7""" },
    { "rate" : """99""" },
    { "rate" : """4.99999""" },
    { "rate" : """23.25""" },
    { "rate" : """6.25""" },
    { "rate" : """4.9""" },
    { "rate" : """1.5""" },
    { "rate" : """4.93""" },
    { "rate" : """9""" },
    { "rate" : """22.9999""" },
    { "rate" : """1""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """8.9""" },
    { "rate" : """8.89998""" },
    { "rate" : """16.16""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """23.58""" },
    { "rate" : """7""" },
    { "rate" : """6.99""" },
    { "rate" : """6.98999""" },
    { "rate" : """23.57999""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """90""" },
    { "rate" : """10.73""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """7""" },
    { "rate" : """9.99999""" },
    { "rate" : """10.73""" },
    { "rate" : """10.72999""" },
    { "rate" : """5.6""" },
    { "rate" : """8.4""" },
    { "rate" : """10.97""" },
    { "rate" : """9.9989""" },
    { "rate" : """23.58""" },
    { "rate" : """21.9999""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """9""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """8.9""" },
    { "rate" : """10.73""" },
    { "rate" : """6.55""" },
    { "rate" : """16.17""" },
    { "rate" : """3""" },
    { "rate" : """6.55""" },
    { "rate" : """2""" },
    { "rate" : """7.5""" },
    { "rate" : """9.1""" },
    { "rate" : """16.17""" },
    { "rate" : """4.9""" },
    { "rate" : """9.96""" },
    { "rate" : """3.25""" },
    { "rate" : """19.9999""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """19.97999""" },
    { "rate" : """6.54""" },
    { "rate" : """7""" },
    { "rate" : """6.9""" },
    { "rate" : """2.99""" },
    { "rate" : """16.17""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """6.55""" },
    { "rate" : """14.98999""" },
    { "rate" : """9.96""" },
    { "rate" : """2.99999""" },
    { "rate" : """6.55""" },
    { "rate" : """16.17""" },
    { "rate" : """6""" },
    { "rate" : """4.5""" },
    { "rate" : """5""" },
    { "rate" : """4.99""" },
    { "rate" : """4.99""" },
    { "rate" : """3.98998""" },
    { "rate" : """5""" },
    { "rate" : """16.17""" },
    { "rate" : """9.89""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """16.17""" },
    { "rate" : """4.98""" },
    { "rate" : """6.55""" },
    { "rate" : """2.9""" },
    { "rate" : """1""" },
    { "rate" : """4.98""" },
    { "rate" : """4.99""" },
    { "rate" : """6.5""" },
    { "rate" : """5""" },
    { "rate" : """4.97""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """6.8""" },
    { "rate" : """4.49""" },
    { "rate" : """4.98999""" },
    { "rate" : """0.99999""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """16.17""" },
    { "rate" : """5""" },
    { "rate" : """4.8""" },
    { "rate" : """4.45""" },
    { "rate" : """7.9""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """4.999""" },
    { "rate" : """4.98""" },
    { "rate" : """4.99997""" },
    { "rate" : """4.8""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """7.48""" },
    { "rate" : """7.5""" },
    { "rate" : """14.9""" },
    { "rate" : """3""" },
    { "rate" : """4.9799""" },
    { "rate" : """14.98""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """4.49""" },
    { "rate" : """6.99999""" },
    { "rate" : """0.49999""" },
    { "rate" : """0.5""" },
    { "rate" : """0.49994""" },
    { "rate" : """0.49998""" },
    { "rate" : """0.96""" },
    { "rate" : """0.49993""" },
    { "rate" : """7.49""" },
    { "rate" : """6.55""" },
    { "rate" : """0.4""" },
    { "rate" : """0.49998""" },
    { "rate" : """7""" },
    { "rate" : """4.49998""" },
    { "rate" : """6""" },
    { "rate" : """3""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """7.49999""" },
    { "rate" : """4.99""" },
    { "rate" : """9.96""" },
    { "rate" : """9.96""" },
    { "rate" : """5.9""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """7.96""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """5""" },
    { "rate" : """4.9""" },
    { "rate" : """10.45""" },
    { "rate" : """4""" },
    { "rate" : """4.98""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """6.9999""" },
    { "rate" : """8.75""" },
    { "rate" : """4.9""" },
    { "rate" : """16.17""" },
    { "rate" : """5""" },
    { "rate" : """4.49998""" },
    { "rate" : """15.17""" },
    { "rate" : """10.5""" },
    { "rate" : """4.49997""" },
    { "rate" : """5""" },
    { "rate" : """5.88""" },
    { "rate" : """5.97""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.99998""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """4.5""" },
    { "rate" : """5.92""" },
    { "rate" : """5.998""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """16.17""" },
    { "rate" : """16.15""" },
    { "rate" : """9""" },
    { "rate" : """4""" },
    { "rate" : """4.99""" },
    { "rate" : """13""" },
    { "rate" : """4""" },
    { "rate" : """4.75""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.975""" },
    { "rate" : """5.89""" },
    { "rate" : """5""" },
    { "rate" : """7.47""" },
    { "rate" : """8.99""" },
    { "rate" : """15""" },
    { "rate" : """5.999""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """0.4706""" },
    { "rate" : """8.8""" },
    { "rate" : """2.99""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """5.9999""" },
    { "rate" : """9.97999""" },
    { "rate" : """4.8""" },
    { "rate" : """9.98""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """5""" },
    { "rate" : """4.98""" },
    { "rate" : """4.95""" },
    { "rate" : """4.99""" },
    { "rate" : """9.94""" },
    { "rate" : """13.72""" },
    { "rate" : """9.99""" },
    { "rate" : """8.8""" },
    { "rate" : """4""" },
    { "rate" : """13.7""" },
    { "rate" : """4""" },
    { "rate" : """8.7""" },
    { "rate" : """4.1""" },
    { "rate" : """4.7""" },
    { "rate" : """6.7""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """7.7""" },
    { "rate" : """4.99""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """3.988""" },
    { "rate" : """9.96""" },
    { "rate" : """10.73""" },
    { "rate" : """5""" },
    { "rate" : """13.72""" },
    { "rate" : """8.8""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """14""" },
    { "rate" : """8.8""" },
    { "rate" : """8.7""" },
    { "rate" : """6.3""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6.5""" },
    { "rate" : """4""" },
    { "rate" : """13""" },
    { "rate" : """6""" },
    { "rate" : """10.73""" },
    { "rate" : """8.8""" },
    { "rate" : """4.83""" },
    { "rate" : """4.99""" },
    { "rate" : """4.999""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """3""" },
    { "rate" : """23""" },
    { "rate" : """6""" },
    { "rate" : """4.99998""" },
    { "rate" : """13.71""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """13.72""" },
    { "rate" : """9.9""" },
    { "rate" : """19.999""" },
    { "rate" : """9.9988""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """0.4706""" },
    { "rate" : """5""" },
    { "rate" : """6.55""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """2""" },
    { "rate" : """4.99996""" },
    { "rate" : """7.98998""" },
    { "rate" : """4.99998""" },
    { "rate" : """12""" },
    { "rate" : """11.99999""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """13.11""" },
    { "rate" : """12.46""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """23.58""" },
    { "rate" : """13.11""" },
    { "rate" : """9.96""" },
    { "rate" : """13""" },
    { "rate" : """13.11""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """4.5""" },
    { "rate" : """6.55""" },
    { "rate" : """6.55""" },
    { "rate" : """9.96""" },
    { "rate" : """23.58""" },
    { "rate" : """8.8""" },
    { "rate" : """12.46""" },
    { "rate" : """23.58""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """3.7""" },
    { "rate" : """23.58""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """6""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """5.9""" },
    { "rate" : """7.8""" },
    { "rate" : """7.9324""" },
    { "rate" : """6.55""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """7.9599""" },
    { "rate" : """9""" },
    { "rate" : """8.79""" },
    { "rate" : """23.5""" },
    { "rate" : """5""" },
    { "rate" : """8""" },
    { "rate" : """7.99999""" },
    { "rate" : """18.89""" },
    { "rate" : """18.98""" },
    { "rate" : """6.55""" },
    { "rate" : """10""" },
    { "rate" : """18.98""" },
    { "rate" : """9""" },
    { "rate" : """13.11""" },
    { "rate" : """8.8""" },
    { "rate" : """5""" },
    { "rate" : """18.98""" },
    { "rate" : """18.97""" },
    { "rate" : """13.11""" },
    { "rate" : """9.96""" },
    { "rate" : """18.98""" },
    { "rate" : """13.11""" },
    { "rate" : """7.5""" },
    { "rate" : """13.11""" },
    { "rate" : """18.98""" },
    { "rate" : """4""" },
    { "rate" : """8.5""" },
    { "rate" : """9.96""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.1""" },
    { "rate" : """13.11""" },
    { "rate" : """18.98""" },
    { "rate" : """13.11""" },
    { "rate" : """18.98""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """18.99""" },
    { "rate" : """6.3""" },
    { "rate" : """9.7""" },
    { "rate" : """14.7""" },
    { "rate" : """12""" },
    { "rate" : """18""" },
    { "rate" : """23.579""" },
    { "rate" : """18.9799""" },
    { "rate" : """5""" },
    { "rate" : """23""" },
    { "rate" : """9.96""" },
    { "rate" : """18.98""" },
    { "rate" : """8""" },
    { "rate" : """13.11""" },
    { "rate" : """5""" },
    { "rate" : """18.98""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """18.98""" },
    { "rate" : """10.999""" },
    { "rate" : """9.96""" },
    { "rate" : """18""" },
    { "rate" : """13.05""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """18.98""" },
    { "rate" : """13.11""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """23.58""" },
    { "rate" : """9.9999""" },
    { "rate" : """9.9999""" },
    { "rate" : """9.9""" },
    { "rate" : """13.11""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13""" },
    { "rate" : """8.46""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """23.58""" },
    { "rate" : """0.4706""" },
    { "rate" : """12.99999""" },
    { "rate" : """13""" },
    { "rate" : """9.9""" },
    { "rate" : """13.11""" },
    { "rate" : """12""" },
    { "rate" : """12.99""" },
    { "rate" : """13.1""" },
    { "rate" : """13.11""" },
    { "rate" : """12""" },
    { "rate" : """11.99999""" },
    { "rate" : """13.11""" },
    { "rate" : """13.09""" },
    { "rate" : """18.96""" },
    { "rate" : """13.11""" },
    { "rate" : """23.58""" },
    { "rate" : """6.549""" },
    { "rate" : """18.98""" },
    { "rate" : """8""" },
    { "rate" : """23""" },
    { "rate" : """0.96""" },
    { "rate" : """13""" },
    { "rate" : """6.49998""" },
    { "rate" : """6.97""" },
    { "rate" : """23""" },
    { "rate" : """18""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """13""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """13.11""" },
    { "rate" : """13.1""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """6.96""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """4.2""" },
    { "rate" : """13.11""" },
    { "rate" : """8.8""" },
    { "rate" : """6.549""" },
    { "rate" : """13.1""" },
    { "rate" : """22""" },
    { "rate" : """8.79""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3.5""" },
    { "rate" : """2.99999""" },
    { "rate" : """18.99""" },
    { "rate" : """3""" },
    { "rate" : """2.8""" },
    { "rate" : """15""" },
    { "rate" : """3""" },
    { "rate" : """6.5""" },
    { "rate" : """2.99""" },
    { "rate" : """8.5""" },
    { "rate" : """3.63""" },
    { "rate" : """10""" },
    { "rate" : """3.6""" },
    { "rate" : """3.64""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """5.5""" },
    { "rate" : """2.99""" },
    { "rate" : """3.57""" },
    { "rate" : """3""" },
    { "rate" : """3.638""" },
    { "rate" : """3""" },
    { "rate" : """2.95""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """0.96""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """18.9""" },
    { "rate" : """2.94""" },
    { "rate" : """0.4706""" },
    { "rate" : """3.64""" },
    { "rate" : """23.58""" },
    { "rate" : """2.99999""" },
    { "rate" : """18.97999""" },
    { "rate" : """2.9""" },
    { "rate" : """6.95""" },
    { "rate" : """6.5""" },
    { "rate" : """18.98""" },
    { "rate" : """23.58""" },
    { "rate" : """2.99""" },
    { "rate" : """2.99""" },
    { "rate" : """3.638""" },
    { "rate" : """18""" },
    { "rate" : """18""" },
    { "rate" : """6""" },
    { "rate" : """2.99""" },
    { "rate" : """3.63999""" },
    { "rate" : """2.9""" },
    { "rate" : """3.64""" },
    { "rate" : """3""" },
    { "rate" : """3.64""" },
    { "rate" : """2""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """8.8""" },
    { "rate" : """18.98""" },
    { "rate" : """8.8""" },
    { "rate" : """23.58""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """6.55""" },
    { "rate" : """3.2""" },
    { "rate" : """3.64""" },
    { "rate" : """3""" },
    { "rate" : """3.64""" },
    { "rate" : """3.61""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """17""" },
    { "rate" : """0.4706""" },
    { "rate" : """18.98""" },
    { "rate" : """5""" },
    { "rate" : """12.24""" },
    { "rate" : """12.26""" },
    { "rate" : """18.98""" },
    { "rate" : """0.4706""" },
    { "rate" : """18.98""" },
    { "rate" : """23.58""" },
    { "rate" : """8.8""" },
    { "rate" : """18.98""" },
    { "rate" : """18.98""" },
    { "rate" : """23.58""" },
    { "rate" : """6.55""" },
    { "rate" : """9.99""" },
    { "rate" : """12.46""" },
    { "rate" : """12.26""" },
    { "rate" : """5""" },
    { "rate" : """23.58""" },
    { "rate" : """15""" },
    { "rate" : """18""" },
    { "rate" : """23""" },
    { "rate" : """11.5""" },
    { "rate" : """23.58""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """14.99""" },
    { "rate" : """2.9""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """11""" },
    { "rate" : """2.89999""" },
    { "rate" : """15""" },
    { "rate" : """2.99""" },
    { "rate" : """3""" },
    { "rate" : """2.99""" },
    { "rate" : """8""" },
    { "rate" : """2.999""" },
    { "rate" : """18.98""" },
    { "rate" : """18.7""" },
    { "rate" : """12""" },
    { "rate" : """8.79999""" },
    { "rate" : """18.97999""" },
    { "rate" : """3""" },
    { "rate" : """5.91""" },
    { "rate" : """15.32""" },
    { "rate" : """15""" },
    { "rate" : """16.98""" },
    { "rate" : """2.95""" },
    { "rate" : """2.74""" },
    { "rate" : """8.7""" },
    { "rate" : """3""" },
    { "rate" : """15.7899""" },
    { "rate" : """18.97999""" },
    { "rate" : """2.99999""" },
    { "rate" : """2.8""" },
    { "rate" : """23.58""" },
    { "rate" : """12.26""" },
    { "rate" : """3""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """3""" },
    { "rate" : """23.58""" },
    { "rate" : """2.99""" },
    { "rate" : """8.799""" },
    { "rate" : """6.55""" },
    { "rate" : """8.59""" },
    { "rate" : """2.99""" },
    { "rate" : """9""" },
    { "rate" : """8.5""" },
    { "rate" : """11""" },
    { "rate" : """2.9""" },
    { "rate" : """12.26""" },
    { "rate" : """15""" },
    { "rate" : """17.99""" },
    { "rate" : """12.46""" },
    { "rate" : """23.58""" },
    { "rate" : """18.98""" },
    { "rate" : """6.55""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """12.26""" },
    { "rate" : """2""" },
    { "rate" : """18.98""" },
    { "rate" : """0.8""" },
    { "rate" : """8.39""" },
    { "rate" : """0.79999""" },
    { "rate" : """2""" },
    { "rate" : """3""" },
    { "rate" : """11.75""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """23.58""" },
    { "rate" : """23.58""" },
    { "rate" : """15.79""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """10.9""" },
    { "rate" : """8.38""" },
    { "rate" : """9.7""" },
    { "rate" : """12.2""" },
    { "rate" : """11.88""" },
    { "rate" : """15""" },
    { "rate" : """8.8""" },
    { "rate" : """15.99999""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """23.58""" },
    { "rate" : """12.26""" },
    { "rate" : """23""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """8.4""" },
    { "rate" : """23.57999""" },
    { "rate" : """7.9""" },
    { "rate" : """23.57999""" },
    { "rate" : """18.98""" },
    { "rate" : """9.3339""" },
    { "rate" : """22.3369""" },
    { "rate" : """13.36""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """12.26""" },
    { "rate" : """6.8""" },
    { "rate" : """6.79999""" },
    { "rate" : """7""" },
    { "rate" : """12.25999""" },
    { "rate" : """22""" },
    { "rate" : """12.26""" },
    { "rate" : """6.9999""" },
    { "rate" : """6.8999""" },
    { "rate" : """0.4706""" },
    { "rate" : """18""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """6.95""" },
    { "rate" : """15""" },
    { "rate" : """6.99999""" },
    { "rate" : """6.88""" },
    { "rate" : """13.17""" },
    { "rate" : """3""" },
    { "rate" : """18""" },
    { "rate" : """18.98""" },
    { "rate" : """6.99""" },
    { "rate" : """15.98""" },
    { "rate" : """9.9""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """4.99""" },
    { "rate" : """4.99""" },
    { "rate" : """4.99""" },
    { "rate" : """4.98999""" },
    { "rate" : """4.98""" },
    { "rate" : """5""" },
    { "rate" : """4.98999""" },
    { "rate" : """8.6279""" },
    { "rate" : """4.9""" },
    { "rate" : """20""" },
    { "rate" : """12.26""" },
    { "rate" : """12""" },
    { "rate" : """18.98""" },
    { "rate" : """8.8""" },
    { "rate" : """6.55""" },
    { "rate" : """12.26""" },
    { "rate" : """8.3999""" },
    { "rate" : """20""" },
    { "rate" : """8.4""" },
    { "rate" : """8""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.63999""" },
    { "rate" : """3.64""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """4.2""" },
    { "rate" : """12.25""" },
    { "rate" : """8.39999""" },
    { "rate" : """12.26""" },
    { "rate" : """4.88""" },
    { "rate" : """5""" },
    { "rate" : """18.75""" },
    { "rate" : """4.97998""" },
    { "rate" : """8.475""" },
    { "rate" : """17.693""" },
    { "rate" : """8.3993""" },
    { "rate" : """8.99""" },
    { "rate" : """8""" },
    { "rate" : """12.26""" },
    { "rate" : """3.64""" },
    { "rate" : """12.26""" },
    { "rate" : """9""" },
    { "rate" : """3.63999""" },
    { "rate" : """3.64""" },
    { "rate" : """4.85""" },
    { "rate" : """8.89""" },
    { "rate" : """4.98""" },
    { "rate" : """3.64""" },
    { "rate" : """7.8""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """3""" },
    { "rate" : """2.99999""" },
    { "rate" : """3.63998""" },
    { "rate" : """8.5""" },
    { "rate" : """4.99999""" },
    { "rate" : """12.25""" },
    { "rate" : """8.49""" },
    { "rate" : """7""" },
    { "rate" : """12.26""" },
    { "rate" : """8.7999""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """3.63998""" },
    { "rate" : """5.46""" },
    { "rate" : """8""" },
    { "rate" : """7.64""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10.73""" },
    { "rate" : """3""" },
    { "rate" : """10.72999""" },
    { "rate" : """10""" },
    { "rate" : """0.4706""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """3.4""" },
    { "rate" : """9""" },
    { "rate" : """3.49999""" },
    { "rate" : """1.6""" },
    { "rate" : """10.73""" },
    { "rate" : """9""" },
    { "rate" : """9.9""" },
    { "rate" : """9""" },
    { "rate" : """9.9""" },
    { "rate" : """5""" },
    { "rate" : """3.64""" },
    { "rate" : """12.26""" },
    { "rate" : """10.73""" },
    { "rate" : """3.5""" },
    { "rate" : """8.17""" },
    { "rate" : """7.9999""" },
    { "rate" : """3""" },
    { "rate" : """2.99999""" },
    { "rate" : """16""" },
    { "rate" : """3.49""" },
    { "rate" : """12.26""" },
    { "rate" : """8.8""" },
    { "rate" : """10.73""" },
    { "rate" : """12.26""" },
    { "rate" : """17""" },
    { "rate" : """12""" },
    { "rate" : """13""" },
    { "rate" : """17""" },
    { "rate" : """16.99999""" },
    { "rate" : """11.99999""" },
    { "rate" : """20""" },
    { "rate" : """11.989""" },
    { "rate" : """16""" },
    { "rate" : """4.99""" },
    { "rate" : """10.72""" },
    { "rate" : """16.17""" },
    { "rate" : """19""" },
    { "rate" : """15""" },
    { "rate" : """12.7""" },
    { "rate" : """14.98""" },
    { "rate" : """21""" },
    { "rate" : """5""" },
    { "rate" : """3.5""" },
    { "rate" : """17""" },
    { "rate" : """6""" },
    { "rate" : """5.79""" },
    { "rate" : """5.78999""" },
    { "rate" : """5.78999""" },
    { "rate" : """14.8999""" },
    { "rate" : """5.79""" },
    { "rate" : """5.98""" },
    { "rate" : """5.79""" },
    { "rate" : """5.79""" },
    { "rate" : """4.97""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """5.79""" },
    { "rate" : """5.79""" },
    { "rate" : """5""" },
    { "rate" : """5.79""" },
    { "rate" : """3.99""" },
    { "rate" : """13.9339""" },
    { "rate" : """10.7293""" },
    { "rate" : """14.8""" },
    { "rate" : """10.73""" },
    { "rate" : """5.79""" },
    { "rate" : """5.5""" },
    { "rate" : """5.789""" },
    { "rate" : """8.9999""" },
    { "rate" : """9""" },
    { "rate" : """8.9899""" },
    { "rate" : """14.89989""" },
    { "rate" : """5.5""" },
    { "rate" : """5.5""" },
    { "rate" : """9""" },
    { "rate" : """5.97""" },
    { "rate" : """9.96""" },
    { "rate" : """5.78""" },
    { "rate" : """8.98989""" },
    { "rate" : """10.73""" },
    { "rate" : """11.99999""" },
    { "rate" : """5""" },
    { "rate" : """27.13""" },
    { "rate" : """5""" },
    { "rate" : """2.5""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """2.49999""" },
    { "rate" : """3.599""" },
    { "rate" : """4.89998""" },
    { "rate" : """10""" },
    { "rate" : """3.4998""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """4.5""" },
    { "rate" : """3.49999""" },
    { "rate" : """17""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """20.9""" },
    { "rate" : """2""" },
    { "rate" : """2.14""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """2""" },
    { "rate" : """1.9""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """4.9999""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """0.999""" },
    { "rate" : """8.64""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """2""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """12.26""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.9999""" },
    { "rate" : """5""" },
    { "rate" : """3""" },
    { "rate" : """2""" },
    { "rate" : """5""" },
    { "rate" : """20""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """16.88""" },
    { "rate" : """2""" },
    { "rate" : """8.8""" },
    { "rate" : """3.33""" },
    { "rate" : """8""" },
    { "rate" : """19.3369""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """0.4706""" },
    { "rate" : """15.14""" },
    { "rate" : """12.26""" },
    { "rate" : """14""" },
    { "rate" : """5""" },
    { "rate" : """15.14""" },
    { "rate" : """2""" },
    { "rate" : """13.7""" },
    { "rate" : """9.7""" },
    { "rate" : """16.98""" },
    { "rate" : """0.5""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """13.9633""" },
    { "rate" : """10.5""" },
    { "rate" : """20.58""" },
    { "rate" : """0.4706""" },
    { "rate" : """10.73""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10.73""" },
    { "rate" : """5""" },
    { "rate" : """10.73""" },
    { "rate" : """9.9""" },
    { "rate" : """12""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """10""" },
    { "rate" : """15.99""" },
    { "rate" : """15.98999""" },
    { "rate" : """16.73""" },
    { "rate" : """12.26""" },
    { "rate" : """5""" },
    { "rate" : """10.65""" },
    { "rate" : """10.72""" },
    { "rate" : """16.17""" },
    { "rate" : """10.73""" },
    { "rate" : """10.71999""" },
    { "rate" : """2.5""" },
    { "rate" : """10""" },
    { "rate" : """16""" },
    { "rate" : """0.96""" },
    { "rate" : """0.4706""" },
    { "rate" : """0.4""" },
    { "rate" : """10""" },
    { "rate" : """29.99""" },
    { "rate" : """6.67""" },
    { "rate" : """12.15""" },
    { "rate" : """16.17""" },
    { "rate" : """16""" },
    { "rate" : """12.26""" },
    { "rate" : """12.26""" },
    { "rate" : """8.99999""" },
    { "rate" : """9""" },
    { "rate" : """9.99999""" },
    { "rate" : """7.98877""" },
    { "rate" : """9""" },
    { "rate" : """15.98""" },
    { "rate" : """0.96""" },
    { "rate" : """11""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """8.89998""" },
    { "rate" : """9.7""" },
    { "rate" : """8.99""" },
    { "rate" : """12""" },
    { "rate" : """8.9""" },
    { "rate" : """9.96""" },
    { "rate" : """11.99""" },
    { "rate" : """12.99""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """9""" },
    { "rate" : """8""" },
    { "rate" : """9""" },
    { "rate" : """8.99""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """4""" },
    { "rate" : """13.10999""" },
    { "rate" : """16.17""" },
    { "rate" : """13""" },
    { "rate" : """7.9""" },
    { "rate" : """7.69""" },
    { "rate" : """8""" },
    { "rate" : """7.9999""" },
    { "rate" : """7.9999""" },
    { "rate" : """7""" },
    { "rate" : """6.99999""" },
    { "rate" : """8.98""" },
    { "rate" : """7.89998""" },
    { "rate" : """14.5""" },
    { "rate" : """7.8""" },
    { "rate" : """8.97888""" },
    { "rate" : """8.4""" },
    { "rate" : """8""" },
    { "rate" : """7.8""" },
    { "rate" : """8""" },
    { "rate" : """12.89""" },
    { "rate" : """7.7""" },
    { "rate" : """12.7""" },
    { "rate" : """9.7""" },
    { "rate" : """12.7""" },
    { "rate" : """7""" },
    { "rate" : """7.899""" },
    { "rate" : """8.9799""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """10.73""" },
    { "rate" : """13.1099""" },
    { "rate" : """10""" },
    { "rate" : """12.1""" },
    { "rate" : """11.5""" },
    { "rate" : """8""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13""" },
    { "rate" : """11.99999""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """12.99999""" },
    { "rate" : """12""" },
    { "rate" : """10.9""" },
    { "rate" : """1""" },
    { "rate" : """11.98999""" },
    { "rate" : """8""" },
    { "rate" : """7.9""" },
    { "rate" : """5""" },
    { "rate" : """6.5""" },
    { "rate" : """7.8""" },
    { "rate" : """12.4""" },
    { "rate" : """11.97""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """11.95""" },
    { "rate" : """3.99999""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """13.11""" },
    { "rate" : """7.79""" },
    { "rate" : """9.99""" },
    { "rate" : """12.45""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """12.22222""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """0.96""" },
    { "rate" : """20""" },
    { "rate" : """12""" },
    { "rate" : """6.55""" },
    { "rate" : """12.45""" },
    { "rate" : """16.16999""" },
    { "rate" : """13.11""" },
    { "rate" : """16.17""" },
    { "rate" : """20.45""" },
    { "rate" : """4.99999""" },
    { "rate" : """4.9""" },
    { "rate" : """4.98""" },
    { "rate" : """3""" },
    { "rate" : """4.89""" },
    { "rate" : """11.9998""" },
    { "rate" : """15.5""" },
    { "rate" : """13.11""" },
    { "rate" : """10.73""" },
    { "rate" : """16.7""" },
    { "rate" : """18.88""" },
    { "rate" : """16.17""" },
    { "rate" : """10""" },
    { "rate" : """15.5""" },
    { "rate" : """10""" },
    { "rate" : """10.369""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """16.17""" },
    { "rate" : """10.73""" },
    { "rate" : """16.1""" },
    { "rate" : """16.17""" },
    { "rate" : """16.1699""" },
    { "rate" : """23.5799""" },
    { "rate" : """11.25""" },
    { "rate" : """20.44""" },
    { "rate" : """13.11""" },
    { "rate" : """15""" },
    { "rate" : """13.11""" },
    { "rate" : """8.8""" },
    { "rate" : """16.1699""" },
    { "rate" : """0.96""" },
    { "rate" : """11.9""" },
    { "rate" : """11.98998""" },
    { "rate" : """16.17""" },
    { "rate" : """10.73""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """10.73""" },
    { "rate" : """8.8""" },
    { "rate" : """10.72999""" },
    { "rate" : """11""" },
    { "rate" : """15""" },
    { "rate" : """11.5""" },
    { "rate" : """15""" },
    { "rate" : """16.17""" },
    { "rate" : """8.8""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """9.5""" },
    { "rate" : """11.46""" },
    { "rate" : """16.17""" },
    { "rate" : """6""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """18.17""" },
    { "rate" : """15""" },
    { "rate" : """11.9""" },
    { "rate" : """6.5""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """16""" },
    { "rate" : """16.17""" },
    { "rate" : """11.99999""" },
    { "rate" : """16.15""" },
    { "rate" : """15.75""" },
    { "rate" : """10.65""" },
    { "rate" : """11.99""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """20""" },
    { "rate" : """9.6""" },
    { "rate" : """9.9""" },
    { "rate" : """9""" },
    { "rate" : """11.963""" },
    { "rate" : """23.53""" },
    { "rate" : """11.95""" },
    { "rate" : """10.72999""" },
    { "rate" : """23.57999""" },
    { "rate" : """7""" },
    { "rate" : """7.99""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """7""" },
    { "rate" : """7.89""" },
    { "rate" : """7.99996""" },
    { "rate" : """7.99999""" },
    { "rate" : """6.9""" },
    { "rate" : """6.89999""" },
    { "rate" : """7.77777""" },
    { "rate" : """7.99""" },
    { "rate" : """7.89999""" },
    { "rate" : """6.9999""" },
    { "rate" : """7.95""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """9.99999""" },
    { "rate" : """8.8""" },
    { "rate" : """12.46""" },
    { "rate" : """20.449""" },
    { "rate" : """10""" },
    { "rate" : """19""" },
    { "rate" : """8.8""" },
    { "rate" : """3""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """0.4706""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99996""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """1.98""" },
    { "rate" : """1.99999""" },
    { "rate" : """6.55""" },
    { "rate" : """2""" },
    { "rate" : """1.2""" },
    { "rate" : """1.999""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
    { "rate" : """1.98996""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """1.998""" },
    { "rate" : """1.5""" },
    { "rate" : """6.5499""" },
    { "rate" : """9.999""" },
    { "rate" : """9.95""" },
    { "rate" : """0.96""" },
    { "rate" : """9.8""" },
    { "rate" : """10""" },
    { "rate" : """20.44999""" },
    { "rate" : """15""" },
    { "rate" : """6.55""" },
    { "rate" : """20""" },
    { "rate" : """12.46""" },
    { "rate" : """10""" },
    { "rate" : """6.55""" },
    { "rate" : """20.449""" },
    { "rate" : """21.98""" },
    { "rate" : """4.98""" },
    { "rate" : """1.2""" },
    { "rate" : """0.9""" },
    { "rate" : """9.89""" },
    { "rate" : """5.99""" },
    { "rate" : """3""" },
    { "rate" : """14""" },
    { "rate" : """14""" },
    { "rate" : """2.99999""" },
    { "rate" : """9.9""" },
    { "rate" : """0.39899""" },
    { "rate" : """5""" },
    { "rate" : """13.11""" },
    { "rate" : """0.387""" },
    { "rate" : """0.39899""" },
    { "rate" : """16.17""" },
    { "rate" : """10.86""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """6.54996""" },
    { "rate" : """0.3""" },
    { "rate" : """0.35""" },
    { "rate" : """12""" },
    { "rate" : """12.46""" },
    { "rate" : """13""" },
    { "rate" : """3""" },
    { "rate" : """21""" },
    { "rate" : """6.54""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """11.7""" },
    { "rate" : """16.17""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """23.25""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """23.49""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """23.48""" },
    { "rate" : """9.99999""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """11.5""" },
    { "rate" : """12.5""" },
    { "rate" : """9.88""" },
    { "rate" : """17.48""" },
    { "rate" : """14.9""" },
    { "rate" : """15.5""" },
    { "rate" : """23""" },
    { "rate" : """23""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6.99999""" },
    { "rate" : """23""" },
    { "rate" : """8""" },
    { "rate" : """7.99999""" },
    { "rate" : """8""" },
    { "rate" : """12.46""" },
    { "rate" : """16.17""" },
    { "rate" : """12.46""" },
    { "rate" : """4.98""" },
    { "rate" : """4.9""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """12.46""" },
    { "rate" : """16.17""" },
    { "rate" : """5""" },
    { "rate" : """12.46""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """14""" },
    { "rate" : """23""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """16.17""" },
    { "rate" : """12.46""" },
    { "rate" : """9.5""" },
    { "rate" : """7""" },
    { "rate" : """16.17""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """15.17""" },
    { "rate" : """6.99""" },
    { "rate" : """20""" },
    { "rate" : """7""" },
    { "rate" : """12.46""" },
    { "rate" : """16.17""" },
    { "rate" : """16.15""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """10""" },
    { "rate" : """8.5""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """3.64""" },
    { "rate" : """1.1""" },
    { "rate" : """3.5""" },
    { "rate" : """3.63""" },
    { "rate" : """9.99999""" },
    { "rate" : """13.11""" },
    { "rate" : """13.11""" },
    { "rate" : """13""" },
    { "rate" : """12.99999""" },
    { "rate" : """6.99999""" },
    { "rate" : """7.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """13.11""" },
    { "rate" : """6.9""" },
    { "rate" : """12.46""" },
    { "rate" : """8.8""" },
    { "rate" : """13.11""" },
    { "rate" : """8""" },
    { "rate" : """2""" },
    { "rate" : """13""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """2.8""" },
    { "rate" : """13""" },
    { "rate" : """3""" },
    { "rate" : """2.79999""" },
    { "rate" : """3""" },
    { "rate" : """7.8""" },
    { "rate" : """6.8""" },
    { "rate" : """12""" },
    { "rate" : """2.9""" },
    { "rate" : """2.99""" },
    { "rate" : """2.99""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """0.1999""" },
    { "rate" : """0.18""" },
    { "rate" : """13.11""" },
    { "rate" : """0.2""" },
    { "rate" : """0.19999""" },
    { "rate" : """8""" },
    { "rate" : """8.8""" },
    { "rate" : """12.46""" },
    { "rate" : """2.99""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """13.11""" },
    { "rate" : """0.2""" },
    { "rate" : """0.249""" },
    { "rate" : """0.175""" },
    { "rate" : """0.2""" },
    { "rate" : """0.26""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.5""" },
    { "rate" : """1.28""" },
    { "rate" : """0.22999""" },
    { "rate" : """0.19""" },
    { "rate" : """0.1""" },
    { "rate" : """8""" },
    { "rate" : """0.2""" },
    { "rate" : """2.98""" },
    { "rate" : """12.46""" },
    { "rate" : """0.2699""" },
    { "rate" : """11""" },
    { "rate" : """9.99999""" },
    { "rate" : """18.98""" },
    { "rate" : """2.97999""" },
    { "rate" : """12""" },
    { "rate" : """0.21987""" },
    { "rate" : """0.1""" },
    { "rate" : """1""" },
    { "rate" : """0.23""" },
    { "rate" : """0.2""" },
    { "rate" : """12""" },
    { "rate" : """7.89""" },
    { "rate" : """6.98""" },
    { "rate" : """11.7""" },
    { "rate" : """12""" },
    { "rate" : """12.5""" },
    { "rate" : """13.7""" },
    { "rate" : """12.49999""" },
    { "rate" : """13.72""" },
    { "rate" : """13""" },
    { "rate" : """12""" },
    { "rate" : """13.7""" },
    { "rate" : """11.9998""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """18.98""" },
    { "rate" : """11.99999""" },
    { "rate" : """13.71999""" },
    { "rate" : """0.11""" },
    { "rate" : """7""" },
    { "rate" : """13""" },
    { "rate" : """0.25""" },
    { "rate" : """0.279""" },
    { "rate" : """6.9999""" },
    { "rate" : """7.99888""" },
    { "rate" : """0.98""" },
    { "rate" : """18.98""" },
    { "rate" : """7.989""" },
    { "rate" : """2.99999""" },
    { "rate" : """11.88""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """4.99999""" },
    { "rate" : """6.99""" },
    { "rate" : """5.8""" },
    { "rate" : """5.95""" },
    { "rate" : """8""" },
    { "rate" : """5.5""" },
    { "rate" : """6.5""" },
    { "rate" : """4.9""" },
    { "rate" : """0.2""" },
    { "rate" : """6""" },
    { "rate" : """5.999""" },
    { "rate" : """5.9""" },
    { "rate" : """6""" },
    { "rate" : """5.98""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """6""" },
    { "rate" : """5.8""" },
    { "rate" : """5.999""" },
    { "rate" : """5.99999""" },
    { "rate" : """6""" },
    { "rate" : """5.99999""" },
    { "rate" : """6""" },
    { "rate" : """5.5""" },
    { "rate" : """5.9999""" },
    { "rate" : """6""" },
    { "rate" : """5.99""" },
    { "rate" : """7""" },
    { "rate" : """0.59999""" },
    { "rate" : """2""" },
    { "rate" : """9""" },
    { "rate" : """7""" },
    { "rate" : """12""" },
    { "rate" : """8""" },
    { "rate" : """4.75""" },
    { "rate" : """5""" },
    { "rate" : """9.96""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """18.98""" },
    { "rate" : """7""" },
    { "rate" : """6.99999""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """6.9999""" },
    { "rate" : """4.99""" },
    { "rate" : """6.9""" },
    { "rate" : """7""" },
    { "rate" : """6.99999""" },
    { "rate" : """6.99996""" },
    { "rate" : """5""" },
    { "rate" : """4.747""" },
    { "rate" : """6.9""" },
    { "rate" : """8""" },
    { "rate" : """6.9999""" },
    { "rate" : """6.9998""" },
    { "rate" : """4.9""" },
    { "rate" : """7.99999""" },
    { "rate" : """7""" },
    { "rate" : """4.19""" },
    { "rate" : """8.8""" },
    { "rate" : """2.9""" },
    { "rate" : """8.79999""" },
    { "rate" : """2.89999""" },
    { "rate" : """6.88""" },
    { "rate" : """6.88""" },
    { "rate" : """8.8""" },
    { "rate" : """9.95""" },
    { "rate" : """6.99999""" },
    { "rate" : """8.8""" },
    { "rate" : """8""" },
    { "rate" : """2.9""" },
    { "rate" : """6.99999""" },
    { "rate" : """8.5""" },
    { "rate" : """8.96""" },
    { "rate" : """17""" },
    { "rate" : """5""" },
    { "rate" : """6.9""" },
    { "rate" : """9""" },
    { "rate" : """5""" },
    { "rate" : """8.9""" },
    { "rate" : """2.75""" },
    { "rate" : """8.5""" },
    { "rate" : """8.75""" },
    { "rate" : """9.5""" },
    { "rate" : """7.8""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """4.7""" },
    { "rate" : """7.999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """13.11""" },
    { "rate" : """9.9""" },
    { "rate" : """9.87""" },
    { "rate" : """9.9""" },
    { "rate" : """9.89999""" },
    { "rate" : """9.99999""" },
    { "rate" : """8""" },
    { "rate" : """9.9""" },
    { "rate" : """10.72999""" },
    { "rate" : """9.4""" },
    { "rate" : """7.99999""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """7.9999""" },
    { "rate" : """10.73""" },
    { "rate" : """9""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """9.98""" },
    { "rate" : """9""" },
    { "rate" : """6.99999""" },
    { "rate" : """5.5""" },
    { "rate" : """6.99999""" },
    { "rate" : """8.8""" },
    { "rate" : """2.85""" },
    { "rate" : """6.5""" },
    { "rate" : """5.25""" },
    { "rate" : """4.99999""" },
    { "rate" : """6""" },
    { "rate" : """4.999""" },
    { "rate" : """2""" },
    { "rate" : """9.9""" },
    { "rate" : """2.8999""" },
    { "rate" : """9.9""" },
    { "rate" : """9.8""" },
    { "rate" : """9""" },
    { "rate" : """10""" },
    { "rate" : """9""" },
    { "rate" : """9.88""" },
    { "rate" : """8.99999""" },
    { "rate" : """7.99""" },
    { "rate" : """13""" },
    { "rate" : """13.11""" },
    { "rate" : """8.8""" },
    { "rate" : """9.989""" },
    { "rate" : """4.99""" },
    { "rate" : """7.5""" },
    { "rate" : """4.75""" },
    { "rate" : """8""" },
    { "rate" : """11""" },
    { "rate" : """9""" },
    { "rate" : """13.1""" },
    { "rate" : """2.9""" },
    { "rate" : """10""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10.73""" },
    { "rate" : """8.8""" },
    { "rate" : """2.89998""" },
    { "rate" : """10.72""" },
    { "rate" : """12.9999""" },
    { "rate" : """7""" },
    { "rate" : """9.9""" },
    { "rate" : """9.99""" },
    { "rate" : """9.86""" },
    { "rate" : """9.89999""" },
    { "rate" : """9.5""" },
    { "rate" : """10.73""" },
    { "rate" : """8.8""" },
    { "rate" : """7""" },
    { "rate" : """0.4706""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """5""" },
    { "rate" : """6.99999""" },
    { "rate" : """7.5""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """8.7""" },
    { "rate" : """10.73""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """1""" },
    { "rate" : """11""" },
    { "rate" : """16.17""" },
    { "rate" : """16.16999""" },
    { "rate" : """1.5""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """0.79999""" },
    { "rate" : """9.99999""" },
    { "rate" : """11.9999""" },
    { "rate" : """15""" },
    { "rate" : """1.98""" },
    { "rate" : """1.99999""" },
    { "rate" : """16.17""" },
    { "rate" : """1""" },
    { "rate" : """11.99999""" },
    { "rate" : """1.337""" },
    { "rate" : """10.73""" },
    { "rate" : """13.10999""" },
    { "rate" : """9.9""" },
    { "rate" : """1.98""" },
    { "rate" : """1.99""" },
    { "rate" : """15""" },
    { "rate" : """18.98""" },
    { "rate" : """16.17""" },
    { "rate" : """12""" },
    { "rate" : """16.17""" },
    { "rate" : """14.11""" },
    { "rate" : """1.83""" },
    { "rate" : """1.7""" },
    { "rate" : """1.9999""" },
    { "rate" : """1.99999""" },
    { "rate" : """7""" },
    { "rate" : """1.9999""" },
    { "rate" : """10""" },
    { "rate" : """6.9""" },
    { "rate" : """10.73""" },
    { "rate" : """8.8""" },
    { "rate" : """16.17""" },
    { "rate" : """8.8""" },
    { "rate" : """6.99999""" },
    { "rate" : """0.5""" },
    { "rate" : """10.73""" },
    { "rate" : """18""" },
    { "rate" : """12""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """1.999""" },
    { "rate" : """1.98""" },
    { "rate" : """10.73""" },
    { "rate" : """16.17""" },
    { "rate" : """10.73""" },
    { "rate" : """10.73""" },
    { "rate" : """1.5""" },
    { "rate" : """10.73""" },
    { "rate" : """8.49""" },
    { "rate" : """16""" },
    { "rate" : """8.79999""" },
    { "rate" : """17""" },
    { "rate" : """8.79999""" },
    { "rate" : """15.99999""" },
    { "rate" : """15""" },
    { "rate" : """13""" },
    { "rate" : """10.72""" },
    { "rate" : """10.71999""" },
    { "rate" : """8.8""" },
    { "rate" : """9.99999""" },
    { "rate" : """11""" },
    { "rate" : """13.72""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """0.96""" },
    { "rate" : """10""" },
    { "rate" : """9.9999""" },
    { "rate" : """11""" },
    { "rate" : """2""" },
    { "rate" : """13.72""" },
    { "rate" : """16.17""" },
    { "rate" : """13.47""" },
    { "rate" : """12""" },
    { "rate" : """23.58""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """8.8""" },
    { "rate" : """20""" },
    { "rate" : """14""" },
    { "rate" : """10""" },
    { "rate" : """16.17""" },
    { "rate" : """8.8""" },
    { "rate" : """16.17""" },
    { "rate" : """8.8""" },
    { "rate" : """12.26""" },
    { "rate" : """16""" },
    { "rate" : """18.98""" },
    { "rate" : """19.8""" },
    { "rate" : """10.72999""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """18.98""" },
    { "rate" : """11""" },
    { "rate" : """16.17""" },
    { "rate" : """9.9""" },
    { "rate" : """12""" },
    { "rate" : """3""" },
    { "rate" : """9.99999""" },
    { "rate" : """2.99999""" },
    { "rate" : """8.8""" },
    { "rate" : """2.99999""" },
    { "rate" : """12.26""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """10.73""" },
    { "rate" : """12.26""" },
    { "rate" : """15.5""" },
    { "rate" : """12.26""" },
    { "rate" : """8.8""" },
    { "rate" : """16.17""" },
    { "rate" : """13""" },
    { "rate" : """16.17""" },
    { "rate" : """8.8""" },
    { "rate" : """8.8""" },
    { "rate" : """11.5""" },
    { "rate" : """12""" },
    { "rate" : """12.46""" },
    { "rate" : """19.99""" },
    { "rate" : """8.8""" },
    { "rate" : """10""" },
    { "rate" : """9.9""" },
    { "rate" : """12.26""" },
    { "rate" : """16.17""" },
    { "rate" : """12""" },
    { "rate" : """18.98""" },
    { "rate" : """12.46""" },
    { "rate" : """5""" },
    { "rate" : """8.8""" },
    { "rate" : """16.17""" },
    { "rate" : """16.17""" },
    { "rate" : """8.8""" },
    { "rate" : """13""" },
    { "rate" : """8""" },
    { "rate" : """11.88""" },
    { "rate" : """12.26""" },
    { "rate" : """18.98""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """8.8""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """0.4706""" },
    { "rate" : """10""" },
    { "rate" : """12.46""" },
    { "rate" : """12""" },
    { "rate" : """6""" },
    { "rate" : """10""" },
    { "rate" : """18.98""" },
    { "rate" : """1""" },
    { "rate" : """0.001""" },
    { "rate" : """0.00099""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """10.5""" },
    { "rate" : """1""" },
    { "rate" : """0.9""" },
    { "rate" : """1""" },
    { "rate" : """8.48""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """8.8""" },
    { "rate" : """1.94998""" },
    { "rate" : """7.99999""" },
    { "rate" : """0.98""" },
    { "rate" : """0.001""" },
    { "rate" : """0.95""" },
    { "rate" : """12.26""" },
    { "rate" : """11.7""" },
    { "rate" : """0.95""" },
    { "rate" : """0.9999""" },
    { "rate" : """1""" },
    { "rate" : """14.7""" },
    { "rate" : """11.99""" },
    { "rate" : """9.98""" },
    { "rate" : """0.87""" },
    { "rate" : """1.8""" },
    { "rate" : """0.8""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """0.75""" },
    { "rate" : """1.95""" },
    { "rate" : """12""" },
    { "rate" : """25.99""" },
    { "rate" : """11""" },
    { "rate" : """25.99""" },
    { "rate" : """0.99""" },
    { "rate" : """25.99""" },
    { "rate" : """1.9""" },
    { "rate" : """15""" },
    { "rate" : """14.99999""" },
    { "rate" : """15""" },
    { "rate" : """14.999""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """14.5""" },
    { "rate" : """0.74999""" },
    { "rate" : """1.9""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """14.9""" },
    { "rate" : """15""" },
    { "rate" : """0.0748""" },
    { "rate" : """18.08""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """1.5""" },
    { "rate" : """14""" },
    { "rate" : """25""" },
    { "rate" : """25""" },
    { "rate" : """15""" },
    { "rate" : """5.99999""" },
    { "rate" : """0.99""" },
    { "rate" : """5.99998""" },
    { "rate" : """15""" },
    { "rate" : """14.9""" },
    { "rate" : """12""" },
    { "rate" : """0.4706""" },
    { "rate" : """15""" },
    { "rate" : """0.4706""" },
    { "rate" : """15""" },
    { "rate" : """4.9""" },
    { "rate" : """4.5""" },
    { "rate" : """0.4706""" },
    { "rate" : """10""" },
    { "rate" : """14""" },
    { "rate" : """4.9""" },
    { "rate" : """0.56""" },
    { "rate" : """4.9""" },
    { "rate" : """1.89""" },
    { "rate" : """14.88""" },
    { "rate" : """4.89""" },
    { "rate" : """2""" },
    { "rate" : """6""" },
    { "rate" : """0.56""" },
    { "rate" : """0.56""" },
    { "rate" : """4.89""" },
    { "rate" : """0.56""" },
    { "rate" : """20""" },
    { "rate" : """0.56""" },
    { "rate" : """0.5""" },
    { "rate" : """14""" },
    { "rate" : """4.89999""" },
    { "rate" : """13.99999""" },
    { "rate" : """15.37""" },
    { "rate" : """0.55""" },
    { "rate" : """19""" },
    { "rate" : """0.55""" },
    { "rate" : """4.89996""" },
    { "rate" : """0.55""" },
    { "rate" : """0.55""" },
    { "rate" : """181.08""" },
    { "rate" : """15""" },
    { "rate" : """181.08""" },
    { "rate" : """29.37""" },
    { "rate" : """25.99""" },
    { "rate" : """4.89""" },
    { "rate" : """18.31""" },
    { "rate" : """0.55999""" },
    { "rate" : """14.8""" },
    { "rate" : """29.37""" },
    { "rate" : """181.08""" },
    { "rate" : """2""" },
    { "rate" : """21.9999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """12""" },
    { "rate" : """25.99""" },
    { "rate" : """8.7""" },
    { "rate" : """12""" },
    { "rate" : """4.89999""" },
    { "rate" : """0.55999""" },
    { "rate" : """0.5""" },
    { "rate" : """5""" },
    { "rate" : """0.56""" },
    { "rate" : """0.54""" },
    { "rate" : """4.7""" },
    { "rate" : """12.7""" },
    { "rate" : """5.99997""" },
    { "rate" : """18.31""" },
    { "rate" : """13.7""" },
    { "rate" : """4.8""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """29.37""" },
    { "rate" : """181.08""" },
    { "rate" : """14.64""" },
    { "rate" : """0.5""" },
    { "rate" : """11.99""" },
    { "rate" : """0.549""" },
    { "rate" : """0.55555""" },
    { "rate" : """20""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.7""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """9""" },
    { "rate" : """12""" },
    { "rate" : """10""" },
    { "rate" : """181.08""" },
    { "rate" : """9.5""" },
    { "rate" : """9""" },
    { "rate" : """0.5""" },
    { "rate" : """8.99999""" },
    { "rate" : """181.08""" },
    { "rate" : """9.88""" },
    { "rate" : """29.37""" },
    { "rate" : """9.99""" },
    { "rate" : """25.99""" },
    { "rate" : """10""" },
    { "rate" : """9.999""" },
    { "rate" : """9.87""" },
    { "rate" : """10""" },
    { "rate" : """20""" },
    { "rate" : """14.99""" },
    { "rate" : """23.99""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """16.5""" },
    { "rate" : """181.08""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """0.5""" },
    { "rate" : """0.5""" },
    { "rate" : """9.99""" },
    { "rate" : """10""" },
    { "rate" : """25""" },
    { "rate" : """9.8899""" },
    { "rate" : """8.4999""" },
    { "rate" : """9""" },
    { "rate" : """20""" },
    { "rate" : """0.55""" },
    { "rate" : """8""" },
    { "rate" : """1.289""" },
    { "rate" : """6""" },
    { "rate" : """0.55""" },
    { "rate" : """15.49""" },
    { "rate" : """19""" },
    { "rate" : """18.31""" },
    { "rate" : """15""" },
    { "rate" : """9.9""" },
    { "rate" : """14""" },
    { "rate" : """23""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """0.5""" },
    { "rate" : """12""" },
    { "rate" : """0.5599""" },
    { "rate" : """11.99""" },
    { "rate" : """11.99""" },
    { "rate" : """14.99999""" },
    { "rate" : """9""" },
    { "rate" : """0.5""" },
    { "rate" : """2.99""" },
    { "rate" : """8.75""" },
    { "rate" : """8""" },
    { "rate" : """7.99999""" },
    { "rate" : """8""" },
    { "rate" : """181.08""" },
    { "rate" : """8.99""" },
    { "rate" : """181.08""" },
    { "rate" : """7.99999""" },
    { "rate" : """7.999""" },
    { "rate" : """19""" },
    { "rate" : """19""" },
    { "rate" : """181.08""" },
    { "rate" : """8.4889""" },
    { "rate" : """8""" },
    { "rate" : """8.48""" },
    { "rate" : """23""" },
    { "rate" : """14.98999""" },
    { "rate" : """181.08""" },
    { "rate" : """181.08""" },
    { "rate" : """14.8""" },
    { "rate" : """181.08""" },
    { "rate" : """18.31""" },
    { "rate" : """8.49""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """18""" },
    { "rate" : """25""" },
    { "rate" : """0.49999""" },
    { "rate" : """181.08""" },
    { "rate" : """8""" },
    { "rate" : """8.39""" },
    { "rate" : """15""" },
    { "rate" : """8""" },
    { "rate" : """8.5""" },
    { "rate" : """7.99999""" },
    { "rate" : """18.31""" },
    { "rate" : """6""" },
    { "rate" : """25.98999""" },
    { "rate" : """5.99999""" },
    { "rate" : """14""" },
    { "rate" : """14.8""" },
    { "rate" : """18.31""" },
    { "rate" : """24.99""" },
    { "rate" : """0.96""" },
    { "rate" : """18.31""" },
    { "rate" : """18.31""" },
    { "rate" : """2.99""" },
    { "rate" : """3.01""" },
    { "rate" : """2.9""" },
    { "rate" : """2.89999""" },
    { "rate" : """2.87999""" },
    { "rate" : """3""" },
    { "rate" : """2.9""" },
    { "rate" : """1.5""" },
    { "rate" : """2.99""" },
    { "rate" : """1.9999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """9.88""" },
    { "rate" : """8""" },
    { "rate" : """18""" },
    { "rate" : """9.999""" },
    { "rate" : """14.8""" },
    { "rate" : """18.31""" },
    { "rate" : """10""" },
    { "rate" : """18""" },
    { "rate" : """6""" },
    { "rate" : """14""" },
    { "rate" : """9.9""" },
    { "rate" : """15""" },
    { "rate" : """14.8""" },
    { "rate" : """15""" },
    { "rate" : """12""" },
    { "rate" : """11.99999""" },
    { "rate" : """13""" },
    { "rate" : """10""" },
    { "rate" : """12.99999""" },
    { "rate" : """11.999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """11.98""" },
    { "rate" : """15""" },
    { "rate" : """11.99""" },
    { "rate" : """11.999""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """13.5""" },
    { "rate" : """12""" },
    { "rate" : """0.39""" },
    { "rate" : """0.39""" },
    { "rate" : """0.39""" },
    { "rate" : """0.39998""" },
    { "rate" : """0.39997""" },
    { "rate" : """10""" },
    { "rate" : """0.3""" },
    { "rate" : """0.398""" },
    { "rate" : """0.39""" },
    { "rate" : """0.32""" },
    { "rate" : """0.98""" },
    { "rate" : """0.3""" },
    { "rate" : """0.38""" },
    { "rate" : """0.9""" },
    { "rate" : """0.3""" },
    { "rate" : """0.89""" },
    { "rate" : """0.949""" },
    { "rate" : """4.96895""" },
    { "rate" : """0.85""" },
    { "rate" : """0.97999""" },
    { "rate" : """1""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.39996""" },
    { "rate" : """0.97999""" },
    { "rate" : """4.9""" },
    { "rate" : """0.3""" },
    { "rate" : """0.3""" },
    { "rate" : """0.2999""" },
    { "rate" : """0.2999""" },
    { "rate" : """0.29999""" },
    { "rate" : """0.38999""" },
    { "rate" : """8.91""" },
    { "rate" : """4.94899""" },
    { "rate" : """0.287""" },
    { "rate" : """4.94""" },
    { "rate" : """4.95""" },
    { "rate" : """3""" },
    { "rate" : """4.94896""" },
    { "rate" : """4.95""" },
    { "rate" : """12.99""" },
    { "rate" : """4""" },
    { "rate" : """4.9""" },
    { "rate" : """12.5""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """9.99""" },
    { "rate" : """4.89999""" },
    { "rate" : """20""" },
    { "rate" : """12""" },
    { "rate" : """12""" },
    { "rate" : """18.31""" },
    { "rate" : """10""" },
    { "rate" : """17""" },
    { "rate" : """18.31""" },
    { "rate" : """18.3""" },
    { "rate" : """18.30999""" },
    { "rate" : """8""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """9.9""" },
    { "rate" : """2.78""" },
    { "rate" : """8.31""" },
    { "rate" : """1""" },
    { "rate" : """6.5""" },
    { "rate" : """6""" },
    { "rate" : """7""" },
    { "rate" : """6.6""" },
    { "rate" : """6""" },
    { "rate" : """6.89""" },
    { "rate" : """7""" },
    { "rate" : """6""" },
    { "rate" : """5.99999""" },
    { "rate" : """4""" },
    { "rate" : """7""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """5.75""" },
    { "rate" : """6""" },
    { "rate" : """5.99""" },
    { "rate" : """3.99999""" },
    { "rate" : """3.98998""" },
    { "rate" : """4""" },
    { "rate" : """12""" },
    { "rate" : """5""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """2""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3""" },
    { "rate" : """6.99""" },
    { "rate" : """8.2""" },
    { "rate" : """3.9""" },
    { "rate" : """14""" },
    { "rate" : """15""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """12""" },
    { "rate" : """11.999""" },
    { "rate" : """9.99999""" },
    { "rate" : """10""" },
    { "rate" : """8""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """11""" },
    { "rate" : """11.9""" },
    { "rate" : """9.9""" },
    { "rate" : """11""" },
    { "rate" : """19""" },
    { "rate" : """10""" },
    { "rate" : """11.88""" },
    { "rate" : """11.88""" },
    { "rate" : """14""" },
    { "rate" : """9""" },
    { "rate" : """3""" },
    { "rate" : """14""" },
    { "rate" : """0.49""" },
    { "rate" : """10""" },
    { "rate" : """0.4""" },
    { "rate" : """0.4899""" },
    { "rate" : """0.5""" },
    { "rate" : """0.4""" },
    { "rate" : """9.9""" },
    { "rate" : """12.99""" },
    { "rate" : """10.99999""" },
    { "rate" : """7.77777""" },
    { "rate" : """13.9999""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """5""" },
    { "rate" : """9.9""" },
    { "rate" : """21""" },
    { "rate" : """4""" },
    { "rate" : """22.04""" },
    { "rate" : """20""" },
    { "rate" : """22.04""" },
    { "rate" : """22.04""" },
    { "rate" : """11.99999""" },
    { "rate" : """9.99998""" },
    { "rate" : """14""" },
    { "rate" : """9""" },
    { "rate" : """22""" },
    { "rate" : """4""" },
    { "rate" : """8""" },
    { "rate" : """8.99999""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """0.05""" },
    { "rate" : """5.99""" },
    { "rate" : """6""" },
    { "rate" : """25""" },
    { "rate" : """25""" },
    { "rate" : """4""" },
    { "rate" : """9""" },
    { "rate" : """1""" },
    { "rate" : """8.34""" },
    { "rate" : """6""" },
    { "rate" : """1.5""" },
    { "rate" : """3.99999""" },
    { "rate" : """6""" },
    { "rate" : """5""" },
    { "rate" : """8.34""" },
    { "rate" : """1.49""" },
    { "rate" : """5.999""" },
    { "rate" : """1.4""" },
    { "rate" : """3.9""" },
    { "rate" : """8""" },
    { "rate" : """0.2987""" },
    { "rate" : """1.38""" },
    { "rate" : """5""" },
    { "rate" : """5.98""" },
    { "rate" : """3.89""" },
    { "rate" : """0.39""" },
    { "rate" : """8.34""" },
    { "rate" : """5.9""" },
    { "rate" : """0.3999""" },
    { "rate" : """8.34""" },
    { "rate" : """5.5""" },
    { "rate" : """3.9""" },
    { "rate" : """7.98""" },
    { "rate" : """0.39999""" },
    { "rate" : """1.5""" },
    { "rate" : """4""" },
    { "rate" : """4.22""" },
    { "rate" : """3""" },
    { "rate" : """5.9""" },
    { "rate" : """6""" },
    { "rate" : """5.993""" },
    { "rate" : """5""" },
    { "rate" : """9""" },
    { "rate" : """10.2""" },
    { "rate" : """20""" },
    { "rate" : """3""" },
    { "rate" : """0.39""" },
    { "rate" : """22""" },
    { "rate" : """8.34""" },
    { "rate" : """8.34""" },
    { "rate" : """3""" },
    { "rate" : """9.9""" },
    { "rate" : """3""" },
    { "rate" : """15""" },
    { "rate" : """35.55999""" },
    { "rate" : """35.56""" },
    { "rate" : """10.22""" },
    { "rate" : """20""" },
    { "rate" : """1""" },
    { "rate" : """10""" },
    { "rate" : """10.22""" },
    { "rate" : """17.36""" },
    { "rate" : """8.34""" },
    { "rate" : """10.22""" },
    { "rate" : """4.36""" },
    { "rate" : """10.22""" },
    { "rate" : """5.34""" },
    { "rate" : """9.9""" },
    { "rate" : """1""" },
    { "rate" : """18.22""" },
    { "rate" : """20""" },
    { "rate" : """0.39""" },
    { "rate" : """4""" },
    { "rate" : """8.34""" },
    { "rate" : """5""" },
    { "rate" : """0.38""" },
    { "rate" : """4.99999""" },
    { "rate" : """8.34""" },
    { "rate" : """14""" },
    { "rate" : """3""" },
    { "rate" : """8.34""" },
    { "rate" : """8""" },
    { "rate" : """8.34""" },
    { "rate" : """8.34""" },
    { "rate" : """5""" },
    { "rate" : """1.4""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """1.9""" },
    { "rate" : """1""" },
    { "rate" : """1.4""" },
    { "rate" : """1""" },
    { "rate" : """1.7""" },
    { "rate" : """1.5""" },
    { "rate" : """1.5""" },
    { "rate" : """1.7""" },
    { "rate" : """2.3""" },
    { "rate" : """1""" },
    { "rate" : """1.4""" },
    { "rate" : """1.39""" },
    { "rate" : """8.34""" },
    { "rate" : """5""" },
    { "rate" : """5""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """1.9""" },
    { "rate" : """2""" },
    { "rate" : """1.999""" },
    { "rate" : """2""" },
    { "rate" : """1.4""" },
    { "rate" : """1""" },
    { "rate" : """1.89999""" },
    { "rate" : """1""" },
    { "rate" : """1.99""" },
    { "rate" : """1.2""" },
    { "rate" : """0.95""" },
    { "rate" : """1.5""" },
    { "rate" : """1.38999""" },
    { "rate" : """1.4""" },
    { "rate" : """1""" },
    { "rate" : """0.8""" },
    { "rate" : """1""" },
    { "rate" : """1.29""" },
    { "rate" : """1.29""" },
    { "rate" : """2""" },
    { "rate" : """1.3""" },
    { "rate" : """0.9""" },
    { "rate" : """1.99""" },
    { "rate" : """1.9999""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """1""" },
    { "rate" : """16""" },
    { "rate" : """1.9""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.99999""" },
    { "rate" : """0.99999""" },
    { "rate" : """1""" },
    { "rate" : """1.5""" },
    { "rate" : """1""" },
    { "rate" : """15""" },
    { "rate" : """14.9""" },
    { "rate" : """0.9""" },
    { "rate" : """1""" },
    { "rate" : """0.9""" },
    { "rate" : """14.99999""" },
    { "rate" : """8.34""" },
    { "rate" : """0.942""" },
    { "rate" : """15""" },
    { "rate" : """1.4""" },
    { "rate" : """0.925""" },
    { "rate" : """0.93999""" },
    { "rate" : """0.97""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9""" },
    { "rate" : """0.93""" },
    { "rate" : """0.999""" },
    { "rate" : """0.4""" },
    { "rate" : """0.92""" },
    { "rate" : """0.89999""" },
    { "rate" : """0.9""" },
    { "rate" : """0.942""" },
    { "rate" : """0.94""" },
    { "rate" : """0.9499""" },
    { "rate" : """1""" },
    { "rate" : """8.34""" },
    { "rate" : """5.79""" },
    { "rate" : """8.34""" },
    { "rate" : """0.8""" },
    { "rate" : """0.9""" },
    { "rate" : """8.34""" },
    { "rate" : """8.34""" },
    { "rate" : """4.5""" },
    { "rate" : """4.5""" },
    { "rate" : """4.44444""" },
    { "rate" : """4.49""" },
    { "rate" : """0.87""" },
    { "rate" : """4.44""" },
    { "rate" : """4.89""" },
    { "rate" : """4.9""" },
    { "rate" : """4.4999""" },
    { "rate" : """4.38""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """4""" },
    { "rate" : """3.99""" },
    { "rate" : """4.9""" },
    { "rate" : """3.98999""" },
    { "rate" : """8.34""" },
    { "rate" : """1.99""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """4.5""" },
    { "rate" : """1.98999""" },
    { "rate" : """3.89999""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """0.99999""" },
    { "rate" : """4.8""" },
    { "rate" : """1""" },
    { "rate" : """1.5""" },
    { "rate" : """0.99999""" },
    { "rate" : """4.8""" },
    { "rate" : """3.9""" },
    { "rate" : """3.9999""" },
    { "rate" : """0.99998""" },
    { "rate" : """1.99999""" },
    { "rate" : """4.5""" },
    { "rate" : """0.98""" },
    { "rate" : """1.99989""" },
    { "rate" : """1.99989""" },
    { "rate" : """0.88""" },
    { "rate" : """4.5""" },
    { "rate" : """3.975""" },
    { "rate" : """0.9""" },
    { "rate" : """0.91""" },
    { "rate" : """1.99999""" },
    { "rate" : """8.34""" },
    { "rate" : """3.89999""" },
    { "rate" : """10""" },
    { "rate" : """3.999""" },
    { "rate" : """1.99""" },
    { "rate" : """10""" },
    { "rate" : """0.99997""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.88888""" },
    { "rate" : """0.87998""" },
    { "rate" : """10""" },
    { "rate" : """9.99999""" },
    { "rate" : """1.88887""" },
    { "rate" : """0.88""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """9.8""" },
    { "rate" : """8.34""" },
    { "rate" : """42.36""" },
    { "rate" : """0.499""" },
    { "rate" : """1.98""" },
    { "rate" : """10""" },
    { "rate" : """0.87""" },
    { "rate" : """1.99""" },
    { "rate" : """9.99999""" },
    { "rate" : """3.99""" },
    { "rate" : """0.87""" },
    { "rate" : """0.87""" },
    { "rate" : """9.9""" },
    { "rate" : """15""" },
    { "rate" : """9.95""" },
    { "rate" : """8.34""" },
    { "rate" : """5.2""" },
    { "rate" : """1""" },
    { "rate" : """0.9""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """6.9""" },
    { "rate" : """6.9""" },
    { "rate" : """6.99999""" },
    { "rate" : """6.95""" },
    { "rate" : """6.95""" },
    { "rate" : """6.5""" },
    { "rate" : """6.8""" },
    { "rate" : """7""" },
    { "rate" : """6.98999""" },
    { "rate" : """6.97""" },
    { "rate" : """6.4""" },
    { "rate" : """1""" },
    { "rate" : """8.34""" },
    { "rate" : """6.9""" },
    { "rate" : """8.34""" },
    { "rate" : """2.85""" },
    { "rate" : """5""" },
    { "rate" : """8.33999""" },
    { "rate" : """0.9""" },
    { "rate" : """8.34""" },
    { "rate" : """8.34""" },
    { "rate" : """8.3""" },
    { "rate" : """8.34""" },
    { "rate" : """8""" },
    { "rate" : """5""" },
    { "rate" : """13.9""" },
    { "rate" : """5""" },
    { "rate" : """8.34""" },
    { "rate" : """2.5""" },
    { "rate" : """14.99""" },
    { "rate" : """8.34""" },
    { "rate" : """10""" },
    { "rate" : """6.99999""" },
    { "rate" : """9.99999""" },
    { "rate" : """14.89999""" },
    { "rate" : """8.33899""" },
    { "rate" : """14.45""" },
    { "rate" : """14""" },
    { "rate" : """14.5""" },
    { "rate" : """12""" },
    { "rate" : """1.38""" },
    { "rate" : """8.34""" },
    { "rate" : """8""" },
    { "rate" : """2.34""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """2.389""" },
    { "rate" : """2.39""" },
    { "rate" : """2.37""" },
    { "rate" : """8.33999""" },
    { "rate" : """9.9999""" },
    { "rate" : """9.88""" },
    { "rate" : """3""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """12.1""" },
    { "rate" : """9.9""" },
    { "rate" : """10""" },
    { "rate" : """10""" },
    { "rate" : """3""" },
    { "rate" : """4""" },
    { "rate" : """10""" },
    { "rate" : """3.9999""" },
    { "rate" : """29.37""" },
    { "rate" : """4.99""" },
    { "rate" : """1.98""" },
    { "rate" : """1.98999""" },
    { "rate" : """1.9999""" },
    { "rate" : """20""" },
    { "rate" : """1.97999""" },
    { "rate" : """1.97""" },
    { "rate" : """2""" },
    { "rate" : """1.98048""" },
    { "rate" : """4.33333""" },
    { "rate" : """29.37""" },
    { "rate" : """20""" },
    { "rate" : """1.98""" },
    { "rate" : """1.99""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """29""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """7""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """4.5""" },
    { "rate" : """1.99""" },
    { "rate" : """15""" },
    { "rate" : """5""" },
    { "rate" : """29.37""" },
    { "rate" : """9.999""" },
    { "rate" : """1.98""" },
    { "rate" : """4.999""" },
    { "rate" : """20""" },
    { "rate" : """6.99""" },
    { "rate" : """4.9""" },
    { "rate" : """19.7""" },
    { "rate" : """1.98""" },
    { "rate" : """3.9""" },
    { "rate" : """3.979""" },
    { "rate" : """3.9""" },
    { "rate" : """3.9""" },
    { "rate" : """3.899""" },
    { "rate" : """3""" },
    { "rate" : """3.5""" },
    { "rate" : """1.9""" },
    { "rate" : """3.9""" },
    { "rate" : """3""" },
    { "rate" : """29.37""" },
    { "rate" : """10""" },
    { "rate" : """2""" },
    { "rate" : """3.97896""" },
    { "rate" : """7""" },
    { "rate" : """4.89999""" },
    { "rate" : """6.99999""" },
    { "rate" : """6.88""" },
    { "rate" : """3.49999""" },
    { "rate" : """3.49998""" },
    { "rate" : """3.99""" },
    { "rate" : """3.91""" },
    { "rate" : """6.98""" },
    { "rate" : """3.88999""" },
    { "rate" : """6.9""" },
    { "rate" : """6.9""" },
    { "rate" : """3.98""" },
    { "rate" : """3.5""" },
    { "rate" : """4.5""" },
    { "rate" : """3.5""" },
    { "rate" : """4.7""" },
    { "rate" : """6.99998""" },
    { "rate" : """6.5""" },
    { "rate" : """8.34""" },
    { "rate" : """6.99999""" },
    { "rate" : """6.8""" },
    { "rate" : """4.8""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """4.98999""" },
    { "rate" : """7""" },
    { "rate" : """8.34""" },
    { "rate" : """8.34""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """7""" },
    { "rate" : """8.34""" },
    { "rate" : """8.34""" },
    { "rate" : """5""" },
    { "rate" : """0.36999""" },
    { "rate" : """0.38""" },
    { "rate" : """18.31""" },
    { "rate" : """7""" },
    { "rate" : """0.37""" },
    { "rate" : """16""" },
    { "rate" : """10""" },
    { "rate" : """15.9""" },
    { "rate" : """6.9999""" },
    { "rate" : """14.99999""" },
    { "rate" : """8.34""" },
    { "rate" : """15""" },
    { "rate" : """3.9""" },
    { "rate" : """3.88""" },
    { "rate" : """3.85""" },
    { "rate" : """18.31""" },
    { "rate" : """12.88""" },
    { "rate" : """18.31""" },
    { "rate" : """8.34""" },
    { "rate" : """14""" },
    { "rate" : """8.34""" },
    { "rate" : """18.3""" },
    { "rate" : """6.99""" },
    { "rate" : """17""" },
    { "rate" : """8.34""" },
    { "rate" : """6.9""" },
    { "rate" : """23.35329""" },
    { "rate" : """5""" },
    { "rate" : """6.99999""" },
    { "rate" : """28.34""" },
    { "rate" : """6.9""" },
    { "rate" : """8.2""" },
    { "rate" : """8.34""" },
    { "rate" : """8.34""" },
    { "rate" : """7""" },
    { "rate" : """8.33""" },
    { "rate" : """8""" },
    { "rate" : """8.34""" },
    { "rate" : """7""" },
    { "rate" : """8""" },
    { "rate" : """8""" },
    { "rate" : """7.99999""" },
    { "rate" : """107.4""" },
    { "rate" : """99""" },
    { "rate" : """1.99999""" },
    { "rate" : """2""" },
    { "rate" : """1.337""" },
    { "rate" : """2.98""" },
    { "rate" : """1.99999""" },
    { "rate" : """0.01""" },
    { "rate" : """18""" },
    { "rate" : """18.31""" },
    { "rate" : """100""" },
    { "rate" : """18.31""" },
    { "rate" : """8.34""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """14.99999""" },
    { "rate" : """19""" },
    { "rate" : """10""" },
    { "rate" : """7""" },
    { "rate" : """20""" },
    { "rate" : """105""" },
    { "rate" : """50""" },
    { "rate" : """8.34""" },
    { "rate" : """107.4""" },
    { "rate" : """8.34""" },
    { "rate" : """107.4""" },
    { "rate" : """100.4""" },
    { "rate" : """8.33""" },
    { "rate" : """10""" },
    { "rate" : """8.34""" },
    { "rate" : """17.5""" },
    { "rate" : """8.3""" },
    { "rate" : """0.6""" },
    { "rate" : """1""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9""" },
    { "rate" : """0.95""" },
    { "rate" : """1""" },
    { "rate" : """0.89""" },
    { "rate" : """0.99998""" },
    { "rate" : """0.9""" },
    { "rate" : """0.89998""" },
    { "rate" : """1""" },
    { "rate" : """1""" },
    { "rate" : """0.99899""" },
    { "rate" : """0.89997""" },
    { "rate" : """0.99""" },
    { "rate" : """1""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.9999""" },
    { "rate" : """15""" },
    { "rate" : """14.98""" },
    { "rate" : """0.75""" },
    { "rate" : """0.999""" },
    { "rate" : """0.9989""" },
    { "rate" : """0.9999""" },
    { "rate" : """0.98765""" },
    { "rate" : """0.99""" },
    { "rate" : """15""" },
    { "rate" : """0.987""" },
    { "rate" : """14.99998""" },
    { "rate" : """0.99999""" },
    { "rate" : """16""" },
    { "rate" : """0.99995""" },
    { "rate" : """15""" },
    { "rate" : """13.99""" },
    { "rate" : """14.8""" },
    { "rate" : """14.7""" },
    { "rate" : """14.8""" },
    { "rate" : """14.8""" },
    { "rate" : """14""" },
    { "rate" : """11""" },
    { "rate" : """15""" },
    { "rate" : """14""" },
    { "rate" : """14.8""" },
    { "rate" : """14.8""" },
    { "rate" : """14.6""" },
    { "rate" : """14.8""" },
    { "rate" : """13.5""" },
    { "rate" : """9.8""" },
    { "rate" : """40""" },
    { "rate" : """14.75""" },
    { "rate" : """15""" },
    { "rate" : """15""" },
    { "rate" : """1""" },
    { "rate" : """0.9""" },
    { "rate" : """0.9""" },
    { "rate" : """1""" },
    { "rate" : """0.89999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99999""" },
    { "rate" : """1.99""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.7""" },
    { "rate" : """1""" },
    { "rate" : """1.9999""" },
    { "rate" : """1.9999""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """2""" },
    { "rate" : """1.99998""" },
    { "rate" : """1.75""" },
    { "rate" : """1.93""" },
    { "rate" : """1.99998""" },
    { "rate" : """1.5""" },
    { "rate" : """1.9""" },
    { "rate" : """1.99""" },
    { "rate" : """1""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """25.99""" },
    { "rate" : """25.99""" },
    { "rate" : """25.99""" },
    { "rate" : """3""" },
    { "rate" : """14""" },
    { "rate" : """3""" },
    { "rate" : """3""" },
    { "rate" : """1""" },
]
# Out:
# [{'borrower': '2110', 'count': '190'},
#  {'borrower': '1012', 'count': '143'},
#  {'borrower': '1995', 'count': '126'},
#  {'borrower': '77', 'count': '103'},
#  {'borrower': '2312', 'count': '95'},
#  {'borrower': '991', 'count': '92'},
#  {'borrower': '4630', 'count': '84'},
#  {'borrower': '6670', 'count': '83'},
#  {'borrower': '3188', 'count': '81'},
#  {'borrower': '1008', 'count': '80'},
#  {'borrower': '8798', 'count': '76'},
#  {'borrower': '532', 'count': '75'},
#  {'borrower': '2857', 'count': '74'},
#  {'borrower': '707', 'count': '73'},
#  {'borrower': '4533', 'count': '70'},
#  {'borrower': '3340', 'count': '66'},
#  {'borrower': '1176', 'count': '65'},
#  {'borrower': '1183', 'count': '65'},
#  {'borrower': '4161', 'count': '64'},
#  {'borrower': '585', 'count': '63'},
#  {'borrower': '5333', 'count': '63'},
#  {'borrower': '8436', 'count': '63'},
#  {'borrower': '2507', 'count': '60'},
#  {'borrower': '1960', 'count': '59'},
#  {'borrower': '1002', 'count': '58'},
# ...

# %%
pd.Serpd.Seriesriesiesiess
