# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
raw_data = [
    { "id" : """14""", "rate" : """10""" },
    { "id" : """63""", "rate" : """10""" },
    { "id" : """216""", "rate" : """15""" },
    { "id" : """324""", "rate" : """15.3202134756504""" },
    { "id" : """326""", "rate" : """6.66666666666667""" },
    { "id" : """330""", "rate" : """15""" },
    { "id" : """338""", "rate" : """12.375""" },
    { "id" : """343""", "rate" : """23.465""" },
    { "id" : """345""", "rate" : """10""" },
    { "id" : """360""", "rate" : """10""" },
    { "id" : """365""", "rate" : """9.76439790575916""" },
    { "id" : """366""", "rate" : """10""" },
    { "id" : """372""", "rate" : """15""" },
    { "id" : """377""", "rate" : """10""" },
    { "id" : """380""", "rate" : """10""" },
    { "id" : """396""", "rate" : """10""" },
    { "id" : """398""", "rate" : """10""" },
    { "id" : """745""", "rate" : """10.1375""" },
    { "id" : """747""", "rate" : """9.75147177142857""" },
    { "id" : """752""", "rate" : """10""" },
    { "id" : """769""", "rate" : """1e-05""" },
    { "id" : """776""", "rate" : """10""" },
    { "id" : """777""", "rate" : """9.95""" },
    { "id" : """780""", "rate" : """5.904929848""" },
    { "id" : """792""", "rate" : """9.66371435714286""" },
    { "id" : """802""", "rate" : """9.399930776""" },
    { "id" : """815""", "rate" : """4.07499983672535""" },
    { "id" : """818""", "rate" : """6""" },
    { "id" : """837""", "rate" : """3.9792""" },
    { "id" : """863""", "rate" : """9.46266666666667""" },
    { "id" : """877""", "rate" : """8.91974666666667""" },
    { "id" : """880""", "rate" : """8""" },
    { "id" : """885""", "rate" : """10.2325""" },
    { "id" : """889""", "rate" : """6.78941052631579""" },
    { "id" : """892""", "rate" : """7.95115714285714""" },
    { "id" : """898""", "rate" : """10.9374""" },
    { "id" : """900""", "rate" : """5.1532""" },
    { "id" : """911""", "rate" : """10.80408""" },
    { "id" : """931""", "rate" : """10.9209677419355""" },
    { "id" : """938""", "rate" : """100""" },
    { "id" : """939""", "rate" : """6.892""" },
    { "id" : """943""", "rate" : """10""" },
    { "id" : """950""", "rate" : """4""" },
    { "id" : """951""", "rate" : """8.706""" },
    { "id" : """952""", "rate" : """1""" },
    { "id" : """959""", "rate" : """9.29956666666667""" },
    { "id" : """962""", "rate" : """5.63""" },
    { "id" : """981""", "rate" : """4""" },
    { "id" : """998""", "rate" : """4.9194""" },
    { "id" : """999""", "rate" : """3.99968""" },
    { "id" : """1003""", "rate" : """6.41725""" },
    { "id" : """1015""", "rate" : """10.43""" },
    { "id" : """1017""", "rate" : """10""" },
    { "id" : """1021""", "rate" : """3.06451612903226""" },
    { "id" : """1026""", "rate" : """8.603385393""" },
    { "id" : """1028""", "rate" : """1.95604""" },
    { "id" : """1045""", "rate" : """10.034125""" },
    { "id" : """1046""", "rate" : """11.8455687114""" },
    { "id" : """1052""", "rate" : """6.55893333333333""" },
    { "id" : """1062""", "rate" : """9.055999053""" },
    { "id" : """1063""", "rate" : """11.09""" },
    { "id" : """1064""", "rate" : """2.9778""" },
    { "id" : """1067""", "rate" : """1.06546179391841""" },
    { "id" : """1075""", "rate" : """9.08647411060232""" },
    { "id" : """1079""", "rate" : """1.95""" },
    { "id" : """1092""", "rate" : """0""" },
    { "id" : """1110""", "rate" : """6.82""" },
    { "id" : """1120""", "rate" : """9.394001""" },
    { "id" : """1124""", "rate" : """3.99996341463415""" },
    { "id" : """1131""", "rate" : """10.3309975""" },
    { "id" : """1135""", "rate" : """13.615""" },
    { "id" : """1138""", "rate" : """7.3658""" },
    { "id" : """1144""", "rate" : """5.59999992""" },
    { "id" : """1154""", "rate" : """11.9753""" },
    { "id" : """1159""", "rate" : """8""" },
    { "id" : """1165""", "rate" : """7.9094""" },
    { "id" : """1166""", "rate" : """4.98331933333333""" },
    { "id" : """1169""", "rate" : """3.999367368""" },
    { "id" : """1178""", "rate" : """7.753258""" },
    { "id" : """1181""", "rate" : """11.61848""" },
    { "id" : """1183""", "rate" : """6""" },
    { "id" : """1202""", "rate" : """9.9989983403""" },
    { "id" : """1204""", "rate" : """5.866""" },
    { "id" : """1207""", "rate" : """9.66636""" },
    { "id" : """1212""", "rate" : """7""" },
    { "id" : """1215""", "rate" : """3""" },
    { "id" : """1223""", "rate" : """27.738""" },
    { "id" : """1231""", "rate" : """4.7989999306""" },
    { "id" : """1240""", "rate" : """3.94105495""" },
    { "id" : """1242""", "rate" : """19.0125""" },
    { "id" : """1258""", "rate" : """2.76960807838432""" },
    { "id" : """1261""", "rate" : """5.99375759066667""" },
    { "id" : """1283""", "rate" : """3.49583""" },
    { "id" : """1306""", "rate" : """6.999996""" },
    { "id" : """1310""", "rate" : """2.99995555555556""" },
    { "id" : """1314""", "rate" : """9.68921""" },
    { "id" : """1321""", "rate" : """3.42555392166667""" },
    { "id" : """1327""", "rate" : """8.153399552""" },
    { "id" : """1335""", "rate" : """9.97""" },
    { "id" : """1339""", "rate" : """16.22""" },
    { "id" : """1350""", "rate" : """5.83333333333333""" },
    { "id" : """1365""", "rate" : """9.9999""" },
    { "id" : """1368""", "rate" : """2.39417218181818""" },
    { "id" : """1432""", "rate" : """3""" },
    { "id" : """1442""", "rate" : """10.1798622727273""" },
    { "id" : """1447""", "rate" : """9.63352333333333""" },
    { "id" : """1461""", "rate" : """5.305267""" },
    { "id" : """1472""", "rate" : """4.46441578075""" },
    { "id" : """1476""", "rate" : """4.421334""" },
    { "id" : """1478""", "rate" : """6.3012""" },
    { "id" : """1502""", "rate" : """1""" },
    { "id" : """1528""", "rate" : """2""" },
    { "id" : """1544""", "rate" : """4.0175""" },
    { "id" : """1570""", "rate" : """3""" },
    { "id" : """1595""", "rate" : """2.53247188202949""" },
    { "id" : """1602""", "rate" : """7""" },
    { "id" : """1604""", "rate" : """2""" },
    { "id" : """1614""", "rate" : """1.9521495""" },
    { "id" : """9022""", "rate" : """7.538101374561""" },
    { "id" : """9032""", "rate" : """4.99851879266667""" },
    { "id" : """9033""", "rate" : """14.5872377055""" },
    { "id" : """9034""", "rate" : """7.5748714276""" },
    { "id" : """9036""", "rate" : """5.886890408""" },
    { "id" : """9039""", "rate" : """8.05547519933334""" },
    { "id" : """9053""", "rate" : """2.66675719285""" },
    { "id" : """9055""", "rate" : """9.99999875""" },
    { "id" : """9065""", "rate" : """12.2699""" },
    { "id" : """9082""", "rate" : """5.54463134456155""" },
    { "id" : """9103""", "rate" : """13.92447477""" },
    { "id" : """9106""", "rate" : """6.204465376""" },
    { "id" : """9120""", "rate" : """1""" },
    { "id" : """9128""", "rate" : """1""" },
    { "id" : """9130""", "rate" : """9.24523683""" },
    { "id" : """9138""", "rate" : """3.4232""" },
    { "id" : """9140""", "rate" : """9.9102981925""" },
    { "id" : """9167""", "rate" : """13.085395""" },
    { "id" : """9188""", "rate" : """9.86696855""" },
    { "id" : """9193""", "rate" : """7.98349925""" },
    { "id" : """9211""", "rate" : """4.98231551666667""" },
    { "id" : """9214""", "rate" : """4.969226092""" },
    { "id" : """9225""", "rate" : """5.73957139396109""" },
    { "id" : """9233""", "rate" : """5.4285183""" },
    { "id" : """9245""", "rate" : """11.303327975""" },
    { "id" : """9255""", "rate" : """2.04""" },
    { "id" : """9271""", "rate" : """8.155188""" },
    { "id" : """9273""", "rate" : """10""" },
    { "id" : """9287""", "rate" : """3.4949032""" },
    { "id" : """9307""", "rate" : """5.43494907119599""" },
    { "id" : """9313""", "rate" : """11.41945353068""" },
    { "id" : """9327""", "rate" : """17""" },
    { "id" : """9341""", "rate" : """3.99978087142857""" },
    { "id" : """9345""", "rate" : """8.81435231""" },
    { "id" : """9361""", "rate" : """5.9553933""" },
    { "id" : """9363""", "rate" : """6.86244822333333""" },
    { "id" : """9364""", "rate" : """5.79439549""" },
    { "id" : """9378""", "rate" : """8.48732164866667""" },
    { "id" : """9389""", "rate" : """9.99771993999672""" },
    { "id" : """9405""", "rate" : """5.5024433476""" },
    { "id" : """9415""", "rate" : """12.289535298""" },
    { "id" : """9416""", "rate" : """6.89398588""" },
    { "id" : """9426""", "rate" : """17""" },
    { "id" : """9435""", "rate" : """8.949055945""" },
    { "id" : """9437""", "rate" : """10.7696288773333""" },
    { "id" : """9440""", "rate" : """4.997579998""" },
    { "id" : """9450""", "rate" : """12.0418333""" },
    { "id" : """9455""", "rate" : """17""" },
    { "id" : """9459""", "rate" : """14.95215""" },
    { "id" : """9466""", "rate" : """6.075849832""" },
    { "id" : """9477""", "rate" : """4.29200287""" },
    { "id" : """9478""", "rate" : """5.068736281""" },
    { "id" : """9500""", "rate" : """5.788851188""" },
    { "id" : """9503""", "rate" : """11.63576""" },
    { "id" : """9515""", "rate" : """7.999679975""" },
    { "id" : """9521""", "rate" : """8.89976""" },
    { "id" : """9546""", "rate" : """9.99663333333333""" },
    { "id" : """9547""", "rate" : """4.988775""" },
    { "id" : """9553""", "rate" : """5.35688039742068""" },
    { "id" : """9555""", "rate" : """6.58785825""" },
    { "id" : """9556""", "rate" : """7.85091558121429""" },
    { "id" : """9566""", "rate" : """6.822999""" },
    { "id" : """9568""", "rate" : """5.26817""" },
    { "id" : """9579""", "rate" : """14.9675428445714""" },
    { "id" : """9590""", "rate" : """3""" },
    { "id" : """9604""", "rate" : """10""" },
    { "id" : """9609""", "rate" : """14.9093744686667""" },
    { "id" : """9614""", "rate" : """8.12335033""" },
    { "id" : """9627""", "rate" : """9.9594935625""" },
    { "id" : """9630""", "rate" : """14.183213932""" },
    { "id" : """9633""", "rate" : """3.25689753333333""" },
    { "id" : """9640""", "rate" : """4.4979821172""" },
    { "id" : """9673""", "rate" : """1""" },
    { "id" : """9716""", "rate" : """10.1174307393333""" },
    { "id" : """9749""", "rate" : """6.4745""" },
    { "id" : """9752""", "rate" : """7.8806""" },
    { "id" : """9777""", "rate" : """14.810625""" },
    { "id" : """9778""", "rate" : """4.77024030354095""" },
    { "id" : """9792""", "rate" : """3.99899""" },
    { "id" : """9829""", "rate" : """7.24479166666667""" },
    { "id" : """9845""", "rate" : """2.83357533857143""" },
    { "id" : """9846""", "rate" : """8.67591613888889""" },
    { "id" : """9855""", "rate" : """14.8477239499167""" },
    { "id" : """9856""", "rate" : """9.01636355166667""" },
    { "id" : """9865""", "rate" : """19""" },
    { "id" : """9866""", "rate" : """19""" },
    { "id" : """9883""", "rate" : """5.628""" },
    { "id" : """9887""", "rate" : """1.990427383""" },
    { "id" : """9913""", "rate" : """2.68364485714286""" },
    { "id" : """9927""", "rate" : """3.88892089826358""" },
    { "id" : """9935""", "rate" : """7.70199666666667""" },
    { "id" : """9950""", "rate" : """14.983749995""" },
    { "id" : """9951""", "rate" : """4.8059812932""" },
    { "id" : """9971""", "rate" : """11.1197448099231""" },
    { "id" : """9987""", "rate" : """9.90439187190715""" },
    { "id" : """9989""", "rate" : """5.64121226688913""" },
    { "id" : """9999""", "rate" : """11.521117""" },
    { "id" : """10010""", "rate" : """11.4117629083333""" },
    { "id" : """10025""", "rate" : """7.2175008""" },
    { "id" : """10028""", "rate" : """8""" },
    { "id" : """10040""", "rate" : """6.962836624""" },
    { "id" : """10047""", "rate" : """8.2843062155""" },
    { "id" : """10087""", "rate" : """14.67163""" },
    { "id" : """10108""", "rate" : """7.55118928571429""" },
    { "id" : """10111""", "rate" : """20""" },
    { "id" : """10112""", "rate" : """4.004749905""" },
    { "id" : """10144""", "rate" : """5""" },
    { "id" : """10186""", "rate" : """9.75520630444444""" },
    { "id" : """10226""", "rate" : """7.6440891995""" },
    { "id" : """10231""", "rate" : """13.2456358993333""" },
    { "id" : """10255""", "rate" : """6.9506496475""" },
    { "id" : """10259""", "rate" : """2.98751105""" },
    { "id" : """10282""", "rate" : """8.174549849""" },
    { "id" : """10302""", "rate" : """9.5655""" },
    { "id" : """10321""", "rate" : """8.208617""" },
    { "id" : """10336""", "rate" : """9.26654""" },
    { "id" : """10342""", "rate" : """11.4993482895833""" },
    { "id" : """10345""", "rate" : """9.730267441""" },
    { "id" : """10356""", "rate" : """7.39602299133333""" },
    { "id" : """10363""", "rate" : """6.98180432666667""" },
    { "id" : """10381""", "rate" : """6.767364509""" },
    { "id" : """10395""", "rate" : """3.91916975""" },
    { "id" : """10414""", "rate" : """3.20908694485515""" },
    { "id" : """10419""", "rate" : """8.6424""" },
    { "id" : """10422""", "rate" : """0.01""" },
    { "id" : """10431""", "rate" : """10.6153525414167""" },
    { "id" : """10436""", "rate" : """6.8446609375""" },
    { "id" : """10441""", "rate" : """9.86238538538461""" },
    { "id" : """10443""", "rate" : """7.867950768""" },
    { "id" : """10445""", "rate" : """9.813762625""" },
    { "id" : """10451""", "rate" : """17.8032461814""" },
    { "id" : """10452""", "rate" : """20""" },
    { "id" : """10454""", "rate" : """4.96574605766667""" },
    { "id" : """10456""", "rate" : """9.7064407""" },
    { "id" : """10459""", "rate" : """8.3350980148""" },
    { "id" : """10478""", "rate" : """4.008899995""" },
    { "id" : """10495""", "rate" : """14.11036575""" },
    { "id" : """10510""", "rate" : """9.48505555500001""" },
    { "id" : """10533""", "rate" : """4.9995808664""" },
    { "id" : """10534""", "rate" : """4.89017483333333""" },
    { "id" : """10560""", "rate" : """10.7128923997273""" },
    { "id" : """10573""", "rate" : """4.929673565""" },
    { "id" : """10581""", "rate" : """9.00999992""" },
    { "id" : """10590""", "rate" : """4.9124719""" },
    { "id" : """10591""", "rate" : """9.500009""" },
    { "id" : """10610""", "rate" : """4.9791806""" },
    { "id" : """10617""", "rate" : """6.9019532804""" },
    { "id" : """10631""", "rate" : """2.955247475""" },
    { "id" : """10638""", "rate" : """3.269095806""" },
    { "id" : """10646""", "rate" : """7.46572""" },
    { "id" : """10652""", "rate" : """8.016813296""" },
    { "id" : """10653""", "rate" : """3.3346903""" },
    { "id" : """10654""", "rate" : """4.965989466""" },
    { "id" : """10656""", "rate" : """10.23475""" },
    { "id" : """10659""", "rate" : """11.0706466333333""" },
    { "id" : """10660""", "rate" : """6.6509195""" },
    { "id" : """10681""", "rate" : """13.6828658125""" },
    { "id" : """10687""", "rate" : """7.0502189""" },
    { "id" : """10710""", "rate" : """5.23314946753529""" },
    { "id" : """10726""", "rate" : """15""" },
    { "id" : """10728""", "rate" : """7.813644775""" },
    { "id" : """10736""", "rate" : """33.1806652108181""" },
    { "id" : """10740""", "rate" : """11.098475""" },
    { "id" : """10744""", "rate" : """15.40826168""" },
    { "id" : """10762""", "rate" : """9.97022068429915""" },
    { "id" : """10776""", "rate" : """13.5467""" },
    { "id" : """10783""", "rate" : """6.76974""" },
    { "id" : """10784""", "rate" : """4.40729759173333""" },
    { "id" : """10804""", "rate" : """4.56830081333333""" },
    { "id" : """10847""", "rate" : """14.7079226642""" },
    { "id" : """10853""", "rate" : """5.564809""" },
    { "id" : """10855""", "rate" : """4.8002085""" },
    { "id" : """10862""", "rate" : """9.96197533333333""" },
    { "id" : """10870""", "rate" : """7.905578348375""" },
    { "id" : """10877""", "rate" : """9.13264117647059""" },
    { "id" : """10895""", "rate" : """9.999849875""" },
    { "id" : """10896""", "rate" : """17.1825436640909""" },
    { "id" : """10901""", "rate" : """4.68386111111111""" },
    { "id" : """10919""", "rate" : """2.4794386598""" },
    { "id" : """10921""", "rate" : """8""" },
    { "id" : """10926""", "rate" : """4.916495""" },
    { "id" : """10929""", "rate" : """19.7470443333333""" },
    { "id" : """10934""", "rate" : """9.89057148604269""" },
    { "id" : """10936""", "rate" : """10.8728818461538""" },
    { "id" : """10946""", "rate" : """2.9757977""" },
    { "id" : """10955""", "rate" : """11.66499866""" },
    { "id" : """10962""", "rate" : """5.4645875""" },
    { "id" : """10971""", "rate" : """9.98566666666667""" },
    { "id" : """10978""", "rate" : """6.16807352877182""" },
    { "id" : """11008""", "rate" : """1.98636352272727""" },
    { "id" : """11021""", "rate" : """9.97333438418182""" },
    { "id" : """11024""", "rate" : """10.0049""" },
    { "id" : """11036""", "rate" : """3.03639397733333""" },
    { "id" : """11040""", "rate" : """2.137799""" },
    { "id" : """11056""", "rate" : """4.0550754117""" },
    { "id" : """11066""", "rate" : """7.97602174""" },
    { "id" : """11077""", "rate" : """10.35253008""" },
    { "id" : """11081""", "rate" : """2.34543009557143""" },
    { "id" : """11095""", "rate" : """7.890502984""" },
    { "id" : """11098""", "rate" : """7.92898558975""" },
    { "id" : """11132""", "rate" : """4.998748""" },
    { "id" : """11146""", "rate" : """5.15678364515762""" },
    { "id" : """11161""", "rate" : """11.6625785446""" },
    { "id" : """11171""", "rate" : """13.995154125""" },
    { "id" : """11176""", "rate" : """13.5219970493""" },
    { "id" : """11188""", "rate" : """2.99777662142857""" },
    { "id" : """11197""", "rate" : """7.99999864727273""" },
    { "id" : """11200""", "rate" : """5.1""" },
    { "id" : """11214""", "rate" : """0.1""" },
    { "id" : """11224""", "rate" : """10.0408346619394""" },
    { "id" : """11239""", "rate" : """8.94425382084993""" },
    { "id" : """11258""", "rate" : """14.999999375""" },
    { "id" : """11263""", "rate" : """4.9974342""" },
    { "id" : """11286""", "rate" : """9.99998714285715""" },
    { "id" : """11301""", "rate" : """8.43726092461539""" },
    { "id" : """11302""", "rate" : """8.04036302772727""" },
    { "id" : """11305""", "rate" : """5.067895998""" },
    { "id" : """11309""", "rate" : """6.70627158285714""" },
    { "id" : """11315""", "rate" : """12.569226675""" },
    { "id" : """11334""", "rate" : """7.891559586125""" },
    { "id" : """11343""", "rate" : """12.0489105416""" },
    { "id" : """11349""", "rate" : """4.47137856304867""" },
    { "id" : """11364""", "rate" : """4.499937345""" },
    { "id" : """11367""", "rate" : """4.62076015""" },
    { "id" : """11374""", "rate" : """7.33795948096886""" },
    { "id" : """11386""", "rate" : """4.83592498""" },
    { "id" : """11424""", "rate" : """4.7277974""" },
    { "id" : """11427""", "rate" : """9.859263585""" },
    { "id" : """11430""", "rate" : """0.1""" },
    { "id" : """11439""", "rate" : """9.31428571428571""" },
    { "id" : """11441""", "rate" : """19.9999625583336""" },
    { "id" : """11462""", "rate" : """5.9321996""" },
    { "id" : """11510""", "rate" : """0.1""" },
    { "id" : """11511""", "rate" : """1""" },
    { "id" : """11513""", "rate" : """20.242""" },
    { "id" : """11516""", "rate" : """7.942429168""" },
    { "id" : """11521""", "rate" : """7.4740633""" },
    { "id" : """11529""", "rate" : """7.26501771805436""" },
    { "id" : """11560""", "rate" : """8.22934201""" },
    { "id" : """11572""", "rate" : """9.9999875""" },
    { "id" : """11577""", "rate" : """7.74719975""" },
    { "id" : """11587""", "rate" : """6.83718327285922""" },
    { "id" : """11592""", "rate" : """4.99999496428571""" },
    { "id" : """11610""", "rate" : """6.613177975""" },
    { "id" : """11612""", "rate" : """14.93743941724""" },
    { "id" : """11621""", "rate" : """5.86046304286""" },
    { "id" : """11634""", "rate" : """13.8337362125""" },
    { "id" : """11637""", "rate" : """4.92138821""" },
    { "id" : """11643""", "rate" : """9.40283603""" },
    { "id" : """11657""", "rate" : """9.38321325""" },
    { "id" : """11664""", "rate" : """14.848489637""" },
    { "id" : """11666""", "rate" : """12.8409618828333""" },
    { "id" : """11680""", "rate" : """5.9999""" },
    { "id" : """11689""", "rate" : """6.94075845166667""" },
    { "id" : """11691""", "rate" : """11.2424819963636""" },
    { "id" : """11706""", "rate" : """14.488717162""" },
    { "id" : """11726""", "rate" : """5.1946685""" },
    { "id" : """11749""", "rate" : """8.97174179372283""" },
    { "id" : """11752""", "rate" : """4.086646006""" },
    { "id" : """11758""", "rate" : """13.5319389683684""" },
    { "id" : """11761""", "rate" : """13.1330067546667""" },
    { "id" : """11773""", "rate" : """4.4990625""" },
    { "id" : """11777""", "rate" : """9.43163935""" },
    { "id" : """11794""", "rate" : """11.7457473125""" },
    { "id" : """11805""", "rate" : """14""" },
    { "id" : """11817""", "rate" : """8.99999""" },
    { "id" : """11834""", "rate" : """9.965333""" },
    { "id" : """11862""", "rate" : """4.99996666666667""" },
    { "id" : """11868""", "rate" : """6.409319795""" },
    { "id" : """11879""", "rate" : """9.826663505""" },
    { "id" : """11904""", "rate" : """20""" },
    { "id" : """11908""", "rate" : """2.894986996""" },
    { "id" : """11912""", "rate" : """19.28784746""" },
    { "id" : """11930""", "rate" : """5.07858045""" },
    { "id" : """11933""", "rate" : """1.37935299841464""" },
    { "id" : """11952""", "rate" : """4.99999926470588""" },
    { "id" : """11973""", "rate" : """19.9141008450667""" },
    { "id" : """11975""", "rate" : """3""" },
    { "id" : """11976""", "rate" : """3.95179277870023""" },
    { "id" : """11985""", "rate" : """4.82952607913952""" },
    { "id" : """11987""", "rate" : """18.4553198595625""" },
    { "id" : """11990""", "rate" : """4.849895663""" },
    { "id" : """11993""", "rate" : """5.00676234666667""" },
    { "id" : """11994""", "rate" : """5""" },
    { "id" : """11999""", "rate" : """14.3206440205""" },
    { "id" : """12004""", "rate" : """9.6205922""" },
    { "id" : """12032""", "rate" : """9.820104618""" },
    { "id" : """12057""", "rate" : """3.0571522254""" },
    { "id" : """12061""", "rate" : """18.3555311936""" },
    { "id" : """12064""", "rate" : """14.7496712672857""" },
    { "id" : """12070""", "rate" : """14.569264375""" },
    { "id" : """12084""", "rate" : """10.499895""" },
    { "id" : """12110""", "rate" : """5.616953972""" },
    { "id" : """12112""", "rate" : """2.49975""" },
    { "id" : """12135""", "rate" : """2.72618""" },
    { "id" : """12149""", "rate" : """7.199589572""" },
    { "id" : """12151""", "rate" : """6.7081076699""" },
    { "id" : """12154""", "rate" : """11.383838""" },
    { "id" : """12162""", "rate" : """2.99874995""" },
    { "id" : """12191""", "rate" : """9.33248193829787""" },
    { "id" : """12192""", "rate" : """2.8039441575""" },
    { "id" : """12198""", "rate" : """15.0101189376667""" },
    { "id" : """12201""", "rate" : """0.01""" },
    { "id" : """12237""", "rate" : """2.76224428571429""" },
    { "id" : """12245""", "rate" : """6.83349515""" },
    { "id" : """12246""", "rate" : """4.428547475""" },
    { "id" : """12251""", "rate" : """0.9""" },
    { "id" : """12261""", "rate" : """9.00968592307692""" },
    { "id" : """12263""", "rate" : """4.97184570833333""" },
    { "id" : """12272""", "rate" : """9.96119689866667""" },
    { "id" : """12273""", "rate" : """2.8607364""" },
    { "id" : """12274""", "rate" : """9.03905986363637""" },
    { "id" : """12280""", "rate" : """7.895237195""" },
    { "id" : """12281""", "rate" : """7.97800275""" },
    { "id" : """12282""", "rate" : """2.99486867""" },
    { "id" : """12297""", "rate" : """10.0738821035""" },
    { "id" : """12308""", "rate" : """9.54054457142857""" },
    { "id" : """12320""", "rate" : """10.2861263636364""" },
    { "id" : """12331""", "rate" : """4.82779383333333""" },
    { "id" : """12368""", "rate" : """17.0421496""" },
    { "id" : """12369""", "rate" : """2.98575028""" },
    { "id" : """12373""", "rate" : """5.66757469582608""" },
    { "id" : """12374""", "rate" : """4.470019718625""" },
    { "id" : """12376""", "rate" : """7.54454785""" },
    { "id" : """12387""", "rate" : """5.99636212121212""" },
    { "id" : """12407""", "rate" : """11.3476474781515""" },
    { "id" : """12408""", "rate" : """7.85675950044444""" },
    { "id" : """12422""", "rate" : """10""" },
    { "id" : """12436""", "rate" : """7.5230335""" },
    { "id" : """12446""", "rate" : """5.99225""" },
    { "id" : """12464""", "rate" : """1.9999""" },
    { "id" : """12465""", "rate" : """1""" },
    { "id" : """12481""", "rate" : """14.7081215332727""" },
    { "id" : """12487""", "rate" : """7.684385""" },
    { "id" : """12488""", "rate" : """15""" },
    { "id" : """12489""", "rate" : """4.15765255433333""" },
    { "id" : """12494""", "rate" : """6.991149875""" },
    { "id" : """12500""", "rate" : """5.23328226666667""" },
    { "id" : """12505""", "rate" : """1.4""" },
    { "id" : """12513""", "rate" : """6.8443""" },
    { "id" : """12517""", "rate" : """11.95966""" },
    { "id" : """12518""", "rate" : """4.07568""" },
    { "id" : """12531""", "rate" : """9.62311095""" },
    { "id" : """12532""", "rate" : """6.3291665625""" },
    { "id" : """12535""", "rate" : """13.9649089852941""" },
    { "id" : """12537""", "rate" : """14.11709975""" },
    { "id" : """12548""", "rate" : """17.996468046""" },
    { "id" : """12551""", "rate" : """4.989682822""" },
    { "id" : """12559""", "rate" : """4.86758727968398""" },
    { "id" : """12565""", "rate" : """4.84804330046177""" },
    { "id" : """12574""", "rate" : """3.59288083733333""" },
    { "id" : """12576""", "rate" : """6.86797441233333""" },
    { "id" : """12595""", "rate" : """9.999995""" },
    { "id" : """12598""", "rate" : """14.958422975""" },
    { "id" : """12600""", "rate" : """9.67234776119403""" },
    { "id" : """12602""", "rate" : """4.9936007""" },
    { "id" : """12605""", "rate" : """9.76307702805263""" },
    { "id" : """12608""", "rate" : """9.9989995""" },
    { "id" : """12611""", "rate" : """1.999936875""" },
    { "id" : """12612""", "rate" : """7.99857302894737""" },
    { "id" : """12616""", "rate" : """7.58467594166667""" },
    { "id" : """12626""", "rate" : """5.84333333333333""" },
    { "id" : """12637""", "rate" : """16.5411108957143""" },
    { "id" : """12643""", "rate" : """6""" },
    { "id" : """12644""", "rate" : """12.4993958669355""" },
    { "id" : """12648""", "rate" : """5.490098655""" },
    { "id" : """12670""", "rate" : """9.375814""" },
    { "id" : """12681""", "rate" : """9.32998666666667""" },
    { "id" : """12688""", "rate" : """11.36212434375""" },
    { "id" : """12689""", "rate" : """8.797594083""" },
    { "id" : """12694""", "rate" : """7.87588131229292""" },
    { "id" : """12702""", "rate" : """14.95130985225""" },
    { "id" : """12714""", "rate" : """9""" },
    { "id" : """12722""", "rate" : """6.20299502857143""" },
    { "id" : """12733""", "rate" : """4.72948017915385""" },
    { "id" : """12751""", "rate" : """16.84052465""" },
    { "id" : """12753""", "rate" : """9.59229990384616""" },
    { "id" : """12754""", "rate" : """6.33751937333333""" },
    { "id" : """12759""", "rate" : """9.91725656142857""" },
    { "id" : """12774""", "rate" : """13.2268124110953""" },
    { "id" : """12778""", "rate" : """1.60454""" },
    { "id" : """12779""", "rate" : """10.0469817501765""" },
    { "id" : """12794""", "rate" : """12.8171642783333""" },
    { "id" : """12796""", "rate" : """8.9869574999""" },
    { "id" : """12800""", "rate" : """3.30454325""" },
    { "id" : """12803""", "rate" : """14.9954365175""" },
    { "id" : """12808""", "rate" : """9.9999999744898""" },
    { "id" : """12816""", "rate" : """1.79905336666667""" },
    { "id" : """12823""", "rate" : """5.487749875""" },
    { "id" : """12828""", "rate" : """9.995""" },
    { "id" : """12830""", "rate" : """21.96221""" },
    { "id" : """12840""", "rate" : """6.99288888888889""" },
    { "id" : """12876""", "rate" : """14.7219511142857""" },
    { "id" : """12879""", "rate" : """8.364135175""" },
    { "id" : """12880""", "rate" : """6.0012""" },
    { "id" : """12881""", "rate" : """11.539339375""" },
    { "id" : """12884""", "rate" : """15.674483625""" },
    { "id" : """12896""", "rate" : """8.8050369875""" },
    { "id" : """12903""", "rate" : """4.99948412698413""" },
    { "id" : """12908""", "rate" : """5.53667460648""" },
    { "id" : """12923""", "rate" : """16.7930918559545""" },
    { "id" : """12930""", "rate" : """1""" },
    { "id" : """12934""", "rate" : """24.1746877772""" },
    { "id" : """12938""", "rate" : """6.9944981""" },
    { "id" : """12955""", "rate" : """15.8316309112426""" },
    { "id" : """12956""", "rate" : """5.0445""" },
    { "id" : """12959""", "rate" : """5.275525221""" },
    { "id" : """12983""", "rate" : """14.9997237333333""" },
    { "id" : """12994""", "rate" : """5.870779849""" },
    { "id" : """12998""", "rate" : """17.9985538774667""" },
    { "id" : """13003""", "rate" : """7.701820667""" },
    { "id" : """13027""", "rate" : """4.92154934958184""" },
    { "id" : """13031""", "rate" : """4.886970726""" },
    { "id" : """13041""", "rate" : """1.997976""" },
    { "id" : """13063""", "rate" : """1.49674576480842""" },
    { "id" : """13064""", "rate" : """5.564758125""" },
    { "id" : """13069""", "rate" : """7.592561596""" },
    { "id" : """13085""", "rate" : """17.4236027857143""" },
    { "id" : """13086""", "rate" : """11.7797825133333""" },
    { "id" : """13094""", "rate" : """8.71534773604651""" },
    { "id" : """13095""", "rate" : """4.665051915""" },
    { "id" : """13153""", "rate" : """1""" },
    { "id" : """13172""", "rate" : """1.2245""" },
    { "id" : """13186""", "rate" : """1""" },
    { "id" : """13188""", "rate" : """5.91222222222222""" },
    { "id" : """13194""", "rate" : """5.29648701785714""" },
    { "id" : """13201""", "rate" : """13.017698""" },
    { "id" : """13219""", "rate" : """8.7114951054""" },
    { "id" : """13235""", "rate" : """11.6696175142857""" },
    { "id" : """13238""", "rate" : """24.9330425""" },
    { "id" : """13242""", "rate" : """10""" },
    { "id" : """13249""", "rate" : """9.488297484""" },
    { "id" : """13254""", "rate" : """11.1031566666667""" },
    { "id" : """13300""", "rate" : """5.9336735845""" },
    { "id" : """13310""", "rate" : """14.794474""" },
    { "id" : """13320""", "rate" : """10.3778076923077""" },
    { "id" : """13341""", "rate" : """0.1""" },
    { "id" : """13346""", "rate" : """9.5625376""" },
    { "id" : """13361""", "rate" : """23.58""" },
    { "id" : """13369""", "rate" : """8.70446173047619""" },
    { "id" : """13377""", "rate" : """16.17""" },
    { "id" : """13409""", "rate" : """13.11""" },
    { "id" : """13411""", "rate" : """11.4127769710833""" },
    { "id" : """13417""", "rate" : """10.73""" },
    { "id" : """13422""", "rate" : """23.58""" },
    { "id" : """13430""", "rate" : """10.044103""" },
    { "id" : """13432""", "rate" : """18.98243835""" },
    { "id" : """13435""", "rate" : """14.7153197926667""" },
    { "id" : """13493""", "rate" : """23.9988""" },
    { "id" : """13520""", "rate" : """8.94601877""" },
    { "id" : """13523""", "rate" : """16.17""" },
    { "id" : """13549""", "rate" : """16.17""" },
    { "id" : """13553""", "rate" : """17.48""" },
    { "id" : """13564""", "rate" : """9.370848""" },
    { "id" : """13573""", "rate" : """9.2955469375""" },
    { "id" : """13575""", "rate" : """2.99906547169811""" },
    { "id" : """13585""", "rate" : """16.0859446666667""" },
    { "id" : """13586""", "rate" : """9.95795217307693""" },
    { "id" : """13604""", "rate" : """9.2174344125""" },
    { "id" : """13617""", "rate" : """17.292218975""" },
    { "id" : """13619""", "rate" : """5.83758055728943""" },
    { "id" : """13622""", "rate" : """17.055409047""" },
    { "id" : """13626""", "rate" : """17.81113545""" },
    { "id" : """13634""", "rate" : """9.82526315789474""" },
    { "id" : """13639""", "rate" : """7.9901202""" },
    { "id" : """13685""", "rate" : """8.89011344327836""" },
    { "id" : """13690""", "rate" : """13.0455533333333""" },
    { "id" : """13692""", "rate" : """7.71157123398165""" },
    { "id" : """13696""", "rate" : """19.719068""" },
    { "id" : """13724""", "rate" : """10.077332""" },
    { "id" : """13737""", "rate" : """15.11801""" },
    { "id" : """13739""", "rate" : """12.3726146388889""" },
    { "id" : """13750""", "rate" : """4.271579""" },
    { "id" : """13755""", "rate" : """15.1981282950741""" },
    { "id" : """13761""", "rate" : """23.06402""" },
    { "id" : """13781""", "rate" : """11.7919997""" },
    { "id" : """13795""", "rate" : """14.2077115882353""" },
    { "id" : """13802""", "rate" : """13.6689665170667""" },
    { "id" : """13810""", "rate" : """14.845780149""" },
    { "id" : """13811""", "rate" : """4.08299""" },
    { "id" : """13817""", "rate" : """12.57579558""" },
    { "id" : """13836""", "rate" : """11.938947038""" },
    { "id" : """13849""", "rate" : """5.3""" },
    { "id" : """13871""", "rate" : """3.1900201""" },
    { "id" : """13888""", "rate" : """14.2301257142857""" },
    { "id" : """13902""", "rate" : """5.90957256666667""" },
    { "id" : """13904""", "rate" : """5.96184489628364""" },
    { "id" : """13905""", "rate" : """11.4198164583333""" },
    { "id" : """13924""", "rate" : """1.99999257692308""" },
    { "id" : """13958""", "rate" : """16.40949464225""" },
    { "id" : """13959""", "rate" : """20.78252""" },
    { "id" : """13991""", "rate" : """7.74562095454546""" },
    { "id" : """13995""", "rate" : """15.5347894575""" },
    { "id" : """13996""", "rate" : """11.9262240285714""" },
    { "id" : """14028""", "rate" : """9.97399993193334""" },
    { "id" : """14030""", "rate" : """14.998""" },
    { "id" : """14048""", "rate" : """14.3658676613""" },
    { "id" : """14049""", "rate" : """12.439384625""" },
    { "id" : """14066""", "rate" : """14.7658831441333""" },
    { "id" : """14081""", "rate" : """16.1570667464""" },
    { "id" : """14113""", "rate" : """15.591801064""" },
    { "id" : """14120""", "rate" : """11.9688931209955""" },
    { "id" : """14128""", "rate" : """10""" },
    { "id" : """14134""", "rate" : """8.715903""" },
    { "id" : """14140""", "rate" : """10.006""" },
    { "id" : """14146""", "rate" : """3.0406704""" },
    { "id" : """14156""", "rate" : """5.96063125""" },
    { "id" : """14159""", "rate" : """6.30895293333334""" },
    { "id" : """14184""", "rate" : """7.9500485""" },
    { "id" : """14187""", "rate" : """13.124088""" },
    { "id" : """14207""", "rate" : """7.43316903749999""" },
    { "id" : """14216""", "rate" : """9.28147065""" },
    { "id" : """14218""", "rate" : """7.41848375""" },
    { "id" : """14226""", "rate" : """4.9986""" },
    { "id" : """14230""", "rate" : """9.07079666666667""" },
    { "id" : """14239""", "rate" : """12.2737325866667""" },
    { "id" : """14244""", "rate" : """13.1048136""" },
    { "id" : """14262""", "rate" : """7.4816536""" },
    { "id" : """14270""", "rate" : """12.5953128571429""" },
    { "id" : """14293""", "rate" : """12.4559294117647""" },
    { "id" : """14302""", "rate" : """7.302728""" },
    { "id" : """14304""", "rate" : """7.51348241912427""" },
    { "id" : """14353""", "rate" : """8.27248304055695""" },
    { "id" : """14363""", "rate" : """7.2132259""" },
    { "id" : """14364""", "rate" : """12.4556666666667""" },
    { "id" : """14371""", "rate" : """3.99972814866667""" },
    { "id" : """14378""", "rate" : """4.949976""" },
    { "id" : """14382""", "rate" : """6.99922047956097""" },
    { "id" : """14393""", "rate" : """18.2731891414141""" },
    { "id" : """14396""", "rate" : """7.7202""" },
    { "id" : """14411""", "rate" : """9.92807835183604""" },
    { "id" : """14413""", "rate" : """14.9999""" },
    { "id" : """14419""", "rate" : """0.001""" },
    { "id" : """14453""", "rate" : """12.2587833333333""" },
    { "id" : """14457""", "rate" : """10.125348215""" },
    { "id" : """14462""", "rate" : """11.7364020525""" },
    { "id" : """14465""", "rate" : """9.05661936905263""" },
    { "id" : """14481""", "rate" : """10.7292216""" },
    { "id" : """14507""", "rate" : """6.58736926""" },
    { "id" : """14513""", "rate" : """11.9956113009091""" },
    { "id" : """14519""", "rate" : """14.2887408482871""" },
    { "id" : """14523""", "rate" : """7.28424863989637""" },
    { "id" : """15029""", "rate" : """13.6315592""" },
    { "id" : """15641""", "rate" : """3.99072231333333""" },
    { "id" : """15645""", "rate" : """18.9339276""" },
    { "id" : """15653""", "rate" : """6.76249426638298""" },
    { "id" : """15655""", "rate" : """9.837838295""" },
    { "id" : """15691""", "rate" : """18.8693""" },
    { "id" : """15699""", "rate" : """14.28083555""" },
    { "id" : """15706""", "rate" : """7.167587475""" },
    { "id" : """15738""", "rate" : """0.00084""" },
    { "id" : """15740""", "rate" : """4.9899405""" },
    { "id" : """15768""", "rate" : """8.318838""" },
    { "id" : """15770""", "rate" : """3.61843328333333""" },
    { "id" : """15804""", "rate" : """12.0840230047972""" },
    { "id" : """15813""", "rate" : """10.6197999""" },
    { "id" : """15817""", "rate" : """3.93653872804194""" },
    { "id" : """15818""", "rate" : """11.97389""" },
    { "id" : """15822""", "rate" : """16.17""" },
    { "id" : """15835""", "rate" : """12.18120847923""" },
    { "id" : """15840""", "rate" : """1""" },
    { "id" : """15843""", "rate" : """9.72486043434783""" },
    { "id" : """15863""", "rate" : """5.897888""" },
    { "id" : """15870""", "rate" : """11.7683733333333""" },
    { "id" : """15886""", "rate" : """8.0261797375""" },
    { "id" : """15916""", "rate" : """8.00118""" },
    { "id" : """15952""", "rate" : """20.247541905""" },
    { "id" : """15962""", "rate" : """17.3241345666667""" },
    { "id" : """15990""", "rate" : """6.34167788700008""" },
    { "id" : """15996""", "rate" : """11.9961985186316""" },
    { "id" : """16002""", "rate" : """17.5756076923077""" },
    { "id" : """16016""", "rate" : """11.5613495""" },
    { "id" : """16018""", "rate" : """15.88547344""" },
    { "id" : """16059""", "rate" : """12.2403944444444""" },
    { "id" : """16109""", "rate" : """19.6381539275""" },
    { "id" : """16131""", "rate" : """18.4688504076923""" },
    { "id" : """16140""", "rate" : """3.76685202963333""" },
    { "id" : """16176""", "rate" : """12.5601249283774""" },
    { "id" : """16179""", "rate" : """15.3459058823529""" },
    { "id" : """16185""", "rate" : """9.99355341""" },
    { "id" : """16189""", "rate" : """8.45076708909091""" },
    { "id" : """16195""", "rate" : """7.9807818""" },
    { "id" : """16201""", "rate" : """13.0227081333333""" },
    { "id" : """16203""", "rate" : """10.5720241857143""" },
    { "id" : """16218""", "rate" : """4.97278955264""" },
    { "id" : """16224""", "rate" : """8.72186119295774""" },
    { "id" : """16228""", "rate" : """8.553339396""" },
    { "id" : """16229""", "rate" : """19.0303360980385""" },
    { "id" : """16252""", "rate" : """18.5542598769231""" },
    { "id" : """16255""", "rate" : """22.0573933316667""" },
    { "id" : """16258""", "rate" : """1""" },
    { "id" : """16261""", "rate" : """15.296961""" },
    { "id" : """16275""", "rate" : """3.89175430493333""" },
    { "id" : """16278""", "rate" : """12.9697900578947""" },
    { "id" : """16285""", "rate" : """13.6201824833333""" },
    { "id" : """16288""", "rate" : """9.96753752""" },
    { "id" : """16290""", "rate" : """10.921928355875""" },
    { "id" : """16303""", "rate" : """8.67553325333333""" },
    { "id" : """16307""", "rate" : """12.4254900578947""" },
    { "id" : """16322""", "rate" : """21.5307515764706""" },
    { "id" : """16332""", "rate" : """13.5931189529412""" },
    { "id" : """16340""", "rate" : """5.44623053714286""" },
    { "id" : """16351""", "rate" : """14.3179177733333""" },
    { "id" : """16364""", "rate" : """12.278511308""" },
    { "id" : """16368""", "rate" : """14.9995""" },
    { "id" : """16369""", "rate" : """15.6997582875""" },
    { "id" : """16370""", "rate" : """15.73542065""" },
    { "id" : """16385""", "rate" : """12""" },
    { "id" : """16386""", "rate" : """13.5394819923077""" },
    { "id" : """16388""", "rate" : """6.4096228375""" },
    { "id" : """16390""", "rate" : """14.1343315319333""" },
    { "id" : """16396""", "rate" : """12.4926152625""" },
    { "id" : """16407""", "rate" : """8.927223733""" },
    { "id" : """16419""", "rate" : """12.8254718941176""" },
    { "id" : """16424""", "rate" : """11.01847232""" },
    { "id" : """16426""", "rate" : """13.4889118475""" },
    { "id" : """16440""", "rate" : """12.2564285714286""" },
    { "id" : """16441""", "rate" : """12.4537647058824""" },
    { "id" : """16445""", "rate" : """13.6184380357143""" },
    { "id" : """16454""", "rate" : """14.7444941176471""" },
    { "id" : """16460""", "rate" : """13.686161446875""" },
    { "id" : """16463""", "rate" : """18.0342366142857""" },
    { "id" : """16465""", "rate" : """12.4474769230769""" },
    { "id" : """16479""", "rate" : """9.42605075""" },
    { "id" : """16491""", "rate" : """14.9962313294118""" },
    { "id" : """16513""", "rate" : """16.503607984""" },
    { "id" : """16516""", "rate" : """18.6669953""" },
    { "id" : """16521""", "rate" : """14.7118466333333""" },
    { "id" : """16533""", "rate" : """14.83035""" },
    { "id" : """16534""", "rate" : """12.9915384615385""" },
    { "id" : """16536""", "rate" : """19.5875078""" },
    { "id" : """16544""", "rate" : """10.5555714285714""" },
    { "id" : """16545""", "rate" : """10.6793269141639""" },
    { "id" : """16548""", "rate" : """8.70845263157895""" },
    { "id" : """16549""", "rate" : """13.3777527388889""" },
    { "id" : """16551""", "rate" : """10.6274897268293""" },
    { "id" : """16552""", "rate" : """9.03689729666667""" },
    { "id" : """16558""", "rate" : """6.82419221""" },
    { "id" : """16560""", "rate" : """16.5258457142857""" },
    { "id" : """16574""", "rate" : """13.50061766""" },
    { "id" : """16581""", "rate" : """8.103821638""" },
    { "id" : """16586""", "rate" : """14.72459256""" },
    { "id" : """16593""", "rate" : """7.8646468466""" },
    { "id" : """16596""", "rate" : """5.0270125892""" },
    { "id" : """16606""", "rate" : """11.9402839357143""" },
    { "id" : """16617""", "rate" : """14.5918""" },
    { "id" : """16625""", "rate" : """12.6339222222222""" },
    { "id" : """16631""", "rate" : """9.53324529913334""" },
    { "id" : """16639""", "rate" : """16.1093956363636""" },
    { "id" : """16667""", "rate" : """14.8065858333333""" },
    { "id" : """16682""", "rate" : """14.3500246777778""" },
    { "id" : """16686""", "rate" : """18.5606903928571""" },
    { "id" : """16688""", "rate" : """1.24623674175""" },
    { "id" : """16690""", "rate" : """8.221923465625""" },
    { "id" : """16694""", "rate" : """6.83899654332""" },
    { "id" : """16696""", "rate" : """14.6677968114286""" },
    { "id" : """16769""", "rate" : """4.37257222222222""" },
    { "id" : """16772""", "rate" : """5.25082786297297""" },
    { "id" : """16775""", "rate" : """10.1387952533333""" },
    { "id" : """16790""", "rate" : """20.81122915""" },
    { "id" : """16812""", "rate" : """12.2648529538462""" },
    { "id" : """16813""", "rate" : """3.638998""" },
    { "id" : """16860""", "rate" : """10.5129907333333""" },
    { "id" : """16868""", "rate" : """11.8793666666667""" },
    { "id" : """16869""", "rate" : """14.0399566216667""" },
    { "id" : """16874""", "rate" : """9.80688892475""" },
    { "id" : """16876""", "rate" : """9.92773941230769""" },
    { "id" : """16893""", "rate" : """16.05044""" },
    { "id" : """16919""", "rate" : """8.483694752""" },
    { "id" : """16925""", "rate" : """3.56005548""" },
    { "id" : """16956""", "rate" : """12.7897684210526""" },
    { "id" : """16961""", "rate" : """9.26645""" },
    { "id" : """16962""", "rate" : """9.81618387096774""" },
    { "id" : """16977""", "rate" : """12.159918""" },
    { "id" : """16989""", "rate" : """16.8521657142857""" },
    { "id" : """16996""", "rate" : """9.9578296""" },
    { "id" : """17000""", "rate" : """5.90524348872045""" },
    { "id" : """17025""", "rate" : """17.292603992""" },
    { "id" : """17030""", "rate" : """13.2422571428571""" },
    { "id" : """17035""", "rate" : """11.89337264""" },
    { "id" : """17036""", "rate" : """14.203045555""" },
    { "id" : """17064""", "rate" : """3.35479999186992""" },
    { "id" : """17152""", "rate" : """9.49491332338144""" },
    { "id" : """17161""", "rate" : """3.6535808065""" },
    { "id" : """17177""", "rate" : """2.9994506504839""" },
    { "id" : """17182""", "rate" : """11.976190397619""" },
    { "id" : """17189""", "rate" : """9.68327286795833""" },
    { "id" : """17288""", "rate" : """10.4762444222222""" },
    { "id" : """17289""", "rate" : """10.0512088888889""" },
    { "id" : """17304""", "rate" : """9.696675""" },
    { "id" : """17310""", "rate" : """4.86080666707143""" },
    { "id" : """17313""", "rate" : """10.3893204035104""" },
    { "id" : """17322""", "rate" : """12.6728819577333""" },
    { "id" : """17344""", "rate" : """6.88951532333333""" },
    { "id" : """17348""", "rate" : """13.3272970590909""" },
    { "id" : """17357""", "rate" : """12.2322995""" },
    { "id" : """17363""", "rate" : """12.2380142857143""" },
    { "id" : """17365""", "rate" : """17.526744""" },
    { "id" : """17375""", "rate" : """10.7195128""" },
    { "id" : """17377""", "rate" : """10.266396776""" },
    { "id" : """17383""", "rate" : """5.21781827761905""" },
    { "id" : """17395""", "rate" : """0.00084""" },
    { "id" : """17419""", "rate" : """11.4813619892308""" },
    { "id" : """17431""", "rate" : """5.06610385""" },
    { "id" : """17436""", "rate" : """12.4155859186667""" },
    { "id" : """17497""", "rate" : """7.60066818512875""" },
    { "id" : """17498""", "rate" : """15.7146073888511""" },
    { "id" : """17507""", "rate" : """12.0585050761667""" },
    { "id" : """17540""", "rate" : """5.44166416728""" },
    { "id" : """17542""", "rate" : """15.1804839941667""" },
    { "id" : """17543""", "rate" : """5.2922""" },
    { "id" : """17636""", "rate" : """4.9899""" },
    { "id" : """17661""", "rate" : """16.6932311972867""" },
    { "id" : """17668""", "rate" : """0.883062376756699""" },
    { "id" : """17690""", "rate" : """9.912218""" },
    { "id" : """17691""", "rate" : """10.1953106029412""" },
    { "id" : """17702""", "rate" : """9.19374352263637""" },
    { "id" : """17735""", "rate" : """11.72962588""" },
    { "id" : """17739""", "rate" : """10""" },
    { "id" : """17758""", "rate" : """9.21738034""" },
    { "id" : """17767""", "rate" : """4.9906894""" },
    { "id" : """17770""", "rate" : """5.557263326""" },
    { "id" : """17783""", "rate" : """2.7597328""" },
    { "id" : """17790""", "rate" : """12.1300785714286""" },
    { "id" : """17800""", "rate" : """11.568372124""" },
    { "id" : """17818""", "rate" : """9.0016998""" },
    { "id" : """17839""", "rate" : """7.42689828571429""" },
    { "id" : """17846""", "rate" : """15.4353838926667""" },
    { "id" : """17857""", "rate" : """10.83419125""" },
    { "id" : """17866""", "rate" : """5.45330887142""" },
    { "id" : """17874""", "rate" : """9.45013523603575""" },
    { "id" : """17902""", "rate" : """7.03""" },
    { "id" : """17905""", "rate" : """11.4063039521""" },
    { "id" : """17922""", "rate" : """9.9811975""" },
    { "id" : """17925""", "rate" : """7.99724339839265""" },
    { "id" : """17940""", "rate" : """4.1753596832""" },
    { "id" : """17964""", "rate" : """7.5732431402439""" },
    { "id" : """17971""", "rate" : """10.5192146913979""" },
    { "id" : """17983""", "rate" : """11.9143249708947""" },
    { "id" : """17990""", "rate" : """4.96372866333333""" },
    { "id" : """18005""", "rate" : """13.11""" },
    { "id" : """18029""", "rate" : """7.24783263805517""" },
    { "id" : """18049""", "rate" : """13.987201""" },
    { "id" : """18061""", "rate" : """8.48571257142857""" },
    { "id" : """18092""", "rate" : """13.0111376923077""" },
    { "id" : """18094""", "rate" : """9.992""" },
    { "id" : """18105""", "rate" : """3.11199772""" },
    { "id" : """18111""", "rate" : """5.22910666666667""" },
    { "id" : """18114""", "rate" : """22.9864545454545""" },
    { "id" : """18129""", "rate" : """18.9740627586207""" },
    { "id" : """18149""", "rate" : """21.0411656333333""" },
    { "id" : """18151""", "rate" : """11.7546859677419""" },
    { "id" : """18152""", "rate" : """11.9331803143333""" },
    { "id" : """18161""", "rate" : """4.93214963148993""" },
    { "id" : """18167""", "rate" : """16.21""" },
    { "id" : """18178""", "rate" : """13.3115666""" },
    { "id" : """18199""", "rate" : """6.884086752""" },
    { "id" : """18231""", "rate" : """15.838023875""" },
    { "id" : """18242""", "rate" : """11.983572""" },
    { "id" : """18245""", "rate" : """10.9979706666667""" },
    { "id" : """18296""", "rate" : """10.71640997""" },
    { "id" : """18318""", "rate" : """8.226291992""" },
    { "id" : """18341""", "rate" : """4.99319413914286""" },
    { "id" : """18348""", "rate" : """11.2461118534286""" },
    { "id" : """18364""", "rate" : """3.63673227647059""" },
    { "id" : """18371""", "rate" : """12.46""" },
    { "id" : """18411""", "rate" : """13.0944167499167""" },
    { "id" : """18425""", "rate" : """3.7701127988""" },
    { "id" : """18450""", "rate" : """8.7679401225""" },
    { "id" : """18453""", "rate" : """13.7073384615385""" },
    { "id" : """18473""", "rate" : """18.7563281125""" },
    { "id" : """18483""", "rate" : """10.045376997""" },
    { "id" : """18488""", "rate" : """10.73""" },
    { "id" : """18511""", "rate" : """4.9999799965""" },
    { "id" : """18514""", "rate" : """8.77628226927273""" },
    { "id" : """18517""", "rate" : """8.90554328381818""" },
    { "id" : """18534""", "rate" : """4.25982215338346""" },
    { "id" : """18550""", "rate" : """7.49847783619048""" },
    { "id" : """18556""", "rate" : """12.1148688041176""" },
    { "id" : """18559""", "rate" : """5.8099044472""" },
    { "id" : """18560""", "rate" : """18.8136357878602""" },
    { "id" : """18562""", "rate" : """6.55""" },
    { "id" : """18579""", "rate" : """12.23599994""" },
    { "id" : """18591""", "rate" : """23.3055714285714""" },
    { "id" : """18609""", "rate" : """7.06582117424""" },
    { "id" : """18630""", "rate" : """12.9130559333333""" },
    { "id" : """18656""", "rate" : """8.41565994283334""" },
    { "id" : """18678""", "rate" : """6.90100916337""" },
    { "id" : """18701""", "rate" : """5.82368213333333""" },
    { "id" : """18722""", "rate" : """6.53216903463333""" },
    { "id" : """18750""", "rate" : """3.54531333333333""" },
    { "id" : """18761""", "rate" : """10.5820351738962""" },
    { "id" : """18822""", "rate" : """12.97008875""" },
    { "id" : """18864""", "rate" : """6.495829999""" },
    { "id" : """18868""", "rate" : """6.04050699300001""" },
    { "id" : """18879""", "rate" : """9.858595375""" },
    { "id" : """18883""", "rate" : """4.9998070425""" },
    { "id" : """18904""", "rate" : """9.83843806379166""" },
    { "id" : """18911""", "rate" : """15.2565435""" },
    { "id" : """18922""", "rate" : """6.05526515306123""" },
    { "id" : """18925""", "rate" : """8.87207887674418""" },
    { "id" : """18927""", "rate" : """11.8560185185185""" },
    { "id" : """18929""", "rate" : """12.3470609444667""" },
    { "id" : """18939""", "rate" : """14.8872942987986""" },
    { "id" : """18943""", "rate" : """13.5891163333333""" },
    { "id" : """18954""", "rate" : """13.328792""" },
    { "id" : """18961""", "rate" : """9.8466582738""" },
    { "id" : """18995""", "rate" : """4.9499429706""" },
    { "id" : """18997""", "rate" : """3.78113023533333""" },
    { "id" : """19011""", "rate" : """6.47678464530095""" },
    { "id" : """19016""", "rate" : """2.81835205623529""" },
    { "id" : """19022""", "rate" : """8.05477351978947""" },
    { "id" : """19049""", "rate" : """9.04790363636364""" },
    { "id" : """19054""", "rate" : """18.9717382587452""" },
    { "id" : """19065""", "rate" : """9.41521999719999""" },
    { "id" : """19109""", "rate" : """10.257591988""" },
    { "id" : """19111""", "rate" : """10.61131534""" },
    { "id" : """19115""", "rate" : """5.3433596397""" },
    { "id" : """19124""", "rate" : """11.6080375294118""" },
    { "id" : """19125""", "rate" : """8.43761923833333""" },
    { "id" : """19134""", "rate" : """11.30834875""" },
    { "id" : """19137""", "rate" : """8.63003071975""" },
    { "id" : """19140""", "rate" : """12.6857856750265""" },
    { "id" : """19194""", "rate" : """4.1261823""" },
    { "id" : """19228""", "rate" : """10.0587549805333""" },
    { "id" : """19239""", "rate" : """4.64920555555555""" },
    { "id" : """19240""", "rate" : """19.392003115625""" },
    { "id" : """19244""", "rate" : """7.66058176""" },
    { "id" : """19249""", "rate" : """7.71301178373675""" },
    { "id" : """19251""", "rate" : """10.870746564""" },
    { "id" : """19254""", "rate" : """6.48868135""" },
    { "id" : """19273""", "rate" : """9.96901""" },
    { "id" : """19291""", "rate" : """11.999834571""" },
    { "id" : """19315""", "rate" : """4.922836378""" },
    { "id" : """19317""", "rate" : """11.9757280839""" },
    { "id" : """19385""", "rate" : """18.0923788751068""" },
    { "id" : """19387""", "rate" : """10.3980352005""" },
    { "id" : """19401""", "rate" : """4.99680937624156""" },
    { "id" : """19405""", "rate" : """14.910883868""" },
    { "id" : """19407""", "rate" : """20.2917997""" },
    { "id" : """19431""", "rate" : """14.7734071875""" },
    { "id" : """19432""", "rate" : """11.0064773238999""" },
    { "id" : """19460""", "rate" : """7.51474332""" },
    { "id" : """19464""", "rate" : """4.51503637942""" },
    { "id" : """19484""", "rate" : """4.8""" },
    { "id" : """19489""", "rate" : """7.28855524""" },
    { "id" : """19497""", "rate" : """9.4703946124""" },
    { "id" : """19509""", "rate" : """6.99113387442857""" },
    { "id" : """19541""", "rate" : """13.1200599925""" },
    { "id" : """19552""", "rate" : """7.16249582258824""" },
    { "id" : """19559""", "rate" : """7.45131858822222""" },
    { "id" : """19615""", "rate" : """15.11135188""" },
    { "id" : """19623""", "rate" : """7.32313676363636""" },
    { "id" : """19632""", "rate" : """8.000306697""" },
    { "id" : """19635""", "rate" : """10.4668383674419""" },
    { "id" : """19639""", "rate" : """8.9090351466""" },
    { "id" : """19682""", "rate" : """5.7851651032""" },
    { "id" : """19697""", "rate" : """9.0442920052""" },
    { "id" : """19710""", "rate" : """2.86393396057143""" },
    { "id" : """19719""", "rate" : """2.95447961704615""" },
    { "id" : """19732""", "rate" : """23.5658166666667""" },
    { "id" : """19735""", "rate" : """9.82683333333334""" },
    { "id" : """19751""", "rate" : """7.99049075901639""" },
    { "id" : """19754""", "rate" : """9.065599996""" },
    { "id" : """19790""", "rate" : """9.9331993""" },
    { "id" : """19792""", "rate" : """6.99965553934899""" },
    { "id" : """19795""", "rate" : """3.6399999976""" },
    { "id" : """19798""", "rate" : """4.9983496852""" },
    { "id" : """19811""", "rate" : """6.49798241666667""" },
    { "id" : """19816""", "rate" : """9.986018673""" },
    { "id" : """19863""", "rate" : """8.01037670666667""" },
    { "id" : """19869""", "rate" : """4.93873""" },
    { "id" : """19872""", "rate" : """4.44917264""" },
    { "id" : """19888""", "rate" : """3.95572538933333""" },
    { "id" : """19895""", "rate" : """4.1634583994""" },
    { "id" : """19910""", "rate" : """7.99993333333333""" },
    { "id" : """19915""", "rate" : """5.152319997""" },
    { "id" : """19919""", "rate" : """4.8466596958""" },
    { "id" : """19925""", "rate" : """8.99275862068965""" },
    { "id" : """19929""", "rate" : """7.25784797888889""" },
    { "id" : """19949""", "rate" : """23.546101520339""" },
    { "id" : """19953""", "rate" : """8.06585797145834""" },
    { "id" : """20037""", "rate" : """11.6273102245555""" },
    { "id" : """20054""", "rate" : """8.43454873""" },
    { "id" : """20091""", "rate" : """5.09869915034286""" },
    { "id" : """20117""", "rate" : """11.9993968""" },
    { "id" : """20124""", "rate" : """9.89733656708333""" },
    { "id" : """20139""", "rate" : """14.8513616526897""" },
    { "id" : """20157""", "rate" : """15.4708740660726""" },
    { "id" : """20166""", "rate" : """11.9279112416364""" },
    { "id" : """20173""", "rate" : """14.13937398""" },
    { "id" : """20178""", "rate" : """4.89539699646643""" },
    { "id" : """20180""", "rate" : """6.23268587409091""" },
    { "id" : """20185""", "rate" : """16.21176""" },
    { "id" : """20195""", "rate" : """5.807196637125""" },
    { "id" : """20197""", "rate" : """12.1094704839""" },
    { "id" : """20209""", "rate" : """5.04848615971429""" },
    { "id" : """20217""", "rate" : """22.4199788888889""" },
    { "id" : """20234""", "rate" : """3.6649127085""" },
    { "id" : """20244""", "rate" : """6.7440358586""" },
    { "id" : """20248""", "rate" : """8.7346118""" },
    { "id" : """20251""", "rate" : """9.73930680555556""" },
    { "id" : """20257""", "rate" : """4.8247876912""" },
    { "id" : """20259""", "rate" : """6.46092817618269""" },
    { "id" : """20261""", "rate" : """12.99""" },
    { "id" : """20296""", "rate" : """7.701348575""" },
    { "id" : """20297""", "rate" : """6.9384911803""" },
    { "id" : """20309""", "rate" : """5.92966601933""" },
    { "id" : """20311""", "rate" : """9.88349555555556""" },
    { "id" : """20321""", "rate" : """11.6411199866667""" },
    { "id" : """20334""", "rate" : """8.18462245901639""" },
    { "id" : """20340""", "rate" : """6.34226547236058""" },
    { "id" : """20367""", "rate" : """9.83401140591667""" },
    { "id" : """20369""", "rate" : """5""" },
    { "id" : """20394""", "rate" : """19.7517456445993""" },
    { "id" : """20422""", "rate" : """15.4696004712766""" },
    { "id" : """20430""", "rate" : """8.8368973""" },
    { "id" : """20432""", "rate" : """7.95109751""" },
    { "id" : """20449""", "rate" : """15.81446""" },
    { "id" : """20462""", "rate" : """5.58416795754717""" },
    { "id" : """20475""", "rate" : """5.39036198342857""" },
    { "id" : """20483""", "rate" : """4.76774442203776""" },
    { "id" : """20494""", "rate" : """17.2138771016338""" },
    { "id" : """20498""", "rate" : """5.65273033283333""" },
    { "id" : """20505""", "rate" : """3.90260883786667""" },
    { "id" : """20525""", "rate" : """11.27182""" },
    { "id" : """20560""", "rate" : """17.02999164""" },
    { "id" : """20564""", "rate" : """1""" },
    { "id" : """20600""", "rate" : """12.93542139625""" },
    { "id" : """20601""", "rate" : """9.911684597""" },
    { "id" : """20612""", "rate" : """14.770731939""" },
    { "id" : """20630""", "rate" : """6.9966611075""" },
    { "id" : """20633""", "rate" : """7.97331194375""" },
    { "id" : """20635""", "rate" : """4.88379162052""" },
    { "id" : """20636""", "rate" : """4.89907""" },
    { "id" : """20640""", "rate" : """70.5325491428571""" },
    { "id" : """20677""", "rate" : """13.69496""" },
    { "id" : """20679""", "rate" : """7.964""" },
    { "id" : """20701""", "rate" : """14.1135877862595""" },
    { "id" : """20712""", "rate" : """10.21707657""" },
    { "id" : """20747""", "rate" : """6.09373157111111""" },
    { "id" : """20752""", "rate" : """9.343689948""" },
    { "id" : """20758""", "rate" : """12.2577141818182""" },
    { "id" : """20760""", "rate" : """5.48437614588""" },
    { "id" : """20761""", "rate" : """18.454533994""" },
    { "id" : """20785""", "rate" : """6.99937568076875""" },
    { "id" : """20800""", "rate" : """5.163284425""" },
    { "id" : """20805""", "rate" : """1.682296684""" },
    { "id" : """20841""", "rate" : """21.48222""" },
    { "id" : """20865""", "rate" : """11.3191020101781""" },
    { "id" : """20875""", "rate" : """10.5170177134286""" },
    { "id" : """20892""", "rate" : """9.9218""" },
    { "id" : """20899""", "rate" : """23.1671593990338""" },
    { "id" : """20925""", "rate" : """23.3186799""" },
    { "id" : """20928""", "rate" : """4.980636538""" },
    { "id" : """20935""", "rate" : """23.0640606060606""" },
    { "id" : """20947""", "rate" : """9.97162216199377""" },
    { "id" : """20951""", "rate" : """30.7468479175387""" },
    { "id" : """20968""", "rate" : """9.62479997333334""" },
    { "id" : """20970""", "rate" : """1.741095696""" },
    { "id" : """20976""", "rate" : """26.88831475""" },
    { "id" : """20983""", "rate" : """5.02840621286667""" },
    { "id" : """20987""", "rate" : """7.19695733333334""" },
    { "id" : """20997""", "rate" : """7.7895""" },
    { "id" : """21004""", "rate" : """6.17570857133333""" },
    { "id" : """21029""", "rate" : """9.73482357255272""" },
    { "id" : """21037""", "rate" : """10.7742820343911""" },
    { "id" : """21038""", "rate" : """3.98277777777778""" },
    { "id" : """21070""", "rate" : """12.4771315922222""" },
    { "id" : """21088""", "rate" : """4.99151047841667""" },
    { "id" : """21093""", "rate" : """9.00584407""" },
    { "id" : """21105""", "rate" : """9.10464188304721""" },
    { "id" : """21111""", "rate" : """17.0920388""" },
    { "id" : """21171""", "rate" : """11.8914649177396""" },
    { "id" : """21176""", "rate" : """4.976095644""" },
    { "id" : """21181""", "rate" : """6.95307775862069""" },
    { "id" : """21228""", "rate" : """5.43864646150658""" },
    { "id" : """21233""", "rate" : """9.92497410714286""" },
    { "id" : """21262""", "rate" : """4.45381887550201""" },
    { "id" : """21266""", "rate" : """9.98759936444445""" },
    { "id" : """21275""", "rate" : """2.99315789583333""" },
    { "id" : """21277""", "rate" : """17.6744101123595""" },
    { "id" : """21281""", "rate" : """10.545908588""" },
    { "id" : """21286""", "rate" : """9.10364642828828""" },
    { "id" : """21305""", "rate" : """17.4507081764706""" },
    { "id" : """21307""", "rate" : """3.8935""" },
    { "id" : """21308""", "rate" : """5""" },
    { "id" : """21311""", "rate" : """7.92609755""" },
    { "id" : """21316""", "rate" : """8.72289298729742""" },
    { "id" : """21330""", "rate" : """6.91160368065218""" },
    { "id" : """21333""", "rate" : """17.2751347856192""" },
    { "id" : """21340""", "rate" : """10.4942947019868""" },
    { "id" : """21367""", "rate" : """5.88371405517143""" },
    { "id" : """21389""", "rate" : """7.90398016834171""" },
    { "id" : """21391""", "rate" : """17.916""" },
    { "id" : """21401""", "rate" : """8.16802913058824""" },
    { "id" : """21402""", "rate" : """7.6974830952381""" },
    { "id" : """21406""", "rate" : """18""" },
    { "id" : """21408""", "rate" : """5.48854280909091""" },
    { "id" : """21409""", "rate" : """12.0218751780822""" },
    { "id" : """21418""", "rate" : """6.90204276515151""" },
    { "id" : """21422""", "rate" : """42.336184""" },
    { "id" : """21428""", "rate" : """2.11157045""" },
    { "id" : """21448""", "rate" : """13.7402076120312""" },
    { "id" : """21464""", "rate" : """12.3772065810173""" },
    { "id" : """21466""", "rate" : """8.89166812253201""" },
    { "id" : """21478""", "rate" : """15.5371154955427""" },
    { "id" : """21493""", "rate" : """0.9294955""" },
    { "id" : """21509""", "rate" : """79.4077192777778""" },
    { "id" : """21512""", "rate" : """7.23788461538462""" },
    { "id" : """21515""", "rate" : """38.5729724324324""" },
    { "id" : """21518""", "rate" : """10.0955971631206""" },
    { "id" : """21532""", "rate" : """14.0844170499461""" },
    { "id" : """21534""", "rate" : """11.5353327546667""" },
    { "id" : """21550""", "rate" : """9.98981672413793""" },
    { "id" : """21562""", "rate" : """6.43750574064961""" },
    { "id" : """21566""", "rate" : """15""" },
    { "id" : """21572""", "rate" : """5""" },
    { "id" : """21573""", "rate" : """5.99999917055469""" },
    { "id" : """21583""", "rate" : """7.53553414634146""" },
    { "id" : """21591""", "rate" : """7.47470999689055""" },
    { "id" : """21594""", "rate" : """12.77""" },
    { "id" : """21596""", "rate" : """4.96270225433526""" },
    { "id" : """21598""", "rate" : """9.99090909090909""" },
]

# %%
raw_data
# Out:
# [{'id': '14', 'rate': '10'},
#  {'id': '63', 'rate': '10'},
#  {'id': '216', 'rate': '15'},
#  {'id': '324', 'rate': '15.3202134756504'},
#  {'id': '326', 'rate': '6.66666666666667'},
#  {'id': '330', 'rate': '15'},
#  {'id': '338', 'rate': '12.375'},
#  {'id': '343', 'rate': '23.465'},
#  {'id': '345', 'rate': '10'},
#  {'id': '360', 'rate': '10'},
#  {'id': '365', 'rate': '9.76439790575916'},
#  {'id': '366', 'rate': '10'},
#  {'id': '372', 'rate': '15'},
#  {'id': '377', 'rate': '10'},
#  {'id': '380', 'rate': '10'},
#  {'id': '396', 'rate': '10'},
#  {'id': '398', 'rate': '10'},
#  {'id': '745', 'rate': '10.1375'},
#  {'id': '747', 'rate': '9.75147177142857'},
#  {'id': '752', 'rate': '10'},
#  {'id': '769', 'rate': '1e-05'},
#  {'id': '776', 'rate': '10'},
#  {'id': '777', 'rate': '9.95'},
#  {'id': '780', 'rate': '5.904929848'},
#  {'id': '792', 'rate': '9.66371435714286'},
#  {'id': '802', 'rate': '9.399930776'},
#  {'id': '815', 'rate': '4.07499983672535'},
# ...

# %%
s = pd.Series([float(x['rate']) for x in raw_data])

# %%
s.hist(bins=25,range=[0,20], label="Interest rate")
